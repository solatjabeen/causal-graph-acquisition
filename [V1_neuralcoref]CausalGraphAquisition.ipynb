# %% [markdown]
# # Import necessary libraries.

# %%
import spacy
import textacy
import textacy.preprocessing
import textacy.resources
#import textacy.keyterms
import textacy.ke
import neuralcoref
from spacy.symbols import ORTH, POS, NOUN, VERB,PRON
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt 
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from networkx.readwrite import json_graph;
import json
from afinn import Afinn
afn = Afinn()
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
lemmatizer = WordNetLemmatizer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from allennlp_models.pretrained import load_predictor
predictor = load_predictor("roberta-sst")
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('C:/SentiStrength/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('C:/SentiStrength/SentStrength_Data_Sept2011/')
import pandas as pd
from IPython.display import display
import collections
from nltk.corpus import stopwords
set(stopwords.words('english'))
from pd_replicator import replicator

nlp = spacy.load("en_core_web_sm")
neuralcoref.add_to_pipe(nlp)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp\tango\__init__.py:18: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   "AllenNLP Tango is an experimental API and parts of it might change or disappear "
# 2022-05-06 05:40:39,179 - ERROR - allennlp.common.plugins - Plugin allennlp_models could not be loaded: No module named 'nltk.translate.meteor_score'
# 2022-05-06 05:40:39,220 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\coref-spanbert.json as plain json
# 2022-05-06 05:40:39,233 - INFO - allennlp.common.params - id = coref-spanbert
# 2022-05-06 05:40:39,235 - INFO - allennlp.common.params - type = coref-spanbert
# 2022-05-06 05:40:39,237 - INFO - allennlp.common.params - registered_model_name = coref
# 2022-05-06 05:40:39,240 - INFO - allennlp.common.params - type = coref
# 2022-05-06 05:40:39,242 - INFO - allennlp.common.params - model_class = None
# 2022-05-06 05:40:39,244 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-06 05:40:39,245 - INFO - allennlp.common.params - display_name = Coreference Resolution
# 2022-05-06 05:40:39,248 - INFO - allennlp.common.params - type = Coreference Resolution
# 2022-05-06 05:40:39,250 - INFO - allennlp.common.params - task_id = coref
# 2022-05-06 05:40:39,252 - INFO - allennlp.common.params - type = coref
# 2022-05-06 05:40:39,254 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:39,260 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:39,266 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:39,272 - INFO - allennlp.common.params - model_usage.archive_file = coref-spanbert-large-2021.03.10.tar.gz
# 2022-05-06 05:40:39,275 - INFO - allennlp.common.params - type = coref-spanbert-large-2021.03.10.tar.gz
# 2022-05-06 05:40:39,282 - INFO - allennlp.common.params - model_usage.training_config = coref/coref_spanbert_large.jsonnet
# 2022-05-06 05:40:39,284 - INFO - allennlp.common.params - type = coref/coref_spanbert_large.jsonnet
# 2022-05-06 05:40:39,291 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-06 05:40:39,294 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-06 05:40:39,300 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-06 05:40:39,303 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:39,311 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:39,315 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:39,321 - INFO - allennlp.common.params - model_details.description = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2022-05-06 05:40:39,323 - INFO - allennlp.common.params - type = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2022-05-06 05:40:39,336 - INFO - allennlp.common.params - model_details.short_description = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2022-05-06 05:40:39,338 - INFO - allennlp.common.params - type = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2022-05-06 05:40:39,343 - INFO - allennlp.common.params - model_details.developed_by = Lee et al
# 2022-05-06 05:40:39,346 - INFO - allennlp.common.params - type = Lee et al
# 2022-05-06 05:40:39,348 - INFO - allennlp.common.params - model_details.contributed_by = Zhaofeng Wu
# 2022-05-06 05:40:39,351 - INFO - allennlp.common.params - type = Zhaofeng Wu
# 2022-05-06 05:40:39,353 - INFO - allennlp.common.params - model_details.date = 2020-02-27
# 2022-05-06 05:40:39,356 - INFO - allennlp.common.params - type = 2020-02-27
# 2022-05-06 05:40:39,358 - INFO - allennlp.common.params - model_details.version = 2
# 2022-05-06 05:40:39,361 - INFO - allennlp.common.params - type = 2
# 2022-05-06 05:40:39,363 - INFO - allennlp.common.params - model_details.model_type = SpanBERT
# 2022-05-06 05:40:39,366 - INFO - allennlp.common.params - type = SpanBERT
# 2022-05-06 05:40:39,369 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:39,376 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:39,380 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:39,385 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lee2018HigherorderCR,
# title={Higher-order Coreference Resolution with Coarse-to-fine Inference},
# author={Kenton Lee and Luheng He and L. Zettlemoyer},
# booktitle={NAACL-HLT},
# year={2018}}
#
# 2022-05-06 05:40:39,387 - INFO - allennlp.common.params - model_details.paper.title = Higher-order Coreference Resolution with Coarse-to-fine Inference
# 2022-05-06 05:40:39,388 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:4891749
# 2022-05-06 05:40:39,390 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-06 05:40:39,392 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-06 05:40:39,395 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-06 05:40:39,404 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:39,415 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:39,422 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:39,431 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-06 05:40:39,434 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-06 05:40:39,437 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-06 05:40:39,441 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:39,444 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:39,462 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:39,471 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-06 05:40:39,473 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-06 05:40:39,475 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:39,484 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:39,492 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:39,500 - INFO - allennlp.common.params - metrics.model_performance_measures = CoNLL coref scores and Mention Recall
# 2022-05-06 05:40:39,502 - INFO - allennlp.common.params - type = CoNLL coref scores and Mention Recall
# 2022-05-06 05:40:39,504 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-06 05:40:39,507 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-06 05:40:39,510 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:39,518 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:39,525 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:39,531 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:39,549 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:39,554 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:39,560 - INFO - allennlp.common.params - evaluation_data.dataset.name = Ontonotes 5.0
# 2022-05-06 05:40:39,562 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2022-05-06 05:40:39,564 - INFO - allennlp.common.params - evaluation_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2022-05-06 05:40:39,566 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = /path/to/dataset
# 2022-05-06 05:40:39,568 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-06 05:40:39,570 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-06 05:40:39,573 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:39,596 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:39,604 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:39,612 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:39,619 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:39,625 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:39,632 - INFO - allennlp.common.params - training_data.dataset.name = Ontonotes 5.0
# 2022-05-06 05:40:39,639 - INFO - allennlp.common.params - training_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2022-05-06 05:40:39,641 - INFO - allennlp.common.params - training_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2022-05-06 05:40:39,645 - INFO - allennlp.common.params - training_data.dataset.processed_url = /path/to/dataset
# 2022-05-06 05:40:39,647 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-06 05:40:39,649 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2022-05-06 05:40:39,652 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:39,657 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:39,663 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:39,668 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2022-05-06 05:40:39,671 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-06 05:40:39,673 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:39,679 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:39,686 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:39,693 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-06 05:40:39,696 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:39,703 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:39,710 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:39,716 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-06 05:40:39,721 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\evaluate_rc-lerc.json as plain json
# 2022-05-06 05:40:39,742 - INFO - allennlp.common.params - id = evaluate_rc-lerc
# 2022-05-06 05:40:39,745 - INFO - allennlp.common.params - type = evaluate_rc-lerc
# 2022-05-06 05:40:39,748 - INFO - allennlp.common.params - registered_model_name = lerc
# 2022-05-06 05:40:39,752 - INFO - allennlp.common.params - type = lerc
# 2022-05-06 05:40:39,755 - INFO - allennlp.common.params - model_class = None
# 2022-05-06 05:40:39,758 - INFO - allennlp.common.params - registered_predictor_name = lerc
# 2022-05-06 05:40:39,761 - INFO - allennlp.common.params - type = lerc
# 2022-05-06 05:40:39,764 - INFO - allennlp.common.params - display_name = Learned Evaluation for Reading Comprehension (LERC)
# 2022-05-06 05:40:39,767 - INFO - allennlp.common.params - type = Learned Evaluation for Reading Comprehension (LERC)
# 2022-05-06 05:40:39,770 - INFO - allennlp.common.params - task_id = evaluate_rc
# 2022-05-06 05:40:39,771 - INFO - allennlp.common.params - type = evaluate_rc
# 2022-05-06 05:40:39,773 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:39,797 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:39,803 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:39,808 - INFO - allennlp.common.params - model_usage.archive_file = lerc-2020-11-18.tar.gz
# 2022-05-06 05:40:39,811 - INFO - allennlp.common.params - type = lerc-2020-11-18.tar.gz
# 2022-05-06 05:40:39,817 - INFO - allennlp.common.params - model_usage.training_config = None
# 2022-05-06 05:40:39,831 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-06 05:40:39,835 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-06 05:40:39,845 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-06 05:40:39,850 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:39,857 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:39,864 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:39,871 - INFO - allennlp.common.params - model_details.description = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2022-05-06 05:40:39,874 - INFO - allennlp.common.params - type = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2022-05-06 05:40:39,882 - INFO - allennlp.common.params - model_details.short_description = A BERT model that scores candidate answers from 0 to 1.
# 2022-05-06 05:40:39,885 - INFO - allennlp.common.params - type = A BERT model that scores candidate answers from 0 to 1.
# 2022-05-06 05:40:39,892 - INFO - allennlp.common.params - model_details.developed_by = Chen et al
# 2022-05-06 05:40:39,895 - INFO - allennlp.common.params - type = Chen et al
# 2022-05-06 05:40:39,897 - INFO - allennlp.common.params - model_details.contributed_by = Anthony Chen
# 2022-05-06 05:40:39,899 - INFO - allennlp.common.params - type = Anthony Chen
# 2022-05-06 05:40:39,901 - INFO - allennlp.common.params - model_details.date = 2021-03-10
# 2022-05-06 05:40:39,904 - INFO - allennlp.common.params - type = 2021-03-10
# 2022-05-06 05:40:39,906 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-06 05:40:39,907 - INFO - allennlp.common.params - type = 1
# 2022-05-06 05:40:39,910 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2022-05-06 05:40:39,912 - INFO - allennlp.common.params - type = BERT
# 2022-05-06 05:40:39,915 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:39,921 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:39,927 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:39,933 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Chen2020MOCHAAD,
# title={MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics},
# author={Anthony Chen and Gabriel Stanovsky and S. Singh and Matt Gardner},
# booktitle={EMNLP},
# year={2020}}
#
# 2022-05-06 05:40:39,935 - INFO - allennlp.common.params - model_details.paper.title = MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics
# 2022-05-06 05:40:39,936 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:222208714
# 2022-05-06 05:40:39,938 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-06 05:40:39,941 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-06 05:40:39,943 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-06 05:40:39,954 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:39,960 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:39,966 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:39,972 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-06 05:40:39,974 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-06 05:40:39,976 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-06 05:40:39,979 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:39,984 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:40,001 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:40,008 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-06 05:40:40,011 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-06 05:40:40,015 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:40,022 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:40,031 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:40,038 - INFO - allennlp.common.params - metrics.model_performance_measures = Pearson Correlation
# 2022-05-06 05:40:40,041 - INFO - allennlp.common.params - type = Pearson Correlation
# 2022-05-06 05:40:40,043 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-06 05:40:40,045 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-06 05:40:40,048 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:40,057 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:40,065 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:40,073 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:40,113 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:40,119 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:40,125 - INFO - allennlp.common.params - evaluation_data.dataset.name = MOCHA
# 2022-05-06 05:40:40,127 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://allennlp.org/mocha
# 2022-05-06 05:40:40,129 - INFO - allennlp.common.params - evaluation_data.dataset.notes = To evaluate this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2022-05-06 05:40:40,131 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = None
# 2022-05-06 05:40:40,133 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-06 05:40:40,135 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-06 05:40:40,138 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:40,144 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:40,150 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:40,156 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:40,162 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:40,167 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:40,187 - INFO - allennlp.common.params - training_data.dataset.name = MOCHA
# 2022-05-06 05:40:40,188 - INFO - allennlp.common.params - training_data.dataset.url = https://allennlp.org/mocha
# 2022-05-06 05:40:40,191 - INFO - allennlp.common.params - training_data.dataset.notes = To train this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2022-05-06 05:40:40,196 - INFO - allennlp.common.params - training_data.dataset.processed_url = None
# 2022-05-06 05:40:40,201 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-06 05:40:40,203 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2022-05-06 05:40:40,206 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:40,214 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:40,221 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:40,227 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2022-05-06 05:40:40,229 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-06 05:40:40,232 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:40,240 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:40,246 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:40,253 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-06 05:40:40,256 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:40,262 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:40,269 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:40,274 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-06 05:40:40,283 - WARNING - allennlp.common.model_card - lerc is not a registered model.
# 2022-05-06 05:40:40,294 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\generation-bart.json as plain json
# 2022-05-06 05:40:40,309 - INFO - allennlp.common.params - id = generation-bart
# 2022-05-06 05:40:40,312 - INFO - allennlp.common.params - type = generation-bart
# 2022-05-06 05:40:40,314 - INFO - allennlp.common.params - registered_model_name = bart
# 2022-05-06 05:40:40,316 - INFO - allennlp.common.params - type = bart
# 2022-05-06 05:40:40,319 - INFO - allennlp.common.params - model_class = None
# 2022-05-06 05:40:40,321 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-06 05:40:40,323 - INFO - allennlp.common.params - display_name = BART
# 2022-05-06 05:40:40,332 - INFO - allennlp.common.params - type = BART
# 2022-05-06 05:40:40,336 - INFO - allennlp.common.params - task_id = None
# 2022-05-06 05:40:40,339 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:40,347 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:40,356 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:40,381 - INFO - allennlp.common.params - model_usage.archive_file = bart-2020.07.25.tar.gz
# 2022-05-06 05:40:40,384 - INFO - allennlp.common.params - type = bart-2020.07.25.tar.gz
# 2022-05-06 05:40:40,391 - INFO - allennlp.common.params - model_usage.training_config = generation/bart_cnn_dm.jsonnet
# 2022-05-06 05:40:40,394 - INFO - allennlp.common.params - type = generation/bart_cnn_dm.jsonnet
# 2022-05-06 05:40:40,401 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-06 05:40:40,404 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-06 05:40:40,411 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-06 05:40:40,415 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:40,420 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:40,427 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:40,434 - INFO - allennlp.common.params - model_details.description = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2022-05-06 05:40:40,436 - INFO - allennlp.common.params - type = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2022-05-06 05:40:40,445 - INFO - allennlp.common.params - model_details.short_description = BART with a language model head for generation.
# 2022-05-06 05:40:40,447 - INFO - allennlp.common.params - type = BART with a language model head for generation.
# 2022-05-06 05:40:40,453 - INFO - allennlp.common.params - model_details.developed_by = Lewis et al
# 2022-05-06 05:40:40,456 - INFO - allennlp.common.params - type = Lewis et al
# 2022-05-06 05:40:40,458 - INFO - allennlp.common.params - model_details.contributed_by = Dirk Groeneveld
# 2022-05-06 05:40:40,460 - INFO - allennlp.common.params - type = Dirk Groeneveld
# 2022-05-06 05:40:40,462 - INFO - allennlp.common.params - model_details.date = 2020-07-25
# 2022-05-06 05:40:40,464 - INFO - allennlp.common.params - type = 2020-07-25
# 2022-05-06 05:40:40,466 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-06 05:40:40,467 - INFO - allennlp.common.params - type = 1
# 2022-05-06 05:40:40,469 - INFO - allennlp.common.params - model_details.model_type = BART
# 2022-05-06 05:40:40,471 - INFO - allennlp.common.params - type = BART
# 2022-05-06 05:40:40,473 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:40,480 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:40,480 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:40,480 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lewis2020BARTDS,
# title={BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension},
# author={M. Lewis and Yinhan Liu and Naman Goyal and Marjan Ghazvininejad and A. Mohamed and Omer Levy and Ves Stoyanov and L. Zettlemoyer},
# booktitle={ACL},
# year={2020}}
#
# 2022-05-06 05:40:40,495 - INFO - allennlp.common.params - model_details.paper.title = BART: Denosing Sequence-to-Sequence Pre-training for Natural Language Generation,Translation, and Comprehension
# 2022-05-06 05:40:40,498 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:204960716
# 2022-05-06 05:40:40,501 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-06 05:40:40,503 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-06 05:40:40,505 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-06 05:40:40,519 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:40,525 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:40,532 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:40,538 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-06 05:40:40,540 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-06 05:40:40,542 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-06 05:40:40,545 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:40,552 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:40,558 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:40,564 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-06 05:40:40,567 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-06 05:40:40,569 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:40,576 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:40,583 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:40,589 - INFO - allennlp.common.params - metrics.model_performance_measures = ROUGE and BLEU
# 2022-05-06 05:40:40,591 - INFO - allennlp.common.params - type = ROUGE and BLEU
# 2022-05-06 05:40:40,593 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-06 05:40:40,595 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-06 05:40:40,598 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:40,607 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:40,612 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:40,618 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:40,648 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:40,655 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:40,662 - INFO - allennlp.common.params - evaluation_data.dataset.name = CNN/DailyMail
# 2022-05-06 05:40:40,664 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2022-05-06 05:40:40,666 - INFO - allennlp.common.params - evaluation_data.dataset.notes = Please download the data from the url provided.
# 2022-05-06 05:40:40,669 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-06 05:40:40,671 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-06 05:40:40,674 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:40,681 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:40,688 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:40,695 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:40,702 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:40,708 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:40,716 - INFO - allennlp.common.params - training_data.dataset.name = CNN/DailyMail
# 2022-05-06 05:40:40,718 - INFO - allennlp.common.params - training_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2022-05-06 05:40:40,720 - INFO - allennlp.common.params - training_data.dataset.notes = Please download the data from the url provided.
# 2022-05-06 05:40:40,722 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-06 05:40:40,724 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2022-05-06 05:40:40,729 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:40,732 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:40,744 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:40,753 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2022-05-06 05:40:40,756 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-06 05:40:40,759 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:40,765 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:40,772 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:40,777 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-06 05:40:40,780 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:40,786 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:40,794 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:40,800 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-06 05:40:40,806 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\glove-sst.json as plain json
# 2022-05-06 05:40:40,820 - INFO - allennlp.common.params - id = glove-sst
# 2022-05-06 05:40:40,821 - INFO - allennlp.common.params - type = glove-sst
# 2022-05-06 05:40:40,829 - INFO - allennlp.common.params - registered_model_name = None
# 2022-05-06 05:40:40,833 - INFO - allennlp.common.params - model_class = None
# 2022-05-06 05:40:40,835 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-06 05:40:40,838 - INFO - allennlp.common.params - display_name = GLoVe-LSTM
# 2022-05-06 05:40:40,841 - INFO - allennlp.common.params - type = GLoVe-LSTM
# 2022-05-06 05:40:40,843 - INFO - allennlp.common.params - task_id = sentiment-analysis
# 2022-05-06 05:40:40,846 - INFO - allennlp.common.params - type = sentiment-analysis
# 2022-05-06 05:40:40,848 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:40,853 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:40,859 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:40,886 - INFO - allennlp.common.params - model_usage.archive_file = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2022-05-06 05:40:40,889 - INFO - allennlp.common.params - type = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2022-05-06 05:40:40,896 - INFO - allennlp.common.params - model_usage.training_config = classification/basic_stanford_sentiment_treebank.jsonnet
# 2022-05-06 05:40:40,898 - INFO - allennlp.common.params - type = classification/basic_stanford_sentiment_treebank.jsonnet
# 2022-05-06 05:40:40,903 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-06 05:40:40,906 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-06 05:40:40,913 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-06 05:40:40,915 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:40,919 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:40,930 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:40,936 - INFO - allennlp.common.params - model_details.description = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2022-05-06 05:40:40,939 - INFO - allennlp.common.params - type = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2022-05-06 05:40:40,948 - INFO - allennlp.common.params - model_details.short_description = LSTM binary classifier with GloVe embeddings.
# 2022-05-06 05:40:40,951 - INFO - allennlp.common.params - type = LSTM binary classifier with GloVe embeddings.
# 2022-05-06 05:40:40,958 - INFO - allennlp.common.params - model_details.developed_by = None
# 2022-05-06 05:40:40,960 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2022-05-06 05:40:40,961 - INFO - allennlp.common.params - model_details.date = 2020-06-09
# 2022-05-06 05:40:40,964 - INFO - allennlp.common.params - type = 2020-06-09
# 2022-05-06 05:40:40,966 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-06 05:40:40,968 - INFO - allennlp.common.params - type = 1
# 2022-05-06 05:40:40,973 - INFO - allennlp.common.params - model_details.model_type = LSTM
# 2022-05-06 05:40:40,974 - INFO - allennlp.common.params - type = LSTM
# 2022-05-06 05:40:40,976 - INFO - allennlp.common.params - model_details.paper = None
# 2022-05-06 05:40:40,979 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-06 05:40:40,980 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-06 05:40:40,982 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-06 05:40:40,991 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:40,996 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:41,002 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-06 05:40:41,004 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-06 05:40:41,004 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-06 05:40:41,015 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-06 05:40:41,018 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:41,022 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:41,027 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-06 05:40:41,033 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-06 05:40:41,036 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-06 05:40:41,038 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:41,044 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:41,049 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-06 05:40:41,053 - INFO - allennlp.common.params - metrics.model_performance_measures = Accuracy
# 2022-05-06 05:40:41,056 - INFO - allennlp.common.params - type = Accuracy
# 2022-05-06 05:40:41,058 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-06 05:40:41,060 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-06 05:40:41,063 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:41,069 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:41,074 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-06 05:40:41,081 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:41,081 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:41,081 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-06 05:40:41,102 - INFO - allennlp.common.params - evaluation_data.dataset.name = Stanford Sentiment Treebank
# 2022-05-06 05:40:41,104 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2022-05-06 05:40:41,106 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/test.txt
# 2022-05-06 05:40:41,108 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-06 05:40:41,110 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-06 05:40:41,112 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:41,119 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:41,140 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-06 05:40:41,147 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:41,153 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:41,160 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-06 05:40:41,166 - INFO - allennlp.common.params - training_data.dataset.name = Stanford Sentiment Treebank
# 2022-05-06 05:40:41,168 - INFO - allennlp.common.params - training_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2022-05-06 05:40:41,170 - INFO - allennlp.common.params - training_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/train.txt
# 2022-05-06 05:40:41,173 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-06 05:40:41,175 - INFO - allennlp.common.params - training_data.preprocessing = Binary classification setting
# 2022-05-06 05:40:41,177 - INFO - allennlp.common.params - type = Binary classification setting
# 2022-05-06 05:40:41,181 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:41,188 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:41,195 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-06 05:40:41,202 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = Accuracy: 87% on SST test set.
# 2022-05-06 05:40:41,204 - INFO - allennlp.common.params - type = Accuracy: 87% on SST test set.
# 2022-05-06 05:40:41,221 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-06 05:40:41,230 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:41,246 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:41,253 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-06 05:40:41,260 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-06 05:40:41,283 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:41,289 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:41,296 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-06 05:40:41,301 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-06 05:40:41,310 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\lm-masked-language-model.json as plain json
# 2022-05-06 05:40:41,326 - INFO - allennlp.common.params - id = lm-masked-language-model
# 2022-05-06 05:40:41,330 - INFO - allennlp.common.params - type = lm-masked-language-model
# 2022-05-06 05:40:41,335 - INFO - allennlp.common.params - registered_model_name = masked_language_model
# 2022-05-06 05:40:41,339 - INFO - allennlp.common.params - type = masked_language_model
# 2022-05-06 05:40:41,342 - INFO - allennlp.common.params - model_class = None
# 2022-05-06 05:40:41,343 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-06 05:40:41,345 - INFO - allennlp.common.params - display_name = BERT-based Masked Language Model
# 2022-05-06 05:40:41,347 - INFO - allennlp.common.params - type = BERT-based Masked Language Model
# 2022-05-06 05:40:41,349 - INFO - allennlp.common.params - task_id = masked-language-modeling
# 2022-05-06 05:40:41,351 - INFO - allennlp.common.params - type = masked-language-modeling
# 2022-05-06 05:40:41,354 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:41,360 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:41,367 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-06 05:40:41,374 - INFO - allennlp.common.params - model_usage.archive_file = bert-masked-lm-2020-10-07.tar.gz
# 2022-05-06 05:40:41,378 - INFO - allennlp.common.params - type = bert-masked-lm-2020-10-07.tar.gz
# 2022-05-06 05:40:41,387 - INFO - allennlp.common.params - model_usage.training_config = lm/bidirectional_language_model.jsonnet
# 2022-05-06 05:40:41,390 - INFO - allennlp.common.params - type = lm/bidirectional_language_model.jsonnet
# 2022-05-06 05:40:41,397 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-06 05:40:41,400 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-06 05:40:41,406 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-06 05:40:41,410 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:41,417 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:41,423 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-06 05:40:41,429 - INFO - allennlp.common.params - model_details.description = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2022-05-06 05:40:41,431 - INFO - allennlp.common.params - type = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2022-05-06 05:40:41,438 - INFO - allennlp.common.params - model_details.short_description = BERT-based masked language model
# 2022-05-06 05:40:41,441 - INFO - allennlp.common.params - type = BERT-based masked language model
# 2022-05-06 05:40:41,443 - INFO - allennlp.common.params - model_details.developed_by = Devlin et al
# 2022-05-06 05:40:41,446 - INFO - allennlp.common.params - type = Devlin et al
# 2022-05-06 05:40:41,448 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2022-05-06 05:40:41,450 - INFO - allennlp.common.params - model_details.date = 2020-10-07
# 2022-05-06 05:40:41,452 - INFO - allennlp.common.params - type = 2020-10-07
# 2022-05-06 05:40:41,454 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-06 05:40:41,456 - INFO - allennlp.common.params - type = 1
# 2022-05-06 05:40:41,458 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2022-05-06 05:40:41,461 - INFO - allennlp.common.params - type = BERT
# 2022-05-06 05:40:41,463 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:41,467 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:41,497 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-06 05:40:41,502 - INFO - allennlp.common.params - model_details.paper.citation =
# ...
# 2022-05-06 05:42:28,553 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.output.dense.weight
# 2022-05-06 05:42:28,555 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.key.bias
# 2022-05-06 05:42:28,558 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.key.weight
# 2022-05-06 05:42:28,560 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.query.bias
# 2022-05-06 05:42:28,562 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.query.weight
# 2022-05-06 05:42:28,564 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.value.bias
# 2022-05-06 05:42:28,571 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.value.weight
# 2022-05-06 05:42:28,575 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.intermediate.dense.bias
# 2022-05-06 05:42:28,576 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.intermediate.dense.weight
# 2022-05-06 05:42:28,579 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.LayerNorm.bias
# 2022-05-06 05:42:28,582 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.LayerNorm.weight
# 2022-05-06 05:42:28,585 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.dense.bias
# 2022-05-06 05:42:28,588 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.dense.weight
# 2022-05-06 05:42:28,590 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2022-05-06 05:42:28,593 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2022-05-06 05:42:28,596 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2022-05-06 05:42:28,603 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2022-05-06 05:42:28,605 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.key.bias
# 2022-05-06 05:42:28,608 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.key.weight
# 2022-05-06 05:42:28,614 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.query.bias
# 2022-05-06 05:42:28,620 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.query.weight
# 2022-05-06 05:42:28,622 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.value.bias
# 2022-05-06 05:42:28,624 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.value.weight
# 2022-05-06 05:42:28,628 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2022-05-06 05:42:28,640 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2022-05-06 05:42:28,645 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2022-05-06 05:42:28,648 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2022-05-06 05:42:28,654 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.dense.bias
# 2022-05-06 05:42:28,656 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.dense.weight
# 2022-05-06 05:42:28,658 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2022-05-06 05:42:28,661 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2022-05-06 05:42:28,663 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2022-05-06 05:42:28,665 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2022-05-06 05:42:28,669 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.key.bias
# 2022-05-06 05:42:28,671 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.key.weight
# 2022-05-06 05:42:28,674 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.query.bias
# 2022-05-06 05:42:28,676 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.query.weight
# 2022-05-06 05:42:28,678 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.value.bias
# 2022-05-06 05:42:28,681 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.value.weight
# 2022-05-06 05:42:28,686 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2022-05-06 05:42:28,688 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2022-05-06 05:42:28,690 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2022-05-06 05:42:28,692 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2022-05-06 05:42:28,695 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.dense.bias
# 2022-05-06 05:42:28,699 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.dense.weight
# 2022-05-06 05:42:28,705 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2022-05-06 05:42:28,709 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2022-05-06 05:42:28,712 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2022-05-06 05:42:28,735 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2022-05-06 05:42:28,738 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.key.bias
# 2022-05-06 05:42:28,740 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.key.weight
# 2022-05-06 05:42:28,743 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.query.bias
# 2022-05-06 05:42:28,748 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.query.weight
# 2022-05-06 05:42:28,758 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.value.bias
# 2022-05-06 05:42:28,761 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.value.weight
# 2022-05-06 05:42:28,764 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2022-05-06 05:42:28,770 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2022-05-06 05:42:28,772 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2022-05-06 05:42:28,775 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2022-05-06 05:42:28,778 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.dense.bias
# 2022-05-06 05:42:28,784 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.dense.weight
# 2022-05-06 05:42:28,787 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2022-05-06 05:42:28,790 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2022-05-06 05:42:28,792 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2022-05-06 05:42:28,795 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2022-05-06 05:42:28,797 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.key.bias
# 2022-05-06 05:42:28,803 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.key.weight
# 2022-05-06 05:42:28,805 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.query.bias
# 2022-05-06 05:42:28,807 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.query.weight
# 2022-05-06 05:42:28,809 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.value.bias
# 2022-05-06 05:42:28,812 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.value.weight
# 2022-05-06 05:42:28,814 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2022-05-06 05:42:28,816 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2022-05-06 05:42:28,820 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2022-05-06 05:42:28,822 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2022-05-06 05:42:28,824 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.dense.bias
# 2022-05-06 05:42:28,832 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.dense.weight
# 2022-05-06 05:42:28,838 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2022-05-06 05:42:28,840 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2022-05-06 05:42:28,842 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2022-05-06 05:42:28,845 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2022-05-06 05:42:28,848 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.key.bias
# 2022-05-06 05:42:28,852 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.key.weight
# 2022-05-06 05:42:28,906 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.query.bias
# 2022-05-06 05:42:28,908 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.query.weight
# 2022-05-06 05:42:28,910 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.value.bias
# 2022-05-06 05:42:28,915 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.value.weight
# 2022-05-06 05:42:28,922 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2022-05-06 05:42:28,927 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2022-05-06 05:42:28,930 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2022-05-06 05:42:28,936 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2022-05-06 05:42:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.dense.bias
# 2022-05-06 05:42:28,942 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.dense.weight
# 2022-05-06 05:42:28,945 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.pooler.dense.bias
# 2022-05-06 05:42:28,952 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.pooler.dense.weight
# 2022-05-06 05:42:57,496 - INFO - allennlp.models.archival - removing temporary unarchived model dir at C:\Users\hp\AppData\Local\Temp\tmp9w1t4c3k

# %% [markdown]
# # Read text file and preprocess.

# %%
#from spacy.lang.en import English

file_name = './Text/Simplified Food Insecurity.txt'
#file_name = 'input.txt'
narrative = open(file_name, encoding="utf8").read()

narrative = textacy.preprocessing.normalize_quotation_marks(narrative)
#narrative = textacy.preprocessing.remove_punctuation(narrative, marks=",;:")
#narrative = textacy.preprocessing.normalize_whitespace(narrative)
#narrative = textacy.make_spacy_doc(narrative)
narrative = narrative.lower()
narrative = nlp(narrative)

#narrative._.coref_clusters
#narrative._.coref_resolved

print('Original Narrative:')
print(narrative)
#print('\n')
print('Extracted Coreferences:')
print(narrative._.coref_clusters)
print('\n')
narrative = narrative._.coref_resolved
print('Narrarive after resolving coreferences:')
print(narrative)

raw_sentences = sent_tokenize(narrative)
#nlp.add_pipe(nlp.create_pipe('sentencizer')) # updated
narrative = nlp(narrative)
#sentences = [sent.string.strip() for sent in narrative.sents]
#narrative = nlp(narrative)

print('\nSpacy Sentences:\n')
for sent in narrative.sents:
    print(sent.text)

print('\nNLTK Sentences:\n')
for sent in raw_sentences:
    print(sent)
# Out:
# Original Narrative:
# institutional weakness hindered development of the agriculture sector. land rights disagreements are a major source of conflict. this conflict discourages farmers from expanding production. this conflict discourages traders from building marketing infrastructure. this conflict discourages retailers from building marketing infrastructure. the low level of public investment shows that no irrigation infrastructure exists. the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. roads are poorly maintained. roads are not repaired. roads are completely washed out during the rainy season. inadequate transportation infrastructure has resulted in less transport to markets. moderate to heavy rainfall is expected to continue during the next two weeks across sudan moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. moderate to heavy rainfall is expected to continue during the next two weeks across uganda. moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya. moderate to heavy rainfall is expected to continue during the next two weeks across western/northern ethiopia. persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. persistent heavy rains in the south sudan cause flooding in flood-prone areas. highly saturated soils cause flooding in flood-prone areas. rain caused floods. floods have displaced more than 100,000 people in south sudan. floods raise fears. floods devastatingly impact on food security in the war-torn nation.
# Extracted Coreferences:
# [conflict: [conflict, this conflict, this conflict, this conflict], the low level of public investment: [the low level of public investment, the low level of public investment], south sudan: [south sudan, south sudan, the eastern sudan, the south sudan, south sudan, the war-torn nation], south sudan's: [south sudan's, sudan, sudan], the next two weeks across south sudan: [the next two weeks across south sudan, the next two weeks across uganda, the next two weeks across northern kenya, the next two weeks across western/northern ethiopia], flood-prone areas: [flood-prone areas, flood-prone areas]]
#
#
# Narrarive after resolving coreferences:
# institutional weakness hindered development of the agriculture sector. land rights disagreements are a major source of conflict. conflict discourages farmers from expanding production. conflict discourages traders from building marketing infrastructure. conflict discourages retailers from building marketing infrastructure. the low level of public investment shows that no irrigation infrastructure exists. the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. roads are poorly maintained. roads are not repaired. roads are completely washed out during the rainy season. inadequate transportation infrastructure has resulted in less transport to markets. moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's moderate to heavy rainfall is expected to continue during the next two weeks across south sudansouth sudan's. moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. persistent heavy rains in south sudan cause flooding in flood-prone areas. persistent heavy rains in south sudan cause flooding in flood-prone areas. highly saturated soils cause flooding in flood-prone areas. rain caused floods. floods have displaced more than 100,000 people in south sudan. floods raise fears. floods devastatingly impact on food security in south sudan.
#
# Spacy Sentences:
#
# institutional weakness hindered development of the agriculture sector.
# land rights disagreements are a major source of conflict.
# conflict discourages farmers from expanding production.
# conflict discourages traders from building marketing infrastructure.
# conflict discourages retailers from building marketing infrastructure.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# roads are poorly maintained.
# roads are not repaired.
# roads are completely washed out during the rainy season.
# inadequate transportation infrastructure has resulted in less transport to markets.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's moderate to heavy rainfall is expected to continue during the next two weeks across south sudansouth sudan's.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan.
# floods raise fears.
# floods devastatingly impact on food security in south sudan.
#
# NLTK Sentences:
#
# institutional weakness hindered development of the agriculture sector.
# land rights disagreements are a major source of conflict.
# conflict discourages farmers from expanding production.
# conflict discourages traders from building marketing infrastructure.
# conflict discourages retailers from building marketing infrastructure.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# roads are poorly maintained.
# roads are not repaired.
# roads are completely washed out during the rainy season.
# inadequate transportation infrastructure has resulted in less transport to markets.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's moderate to heavy rainfall is expected to continue during the next two weeks across south sudansouth sudan's.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan.
# floods raise fears.
# floods devastatingly impact on food security in south sudan.

# %% [markdown]
# # Extract the Subject-Verb-Object triples.

# %% [raw]
# for sent in narrative.sents:
#     #print("Heyyyy!")
#     print(sent)
#     for tok in sent:
#         print(tok.text,tok.pos_,tok.dep_)

# %%
#new
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
#tuple =('a','b','c')

#print(tuple[0])

for sent in narrative.sents:
    print("Sentence:")
    print(sent)
    
    print("Noun Chunks:")
    for nc in sent.noun_chunks:
        print (nc)
        ncl.append(nc)
    print ("Number of noun chunks: ", len(ncl))
    
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            print("Triples other than textacy:")
            print(nncl[0])
            print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],triplets[0][1],ncl[1])]
#            print("Triples other than textacy:")
#            print(nncl[0])
#            finalList.append(nncl[0])
    else:
        print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                sub = token
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
                #tuple[1] = token.text
            #elif token.dep_ == 'dobj':
            #    obj = token.text
                #tuple[2] = token.text
            #    break
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue
                
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        print("Triple by combining nsubj, root and dobj:")
        print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],verb,ncl[1])]
#            print("Triples other than sub, verb and obj:")
#            print(nncl[0])
#            finalList.append(nncl[0])

    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
    
trips = finalList

#        for token in nc:
#            print(token.text, token.dep_)
# Out:
# Sentence:
# institutional weakness hindered development of the agriculture sector.
# Noun Chunks:
# institutional weakness
# development
# the agriculture sector
# Number of noun chunks:  3
# Triples from textacy:
# (institutional weakness, hindered, development)
# Triples other than textacy:
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# Sentence:
# land rights disagreements are a major source of conflict.
# Noun Chunks:
# land rights disagreements
# a major source
# conflict
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (land rights disagreements, are, conflict)
# Triples other than sub, verb and obj:
# (land rights disagreements, are, a major source)
# (land rights disagreements, are, conflict)
# Sentence:
# conflict discourages farmers from expanding production.
# Noun Chunks:
# conflict
# farmers
# production
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, farmers)
# Triples other than textacy:
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# Sentence:
# conflict discourages traders from building marketing infrastructure.
# Noun Chunks:
# conflict
# traders
# marketing infrastructure
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, traders)
# Triples other than textacy:
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# Sentence:
# conflict discourages retailers from building marketing infrastructure.
# Noun Chunks:
# conflict
# retailers
# marketing infrastructure
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, retailers)
# Triples other than textacy:
# (conflict, discourages, retailers)
# (conflict, discourages, marketing infrastructure)
# Sentence:
# the low level of public investment shows that no irrigation infrastructure exists.
# Noun Chunks:
# the low level
# public investment
# no irrigation infrastructure
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (no irrigation infrastructure, shows, public investment)
# Triples other than sub, verb and obj:
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# Sentence:
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# Noun Chunks:
# the low level
# public investment
# only 2 percent
# south sudan's limited road network
# Number of noun chunks:  4
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (south sudan's limited road network, shows, only 2 percent)
# Sentence:
# roads are poorly maintained.
# Noun Chunks:
# roads
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (south sudan's limited road network, maintained, roads)
# Sentence:
# roads are not repaired.
# Noun Chunks:
# roads
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (south sudan's limited road network, repaired, roads)
# Sentence:
# roads are completely washed out during the rainy season.
# Noun Chunks:
# roads
# the rainy season
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the rainy season, washed, roads)
# Sentence:
# inadequate transportation infrastructure has resulted in less transport to markets.
# Noun Chunks:
# inadequate transportation infrastructure
# less transport
# markets
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (inadequate transportation infrastructure, resulted, markets)
# Triples other than sub, verb and obj:
# (inadequate transportation infrastructure, resulted, less transport)
# (inadequate transportation infrastructure, resulted, markets)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's moderate to heavy rainfall is expected to continue during the next two weeks across south sudansouth sudan's.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# heavy rainfall
# the next two weeks
# south sudansouth sudan
# Number of noun chunks:  5
# Triples from textacy:
# (moderate, is expected, to continue)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# south sudan
# Number of noun chunks:  3
# Triples from textacy:
# (moderate, is expected, to continue)
# Triples other than textacy:
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, south sudan)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# south sudan
# Number of noun chunks:  3
# Triples from textacy:
# (moderate, is expected, to continue)
# Triples other than textacy:
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, south sudan)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# south sudan
# Number of noun chunks:  3
# Triples from textacy:
# (moderate, is expected, to continue)
# Triples other than textacy:
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, south sudan)
# Sentence:
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# Noun Chunks:
# persistent heavy rains
# the ethiopian highlands
# flood prone areas
# Number of noun chunks:  3
# Triples from textacy:
# (persistent heavy rains, cause, flooding)
# Triples other than textacy:
# (persistent heavy rains, cause, the ethiopian highlands)
# (persistent heavy rains, cause, flood prone areas)
# Sentence:
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# Noun Chunks:
# persistent heavy rains
# south sudan
# flooding
# flood-prone areas
# Number of noun chunks:  4
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (persistent heavy rains, cause, flood-prone areas)
# Sentence:
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# Noun Chunks:
# persistent heavy rains
# south sudan
# flooding
# flood-prone areas
# Number of noun chunks:  4
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (persistent heavy rains, cause, flood-prone areas)
# Sentence:
# highly saturated soils cause flooding in flood-prone areas.
# Noun Chunks:
# highly saturated soils
# flood-prone areas
# Number of noun chunks:  2
# Triples from textacy:
# (highly saturated soils, cause, flooding)
# Sentence:
# rain caused floods.
# Noun Chunks:
# rain
# floods
# Number of noun chunks:  2
# Triples from textacy:
# (rain, caused, floods)
# Sentence:
# floods have displaced more than 100,000 people in south sudan.
# Noun Chunks:
# floods
# more than 100,000 people
# south sudan
# Number of noun chunks:  3
# Triples from textacy:
# (floods, have displaced, more than 100,000 people)
# Triples other than textacy:
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# Sentence:
# floods raise fears.
# Noun Chunks:
# floods
# fears
# Number of noun chunks:  2
# Triples from textacy:
# (floods, raise, fears)
# Sentence:
# floods devastatingly impact on food security in south sudan.
# Noun Chunks:
# floods
# food security
# south sudan
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (floods, impact, south sudan)
# Triples other than sub, verb and obj:
# (floods, impact, food security)
# (floods, impact, south sudan)

# %% [raw]
# #old
# def SVO(narrative):
#     ncl = []
#     fl = []
#     nncl = [()]
#     for sent in narrative.sents:
#         #sent = str(sent)
#         print("\n" + str(sent))
#         for nc in sent.noun_chunks:
#             print (nc)
#             ncl.append(nc)
#         print(len(ncl))
#         triplets = textacy.extract.subject_verb_object_triples(sent)
#         triplets = list(triplets)
#         if len(ncl) <= 3:
#             if len(triplets) == 0:
#                 print("Method from textacy; subject_verb_object_triples extracted nothing!")
#                 for token in sent:
#                 #print(token.text, token.dep_,)
#                     if token.dep_ == 'ROOT':
#                         text = token.text
#                         break
#                     #print(token.text)
#                 if len(ncl) == 3:
#                         nncl = [(ncl[0],token.text,ncl[1])]
#                         nncl.append((ncl[0],token.text,ncl[2]))
#                         fl.append(nncl[0])
#                         fl.append(nncl[1])
#                 elif len(ncl) == 2:
#                         nncl = [(ncl[0],token.text,ncl[1])]
#                         fl.append(nncl[0])
#                 else:
#                     continue
#                 print("Triples without textacy.")
#                 print(nncl)
#
#             else:
#                 print(triplets)
#                 for t in triplets:
#                     print(t)
#                     fl.append(t)
#                 if len(ncl) == 3:
#                     nncl = [(ncl[0],triplets[0][1],ncl[1])]
#                     nncl.append((ncl[0],triplets[0][1],ncl[2]))
#                     fl.append(nncl[0])
#                     fl.append(nncl[1])
#                     #print(nncl[0])
#                     #print(nncl[1])
#                 elif len(ncl) == 2:
#                     nncl = [(ncl[0],triplets[0][1],ncl[1])]
#                     fl.append(nncl[0])
#                 else:
#                     continue;
#                 print(nncl)
#         ncl.clear()
#         nncl.clear()
#     return fl
#
# trips = SVO(narrative)

# %% [markdown]
# # Print the extracted triples without duplicates.

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("Length of triples' List before removing duplicates:")
print(len(trips))


Triples = []

for ce in trips:
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

for t in Triples:
    print(t)
# Out:
# Length of triples' List before removing duplicates:
# 49
#
# List after removing duplicates:
# 32
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (land rights disagreements, are, conflict)
# (land rights disagreements, are, a major source)
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (south sudan's limited road network, maintained, roads)
# (south sudan's limited road network, repaired, roads)
# (the rainy season, washed, roads)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (moderate, is expected, to continue)
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, south sudan)
# (persistent heavy rains, cause, flooding)
# (persistent heavy rains, cause, the ethiopian highlands)
# (persistent heavy rains, cause, flood prone areas)
# (persistent heavy rains, cause, flood-prone areas)
# (highly saturated soils, cause, flooding)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (floods, impact, south sudan)
# (floods, impact, food security)

# %% [markdown]
# # Print the extracted triples with sentences.

# %%
for sentence, triple  in zip(sentences, trips):
    print(sentence, triple)
# Out:
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector)
# land rights disagreements are a major source of conflict. (land rights disagreements, are, conflict)
# land rights disagreements are a major source of conflict. (land rights disagreements, are, a major source)
# land rights disagreements are a major source of conflict. (land rights disagreements, are, conflict)
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
# conflict discourages farmers from expanding production. (conflict, discourages, production)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure)
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent)
# roads are poorly maintained. (south sudan's limited road network, maintained, roads)
# roads are not repaired. (south sudan's limited road network, repaired, roads)
# roads are completely washed out during the rainy season. (the rainy season, washed, roads)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's moderate to heavy rainfall is expected to continue during the next two weeks across south sudansouth sudan's. (moderate, is expected, to continue)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (moderate, is expected, to continue)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (heavy rainfall, is expected, the next two weeks)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (heavy rainfall, is expected, south sudan)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (moderate, is expected, to continue)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (heavy rainfall, is expected, the next two weeks)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (heavy rainfall, is expected, south sudan)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (moderate, is expected, to continue)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (heavy rainfall, is expected, the next two weeks)
# moderate to heavy rainfall is expected to continue during the next two weeks across south sudan. (heavy rainfall, is expected, south sudan)
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, cause, flooding)
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, cause, the ethiopian highlands)
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, cause, flood prone areas)
# persistent heavy rains in south sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
# persistent heavy rains in south sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
# highly saturated soils cause flooding in flood-prone areas. (highly saturated soils, cause, flooding)
# rain caused floods. (rain, caused, floods)
# floods have displaced more than 100,000 people in south sudan. (floods, have displaced, more than 100,000 people)
# floods have displaced more than 100,000 people in south sudan. (floods, have displaced, more than 100,000 people)
# floods have displaced more than 100,000 people in south sudan. (floods, have displaced, south sudan)
# floods raise fears. (floods, raise, fears)
# floods devastatingly impact on food security in south sudan. (floods, impact, south sudan)
# floods devastatingly impact on food security in south sudan. (floods, impact, food security)
# floods devastatingly impact on food security in south sudan. (floods, impact, south sudan)

# %% [markdown]
# # Plot the knowledge Graph.

# %%
cmap = nx.DiGraph()

for triple in trips:
    s = str(triple[0])    
    d = str(triple[2])
    cmap.add_edge(s, d, predicate=triple[1])
    #print(triple)

print("Nodes:",len(cmap.nodes))
print("Edges:",len(cmap.edges))
for e in cmap.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cmap, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cmap, pos=pos, with_labels=True,  connectionstyle='arc3, rad = 0.05', node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cmap.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cmap,'predicade')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 37
# Edges: 30
# institutional weakness , {'predicate': hindered} , development
# institutional weakness , {'predicate': hindered} , the agriculture sector
# land rights disagreements , {'predicate': are} , conflict
# land rights disagreements , {'predicate': are} , a major source
# conflict , {'predicate': discourages} , farmers
# conflict , {'predicate': discourages} , production
# conflict , {'predicate': discourages} , traders
# conflict , {'predicate': discourages} , marketing infrastructure
# conflict , {'predicate': discourages} , retailers
# no irrigation infrastructure , {'predicate': shows} , public investment
# the low level , {'predicate': shows} , public investment
# the low level , {'predicate': shows} , no irrigation infrastructure
# south sudan's limited road network , {'predicate': shows} , only 2 percent
# south sudan's limited road network , {'predicate': repaired} , roads
# the rainy season , {'predicate': washed} , roads
# inadequate transportation infrastructure , {'predicate': resulted} , markets
# inadequate transportation infrastructure , {'predicate': resulted} , less transport
# moderate , {'predicate': is expected} , to continue
# heavy rainfall , {'predicate': is expected} , the next two weeks
# heavy rainfall , {'predicate': is expected} , south sudan
# persistent heavy rains , {'predicate': cause} , flooding
# persistent heavy rains , {'predicate': cause} , the ethiopian highlands
# persistent heavy rains , {'predicate': cause} , flood prone areas
# persistent heavy rains , {'predicate': cause} , flood-prone areas
# highly saturated soils , {'predicate': cause} , flooding
# rain , {'predicate': caused} , floods
# floods , {'predicate': have displaced} , more than 100,000 people
# floods , {'predicate': impact} , south sudan
# floods , {'predicate': raise} , fears
# floods , {'predicate': impact} , food security

# %% [markdown]
# # Dump the Knowledge Graph on "Knowledge Graph.json"

# %%
knowledgeGraph = nx.DiGraph()

for svo in trips:
    s = str(svo[0])    
    d = str(svo[2])
    knowledgeGraph.add_node(s,id = str(s),title=str(s),x=615,y=200)
    knowledgeGraph.add_node(d,id = str(d),title=str(d),x=615,y=200)
    knowledgeGraph.add_edge(s, d, predicade=str(svo[1]))

#print(len(knowledgeGraph.nodes))
#print(len(knowledgeGraph.edges))

data = json_graph.node_link_data(knowledgeGraph)


out_file = open("./Json Graphs/Knowledge Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Create Causal Trigger Words Dictionary along with their synonyms.

# %%
#new

causalWords1 = ["forced","caused", "resulted", "reason", "as a result of", "as a consequence of", 
               "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
               ,"made","minimize","maximize","hindered", "displaced", "conspired","led to","activate","impel","inspire",
                "excite","quicken","rouse","stimulate","influence","determine","likely","probable","disconnected","separated"
                ,"excluded","after","as","since","trigger","oppose","fight","provides","strengthened","launched","develop"
               ,"guarantees","declared", "developed","produced","discourages","demotivated","encouraged","motivated"]

#causalWords1 = ["develop"]
synonyms1 = []
lemma_function = WordNetLemmatizer()

for cw1 in causalWords1:
    #print(cw1)
    synonyms1.append(cw1.lower())
    tokens1 = word_tokenize(cw1)
    for token1, tag1 in pos_tag(tokens1):
        lemma1 = lemma_function.lemmatize(token1)
        #print(token1,lemma1)
        
        for syn in wordnet.synsets(str(lemma1)):
            
            for l1 in syn.lemmas():
                #print(l1)
                #synonyms1.append(lemma1.lower())
                synonyms1.append(l1.name().lower())
                #print(l1)
                for syn1 in wordnet.synsets(str(l1.name())):
                    for l2 in syn1.lemmas():
                        #print(l2)
                        synonyms1.append(l2.name().lower())
            

#remove duplicates from synonyms1
synonyms = []
     
for synonym in synonyms1:
    if synonym not in synonyms:
        synonyms.append(synonym)
    
#for x in synonyms:
#    print (synonym)

print(len(synonyms))
# Out:
# 3226

# %% [markdown]
# # Writing causal trigger words dictionary to text file (dictionary.txt)

# %%
#synonyms
output_file = open('.\dictionary.txt', 'w')

for syn in synonyms:
    #print(syn)
    output_file.write(syn + '\n')

output_file.close()

# %% [markdown]
# # Reading causal trigger words dictionary from text file (dictionary.txt) to list

# %%
synonyms = []

my_file = open(".\dictionary.txt", "r")
  
data = my_file.read()
  
synonyms = data.split("\n")
#print(data_into_list)
my_file.close()

print(len(synonyms))
# Out:
# 3227

# %% [raw]
# #old
#
# causalWords = ["forced","caused", "result", "reason", "as a result of", "as a consequence of",
#                "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
#                ,"made","mimimize","maximize","led to","produced"]
#
# #causalWords = ["as a result of"]
# synonyms = []
#
# for cw in causalWords:
#
#     for syn in wordnet.synsets(str(cw)):
#         for l in syn.lemmas():
#             synonyms.append(cw)
#             synonyms.append(l.name())
#
# print(set(synonyms))
# print(len(synonyms))

# %% [markdown]
# # Filter Causal triples along with their causal sentences from SVO triples based upon causal trigger words dictionary.

# %%
causeffect = [] #without duplicates
causalSentences = [] #with duplicates
#lem = []
#lemma_function = WordNetLemmatizer()
for s,st in zip(sentences,trips):
    check = False
    #st = (str(st[0]),str(st[1]),str(st[2]))
    #synonym = synonym[0]
    tokens = word_tokenize(str(st[1]))
    for token, tag in pos_tag(tokens):
        lemma = lemma_function.lemmatize(token)
        #print(token,lemma)
        #st[1] = lemma
        #lem.append(lemma)
        
    for synonym in synonyms:
        if synonym == lemma:
            #causeffect = [(st[0],st[1],st[2])]
            #strTriples.append((ncl[0],token.text,st[2]))
           # print(st)
            if len(causeffect) == 0:
                causeffect.append(st)
                causalSentences.append(s)
            else:
                for ct in causeffect:
                    if str(st[0]) == str(ct[0]) and str(st[1]) == str(ct[1]) and str(st[2]) == str(ct[2]):
                        check = True
                        break;
                if check == False:
                    causeffect.append(st)
                    causalSentences.append(s)
            #if (len(causeffect) >0 ) and (st in causeffect == False):
                
            #    causeffect.append(st)
            break
    
#causeffect.sort(key = lambda x: x[0])

#for sortedTriple in causeffect:
#    print(sortedTriple)
print(len(causalSentences))
print(len(causeffect))
for causalSentence, causalTriple  in zip(causalSentences, causeffect):
    print(causalSentence, causalTriple)
# Out:
# 24
# 24
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector)
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
# conflict discourages farmers from expanding production. (conflict, discourages, production)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure)
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport)
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, cause, flooding)
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, cause, the ethiopian highlands)
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, cause, flood prone areas)
# persistent heavy rains in south sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
# highly saturated soils cause flooding in flood-prone areas. (highly saturated soils, cause, flooding)
# rain caused floods. (rain, caused, floods)
# floods have displaced more than 100,000 people in south sudan. (floods, have displaced, more than 100,000 people)
# floods have displaced more than 100,000 people in south sudan. (floods, have displaced, south sudan)
# floods raise fears. (floods, raise, fears)
# floods devastatingly impact on food security in south sudan. (floods, impact, south sudan)
# floods devastatingly impact on food security in south sudan. (floods, impact, food security)

# %% [markdown]
# # Plot the Causal Graph.

# %%
#new (DAG Implementation)
#without duplicates
dagCauseTriples = []
cg = nx.DiGraph()

for ce in causeffect:
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
    dagCauseTriples.append(ce)
    if nx.is_directed_acyclic_graph(cg) is False:
        cg.remove_edge(s, d)
        dagCauseTriples.remove(ce)
        

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 29
# Edges: 23
# institutional weakness , {'predicade': 'hindered'} , development
# institutional weakness , {'predicade': 'hindered'} , the agriculture sector
# conflict , {'predicade': 'discourages'} , farmers
# conflict , {'predicade': 'discourages'} , production
# conflict , {'predicade': 'discourages'} , traders
# conflict , {'predicade': 'discourages'} , marketing infrastructure
# conflict , {'predicade': 'discourages'} , retailers
# no irrigation infrastructure , {'predicade': 'shows'} , public investment
# the low level , {'predicade': 'shows'} , public investment
# the low level , {'predicade': 'shows'} , no irrigation infrastructure
# south sudan's limited road network , {'predicade': 'shows'} , only 2 percent
# inadequate transportation infrastructure , {'predicade': 'resulted'} , markets
# inadequate transportation infrastructure , {'predicade': 'resulted'} , less transport
# persistent heavy rains , {'predicade': 'cause'} , flooding
# persistent heavy rains , {'predicade': 'cause'} , the ethiopian highlands
# persistent heavy rains , {'predicade': 'cause'} , flood prone areas
# persistent heavy rains , {'predicade': 'cause'} , flood-prone areas
# highly saturated soils , {'predicade': 'cause'} , flooding
# rain , {'predicade': 'caused'} , floods
# floods , {'predicade': 'have displaced'} , more than 100,000 people
# floods , {'predicade': 'impact'} , south sudan
# floods , {'predicade': 'raise'} , fears
# floods , {'predicade': 'impact'} , food security

# %%
#old
#without duplicates

cg = nx.DiGraph()

for ce in causeffect:
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
        

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])
    
print(nx.is_directed_acyclic_graph(cg))

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 5
# Edges: 5
# excessive overthinking , {'predicade': 'leads'} , insomnia
# insomnia , {'predicade': 'causes'} , stress
# stress , {'predicade': 'results'} , insomnia
# overthinking , {'predicade': 'can increase'} , anxiety
# overthinking , {'predicade': 'can cause'} , insomnia
# False

# %% [markdown]
# # Plot the Causal Graph on using Pyvis "Causal Graph.html" file

# %%
nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')

for dm in dagCauseTriples:
    #color = "#ffffff"
    nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_node(str(dm[2]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_edge(str(dm[0]),str(dm[2]),label=str(dm[1]), weight=10, physics='false',color='black')

#nt.show_buttons(filter_=['physics'])
nt.set_edge_smooth('discrete')
nt.show("./Pyvis Graph/Causal Graph.html")
# Out:
#         <iframe
#             width="1000px"
#             height="500px"
#             src="./Pyvis Graph/Causal Graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [raw]
# nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')
#
# nt.add_node(1, label="Subject (cause)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_node(2, label="Object (effect)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_edge(1,2,label="Verb (cause-effect)", weight=10, physics='false',color='black')
#
#
# nt.show("./Pyvis Graph/Causal Graph.html")

# %% [markdown]
# # Dump the Causal Graph on "Causal Graph.json" file

# %%
data = json_graph.node_link_data(cg)


out_file = open("./Json Graphs/Causal Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Remove Duplicates from Causal Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("List before removing duplicates:")
print(len(causeffect))

for t in causeffect:
    print(t)
    
causalTriples = []

for ce in causeffect:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalTriples) == 0:
        #print("HEY!")
        causalTriples.append(ce)
        #print("added!")
    else:
        for ct in causalTriples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalTriples.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalTriples))

for t in causalTriples:
    print(t)
# Out:
# List before removing duplicates:
# 6
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, guards, nuclear bomb)
#
# List after removing duplicates:
# 6
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, guards, nuclear bomb)

# %% [markdown]
# # Remove Duplicates from causalSentences

# %%
#causalSentences = list(dict.fromkeys(causalSentences))
#causalSentences = list(set(causalSentences))
print("List before removing duplicates:")
print(len(causalSentences))

for t in causalSentences:
    print(t)
    
causalSentencesNoDup = []

for ce in causalSentences:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalSentencesNoDup) == 0:
        #print("HEY!")
        causalSentencesNoDup.append(ce)
        #print("added!")
    else:
        for ct in causalSentencesNoDup:
            #print("ct:")
            #print(ct)
            if str(ce) == str(ct):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalSentencesNoDup.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalSentencesNoDup))

for t in causalSentencesNoDup:
    print(t)
# Out:
# List before removing duplicates:
# 19
# institutional weakness hindered development of the agriculture sector.
# institutional weakness hindered development of the agriculture sector.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# inadequate transportation infrastructure has resulted in less transport to markets.
# inadequate transportation infrastructure has resulted in less transport to markets.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan.
# floods have displaced more than 100,000 people in south sudan.
# floods raise fears.
# floods devastatingly impact on food security in south sudan.
# floods devastatingly impact on food security in south sudan.
#
# List after removing duplicates:
# 11
# institutional weakness hindered development of the agriculture sector.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# inadequate transportation infrastructure has resulted in less transport to markets.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan.
# floods raise fears.
# floods devastatingly impact on food security in south sudan.

# %% [markdown]
# # Causal Triples' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
allen = []
for sent in causalTriples:
    #print(sent)
    preds = predictor.predict(str(sent))
    #print(preds['label'][0])
    label = preds['label'][0]
    if label is '0':
        allen.append(-1)
    else:
        allen.append(1)
    
for causalSentence, polarity  in zip(causalTriples, allen):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) -1
# (persistent heavy rains, cause, the ethiopian highlands) -1
# (persistent heavy rains, cause, flood prone areas) -1
# (persistent heavy rains, cause, flood-prone areas) -1
# (highly saturated soils, cause, flooding) -1
# (rain, caused, floods) -1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (floods, impact, south sudan) 1
# (floods, impact, food security) 1

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)

afinn = []
for sent in causalTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    #print(score)
    if score > 0:
        #print('positive')
        afinn.append(1)
    elif score < 0:
        #print('negative')
        afinn.append(-1)
    else:
        #print('neutral')
        afinn.append(0)
        
for causalSentence, polarity  in zip(causalTriples, afinn):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) 0
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) 0
# (persistent heavy rains, cause, the ethiopian highlands) 0
# (persistent heavy rains, cause, flood prone areas) 0
# (persistent heavy rains, cause, flood-prone areas) 0
# (highly saturated soils, cause, flooding) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) 0
# (floods, impact, south sudan) 0
# (floods, impact, food security) 0

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    if compound >= 0.05:
        vader.append(1)
        return 'Positive'
    elif compound <= -0.05 :
        vader.append(-1)
        return 'Negative'
        
    elif  compound > -0.05 and compound < 0.05:
        vader.append(0)
        return 'Neutral'
    
for sent in causalTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    vader_analysis(compound)
    
for causalSentence, polarity  in zip(causalTriples, vader):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) 0
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) 0
# (persistent heavy rains, cause, the ethiopian highlands) 0
# (persistent heavy rains, cause, flood prone areas) 0
# (persistent heavy rains, cause, flood-prone areas) 0
# (highly saturated soils, cause, flooding) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) -1
# (floods, impact, south sudan) 0
# (floods, impact, food security) 1

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

sentiStrength = []

for sent in causalTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='binary')
    #print(result)
    
    if result[0]==1:
        #print('Positive')
        sentiStrength.append(1)
    elif result[0]==-1:
        sentiStrength.append(-1)
        #print('Negative')
    #else:
    #    print('Neutral')

for causalSentence, polarity  in zip(causalTriples, sentiStrength):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) 1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) 1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) 1
# (persistent heavy rains, cause, the ethiopian highlands) 1
# (persistent heavy rains, cause, flood prone areas) 1
# (persistent heavy rains, cause, flood-prone areas) 1
# (highly saturated soils, cause, flooding) 1
# (rain, caused, floods) 1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (floods, impact, south sudan) 1
# (floods, impact, food security) 1

# %% [markdown]
# ### Data Frame (Causal Triples Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# <style  type="text/css" >
# </style><table id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Triple</th>        <th class="col_heading level0 col1" >AllenNLP</th>        <th class="col_heading level0 col2" >Afinn</th>        <th class="col_heading level0 col3" >Vader</th>        <th class="col_heading level0 col4" >SentiStrength</th>        <th class="col_heading level0 col5" >Weight</th>        <th class="col_heading level0 col6" >Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col0" class="data row0 col0" >(institutional weakness, hindered, development)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col1" class="data row0 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col2" class="data row0 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col3" class="data row0 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col4" class="data row0 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col5" class="data row0 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col6" class="data row0 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col0" class="data row1 col0" >(institutional weakness, hindered, the agriculture sector)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col1" class="data row1 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col2" class="data row1 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col4" class="data row1 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col5" class="data row1 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col6" class="data row1 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col0" class="data row2 col0" >(no irrigation infrastructure, shows, public investment)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col1" class="data row2 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col2" class="data row2 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col5" class="data row2 col5" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col6" class="data row2 col6" >Weak Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col0" class="data row3 col0" >(the low level, shows, public investment)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col1" class="data row3 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col3" class="data row3 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col4" class="data row3 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col5" class="data row3 col5" >-3</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col6" class="data row3 col6" >Moderate Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col0" class="data row4 col0" >(the low level, shows, no irrigation infrastructure)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col1" class="data row4 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col2" class="data row4 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col3" class="data row4 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col4" class="data row4 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col5" class="data row4 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col6" class="data row4 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col0" class="data row5 col0" >(south sudan's limited road network, shows, only 2 percent)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col1" class="data row5 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col2" class="data row5 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col3" class="data row5 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col5" class="data row5 col5" >-2</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col6" class="data row5 col6" >Mild Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col0" class="data row6 col0" >(inadequate transportation infrastructure, resulted, markets)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col1" class="data row6 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col2" class="data row6 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col3" class="data row6 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col4" class="data row6 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col5" class="data row6 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col6" class="data row6 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row7_col0" class="data row7 col0" >(inadequate transportation infrastructure, resulted, less transport)</td>

# %% [markdown]
# # Causal Sentences' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
def Allen_sents_SentLevel(causalSentences):
    allen = []
    for sent in causalSentences:
        #print(sent)
        preds = predictor.predict(str(sent))
        #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen.append(-1)
        else:
            allen.append(1)
    return allen

#for causalSentence, polarity  in zip(causalSentences, allen):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)
def Afinn_sents_SentLevel(causalSentences):
    afinn = []
    for sent in causalSentences:
        #print(sent)
        score = afn.score(str(sent))
        #print(score)
        if score > 0:
            #print('positive')
            afinn.append(1)
        elif score < 0:
            #print('negative')
            afinn.append(-1)
        else:
            #print('neutral')
            afinn.append(0)
    return afinn

#for causalSentence, polarity  in zip(causalSentences, afinn):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    #vader = []
    if compound >= 0.05:
        #vader.append(1)
        return 1
    elif compound <= -0.05 :
        #vader.append(-1)
        return -1
        
    elif  compound > -0.05 and compound < 0.05:
        #vader.append(0)
        return 0
    #return vader
    
def Vader_sents_SentLevel(causalSentences):
    vader = []
    for sent in causalSentences:
        #print(sent)
        #vaderTup = []
        compound = vadersentimentanalysis(str(sent))
        res = vader_analysis(compound)
        #vaderTup.append(res)
        vader.append(res)
    return vader

#vader = Vader_sents_SentLevel(causalSents)
#vader
#for causalSentence, polarity  in zip(causalSentences, vader):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

def Senti_sents_SentLevel(causalSentences):
    sentiStrength = []
    for sent in causalSentences:
        #print(sent)
        result = senti.getSentiment(str(sent), score='binary')
        #print(result)
    
        if result[0]==1:
            #print('Positive')
            sentiStrength.append(1)
        elif result[0]==-1:
            sentiStrength.append(-1)
            #print('Negative')
        #else:
        #    print('Neutral')
    return sentiStrength

#for causalSentence, polarity  in zip(causalSentences, sentiStrength):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiWordnet]

# %% [raw]
# def penn_to_wn(tag):
#     if tag.startswith('J'):
#         return wn.ADJ
#     elif tag.startswith('N'):
#         return wn.NOUN
#     elif tag.startswith('R'):
#         return wn.ADV
#     elif tag.startswith('V'):
#         return wn.VERB
#     return None
#
# def sentiment_sentiwordnet(text):
#     #text = text.decode("utf-8")
#     raw_sentences = sent_tokenize(text)
#     #print(raw_sentences)
#     sentiment = 0
#     tokens_count = 0
#
#     for raw_sentence in raw_sentences:
#         print(raw_sentence)
#         tagged_sentence = pos_tag(word_tokenize(raw_sentence))
#         print(tagged_sentence)
#
#         for word, tag in tagged_sentence:
#             wn_tag = penn_to_wn(tag)
#             if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
#                 continue
#
#             #lemma = lemmatizer.lemmatize(word, pos=wn_tag)
#             #if not lemma:
#             #    continue
#
#             synsets = wn.synsets(word, pos=wn_tag)
#             if not synsets:
#                 continue
#
#             synset = synsets[0]
#             swn_synset = swn.senti_synset(synset.name())
#             sentiment += swn_synset.pos_score() - swn_synset.neg_score()
#             tokens_count += 1
#         # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
#         if not tokens_count:
#             return 0
#         if sentiment>0:
#             #return "Positive"
#             print("Positive")
#         elif sentiment==0:
#             #return "Neutral"
#             print("Neutral")
#         else:
#             #return "Negative"
#             print("Negative")
#
# causalNarrative = ""
# for cS in causalSentences:
#     causalNarrative = causalNarrative+str(cS)+" "
#
# causalNarrative = nlp(causalNarrative)
# #raw_sentences = sent_tokenize(causalNarrative)
# #print(str(causalNarrative)+"\n")
# #print(raw_sentences)
# #print(str(narrative))
#
# sentiment_sentiwordnet(str(narrative))

# %% [markdown]
# ### [SentiWordNet OnlyVerbs]

# %% [raw]
# from nltk.corpus import wordnet as wn
# from nltk.corpus import sentiwordnet as swn
# from nltk.tag import pos_tag
# import nltk
#
#
# polarizedCauseffect = []
# for ce in causeffect:
#     print(ce[1])
#     token = nltk.word_tokenize(str(ce[1]))
#     after_tagging = nltk.pos_tag(token)
#     print(after_tagging)
#     print(len(after_tagging))
#     for tag in after_tagging:
#         if tag[1].startswith('V') or len(after_tagging)==1:
#             words = swn.senti_synsets(tag[0])
#             answer = list(words)[0]
#             if (answer.pos_score() > answer.neg_score()):
#                 mce = str(ce[1])+"(+ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             elif (answer.pos_score() > 0):
#                 mce = str(ce[1])+"(-ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             else:
#                 mce = str(ce[1])+"(neutral)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#
# polarizedCauseffect

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) without duplicates

# %%
causalSents = causalSentencesNoDup
print(len(causalSents))
# Out:
# 11

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) with duplicates

# %% [raw]
# causalSents = causalSentences
# print(len(causalSents))

# %% [markdown]
# ### Data Frame (Causal Sentence at Sentence Level)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

allen = Allen_sents_SentLevel(causalSents)
afinn = Afinn_sents_SentLevel(causalSents)
vader = Vader_sents_SentLevel(causalSents)
sentiStrength = Senti_sents_SentLevel(causalSents)

df2 = pd.DataFrame(list(zip(causalSents, allen, afinn, vader,sentiStrength)), columns =['Causal Sentence', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)


sentPolarity = []
sentsWeight_sentLevel = []

for index, row in df2.iterrows():
    sentWeightTuple = []
    weight = row['Weight']
    sentWeightTuple.append(weight)
    sentsWeight_sentLevel.append(sentWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# <style  type="text/css" >
# </style><table id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >AllenNLP</th>        <th class="col_heading level0 col2" >Afinn</th>        <th class="col_heading level0 col3" >Vader</th>        <th class="col_heading level0 col4" >SentiStrength</th>        <th class="col_heading level0 col5" >Weight</th>        <th class="col_heading level0 col6" >Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col1" class="data row0 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col2" class="data row0 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col3" class="data row0 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col4" class="data row0 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col5" class="data row0 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col6" class="data row0 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col1" class="data row1 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col2" class="data row1 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col4" class="data row1 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col5" class="data row1 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col6" class="data row1 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col1" class="data row2 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col2" class="data row2 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col3" class="data row2 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col4" class="data row2 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col5" class="data row2 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col6" class="data row2 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col1" class="data row3 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col2" class="data row3 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col3" class="data row3 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col4" class="data row3 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col5" class="data row3 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col6" class="data row3 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col1" class="data row4 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col6" class="data row4 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col1" class="data row5 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col6" class="data row5 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col1" class="data row6 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col4" class="data row6 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col5" class="data row6 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col6" class="data row6 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8

# %% [markdown]
# # Causal Triples' Polarity (Token Level)

# %% [markdown]
# ### [AllenNlp]

# %%
allen_word = []
allen_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks: 
        #print(token)
        preds = predictor.predict(str(token))
            #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen_tuple.append(-1)
                #allen_word.append(-1)
        else:
                #allen_word.append(1)
            allen_tuple.append(1)
    allen_word.append(allen_tuple)
    allen_tuple = []
                
for a,b in zip(causalTriples,allen_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, -1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, -1, 1]
# (no irrigation infrastructure, shows, public investment) [-1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 1, -1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, -1]
# (persistent heavy rains, cause, flooding) [-1, 1, -1]
# (persistent heavy rains, cause, the ethiopian highlands) [-1, 1, 1]
# (persistent heavy rains, cause, flood prone areas) [-1, 1, -1]
# (persistent heavy rains, cause, flood-prone areas) [-1, 1, -1]
# (highly saturated soils, cause, flooding) [1, 1, -1]
# (rain, caused, floods) [-1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (floods, impact, south sudan) [1, 1, 1]
# (floods, impact, food security) [1, 1, 1]

# %% [markdown]
# ### [Afinn]

# %%
afinn_word = []
afinn_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
        #if str(token) not in marks:
            #print(token)
        score = afn.score(str(token))
        if score > 0:
                #print('positive')
            afinn_tuple.append(1)
        elif score < 0:
                #print('negative')
            afinn_tuple.append(-1)
        else:
                #print('neutral')
            afinn_tuple.append(0)
    afinn_word.append(afinn_tuple)
    afinn_tuple = []

for a,b in zip(causalTriples,afinn_word):
   # print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [0, 0, 0]
# (the low level, shows, no irrigation infrastructure) [0, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, flooding) [0, 0, 0]
# (persistent heavy rains, cause, the ethiopian highlands) [0, 0, 0]
# (persistent heavy rains, cause, flood prone areas) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flooding) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, 0]
# (floods, impact, south sudan) [0, 0, 0]
# (floods, impact, food security) [0, 0, 0]

# %% [markdown]
# ### [Vader]

# %%
vader_word = []
vader_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) not in marks:
        vs = analyzer.polarity_scores(str(token))
        compound = vs['compound']
        if compound >= 0.05:
            vader_tuple.append(1)   
        elif compound <= -0.05 :
            vader_tuple.append(-1)
        elif  compound > -0.05 and compound < 0.05:
            vader_tuple.append(0)
    vader_word.append(vader_tuple)
    vader_tuple = []

for a,b in zip(causalTriples,vader_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [-1, 0, 0]
# (the low level, shows, no irrigation infrastructure) [-1, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, flooding) [0, 0, 0]
# (persistent heavy rains, cause, the ethiopian highlands) [0, 0, 0]
# (persistent heavy rains, cause, flood prone areas) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flooding) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, -1]
# (floods, impact, south sudan) [0, 0, 0]
# (floods, impact, food security) [0, 0, 1]

# %% [markdown]
# ### [SentiStrength]

# %%
senti_word = []
senti_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks:
        #print(token)
        result = senti.getSentiment(str(token), score='binary')
            #print(result)
        if result[0]==1:
                #print('Positive')
            senti_tuple.append(1)
        elif result[0]==-1:
                #print('Negative')
            senti_tuple.append(-1)
        else:
                #print('Neutral')
            senti_tuple.append(0)
    senti_word.append(senti_tuple)
    senti_tuple = []
    
for a,b in zip(causalTriples,senti_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, 1, 1]
# (no irrigation infrastructure, shows, public investment) [1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, 1]
# (south sudan's limited road network, shows, only 2 percent) [1, 1, 1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, 1]
# (persistent heavy rains, cause, flooding) [1, 1, 1]
# (persistent heavy rains, cause, the ethiopian highlands) [1, 1, 1]
# (persistent heavy rains, cause, flood prone areas) [1, 1, 1]
# (persistent heavy rains, cause, flood-prone areas) [1, 1, 1]
# (highly saturated soils, cause, flooding) [1, 1, 1]
# (rain, caused, floods) [1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (floods, impact, south sudan) [1, 1, 1]
# (floods, impact, food security) [1, 1, 1]

# %% [markdown]
# ### Data Frame (Causal Triples Token Level)

# %%
from pd_replicator import replicator

sum_list = []
sum_tup = []
limit= len(causalTriples)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

triplesWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    triplesWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([causalTriples[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],triplesWeight_TokenLevel[i],triplePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0           1              2
# Tokens           (institutional, weakness)  (hindered)  (development)
# AllenNlp                                -1          -1              1
# Afinn                                   -1           0              0
# Vader                                   -1           0              0
# SentiStrength                           -1           1              1
# Token Weight                            -4           0              2
# Token Polarity             Strong Negative     Neutral  Mild Positive
# Triple Weight                        -0.67        None           None
# Triple Polarity              Weak Negative        None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0           1  \
# Tokens           (institutional, weakness)  (hindered)
# AllenNlp                                -1          -1
# Afinn                                   -1           0
# Vader                                   -1           0
# SentiStrength                           -1           1
# Token Weight                            -4           0
# Token Polarity             Strong Negative     Neutral
# Triple Weight                        -0.67        None
# Triple Polarity              Weak Negative        None
#
#                                           2
# Tokens           (the, agriculture, sector)
# AllenNlp                                  1
# Afinn                                     0
# Vader                                     0
# SentiStrength                             1
# Token Weight                              2
# Token Polarity                Mild Positive
# Triple Weight                          None
# Triple Polarity                        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                 0              1  \
# Tokens           (no, irrigation, infrastructure)          shows
# AllenNlp                                       -1              1
# Afinn                                          -1              0
# Vader                                          -1              0
# SentiStrength                                   1              1
# Token Weight                                   -2              2
# Token Polarity                      Mild Negative  Mild Positive
# Triple Weight                                0.67           None
# Triple Polarity                     Weak Positive           None
#
#                                     2
# Tokens           (public, investment)
# AllenNlp                            1
# Afinn                               0
# Vader                               0
# SentiStrength                       1
# Token Weight                        2
# Token Polarity          Mild Positive
# Triple Weight                    None
# Triple Polarity                  None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1                     2
# Tokens           (the, low, level)          shows  (public, investment)
# AllenNlp                        -1              1                     1
# Afinn                            0              0                     0
# Vader                           -1              0                     0
# SentiStrength                   -1              1                     1
# Token Weight                    -3              2                     2
# Token Polarity   Moderate Negative  Mild Positive         Mild Positive
# Triple Weight                 0.33           None                  None
# Triple Polarity      Weak Positive           None                  None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1  \
# Tokens           (the, low, level)          shows
# AllenNlp                        -1              1
# Afinn                            0              0
# Vader                           -1              0
# SentiStrength                   -1              1
# Token Weight                    -3              2
# Token Polarity   Moderate Negative  Mild Positive
# Triple Weight                   -1           None
# Triple Polarity      Weak Negative           None
#
#                                                 2
# Tokens           (no, irrigation, infrastructure)
# AllenNlp                                       -1
# Afinn                                          -1
# Vader                                          -1
# SentiStrength                                   1
# Token Weight                                   -2
# Token Polarity                      Mild Negative
# Triple Weight                                None
# Triple Polarity                              None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                           0              1  \
# Tokens           (south, sudan, 's, limited, road, network)          shows
# AllenNlp                                                 -1              1
# Afinn                                                    -1              0
# Vader                                                    -1              0
# SentiStrength                                             1              1
# Token Weight                                             -2              2
# Token Polarity                                Mild Negative  Mild Positive
# Triple Weight                                             0           None
# Triple Polarity                                     Neutral           None
#
#                                   2
# Tokens           (only, 2, percent)
# AllenNlp                         -1
# Afinn                             0
# Vader                             0
# SentiStrength                     1
# Token Weight                      0
# Token Polarity              Neutral
# Triple Weight                  None
# Triple Polarity                None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                             0              1  \
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                               0           None
# Triple Polarity                                       Neutral           None
#
#                              2
# Tokens               (markets)
# AllenNlp                     1
# Afinn                        0
# Vader                        0
# SentiStrength                1
# Token Weight                 2
# Token Polarity   Mild Positive
# Triple Weight             None
# Triple Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                             0              1  \
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                           -0.67           None
# Triple Polarity                                 Weak Negative           None
#
#                                  2
# Tokens           (less, transport)
# AllenNlp                        -1
# Afinn                            0
# Vader                            0
# SentiStrength                    1
# Token Weight                     0
# Token Polarity             Neutral
# Triple Weight                 None
# Triple Polarity               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1           2
# Tokens           (persistent, heavy, rains)        (cause)  (flooding)
# AllenNlp                                 -1              1          -1
# Afinn                                     0              0           0
# Vader                                     0              0           0
# SentiStrength                             1              1           1
# Token Weight                              0              2           0
# Token Polarity                      Neutral  Mild Positive     Neutral
# Triple Weight                          0.67           None        None
# Triple Polarity               Weak Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          1.33           None
# Triple Polarity               Mild Positive           None
#
#                                            2
# Tokens           (the, ethiopian, highlands)
# AllenNlp                                   1
# Afinn                                      0
# Vader                                      0
# SentiStrength                              1
# Token Weight                               2
# Token Polarity                 Mild Positive
# Triple Weight                           None
# Triple Polarity                         None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          0.67           None
# Triple Polarity               Weak Positive           None
#
#                                      2
# Tokens           (flood, prone, areas)
# AllenNlp                            -1
# Afinn                                0
# Vader                                0
# SentiStrength                        1
# Token Weight                         0
# Token Polarity                 Neutral
# Triple Weight                     None
# Triple Polarity                   None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)          cause
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          0.67           None
# Triple Polarity               Weak Positive           None
#
#                                         2
# Tokens           (flood, -, prone, areas)
# AllenNlp                               -1
# Afinn                                   0
# Vader                                   0
# SentiStrength                           1
# Token Weight                            0
# Token Polarity                    Neutral
# Triple Weight                        None
# Triple Polarity                      None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1           2
# Tokens           (highly, saturated, soils)        (cause)  (flooding)
# AllenNlp                                  1              1          -1
# Afinn                                     0              0           0
# Vader                                     0              0           0
# SentiStrength                             1              1           1
# Token Weight                              2              2           0
# Token Polarity                Mild Positive  Mild Positive     Neutral
# Triple Weight                          1.33           None        None
# Triple Polarity               Mild Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens                  (rain)       (caused)       (floods)
# AllenNlp                    -1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 0              2              2
# Token Polarity         Neutral  Mild Positive  Mild Positive
# Triple Weight             1.33           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1  \
# Tokens                (floods)  (have, displaced)
# AllenNlp                     1                 -1
# Afinn                        0                  0
# Vader                        0                  0
# SentiStrength                1                 -1
# Token Weight                 2                 -2
# Token Polarity   Mild Positive      Mild Negative
# Triple Weight             0.67               None
# Triple Polarity  Weak Positive               None
#
#                                              2
# Tokens           (more, than, 100,000, people)
# AllenNlp                                     1
# Afinn                                        0
# Vader                                        0
# SentiStrength                                1
# Token Weight                                 2
# Token Polarity                   Mild Positive
# Triple Weight                             None
# Triple Polarity                           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1               2
# Tokens                (floods)  (have, displaced)  (south, sudan)
# AllenNlp                     1                 -1               1
# Afinn                        0                  0               0
# Vader                        0                  0               0
# SentiStrength                1                 -1               1
# Token Weight                 2                 -2               2
# Token Polarity   Mild Positive      Mild Negative   Mild Positive
# Triple Weight             0.67               None            None
# Triple Polarity  Weak Positive               None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                  2
# Tokens                (floods)        (raise)            (fears)
# AllenNlp                     1              1                 -1
# Afinn                        0              0                  0
# Vader                        0              0                 -1
# SentiStrength                1              1                 -1
# Token Weight                 2              2                 -3
# Token Polarity   Mild Positive  Mild Positive  Moderate Negative
# Triple Weight             0.33           None               None
# Triple Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens                (floods)         impact  (south, sudan)
# AllenNlp                     1              1               1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength                1              1               1
# Token Weight                 2              2               2
# Token Polarity   Mild Positive  Mild Positive   Mild Positive
# Triple Weight                2           None            None
# Triple Polarity  Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1                  2
# Tokens                    (floods)         impact   (food, security)
# AllenNlp                         1              1                  1
# Afinn                            0              0                  0
# Vader                            0              0                  1
# SentiStrength                    1              1                  1
# Token Weight                     2              2                  3
# Token Polarity       Mild Positive  Mild Positive  Moderate Positive
# Triple Weight                 2.33           None               None
# Triple Polarity  Moderate Positive           None               None

# %% [markdown]
# # Causal Sentences' Polarity (Token Level)

# %% [markdown]
# ### Generating list of tokens without stop words and punctuation marks.

# %%
def GenerateTokens(causalSentences):
    marks = ['.',',','(',')','-',':',';','/',"'s",'_','__','--','"', '’', '—']
    token_list = []
   
    for sent in causalSentences:
        token_tuple = []
        for token in sent:
            if str(token) not in marks:
                if str(token) not in stopwords.words():
                    token_tuple.append(str(token))
        token_list.append(token_tuple)
    return token_list
        
#print(len(token_list))
#print(token_list)

# %% [markdown]
# ### [AllenNlp]

# %%
def Allen_sents_TokenLevel(token_list):
    allen_word = []
    allen_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks: 
                #print(token)
            preds = predictor.predict(str(token))
                #print(preds['label'][0])
            label = preds['label'][0]
            if label is '0':
                allen_tuple.append(-1)
                    #allen_word.append(-1)
            else:
                    #allen_word.append(1)
                allen_tuple.append(1)
        allen_word.append(allen_tuple)
        allen_tuple = []
    return allen_word

#for a in allen_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Afinn]

# %%
def Afinn_sents_TokenLevel(token_list):
    afinn_word = []
    afinn_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
            #if str(token) not in marks:
                #print(token)
            score = afn.score(str(token))
            if score > 0:
                    #print('positive')
                afinn_tuple.append(1)
            elif score < 0:
                    #print('negative')
                afinn_tuple.append(-1)
            else:
                    #print('neutral')
                afinn_tuple.append(0)
        afinn_word.append(afinn_tuple)
        afinn_tuple = []
    return afinn_word

#for a in afinn_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Vader]

# %%
def Vader_sents_TokenLevel(token_list):
    vader_word = []
    vader_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
            vs = analyzer.polarity_scores(str(token))
            compound = vs['compound']
            if compound >= 0.05:
                vader_tuple.append(1)   
            elif compound <= -0.05 :
                vader_tuple.append(-1)
            elif  compound > -0.05 and compound < 0.05:
                vader_tuple.append(0)
        vader_word.append(vader_tuple)
        vader_tuple = []
    return vader_word

#for a in vader_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [SentiStrength]

# %%
def Senti_sents_TokenLevel(token_list):
    senti_word = []
    senti_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
                #print(token)
            result = senti.getSentiment(str(token), score='binary')
                #print(result)
            if result[0]==1:
                    #print('Positive')
                senti_tuple.append(1)
            elif result[0]==-1:
                    #print('Negative')
                senti_tuple.append(-1)
            else:
                    #print('Neutral')
                senti_tuple.append(0)
        senti_word.append(senti_tuple)
        senti_tuple = []
    return senti_word
    
#for a in senti_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### Data Frame (Causal Sentences Word Level)

# %%
token_list = GenerateTokens(causalSents)
allen_word = Allen_sents_TokenLevel(token_list)
afinn_word = Afinn_sents_TokenLevel(token_list)
vader_word = Vader_sents_TokenLevel(token_list)   
senti_word = Senti_sents_TokenLevel(token_list)

sum_list = []
sum_tup = []
limit= len(causalSents)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

sentsWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    sentsWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([token_list[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],sentsWeight_TokenLevel[i],SentencePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                1         2              3  \
# Tokens             institutional         weakness  hindered    development
# AllenNlp                       1               -1        -1              1
# Afinn                          0               -1         0              0
# Vader                          0               -1         0              0
# SentiStrength                  1               -1         1              1
# Token Weight                   2               -4         0              2
# Token Polarity     Mild Positive  Strong Negative   Neutral  Mild Positive
# Sentence Weight             0.67             None      None           None
# Sentence Polarity  Weak Positive             None      None           None
#
#                                4              5
# Tokens               agriculture         sector
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight             None           None
# Sentence Polarity           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 1.12           None           None
# Sentence Polarity      Mild Positive           None           None
#
#                                3              4           5               6  \
# Tokens                investment          shows  irrigation  infrastructure
# AllenNlp                       1              1          -1               1
# Afinn                          0              0           0               0
# Vader                          0              0           0               0
# SentiStrength                  1              1           1               1
# Token Weight                   2              2           0               2
# Token Polarity     Mild Positive  Mild Positive     Neutral   Mild Positive
# Sentence Weight             None           None        None            None
# Sentence Polarity           None           None        None            None
#
#                                7
# Tokens                    exists
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 0.85           None           None
# Sentence Polarity      Weak Positive           None           None
#
#                                3              4              5              6  \
# Tokens                investment          shows              2        percent
# AllenNlp                       1              1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1              1              1              1
# Token Weight                   2              2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive  Mild Positive
# Sentence Weight             None           None           None           None
# Sentence Polarity           None           None           None           None
#
#                          7        8              9       10             11  \
# Tokens               south    sudan        limited     road        network
# AllenNlp                -1       -1             -1       -1              1
# Afinn                    0        0             -1        0              0
# Vader                    0        0             -1        0              0
# SentiStrength            1        1              1        1              1
# Token Weight             0        0             -2        0              2
# Token Polarity     Neutral  Neutral  Mild Negative  Neutral  Mild Positive
# Sentence Weight       None     None           None     None           None
# Sentence Polarity     None     None           None     None           None
#
#                               12
# Tokens                     paved
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0               1               2  \
# Tokens                  inadequate  transportation  infrastructure
# AllenNlp                        -1               1               1
# Afinn                           -1               0               0
# Vader                           -1               0               0
# SentiStrength                   -1               1               1
# Token Weight                    -4               2               2
# Token Polarity     Strong Negative   Mild Positive   Mild Positive
# Sentence Weight               0.86            None            None
# Sentence Polarity    Weak Positive            None            None
#
#                                3        4              5              6
# Tokens                  resulted     less      transport        markets
# AllenNlp                       1       -1              1              1
# Afinn                          0        0              0              0
# Vader                          0        0              0              0
# SentiStrength                  1        1              1              1
# Token Weight                   2        0              2              2
# Token Polarity     Mild Positive  Neutral  Mild Positive  Mild Positive
# Sentence Weight             None     None           None           None
# Sentence Polarity           None     None           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2              3  \
# Tokens                persistent    heavy    rains      ethiopian
# AllenNlp                       1       -1       -1              1
# Afinn                          0        0        0              0
# Vader                          0        0        0              0
# SentiStrength                  1        1        1              1
# Token Weight                   2        0        0              2
# Token Polarity     Mild Positive  Neutral  Neutral  Mild Positive
# Sentence Weight                1     None     None           None
# Sentence Polarity  Weak Positive     None     None           None
#
#                                4              5         6        7        8  \
# Tokens                 highlands          cause  flooding    flood    prone
# AllenNlp                       1              1        -1       -1       -1
# Afinn                          0              0         0        0        0
# Vader                          0              0         0        0        0
# SentiStrength                  1              1         1        1        1
# Token Weight                   2              2         0        0        0
# Token Polarity     Mild Positive  Mild Positive   Neutral  Neutral  Neutral
# Sentence Weight             None           None      None     None     None
# Sentence Polarity           None           None      None     None     None
#
#                                9
# Tokens                     areas
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2        3        4  \
# Tokens                persistent    heavy    rains    south    sudan
# AllenNlp                       1       -1       -1       -1       -1
# Afinn                          0        0        0        0        0
# Vader                          0        0        0        0        0
# SentiStrength                  1        1        1        1        1
# Token Weight                   2        0        0        0        0
# Token Polarity     Mild Positive  Neutral  Neutral  Neutral  Neutral
# Sentence Weight              0.6     None     None     None     None
# Sentence Polarity  Weak Positive     None     None     None     None
#
#                                5         6        7        8              9
# Tokens                     cause  flooding    flood    prone          areas
# AllenNlp                       1        -1       -1       -1              1
# Afinn                          0         0        0        0              0
# Vader                          0         0        0        0              0
# SentiStrength                  1         1        1        1              1
# Token Weight                   2         0        0        0              2
# Token Polarity     Mild Positive   Neutral  Neutral  Neutral  Mild Positive
# Sentence Weight             None      None     None     None           None
# Sentence Polarity           None      None     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0          1        2              3         4  \
# Tokens                    highly  saturated    soils          cause  flooding
# AllenNlp                       1         -1       -1              1        -1
# Afinn                          0          0        0              0         0
# Vader                          0          0        0              0         0
# SentiStrength                  1          1        1              1         1
# Token Weight                   2          0        0              2         0
# Token Polarity     Mild Positive    Neutral  Neutral  Mild Positive   Neutral
# Sentence Weight             0.75       None     None           None      None
# Sentence Polarity  Weak Positive       None     None           None      None
#
#                          5        6              7
# Tokens               flood    prone          areas
# AllenNlp                -1       -1              1
# Afinn                    0        0              0
# Vader                    0        0              0
# SentiStrength            1        1              1
# Token Weight             0        0              2
# Token Polarity     Neutral  Neutral  Mild Positive
# Sentence Weight       None     None           None
# Sentence Polarity     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      rain         caused         floods
# AllenNlp                      -1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   0              2              2
# Token Polarity           Neutral  Mild Positive  Mild Positive
# Sentence Weight             1.33           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2              3  \
# Tokens                    floods      displaced        100,000         people
# AllenNlp                       1             -1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1             -1              1              1
# Token Weight                   2             -2              2              2
# Token Polarity     Mild Positive  Mild Negative  Mild Positive  Mild Positive
# Sentence Weight             0.67           None           None           None
# Sentence Polarity  Weak Positive           None           None           None
#
#                          4        5
# Tokens               south    sudan
# AllenNlp                -1       -1
# Afinn                    0        0
# Vader                    0        0
# SentiStrength            1        1
# Token Weight             0        0
# Token Polarity     Neutral  Neutral
# Sentence Weight       None     None
# Sentence Polarity     None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                  2
# Tokens                    floods          raise              fears
# AllenNlp                       1              1                 -1
# Afinn                          0              0                  0
# Vader                          0              0                 -1
# SentiStrength                  1              1                 -1
# Token Weight                   2              2                 -3
# Token Polarity     Mild Positive  Mild Positive  Moderate Negative
# Sentence Weight             0.33           None               None
# Sentence Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                  1              2  \
# Tokens                    floods      devastatingly         impact
# AllenNlp                       1                 -1              1
# Afinn                          0                  0              0
# Vader                          0                 -1              0
# SentiStrength                  1                 -1              1
# Token Weight                   2                 -3              2
# Token Polarity     Mild Positive  Moderate Negative  Mild Positive
# Sentence Weight             0.86               None           None
# Sentence Polarity  Weak Positive               None           None
#
#                                3                  4        5        6
# Tokens                      food           security    south    sudan
# AllenNlp                       1                  1       -1       -1
# Afinn                          0                  0        0        0
# Vader                          0                  1        0        0
# SentiStrength                  1                  1        1        1
# Token Weight                   2                  3        0        0
# Token Polarity     Mild Positive  Moderate Positive  Neutral  Neutral
# Sentence Weight             None               None     None     None
# Sentence Polarity           None               None     None     None

# %% [markdown]
# # Overall Polarity of Sents and Triples by all Four Methods

# %% [markdown]
# ### Follow the following instructions (steps) before executing the cell given below
# #### Step1- Execute cell for setting causalSents to causalTriples (with duplicates).
# #### Step2- Execute cell for computing sentences' polarity at sentence level.
# #### Step3- Execute cell for computing sentences' polarity at token level.
# #### Step4- Execute the below cell.

# %% [raw]
# totalWeight_AllMethods = []
#
# limit= len(causalSents)
#
# for i in range(0,limit):
#     #dataframe_WordLevel(i)
#     #print(len(allen_word[i]))
#     sum_tup = []
#     for j in range(0,len(sentsWeight_sentLevel[i])):
#         res = sentsWeight_sentLevel[i][j]+triplesWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]+triplesWeight_TokenLevel[i][j]
#         #print(res)
#         res = round(res/4,2)
#         sum_tup.append(res)
#     totalWeight_AllMethods.append(sum_tup)
#
# totalPlarity_AllMethods = DetectPolarity(totalWeight_AllMethods)
#
# df_AllMethods = pd.DataFrame(list(zip(causalSents, causalTriples, sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel, totalWeight_AllMethods,totalPlarity_AllMethods)),
#                              columns =['Causal Sentence', 'Causal Triple', 'Method1 (Sent_SentLevel)', 'Method2 (Trip_SentLevel)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)','Total Weight','Overall Polarity'])
#
# df_AllMethods.style

# %% [markdown]
# # Overall Polarity of Triples at two (sentence and token) levels

# %%
totalTriplesWeight_AllLevels = []

limit= len(causalTriples)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(triplesWeight_sentLevel[i])):
        res = triplesWeight_sentLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalTriplesWeight_AllLevels.append(sum_tup)
    
totalTripsPlarity_AllLevels = DetectPolarity(totalTriplesWeight_AllLevels)

df_TripAllLevels = pd.DataFrame(list(zip(causalTriples, triplesWeight_sentLevel, triplesWeight_TokenLevel, totalTriplesWeight_AllLevels, totalTripsPlarity_AllLevels)), 
                             columns =['Causal Triple', 'Weight (Trip_SentLevel)','Weight (Trip_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_TripAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d559be8c_3cf2_11ec_a91c_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Triple</th>        <th class="col_heading level0 col1" >Weight (Trip_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Trip_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col0" class="data row0 col0" >(institutional weakness, hindered, development)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col2" class="data row0 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col3" class="data row0 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col4" class="data row0 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col0" class="data row1 col0" >(institutional weakness, hindered, the agriculture sector)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col2" class="data row1 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col3" class="data row1 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col4" class="data row1 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col0" class="data row2 col0" >(no irrigation infrastructure, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col1" class="data row2 col1" >[-1]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col2" class="data row2 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col3" class="data row2 col3" >[-0.16]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col4" class="data row2 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col0" class="data row3 col0" >(the low level, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col1" class="data row3 col1" >[-3]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col2" class="data row3 col2" >[0.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col3" class="data row3 col3" >[-1.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col0" class="data row4 col0" >(the low level, shows, no irrigation infrastructure)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col1" class="data row4 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col2" class="data row4 col2" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col3" class="data row4 col3" >[-2.5]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col4" class="data row4 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col0" class="data row5 col0" >(south sudan's limited road network, shows, only 2 percent)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col1" class="data row5 col1" >[-2]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col2" class="data row5 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col3" class="data row5 col3" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col4" class="data row5 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col0" class="data row6 col0" >(inadequate transportation infrastructure, resulted, markets)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col1" class="data row6 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col2" class="data row6 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col3" class="data row6 col3" >[-2.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col4" class="data row6 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col0" class="data row7 col0" >(inadequate transportation infrastructure, resulted, less transport)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col1" class="data row7 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col2" class="data row7 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col3" class="data row7 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col4" class="data row7 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col0" class="data row8 col0" >(persistent heavy rains, cause, flooding)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col1" class="data row8 col1" >[0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col3" class="data row8 col3" >[0.34]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col4" class="data row8 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row9_col0" class="data row9 col0" >(persistent heavy r

# %% [markdown]
# # Overall Polarity of Sentences at two (sentence and token) Levels

# %%
totalSentsWeight_AllLevels = []

limit= len(causalSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalSentsWeight_AllLevels.append(sum_tup)
    
totalSentsPolarity_AllLevels = DetectPolarity(totalSentsWeight_AllLevels)

df_SentsAllLevels = pd.DataFrame(list(zip(causalSents, sentsWeight_sentLevel, sentsWeight_TokenLevel, totalSentsWeight_AllLevels, totalSentsPolarity_AllLevels)), 
                             columns =['Causal Sentence', 'Weight (Sent_SentLevel)','Weight (Sent_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_SentsAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d560e568_3cf2_11ec_870b_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >Weight (Sent_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Sent_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col2" class="data row0 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col3" class="data row0 col3" >[-1.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col4" class="data row0 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col2" class="data row1 col2" >[1.12]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col3" class="data row1 col3" >[-1.44]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col4" class="data row1 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col1" class="data row2 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col2" class="data row2 col2" >[0.85]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col3" class="data row2 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col4" class="data row2 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col1" class="data row3 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col2" class="data row3 col2" >[0.86]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col3" class="data row3 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col1" class="data row4 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col2" class="data row4 col2" >[1.0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col3" class="data row4 col3" >[0.5]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col4" class="data row4 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col1" class="data row5 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col2" class="data row5 col2" >[0.6]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col3" class="data row5 col3" >[0.3]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col4" class="data row5 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col1" class="data row6 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col2" class="data row6 col2" >[0.75]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col3" class="data row6 col3" >[0.38]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col4" class="data row6 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col0" class="data row7 col0" >rain caused floods.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col1" class="data row7 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col2" class="data row7 col2" >[1.33]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col3" class="data row7 col3" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col4" class="data row7 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col0" class="data row8 col0" >floods have displaced more than 100,000 people in south sudan.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col1" class="data row8 col1" >[-2]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col3" class="data row8 col3" >[-0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col4" class="data row8 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row9" class="row_heading level0

# %% [markdown]
# # Plot the Polarized/Modified Causal Graph.

# %% [raw]
# cg = nx.DiGraph()
#
# for ce in polarizedCauseffect:
#     s = str(ce[0])
#     d = str(ce[2])
#     cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
#     cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
#     cg.add_edge(s, d, predicade=str(ce[1]))
#
# print(len(cg.nodes))
# print(len(cg.edges))
#
# pos = nx.spring_layout(cg, k=4, iterations=20)
# plt.figure(figsize=(15,12))
#
# nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
# edge_labels = nx.get_edge_attributes(cg,'predicade')
# nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)
#
# plt.axis('off')
# plt.show()
