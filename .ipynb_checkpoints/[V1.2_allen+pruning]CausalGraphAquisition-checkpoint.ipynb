# %% [markdown]
# # Import necessary libraries.

# %%
import spacy
import textacy
import textacy.preprocessing
import textacy.resources
#import textacy.keyterms
import textacy.ke
#import neuralcoref
from spacy.symbols import ORTH, POS, NOUN, VERB,PRON
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt 
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
#from nltk import word_tokenize, pos_tag
from networkx.readwrite import json_graph;
import json
from afinn import Afinn
afn = Afinn()
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
lemmatizer = WordNetLemmatizer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from allennlp_models.pretrained import load_predictor
predictor1 = load_predictor("roberta-sst")   #for sentiment analysis
#predictor = load_predictor("coref-spanbert") #for coreference resolution
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')
import pandas as pd
from IPython.display import display
import collections
from nltk.corpus import stopwords
set(stopwords.words('english'))
from pd_replicator import replicator
from textacy.preprocessing.remove import remove_punctuation
from textacy.preprocessing.normalize import normalize_hyphenated_words

import allennlp_models.tagging

#coreference resolution
from allennlp.predictors.predictor import Predictor
predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz")

#from allennlp_models.pretrained import load_predictor
#predictor = load_predictor("roberta-sst")

nlp = spacy.load("en_core_web_sm")
#neuralcoref.add_to_pipe(nlp)
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp\tango\__init__.py:18: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   "AllenNLP Tango is an experimental API and parts of it might change or disappear "
# 2023-08-08 05:43:27,197 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-08-08 05:43:27,212 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\coref-spanbert.json as plain json
# 2023-08-08 05:43:27,219 - INFO - allennlp.common.params - id = coref-spanbert
# 2023-08-08 05:43:27,223 - INFO - allennlp.common.params - type = coref-spanbert
# 2023-08-08 05:43:27,224 - INFO - allennlp.common.params - registered_model_name = coref
# 2023-08-08 05:43:27,227 - INFO - allennlp.common.params - type = coref
# 2023-08-08 05:43:27,228 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:43:27,230 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:43:27,232 - INFO - allennlp.common.params - display_name = Coreference Resolution
# 2023-08-08 05:43:27,234 - INFO - allennlp.common.params - type = Coreference Resolution
# 2023-08-08 05:43:27,237 - INFO - allennlp.common.params - task_id = coref
# 2023-08-08 05:43:27,239 - INFO - allennlp.common.params - type = coref
# 2023-08-08 05:43:27,241 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,243 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,245 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,251 - INFO - allennlp.common.params - model_usage.archive_file = coref-spanbert-large-2021.03.10.tar.gz
# 2023-08-08 05:43:27,253 - INFO - allennlp.common.params - type = coref-spanbert-large-2021.03.10.tar.gz
# 2023-08-08 05:43:27,261 - INFO - allennlp.common.params - model_usage.training_config = coref/coref_spanbert_large.jsonnet
# 2023-08-08 05:43:27,263 - INFO - allennlp.common.params - type = coref/coref_spanbert_large.jsonnet
# 2023-08-08 05:43:27,272 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:43:27,276 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:43:27,289 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:43:27,293 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:27,297 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:27,301 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:27,304 - INFO - allennlp.common.params - model_details.description = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-08-08 05:43:27,308 - INFO - allennlp.common.params - type = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-08-08 05:43:27,320 - INFO - allennlp.common.params - model_details.short_description = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-08-08 05:43:27,325 - INFO - allennlp.common.params - type = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-08-08 05:43:27,332 - INFO - allennlp.common.params - model_details.developed_by = Lee et al
# 2023-08-08 05:43:27,335 - INFO - allennlp.common.params - type = Lee et al
# 2023-08-08 05:43:27,336 - INFO - allennlp.common.params - model_details.contributed_by = Zhaofeng Wu
# 2023-08-08 05:43:27,338 - INFO - allennlp.common.params - type = Zhaofeng Wu
# 2023-08-08 05:43:27,339 - INFO - allennlp.common.params - model_details.date = 2020-02-27
# 2023-08-08 05:43:27,341 - INFO - allennlp.common.params - type = 2020-02-27
# 2023-08-08 05:43:27,344 - INFO - allennlp.common.params - model_details.version = 2
# 2023-08-08 05:43:27,346 - INFO - allennlp.common.params - type = 2
# 2023-08-08 05:43:27,348 - INFO - allennlp.common.params - model_details.model_type = SpanBERT
# 2023-08-08 05:43:27,351 - INFO - allennlp.common.params - type = SpanBERT
# 2023-08-08 05:43:27,353 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:27,356 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:27,359 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:27,363 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lee2018HigherorderCR,
# title={Higher-order Coreference Resolution with Coarse-to-fine Inference},
# author={Kenton Lee and Luheng He and L. Zettlemoyer},
# booktitle={NAACL-HLT},
# year={2018}}
#
# 2023-08-08 05:43:27,365 - INFO - allennlp.common.params - model_details.paper.title = Higher-order Coreference Resolution with Coarse-to-fine Inference
# 2023-08-08 05:43:27,367 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:4891749
# 2023-08-08 05:43:27,370 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:43:27,373 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:43:27,375 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:43:27,385 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:27,389 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:27,392 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:27,395 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:43:27,398 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:43:27,399 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:43:27,402 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:27,409 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:27,416 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:27,420 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:43:27,424 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:43:27,426 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:27,429 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:27,438 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:27,444 - INFO - allennlp.common.params - metrics.model_performance_measures = CoNLL coref scores and Mention Recall
# 2023-08-08 05:43:27,448 - INFO - allennlp.common.params - type = CoNLL coref scores and Mention Recall
# 2023-08-08 05:43:27,452 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:43:27,457 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:43:27,463 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:27,469 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:27,475 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:27,483 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:27,490 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:27,494 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:27,501 - INFO - allennlp.common.params - evaluation_data.dataset.name = Ontonotes 5.0
# 2023-08-08 05:43:27,508 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-08-08 05:43:27,515 - INFO - allennlp.common.params - evaluation_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-08-08 05:43:27,522 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = /path/to/dataset
# 2023-08-08 05:43:27,527 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:43:27,529 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:43:27,533 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:27,537 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:27,542 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:27,545 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:27,549 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:27,553 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:27,557 - INFO - allennlp.common.params - training_data.dataset.name = Ontonotes 5.0
# 2023-08-08 05:43:27,559 - INFO - allennlp.common.params - training_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-08-08 05:43:27,560 - INFO - allennlp.common.params - training_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-08-08 05:43:27,561 - INFO - allennlp.common.params - training_data.dataset.processed_url = /path/to/dataset
# 2023-08-08 05:43:27,563 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:43:27,565 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 05:43:27,568 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:27,572 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:27,579 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:27,582 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 05:43:27,585 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:43:27,588 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:27,591 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:27,593 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:27,597 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:43:27,601 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:27,605 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:27,607 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:27,610 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:43:27,613 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\evaluate_rc-lerc.json as plain json
# 2023-08-08 05:43:27,626 - INFO - allennlp.common.params - id = evaluate_rc-lerc
# 2023-08-08 05:43:27,628 - INFO - allennlp.common.params - type = evaluate_rc-lerc
# 2023-08-08 05:43:27,630 - INFO - allennlp.common.params - registered_model_name = lerc
# 2023-08-08 05:43:27,631 - INFO - allennlp.common.params - type = lerc
# 2023-08-08 05:43:27,634 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:43:27,637 - INFO - allennlp.common.params - registered_predictor_name = lerc
# 2023-08-08 05:43:27,639 - INFO - allennlp.common.params - type = lerc
# 2023-08-08 05:43:27,640 - INFO - allennlp.common.params - display_name = Learned Evaluation for Reading Comprehension (LERC)
# 2023-08-08 05:43:27,642 - INFO - allennlp.common.params - type = Learned Evaluation for Reading Comprehension (LERC)
# 2023-08-08 05:43:27,645 - INFO - allennlp.common.params - task_id = evaluate_rc
# 2023-08-08 05:43:27,647 - INFO - allennlp.common.params - type = evaluate_rc
# 2023-08-08 05:43:27,650 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,654 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,657 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,660 - INFO - allennlp.common.params - model_usage.archive_file = lerc-2020-11-18.tar.gz
# 2023-08-08 05:43:27,663 - INFO - allennlp.common.params - type = lerc-2020-11-18.tar.gz
# 2023-08-08 05:43:27,671 - INFO - allennlp.common.params - model_usage.training_config = None
# 2023-08-08 05:43:27,673 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:43:27,674 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:43:27,683 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:43:27,686 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:27,688 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:27,691 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:27,693 - INFO - allennlp.common.params - model_details.description = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-08-08 05:43:27,695 - INFO - allennlp.common.params - type = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-08-08 05:43:27,705 - INFO - allennlp.common.params - model_details.short_description = A BERT model that scores candidate answers from 0 to 1.
# 2023-08-08 05:43:27,707 - INFO - allennlp.common.params - type = A BERT model that scores candidate answers from 0 to 1.
# 2023-08-08 05:43:27,713 - INFO - allennlp.common.params - model_details.developed_by = Chen et al
# 2023-08-08 05:43:27,716 - INFO - allennlp.common.params - type = Chen et al
# 2023-08-08 05:43:27,719 - INFO - allennlp.common.params - model_details.contributed_by = Anthony Chen
# 2023-08-08 05:43:27,722 - INFO - allennlp.common.params - type = Anthony Chen
# 2023-08-08 05:43:27,724 - INFO - allennlp.common.params - model_details.date = 2021-03-10
# 2023-08-08 05:43:27,725 - INFO - allennlp.common.params - type = 2021-03-10
# 2023-08-08 05:43:27,726 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:43:27,727 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:43:27,728 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-08-08 05:43:27,729 - INFO - allennlp.common.params - type = BERT
# 2023-08-08 05:43:27,732 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:27,736 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:27,740 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:27,742 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Chen2020MOCHAAD,
# title={MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics},
# author={Anthony Chen and Gabriel Stanovsky and S. Singh and Matt Gardner},
# booktitle={EMNLP},
# year={2020}}
#
# 2023-08-08 05:43:27,742 - INFO - allennlp.common.params - model_details.paper.title = MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics
# 2023-08-08 05:43:27,743 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:222208714
# 2023-08-08 05:43:27,745 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:43:27,746 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:43:27,749 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:43:27,759 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:27,765 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:27,769 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:27,772 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:43:27,773 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:43:27,775 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:43:27,776 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:27,778 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:27,780 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:27,786 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:43:27,789 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:43:27,791 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:27,793 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:27,796 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:27,800 - INFO - allennlp.common.params - metrics.model_performance_measures = Pearson Correlation
# 2023-08-08 05:43:27,803 - INFO - allennlp.common.params - type = Pearson Correlation
# 2023-08-08 05:43:27,804 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:43:27,806 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:43:27,808 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:27,810 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:27,813 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:27,816 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:27,821 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:27,823 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:27,826 - INFO - allennlp.common.params - evaluation_data.dataset.name = MOCHA
# 2023-08-08 05:43:27,828 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://allennlp.org/mocha
# 2023-08-08 05:43:27,829 - INFO - allennlp.common.params - evaluation_data.dataset.notes = To evaluate this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-08-08 05:43:27,831 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = None
# 2023-08-08 05:43:27,833 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:43:27,835 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:43:27,837 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:27,839 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:27,842 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:27,844 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:27,847 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:27,855 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:27,857 - INFO - allennlp.common.params - training_data.dataset.name = MOCHA
# 2023-08-08 05:43:27,859 - INFO - allennlp.common.params - training_data.dataset.url = https://allennlp.org/mocha
# 2023-08-08 05:43:27,860 - INFO - allennlp.common.params - training_data.dataset.notes = To train this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-08-08 05:43:27,861 - INFO - allennlp.common.params - training_data.dataset.processed_url = None
# 2023-08-08 05:43:27,862 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:43:27,863 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 05:43:27,866 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:27,870 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:27,874 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:27,878 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 05:43:27,880 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:43:27,886 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:27,890 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:27,893 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:27,895 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:43:27,896 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:27,900 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:27,903 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:27,907 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:43:27,911 - WARNING - allennlp.common.model_card - lerc is not a registered model.
# 2023-08-08 05:43:27,915 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\generation-bart.json as plain json
# 2023-08-08 05:43:27,927 - INFO - allennlp.common.params - id = generation-bart
# 2023-08-08 05:43:27,929 - INFO - allennlp.common.params - type = generation-bart
# 2023-08-08 05:43:27,932 - INFO - allennlp.common.params - registered_model_name = bart
# 2023-08-08 05:43:27,934 - INFO - allennlp.common.params - type = bart
# 2023-08-08 05:43:27,936 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:43:27,938 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:43:27,940 - INFO - allennlp.common.params - display_name = BART
# 2023-08-08 05:43:27,941 - INFO - allennlp.common.params - type = BART
# 2023-08-08 05:43:27,943 - INFO - allennlp.common.params - task_id = None
# 2023-08-08 05:43:27,944 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,948 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,952 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:27,955 - INFO - allennlp.common.params - model_usage.archive_file = bart-2020.07.25.tar.gz
# 2023-08-08 05:43:27,958 - INFO - allennlp.common.params - type = bart-2020.07.25.tar.gz
# 2023-08-08 05:43:27,973 - INFO - allennlp.common.params - model_usage.training_config = generation/bart_cnn_dm.jsonnet
# 2023-08-08 05:43:27,975 - INFO - allennlp.common.params - type = generation/bart_cnn_dm.jsonnet
# 2023-08-08 05:43:27,987 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:43:27,988 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:43:28,001 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:43:28,003 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,007 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,010 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,012 - INFO - allennlp.common.params - model_details.description = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-08-08 05:43:28,015 - INFO - allennlp.common.params - type = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-08-08 05:43:28,029 - INFO - allennlp.common.params - model_details.short_description = BART with a language model head for generation.
# 2023-08-08 05:43:28,032 - INFO - allennlp.common.params - type = BART with a language model head for generation.
# 2023-08-08 05:43:28,044 - INFO - allennlp.common.params - model_details.developed_by = Lewis et al
# 2023-08-08 05:43:28,046 - INFO - allennlp.common.params - type = Lewis et al
# 2023-08-08 05:43:28,047 - INFO - allennlp.common.params - model_details.contributed_by = Dirk Groeneveld
# 2023-08-08 05:43:28,049 - INFO - allennlp.common.params - type = Dirk Groeneveld
# 2023-08-08 05:43:28,052 - INFO - allennlp.common.params - model_details.date = 2020-07-25
# 2023-08-08 05:43:28,054 - INFO - allennlp.common.params - type = 2020-07-25
# 2023-08-08 05:43:28,055 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:43:28,057 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:43:28,058 - INFO - allennlp.common.params - model_details.model_type = BART
# 2023-08-08 05:43:28,059 - INFO - allennlp.common.params - type = BART
# 2023-08-08 05:43:28,061 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:28,063 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:28,069 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:28,072 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lewis2020BARTDS,
# title={BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension},
# author={M. Lewis and Yinhan Liu and Naman Goyal and Marjan Ghazvininejad and A. Mohamed and Omer Levy and Ves Stoyanov and L. Zettlemoyer},
# booktitle={ACL},
# year={2020}}
#
# 2023-08-08 05:43:28,074 - INFO - allennlp.common.params - model_details.paper.title = BART: Denosing Sequence-to-Sequence Pre-training for Natural Language Generation,Translation, and Comprehension
# 2023-08-08 05:43:28,076 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:204960716
# 2023-08-08 05:43:28,077 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:43:28,078 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:43:28,079 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:43:28,094 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:28,097 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:28,105 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:28,108 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:43:28,110 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:43:28,111 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:43:28,111 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:28,114 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:28,118 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:28,123 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:43:28,126 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:43:28,128 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:28,130 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:28,135 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:28,138 - INFO - allennlp.common.params - metrics.model_performance_measures = ROUGE and BLEU
# 2023-08-08 05:43:28,141 - INFO - allennlp.common.params - type = ROUGE and BLEU
# 2023-08-08 05:43:28,143 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:43:28,144 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:43:28,146 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:28,151 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:28,155 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:28,162 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:28,167 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:28,171 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:28,177 - INFO - allennlp.common.params - evaluation_data.dataset.name = CNN/DailyMail
# 2023-08-08 05:43:28,183 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-08-08 05:43:28,189 - INFO - allennlp.common.params - evaluation_data.dataset.notes = Please download the data from the url provided.
# 2023-08-08 05:43:28,191 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:43:28,192 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:43:28,194 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:28,197 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:28,204 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:28,213 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:28,223 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:28,232 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:28,240 - INFO - allennlp.common.params - training_data.dataset.name = CNN/DailyMail
# 2023-08-08 05:43:28,246 - INFO - allennlp.common.params - training_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-08-08 05:43:28,251 - INFO - allennlp.common.params - training_data.dataset.notes = Please download the data from the url provided.
# 2023-08-08 05:43:28,254 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:43:28,255 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 05:43:28,256 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:28,258 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:28,264 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:28,267 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 05:43:28,270 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:43:28,271 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:28,273 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:28,275 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:28,277 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:43:28,278 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:28,281 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:28,285 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:28,288 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:43:28,291 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\glove-sst.json as plain json
# 2023-08-08 05:43:28,302 - INFO - allennlp.common.params - id = glove-sst
# 2023-08-08 05:43:28,304 - INFO - allennlp.common.params - type = glove-sst
# 2023-08-08 05:43:28,306 - INFO - allennlp.common.params - registered_model_name = None
# 2023-08-08 05:43:28,307 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:43:28,309 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:43:28,310 - INFO - allennlp.common.params - display_name = GLoVe-LSTM
# 2023-08-08 05:43:28,312 - INFO - allennlp.common.params - type = GLoVe-LSTM
# 2023-08-08 05:43:28,312 - INFO - allennlp.common.params - task_id = sentiment-analysis
# 2023-08-08 05:43:28,314 - INFO - allennlp.common.params - type = sentiment-analysis
# 2023-08-08 05:43:28,317 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:28,321 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:28,323 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:28,325 - INFO - allennlp.common.params - model_usage.archive_file = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-08-08 05:43:28,327 - INFO - allennlp.common.params - type = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-08-08 05:43:28,337 - INFO - allennlp.common.params - model_usage.training_config = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-08-08 05:43:28,338 - INFO - allennlp.common.params - type = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-08-08 05:43:28,346 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:43:28,347 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:43:28,357 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:43:28,359 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,362 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,365 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,370 - INFO - allennlp.common.params - model_details.description = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-08-08 05:43:28,372 - INFO - allennlp.common.params - type = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-08-08 05:43:28,379 - INFO - allennlp.common.params - model_details.short_description = LSTM binary classifier with GloVe embeddings.
# 2023-08-08 05:43:28,380 - INFO - allennlp.common.params - type = LSTM binary classifier with GloVe embeddings.
# 2023-08-08 05:43:28,389 - INFO - allennlp.common.params - model_details.developed_by = None
# 2023-08-08 05:43:28,390 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-08-08 05:43:28,391 - INFO - allennlp.common.params - model_details.date = 2020-06-09
# 2023-08-08 05:43:28,393 - INFO - allennlp.common.params - type = 2020-06-09
# 2023-08-08 05:43:28,395 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:43:28,396 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:43:28,399 - INFO - allennlp.common.params - model_details.model_type = LSTM
# 2023-08-08 05:43:28,402 - INFO - allennlp.common.params - type = LSTM
# 2023-08-08 05:43:28,404 - INFO - allennlp.common.params - model_details.paper = None
# 2023-08-08 05:43:28,405 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:43:28,408 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:43:28,409 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:43:28,417 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:28,420 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:28,423 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:43:28,425 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:43:28,427 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:43:28,428 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:43:28,429 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:28,431 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:28,436 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:43:28,437 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:43:28,440 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:43:28,441 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:28,447 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:28,450 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:43:28,453 - INFO - allennlp.common.params - metrics.model_performance_measures = Accuracy
# 2023-08-08 05:43:28,455 - INFO - allennlp.common.params - type = Accuracy
# 2023-08-08 05:43:28,457 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:43:28,457 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:43:28,459 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:28,461 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:28,464 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:43:28,468 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:28,472 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:28,474 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:43:28,476 - INFO - allennlp.common.params - evaluation_data.dataset.name = Stanford Sentiment Treebank
# 2023-08-08 05:43:28,477 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-08-08 05:43:28,478 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/test.txt
# 2023-08-08 05:43:28,479 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:43:28,481 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:43:28,483 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:28,487 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:28,490 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:43:28,493 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:28,495 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:28,498 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:43:28,502 - INFO - allennlp.common.params - training_data.dataset.name = Stanford Sentiment Treebank
# 2023-08-08 05:43:28,504 - INFO - allennlp.common.params - training_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-08-08 05:43:28,506 - INFO - allennlp.common.params - training_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/train.txt
# 2023-08-08 05:43:28,507 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:43:28,509 - INFO - allennlp.common.params - training_data.preprocessing = Binary classification setting
# 2023-08-08 05:43:28,510 - INFO - allennlp.common.params - type = Binary classification setting
# 2023-08-08 05:43:28,511 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:28,513 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:28,517 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:43:28,520 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = Accuracy: 87% on SST test set.
# 2023-08-08 05:43:28,522 - INFO - allennlp.common.params - type = Accuracy: 87% on SST test set.
# 2023-08-08 05:43:28,530 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:43:28,533 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:28,537 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:28,539 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:43:28,543 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:43:28,546 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:28,549 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:28,553 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:43:28,556 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:43:28,559 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\lm-masked-language-model.json as plain json
# 2023-08-08 05:43:28,569 - INFO - allennlp.common.params - id = lm-masked-language-model
# 2023-08-08 05:43:28,571 - INFO - allennlp.common.params - type = lm-masked-language-model
# 2023-08-08 05:43:28,572 - INFO - allennlp.common.params - registered_model_name = masked_language_model
# 2023-08-08 05:43:28,573 - INFO - allennlp.common.params - type = masked_language_model
# 2023-08-08 05:43:28,575 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:43:28,576 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:43:28,578 - INFO - allennlp.common.params - display_name = BERT-based Masked Language Model
# 2023-08-08 05:43:28,579 - INFO - allennlp.common.params - type = BERT-based Masked Language Model
# 2023-08-08 05:43:28,582 - INFO - allennlp.common.params - task_id = masked-language-modeling
# 2023-08-08 05:43:28,584 - INFO - allennlp.common.params - type = masked-language-modeling
# 2023-08-08 05:43:28,587 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:28,589 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:28,592 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:43:28,594 - INFO - allennlp.common.params - model_usage.archive_file = bert-masked-lm-2020-10-07.tar.gz
# 2023-08-08 05:43:28,595 - INFO - allennlp.common.params - type = bert-masked-lm-2020-10-07.tar.gz
# 2023-08-08 05:43:28,604 - INFO - allennlp.common.params - model_usage.training_config = lm/bidirectional_language_model.jsonnet
# 2023-08-08 05:43:28,606 - INFO - allennlp.common.params - type = lm/bidirectional_language_model.jsonnet
# 2023-08-08 05:43:28,613 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:43:28,615 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:43:28,624 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:43:28,626 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,627 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,629 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:43:28,632 - INFO - allennlp.common.params - model_details.description = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-08-08 05:43:28,634 - INFO - allennlp.common.params - type = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-08-08 05:43:28,642 - INFO - allennlp.common.params - model_details.short_description = BERT-based masked language model
# 2023-08-08 05:43:28,644 - INFO - allennlp.common.params - type = BERT-based masked language model
# 2023-08-08 05:43:28,645 - INFO - allennlp.common.params - model_details.developed_by = Devlin et al
# 2023-08-08 05:43:28,646 - INFO - allennlp.common.params - type = Devlin et al
# 2023-08-08 05:43:28,648 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-08-08 05:43:28,650 - INFO - allennlp.common.params - model_details.date = 2020-10-07
# 2023-08-08 05:43:28,652 - INFO - allennlp.common.params - type = 2020-10-07
# 2023-08-08 05:43:28,653 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:43:28,654 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:43:28,656 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-08-08 05:43:28,657 - INFO - allennlp.common.params - type = BERT
# 2023-08-08 05:43:28,659 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:28,662 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:28,666 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:43:28,669 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Devlin2019BERTPO,
# title={BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding},
# author={J. Devlin and Ming-Wei Chang and Kenton Lee and Kristina Toutanova},
# booktitle={NAACL-HLT},
# year={2019}}
#
# 2023-08-08 05:43:28,671 - INFO - allennlp.common.params - model_details.paper.title = BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# ...
# 2023-08-08 05:44:38,278 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.bias
# 2023-08-08 05:44:38,279 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.weight
# 2023-08-08 05:44:38,280 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2023-08-08 05:44:38,281 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2023-08-08 05:44:38,282 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2023-08-08 05:44:38,285 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2023-08-08 05:44:38,288 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.bias
# 2023-08-08 05:44:38,290 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.weight
# 2023-08-08 05:44:38,292 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.bias
# 2023-08-08 05:44:38,294 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.weight
# 2023-08-08 05:44:38,295 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.bias
# 2023-08-08 05:44:38,296 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.weight
# 2023-08-08 05:44:38,298 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2023-08-08 05:44:38,299 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2023-08-08 05:44:38,301 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2023-08-08 05:44:38,303 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2023-08-08 05:44:38,305 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.bias
# 2023-08-08 05:44:38,307 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.weight
# 2023-08-08 05:44:38,309 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2023-08-08 05:44:38,310 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2023-08-08 05:44:38,312 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2023-08-08 05:44:38,314 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2023-08-08 05:44:38,316 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.bias
# 2023-08-08 05:44:38,317 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.weight
# 2023-08-08 05:44:38,319 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.bias
# 2023-08-08 05:44:38,321 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.weight
# 2023-08-08 05:44:38,324 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.bias
# 2023-08-08 05:44:38,326 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.weight
# 2023-08-08 05:44:38,331 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2023-08-08 05:44:38,333 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2023-08-08 05:44:38,336 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2023-08-08 05:44:38,339 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2023-08-08 05:44:38,341 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.bias
# 2023-08-08 05:44:38,342 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.weight
# 2023-08-08 05:44:38,343 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2023-08-08 05:44:38,344 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2023-08-08 05:44:38,346 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2023-08-08 05:44:38,349 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2023-08-08 05:44:38,351 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.bias
# 2023-08-08 05:44:38,354 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.weight
# 2023-08-08 05:44:38,355 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.bias
# 2023-08-08 05:44:38,357 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.weight
# 2023-08-08 05:44:38,358 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.bias
# 2023-08-08 05:44:38,360 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.weight
# 2023-08-08 05:44:38,362 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2023-08-08 05:44:38,363 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2023-08-08 05:44:38,365 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2023-08-08 05:44:38,367 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2023-08-08 05:44:38,370 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.bias
# 2023-08-08 05:44:38,371 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.weight
# 2023-08-08 05:44:38,373 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2023-08-08 05:44:38,375 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2023-08-08 05:44:38,377 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2023-08-08 05:44:38,378 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2023-08-08 05:44:38,379 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2023-08-08 05:44:38,381 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2023-08-08 05:44:38,385 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2023-08-08 05:44:38,387 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2023-08-08 05:44:38,389 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2023-08-08 05:44:38,390 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2023-08-08 05:44:38,392 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2023-08-08 05:44:38,393 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2023-08-08 05:44:38,395 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2023-08-08 05:44:38,397 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2023-08-08 05:44:38,400 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2023-08-08 05:44:38,402 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2023-08-08 05:44:38,404 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2023-08-08 05:44:38,405 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2023-08-08 05:44:38,408 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2023-08-08 05:44:38,410 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2023-08-08 05:44:38,412 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2023-08-08 05:44:38,414 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2023-08-08 05:44:38,416 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2023-08-08 05:44:38,418 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2023-08-08 05:44:38,420 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2023-08-08 05:44:38,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2023-08-08 05:44:38,424 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2023-08-08 05:44:38,427 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2023-08-08 05:44:38,429 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2023-08-08 05:44:38,432 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2023-08-08 05:44:38,435 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2023-08-08 05:44:38,441 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2023-08-08 05:44:38,443 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2023-08-08 05:44:38,445 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2023-08-08 05:44:38,458 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-08-08 05:44:38,459 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-08-08 05:44:39,595 - INFO - allennlp.models.archival - removing temporary unarchived model dir at C:\Users\sjsheikh\AppData\Local\Temp\tmprjvhb1_w

# %% [markdown]
# # Read text file and preprocess.

# %%
file_name = './Text/Simplified Medical Text.txt'
narrative = open(file_name, encoding="utf8").read()

print('Original Narrative:')
print(narrative)
print('\n')

narrative = predictor.coref_resolved(narrative)
narrative = narrative.lower()
narrative = textacy.preprocessing.normalize_quotation_marks(narrative)
narrative = normalize_hyphenated_words(narrative)
narrative = textacy.preprocessing.normalize_whitespace(narrative)
narrative = remove_punctuation(narrative, marks=';"":')

print('Narrarive after resolving coreferences:')
print(narrative)

print('\nSpacy Sentences:\n')
narrative = nlp(narrative)
for sent in narrative.sents:
    print(sent.text)
    print()

print('\nNLTK Sentences:\n')
raw_sentences = sent_tokenize(str(narrative))
for sent in raw_sentences:
    print(sent)
    print()
# Out:
# Original Narrative:
# Excessive overthinking leads to insomnia. Stress caused insomnia. Insomnia causes stress. Stress results in insomnia. Stress caused my insomnia. Overthinking can increase anxiety. Overthinking can cause insomnia. Stress is a reason of my insomnia. Stress results to insomnia.
#
#
# Narrarive after resolving coreferences:
# excessive overthinking leads to insomnia. stress caused insomnia. insomnia causes stress. stress results in insomnia. stress caused insomnia. overthinking can increase anxiety. overthinking can cause insomnia. stress is a reason of my's . stress results to insomnia.
#
# Spacy Sentences:
#
# excessive overthinking leads to insomnia.
#
# stress caused insomnia.
#
# insomnia causes stress.
#
# stress results in insomnia.
#
# stress caused insomnia.
#
# overthinking can increase anxiety.
#
# overthinking can cause insomnia.
#
# stress is a reason of my's .
#
# stress results to insomnia.
#
#
# NLTK Sentences:
#
# excessive overthinking leads to insomnia.
#
# stress caused insomnia.
#
# insomnia causes stress.
#
# stress results in insomnia.
#
# stress caused insomnia.
#
# overthinking can increase anxiety.
#
# overthinking can cause insomnia.
#
# stress is a reason of my's .
#
# stress results to insomnia.

# %% [markdown]
# # Extract the Subject-Verb-Object triples.

# %%
#new
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
sub = ''
obj = ''
#tuple =('a','b','c')

#print(tuple[0])

for sent in raw_sentences:
    sent = nlp(sent)
    print("Sentence:")
    print(sent)
    
    print("Noun Chunks:")
    for nc in sent.noun_chunks:
        print (nc)
        ncl.append(nc)
    print ("Number of noun chunks: ", len(ncl))
    
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            print("Triples other than textacy:")
            print(nncl[0])
            print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],triplets[0][1],ncl[1])]
#            print("Triples other than textacy:")
#            print(nncl[0])
#            finalList.append(nncl[0])
    else:
        print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                sub = token
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
                #tuple[1] = token.text
            #elif token.dep_ == 'dobj':
            #    obj = token.text
                #tuple[2] = token.text
            #    break
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue
                
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        print("Triple by combining nsubj, root and dobj:")
        print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],verb,ncl[1])]
#            print("Triples other than sub, verb and obj:")
#            print(nncl[0])
#            finalList.append(nncl[0])

    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
    
trips = finalList

#        for token in nc:
#            print(token.text, token.dep_)
# Out:
# Sentence:
# excessive overthinking leads to insomnia.
# Noun Chunks:
# excessive overthinking leads
# insomnia
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking leads, leads, insomnia)
# Sentence:
# stress caused insomnia.
# Noun Chunks:
# stress
# insomnia
# Number of noun chunks:  2
# Triples from textacy:
# (stress, caused, insomnia)
# Sentence:
# insomnia causes stress.
# Noun Chunks:
# insomnia
# stress
# Number of noun chunks:  2
# Triples from textacy:
# (insomnia, causes, stress)
# Sentence:
# stress results in insomnia.
# Noun Chunks:
# stress results
# insomnia
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking leads, results, insomnia)
# Sentence:
# stress caused insomnia.
# Noun Chunks:
# stress
# insomnia
# Number of noun chunks:  2
# Triples from textacy:
# (stress, caused, insomnia)
# Sentence:
# overthinking can increase anxiety.
# Noun Chunks:
# anxiety
# Number of noun chunks:  1
# Triples from textacy:
# (overthinking, can increase, anxiety)
# Sentence:
# overthinking can cause insomnia.
# Noun Chunks:
# insomnia
# Number of noun chunks:  1
# Triples from textacy:
# (overthinking, can cause, insomnia)
# Sentence:
# stress is a reason of my's .
# Noun Chunks:
# stress
# a reason
# Number of noun chunks:  2
# Triples from textacy:
# (stress, is, a reason)
# Sentence:
# stress results to insomnia.
# Noun Chunks:
# stress results
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking leads, results, insomnia)

# %% [markdown]
# # Remove Duplicates from Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("Length of triples' List before removing duplicates:")
print(len(trips))

Triples = []
sentences1 = []

for sentence,ce in zip(sentences, trips):
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        sentences1.append(sentence)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            sentences1.append(sentence)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

for t in Triples:
    print(t)
# Out:
# Length of triples' List before removing duplicates:
# 52
#
# List after removing duplicates:
# 38
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (land rights disagreements, are, conflict)
# (land rights disagreements, are, a major source)
# (conflict, discourages, production)
# (conflict, discourages, farmers)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (south sudan's limited road network, maintained, roads)
# (south sudan's limited road network, repaired, roads)
# (the rainy season, washed, roads)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (moderate, is expected, to continue)
# (expected, is expected, to continue)
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, uganda)
# (heavy rainfall, is expected, northern kenya)
# (heavy rainfall, is expected, western/northern ethiopia)
# (persistent heavy rains, highlands, flood prone areas)
# (persistent heavy rains, cause, flooding)
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, cause, flood-prone areas)
# (persistent heavy rains, rains, flood-prone areas)
# (persistent heavy rains, rains, south sudan's cause)
# (highly saturated soils, cause, flood-prone areas)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (highly saturated soils, impact, the war-torn nation)
# (floods devastatingly impact, impact, food security)
# (floods devastatingly impact, impact, the war-torn nation)

# %% [markdown]
# # Filter correct triples from extracted triples

# %%
correctTriples = []
sentences2 = []

for sentence,line in zip(sentences1, Triples):
    taggedWords = []
    taggedWords1 = []
    check0 = False
    check2 = False
    print(line)
    taggedWords = pos_tag(word_tokenize(str(line[0])))
    taggedWords1 = pos_tag(word_tokenize(str(line[2])))
    print(taggedWords)
    print(taggedWords1)
    for i in range(len(taggedWords)):
        if taggedWords[i][1] == 'NN' or taggedWords[i][1] == 'NNS':
            check0 = True
    for i in range(len(taggedWords1)):
        if taggedWords1[i][1] == 'NN' or taggedWords1[i][1] == 'NNS':
            check2 = True
    print(check0)  
    print(check2)
    if check0 == True and check2 == True:
        correctTriples.append(line)
        sentences2.append(sentence)
    print("**************************************************************************")
    
for correctTriple in correctTriples:
    print(correctTriple)
# Out:
# (institutional weakness, hindered, development)
# [('institutional', 'JJ'), ('weakness', 'NN')]
# [('development', 'NN')]
# True
# True
# **************************************************************************
# (institutional weakness, hindered, the agriculture sector)
# [('institutional', 'JJ'), ('weakness', 'NN')]
# [('the', 'DT'), ('agriculture', 'NN'), ('sector', 'NN')]
# True
# True
# **************************************************************************
# (land rights disagreements, are, conflict)
# [('land', 'NN'), ('rights', 'NNS'), ('disagreements', 'NNS')]
# [('conflict', 'NN')]
# True
# True
# **************************************************************************
# (land rights disagreements, are, a major source)
# [('land', 'NN'), ('rights', 'NNS'), ('disagreements', 'NNS')]
# [('a', 'DT'), ('major', 'JJ'), ('source', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, production)
# [('conflict', 'NN')]
# [('production', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, farmers)
# [('conflict', 'NN')]
# [('farmers', 'NNS')]
# True
# True
# **************************************************************************
# (conflict, discourages, traders)
# [('conflict', 'NN')]
# [('traders', 'NNS')]
# True
# True
# **************************************************************************
# (conflict, discourages, marketing infrastructure)
# [('conflict', 'NN')]
# [('marketing', 'NN'), ('infrastructure', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, retailers)
# [('conflict', 'NN')]
# [('retailers', 'NNS')]
# True
# True
# **************************************************************************
# (no irrigation infrastructure, shows, public investment)
# [('no', 'DT'), ('irrigation', 'NN'), ('infrastructure', 'NN')]
# [('public', 'JJ'), ('investment', 'NN')]
# True
# True
# **************************************************************************
# (the low level, shows, public investment)
# [('the', 'DT'), ('low', 'JJ'), ('level', 'NN')]
# [('public', 'JJ'), ('investment', 'NN')]
# True
# True
# **************************************************************************
# (the low level, shows, no irrigation infrastructure)
# [('the', 'DT'), ('low', 'JJ'), ('level', 'NN')]
# [('no', 'DT'), ('irrigation', 'NN'), ('infrastructure', 'NN')]
# True
# True
# **************************************************************************
# (south sudan's limited road network, shows, only 2 percent)
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('limited', 'JJ'), ('road', 'NN'), ('network', 'NN')]
# [('only', 'RB'), ('2', 'CD'), ('percent', 'NN')]
# True
# True
# **************************************************************************
# (south sudan's limited road network, maintained, roads)
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('limited', 'JJ'), ('road', 'NN'), ('network', 'NN')]
# [('roads', 'NNS')]
# True
# True
# **************************************************************************
# (south sudan's limited road network, repaired, roads)
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('limited', 'JJ'), ('road', 'NN'), ('network', 'NN')]
# [('roads', 'NNS')]
# True
# True
# **************************************************************************
# (the rainy season, washed, roads)
# [('the', 'DT'), ('rainy', 'NN'), ('season', 'NN')]
# [('roads', 'NNS')]
# True
# True
# **************************************************************************
# (inadequate transportation infrastructure, resulted, markets)
# [('inadequate', 'JJ'), ('transportation', 'NN'), ('infrastructure', 'NN')]
# [('markets', 'NNS')]
# True
# True
# **************************************************************************
# (inadequate transportation infrastructure, resulted, less transport)
# [('inadequate', 'JJ'), ('transportation', 'NN'), ('infrastructure', 'NN')]
# [('less', 'RBR'), ('transport', 'NN')]
# True
# True
# **************************************************************************
# (moderate, is expected, to continue)
# [('moderate', 'NN')]
# [('to', 'TO'), ('continue', 'VB')]
# True
# False
# **************************************************************************
# (expected, is expected, to continue)
# [('expected', 'VBN')]
# [('to', 'TO'), ('continue', 'VB')]
# False
# False
# **************************************************************************
# (heavy rainfall, is expected, the next two weeks)
# [('heavy', 'JJ'), ('rainfall', 'NN')]
# [('the', 'DT'), ('next', 'JJ'), ('two', 'CD'), ('weeks', 'NNS')]
# True
# True
# **************************************************************************
# (heavy rainfall, is expected, uganda)
# [('heavy', 'JJ'), ('rainfall', 'NN')]
# [('uganda', 'NN')]
# True
# True
# **************************************************************************
# (heavy rainfall, is expected, northern kenya)
# [('heavy', 'JJ'), ('rainfall', 'NN')]
# [('northern', 'JJ'), ('kenya', 'NN')]
# True
# True
# **************************************************************************
# (heavy rainfall, is expected, western/northern ethiopia)
# [('heavy', 'JJ'), ('rainfall', 'NN')]
# [('western/northern', 'JJ'), ('ethiopia', 'NN')]
# True
# True
# **************************************************************************
# (persistent heavy rains, highlands, flood prone areas)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flood', 'NN'), ('prone', 'NN'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (persistent heavy rains, cause, flooding)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flooding', 'VBG')]
# True
# False
# **************************************************************************
# (persistent heavy rains, cause, the eastern sudan)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('the', 'DT'), ('eastern', 'JJ'), ('sudan', 'NN')]
# True
# True
# **************************************************************************
# (persistent heavy rains, cause, flood-prone areas)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flood-prone', 'JJ'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (persistent heavy rains, rains, flood-prone areas)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flood-prone', 'JJ'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (persistent heavy rains, rains, south sudan's cause)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('cause', 'NN')]
# True
# True
# **************************************************************************
# (highly saturated soils, cause, flood-prone areas)
# [('highly', 'RB'), ('saturated', 'VBN'), ('soils', 'NNS')]
# [('flood-prone', 'JJ'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (rain, caused, floods)
# [('rain', 'NN')]
# [('floods', 'NNS')]
# True
# True
# **************************************************************************
# (floods, have displaced, more than 100,000 people)
# [('floods', 'NNS')]
# [('more', 'JJR'), ('than', 'IN'), ('100,000', 'CD'), ('people', 'NNS')]
# True
# True
# **************************************************************************
# (floods, have displaced, south sudan)
# [('floods', 'NNS')]
# [('south', 'JJ'), ('sudan', 'NN')]
# True
# True
# **************************************************************************
# (floods, raise, fears)
# [('floods', 'NNS')]
# [('fears', 'NNS')]
# True
# True
# **************************************************************************
# (highly saturated soils, impact, the war-torn nation)
# [('highly', 'RB'), ('saturated', 'VBN'), ('soils', 'NNS')]
# [('the', 'DT'), ('war-torn', 'JJ'), ('nation', 'NN')]
# True
# True
# **************************************************************************
# (floods devastatingly impact, impact, food security)
# [('floods', 'NNS'), ('devastatingly', 'RB'), ('impact', 'VBP')]
# [('food', 'NN'), ('security', 'NN')]
# True
# True
# **************************************************************************
# (floods devastatingly impact, impact, the war-torn nation)
# [('floods', 'NNS'), ('devastatingly', 'RB'), ('impact', 'VBP')]
# [('the', 'DT'), ('war-torn', 'JJ'), ('nation', 'NN')]
# True
# True
# **************************************************************************
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (land rights disagreements, are, conflict)
# (land rights disagreements, are, a major source)
# (conflict, discourages, production)
# (conflict, discourages, farmers)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (south sudan's limited road network, maintained, roads)
# (south sudan's limited road network, repaired, roads)
# (the rainy season, washed, roads)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, uganda)
# (heavy rainfall, is expected, northern kenya)
# (heavy rainfall, is expected, western/northern ethiopia)
# (persistent heavy rains, highlands, flood prone areas)
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, cause, flood-prone areas)
# (persistent heavy rains, rains, flood-prone areas)
# (persistent heavy rains, rains, south sudan's cause)
# (highly saturated soils, cause, flood-prone areas)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (highly saturated soils, impact, the war-torn nation)
# (floods devastatingly impact, impact, food security)
# (floods devastatingly impact, impact, the war-torn nation)

# %% [markdown]
# # Print the extracted triples with sentences.

# %%
for sentence, triple  in zip(sentences2, correctTriples):
    print(sentence, triple)
    print()
# Out:
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
#
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector)
#
# land rights disagreements are a major source of conflict. (land rights disagreements, are, conflict)
#
# land rights disagreements are a major source of conflict. (land rights disagreements, are, a major source)
#
# conflict discourages farmers from expanding production. (conflict, discourages, production)
#
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
#
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
#
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment)
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment)
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure)
#
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent)
#
# roads are poorly maintained. (south sudan's limited road network, maintained, roads)
#
# roads are not repaired. (south sudan's limited road network, repaired, roads)
#
# roads are completely washed out during the rainy season. (the rainy season, washed, roads)
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport)
#
# moderate to heavy rainfall is expected to continue during the next two weeks across uganda. (heavy rainfall, is expected, the next two weeks)
#
# moderate to heavy rainfall is expected to continue during the next two weeks across uganda. (heavy rainfall, is expected, uganda)
#
# moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya. (heavy rainfall, is expected, northern kenya)
#
# moderate to heavy rainfall is expected to continue during the next two weeks across western/northern ethiopia. (heavy rainfall, is expected, western/northern ethiopia)
#
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, highlands, flood prone areas)
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, the eastern sudan)
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
#
# persistent heavy rains in south sudan's cause flooding in flood-prone areas. (persistent heavy rains, rains, flood-prone areas)
#
# persistent heavy rains in south sudan's cause flooding in flood-prone areas. (persistent heavy rains, rains, south sudan's cause)
#
# highly saturated soils cause flooding in flood-prone areas. (highly saturated soils, cause, flood-prone areas)
#
# rain caused floods. (rain, caused, floods)
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, more than 100,000 people)
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, south sudan)
#
# floods raise fears. (floods, raise, fears)
#
# floods devastatingly impact on food security in the war-torn nation. (highly saturated soils, impact, the war-torn nation)
#
# floods devastatingly impact on food security in the war-torn nation. (floods devastatingly impact, impact, food security)
#
# floods devastatingly impact on food security in the war-torn nation. (floods devastatingly impact, impact, the war-torn nation)

# %% [markdown]
# # Plot the knowledge Graph.

# %%
cmap = nx.DiGraph()

for triple in correctTriples:
    s = str(triple[0])    
    d = str(triple[2])
    cmap.add_edge(s, d, predicate=triple[1])
    #print(triple)

print("Nodes:",len(cmap.nodes))
print("Edges:",len(cmap.edges))
for e in cmap.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cmap, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cmap, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cmap.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cmap,'predicate')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 40
# Edges: 33
# institutional weakness , {'predicate': hindered} , development
# institutional weakness , {'predicate': hindered} , the agriculture sector
# land rights disagreements , {'predicate': are} , conflict
# land rights disagreements , {'predicate': are} , a major source
# conflict , {'predicate': discourages} , production
# conflict , {'predicate': discourages} , farmers
# conflict , {'predicate': discourages} , traders
# conflict , {'predicate': discourages} , marketing infrastructure
# conflict , {'predicate': discourages} , retailers
# no irrigation infrastructure , {'predicate': shows} , public investment
# the low level , {'predicate': shows} , public investment
# the low level , {'predicate': shows} , no irrigation infrastructure
# south sudan's limited road network , {'predicate': shows} , only 2 percent
# south sudan's limited road network , {'predicate': repaired} , roads
# the rainy season , {'predicate': washed} , roads
# inadequate transportation infrastructure , {'predicate': resulted} , markets
# inadequate transportation infrastructure , {'predicate': resulted} , less transport
# heavy rainfall , {'predicate': is expected} , the next two weeks
# heavy rainfall , {'predicate': is expected} , uganda
# heavy rainfall , {'predicate': is expected} , northern kenya
# heavy rainfall , {'predicate': is expected} , western/northern ethiopia
# persistent heavy rains , {'predicate': highlands} , flood prone areas
# persistent heavy rains , {'predicate': cause} , the eastern sudan
# persistent heavy rains , {'predicate': rains} , flood-prone areas
# persistent heavy rains , {'predicate': rains} , south sudan's cause
# highly saturated soils , {'predicate': cause} , flood-prone areas
# highly saturated soils , {'predicate': impact} , the war-torn nation
# rain , {'predicate': caused} , floods
# floods , {'predicate': have displaced} , more than 100,000 people
# floods , {'predicate': have displaced} , south sudan
# floods , {'predicate': raise} , fears
# floods devastatingly impact , {'predicate': impact} , food security
# floods devastatingly impact , {'predicate': impact} , the war-torn nation

# %% [markdown]
# # Dump the Knowledge Graph on "Knowledge Graph.json"

# %%
knowledgeGraph = nx.DiGraph()

for svo in correctTriples:
    s = str(svo[0])    
    d = str(svo[2])
    knowledgeGraph.add_node(s,id = str(s),title=str(s),x=615,y=200)
    knowledgeGraph.add_node(d,id = str(d),title=str(d),x=615,y=200)
    knowledgeGraph.add_edge(s, d, predicade=str(svo[1]))

#print(len(knowledgeGraph.nodes))
#print(len(knowledgeGraph.edges))

data = json_graph.node_link_data(knowledgeGraph)


out_file = open("./Json Graphs/Knowledge Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Create Causal Trigger Words Dictionary along with their synonyms.

# %%
#new

causalWords1 = ["forced","caused", "resulted", "reason", "as a result of", "as a consequence of", 
               "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
               ,"made","minimize","maximize","hindered", "displaced", "conspired","led to","activate","impel","inspire",
                "excite","quicken","rouse","stimulate","influence","determine","likely","probable","disconnected","separated"
                ,"excluded","after","as","since","trigger","oppose","fight","provides","strengthened","launched","develop"
               ,"guarantees","declared", "developed","produced","discourages","demotivated","encouraged","motivated"]

#causalWords1 = ["develop"]
synonyms1 = []
lemma_function = WordNetLemmatizer()

for cw1 in causalWords1:
    #print(cw1)
    synonyms1.append(cw1.lower())
    tokens1 = word_tokenize(cw1)
    for token1, tag1 in pos_tag(tokens1):
        lemma1 = lemma_function.lemmatize(token1)
        #print(token1,lemma1)
        
        for syn in wordnet.synsets(str(lemma1)):
            
            for l1 in syn.lemmas():
                #print(l1)
                #synonyms1.append(lemma1.lower())
                synonyms1.append(l1.name().lower())
                #print(l1)
                for syn1 in wordnet.synsets(str(l1.name())):
                    for l2 in syn1.lemmas():
                        #print(l2)
                        synonyms1.append(l2.name().lower())
            

#remove duplicates from synonyms1
synonyms = []
     
for synonym in synonyms1:
    if synonym not in synonyms:
        synonyms.append(synonym)
    
#for x in synonyms:
#    print (synonym)

print(len(synonyms))
# Out:
# 3226

# %% [markdown]
# # Writing causal trigger words dictionary to text file (dictionary.txt)

# %%
#synonyms
output_file = open('.\dictionary.txt', 'w')

for syn in synonyms:
    #print(syn)
    output_file.write(syn + '\n')

output_file.close()

# %% [markdown]
# # Reading causal trigger words dictionary from text file (dictionary.txt) to list

# %%
synonyms = []

my_file = open(".\dictionary.txt", "r")
  
data = my_file.read()
  
synonyms = data.split("\n")
#print(data_into_list)
my_file.close()

print(len(synonyms))
# Out:
# 3227

# %% [raw]
# #old
#
# causalWords = ["forced","caused", "result", "reason", "as a result of", "as a consequence of",
#                "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
#                ,"made","mimimize","maximize","led to","produced"]
#
# #causalWords = ["as a result of"]
# synonyms = []
#
# for cw in causalWords:
#
#     for syn in wordnet.synsets(str(cw)):
#         for l in syn.lemmas():
#             synonyms.append(cw)
#             synonyms.append(l.name())
#
# print(set(synonyms))
# print(len(synonyms))

# %% [markdown]
# # Filter Causal triples along with their causal sentences from SVO triples based upon causal trigger words dictionary.

# %%
causeffect = [] #without duplicates
causalSentences = [] #with duplicates
#lem = []
#lemma_function = WordNetLemmatizer()
for s,st in zip(sentences2,correctTriples):
    check = False
    #st = (str(st[0]),str(st[1]),str(st[2]))
    #synonym = synonym[0]
    tokens = word_tokenize(str(st[1]))
    for token, tag in pos_tag(tokens):
        lemma = lemma_function.lemmatize(token)
        #print(token,lemma)
        #st[1] = lemma
        #lem.append(lemma)
        
    for synonym in synonyms:
        if synonym == lemma:
            #causeffect = [(st[0],st[1],st[2])]
            #strTriples.append((ncl[0],token.text,st[2]))
           # print(st)
            if len(causeffect) == 0:
                causeffect.append(st)
                causalSentences.append(s)
            else:
                for ct in causeffect:
                    if str(st[0]) == str(ct[0]) and str(st[1]) == str(ct[1]) and str(st[2]) == str(ct[2]):
                        check = True
                        break;
                if check == False:
                    causeffect.append(st)
                    causalSentences.append(s)
            #if (len(causeffect) >0 ) and (st in causeffect == False):
                
            #    causeffect.append(st)
            break
    
#causeffect.sort(key = lambda x: x[0])

#for sortedTriple in causeffect:
#    print(sortedTriple)
print(len(causalSentences))
print(len(causeffect))
for causalSentence, causalTriple  in zip(causalSentences, causeffect):
    print(causalSentence, causalTriple)
# Out:
# 23
# 23
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector)
# conflict discourages farmers from expanding production. (conflict, discourages, production)
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure)
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport)
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, the eastern sudan)
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
# highly saturated soils cause flooding in flood-prone areas. (highly saturated soils, cause, flood-prone areas)
# rain caused floods. (rain, caused, floods)
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, more than 100,000 people)
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, south sudan)
# floods raise fears. (floods, raise, fears)
# floods devastatingly impact on food security in the war-torn nation. (highly saturated soils, impact, the war-torn nation)
# floods devastatingly impact on food security in the war-torn nation. (floods devastatingly impact, impact, food security)
# floods devastatingly impact on food security in the war-torn nation. (floods devastatingly impact, impact, the war-torn nation)

# %% [markdown]
# # Plot the Causal Graph.

# %%
#new (DAG Implementation)
#without duplicates
dagCauseTriples = []
cg = nx.DiGraph()

for ce in causeffect:
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
    dagCauseTriples.append(ce)
    if nx.is_directed_acyclic_graph(cg) is False:
        cg.remove_edge(s, d)
        dagCauseTriples.remove(ce)
        

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 29
# Edges: 23
# institutional weakness , {'predicade': 'hindered'} , development
# institutional weakness , {'predicade': 'hindered'} , the agriculture sector
# conflict , {'predicade': 'discourages'} , production
# conflict , {'predicade': 'discourages'} , farmers
# conflict , {'predicade': 'discourages'} , traders
# conflict , {'predicade': 'discourages'} , marketing infrastructure
# conflict , {'predicade': 'discourages'} , retailers
# no irrigation infrastructure , {'predicade': 'shows'} , public investment
# the low level , {'predicade': 'shows'} , public investment
# the low level , {'predicade': 'shows'} , no irrigation infrastructure
# south sudan's limited road network , {'predicade': 'shows'} , only 2 percent
# inadequate transportation infrastructure , {'predicade': 'resulted'} , markets
# inadequate transportation infrastructure , {'predicade': 'resulted'} , less transport
# persistent heavy rains , {'predicade': 'cause'} , the eastern sudan
# persistent heavy rains , {'predicade': 'cause'} , flood-prone areas
# highly saturated soils , {'predicade': 'cause'} , flood-prone areas
# highly saturated soils , {'predicade': 'impact'} , the war-torn nation
# rain , {'predicade': 'caused'} , floods
# floods , {'predicade': 'have displaced'} , more than 100,000 people
# floods , {'predicade': 'have displaced'} , south sudan
# floods , {'predicade': 'raise'} , fears
# floods devastatingly impact , {'predicade': 'impact'} , food security
# floods devastatingly impact , {'predicade': 'impact'} , the war-torn nation

# %% [markdown]
# # Plot the Causal Graph on using Pyvis "Causal Graph.html" file

# %%
nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')

for dm in dagCauseTriples:
    #color = "#ffffff"
    nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_node(str(dm[2]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_edge(str(dm[0]),str(dm[2]),label=str(dm[1]), weight=10, physics='false',color='black')

#nt.show_buttons(filter_=['physics'])
nt.set_edge_smooth('discrete')
nt.show("./Pyvis Graph/Causal Graph.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_944\2767877602.py in <module>
# ----> 1 nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')
#       2
#       3 for dm in dagCauseTriples:
#       4     #color = "#ffffff"
#       5     nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
#
# NameError: name 'Network' is not defined

# %% [raw]
# nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')
#
# nt.add_node(1, label="Subject (cause)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_node(2, label="Object (effect)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_edge(1,2,label="Verb (cause-effect)", weight=10, physics='false',color='black')
#
#
# nt.show("./Pyvis Graph/Causal Graph.html")

# %% [markdown]
# # Dump the Causal Graph on "Causal Graph.json" file

# %%
data = json_graph.node_link_data(cg)


out_file = open("./Json Graphs/Causal Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Remove Duplicates from Causal Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("List before removing duplicates:")
print(len(causeffect))

for t in causeffect:
    print(t)
    
causalTriples = []

for ce in causeffect:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalTriples) == 0:
        #print("HEY!")
        causalTriples.append(ce)
        #print("added!")
    else:
        for ct in causalTriples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalTriples.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalTriples))

for t in causalTriples:
    print(t)
# Out:
# List before removing duplicates:
# 12
# (zulfikar ali bhutto, launched, nuclear program)
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# (aq khan, developed, nuclear bomb)
# (nuclear bomb, strengthened, pakistan)
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, provides, vigilance)
# (vigilance, strengthened, national survival)
#
# List after removing duplicates:
# 12
# (zulfikar ali bhutto, launched, nuclear program)
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# (aq khan, developed, nuclear bomb)
# (nuclear bomb, strengthened, pakistan)
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, provides, vigilance)
# (vigilance, strengthened, national survival)

# %% [markdown]
# # Remove Duplicates from causalSentences

# %%
#causalSentences = list(dict.fromkeys(causalSentences))
#causalSentences = list(set(causalSentences))
print("List before removing duplicates:")
print(len(causalSentences))

for t in causalSentences:
    print(t)
    
causalSentencesNoDup = []

for ce in causalSentences:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalSentencesNoDup) == 0:
        #print("HEY!")
        causalSentencesNoDup.append(ce)
        #print("added!")
    else:
        for ct in causalSentencesNoDup:
            #print("ct:")
            #print(ct)
            if str(ce) == str(ct):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalSentencesNoDup.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalSentencesNoDup))

for t in causalSentencesNoDup:
    print(t)
# Out:
# List before removing duplicates:
# 12
# zulfikar ali bhutto launched nuclear program.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# aq khan developed nuclear bomb.
# nuclear bomb strengthened pakistan.
# nuclear bomb makes nuclear power.
# pakistan must never surrender nuclear bomb.
# pakistan must fight off existential threats.
# pakistan must support army and aq khan.
# pakistan must support army and aq khan.
# army provides vigilance.
# vigilance strengthened national survival.
#
# List after removing duplicates:
# 10
# zulfikar ali bhutto launched nuclear program.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# aq khan developed nuclear bomb.
# nuclear bomb strengthened pakistan.
# nuclear bomb makes nuclear power.
# pakistan must never surrender nuclear bomb.
# pakistan must fight off existential threats.
# pakistan must support army and aq khan.
# army provides vigilance.
# vigilance strengthened national survival.

# %% [markdown]
# # Causal Triples' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
allen = []
for sent in causalTriples:
    #print(sent)
    preds = predictor1.predict(str(sent))
    #print(preds['label'][0])
    label = preds['label'][0]
    if label is '0':
        allen.append(-1)
    else:
        allen.append(1)
    
for causalSentence, polarity  in zip(causalTriples, allen):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) -1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) 1
# (pakistan, must never surrender, nuclear bomb) 1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 1
# (vigilance, strengthened, national survival) 1

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)

afinn = []
for sent in causalTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    #print(score)
    if score > 0:
        #print('positive')
        afinn.append(1)
    elif score < 0:
        #print('negative')
        afinn.append(-1)
    else:
        #print('neutral')
        afinn.append(0)
        
for causalSentence, polarity  in zip(causalTriples, afinn):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) 1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) -1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 0
# (vigilance, strengthened, national survival) 1

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    if compound >= 0.05:
        vader.append(1)
        return 'Positive'
    elif compound <= -0.05 :
        vader.append(-1)
        return 'Negative'
        
    elif  compound > -0.05 and compound < 0.05:
        vader.append(0)
        return 'Neutral'
    
for sent in causalTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    vader_analysis(compound)
    
for causalSentence, polarity  in zip(causalTriples, vader):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 0
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) 1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 0
# (vigilance, strengthened, national survival) 1

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

#senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
#senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')


sentiStrength = []

for sent in causalTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='binary')
    #print(result)
    
    if result[0]==1:
        #print('Positive')
        sentiStrength.append(1)
    elif result[0]==-1:
        sentiStrength.append(-1)
        #print('Negative')
    #else:
    #    print('Neutral')

for causalSentence, polarity  in zip(causalTriples, sentiStrength):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) -1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 1
# (vigilance, strengthened, national survival) 1

# %% [markdown]
# ### Data Frame (Causal Triples Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style

# %% [markdown]
# # Causal Sentences' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
def Allen_sents_SentLevel(causalSentences):
    allen = []
    for sent in causalSentences:
        #print(sent)
        preds = predictor1.predict(str(sent))
        #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen.append(-1)
        else:
            allen.append(1)
    return allen

#for causalSentence, polarity  in zip(causalSentences, allen):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)
def Afinn_sents_SentLevel(causalSentences):
    afinn = []
    for sent in causalSentences:
        #print(sent)
        score = afn.score(str(sent))
        #print(score)
        if score > 0:
            #print('positive')
            afinn.append(1)
        elif score < 0:
            #print('negative')
            afinn.append(-1)
        else:
            #print('neutral')
            afinn.append(0)
    return afinn

#for causalSentence, polarity  in zip(causalSentences, afinn):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    #vader = []
    if compound >= 0.05:
        #vader.append(1)
        return 1
    elif compound <= -0.05 :
        #vader.append(-1)
        return -1
        
    elif  compound > -0.05 and compound < 0.05:
        #vader.append(0)
        return 0
    #return vader
    
def Vader_sents_SentLevel(causalSentences):
    vader = []
    for sent in causalSentences:
        #print(sent)
        #vaderTup = []
        compound = vadersentimentanalysis(str(sent))
        res = vader_analysis(compound)
        #vaderTup.append(res)
        vader.append(res)
    return vader

#vader = Vader_sents_SentLevel(causalSents)
#vader
#for causalSentence, polarity  in zip(causalSentences, vader):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

def Senti_sents_SentLevel(causalSentences):
    sentiStrength = []
    for sent in causalSentences:
        #print(sent)
        result = senti.getSentiment(str(sent), score='binary')
        #print(result)
    
        if result[0]==1:
            #print('Positive')
            sentiStrength.append(1)
        elif result[0]==-1:
            sentiStrength.append(-1)
            #print('Negative')
        #else:
        #    print('Neutral')
    return sentiStrength

#for causalSentence, polarity  in zip(causalSentences, sentiStrength):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiWordnet]

# %% [raw]
# def penn_to_wn(tag):
#     if tag.startswith('J'):
#         return wn.ADJ
#     elif tag.startswith('N'):
#         return wn.NOUN
#     elif tag.startswith('R'):
#         return wn.ADV
#     elif tag.startswith('V'):
#         return wn.VERB
#     return None
#
# def sentiment_sentiwordnet(text):
#     #text = text.decode("utf-8")
#     raw_sentences = sent_tokenize(text)
#     #print(raw_sentences)
#     sentiment = 0
#     tokens_count = 0
#
#     for raw_sentence in raw_sentences:
#         print(raw_sentence)
#         tagged_sentence = pos_tag(word_tokenize(raw_sentence))
#         print(tagged_sentence)
#
#         for word, tag in tagged_sentence:
#             wn_tag = penn_to_wn(tag)
#             if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
#                 continue
#
#             #lemma = lemmatizer.lemmatize(word, pos=wn_tag)
#             #if not lemma:
#             #    continue
#
#             synsets = wn.synsets(word, pos=wn_tag)
#             if not synsets:
#                 continue
#
#             synset = synsets[0]
#             swn_synset = swn.senti_synset(synset.name())
#             sentiment += swn_synset.pos_score() - swn_synset.neg_score()
#             tokens_count += 1
#         # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
#         if not tokens_count:
#             return 0
#         if sentiment>0:
#             #return "Positive"
#             print("Positive")
#         elif sentiment==0:
#             #return "Neutral"
#             print("Neutral")
#         else:
#             #return "Negative"
#             print("Negative")
#
# causalNarrative = ""
# for cS in causalSentences:
#     causalNarrative = causalNarrative+str(cS)+" "
#
# causalNarrative = nlp(causalNarrative)
# #raw_sentences = sent_tokenize(causalNarrative)
# #print(str(causalNarrative)+"\n")
# #print(raw_sentences)
# #print(str(narrative))
#
# sentiment_sentiwordnet(str(narrative))

# %% [markdown]
# ### [SentiWordNet OnlyVerbs]

# %% [raw]
# from nltk.corpus import wordnet as wn
# from nltk.corpus import sentiwordnet as swn
# from nltk.tag import pos_tag
# import nltk
#
#
# polarizedCauseffect = []
# for ce in causeffect:
#     print(ce[1])
#     token = nltk.word_tokenize(str(ce[1]))
#     after_tagging = nltk.pos_tag(token)
#     print(after_tagging)
#     print(len(after_tagging))
#     for tag in after_tagging:
#         if tag[1].startswith('V') or len(after_tagging)==1:
#             words = swn.senti_synsets(tag[0])
#             answer = list(words)[0]
#             if (answer.pos_score() > answer.neg_score()):
#                 mce = str(ce[1])+"(+ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             elif (answer.pos_score() > 0):
#                 mce = str(ce[1])+"(-ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             else:
#                 mce = str(ce[1])+"(neutral)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#
# polarizedCauseffect

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) without duplicates

# %%
causalSents = causalSentencesNoDup
print(len(causalSents))
# Out:
# 11

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) with duplicates

# %% [raw]
# causalSents = causalSentences
# print(len(causalSents))

# %% [markdown]
# ### Data Frame (Causal Sentence at Sentence Level)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

allen = Allen_sents_SentLevel(causalSents)
afinn = Afinn_sents_SentLevel(causalSents)
vader = Vader_sents_SentLevel(causalSents)
sentiStrength = Senti_sents_SentLevel(causalSents)

df2 = pd.DataFrame(list(zip(causalSents, allen, afinn, vader,sentiStrength)), columns =['Causal Sentence', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)


sentPolarity = []
sentsWeight_sentLevel = []

for index, row in df2.iterrows():
    sentWeightTuple = []
    weight = row['Weight']
    sentWeightTuple.append(weight)
    sentsWeight_sentLevel.append(sentWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# <style  type="text/css" >
# </style><table id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >AllenNLP</th>        <th class="col_heading level0 col2" >Afinn</th>        <th class="col_heading level0 col3" >Vader</th>        <th class="col_heading level0 col4" >SentiStrength</th>        <th class="col_heading level0 col5" >Weight</th>        <th class="col_heading level0 col6" >Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col1" class="data row0 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col2" class="data row0 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col3" class="data row0 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col4" class="data row0 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col5" class="data row0 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col6" class="data row0 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col1" class="data row1 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col2" class="data row1 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col4" class="data row1 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col5" class="data row1 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col6" class="data row1 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col1" class="data row2 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col2" class="data row2 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col3" class="data row2 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col4" class="data row2 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col5" class="data row2 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col6" class="data row2 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col1" class="data row3 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col2" class="data row3 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col3" class="data row3 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col4" class="data row3 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col5" class="data row3 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col6" class="data row3 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col1" class="data row4 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col6" class="data row4 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col1" class="data row5 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col6" class="data row5 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col1" class="data row6 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col4" class="data row6 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col5" class="data row6 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col6" class="data row6 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8

# %% [markdown]
# # Causal Triples' Polarity (Token Level)

# %% [markdown]
# ### [AllenNlp]

# %%
allen_word = []
allen_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks: 
        #print(token)
        preds = predictor1.predict(str(token))
            #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen_tuple.append(-1)
                #allen_word.append(-1)
        else:
                #allen_word.append(1)
            allen_tuple.append(1)
    allen_word.append(allen_tuple)
    allen_tuple = []
                
for a,b in zip(causalTriples,allen_word):
    #print(len(a))
    print(a,b)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) [1, 1, -1]
# (nuclear program, declared, pakistan's commitment) [-1, 1, 1]
# (nuclear program, declared, pakistan's dedication) [-1, 1, 1]
# (aq khan, developed, nuclear bomb) [1, 1, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 1]
# (nuclear bomb, makes, nuclear power) [-1, 1, 1]
# (pakistan, must never surrender, nuclear bomb) [1, 1, -1]
# (pakistan, must fight, existential threats) [1, 1, -1]
# (pakistan, must support, army) [1, 1, 1]
# (pakistan, must support, aq khan) [1, 1, 1]
# (army, provides, vigilance) [1, 1, 1]
# (vigilance, strengthened, national survival) [1, 1, 1]

# %% [markdown]
# ### [Afinn]

# %%
afinn_word = []
afinn_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
        #if str(token) not in marks:
            #print(token)
        score = afn.score(str(token))
        if score > 0:
                #print('positive')
            afinn_tuple.append(1)
        elif score < 0:
                #print('negative')
            afinn_tuple.append(-1)
        else:
                #print('neutral')
            afinn_tuple.append(0)
    afinn_word.append(afinn_tuple)
    afinn_tuple = []

for a,b in zip(causalTriples,afinn_word):
   # print(len(a))
    print(a,b)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) [0, 1, 0]
# (nuclear program, declared, pakistan's commitment) [0, 0, 1]
# (nuclear program, declared, pakistan's dedication) [0, 0, 1]
# (aq khan, developed, nuclear bomb) [0, 0, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 0]
# (nuclear bomb, makes, nuclear power) [-1, 0, 0]
# (pakistan, must never surrender, nuclear bomb) [0, 0, -1]
# (pakistan, must fight, existential threats) [0, -1, -1]
# (pakistan, must support, army) [0, 1, 0]
# (pakistan, must support, aq khan) [0, 1, 0]
# (army, provides, vigilance) [0, 0, 0]
# (vigilance, strengthened, national survival) [0, 1, 0]

# %% [markdown]
# ### [Vader]

# %%
vader_word = []
vader_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) not in marks:
        vs = analyzer.polarity_scores(str(token))
        compound = vs['compound']
        if compound >= 0.05:
            vader_tuple.append(1)   
        elif compound <= -0.05 :
            vader_tuple.append(-1)
        elif  compound > -0.05 and compound < 0.05:
            vader_tuple.append(0)
    vader_word.append(vader_tuple)
    vader_tuple = []

for a,b in zip(causalTriples,vader_word):
    #print(len(a))
    print(a,b)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) [0, 1, 0]
# (nuclear program, declared, pakistan's commitment) [0, 0, 1]
# (nuclear program, declared, pakistan's dedication) [0, 0, 0]
# (aq khan, developed, nuclear bomb) [0, 0, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 0]
# (nuclear bomb, makes, nuclear power) [-1, 0, 0]
# (pakistan, must never surrender, nuclear bomb) [0, 0, -1]
# (pakistan, must fight, existential threats) [0, -1, -1]
# (pakistan, must support, army) [0, 1, 0]
# (pakistan, must support, aq khan) [0, 1, 0]
# (army, provides, vigilance) [0, 0, 0]
# (vigilance, strengthened, national survival) [0, 1, 0]

# %% [markdown]
# ### [SentiStrength]

# %%
senti_word = []
senti_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks:
        #print(token)
        result = senti.getSentiment(str(token), score='binary')
            #print(result)
        if result[0]==1:
                #print('Positive')
            senti_tuple.append(1)
        elif result[0]==-1:
                #print('Negative')
            senti_tuple.append(-1)
        else:
                #print('Neutral')
            senti_tuple.append(0)
    senti_word.append(senti_tuple)
    senti_tuple = []
    
for a,b in zip(causalTriples,senti_word):
    #print(len(a))
    print(a,b)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) [1, 1, 1]
# (nuclear program, declared, pakistan's commitment) [1, 1, 1]
# (nuclear program, declared, pakistan's dedication) [1, 1, 1]
# (aq khan, developed, nuclear bomb) [1, 1, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 1]
# (nuclear bomb, makes, nuclear power) [-1, 1, 1]
# (pakistan, must never surrender, nuclear bomb) [1, 1, -1]
# (pakistan, must fight, existential threats) [1, -1, -1]
# (pakistan, must support, army) [1, 1, 1]
# (pakistan, must support, aq khan) [1, 1, 1]
# (army, provides, vigilance) [1, 1, 1]
# (vigilance, strengthened, national survival) [1, 1, 1]

# %% [markdown]
# ### Data Frame (Causal Triples Token Level)

# %%
sum_list = []
sum_tup = []
limit= len(causalTriples)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

triplesWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    triplesWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([causalTriples[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],triplesWeight_TokenLevel[i],triplePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                        0                1                   2
# Tokens           (zulfikar, ali, bhutto)       (launched)  (nuclear, program)
# AllenNlp                               1                1                  -1
# Afinn                                  0                1                   0
# Vader                                  0                1                   0
# SentiStrength                          1                1                   1
# Token Weight                           2                4                   0
# Token Polarity             Mild Positive  Strong Positive             Neutral
# Triple Weight                        2.0             None                None
# Triple Polarity            Mild Positive             None                None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                   0              1                           2
# Tokens           (nuclear, program)     (declared)  (pakistan, 's, commitment)
# AllenNlp                         -1              1                           1
# Afinn                             0              0                           1
# Vader                             0              0                           1
# SentiStrength                     1              1                           1
# Token Weight                      0              2                           4
# Token Polarity              Neutral  Mild Positive             Strong Positive
# Triple Weight                   2.0           None                        None
# Triple Polarity       Mild Positive           None                        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                   0              1                           2
# Tokens           (nuclear, program)     (declared)  (pakistan, 's, dedication)
# AllenNlp                         -1              1                           1
# Afinn                             0              0                           1
# Vader                             0              0                           0
# SentiStrength                     1              1                           1
# Token Weight                      0              2                           3
# Token Polarity              Neutral  Mild Positive           Moderate Positive
# Triple Weight                  1.67           None                        None
# Triple Polarity       Mild Positive           None                        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                2
# Tokens              (aq, khan)    (developed)  (nuclear, bomb)
# AllenNlp                     1              1               -1
# Afinn                        0              0               -1
# Vader                        0              0               -1
# SentiStrength                1              1               -1
# Token Weight                 2              2               -4
# Token Polarity   Mild Positive  Mild Positive  Strong Negative
# Triple Weight              0.0           None             None
# Triple Polarity        Neutral           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                1              2
# Tokens           (nuclear, bomb)   (strengthened)     (pakistan)
# AllenNlp                      -1                1              1
# Afinn                         -1                1              0
# Vader                         -1                1              0
# SentiStrength                 -1                1              1
# Token Weight                  -4                4              2
# Token Polarity   Strong Negative  Strong Positive  Mild Positive
# Triple Weight               0.67             None           None
# Triple Polarity    Weak Positive             None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                 2
# Tokens           (nuclear, bomb)        (makes)  (nuclear, power)
# AllenNlp                      -1              1                 1
# Afinn                         -1              0                 0
# Vader                         -1              0                 0
# SentiStrength                 -1              1                 1
# Token Weight                  -4              2                 2
# Token Polarity   Strong Negative  Mild Positive     Mild Positive
# Triple Weight                0.0           None              None
# Triple Polarity          Neutral           None              None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                         1                2
# Tokens              (pakistan)  (must, never, surrender)  (nuclear, bomb)
# AllenNlp                     1                         1               -1
# Afinn                        0                         0               -1
# Vader                        0                         0               -1
# SentiStrength                1                         1               -1
# Token Weight                 2                         2               -4
# Token Polarity   Mild Positive             Mild Positive  Strong Negative
# Triple Weight              0.0                      None             None
# Triple Polarity        Neutral                      None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                       2
# Tokens              (pakistan)  (must, fight)  (existential, threats)
# AllenNlp                     1              1                      -1
# Afinn                        0             -1                      -1
# Vader                        0             -1                      -1
# SentiStrength                1             -1                      -1
# Token Weight                 2             -2                      -4
# Token Polarity   Mild Positive  Mild Negative         Strong Negative
# Triple Weight            -1.33           None                    None
# Triple Polarity  Mild Negative           None                    None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                1              2
# Tokens                  (pakistan)  (must, support)         (army)
# AllenNlp                         1                1              1
# Afinn                            0                1              0
# Vader                            0                1              0
# SentiStrength                    1                1              1
# Token Weight                     2                4              2
# Token Polarity       Mild Positive  Strong Positive  Mild Positive
# Triple Weight                 2.67             None           None
# Triple Polarity  Moderate Positive             None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                1              2
# Tokens                  (pakistan)  (must, support)     (aq, khan)
# AllenNlp                         1                1              1
# Afinn                            0                1              0
# Vader                            0                1              0
# SentiStrength                    1                1              1
# Token Weight                     2                4              2
# Token Polarity       Mild Positive  Strong Positive  Mild Positive
# Triple Weight                 2.67             None           None
# Triple Polarity  Moderate Positive             None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens                  (army)     (provides)    (vigilance)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                1                     2
# Tokens                 (vigilance)   (strengthened)  (national, survival)
# AllenNlp                         1                1                     1
# Afinn                            0                1                     0
# Vader                            0                1                     0
# SentiStrength                    1                1                     1
# Token Weight                     2                4                     2
# Token Polarity       Mild Positive  Strong Positive         Mild Positive
# Triple Weight                 2.67             None                  None
# Triple Polarity  Moderate Positive             None                  None

# %% [markdown]
# # Causal Sentences' Polarity (Token Level)

# %% [markdown]
# ### Generating list of tokens without stop words and punctuation marks.

# %%
def GenerateTokens(causalSentences):
    marks = ['.',',','(',')','-',':',';','/',"'s",'_','__','--','"', '’', '—']
    token_list = []
   
    for sent in causalSentences:
        token_tuple = []
        for token in sent:
            if str(token) not in marks:
                if str(token) not in stopwords.words():
                    token_tuple.append(str(token))
        token_list.append(token_tuple)
    return token_list
        
#print(len(token_list))
#print(token_list)

# %% [markdown]
# ### [AllenNlp]

# %%
def Allen_sents_TokenLevel(token_list):
    allen_word = []
    allen_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks: 
                #print(token)
            preds = predictor1.predict(str(token))
                #print(preds['label'][0])
            label = preds['label'][0]
            if label is '0':
                allen_tuple.append(-1)
                    #allen_word.append(-1)
            else:
                    #allen_word.append(1)
                allen_tuple.append(1)
        allen_word.append(allen_tuple)
        allen_tuple = []
    return allen_word

#for a in allen_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Afinn]

# %%
def Afinn_sents_TokenLevel(token_list):
    afinn_word = []
    afinn_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
            #if str(token) not in marks:
                #print(token)
            score = afn.score(str(token))
            if score > 0:
                    #print('positive')
                afinn_tuple.append(1)
            elif score < 0:
                    #print('negative')
                afinn_tuple.append(-1)
            else:
                    #print('neutral')
                afinn_tuple.append(0)
        afinn_word.append(afinn_tuple)
        afinn_tuple = []
    return afinn_word

#for a in afinn_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Vader]

# %%
def Vader_sents_TokenLevel(token_list):
    vader_word = []
    vader_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
            vs = analyzer.polarity_scores(str(token))
            compound = vs['compound']
            if compound >= 0.05:
                vader_tuple.append(1)   
            elif compound <= -0.05 :
                vader_tuple.append(-1)
            elif  compound > -0.05 and compound < 0.05:
                vader_tuple.append(0)
        vader_word.append(vader_tuple)
        vader_tuple = []
    return vader_word

#for a in vader_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [SentiStrength]

# %%
def Senti_sents_TokenLevel(token_list):
    senti_word = []
    senti_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
                #print(token)
            result = senti.getSentiment(str(token), score='binary')
                #print(result)
            if result[0]==1:
                    #print('Positive')
                senti_tuple.append(1)
            elif result[0]==-1:
                    #print('Negative')
                senti_tuple.append(-1)
            else:
                    #print('Neutral')
                senti_tuple.append(0)
        senti_word.append(senti_tuple)
        senti_tuple = []
    return senti_word
    
#for a in senti_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### Data Frame (Causal Sentences Word Level)

# %%
token_list = GenerateTokens(causalSents)
allen_word = Allen_sents_TokenLevel(token_list)
afinn_word = Afinn_sents_TokenLevel(token_list)
vader_word = Vader_sents_TokenLevel(token_list)   
senti_word = Senti_sents_TokenLevel(token_list)

sum_list = []
sum_tup = []
limit= len(causalSents)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

sentsWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    sentsWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([token_list[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],sentsWeight_TokenLevel[i],SentencePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                1         2              3  \
# Tokens             institutional         weakness  hindered    development
# AllenNlp                       1               -1        -1              1
# Afinn                          0               -1         0              0
# Vader                          0               -1         0              0
# SentiStrength                  1               -1         1              1
# Token Weight                   2               -4         0              2
# Token Polarity     Mild Positive  Strong Negative   Neutral  Mild Positive
# Sentence Weight             0.67             None      None           None
# Sentence Polarity  Weak Positive             None      None           None
#
#                                4              5
# Tokens               agriculture         sector
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight             None           None
# Sentence Polarity           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 1.12           None           None
# Sentence Polarity      Mild Positive           None           None
#
#                                3              4           5               6  \
# Tokens                investment          shows  irrigation  infrastructure
# AllenNlp                       1              1          -1               1
# Afinn                          0              0           0               0
# Vader                          0              0           0               0
# SentiStrength                  1              1           1               1
# Token Weight                   2              2           0               2
# Token Polarity     Mild Positive  Mild Positive     Neutral   Mild Positive
# Sentence Weight             None           None        None            None
# Sentence Polarity           None           None        None            None
#
#                                7
# Tokens                    exists
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 0.85           None           None
# Sentence Polarity      Weak Positive           None           None
#
#                                3              4              5              6  \
# Tokens                investment          shows              2        percent
# AllenNlp                       1              1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1              1              1              1
# Token Weight                   2              2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive  Mild Positive
# Sentence Weight             None           None           None           None
# Sentence Polarity           None           None           None           None
#
#                          7        8              9       10             11  \
# Tokens               south    sudan        limited     road        network
# AllenNlp                -1       -1             -1       -1              1
# Afinn                    0        0             -1        0              0
# Vader                    0        0             -1        0              0
# SentiStrength            1        1              1        1              1
# Token Weight             0        0             -2        0              2
# Token Polarity     Neutral  Neutral  Mild Negative  Neutral  Mild Positive
# Sentence Weight       None     None           None     None           None
# Sentence Polarity     None     None           None     None           None
#
#                               12
# Tokens                     paved
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0               1               2  \
# Tokens                  inadequate  transportation  infrastructure
# AllenNlp                        -1               1               1
# Afinn                           -1               0               0
# Vader                           -1               0               0
# SentiStrength                   -1               1               1
# Token Weight                    -4               2               2
# Token Polarity     Strong Negative   Mild Positive   Mild Positive
# Sentence Weight               0.86            None            None
# Sentence Polarity    Weak Positive            None            None
#
#                                3        4              5              6
# Tokens                  resulted     less      transport        markets
# AllenNlp                       1       -1              1              1
# Afinn                          0        0              0              0
# Vader                          0        0              0              0
# SentiStrength                  1        1              1              1
# Token Weight                   2        0              2              2
# Token Polarity     Mild Positive  Neutral  Mild Positive  Mild Positive
# Sentence Weight             None     None           None           None
# Sentence Polarity           None     None           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2              3  \
# Tokens                persistent    heavy    rains      ethiopian
# AllenNlp                       1       -1       -1              1
# Afinn                          0        0        0              0
# Vader                          0        0        0              0
# SentiStrength                  1        1        1              1
# Token Weight                   2        0        0              2
# Token Polarity     Mild Positive  Neutral  Neutral  Mild Positive
# Sentence Weight                1     None     None           None
# Sentence Polarity  Weak Positive     None     None           None
#
#                                4              5         6        7        8  \
# Tokens                 highlands          cause  flooding    flood    prone
# AllenNlp                       1              1        -1       -1       -1
# Afinn                          0              0         0        0        0
# Vader                          0              0         0        0        0
# SentiStrength                  1              1         1        1        1
# Token Weight                   2              2         0        0        0
# Token Polarity     Mild Positive  Mild Positive   Neutral  Neutral  Neutral
# Sentence Weight             None           None      None     None     None
# Sentence Polarity           None           None      None     None     None
#
#                                9
# Tokens                     areas
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2        3        4  \
# Tokens                persistent    heavy    rains    south    sudan
# AllenNlp                       1       -1       -1       -1       -1
# Afinn                          0        0        0        0        0
# Vader                          0        0        0        0        0
# SentiStrength                  1        1        1        1        1
# Token Weight                   2        0        0        0        0
# Token Polarity     Mild Positive  Neutral  Neutral  Neutral  Neutral
# Sentence Weight              0.6     None     None     None     None
# Sentence Polarity  Weak Positive     None     None     None     None
#
#                                5         6        7        8              9
# Tokens                     cause  flooding    flood    prone          areas
# AllenNlp                       1        -1       -1       -1              1
# Afinn                          0         0        0        0              0
# Vader                          0         0        0        0              0
# SentiStrength                  1         1        1        1              1
# Token Weight                   2         0        0        0              2
# Token Polarity     Mild Positive   Neutral  Neutral  Neutral  Mild Positive
# Sentence Weight             None      None     None     None           None
# Sentence Polarity           None      None     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0          1        2              3         4  \
# Tokens                    highly  saturated    soils          cause  flooding
# AllenNlp                       1         -1       -1              1        -1
# Afinn                          0          0        0              0         0
# Vader                          0          0        0              0         0
# SentiStrength                  1          1        1              1         1
# Token Weight                   2          0        0              2         0
# Token Polarity     Mild Positive    Neutral  Neutral  Mild Positive   Neutral
# Sentence Weight             0.75       None     None           None      None
# Sentence Polarity  Weak Positive       None     None           None      None
#
#                          5        6              7
# Tokens               flood    prone          areas
# AllenNlp                -1       -1              1
# Afinn                    0        0              0
# Vader                    0        0              0
# SentiStrength            1        1              1
# Token Weight             0        0              2
# Token Polarity     Neutral  Neutral  Mild Positive
# Sentence Weight       None     None           None
# Sentence Polarity     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      rain         caused         floods
# AllenNlp                      -1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   0              2              2
# Token Polarity           Neutral  Mild Positive  Mild Positive
# Sentence Weight             1.33           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2              3  \
# Tokens                    floods      displaced        100,000         people
# AllenNlp                       1             -1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1             -1              1              1
# Token Weight                   2             -2              2              2
# Token Polarity     Mild Positive  Mild Negative  Mild Positive  Mild Positive
# Sentence Weight             0.67           None           None           None
# Sentence Polarity  Weak Positive           None           None           None
#
#                          4        5
# Tokens               south    sudan
# AllenNlp                -1       -1
# Afinn                    0        0
# Vader                    0        0
# SentiStrength            1        1
# Token Weight             0        0
# Token Polarity     Neutral  Neutral
# Sentence Weight       None     None
# Sentence Polarity     None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                  2
# Tokens                    floods          raise              fears
# AllenNlp                       1              1                 -1
# Afinn                          0              0                  0
# Vader                          0              0                 -1
# SentiStrength                  1              1                 -1
# Token Weight                   2              2                 -3
# Token Polarity     Mild Positive  Mild Positive  Moderate Negative
# Sentence Weight             0.33           None               None
# Sentence Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                  1              2  \
# Tokens                    floods      devastatingly         impact
# AllenNlp                       1                 -1              1
# Afinn                          0                  0              0
# Vader                          0                 -1              0
# SentiStrength                  1                 -1              1
# Token Weight                   2                 -3              2
# Token Polarity     Mild Positive  Moderate Negative  Mild Positive
# Sentence Weight             0.86               None           None
# Sentence Polarity  Weak Positive               None           None
#
#                                3                  4        5        6
# Tokens                      food           security    south    sudan
# AllenNlp                       1                  1       -1       -1
# Afinn                          0                  0        0        0
# Vader                          0                  1        0        0
# SentiStrength                  1                  1        1        1
# Token Weight                   2                  3        0        0
# Token Polarity     Mild Positive  Moderate Positive  Neutral  Neutral
# Sentence Weight             None               None     None     None
# Sentence Polarity           None               None     None     None

# %% [markdown]
# # Overall Polarity of Sents and Triples by all Four Methods

# %% [markdown]
# ### Follow the following instructions (steps) before executing the cell given below
# #### Step1- Execute cell for setting causalSents to causalSentences (with duplicates).
# #### Step2- Execute cell for computing sentences' polarity at sentence level.
# #### Step3- Execute cell for computing sentences' polarity at token level.
# #### Step4- Execute the below cell.

# %%
totalWeight_AllMethods = []

limit= len(causalSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+triplesWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/4,2)
        sum_tup.append(res)
    totalWeight_AllMethods.append(sum_tup)
    
totalPlarity_AllMethods = DetectPolarity(totalWeight_AllMethods)

df_AllMethods = pd.DataFrame(list(zip(causalSents, causalTriples, sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel, totalWeight_AllMethods,totalPlarity_AllMethods)), 
                             columns =['Causal Sentence', 'Causal Triple', 'Method1 (Sent_SentLevel)', 'Method2 (Trip_SentLevel)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)','Total Weight','Overall Polarity'])

df_AllMethods.style

# %% [markdown]
# # Overall Polarity of Triples at two (sentence and token) levels

# %%
totalTriplesWeight_AllLevels = []

limit= len(causalTriples)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(triplesWeight_sentLevel[i])):
        res = triplesWeight_sentLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalTriplesWeight_AllLevels.append(sum_tup)
    
totalTripsPlarity_AllLevels = DetectPolarity(totalTriplesWeight_AllLevels)

df_TripAllLevels = pd.DataFrame(list(zip(causalTriples, triplesWeight_sentLevel, triplesWeight_TokenLevel, totalTriplesWeight_AllLevels, totalTripsPlarity_AllLevels)), 
                             columns =['Causal Triple', 'Weight (Trip_SentLevel)','Weight (Trip_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_TripAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d559be8c_3cf2_11ec_a91c_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Triple</th>        <th class="col_heading level0 col1" >Weight (Trip_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Trip_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col0" class="data row0 col0" >(institutional weakness, hindered, development)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col2" class="data row0 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col3" class="data row0 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col4" class="data row0 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col0" class="data row1 col0" >(institutional weakness, hindered, the agriculture sector)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col2" class="data row1 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col3" class="data row1 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col4" class="data row1 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col0" class="data row2 col0" >(no irrigation infrastructure, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col1" class="data row2 col1" >[-1]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col2" class="data row2 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col3" class="data row2 col3" >[-0.16]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col4" class="data row2 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col0" class="data row3 col0" >(the low level, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col1" class="data row3 col1" >[-3]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col2" class="data row3 col2" >[0.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col3" class="data row3 col3" >[-1.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col0" class="data row4 col0" >(the low level, shows, no irrigation infrastructure)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col1" class="data row4 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col2" class="data row4 col2" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col3" class="data row4 col3" >[-2.5]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col4" class="data row4 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col0" class="data row5 col0" >(south sudan's limited road network, shows, only 2 percent)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col1" class="data row5 col1" >[-2]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col2" class="data row5 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col3" class="data row5 col3" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col4" class="data row5 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col0" class="data row6 col0" >(inadequate transportation infrastructure, resulted, markets)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col1" class="data row6 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col2" class="data row6 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col3" class="data row6 col3" >[-2.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col4" class="data row6 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col0" class="data row7 col0" >(inadequate transportation infrastructure, resulted, less transport)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col1" class="data row7 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col2" class="data row7 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col3" class="data row7 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col4" class="data row7 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col0" class="data row8 col0" >(persistent heavy rains, cause, flooding)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col1" class="data row8 col1" >[0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col3" class="data row8 col3" >[0.34]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col4" class="data row8 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row9_col0" class="data row9 col0" >(persistent heavy r

# %% [markdown]
# # Overall Polarity of Sentences at two (sentence and token) Levels

# %%
totalSentsWeight_AllLevels = []

limit= len(causalSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalSentsWeight_AllLevels.append(sum_tup)
    
totalSentsPolarity_AllLevels = DetectPolarity(totalSentsWeight_AllLevels)

df_SentsAllLevels = pd.DataFrame(list(zip(causalSents, sentsWeight_sentLevel, sentsWeight_TokenLevel, totalSentsWeight_AllLevels, totalSentsPolarity_AllLevels)), 
                             columns =['Causal Sentence', 'Weight (Sent_SentLevel)','Weight (Sent_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_SentsAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d560e568_3cf2_11ec_870b_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >Weight (Sent_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Sent_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col2" class="data row0 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col3" class="data row0 col3" >[-1.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col4" class="data row0 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col2" class="data row1 col2" >[1.12]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col3" class="data row1 col3" >[-1.44]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col4" class="data row1 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col1" class="data row2 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col2" class="data row2 col2" >[0.85]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col3" class="data row2 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col4" class="data row2 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col1" class="data row3 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col2" class="data row3 col2" >[0.86]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col3" class="data row3 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col1" class="data row4 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col2" class="data row4 col2" >[1.0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col3" class="data row4 col3" >[0.5]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col4" class="data row4 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col1" class="data row5 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col2" class="data row5 col2" >[0.6]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col3" class="data row5 col3" >[0.3]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col4" class="data row5 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col1" class="data row6 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col2" class="data row6 col2" >[0.75]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col3" class="data row6 col3" >[0.38]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col4" class="data row6 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col0" class="data row7 col0" >rain caused floods.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col1" class="data row7 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col2" class="data row7 col2" >[1.33]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col3" class="data row7 col3" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col4" class="data row7 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col0" class="data row8 col0" >floods have displaced more than 100,000 people in south sudan.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col1" class="data row8 col1" >[-2]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col3" class="data row8 col3" >[-0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col4" class="data row8 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row9" class="row_heading level0

# %% [markdown]
# # Plot the Polarized/Modified Causal Graph.

# %% [raw]
# cg = nx.DiGraph()
#
# for ce in polarizedCauseffect:
#     s = str(ce[0])
#     d = str(ce[2])
#     cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
#     cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
#     cg.add_edge(s, d, predicade=str(ce[1]))
#
# print(len(cg.nodes))
# print(len(cg.edges))
#
# pos = nx.spring_layout(cg, k=4, iterations=20)
# plt.figure(figsize=(15,12))
#
# nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
# edge_labels = nx.get_edge_attributes(cg,'predicade')
# nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)
#
# plt.axis('off')
# plt.show()
