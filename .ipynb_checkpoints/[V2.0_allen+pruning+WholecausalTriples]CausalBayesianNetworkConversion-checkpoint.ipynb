# %% [markdown]
# # Import necessary libraries.

# %%
import spacy
import textacy
import textacy.preprocessing
import textacy.resources
#import textacy.keyterms
import textacy.ke
#import neuralcoref
from spacy.symbols import ORTH, POS, NOUN, VERB,PRON
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt 
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
#from nltk import word_tokenize, pos_tag
from networkx.readwrite import json_graph;
import json
from afinn import Afinn
afn = Afinn()
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
lemmatizer = WordNetLemmatizer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from allennlp_models.pretrained import load_predictor
predictor1 = load_predictor("roberta-sst")   #for sentiment analysis
#predictor = load_predictor("coref-spanbert") #for coreference resolution
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')
import pandas as pd
from IPython.display import display
import collections
from nltk.corpus import stopwords
set(stopwords.words('english'))
from pd_replicator import replicator
from textacy.preprocessing.remove import remove_punctuation
from textacy.preprocessing.normalize import normalize_hyphenated_words

import allennlp_models.tagging

#coreference resolution
from allennlp.predictors.predictor import Predictor
predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz")

#from allennlp_models.pretrained import load_predictor
#predictor = load_predictor("roberta-sst")

nlp = spacy.load("en_core_web_sm")
#neuralcoref.add_to_pipe(nlp)

import pysmile
pysmile.License((
	b"SMILE LICENSE c978699b 97c07af6 f69b7377 "
	b"THIS IS AN ACADEMIC LICENSE AND CAN BE USED "
	b"SOLELY FOR ACADEMIC RESEARCH AND TEACHING, "
	b"AS DEFINED IN THE BAYESFUSION ACADEMIC "
	b"SOFTWARE LICENSING AGREEMENT. "
	b"Serial #: damx5dd4ezqly012c37ko4l9i "
	b"Issued for: Solat Jabeen (solatjabeen@gmail.com) "
	b"Academic institution: Institute of Business Administration "
	b"Valid until: 2024-02-05 "
	b"Issued by BayesFusion activation server"
	),[
	0x73,0x67,0x28,0xba,0x6a,0x03,0x97,0x7f,0x5b,0x89,0x34,0xc7,0xc1,0x5a,0x5a,0xb3,
	0xec,0x9e,0x9e,0x6a,0x09,0xd5,0xc2,0x93,0xb4,0x57,0x24,0xc9,0x3d,0xf8,0x8d,0x25,
	0x96,0xbd,0x56,0xb8,0x3c,0xad,0x98,0x00,0xcb,0x27,0xa2,0x28,0x4b,0x1f,0x76,0xb1,
	0x92,0x1a,0x65,0x41,0xd6,0xbe,0x12,0xa3,0x4b,0x60,0x83,0x3f,0x57,0x1d,0xf7,0x23])
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp\tango\__init__.py:18: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   "AllenNLP Tango is an experimental API and parts of it might change or disappear "
# 2023-08-08 06:15:06,724 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-08-08 06:15:06,756 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\coref-spanbert.json as plain json
# 2023-08-08 06:15:06,765 - INFO - allennlp.common.params - id = coref-spanbert
# 2023-08-08 06:15:06,769 - INFO - allennlp.common.params - type = coref-spanbert
# 2023-08-08 06:15:06,769 - INFO - allennlp.common.params - registered_model_name = coref
# 2023-08-08 06:15:06,770 - INFO - allennlp.common.params - type = coref
# 2023-08-08 06:15:06,771 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 06:15:06,773 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 06:15:06,774 - INFO - allennlp.common.params - display_name = Coreference Resolution
# 2023-08-08 06:15:06,776 - INFO - allennlp.common.params - type = Coreference Resolution
# 2023-08-08 06:15:06,778 - INFO - allennlp.common.params - task_id = coref
# 2023-08-08 06:15:06,779 - INFO - allennlp.common.params - type = coref
# 2023-08-08 06:15:06,781 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:06,785 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:06,788 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:06,795 - INFO - allennlp.common.params - model_usage.archive_file = coref-spanbert-large-2021.03.10.tar.gz
# 2023-08-08 06:15:06,798 - INFO - allennlp.common.params - type = coref-spanbert-large-2021.03.10.tar.gz
# 2023-08-08 06:15:06,810 - INFO - allennlp.common.params - model_usage.training_config = coref/coref_spanbert_large.jsonnet
# 2023-08-08 06:15:06,812 - INFO - allennlp.common.params - type = coref/coref_spanbert_large.jsonnet
# 2023-08-08 06:15:06,821 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 06:15:06,826 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 06:15:06,839 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 06:15:06,845 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:06,848 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:06,851 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:06,855 - INFO - allennlp.common.params - model_details.description = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-08-08 06:15:06,857 - INFO - allennlp.common.params - type = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-08-08 06:15:06,868 - INFO - allennlp.common.params - model_details.short_description = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-08-08 06:15:06,872 - INFO - allennlp.common.params - type = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-08-08 06:15:06,878 - INFO - allennlp.common.params - model_details.developed_by = Lee et al
# 2023-08-08 06:15:06,881 - INFO - allennlp.common.params - type = Lee et al
# 2023-08-08 06:15:06,883 - INFO - allennlp.common.params - model_details.contributed_by = Zhaofeng Wu
# 2023-08-08 06:15:06,885 - INFO - allennlp.common.params - type = Zhaofeng Wu
# 2023-08-08 06:15:06,886 - INFO - allennlp.common.params - model_details.date = 2020-02-27
# 2023-08-08 06:15:06,888 - INFO - allennlp.common.params - type = 2020-02-27
# 2023-08-08 06:15:06,891 - INFO - allennlp.common.params - model_details.version = 2
# 2023-08-08 06:15:06,894 - INFO - allennlp.common.params - type = 2
# 2023-08-08 06:15:06,896 - INFO - allennlp.common.params - model_details.model_type = SpanBERT
# 2023-08-08 06:15:06,898 - INFO - allennlp.common.params - type = SpanBERT
# 2023-08-08 06:15:06,901 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:06,906 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:06,909 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:06,913 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lee2018HigherorderCR,
# title={Higher-order Coreference Resolution with Coarse-to-fine Inference},
# author={Kenton Lee and Luheng He and L. Zettlemoyer},
# booktitle={NAACL-HLT},
# year={2018}}
#
# 2023-08-08 06:15:06,915 - INFO - allennlp.common.params - model_details.paper.title = Higher-order Coreference Resolution with Coarse-to-fine Inference
# 2023-08-08 06:15:06,917 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:4891749
# 2023-08-08 06:15:06,921 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 06:15:06,923 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 06:15:06,926 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 06:15:06,936 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:06,940 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:06,943 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:06,947 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 06:15:06,949 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 06:15:06,950 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 06:15:06,953 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:06,956 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:06,963 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:06,966 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 06:15:06,969 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 06:15:06,972 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:06,975 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:06,979 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:06,981 - INFO - allennlp.common.params - metrics.model_performance_measures = CoNLL coref scores and Mention Recall
# 2023-08-08 06:15:06,983 - INFO - allennlp.common.params - type = CoNLL coref scores and Mention Recall
# 2023-08-08 06:15:06,986 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 06:15:06,988 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 06:15:06,991 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:06,993 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:06,996 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:06,999 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,003 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,006 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,009 - INFO - allennlp.common.params - evaluation_data.dataset.name = Ontonotes 5.0
# 2023-08-08 06:15:07,011 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-08-08 06:15:07,012 - INFO - allennlp.common.params - evaluation_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-08-08 06:15:07,014 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = /path/to/dataset
# 2023-08-08 06:15:07,014 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 06:15:07,016 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 06:15:07,019 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,021 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,024 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,028 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,031 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,034 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,037 - INFO - allennlp.common.params - training_data.dataset.name = Ontonotes 5.0
# 2023-08-08 06:15:07,040 - INFO - allennlp.common.params - training_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-08-08 06:15:07,041 - INFO - allennlp.common.params - training_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-08-08 06:15:07,042 - INFO - allennlp.common.params - training_data.dataset.processed_url = /path/to/dataset
# 2023-08-08 06:15:07,044 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 06:15:07,045 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 06:15:07,047 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,055 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,058 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,061 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 06:15:07,063 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 06:15:07,065 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,069 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,072 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,075 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 06:15:07,076 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,079 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,082 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,085 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 06:15:07,089 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\evaluate_rc-lerc.json as plain json
# 2023-08-08 06:15:07,106 - INFO - allennlp.common.params - id = evaluate_rc-lerc
# 2023-08-08 06:15:07,108 - INFO - allennlp.common.params - type = evaluate_rc-lerc
# 2023-08-08 06:15:07,110 - INFO - allennlp.common.params - registered_model_name = lerc
# 2023-08-08 06:15:07,111 - INFO - allennlp.common.params - type = lerc
# 2023-08-08 06:15:07,113 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 06:15:07,115 - INFO - allennlp.common.params - registered_predictor_name = lerc
# 2023-08-08 06:15:07,116 - INFO - allennlp.common.params - type = lerc
# 2023-08-08 06:15:07,118 - INFO - allennlp.common.params - display_name = Learned Evaluation for Reading Comprehension (LERC)
# 2023-08-08 06:15:07,120 - INFO - allennlp.common.params - type = Learned Evaluation for Reading Comprehension (LERC)
# 2023-08-08 06:15:07,123 - INFO - allennlp.common.params - task_id = evaluate_rc
# 2023-08-08 06:15:07,125 - INFO - allennlp.common.params - type = evaluate_rc
# 2023-08-08 06:15:07,127 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,129 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,132 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,134 - INFO - allennlp.common.params - model_usage.archive_file = lerc-2020-11-18.tar.gz
# 2023-08-08 06:15:07,136 - INFO - allennlp.common.params - type = lerc-2020-11-18.tar.gz
# 2023-08-08 06:15:07,142 - INFO - allennlp.common.params - model_usage.training_config = None
# 2023-08-08 06:15:07,144 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 06:15:07,145 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 06:15:07,152 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 06:15:07,154 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,155 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,160 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,162 - INFO - allennlp.common.params - model_details.description = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-08-08 06:15:07,163 - INFO - allennlp.common.params - type = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-08-08 06:15:07,169 - INFO - allennlp.common.params - model_details.short_description = A BERT model that scores candidate answers from 0 to 1.
# 2023-08-08 06:15:07,170 - INFO - allennlp.common.params - type = A BERT model that scores candidate answers from 0 to 1.
# 2023-08-08 06:15:07,177 - INFO - allennlp.common.params - model_details.developed_by = Chen et al
# 2023-08-08 06:15:07,179 - INFO - allennlp.common.params - type = Chen et al
# 2023-08-08 06:15:07,180 - INFO - allennlp.common.params - model_details.contributed_by = Anthony Chen
# 2023-08-08 06:15:07,181 - INFO - allennlp.common.params - type = Anthony Chen
# 2023-08-08 06:15:07,182 - INFO - allennlp.common.params - model_details.date = 2021-03-10
# 2023-08-08 06:15:07,183 - INFO - allennlp.common.params - type = 2021-03-10
# 2023-08-08 06:15:07,184 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 06:15:07,185 - INFO - allennlp.common.params - type = 1
# 2023-08-08 06:15:07,186 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-08-08 06:15:07,189 - INFO - allennlp.common.params - type = BERT
# 2023-08-08 06:15:07,189 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:07,191 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:07,194 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:07,202 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Chen2020MOCHAAD,
# title={MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics},
# author={Anthony Chen and Gabriel Stanovsky and S. Singh and Matt Gardner},
# booktitle={EMNLP},
# year={2020}}
#
# 2023-08-08 06:15:07,203 - INFO - allennlp.common.params - model_details.paper.title = MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics
# 2023-08-08 06:15:07,205 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:222208714
# 2023-08-08 06:15:07,208 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 06:15:07,210 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 06:15:07,212 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 06:15:07,218 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,221 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,223 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,225 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 06:15:07,226 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 06:15:07,227 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 06:15:07,229 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,230 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,232 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,235 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 06:15:07,237 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 06:15:07,238 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,240 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,243 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,245 - INFO - allennlp.common.params - metrics.model_performance_measures = Pearson Correlation
# 2023-08-08 06:15:07,247 - INFO - allennlp.common.params - type = Pearson Correlation
# 2023-08-08 06:15:07,249 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 06:15:07,252 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 06:15:07,254 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,256 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,257 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,260 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,262 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,264 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,267 - INFO - allennlp.common.params - evaluation_data.dataset.name = MOCHA
# 2023-08-08 06:15:07,269 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://allennlp.org/mocha
# 2023-08-08 06:15:07,270 - INFO - allennlp.common.params - evaluation_data.dataset.notes = To evaluate this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-08-08 06:15:07,271 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = None
# 2023-08-08 06:15:07,272 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 06:15:07,272 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 06:15:07,273 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,275 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,277 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,279 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,287 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,292 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,296 - INFO - allennlp.common.params - training_data.dataset.name = MOCHA
# 2023-08-08 06:15:07,297 - INFO - allennlp.common.params - training_data.dataset.url = https://allennlp.org/mocha
# 2023-08-08 06:15:07,298 - INFO - allennlp.common.params - training_data.dataset.notes = To train this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-08-08 06:15:07,301 - INFO - allennlp.common.params - training_data.dataset.processed_url = None
# 2023-08-08 06:15:07,302 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 06:15:07,304 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 06:15:07,307 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,310 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,313 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,318 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 06:15:07,320 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 06:15:07,323 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,327 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,330 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,332 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 06:15:07,335 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,337 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,341 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,344 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 06:15:07,352 - WARNING - allennlp.common.model_card - lerc is not a registered model.
# 2023-08-08 06:15:07,355 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\generation-bart.json as plain json
# 2023-08-08 06:15:07,372 - INFO - allennlp.common.params - id = generation-bart
# 2023-08-08 06:15:07,373 - INFO - allennlp.common.params - type = generation-bart
# 2023-08-08 06:15:07,375 - INFO - allennlp.common.params - registered_model_name = bart
# 2023-08-08 06:15:07,376 - INFO - allennlp.common.params - type = bart
# 2023-08-08 06:15:07,377 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 06:15:07,378 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 06:15:07,379 - INFO - allennlp.common.params - display_name = BART
# 2023-08-08 06:15:07,380 - INFO - allennlp.common.params - type = BART
# 2023-08-08 06:15:07,381 - INFO - allennlp.common.params - task_id = None
# 2023-08-08 06:15:07,382 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,384 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,387 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,388 - INFO - allennlp.common.params - model_usage.archive_file = bart-2020.07.25.tar.gz
# 2023-08-08 06:15:07,389 - INFO - allennlp.common.params - type = bart-2020.07.25.tar.gz
# 2023-08-08 06:15:07,395 - INFO - allennlp.common.params - model_usage.training_config = generation/bart_cnn_dm.jsonnet
# 2023-08-08 06:15:07,396 - INFO - allennlp.common.params - type = generation/bart_cnn_dm.jsonnet
# 2023-08-08 06:15:07,403 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 06:15:07,405 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 06:15:07,411 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 06:15:07,413 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,416 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,419 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,422 - INFO - allennlp.common.params - model_details.description = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-08-08 06:15:07,423 - INFO - allennlp.common.params - type = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-08-08 06:15:07,429 - INFO - allennlp.common.params - model_details.short_description = BART with a language model head for generation.
# 2023-08-08 06:15:07,432 - INFO - allennlp.common.params - type = BART with a language model head for generation.
# 2023-08-08 06:15:07,441 - INFO - allennlp.common.params - model_details.developed_by = Lewis et al
# 2023-08-08 06:15:07,442 - INFO - allennlp.common.params - type = Lewis et al
# 2023-08-08 06:15:07,443 - INFO - allennlp.common.params - model_details.contributed_by = Dirk Groeneveld
# 2023-08-08 06:15:07,445 - INFO - allennlp.common.params - type = Dirk Groeneveld
# 2023-08-08 06:15:07,448 - INFO - allennlp.common.params - model_details.date = 2020-07-25
# 2023-08-08 06:15:07,449 - INFO - allennlp.common.params - type = 2020-07-25
# 2023-08-08 06:15:07,450 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 06:15:07,452 - INFO - allennlp.common.params - type = 1
# 2023-08-08 06:15:07,454 - INFO - allennlp.common.params - model_details.model_type = BART
# 2023-08-08 06:15:07,456 - INFO - allennlp.common.params - type = BART
# 2023-08-08 06:15:07,458 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:07,459 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:07,461 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:07,464 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lewis2020BARTDS,
# title={BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension},
# author={M. Lewis and Yinhan Liu and Naman Goyal and Marjan Ghazvininejad and A. Mohamed and Omer Levy and Ves Stoyanov and L. Zettlemoyer},
# booktitle={ACL},
# year={2020}}
#
# 2023-08-08 06:15:07,466 - INFO - allennlp.common.params - model_details.paper.title = BART: Denosing Sequence-to-Sequence Pre-training for Natural Language Generation,Translation, and Comprehension
# 2023-08-08 06:15:07,466 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:204960716
# 2023-08-08 06:15:07,468 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 06:15:07,470 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 06:15:07,472 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 06:15:07,479 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,490 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,493 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,496 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 06:15:07,499 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 06:15:07,500 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 06:15:07,502 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,505 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,507 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,509 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 06:15:07,511 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 06:15:07,514 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,517 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,520 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,523 - INFO - allennlp.common.params - metrics.model_performance_measures = ROUGE and BLEU
# 2023-08-08 06:15:07,526 - INFO - allennlp.common.params - type = ROUGE and BLEU
# 2023-08-08 06:15:07,527 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 06:15:07,528 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 06:15:07,529 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,532 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,533 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,536 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,538 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,540 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,542 - INFO - allennlp.common.params - evaluation_data.dataset.name = CNN/DailyMail
# 2023-08-08 06:15:07,543 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-08-08 06:15:07,544 - INFO - allennlp.common.params - evaluation_data.dataset.notes = Please download the data from the url provided.
# 2023-08-08 06:15:07,545 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 06:15:07,547 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 06:15:07,548 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,551 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,554 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,557 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,559 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,560 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,562 - INFO - allennlp.common.params - training_data.dataset.name = CNN/DailyMail
# 2023-08-08 06:15:07,564 - INFO - allennlp.common.params - training_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-08-08 06:15:07,566 - INFO - allennlp.common.params - training_data.dataset.notes = Please download the data from the url provided.
# 2023-08-08 06:15:07,567 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 06:15:07,568 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 06:15:07,571 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,583 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,586 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,591 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 06:15:07,599 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 06:15:07,602 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,605 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,609 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:07,613 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 06:15:07,615 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,618 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,621 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:07,623 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 06:15:07,629 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\glove-sst.json as plain json
# 2023-08-08 06:15:07,639 - INFO - allennlp.common.params - id = glove-sst
# 2023-08-08 06:15:07,641 - INFO - allennlp.common.params - type = glove-sst
# 2023-08-08 06:15:07,642 - INFO - allennlp.common.params - registered_model_name = None
# 2023-08-08 06:15:07,645 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 06:15:07,646 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 06:15:07,647 - INFO - allennlp.common.params - display_name = GLoVe-LSTM
# 2023-08-08 06:15:07,648 - INFO - allennlp.common.params - type = GLoVe-LSTM
# 2023-08-08 06:15:07,649 - INFO - allennlp.common.params - task_id = sentiment-analysis
# 2023-08-08 06:15:07,651 - INFO - allennlp.common.params - type = sentiment-analysis
# 2023-08-08 06:15:07,652 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,654 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,656 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:07,658 - INFO - allennlp.common.params - model_usage.archive_file = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-08-08 06:15:07,659 - INFO - allennlp.common.params - type = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-08-08 06:15:07,668 - INFO - allennlp.common.params - model_usage.training_config = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-08-08 06:15:07,670 - INFO - allennlp.common.params - type = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-08-08 06:15:07,685 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 06:15:07,686 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 06:15:07,693 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 06:15:07,695 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,696 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,698 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:07,701 - INFO - allennlp.common.params - model_details.description = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-08-08 06:15:07,702 - INFO - allennlp.common.params - type = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-08-08 06:15:07,709 - INFO - allennlp.common.params - model_details.short_description = LSTM binary classifier with GloVe embeddings.
# 2023-08-08 06:15:07,712 - INFO - allennlp.common.params - type = LSTM binary classifier with GloVe embeddings.
# 2023-08-08 06:15:07,722 - INFO - allennlp.common.params - model_details.developed_by = None
# 2023-08-08 06:15:07,723 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-08-08 06:15:07,724 - INFO - allennlp.common.params - model_details.date = 2020-06-09
# 2023-08-08 06:15:07,725 - INFO - allennlp.common.params - type = 2020-06-09
# 2023-08-08 06:15:07,726 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 06:15:07,727 - INFO - allennlp.common.params - type = 1
# 2023-08-08 06:15:07,728 - INFO - allennlp.common.params - model_details.model_type = LSTM
# 2023-08-08 06:15:07,731 - INFO - allennlp.common.params - type = LSTM
# 2023-08-08 06:15:07,731 - INFO - allennlp.common.params - model_details.paper = None
# 2023-08-08 06:15:07,732 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 06:15:07,734 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 06:15:07,736 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 06:15:07,744 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,748 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,751 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 06:15:07,755 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 06:15:07,759 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 06:15:07,761 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 06:15:07,764 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,769 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,777 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 06:15:07,784 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 06:15:07,790 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 06:15:07,803 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,806 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,817 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 06:15:07,821 - INFO - allennlp.common.params - metrics.model_performance_measures = Accuracy
# 2023-08-08 06:15:07,825 - INFO - allennlp.common.params - type = Accuracy
# 2023-08-08 06:15:07,826 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 06:15:07,835 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 06:15:07,838 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,843 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,852 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 06:15:07,859 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,864 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,869 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 06:15:07,874 - INFO - allennlp.common.params - evaluation_data.dataset.name = Stanford Sentiment Treebank
# 2023-08-08 06:15:07,876 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-08-08 06:15:07,878 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/test.txt
# 2023-08-08 06:15:07,881 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 06:15:07,882 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 06:15:07,885 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,894 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,896 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 06:15:07,903 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,908 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,918 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 06:15:07,926 - INFO - allennlp.common.params - training_data.dataset.name = Stanford Sentiment Treebank
# 2023-08-08 06:15:07,929 - INFO - allennlp.common.params - training_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-08-08 06:15:07,930 - INFO - allennlp.common.params - training_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/train.txt
# 2023-08-08 06:15:07,931 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 06:15:07,932 - INFO - allennlp.common.params - training_data.preprocessing = Binary classification setting
# 2023-08-08 06:15:07,934 - INFO - allennlp.common.params - type = Binary classification setting
# 2023-08-08 06:15:07,936 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,943 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,954 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 06:15:07,968 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = Accuracy: 87% on SST test set.
# 2023-08-08 06:15:07,986 - INFO - allennlp.common.params - type = Accuracy: 87% on SST test set.
# 2023-08-08 06:15:08,023 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 06:15:08,032 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:08,044 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:08,047 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 06:15:08,049 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 06:15:08,051 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:08,053 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:08,056 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 06:15:08,058 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 06:15:08,061 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\lm-masked-language-model.json as plain json
# 2023-08-08 06:15:08,073 - INFO - allennlp.common.params - id = lm-masked-language-model
# 2023-08-08 06:15:08,075 - INFO - allennlp.common.params - type = lm-masked-language-model
# 2023-08-08 06:15:08,077 - INFO - allennlp.common.params - registered_model_name = masked_language_model
# 2023-08-08 06:15:08,078 - INFO - allennlp.common.params - type = masked_language_model
# 2023-08-08 06:15:08,079 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 06:15:08,081 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 06:15:08,082 - INFO - allennlp.common.params - display_name = BERT-based Masked Language Model
# 2023-08-08 06:15:08,083 - INFO - allennlp.common.params - type = BERT-based Masked Language Model
# 2023-08-08 06:15:08,083 - INFO - allennlp.common.params - task_id = masked-language-modeling
# 2023-08-08 06:15:08,084 - INFO - allennlp.common.params - type = masked-language-modeling
# 2023-08-08 06:15:08,085 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:08,091 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:08,093 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 06:15:08,095 - INFO - allennlp.common.params - model_usage.archive_file = bert-masked-lm-2020-10-07.tar.gz
# 2023-08-08 06:15:08,096 - INFO - allennlp.common.params - type = bert-masked-lm-2020-10-07.tar.gz
# 2023-08-08 06:15:08,103 - INFO - allennlp.common.params - model_usage.training_config = lm/bidirectional_language_model.jsonnet
# 2023-08-08 06:15:08,106 - INFO - allennlp.common.params - type = lm/bidirectional_language_model.jsonnet
# 2023-08-08 06:15:08,115 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 06:15:08,118 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 06:15:08,123 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 06:15:08,124 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:08,126 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:08,128 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 06:15:08,131 - INFO - allennlp.common.params - model_details.description = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-08-08 06:15:08,132 - INFO - allennlp.common.params - type = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-08-08 06:15:08,139 - INFO - allennlp.common.params - model_details.short_description = BERT-based masked language model
# 2023-08-08 06:15:08,140 - INFO - allennlp.common.params - type = BERT-based masked language model
# 2023-08-08 06:15:08,141 - INFO - allennlp.common.params - model_details.developed_by = Devlin et al
# 2023-08-08 06:15:08,143 - INFO - allennlp.common.params - type = Devlin et al
# 2023-08-08 06:15:08,144 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-08-08 06:15:08,145 - INFO - allennlp.common.params - model_details.date = 2020-10-07
# 2023-08-08 06:15:08,147 - INFO - allennlp.common.params - type = 2020-10-07
# 2023-08-08 06:15:08,149 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 06:15:08,149 - INFO - allennlp.common.params - type = 1
# 2023-08-08 06:15:08,151 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-08-08 06:15:08,152 - INFO - allennlp.common.params - type = BERT
# 2023-08-08 06:15:08,154 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:08,157 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:08,160 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 06:15:08,162 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Devlin2019BERTPO,
# title={BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding},
# author={J. Devlin and Ming-Wei Chang and Kenton Lee and Kristina Toutanova},
# booktitle={NAACL-HLT},
# year={2019}}
#
# 2023-08-08 06:15:08,164 - INFO - allennlp.common.params - model_details.paper.title = BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# ...
# 2023-08-08 06:16:29,001 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.bias
# 2023-08-08 06:16:29,002 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.weight
# 2023-08-08 06:16:29,003 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2023-08-08 06:16:29,004 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2023-08-08 06:16:29,006 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2023-08-08 06:16:29,007 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2023-08-08 06:16:29,008 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.bias
# 2023-08-08 06:16:29,009 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.weight
# 2023-08-08 06:16:29,012 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.bias
# 2023-08-08 06:16:29,013 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.weight
# 2023-08-08 06:16:29,014 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.bias
# 2023-08-08 06:16:29,015 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.weight
# 2023-08-08 06:16:29,016 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2023-08-08 06:16:29,020 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2023-08-08 06:16:29,021 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2023-08-08 06:16:29,022 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2023-08-08 06:16:29,023 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.bias
# 2023-08-08 06:16:29,026 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.weight
# 2023-08-08 06:16:29,028 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2023-08-08 06:16:29,029 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2023-08-08 06:16:29,030 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2023-08-08 06:16:29,033 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2023-08-08 06:16:29,035 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.bias
# 2023-08-08 06:16:29,037 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.weight
# 2023-08-08 06:16:29,039 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.bias
# 2023-08-08 06:16:29,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.weight
# 2023-08-08 06:16:29,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.bias
# 2023-08-08 06:16:29,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.weight
# 2023-08-08 06:16:29,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2023-08-08 06:16:29,047 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2023-08-08 06:16:29,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2023-08-08 06:16:29,050 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2023-08-08 06:16:29,051 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.bias
# 2023-08-08 06:16:29,054 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.weight
# 2023-08-08 06:16:29,056 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2023-08-08 06:16:29,057 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2023-08-08 06:16:29,058 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2023-08-08 06:16:29,061 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2023-08-08 06:16:29,063 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.bias
# 2023-08-08 06:16:29,065 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.weight
# 2023-08-08 06:16:29,066 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.bias
# 2023-08-08 06:16:29,068 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.weight
# 2023-08-08 06:16:29,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.bias
# 2023-08-08 06:16:29,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.weight
# 2023-08-08 06:16:29,072 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2023-08-08 06:16:29,075 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2023-08-08 06:16:29,076 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2023-08-08 06:16:29,079 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2023-08-08 06:16:29,081 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.bias
# 2023-08-08 06:16:29,083 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.weight
# 2023-08-08 06:16:29,084 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2023-08-08 06:16:29,086 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2023-08-08 06:16:29,087 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2023-08-08 06:16:29,089 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2023-08-08 06:16:29,091 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2023-08-08 06:16:29,093 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2023-08-08 06:16:29,096 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2023-08-08 06:16:29,098 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2023-08-08 06:16:29,100 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2023-08-08 06:16:29,102 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2023-08-08 06:16:29,105 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2023-08-08 06:16:29,106 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2023-08-08 06:16:29,109 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2023-08-08 06:16:29,111 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2023-08-08 06:16:29,113 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2023-08-08 06:16:29,113 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2023-08-08 06:16:29,115 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2023-08-08 06:16:29,118 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2023-08-08 06:16:29,118 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2023-08-08 06:16:29,119 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2023-08-08 06:16:29,121 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2023-08-08 06:16:29,123 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2023-08-08 06:16:29,124 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2023-08-08 06:16:29,126 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2023-08-08 06:16:29,128 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2023-08-08 06:16:29,129 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2023-08-08 06:16:29,130 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2023-08-08 06:16:29,132 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2023-08-08 06:16:29,132 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2023-08-08 06:16:29,134 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2023-08-08 06:16:29,136 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2023-08-08 06:16:29,138 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2023-08-08 06:16:29,139 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2023-08-08 06:16:29,141 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2023-08-08 06:16:29,151 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-08-08 06:16:29,153 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-08-08 06:16:30,337 - INFO - allennlp.models.archival - removing temporary unarchived model dir at C:\Users\sjsheikh\AppData\Local\Temp\tmpkbg07qdv

# %% [markdown]
# # Read text file and preprocess.

# %%
file_name = './Text/Simplified Food Insecurity.txt'
narrative = open(file_name, encoding="utf8").read()

print('Original Narrative:')
print(narrative)
print('\n')

narrative = predictor.coref_resolved(narrative)
narrative = narrative.lower()
narrative = textacy.preprocessing.normalize_quotation_marks(narrative)
narrative = normalize_hyphenated_words(narrative)
narrative = textacy.preprocessing.normalize_whitespace(narrative)
narrative = remove_punctuation(narrative, marks=';"":')

print('Narrarive after resolving coreferences:')
print(narrative)

print('\nSpacy Sentences:\n')
narrative = nlp(narrative)
for sent in narrative.sents:
    print(sent.text)
    print()

print('\nNLTK Sentences:\n')
raw_sentences = sent_tokenize(str(narrative))
for sent in raw_sentences:
    print(sent)
    print()
# Out:
# Original Narrative:
# Institutional weakness hindered development of the agriculture sector. Land Rights disagreements are a major source of conflict. This conflict discourages farmers from expanding production. This conflict discourages traders from building marketing infrastructure. This conflict discourages retailers from building marketing infrastructure. The low level of public investment shows that no irrigation infrastructure exists. The low level of public investment shows that only 2 percent of South Sudan's limited road network is paved. Roads are poorly maintained. Roads are not repaired. Roads are completely washed out during the rainy season. Inadequate transportation infrastructure has resulted in less transport to markets. Moderate to heavy rainfall is expected to continue during the next two weeks across Sudan Moderate to heavy rainfall is expected to continue during the next two weeks across South Sudan. Moderate to heavy rainfall is expected to continue during the next two weeks across Uganda. Moderate to heavy rainfall is expected to continue during the next two weeks across northern Kenya. Moderate to heavy rainfall is expected to continue during the next two weeks across western/northern Ethiopia. Persistent heavy rains in the Ethiopian highlands cause flooding in flood prone areas. Persistent heavy rains in the eastern Sudan cause flooding in flood-prone areas. Persistent heavy rains in the South Sudan cause flooding in flood-prone areas. Highly saturated soils cause flooding in flood-prone areas. Rain caused floods. Floods have displaced more than 100,000 people in South Sudan. Floods raise fears. Floods devastatingly impact on food security in the war-torn nation.
#
#
# Narrarive after resolving coreferences:
# institutional weakness hindered development of the agriculture sector. land rights disagreements are a major source of conflict. conflict discourages farmers from expanding production. conflict discourages traders from building marketing infrastructure. conflict discourages retailers from building marketing infrastructure. the low level of public investment shows that no irrigation infrastructure exists. the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. roads are poorly maintained. roads are not repaired. roads are completely washed out during the rainy season. inadequate transportation infrastructure has resulted in less transport to markets. moderate to heavy rainfall is expected to continue during the next two weeks across sudan moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's. moderate to heavy rainfall is expected to continue during the next two weeks across uganda. moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya. moderate to heavy rainfall is expected to continue during the next two weeks across western/northern ethiopia. persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. persistent heavy rains in south sudan's cause flooding in flood-prone areas. highly saturated soils cause flooding in flood-prone areas. rain caused floods. floods have displaced more than 100,000 people in south sudan's. floods raise fears. floods devastatingly impact on food security in the war-torn nation.
#
# Spacy Sentences:
#
# institutional weakness hindered development of the agriculture sector.
#
# land rights disagreements are a major source of conflict.
#
# conflict discourages farmers from expanding production.
#
# conflict discourages traders from building marketing infrastructure.
#
# conflict discourages retailers from building marketing infrastructure.
#
# the low level of public investment shows that no irrigation infrastructure exists.
#
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
#
# roads are poorly maintained.
#
# roads are not repaired.
#
# roads are completely washed out during the rainy season.
#
# inadequate transportation infrastructure has resulted in less transport to markets.
#
# moderate to heavy rainfall is expected to continue during the next two weeks across sudan moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's. moderate to heavy rainfall is expected to continue during the next two weeks across uganda.
#
# moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya.
#
# moderate to heavy rainfall is expected to continue during the next two weeks across western/northern ethiopia.
#
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
#
# persistent heavy rains in south sudan's cause flooding in flood-prone areas.
#
# highly saturated soils cause flooding in flood-prone areas.
#
# rain caused floods.
#
# floods have displaced more than 100,000 people in south sudan's.
#
# floods raise fears.
#
# floods devastatingly impact on food security in the war-torn nation.
#
#
# NLTK Sentences:
#
# institutional weakness hindered development of the agriculture sector.
#
# land rights disagreements are a major source of conflict.
#
# conflict discourages farmers from expanding production.
#
# conflict discourages traders from building marketing infrastructure.
#
# conflict discourages retailers from building marketing infrastructure.
#
# the low level of public investment shows that no irrigation infrastructure exists.
#
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
#
# roads are poorly maintained.
#
# roads are not repaired.
#
# roads are completely washed out during the rainy season.
#
# inadequate transportation infrastructure has resulted in less transport to markets.
#
# moderate to heavy rainfall is expected to continue during the next two weeks across sudan moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's.
#
# moderate to heavy rainfall is expected to continue during the next two weeks across uganda.
#
# moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya.
#
# moderate to heavy rainfall is expected to continue during the next two weeks across western/northern ethiopia.
#
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
#
# persistent heavy rains in south sudan's cause flooding in flood-prone areas.
#
# highly saturated soils cause flooding in flood-prone areas.
#
# rain caused floods.
#
# floods have displaced more than 100,000 people in south sudan's.
#
# floods raise fears.
#
# floods devastatingly impact on food security in the war-torn nation.

# %% [markdown]
# # Extract the Subject-Verb-Object triples.

# %%
#new
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
sub = ''
obj = ''
#tuple =('a','b','c')

#print(tuple[0])

for sent in raw_sentences:
    sent = nlp(sent)
    print("Sentence:")
    print(sent)
    
    print("Noun Chunks:")
    for nc in sent.noun_chunks:
        print (nc)
        ncl.append(nc)
    print ("Number of noun chunks: ", len(ncl))
    
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            print("Triples other than textacy:")
            print(nncl[0])
            print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],triplets[0][1],ncl[1])]
#            print("Triples other than textacy:")
#            print(nncl[0])
#            finalList.append(nncl[0])
    else:
        print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                sub = token
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
                #tuple[1] = token.text
            #elif token.dep_ == 'dobj':
            #    obj = token.text
                #tuple[2] = token.text
            #    break
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue
                
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        print("Triple by combining nsubj, root and dobj:")
        print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],verb,ncl[1])]
#            print("Triples other than sub, verb and obj:")
#            print(nncl[0])
#            finalList.append(nncl[0])

    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
    
trips = finalList

#        for token in nc:
#            print(token.text, token.dep_)
# Out:
# Sentence:
# institutional weakness hindered development of the agriculture sector.
# Noun Chunks:
# institutional weakness
# development
# the agriculture sector
# Number of noun chunks:  3
# Triples from textacy:
# (institutional weakness, hindered, development)
# Triples other than textacy:
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# Sentence:
# land rights disagreements are a major source of conflict.
# Noun Chunks:
# land rights disagreements
# a major source
# conflict
# Number of noun chunks:  3
# Triples from textacy:
# (rights disagreements, are, a major source)
# Triples other than textacy:
# (land rights disagreements, are, a major source)
# (land rights disagreements, are, conflict)
# Sentence:
# conflict discourages farmers from expanding production.
# Noun Chunks:
# conflict
# farmers
# production
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, farmers)
# Triples other than textacy:
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# Sentence:
# conflict discourages traders from building marketing infrastructure.
# Noun Chunks:
# conflict
# traders
# marketing infrastructure
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, traders)
# Triples other than textacy:
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# Sentence:
# conflict discourages retailers from building marketing infrastructure.
# Noun Chunks:
# conflict
# retailers
# marketing infrastructure
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, retailers)
# Triples other than textacy:
# (conflict, discourages, retailers)
# (conflict, discourages, marketing infrastructure)
# Sentence:
# the low level of public investment shows that no irrigation infrastructure exists.
# Noun Chunks:
# the low level
# public investment
# no irrigation infrastructure
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (no irrigation infrastructure, shows, public investment)
# Triples other than sub, verb and obj:
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# Sentence:
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# Noun Chunks:
# the low level
# public investment
# only 2 percent
# south sudan's limited road network
# Number of noun chunks:  4
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (south sudan's limited road network, shows, only 2 percent)
# Sentence:
# roads are poorly maintained.
# Noun Chunks:
# roads
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (south sudan's limited road network, maintained, roads)
# Sentence:
# roads are not repaired.
# Noun Chunks:
# roads
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (south sudan's limited road network, repaired, roads)
# Sentence:
# roads are completely washed out during the rainy season.
# Noun Chunks:
# roads
# the rainy season
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the rainy season, washed, roads)
# Sentence:
# inadequate transportation infrastructure has resulted in less transport to markets.
# Noun Chunks:
# inadequate transportation infrastructure
# less transport
# markets
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (inadequate transportation infrastructure, resulted, markets)
# Triples other than sub, verb and obj:
# (inadequate transportation infrastructure, resulted, less transport)
# (inadequate transportation infrastructure, resulted, markets)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across sudan moderate to heavy rainfall is expected to continue during the next two weeks across south sudan's.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# sudan
# heavy rainfall
# the next two weeks
# south sudan
# Number of noun chunks:  6
# Triples from textacy:
# (moderate, is expected, to continue)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across uganda.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# Number of noun chunks:  2
# Triples from textacy:
# (moderate, is expected, to continue)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# northern kenya
# Number of noun chunks:  3
# Triples from textacy:
# (moderate, is expected, to continue)
# Triples other than textacy:
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, northern kenya)
# Sentence:
# moderate to heavy rainfall is expected to continue during the next two weeks across western/northern ethiopia.
# Noun Chunks:
# heavy rainfall
# the next two weeks
# western/northern ethiopia
# Number of noun chunks:  3
# Triples from textacy:
# (moderate, is expected, to continue)
# Triples other than textacy:
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, western/northern ethiopia)
# Sentence:
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# Noun Chunks:
# persistent heavy rains
# flood prone areas
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (persistent heavy rains, highlands, flood prone areas)
# Sentence:
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
# Noun Chunks:
# persistent heavy rains
# the eastern sudan
# flood-prone areas
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (persistent heavy rains, cause, flood-prone areas)
# Triples other than sub, verb and obj:
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, cause, flood-prone areas)
# Sentence:
# persistent heavy rains in south sudan's cause flooding in flood-prone areas.
# Noun Chunks:
# persistent heavy rains
# south sudan's cause
# flood-prone areas
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (persistent heavy rains, flooding, flood-prone areas)
# Triples other than sub, verb and obj:
# (persistent heavy rains, flooding, south sudan's cause)
# (persistent heavy rains, flooding, flood-prone areas)
# Sentence:
# highly saturated soils cause flooding in flood-prone areas.
# Noun Chunks:
# highly saturated soils
# flood-prone areas
# Number of noun chunks:  2
# Triples from textacy:
# (highly saturated soils, cause, flooding)
# Sentence:
# rain caused floods.
# Noun Chunks:
# rain
# floods
# Number of noun chunks:  2
# Triples from textacy:
# (rain, caused, floods)
# Sentence:
# floods have displaced more than 100,000 people in south sudan's.
# Noun Chunks:
# floods
# more than 100,000 people
# south sudan
# Number of noun chunks:  3
# Triples from textacy:
# (floods, have displaced, more than 100,000 people)
# Triples other than textacy:
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# Sentence:
# floods raise fears.
# Noun Chunks:
# floods
# fears
# Number of noun chunks:  2
# Triples from textacy:
# (floods, raise, fears)
# Sentence:
# floods devastatingly impact on food security in the war-torn nation.
# Noun Chunks:
# floods
# food security
# the war-torn nation
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (floods, impact, the war-torn nation)
# Triples other than sub, verb and obj:
# (floods, impact, food security)
# (floods, impact, the war-torn nation)

# %% [markdown]
# # Remove Duplicates from Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("Length of triples' List before removing duplicates:")
print(len(trips))

Triples = []
sentences1 = []

for sentence,ce in zip(sentences, trips):
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        sentences1.append(sentence)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            sentences1.append(sentence)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

for t in Triples:
    print(t)
# Out:
# Length of triples' List before removing duplicates:
# 49
#
# List after removing duplicates:
# 35
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (rights disagreements, are, a major source)
# (land rights disagreements, are, a major source)
# (land rights disagreements, are, conflict)
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (south sudan's limited road network, maintained, roads)
# (south sudan's limited road network, repaired, roads)
# (the rainy season, washed, roads)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (moderate, is expected, to continue)
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, northern kenya)
# (heavy rainfall, is expected, western/northern ethiopia)
# (persistent heavy rains, highlands, flood prone areas)
# (persistent heavy rains, cause, flood-prone areas)
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, flooding, flood-prone areas)
# (persistent heavy rains, flooding, south sudan's cause)
# (highly saturated soils, cause, flooding)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (floods, impact, the war-torn nation)
# (floods, impact, food security)

# %% [markdown]
# # Filter correct triples from extracted triples

# %%
correctTriples = []
sentences2 = []

for sentence,line in zip(sentences1, Triples):
    taggedWords = []
    taggedWords1 = []
    check0 = False
    check2 = False
    print(line)
    taggedWords = pos_tag(word_tokenize(str(line[0])))
    taggedWords1 = pos_tag(word_tokenize(str(line[2])))
    print(taggedWords)
    print(taggedWords1)
    for i in range(len(taggedWords)):
        if taggedWords[i][1] == 'NN' or taggedWords[i][1] == 'NNS':
            check0 = True
    for i in range(len(taggedWords1)):
        if taggedWords1[i][1] == 'NN' or taggedWords1[i][1] == 'NNS':
            check2 = True
    print(check0)  
    print(check2)
    if check0 == True and check2 == True:
        correctTriples.append(line)
        sentences2.append(sentence)
    print("**************************************************************************")
    
for correctTriple in correctTriples:
    print(correctTriple)
# Out:
# (institutional weakness, hindered, development)
# [('institutional', 'JJ'), ('weakness', 'NN')]
# [('development', 'NN')]
# True
# True
# **************************************************************************
# (institutional weakness, hindered, the agriculture sector)
# [('institutional', 'JJ'), ('weakness', 'NN')]
# [('the', 'DT'), ('agriculture', 'NN'), ('sector', 'NN')]
# True
# True
# **************************************************************************
# (rights disagreements, are, a major source)
# [('rights', 'NNS'), ('disagreements', 'NNS')]
# [('a', 'DT'), ('major', 'JJ'), ('source', 'NN')]
# True
# True
# **************************************************************************
# (land rights disagreements, are, a major source)
# [('land', 'NN'), ('rights', 'NNS'), ('disagreements', 'NNS')]
# [('a', 'DT'), ('major', 'JJ'), ('source', 'NN')]
# True
# True
# **************************************************************************
# (land rights disagreements, are, conflict)
# [('land', 'NN'), ('rights', 'NNS'), ('disagreements', 'NNS')]
# [('conflict', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, farmers)
# [('conflict', 'NN')]
# [('farmers', 'NNS')]
# True
# True
# **************************************************************************
# (conflict, discourages, production)
# [('conflict', 'NN')]
# [('production', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, traders)
# [('conflict', 'NN')]
# [('traders', 'NNS')]
# True
# True
# **************************************************************************
# (conflict, discourages, marketing infrastructure)
# [('conflict', 'NN')]
# [('marketing', 'NN'), ('infrastructure', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, retailers)
# [('conflict', 'NN')]
# [('retailers', 'NNS')]
# True
# True
# **************************************************************************
# (no irrigation infrastructure, shows, public investment)
# [('no', 'DT'), ('irrigation', 'NN'), ('infrastructure', 'NN')]
# [('public', 'JJ'), ('investment', 'NN')]
# True
# True
# **************************************************************************
# (the low level, shows, public investment)
# [('the', 'DT'), ('low', 'JJ'), ('level', 'NN')]
# [('public', 'JJ'), ('investment', 'NN')]
# True
# True
# **************************************************************************
# (the low level, shows, no irrigation infrastructure)
# [('the', 'DT'), ('low', 'JJ'), ('level', 'NN')]
# [('no', 'DT'), ('irrigation', 'NN'), ('infrastructure', 'NN')]
# True
# True
# **************************************************************************
# (south sudan's limited road network, shows, only 2 percent)
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('limited', 'JJ'), ('road', 'NN'), ('network', 'NN')]
# [('only', 'RB'), ('2', 'CD'), ('percent', 'NN')]
# True
# True
# **************************************************************************
# (south sudan's limited road network, maintained, roads)
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('limited', 'JJ'), ('road', 'NN'), ('network', 'NN')]
# [('roads', 'NNS')]
# True
# True
# **************************************************************************
# (south sudan's limited road network, repaired, roads)
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('limited', 'JJ'), ('road', 'NN'), ('network', 'NN')]
# [('roads', 'NNS')]
# True
# True
# **************************************************************************
# (the rainy season, washed, roads)
# [('the', 'DT'), ('rainy', 'NN'), ('season', 'NN')]
# [('roads', 'NNS')]
# True
# True
# **************************************************************************
# (inadequate transportation infrastructure, resulted, markets)
# [('inadequate', 'JJ'), ('transportation', 'NN'), ('infrastructure', 'NN')]
# [('markets', 'NNS')]
# True
# True
# **************************************************************************
# (inadequate transportation infrastructure, resulted, less transport)
# [('inadequate', 'JJ'), ('transportation', 'NN'), ('infrastructure', 'NN')]
# [('less', 'RBR'), ('transport', 'NN')]
# True
# True
# **************************************************************************
# (moderate, is expected, to continue)
# [('moderate', 'NN')]
# [('to', 'TO'), ('continue', 'VB')]
# True
# False
# **************************************************************************
# (heavy rainfall, is expected, the next two weeks)
# [('heavy', 'JJ'), ('rainfall', 'NN')]
# [('the', 'DT'), ('next', 'JJ'), ('two', 'CD'), ('weeks', 'NNS')]
# True
# True
# **************************************************************************
# (heavy rainfall, is expected, northern kenya)
# [('heavy', 'JJ'), ('rainfall', 'NN')]
# [('northern', 'JJ'), ('kenya', 'NN')]
# True
# True
# **************************************************************************
# (heavy rainfall, is expected, western/northern ethiopia)
# [('heavy', 'JJ'), ('rainfall', 'NN')]
# [('western/northern', 'JJ'), ('ethiopia', 'NN')]
# True
# True
# **************************************************************************
# (persistent heavy rains, highlands, flood prone areas)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flood', 'NN'), ('prone', 'NN'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (persistent heavy rains, cause, flood-prone areas)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flood-prone', 'JJ'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (persistent heavy rains, cause, the eastern sudan)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('the', 'DT'), ('eastern', 'JJ'), ('sudan', 'NN')]
# True
# True
# **************************************************************************
# (persistent heavy rains, flooding, flood-prone areas)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flood-prone', 'JJ'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (persistent heavy rains, flooding, south sudan's cause)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('cause', 'NN')]
# True
# True
# **************************************************************************
# (highly saturated soils, cause, flooding)
# [('highly', 'RB'), ('saturated', 'VBN'), ('soils', 'NNS')]
# [('flooding', 'VBG')]
# True
# False
# **************************************************************************
# (rain, caused, floods)
# [('rain', 'NN')]
# [('floods', 'NNS')]
# True
# True
# **************************************************************************
# (floods, have displaced, more than 100,000 people)
# [('floods', 'NNS')]
# [('more', 'JJR'), ('than', 'IN'), ('100,000', 'CD'), ('people', 'NNS')]
# True
# True
# **************************************************************************
# (floods, have displaced, south sudan)
# [('floods', 'NNS')]
# [('south', 'JJ'), ('sudan', 'NN')]
# True
# True
# **************************************************************************
# (floods, raise, fears)
# [('floods', 'NNS')]
# [('fears', 'NNS')]
# True
# True
# **************************************************************************
# (floods, impact, the war-torn nation)
# [('floods', 'NNS')]
# [('the', 'DT'), ('war-torn', 'JJ'), ('nation', 'NN')]
# True
# True
# **************************************************************************
# (floods, impact, food security)
# [('floods', 'NNS')]
# [('food', 'NN'), ('security', 'NN')]
# True
# True
# **************************************************************************
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (rights disagreements, are, a major source)
# (land rights disagreements, are, a major source)
# (land rights disagreements, are, conflict)
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (south sudan's limited road network, maintained, roads)
# (south sudan's limited road network, repaired, roads)
# (the rainy season, washed, roads)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (heavy rainfall, is expected, the next two weeks)
# (heavy rainfall, is expected, northern kenya)
# (heavy rainfall, is expected, western/northern ethiopia)
# (persistent heavy rains, highlands, flood prone areas)
# (persistent heavy rains, cause, flood-prone areas)
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, flooding, flood-prone areas)
# (persistent heavy rains, flooding, south sudan's cause)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (floods, impact, the war-torn nation)
# (floods, impact, food security)

# %% [markdown]
# # Print the extracted triples with sentences.

# %%
for sentence, triple  in zip(sentences2, correctTriples):
    print(sentence, triple)
    print()
# Out:
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
#
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector)
#
# land rights disagreements are a major source of conflict. (rights disagreements, are, a major source)
#
# land rights disagreements are a major source of conflict. (land rights disagreements, are, a major source)
#
# land rights disagreements are a major source of conflict. (land rights disagreements, are, conflict)
#
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
#
# conflict discourages farmers from expanding production. (conflict, discourages, production)
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
#
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
#
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment)
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment)
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure)
#
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent)
#
# roads are poorly maintained. (south sudan's limited road network, maintained, roads)
#
# roads are not repaired. (south sudan's limited road network, repaired, roads)
#
# roads are completely washed out during the rainy season. (the rainy season, washed, roads)
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport)
#
# moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya. (heavy rainfall, is expected, the next two weeks)
#
# moderate to heavy rainfall is expected to continue during the next two weeks across northern kenya. (heavy rainfall, is expected, northern kenya)
#
# moderate to heavy rainfall is expected to continue during the next two weeks across western/northern ethiopia. (heavy rainfall, is expected, western/northern ethiopia)
#
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas. (persistent heavy rains, highlands, flood prone areas)
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, the eastern sudan)
#
# persistent heavy rains in south sudan's cause flooding in flood-prone areas. (persistent heavy rains, flooding, flood-prone areas)
#
# persistent heavy rains in south sudan's cause flooding in flood-prone areas. (persistent heavy rains, flooding, south sudan's cause)
#
# rain caused floods. (rain, caused, floods)
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, more than 100,000 people)
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, south sudan)
#
# floods raise fears. (floods, raise, fears)
#
# floods devastatingly impact on food security in the war-torn nation. (floods, impact, the war-torn nation)
#
# floods devastatingly impact on food security in the war-torn nation. (floods, impact, food security)

# %% [markdown]
# # Reading causal trigger words dictionary from text file (dictionary.txt) to list

# %%
synonyms = []

my_file = open(".\dictionary.txt", "r")
  
data = my_file.read()
  
synonyms = data.split("\n")
#print(data_into_list)
my_file.close()

print(len(synonyms))
# Out:
# 3227

# %% [markdown]
# # Filter Causal triples along with their causal sentences from SVO triples based upon causal trigger words dictionary.

# %%
causeffect = [] #without duplicates
causalSentences = [] #with duplicates
#lem = []
lemma_function = WordNetLemmatizer()
for s,st in zip(sentences2,correctTriples):
    check = False
    #st = (str(st[0]),str(st[1]),str(st[2]))
    #synonym = synonym[0]
    tokens = word_tokenize(str(st[1]))
    for token, tag in pos_tag(tokens):
        lemma = lemma_function.lemmatize(token)
        #print(token,lemma)
        #st[1] = lemma
        #lem.append(lemma)
        
    for synonym in synonyms:
        if synonym == lemma:
            #causeffect = [(st[0],st[1],st[2])]
            #strTriples.append((ncl[0],token.text,st[2]))
           # print(st)
            if len(causeffect) == 0:
                causeffect.append(st)
                causalSentences.append(s)
            else:
                for ct in causeffect:
                    if str(st[0]) == str(ct[0]) and str(st[1]) == str(ct[1]) and str(st[2]) == str(ct[2]):
                        check = True
                        break;
                if check == False:
                    causeffect.append(st)
                    causalSentences.append(s)
            #if (len(causeffect) >0 ) and (st in causeffect == False):
                
            #    causeffect.append(st)
            break
    
#causeffect.sort(key = lambda x: x[0])

#for sortedTriple in causeffect:
#    print(sortedTriple)
print(len(causalSentences))
print(len(causeffect))
for causalSentence, causalTriple  in zip(causalSentences, causeffect):
    print(causalSentence, causalTriple)
# Out:
# 21
# 21
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector)
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
# conflict discourages farmers from expanding production. (conflict, discourages, production)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment)
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure)
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport)
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, the eastern sudan)
# rain caused floods. (rain, caused, floods)
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, more than 100,000 people)
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, south sudan)
# floods raise fears. (floods, raise, fears)
# floods devastatingly impact on food security in the war-torn nation. (floods, impact, the war-torn nation)
# floods devastatingly impact on food security in the war-torn nation. (floods, impact, food security)

# %% [markdown]
# # Plot the Causal Graph.

# %%
#new (DAG Implementation)
#without duplicates
dagCauseTriples = []
cg = nx.DiGraph()

for ce in causeffect:
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
    dagCauseTriples.append(ce)
    if nx.is_directed_acyclic_graph(cg) is False:
        cg.remove_edge(s, d)
        dagCauseTriples.remove(ce)
        

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 27
# Edges: 21
# institutional weakness , {'predicade': 'hindered'} , development
# institutional weakness , {'predicade': 'hindered'} , the agriculture sector
# conflict , {'predicade': 'discourages'} , farmers
# conflict , {'predicade': 'discourages'} , production
# conflict , {'predicade': 'discourages'} , traders
# conflict , {'predicade': 'discourages'} , marketing infrastructure
# conflict , {'predicade': 'discourages'} , retailers
# no irrigation infrastructure , {'predicade': 'shows'} , public investment
# the low level , {'predicade': 'shows'} , public investment
# the low level , {'predicade': 'shows'} , no irrigation infrastructure
# south sudan's limited road network , {'predicade': 'shows'} , only 2 percent
# inadequate transportation infrastructure , {'predicade': 'resulted'} , markets
# inadequate transportation infrastructure , {'predicade': 'resulted'} , less transport
# persistent heavy rains , {'predicade': 'cause'} , flood-prone areas
# persistent heavy rains , {'predicade': 'cause'} , the eastern sudan
# rain , {'predicade': 'caused'} , floods
# floods , {'predicade': 'have displaced'} , more than 100,000 people
# floods , {'predicade': 'have displaced'} , south sudan
# floods , {'predicade': 'raise'} , fears
# floods , {'predicade': 'impact'} , the war-torn nation
# floods , {'predicade': 'impact'} , food security

# %% [markdown]
# # Remove Duplicates from Causal Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("List before removing duplicates:")
print(len(causeffect))

for t in causeffect:
    print(t)
    
causalTriples = []

for ce in causeffect:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalTriples) == 0:
        #print("HEY!")
        causalTriples.append(ce)
        #print("added!")
    else:
        for ct in causalTriples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalTriples.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalTriples))

for t in causalTriples:
    print(t)
# Out:
# List before removing duplicates:
# 21
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (persistent heavy rains, cause, flood-prone areas)
# (persistent heavy rains, cause, the eastern sudan)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (floods, impact, the war-torn nation)
# (floods, impact, food security)
#
# List after removing duplicates:
# 21
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (persistent heavy rains, cause, flood-prone areas)
# (persistent heavy rains, cause, the eastern sudan)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (floods, impact, the war-torn nation)
# (floods, impact, food security)

# %% [markdown]
# # Causal Triples' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
allen = []
for sent in causalTriples:
    #print(sent)
    preds = predictor1.predict(str(sent))
    #print(preds['label'][0])
    label = preds['label'][0]
    if label is '0':
        allen.append(-1)
    else:
        allen.append(1)
    
for causalSentence, polarity  in zip(causalTriples, allen):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, production) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flood-prone areas) -1
# (persistent heavy rains, cause, the eastern sudan) -1
# (rain, caused, floods) -1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (floods, impact, the war-torn nation) -1
# (floods, impact, food security) 1

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)

afinn = []
for sent in causalTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    #print(score)
    if score > 0:
        #print('positive')
        afinn.append(1)
    elif score < 0:
        #print('negative')
        afinn.append(-1)
    else:
        #print('neutral')
        afinn.append(0)
        
for causalSentence, polarity  in zip(causalTriples, afinn):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, production) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) 0
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flood-prone areas) 0
# (persistent heavy rains, cause, the eastern sudan) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) 0
# (floods, impact, the war-torn nation) -1
# (floods, impact, food security) 0

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    if compound >= 0.05:
        vader.append(1)
        return 'Positive'
    elif compound <= -0.05 :
        vader.append(-1)
        return 'Negative'
        
    elif  compound > -0.05 and compound < 0.05:
        vader.append(0)
        return 'Neutral'
    
for sent in causalTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    vader_analysis(compound)
    
for causalSentence, polarity  in zip(causalTriples, vader):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, production) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) 0
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flood-prone areas) 0
# (persistent heavy rains, cause, the eastern sudan) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) -1
# (floods, impact, the war-torn nation) 0
# (floods, impact, food security) 1

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

#senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
#senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')


sentiStrength = []

for sent in causalTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='binary')
    #print(result)
    
    if result[0]==1:
        #print('Positive')
        sentiStrength.append(1)
    elif result[0]==-1:
        sentiStrength.append(-1)
        #print('Negative')
    #else:
    #    print('Neutral')

for causalSentence, polarity  in zip(causalTriples, sentiStrength):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, production) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) 1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) 1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flood-prone areas) 1
# (persistent heavy rains, cause, the eastern sudan) 1
# (rain, caused, floods) 1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (floods, impact, the war-torn nation) -1
# (floods, impact, food security) 1

# %% [markdown]
# ### Data Frame (Causal Triples Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.
# <style type="text/css">
# </style>
# <table id="T_05b0a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Triple</th>
#       <th class="col_heading level0 col1" >AllenNLP</th>
#       <th class="col_heading level0 col2" >Afinn</th>
#       <th class="col_heading level0 col3" >Vader</th>
#       <th class="col_heading level0 col4" >SentiStrength</th>
#       <th class="col_heading level0 col5" >Weight</th>
#       <th class="col_heading level0 col6" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05b0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05b0a_row0_col0" class="data row0 col0" >(institutional weakness, hindered, development)</td>
#       <td id="T_05b0a_row0_col1" class="data row0 col1" >-1</td>
#       <td id="T_05b0a_row0_col2" class="data row0 col2" >-1</td>
#       <td id="T_05b0a_row0_col3" class="data row0 col3" >-1</td>
#       <td id="T_05b0a_row0_col4" class="data row0 col4" >-1</td>
#       <td id="T_05b0a_row0_col5" class="data row0 col5" >-4</td>
#       <td id="T_05b0a_row0_col6" class="data row0 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05b0a_row1_col0" class="data row1 col0" >(institutional weakness, hindered, the agriculture sector)</td>
#       <td id="T_05b0a_row1_col1" class="data row1 col1" >-1</td>
#       <td id="T_05b0a_row1_col2" class="data row1 col2" >-1</td>
#       <td id="T_05b0a_row1_col3" class="data row1 col3" >-1</td>
#       <td id="T_05b0a_row1_col4" class="data row1 col4" >-1</td>
#       <td id="T_05b0a_row1_col5" class="data row1 col5" >-4</td>
#       <td id="T_05b0a_row1_col6" class="data row1 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_05b0a_row2_col0" class="data row2 col0" >(conflict, discourages, farmers)</td>
#       <td id="T_05b0a_row2_col1" class="data row2 col1" >-1</td>
#       <td id="T_05b0a_row2_col2" class="data row2 col2" >-1</td>
#       <td id="T_05b0a_row2_col3" class="data row2 col3" >-1</td>
#       <td id="T_05b0a_row2_col4" class="data row2 col4" >-1</td>
#       <td id="T_05b0a_row2_col5" class="data row2 col5" >-4</td>
#       <td id="T_05b0a_row2_col6" class="data row2 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_05b0a_row3_col0" class="data row3 col0" >(conflict, discourages, production)</td>
#       <td id="T_05b0a_row3_col1" class="data row3 col1" >-1</td>
#       <td id="T_05b0a_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_05b0a_row3_col3" class="data row3 col3" >-1</td>
#       <td id="T_05b0a_row3_col4" class="data row3 col4" >-1</td>
#       <td id="T_05b0a_row3_col5" class="data row3 col5" >-4</td>
#       <td id="T_05b0a_row3_col6" class="data row3 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_05b0a_row4_col0" class="data row4 col0" >(conflict, discourages, traders)</td>
#       <td id="T_05b0a_row4_col1" class="data row4 col1" >-1</td>
#       <td id="T_05b0a_row4_col2" class="data row4 col2" >-1</td>
#       <td id="T_05b0a_row4_col3" class="data row4 col3" >-1</td>
#       <td id="T_05b0a_row4_col4" class="data row4 col4" >-1</td>
#       <td id="T_05b0a_row4_col5" class="data row4 col5" >-4</td>
#       <td id="T_05b0a_row4_col6" class="data row4 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_05b0a_row5_col0" class="data row5 col0" >(conflict, discourages, marketing infrastructure)</td>
#       <td id="T_05b0a_row5_col1" class="data row5 col1" >-1</td>
#       <td id="T_05b0a_row5_col2" class="data row5 col2" >-1</td>
#       <td id="T_05b0a_row5_col3" class="data row5 col3" >-1</td>
#       <td id="T_05b0a_row5_col4" class="data row5 col4" >-1</td>
#       <td id="T_05b0a_row5_col5" class="data row5 col5" >-4</td>
#       <td id="T_05b0a_row5_col6" class="data row5 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_05b0a_row6_col0" class="data row6 col0" >(conflict, discourages, retailers)</td>
#       <td id="T_05b0a_row6_col1" class="data row6 col1" >-1</td>
#       <td id="T_05b0a_row6_col2" class="data row6 col2" >-1</td>
#       <td id="T_05b0a_row6_col3" class="data row6 col3" >-1</td>
#       <td id="T_05b0a_row6_col4" class="data row6 col4" >-1</td>
#       <td id="T_05b0a_row6_col5" class="data row6 col5" >-4</td>
#       <td id="T_05b0a_row6_col6" class="data row6 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_05b0a_row7_col0" class="data row7 col0" >(no irrigation infrastructure, shows, public investment)</td>
#       <td id="T_05b0a_row7_col1" class="data row7 col1" >-1</td>
#       <td id="T_05b0a_row7_col2" class="data row7 col2" >-1</td>
#       <td id="T_05b0a_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_05b0a_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_05b0a_row7_col5" class="data row7 col5" >-1</td>
#       <td id="T_05b0a_row7_col6" class="data row7 col6" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_05b0a_row8_col0" class="data row8 col0" >(the low level, shows, public investment)</td>
#       <td id="T_05b0a_row8_col1" class="data row8 col1" >-1</td>
#       <td id="T_05b0a_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_05b0a_row8_col3" class="data row8 col3" >-1</td>
#       <td id="T_05b0a_row8_col4" class="data row8 col4" >-1</td>
#       <td id="T_05b0a_row8_col5" class="data row8 col5" >-3</td>
#       <td id="T_05b0a_row8_col6" class="data row8 col6" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_05b0a_row9_col0" class="data row9 col0" >(the low level, shows, no irrigation infrastructure)</td>
#       <td id="T_05b0a_row9_col1" class="data row9 col1" >-1</td>
#       <td id="T_05b0a_row9_col2" class="data row9 col2" >-1</td>
#       <td id="T_05b0a_row9_col3" class="data row9 col3" >-1</td>
#       <td id="T_05b0a_row9_col4" class="data row9 col4" >-1</td>
#       <td id="T_05b0a_row9_col5" class="data row9 col5" >-4</td>
#       <td id="T_05b0a_row9_col6" class="data row9 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_05b0a_row10_col0" class="data row10 col0" >(south sudan's limited road network, shows, only 2 percent)</td>
#       <td id="T_05b0a_row10_col1" class="data row10 col1" >-1</td>
#       <td id="T_05b0a_row10_col2" class="data row10 col2" >-1</td>
#       <td id="T_05b0a_row10_col3" class="data row10 col3" >-1</td>
#       <td id="T_05b0a_row10_col4" class="data row10 col4" >1</td>
#       <td id="T_05b0a_row10_col5" class="data row10 col5" >-2</td>
#       <td id="T_05b0a_row10_col6" class="data row10 col6" >Mild Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_05b0a_row11_col0" class="data row11 col0" >(inadequate transportation infrastructure, resulted, markets)</td>
#       <td id="T_05b0a_row11_col1" class="data row11 col1" >-1</td>
#       <td id="T_05b0a_row11_col2" class="data row11 col2" >-1</td>
#       <td id="T_05b0a_row11_col3" class="data row11 col3" >-1</td>
#       <td id="T_05b0a_row11_col4" class="data row11 col4" >-1</td>
#       <td id="T_05b0a_row11_col5" class="data row11 col5" >-4</td>
#       <td id="T_05b0a_row11_col6" class="data row11 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_05b0a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_05b0a_row12_col0" class="data row12 col0" >

# %% [markdown]
# # Plot the Polarized/Weighted Causal Graph.

# %%
weights = df2["Weight"].tolist()
polarities = df2["Polarity"].tolist()
cwg = nx.DiGraph()

for ce,p,w in zip(dagCauseTriples, polarities,weights):
    s = str(ce[0])    
    d = str(ce[2])
    cwg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    cwg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cwg.add_edge(s, d, predicate=str(ce[1]), polarity = p, weight = w)
    
print("Nodes:",len(cwg.nodes))
print("Edges:",len(cwg.edges))
for e in cwg.edges(data=True):
    print(e[0],",",e[2],",",e[1])
    #for nbr, eattr in e[2].items():
    #    if nbr == "weight":
    #        print(eattr)

pos = nx.spring_layout(cwg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cwg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cwg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cwg,'predicate')
#edge_labels2 = nx.get_edge_attributes(cwg,'polarity')
#edge_labels3 = nx.get_edge_attributes(cwg,'weight')

nx.draw_networkx_edge_labels(cwg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 27
# Edges: 21
# institutional weakness , {'predicate': 'hindered', 'polarity': 'Strong Negative', 'weight': -4} , development
# institutional weakness , {'predicate': 'hindered', 'polarity': 'Strong Negative', 'weight': -4} , the agriculture sector
# conflict , {'predicate': 'discourages', 'polarity': 'Strong Negative', 'weight': -4} , farmers
# conflict , {'predicate': 'discourages', 'polarity': 'Strong Negative', 'weight': -4} , production
# conflict , {'predicate': 'discourages', 'polarity': 'Strong Negative', 'weight': -4} , traders
# conflict , {'predicate': 'discourages', 'polarity': 'Strong Negative', 'weight': -4} , marketing infrastructure
# conflict , {'predicate': 'discourages', 'polarity': 'Strong Negative', 'weight': -4} , retailers
# no irrigation infrastructure , {'predicate': 'shows', 'polarity': 'Weak Negative', 'weight': -1} , public investment
# the low level , {'predicate': 'shows', 'polarity': 'Moderate Negative', 'weight': -3} , public investment
# the low level , {'predicate': 'shows', 'polarity': 'Strong Negative', 'weight': -4} , no irrigation infrastructure
# south sudan's limited road network , {'predicate': 'shows', 'polarity': 'Mild Negative', 'weight': -2} , only 2 percent
# inadequate transportation infrastructure , {'predicate': 'resulted', 'polarity': 'Strong Negative', 'weight': -4} , markets
# inadequate transportation infrastructure , {'predicate': 'resulted', 'polarity': 'Strong Negative', 'weight': -4} , less transport
# persistent heavy rains , {'predicate': 'cause', 'polarity': 'Neutral', 'weight': 0} , flood-prone areas
# persistent heavy rains , {'predicate': 'cause', 'polarity': 'Neutral', 'weight': 0} , the eastern sudan
# rain , {'predicate': 'caused', 'polarity': 'Neutral', 'weight': 0} , floods
# floods , {'predicate': 'have displaced', 'polarity': 'Mild Negative', 'weight': -2} , more than 100,000 people
# floods , {'predicate': 'have displaced', 'polarity': 'Mild Negative', 'weight': -2} , south sudan
# floods , {'predicate': 'raise', 'polarity': 'Moderate Negative', 'weight': -3} , fears
# floods , {'predicate': 'impact', 'polarity': 'Moderate Negative', 'weight': -3} , the war-torn nation
# floods , {'predicate': 'impact', 'polarity': 'Moderate Positive', 'weight': 3} , food security

# %% [markdown]
# # Plot the Polarized Causal Graph on using Pyvis "Polarized Causal Graph.html" file

# %%
nt = Network("660px", "1515px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Polarized Causal Graph')

for dm,p,w in zip(dagCauseTriples, polarities,weights):
    #color = "#ffffff"
    nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_node(str(dm[2]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_edge(str(dm[0]),str(dm[2]),label=str(dm[1]) + " ("+str(p)+" "+str(w)+")", weight=10, physics='false',color='black')

#nt.show_buttons(filter_=['physics'])
nt.set_edge_smooth('discrete')
nt.show("./Pyvis Graph/Polarized Causal Graph.html")
# Out:
#         <iframe
#             width="1515px"
#             height="660px"
#             src="./Pyvis Graph/Polarized Causal Graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Compute CPs using CAST Logic

# %%
class Tutorial1:
    #def __init__(self):
    def Add(self, net, id ,name, outcomes, x_pos, y_pos):
        e = self.create_cpt_node(net, id, name, outcomes, x_pos, y_pos)
        #net.add_arc("Economy", "Forecast");
        #net.add_arc("Node0", "Node1");
        #nodeHandles.append(self.create_cpt_node(net, id, name, outcomes, x_pos, y_pos))
        nodeNames.append(net.get_node_name(e))
        nodeIds.append(net.get_node_id(e))
        nodeHandles.append(e)
        net.write_file("./GeNie CBN/CBN.xdsl")
        
    def AddArcs(self, net, s, d):
        net.add_arc(s, d)
        net.write_file("./GeNie CBN/CBN.xdsl")

    def Addcpts(self, net, h, cpt):
        net. set_node_definition(h, cpt)
        net.write_file("./GeNie CBN/CBN.xdsl")
        
    def create_cpt_node(self, net, id, name, outcomes, x_pos, y_pos):
        handle = net.add_node(pysmile.NodeType.CPT, id)
        net.set_node_name(handle, name)
        net.set_node_position(handle, x_pos, y_pos, 85, 55)
        initial_outcome_count = net.get_outcome_count(handle)
        for i in range(0, initial_outcome_count):
            net.set_outcome_id(handle, i, outcomes[i])
        for i in range(initial_outcome_count, len(outcomes)):
            net.add_outcome(handle, outcomes[i])
        return handle
    
    def print_cpt_matrix(self, net, node_handle):
        cpt = net.get_node_definition(node_handle)
        return cpt
    

net = pysmile.Network()
obj = Tutorial1()
outcomes = ["True","False"]
nodeNames = []    
nodeIds = []
nodeHandles = []
cpts=[]
baseline = 0.1
x = 160
y = 40

for node in cwg.nodes: 
    obj.Add(net, str(node),str(node), outcomes, x, y)
    #x = x + 100
    #y = y + 100
        
for e in cwg.edges():
    for id,name in zip(nodeIds,nodeNames):
        if name == e[0]:
            s = id
        if name == e[1]:
            d = id 
    obj.AddArcs(net, s, d)
    
for handle,name in zip(nodeHandles,nodeNames): 
    print("Handle:" + str(handle))
    print("Node:" + name)
    parent_ids = net.get_parent_ids(handle)
    num_parents = len(parent_ids)
    print("Number of Parents:" + str(num_parents))
    cpt = []
    parent_names = []
    totalCols = 1
    if num_parents == 0:
        cpt.append(baseline)
        cpt.append(1 - baseline)
        print("CPT:" + str(cpt))
        obj.Addcpts(net, handle, cpt)
        print("CPT from Network:")
        print(obj.print_cpt_matrix(net, handle))
        print("********************************************************************")
    elif num_parents > 0:
        for par in parent_ids:
                parent_names.append(net.get_node_name(par))
                #totalCols = totalCols * (num_parents * 2)
                totalCols = 2 ** num_parents
                #totalCols = totalCols + totalCols
        print("Names of Parents:" + str(parent_names))
        print("totalCols:" + str(totalCols))
        for j in range(0, totalCols):
            PI = 1
            NI = 1
            for parent,edge in zip(parent_names,cwg.edges(data=True)):
                if parent == edge[0] and name == edge[1]:
                    for nbr, eattr in edge[2].items():
                        if nbr == "weight":
                            #print(eattr)
                            #polarities.append(eattr)
                            polarity = eattr
            
                if polarity >= 0:
                    polarity = polarity/4
                    PI = PI * (1 - polarity)
                else:
                    polarity = polarity/ (-4)
                    NI = NI * (1 - polarity)
            PI = 1 - PI
            NI = 1 - NI
            AI = abs(PI - NI) / (1 - min(PI, NI))  
            CP = 0
            if PI > NI:
                CP = baseline + ((1 - baseline) * AI)
            elif PI < NI:
                CP = baseline - (baseline * AI)
            elif PI == NI:
                CP = baseline
            cpt.append(round(CP, 3))
            cpt.append(1 - round(CP, 3))
        print("CPT:" + str(cpt))
        obj.Addcpts(net, handle, cpt)
        print("CPT from Network:")
        print(obj.print_cpt_matrix(net, handle))
        print("********************************************************************")
# Out:
# Handle:0
# Node:institutional weakness
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:1
# Node:development
# Number of Parents:1
# Names of Parents:['institutional weakness']
# totalCols:2
# CPT:[0.0, 1.0, 0.0, 1.0]
# CPT from Network:
# [0.0, 1.0, 0.0, 1.0]
# ********************************************************************
# Handle:2
# Node:the agriculture sector
# Number of Parents:1
# Names of Parents:['institutional weakness']
# totalCols:2
# CPT:[0.325, 0.675, 0.156, 0.844]
# CPT from Network:
# [0.325, 0.675, 0.156, 0.844]
# ********************************************************************
# Handle:3
# Node:conflict
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:4
# Node:farmers
# Number of Parents:1
# Names of Parents:['conflict']
# totalCols:2
# CPT:[0.114, 0.886, 0.104, 0.896]
# CPT from Network:
# [0.114, 0.886, 0.104, 0.896]
# ********************************************************************
# Handle:5
# Node:production
# Number of Parents:1
# Names of Parents:['conflict']
# totalCols:2
# CPT:[0.101, 0.899, 0.1, 0.9]
# CPT from Network:
# [0.101, 0.899, 0.1, 0.9]
# ********************************************************************
# Handle:6
# Node:traders
# Number of Parents:1
# Names of Parents:['conflict']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:7
# Node:marketing infrastructure
# Number of Parents:1
# Names of Parents:['conflict']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:8
# Node:retailers
# Number of Parents:1
# Names of Parents:['conflict']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:9
# Node:no irrigation infrastructure
# Number of Parents:1
# Names of Parents:['the low level']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:10
# Node:public investment
# Number of Parents:2
# Names of Parents:['no irrigation infrastructure', 'the low level']
# totalCols:4
# CPT:[0.1, 0.9, 0.1, 0.9, 0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9, 0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:11
# Node:the low level
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:12
# Node:south sudan's limited road network
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:13
# Node:only 2 percent
# Number of Parents:1
# Names of Parents:["south sudan's limited road network"]
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:14
# Node:inadequate transportation infrastructure
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:15
# Node:markets
# Number of Parents:1
# Names of Parents:['inadequate transportation infrastructure']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:16
# Node:less transport
# Number of Parents:1
# Names of Parents:['inadequate transportation infrastructure']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:17
# Node:persistent heavy rains
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:18
# Node:flood-prone areas
# Number of Parents:1
# Names of Parents:['persistent heavy rains']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:19
# Node:the eastern sudan
# Number of Parents:1
# Names of Parents:['persistent heavy rains']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:20
# Node:rain
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:21
# Node:floods
# Number of Parents:1
# Names of Parents:['rain']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:22
# Node:more than 100,000 people
# Number of Parents:1
# Names of Parents:['floods']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:23
# Node:south sudan
# Number of Parents:1
# Names of Parents:['floods']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:24
# Node:fears
# Number of Parents:1
# Names of Parents:['floods']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:25
# Node:the war-torn nation
# Number of Parents:1
# Names of Parents:['floods']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:26
# Node:food security
# Number of Parents:1
# Names of Parents:['floods']
# totalCols:2
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
