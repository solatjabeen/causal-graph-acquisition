# %% [markdown]
# # Use kernel 'second' to execute this file
# # Import necessary libraries.

# %%
import spacy
import textacy
#import textacy.preprocessing
import textacy.resources
#import textacy.keyterms
#import textacy.ke
#import neuralcoref
from spacy.symbols import ORTH, POS, NOUN, VERB,PRON
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt 
import spacy
import textacy
from nltk import sent_tokenize, word_tokenize, pos_tag
nlp = spacy.load("en_core_web_sm")
# from allennlp_models.pretrained import load_predictor
# predictor1 = load_predictor("glove-sst")
import seaborn as sns
import pandas as pd
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from afinn import Afinn
afn = Afinn()
from pd_replicator import replicator
from nltk.corpus import stopwords
set(stopwords.words('english'))
from nltk.stem import PorterStemmer
ps = PorterStemmer()
from nltk.stem.wordnet import WordNetLemmatizer
lemma_function = WordNetLemmatizer()
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax
MODEL = f"cardiffnlp/twitter-xlm-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %% [markdown]
# # Read text file and preprocess.

# %%
file_name = './Text/Causal Sentences.txt'
narrative = open(file_name, encoding="utf8").read()
narrative = narrative.lower()

#print('\nNLTK Sentences:\n')
raw_sentences = sent_tokenize(str(narrative))
print(len(raw_sentences))
# for sent in raw_sentences:
#     print(sent)
#     print()
# Out:
# 380

# %% [markdown]
# # Extract the Subject-Verb-Object triples.

# %%
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
sub = ''
obj = ''
for sent in raw_sentences:
    sent = nlp(sent)
    #print("Sentence:")
    print(sent) 
    #print("Noun Chunks:")
    for nc in sent.noun_chunks:
        #print (nc)
        ncl.append(nc)
    #print ("Number of noun chunks: ", len(ncl)) 
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        #print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            #print("Triples other than textacy:")
            #print(nncl[0])
            #print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
    else:
        #print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                sub = token
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue           
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        #print("Triple by combining nsubj, root and dobj:")
        #print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                #print("Triples other than sub, verb and obj:")
                #print(nncl[0])
                #print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                #print("Triples other than sub, verb and obj:")
                #print(nncl[0])
                #print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
trips = finalList
print(trips)
# Out:
# the company modernized its technology.
# (the company, modernized, its technology)
# the singer released a single.
# (the singer, released, a single)
# the doctor saved a life.
# (the doctor, saved, a life)
# the farmer harvested the wheat.
# (the farmer, harvested, the wheat)
# the artist painted a landscape.
# (the artist, painted, a landscape)
# the dog chased its tail.
# (the dog, chased, its tail)
# the bird nested in the tree.
# the teacher planned the lesson.
# (the teacher, planned, the lesson)
# the child played with friends.
# the company invested in research.
# the band recorded a demo.
# (the band, recorded, a demo)
# the doctor referred the patient.
# (the doctor, referred, the patient)
# the engineer tested the prototype.
# (the engineer, tested, the prototype)
# the scientist published a paper.
# (the scientist, published, a paper)
# the worker installed the software.
# (the worker, installed, the software)
# the author wrote a poem.
# (the author, wrote, a poem)
# the player scored a hat trick.
# (the player, scored, hat trick)
# the photographer took a snapshot.
# (the photographer, took, a snapshot)
# the police officer solved the case.
# (police officer, solved, the case)
# the chef baked a cake.
# (the chef, baked, a cake)
# the musician wrote a score.
# (the musician, wrote, a score)
# the designer created a brand identity.
# (the designer, created, brand identity)
# the mail man jumped because the dog barked.
# the rain caused wilting of flowers.
# (the rain, caused, wilting)
# the sun rises in the east.
# the wind blew the leaves.
# (the wind, blew, the leaves)
# the dog bit the mailman.
# (the dog, bit, the mailman)
# the boy kicked the ball.
# (the boy, kicked, the ball)
# the girl sang a song.
# (the girl, sang, a song)
# the teacher graded the papers.
# (the teacher, graded, the papers)
# the car hit the tree.
# (the car, hit, the tree)
# the storm knocked down the power lines.
# (the storm, knocked, power lines)
# the baby cried for milk.
# the cook made dinner.
# (the cook, made, dinner)
# the student passed the exam.
# (the student, passed, the exam)
# the company launched a new product.
# (the company, launched, a new product)
# the singer performed on stage.
# the doctor prescribed medicine.
# (the doctor, prescribed, medicine)
# the farmer harvested the crops.
# (the farmer, harvested, the crops)
# the artist painted a picture.
# (the artist, painted, a picture)
# the dog chased the cat.
# (the dog, chased, the cat)
# the bird built a nest.
# (the bird, built, a nest)
# the teacher taught the lesson.
# (the teacher, taught, the lesson)
# the child played with the toy.
# the company released a statement.
# (the company, released, a statement)
# the band played a concert.
# (the band, played, a concert)
# the doctor examined the patient.
# (the doctor, examined, the patient)
# the engineer designed the bridge.
# (the engineer, designed, the bridge)
# the scientist conducted the experiment.
# (the scientist, conducted, the experiment)
# the worker assembled the machine.
# (the worker, assembled, the machine)
# the author wrote a novel.
# (the author, wrote, a novel)
# the player scored a goal.
# (the player, scored, a goal)
# the photographer took a picture.
# (the photographer, took, a picture)
# the police officer arrested the suspect.
# (police officer, arrested, the suspect)
# the chef cooked a meal.
# (the chef, cooked, a meal)
# the musician composed a song.
# (the musician, composed, a song)
# the designer created a website.
# (the designer, created, a website)
# the athlete won the race.
# (the athlete, won, the race)
# the businessman made a deal.
# (the businessman, made, a deal)
# the driver drove the car.
# (the driver, drove, the car)
# the writer wrote an article.
# (the writer, wrote, an article)
# the teacher gave a lecture.
# (the teacher, gave, a lecture)
# the student studied for the test.
# the company hired a new employee.
# (the company, hired, a new employee)
# the doctor treated the illness.
# (the doctor, treated, the illness)
# the artist sculpted a statue.
# (the artist, sculpted, a statue)
# the dog barked at the stranger.
# the bird flew in the sky.
# the teacher graded the quizzes.
# (the teacher, graded, the quizzes)
# the car broke down on the highway.
# the storm caused a flood.
# (the storm, caused, a flood)
# the baby slept through the night.
# the cook prepared the ingredients.
# (the cook, prepared, the ingredients)
# the student completed the assignment.
# (the student, completed, the assignment)
# the company expanded its market.
# (the company, expanded, its market)
# the singer recorded an album.
# (the singer, recorded, an album)
# the doctor performed surgery.
# (the doctor, performed, surgery)
# the farmer tended to the animals.
# the artist drew a portrait.
# (the artist, drew, a portrait)
# the dog fetched the ball.
# (the dog, fetched, the ball)
# the bird sang a melody.
# (the bird, sang, a melody)
# the teacher taught a class.
# (the teacher, taught, a class)
# the child learned how to read.
# (the child, learned, to read)
# the company released an update.
# (the company, released, an update)
# the band played a gig.
# (the band, played, a gig)
# the doctor diagnosed the illness.
# (the doctor, diagnosed, the illness)
# the engineer constructed the building.
# (the engineer, constructed, the building)
# the scientist discovered a new element.
# (the scientist, discovered, a new element)
# the worker repaired the equipment.
# (the worker, repaired, the equipment)
# the author wrote a short story.
# (the author, wrote, a short story)
# the player made a save.
# (the player, made, a save)
# the photographer captured a moment.
# (the photographer, captured, a moment)
# the police officer investigated the crime.
# (police officer, investigated, the crime)
# the chef served the meal.
# (the chef, served, the meal)
# the musician played an instrument.
# (the musician, played, an instrument)
# the designer created a logo.
# (the designer, created, a logo)
# the athlete trained for the competition.
# the businessman closed the deal.
# (the businessman, closed, the deal)
# the driver followed the map.
# (the driver, followed, the map)
# the writer wrote a story.
# (the writer, wrote, a story)
# the teacher gave a presentation.
# (the teacher, gave, a presentation)
# the student reviewed the material.
# (the student, reviewed, the material)
# zulfikar ali bhutto launched nuclear program.
# (zulfikar ali bhutto, launched, nuclear program)
# nuclear program declared pakistan's commitment and pakistan's dedication.
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# aq khan developed nuclear bomb.
# (aq khan, developed, nuclear bomb)
# nuclear bomb strengthened pakistan.
# (nuclear bomb, strengthened, pakistan)
# nuclear bomb makes nuclear power.
# (nuclear bomb, makes, nuclear power)
# pakistan must never surrender nuclear bomb.
# (pakistan, must never surrender, nuclear bomb)
# pakistan must fight off existential threats.
# (pakistan, must fight, existential threats)
# pakistan must support army and aq khan.
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# army provides vigilance.
# (army, provides, vigilance)
# vigilance strengthened national survival.
# (vigilance, strengthened, national survival)
# institutional weakness hindered development of the agriculture sector.
# (institutional weakness, hindered, development)
# conflict discourages farmers from expanding production.
# (conflict, discourages, farmers)
# conflict discourages traders from building marketing infrastructure.
# (conflict, discourages, traders)
# conflict discourages retailers from building marketing infrastructure.
# (conflict, discourages, retailers)
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# inadequate transportation infrastructure has resulted in less transport to markets.
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# (highly saturated soils, cause, flooding)
# rain caused floods.
# (rain, caused, floods)
# floods have displaced more than 100,000 people in south sudan's.
# (floods, have displaced, more than 100,000 people)
# floods raise fears.
# (floods, raise, fears)
# floods devastatingly impact on food security in the war-torn nation.
# excessive overthinking leads to insomnia.
# stress caused insomnia.
# (stress, caused, insomnia)
# insomnia causes stress.
# (insomnia, causes, stress)
# stress results in insomnia.
# stress results to insomnia.
# the heat melted the ice.
# (the heat, melted, the ice)
# the earthquake shook the ground.
# (the earthquake, shook, the ground)
# the manager's decision prompted changes.
# (the manager's decision, prompted, changes)
# the deforestation led to soil erosion.
# the argument provoked anger.
# (the argument, provoked, anger)
# the scent attracted bees to the flowers.
# (the scent, attracted, bees)
# the loud noise startled the birds.
# (the loud noise, startled, the birds)
# the pollution weakened the immune systems.
# (the pollution, weakened, the immune systems)
# the marathon exhausted the runners.
# (the marathon, exhausted, the runners)
# the chef's skills enhanced the flavor.
# (the chef's skills, enhanced, the flavor)
# the medication alleviated the pain.
# (the medication, alleviated, the pain)
# the construction blocked the usual route.
# (the construction, blocked, the usual route)
# the praise motivated the students.
# (the praise, motivated, the students)
# the excessive rain flooded the streets.
# (the excessive rain, flooded, the streets)
# the compliments boosted his confidence.
# (the compliments, boosted, his confidence)
# the faulty wiring sparked a fire.
# (the faulty wiring, sparked, a fire)
# the competition encouraged creativity.
# (the competition, encouraged, creativity)
# the workout strained his muscles.
# (the workout, strained, his muscles)
# the vandalism caused property damage.
# (the vandalism, caused, property damage)
# the disappointment dampened their spirits.
# (the disappointment, dampened, their spirits)
# the car crash injured the passengers.
# (car crash, injured, the passengers)
# the savings accumulated over time.
# the betrayal shattered their trust.
# (the betrayal, shattered, their trust)
# the scarcity of resources hindered progress.
# (the scarcity, hindered, progress)
# the investigation uncovered the truth.
# (the investigation, uncovered, the truth)
# the compromise resolved the conflict.
# (the compromise, resolved, the conflict)
# the technology revolutionized communication.
# (the technology, revolutionized, communication)
# the rumor spread panic among the crowd.
# (the rumor, spread, panic)
# the negotiations settled the dispute.
# (the negotiations, settled, the dispute)
# the success motivated her to pursue more.
# (the success, motivated, her)
# (the success, motivated, to pursue)
# the negligence resulted in a loss.
# the endorsement boosted sales.
# (the endorsement, boosted, sales)
# the excessive spending depleted their savings.
# (the excessive spending, depleted, their savings)
# the miscommunication caused confusion.
# (the miscommunication, caused, confusion)
# the endorsement amplified their popularity.
# (the endorsement, amplified, their popularity)
# the incentives encouraged higher productivity.
# (the incentives, encouraged, higher productivity)
# the promotion motivated employees.
# the charity's efforts alleviated suffering.
# (the charity's efforts, alleviated, suffering)
# the weather conditions impacted crop growth.
# (weather conditions, impacted, crop growth)
# the criticism demoralized the team.
# (the criticism, demoralized, the team)
# the software upgrade improved functionality.
# (the software, upgrade, improved functionality)
# the betrayal strained their relationship.
# (the betrayal, strained, their relationship)
# the applause energized the performer.
# (the applause, energized, the performer)
# the malfunction disrupted the event.
# (the malfunction, disrupted, the event)
# the scandal damaged his reputation.
# (the scandal, damaged, his reputation)
# the encouragement inspired her artwork.
# (the encouragement, inspired, her artwork)
# the neglect resulted in poor performance.
# the overtime work exhausted the staff.
# (overtime work, exhausted, the staff)
# the coaching refined their skills.
# (the coaching, refined, their skills)
# the cheating scandal tarnished the institution.
# (cheating scandal, tarnished, the institution)
# the consistent practice honed his abilities.
# (the consistent practice, honed, his abilities)
# the broken ladder caused the accident.
# (the broken ladder, caused, the accident)
# the intriguing plot captivated the readers.
# (the intriguing plot, captivated, the readers)
# the warm temperatures melted the snow quickly.
# (the warm temperatures, melted, the snow)
# the unexpected compliment brightened her day.
# the compromise reached a mutual agreement.
# (the compromise, reached, a mutual agreement)
# the frequent use wore out the machinery.
# (the frequent use, wore, the machinery)
# the challenging puzzle stimulated their minds.
# (the challenging puzzle, stimulated, their minds)
# the lack of maintenance resulted in decay.
# the passionate speech swayed the audience.
# (the passionate speech, swayed, the audience)
# the charity's efforts alleviated poverty.
# (the charity's efforts, alleviated, poverty)
# the economic downturn affected job opportunities.
# (the economic downturn, affected, job opportunities)
# the innovative idea revolutionized the industry.
# (the innovative idea, revolutionized, the industry)
# the rough terrain hindered their progress.
# (the rough terrain, hindered, their progress)
# the charismatic leader inspired the team.
# (the charismatic leader, inspired, the team)
# the excessive workload stressed the employees.
# (the excessive workload, stressed, the employees)
# the insightful observation deepened their understanding.
# (the insightful observation, deepened, their understanding)
# the faulty wiring triggered a series of problems.
# (the faulty wiring, triggered, a series)
# the infectious laughter cheered everyone up.
# (the infectious laughter, cheered, everyone)
# the poor nutrition impacted their health.
# (the poor nutrition, impacted, their health)
# the effective training improved their skills.
# (the effective training, improved, their skills)
# the harsh criticism demotivated the students.
# (the harsh criticism, demotivated, the students)
# the social media post sparked a controversy.
# (media post, sparked, a controversy)
# the genuine smile warmed their hearts.
# (the genuine smile, warmed, their hearts)
# the lack of sunlight stunted plant growth.
# the reckless driving caused the collision.
# (the reckless driving, caused, the collision)
# the dedication and practice led to success.
# the distant thunder signaled an approaching storm.
# (the distant thunder, signaled, an approaching storm)
# the unresolved issues strained their relationship.
# (the unresolved issues, strained, their relationship)
# the thorough research uncovered hidden truths.
# (the thorough research, uncovered, hidden truths)
# the wise advice guided his decision.
# (the wise advice, guided, his decision)
# the ongoing construction disrupted daily life.
# (the ongoing construction, disrupted, daily life)
# the repetitive tasks bored the employees.
# (the repetitive tasks, bored, the employees)
# the heavy rain resulted in flooding.
# the heartwarming story brought tears to their eyes.
# (heartwarming story, brought, tears)
# the efficient process saved time and resources.
# (the efficient process, saved, time)
# (the efficient process, saved, resources)
# the tight deadline pressured the team.
# (the tight deadline, pressured, the team)
# the poor communication led to misunderstandings.
# the unexpected bonus boosted their morale.
# (the unexpected bonus, boosted, their morale)
# the persistent effort yielded positive outcomes.
# (the persistent effort, yielded, positive outcomes)
# the unchecked pollution harmed the environment.
# (the unchecked pollution, harmed, the environment)
# the sharp decline in sales worried the company.
# (the sharp decline, worried, the company)
# the thorough planning averted potential issues.
# (the thorough planning, averted, potential issues)
# the strong winds damaged the roof.
# (the strong winds, damaged, the roof)
# the encouraging feedback motivated her to continue.
# the limited budget constrained their choices.
# (the limited budget, constrained, their choices)
# the urgent situation demanded quick action.
# (the urgent situation, demanded, quick action)
# the remarkable performance impressed the judges.
# (the remarkable performance, impressed, the judges)
# the controversial decision divided the community.
# (the controversial decision, divided, the community)
# the heartfelt apology mended their friendship.
# (the heartfelt apology, mended, their friendship)
# the antibiotic treatment cured the infection.
# (the antibiotic treatment, cured, the infection)
# the surgeon's expertise ensured a successful procedure.
# (the surgeon's expertise, ensured, a successful procedure)
# the lack of exercise contributed to weight gain.
# the timely intervention prevented further complications.
# (the timely intervention, prevented, further complications)
# the proper dosage of medication improved his condition.
# (the proper dosage, improved, his condition)
# the accurate diagnosis guided the treatment plan.
# (the accurate diagnosis, guided, treatment plan)
# the patient's allergies triggered an allergic reaction.
# (the patient's allergies, triggered, an allergic reaction)
# the consistent physical therapy aided in recovery.
# the immunization protected against contagious diseases.
# the healthy lifestyle choices promoted overall well-being.
# (lifestyle choices, promoted, overall well-being)
# the regular check-ups detected potential issues early.
# the advanced medical technology enhanced diagnosis accuracy.
# (the advanced medical technology, enhanced, diagnosis accuracy)
# the patient's adherence to medication improved outcomes.
# (the patient's adherence, improved, outcomes)
# the proper wound care minimized the risk of infection.
# (wound care, minimized, the risk)
# the medical research led to groundbreaking discoveries.
# the genetic predisposition increased the susceptibility.
# (the genetic predisposition, increased, the susceptibility)
# the medical staff's dedication provided quality care.
# (the medical staff's dedication, provided, quality care)
# the dietary restrictions managed his chronic condition.
# (the dietary restrictions, managed, his chronic condition)
# the rehabilitation program restored his mobility.
# (rehabilitation program, restored, his mobility)
# the side effects of chemotherapy weakened her immune system.
# (the side effects, weakened, her immune system)
# the organ transplant saved his life.
# (organ transplant, saved, his life)
# the mental health therapy helped manage anxiety.
# (health therapy, helped, manage)
# the effective pain management improved his comfort.
# (pain management, improved, his comfort)
# the radiologist's expertise ensured accurate imaging.
# (the radiologist's expertise, ensured, accurate imaging)
# the blood test results indicated a vitamin deficiency.
# (blood test results, indicated, vitamin deficiency)
# the medication regimen controlled his blood pressure.
# (medication regimen, controlled, blood pressure)
# the medical breakthrough offered hope for a cure.
# (the medical breakthrough, offered, hope)
# the occupational therapist aided in functional recovery.
# the proper wound dressing prevented complications.
# the medical team collaborated for optimal patient care.
# the heart monitor displayed irregular rhythms.
# (heart monitor, displayed, irregular rhythms)
# the surgeon's precision minimized scarring.
# the rehabilitation exercises strengthened his muscles.
# (rehabilitation exercises, strengthened, his muscles)
# the patient's medical history influenced the treatment approach.
# (the patient's medical history, influenced, treatment approach)
# the physical therapy sessions improved his range of motion.
# (therapy sessions, improved, his range)
# the accurate medical records facilitated proper diagnosis.
# (the accurate medical records, facilitated, proper diagnosis)
# the timely medical intervention saved her from a stroke.
# (the timely medical intervention, saved, her)
# the medication side effects caused drowsiness.
# (medication side effects, caused, drowsiness)
# the medical examination revealed underlying issues.
# (the medical examination, revealed, underlying issues)
# the preventive measures reduced the risk of infection.
# (the preventive measures, reduced, the risk)
# the pediatrician's guidance ensured proper child development.
# (the pediatrician's guidance, ensured, child development)
# the specialist's consultation provided expert insights.
# (the specialist's consultation, provided, expert insights)
# the pain management techniques alleviated discomfort.
# (management techniques, alleviated, discomfort)
# the diagnostic tests confirmed the presence of a tumor.
# (the diagnostic tests, confirmed, the presence)
# the vaccination schedule protected against communicable diseases.
# the health screening identified potential health risks.
# (health screening, identified, health risks)
# the intensive care unit monitored critically ill patients.
# (care unit, monitored, critically ill patients)
# the medical treatment plan addressed specific symptoms.
# (treatment plan, addressed, specific symptoms)
# the medical device monitored glucose levels.
# (the medical device, monitored, glucose levels)
# the surgical procedure required meticulous planning.
# (the surgical procedure, required, meticulous planning)
# the faulty wiring caused the electrical outage.
# (the faulty wiring, caused, the electrical outage)
# poor time management caused him to miss the deadline.
# (him, to miss, the deadline)
# excessive sugar consumption can cause tooth decay.
# (sugar consumption, can cause, tooth decay)
# the lack of exercise caused weight gain.
# (the lack, caused, weight gain)
# neglecting regular maintenance can cause machinery breakdowns.
# (neglecting, can cause, machinery breakdowns)
# the car accident caused a major traffic jam.
# (car accident, caused, traffic jam)
# his careless actions caused the glass to shatter.
# skipping breakfast can cause low energy levels throughout the day.
# (skipping breakfast, can cause, energy levels)
# the allergen exposure caused a severe allergic reaction.
# (allergen exposure, caused, a severe allergic reaction)
# overuse of electronic devices can cause eye strain.
# (overuse, can cause, eye strain)
# the earthquake caused buildings to collapse.
# stress can cause a variety of health issues.
# (stress, can cause, a variety)
# the absence of sunlight can cause vitamin d deficiency.
# (the absence, can cause, d deficiency)
# his rude behavior caused offense to others.
# (his rude behavior, caused, offense)
# (his rude behavior, caused, to)
# lack of proper ventilation can cause indoor air pollution.
# (lack, can cause, air pollution)
# the strong winds caused tree branches to fall.
# smoking can cause respiratory problems.
# (smoking, can cause, respiratory problems)
# the inadequate drainage system caused flooding in the streets.
# (drainage system, caused, flooding)
# failing to follow instructions can cause errors in the final product.
# (failing, can cause, errors)
# the high humidity levels caused mold growth in the basement.
# (humidity levels, caused, mold growth)
# the excessive noise from construction caused sleep disturbances.
# (the excessive noise, caused, sleep disturbances)
# ignoring warning signs can cause accidents.
# (ignoring, can cause, accidents)
# the absence of rain caused drought conditions.
# (the absence, caused, drought conditions)
# the wrong dosage of medication can cause adverse effects.
# (the wrong dosage, can cause, adverse effects)
# poor communication can cause misunderstandings.
# (poor communication, can cause, misunderstandings)
# the malfunctioning thermostat caused temperature fluctuations.
# (the malfunctioning thermostat, caused, temperature fluctuations)
# improper handling of chemicals can cause hazardous reactions.
# (improper handling, can cause, hazardous reactions)
# the scarcity of resources can cause conflicts.
# (the scarcity, can cause, conflicts)
# the intense workout caused muscle soreness.
# (the intense workout, caused, muscle soreness)
# the misalignment of gears caused the machine to malfunction.
# (the misalignment, caused, the machine)
# overexposure to the sun can cause sunburn.
# (overexposure, can cause, sunburn)
# the incorrect password entry caused account lockout.
# (password entry, caused, account lockout)
# the polluted water source caused widespread illness.
# (water source, caused, widespread illness)
# the inadequate insulation caused heat loss from the building.
# (the inadequate insulation, caused, heat loss)
# neglecting regular check-ups can cause undetected health problems.
# (neglecting, can cause, health problems)
# the absence of parental guidance can cause behavioral issues in children.
# (the absence, can cause, behavioral issues)
# the absence of rain caused crop failure.
# (the absence, caused, crop failure)
# the excessive use of pesticides can cause harm to the environment.
# (the excessive use, can cause, harm)
# poor circulation can cause numbness in extremities.
# (poor circulation, can cause, numbness)
# the faulty brake system caused the car to skid.
# the financial crisis caused a decline in the housing market.
# (the financial crisis, caused, a decline)
# the lack of sleep can cause impaired cognitive function.
# (the lack, can cause, impaired cognitive function)
# the absence of proper sanitation can cause the spread of diseases.
# (the absence, can cause, the spread)
# the sudden change in temperature caused pipes to burst.
# the misuse of antibiotics can cause antibiotic resistance.
# (the misuse, can cause, antibiotic resistance)
# the aggressive driving behavior caused road rage.
# (driving behavior, caused, road rage)
# the misinterpretation of data can cause incorrect conclusions.
# (the misinterpretation, can cause, incorrect conclusions)
# the reduction in funding caused program cutbacks.
# (the reduction, caused, program cutbacks)
# the inadequate training can cause employees to make mistakes.
# (employees, to make, mistakes)
# the absence of parental support can cause poor academic performance.
# (the absence, can cause, poor academic performance)
# the excessive screen time caused digital eye strain.
# the lack of coordination among team members caused project delays.
# (the lack, caused, project delays)
# the improper storage of food can cause bacterial contamination.
# (the improper storage, can cause, bacterial contamination)
# the defective valve caused water leakage in the pipes.
# (the defective valve, caused, water leakage)
# the absence of exercise can cause a decline in cardiovascular health.
# (the absence, can cause, a decline)
# the irresponsible behavior of the driver caused a traffic accident.
# (the irresponsible behavior, caused, traffic accident)
# the absence of proper maintenance can cause equipment breakdowns.
# (the absence, can cause, equipment breakdowns)
# the constant exposure to loud noise can cause hearing loss.
# (the constant exposure, can cause, hearing)
# the misinformation spread on social media can cause panic.
# the excessive consumption of sugary foods can cause obesity.
# (the excessive consumption, can cause, obesity)
# the lack of insulation in the walls can cause heat loss.
# (the lack, can cause, heat loss)
# the increased pollution levels can cause respiratory problems.
# (pollution levels, can cause, respiratory problems)
# the neglect of oral hygiene can cause dental issues.
# (the neglect, can cause, dental issues)
# the misunderstanding of instructions can cause errors in assembly.
# (the misunderstanding, can cause, errors)
# the absence of clear guidelines can cause confusion.
# (the absence, can cause, confusion)
# the sudden shift in market demand caused supply chain disruptions.
# (the sudden shift, caused, chain disruptions)
# the lack of empathy can cause strained relationships.
# (the lack, can cause, strained relationships)
# the illegal logging in the forest caused environmental degradation.
# (the illegal logging, caused, environmental degradation)
# the poor drainage system caused waterlogging in the streets.
# (drainage system, caused, waterlogging)
# the lack of financial planning can cause debt accumulation.
# (the lack, can cause, debt accumulation)
# the inadequate security measures can cause data breaches.
# (security measures, can cause, data breaches)
# the excessive use of electronic devices can cause sleep disturbances.
# (the excessive use, can cause, sleep disturbances)
# the absence of streetlights can cause unsafe neighborhoods.
# (the absence, can cause, unsafe neighborhoods)
# the unchecked spread of rumors can cause reputational damage.
# (the unchecked spread, can cause, reputational damage)
# the poor road conditions can cause vehicle damage.
# (road conditions, can cause, vehicle damage)
# the irregular eating habits can cause digestive issues.
# (eating habits, can cause, digestive issues)
# the lack of proper sanitation facilities can cause unsanitary conditions.
# (the lack, can cause, unsanitary conditions)
# the heavy rainfall caused landslides in the hilly areas.
# (the heavy rainfall, caused, landslides)
# the lack of insect repellent can cause mosquito bites.
# (the lack, can cause, mosquito bites)
# the absence of proper training can cause inefficiencies in the workplace.
# (the absence, can cause, inefficiencies)
# the exposure to harmful chemicals can cause skin irritation.
# (the exposure, can cause, skin irritation)
# the fluctuating exchange rates can cause economic instability.
# (exchange rates, can cause, economic instability)
# the absence of proper documentation can cause delays in processing.
# (the absence, can cause, delays)
# the unregulated use of pesticides can cause harm to beneficial insects.
# (the unregulated use, can cause, harm)
# the absence of fire safety measures can cause serious accidents.
# (the absence, can cause, serious accidents)
# the absence of parental supervision can cause risky behavior in teenagers.
# (the absence, can cause, risky behavior)
# the excessive use of antibiotics can cause disruption of gut bacteria.
# (the excessive use, can cause, disruption)
# the poor air quality caused respiratory problems for residents.
# (air quality, caused, respiratory problems)
# the lack of diversity can cause a stagnant work environment.
# (the lack, can cause, work environment)
# the sudden power outage caused disruption in communication.
# (power outage, caused, disruption)
# the absence of proper maintenance can cause elevator breakdowns.
# (the absence, can cause, elevator breakdowns)
# the lack of physical activity can cause a sedentary lifestyle.
# (the lack, can cause, a sedentary lifestyle)
# the lack of transparency in decision-making can cause distrust.
# (the lack, can cause, distrust)
# the excessive sugar intake can cause insulin resistance.
# (sugar intake, can cause, insulin resistance)
# the absence of green spaces can cause stress in urban areas.
# (the absence, can cause, stress)
# the incorrect calibration of instruments can cause measurement errors.
# (the incorrect calibration, can cause, measurement errors)
# the improper disposal of waste can cause environmental pollution.
# (the improper disposal, can cause, environmental pollution)
# the absence of routine medical check-ups can cause undiagnosed health issues.
# (the absence, can cause, health issues)
# the lack of empathy in leadership can cause employee dissatisfaction.
# (the lack, can cause, employee dissatisfaction)
# the absence of seat belts can cause serious injuries in car accidents.
# (the absence, can cause, serious injuries)
# [(the company, modernized, its technology), (the singer, released, a single), (the doctor, saved, a life), (the farmer, harvested, the wheat), (the artist, painted, a landscape), (the dog, chased, its tail), (the bird, nested, the tree), (the teacher, planned, the lesson), (the child, played, friends), (the company, invested, research), (the band, recorded, a demo), (the doctor, referred, the patient), (the engineer, tested, the prototype), (the scientist, published, a paper), (the worker, installed, the software), (the author, wrote, a poem), (the player, scored, hat trick), (the photographer, took, a snapshot), (police officer, solved, the case), (the chef, baked, a cake), (the musician, wrote, a score), (the designer, created, brand identity), (the dog, jumped, research), (the rain, caused, wilting), (the rain, caused, wilting), (the rain, caused, flowers), (the sun, rises, the east), (the wind, blew, the leaves), (the dog, bit, the mailman), (the boy, kicked, the ball), (the girl, sang, a song), (the teacher, graded, the papers), (the car, hit, the tree), (the storm, knocked, power lines), (the baby, cried, milk), (the cook, made, dinner), (the student, passed, the exam), (the company, launched, a new product), (the singer, performed, stage), (the doctor, prescribed, medicine), (the farmer, harvested, the crops), (the artist, painted, a picture), (the dog, chased, the cat), (the bird, built, a nest), (the teacher, taught, the lesson), (the child, played, the toy), (the company, released, a statement), (the band, played, a concert), (the doctor, examined, the patient), (the engineer, designed, the bridge), (the scientist, conducted, the experiment), (the worker, assembled, the machine), (the author, wrote, a novel), (the player, scored, a goal), (the photographer, took, a picture), (police officer, arrested, the suspect), (the chef, cooked, a meal), (the musician, composed, a song), (the designer, created, a website), (the athlete, won, the race), (the businessman, made, a deal), (the driver, drove, the car), (the writer, wrote, an article), (the teacher, gave, a lecture), (the student, studied, the test), (the company, hired, a new employee), (the doctor, treated, the illness), (the artist, sculpted, a statue), (the dog, barked, the stranger), (the bird, flew, the sky), (the teacher, graded, the quizzes), (the car, broke, the highway), (the storm, caused, a flood), (the baby, slept, the night), (the cook, prepared, the ingredients), (the student, completed, the assignment), (the company, expanded, its market), (the singer, recorded, an album), (the doctor, performed, surgery), (the farmer, tended, the animals), (the artist, drew, a portrait), (the dog, fetched, the ball), (the bird, sang, a melody), (the teacher, taught, a class), (the child, learned, to read), (the company, released, an update), (the band, played, a gig), (the doctor, diagnosed, the illness), (the engineer, constructed, the building), (the scientist, discovered, a new element), (the worker, repaired, the equipment), (the author, wrote, a short story), (the player, made, a save), (the photographer, captured, a moment), (police officer, investigated, the crime), (the chef, served, the meal), (the musician, played, an instrument), (the designer, created, a logo), (the athlete, trained, the competition), (the businessman, closed, the deal), (the driver, followed, the map), (the writer, wrote, a story), (the teacher, gave, a presentation), (the student, reviewed, the material), (zulfikar ali bhutto, launched, nuclear program), (nuclear program, declared, pakistan's commitment), (nuclear program, declared, pakistan's dedication), (nuclear program, declared, pakistan's commitment), (nuclear program, declared, pakistan's dedication), (aq khan, developed, nuclear bomb), (nuclear bomb, strengthened, pakistan), (nuclear bomb, makes, nuclear power), (pakistan, must never surrender, nuclear bomb), (pakistan, must fight, existential threats), (pakistan, must support, a ...

# %% [markdown]
# # Remove Duplicates from Triples

# %%
print("Length of triples' List before removing duplicates:")
print(len(trips))

Triples = []
sentences1 = []

for sentence,ce in zip(sentences, trips):
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        sentences1.append(sentence)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            sentences1.append(sentence)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

#for t in Triples:
#    print(t)
    
#print(len(sentences1))
# Out:
# Length of triples' List before removing duplicates:
# 561
#
# List after removing duplicates:
# 487

# %% [markdown]
# # Filter correct triples from extracted triples

# %%
causalTriples = []
causalSentences = []

for sentence,line in zip(sentences1, Triples):
    taggedWords = []
    taggedWords1 = []
    check0 = False
    check2 = False
    #print(line)
    taggedWords = pos_tag(word_tokenize(str(line[0])))
    taggedWords1 = pos_tag(word_tokenize(str(line[2])))
    #print(taggedWords)
    #print(taggedWords1)
    for i in range(len(taggedWords)):
        if taggedWords[i][1] == 'NN' or taggedWords[i][1] == 'NNS':
            check0 = True
    for i in range(len(taggedWords1)):
        if taggedWords1[i][1] == 'NN' or taggedWords1[i][1] == 'NNS':
            check2 = True
    #print(check0)  
    #print(check2)
    if check0 == True and check2 == True:
        causalTriples.append(line)
        causalSentences.append(sentence)
    #print("**************************************************************************")
    
#for correctTriple in causalTriples:
#    print(correctTriple)

print(len(causalTriples))
# Out:
# 466

# %% [markdown]
# # Print the extracted triples with sentences and verbs

# %%
causalVerbs = []
for triple in causalTriples:
    causalVerbs.append(triple[1])

for sentence, triple, verb  in zip(causalSentences, causalTriples, causalVerbs):
    print(sentence, triple, verb)
    print()
# Out:
# the company modernized its technology. (the company, modernized, its technology) modernized
#
# the doctor saved a life. (the doctor, saved, a life) saved
#
# the farmer harvested the wheat. (the farmer, harvested, the wheat) harvested
#
# the artist painted a landscape. (the artist, painted, a landscape) painted
#
# the dog chased its tail. (the dog, chased, its tail) chased
#
# the bird nested in the tree. (the bird, nested, the tree) nested
#
# the teacher planned the lesson. (the teacher, planned, the lesson) planned
#
# the child played with friends. (the child, played, friends) played
#
# the company invested in research. (the company, invested, research) invested
#
# the band recorded a demo. (the band, recorded, a demo) recorded
#
# the doctor referred the patient. (the doctor, referred, the patient) referred
#
# the engineer tested the prototype. (the engineer, tested, the prototype) tested
#
# the scientist published a paper. (the scientist, published, a paper) published
#
# the worker installed the software. (the worker, installed, the software) installed
#
# the author wrote a poem. (the author, wrote, a poem) wrote
#
# the player scored a hat trick. (the player, scored, hat trick) scored
#
# the photographer took a snapshot. (the photographer, took, a snapshot) took
#
# the police officer solved the case. (police officer, solved, the case) solved
#
# the chef baked a cake. (the chef, baked, a cake) baked
#
# the musician wrote a score. (the musician, wrote, a score) wrote
#
# the designer created a brand identity. (the designer, created, brand identity) created
#
# the mail man jumped because the dog barked. (the dog, jumped, research) jumped
#
# the rain caused wilting of flowers. (the rain, caused, flowers) caused
#
# the sun rises in the east. (the sun, rises, the east) rises
#
# the wind blew the leaves. (the wind, blew, the leaves) blew
#
# the dog bit the mailman. (the dog, bit, the mailman) bit
#
# the boy kicked the ball. (the boy, kicked, the ball) kicked
#
# the girl sang a song. (the girl, sang, a song) sang
#
# the teacher graded the papers. (the teacher, graded, the papers) graded
#
# the car hit the tree. (the car, hit, the tree) hit
#
# the storm knocked down the power lines. (the storm, knocked, power lines) knocked
#
# the baby cried for milk. (the baby, cried, milk) cried
#
# the cook made dinner. (the cook, made, dinner) made
#
# the student passed the exam. (the student, passed, the exam) passed
#
# the company launched a new product. (the company, launched, a new product) launched
#
# the singer performed on stage. (the singer, performed, stage) performed
#
# the doctor prescribed medicine. (the doctor, prescribed, medicine) prescribed
#
# the farmer harvested the crops. (the farmer, harvested, the crops) harvested
#
# the artist painted a picture. (the artist, painted, a picture) painted
#
# the dog chased the cat. (the dog, chased, the cat) chased
#
# the bird built a nest. (the bird, built, a nest) built
#
# the teacher taught the lesson. (the teacher, taught, the lesson) taught
#
# the child played with the toy. (the child, played, the toy) played
#
# the company released a statement. (the company, released, a statement) released
#
# the band played a concert. (the band, played, a concert) played
#
# the doctor examined the patient. (the doctor, examined, the patient) examined
#
# the engineer designed the bridge. (the engineer, designed, the bridge) designed
#
# the scientist conducted the experiment. (the scientist, conducted, the experiment) conducted
#
# the worker assembled the machine. (the worker, assembled, the machine) assembled
#
# the author wrote a novel. (the author, wrote, a novel) wrote
#
# the player scored a goal. (the player, scored, a goal) scored
#
# the photographer took a picture. (the photographer, took, a picture) took
#
# the police officer arrested the suspect. (police officer, arrested, the suspect) arrested
#
# the chef cooked a meal. (the chef, cooked, a meal) cooked
#
# the musician composed a song. (the musician, composed, a song) composed
#
# the designer created a website. (the designer, created, a website) created
#
# the athlete won the race. (the athlete, won, the race) won
#
# the businessman made a deal. (the businessman, made, a deal) made
#
# the driver drove the car. (the driver, drove, the car) drove
#
# the writer wrote an article. (the writer, wrote, an article) wrote
#
# the teacher gave a lecture. (the teacher, gave, a lecture) gave
#
# the student studied for the test. (the student, studied, the test) studied
#
# the company hired a new employee. (the company, hired, a new employee) hired
#
# the doctor treated the illness. (the doctor, treated, the illness) treated
#
# the artist sculpted a statue. (the artist, sculpted, a statue) sculpted
#
# the dog barked at the stranger. (the dog, barked, the stranger) barked
#
# the bird flew in the sky. (the bird, flew, the sky) flew
#
# the teacher graded the quizzes. (the teacher, graded, the quizzes) graded
#
# the car broke down on the highway. (the car, broke, the highway) broke
#
# the storm caused a flood. (the storm, caused, a flood) caused
#
# the baby slept through the night. (the baby, slept, the night) slept
#
# the cook prepared the ingredients. (the cook, prepared, the ingredients) prepared
#
# the student completed the assignment. (the student, completed, the assignment) completed
#
# the company expanded its market. (the company, expanded, its market) expanded
#
# the singer recorded an album. (the singer, recorded, an album) recorded
#
# the doctor performed surgery. (the doctor, performed, surgery) performed
#
# the farmer tended to the animals. (the farmer, tended, the animals) tended
#
# the artist drew a portrait. (the artist, drew, a portrait) drew
#
# the dog fetched the ball. (the dog, fetched, the ball) fetched
#
# the bird sang a melody. (the bird, sang, a melody) sang
#
# the teacher taught a class. (the teacher, taught, a class) taught
#
# the company released an update. (the company, released, an update) released
#
# the band played a gig. (the band, played, a gig) played
#
# the doctor diagnosed the illness. (the doctor, diagnosed, the illness) diagnosed
#
# the engineer constructed the building. (the engineer, constructed, the building) constructed
#
# the scientist discovered a new element. (the scientist, discovered, a new element) discovered
#
# the worker repaired the equipment. (the worker, repaired, the equipment) repaired
#
# the author wrote a short story. (the author, wrote, a short story) wrote
#
# the player made a save. (the player, made, a save) made
#
# the photographer captured a moment. (the photographer, captured, a moment) captured
#
# the police officer investigated the crime. (police officer, investigated, the crime) investigated
#
# the chef served the meal. (the chef, served, the meal) served
#
# the musician played an instrument. (the musician, played, an instrument) played
#
# the designer created a logo. (the designer, created, a logo) created
#
# the athlete trained for the competition. (the athlete, trained, the competition) trained
#
# the businessman closed the deal. (the businessman, closed, the deal) closed
#
# the driver followed the map. (the driver, followed, the map) followed
#
# the writer wrote a story. (the writer, wrote, a story) wrote
#
# the teacher gave a presentation. (the teacher, gave, a presentation) gave
#
# the student reviewed the material. (the student, reviewed, the material) reviewed
#
# zulfikar ali bhutto launched nuclear program. (zulfikar ali bhutto, launched, nuclear program) launched
#
# nuclear program declared pakistan's commitment and pakistan's dedication. (nuclear program, declared, pakistan's commitment) declared
#
# nuclear program declared pakistan's commitment and pakistan's dedication. (nuclear program, declared, pakistan's dedication) declared
#
# aq khan developed nuclear bomb. (aq khan, developed, nuclear bomb) developed
#
# nuclear bomb strengthened pakistan. (nuclear bomb, strengthened, pakistan) strengthened
#
# nuclear bomb makes nuclear power. (nuclear bomb, makes, nuclear power) makes
#
# pakistan must never surrender nuclear bomb. (pakistan, must never surrender, nuclear bomb) must never surrender
#
# pakistan must fight off existential threats. (pakistan, must fight, existential threats) must fight
#
# pakistan must support army and aq khan. (pakistan, must support, army) must support
#
# pakistan must support army and aq khan. (pakistan, must support, aq khan) must support
#
# army provides vigilance. (army, provides, vigilance) provides
#
# vigilance strengthened national survival. (vigilance, strengthened, national survival) strengthened
#
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development) hindered
#
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector) hindered
#
# conflict discourages farmers from expanding production. (conflict, discourages, farmers) discourages
#
# conflict discourages farmers from expanding production. (conflict, discourages, production) discourages
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders) discourages
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure) discourages
#
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers) discourages
#
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment) shows
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment) shows
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure) shows
#
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent) shows
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets) resulted
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport) resulted
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas) cause
#
# rain caused floods. (rain, caused, floods) caused
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, more than 100,000 people) have displaced
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, south sudan) have displaced
#
# floods raise fears. (floods, raise, fears) raise
#
# floods devastatingly impact on food security in the war-torn nation. (floods, impact, the war-torn nation) impact
#
# floods devastatingly impact on food security in the war-torn nation. (floods, impact, food security) impact
#
# excessive overthinking leads to insomnia. (excessive overthinking, leads, insomnia) leads
#
# stress caused insomnia. (stress, caused, insomnia) caused
#
# insomnia causes stress. (insomnia, causes, stress) causes
#
# stress results in insomnia. (stress, results, insomnia) results
#
# the heat melted the ice. (the heat, melted, the ice) melted
#
# the earthquake shook the ground. (the earthquake, shook, the ground) shook
#
# the manager's decision prompted changes. (the manager's decision, prompted, changes) prompted
#
# the deforestation led to soil erosion. (the deforestation, led, soil erosion) led
#
# the argument provoked anger. (the argument, provoked, anger) provoked
#
# the scent attracted bees to the flowers. (the scent, attracted, bees) attracted
#
# the scent attracted bees to the flowers. (the scent, attracted, the flowers) attracted
#
# the loud noise startled the birds. (the loud noise, startled, the birds) startled
#
# the pollution weakened the immune systems. (the pollution, weakened, the immune systems) weakened
#
# the marathon exhausted the runners. (the marathon, exhausted, the runners) exhausted
#
# the chef's skills enhanced the flavor. (the chef's skills, enhanced, the flavor) enhanced
#
# the medication alleviated the pain. (the medication, alleviated, the pain) alleviated
#
# the construction blocked the usual route. (the construction, blocked, the usual route) blocked
#
# the praise motivated the students. (the praise, motivated, the students) motivated
#
# the excessive rain flooded the streets. (the excessive rain, flooded, the streets) flooded
#
# the compliments boosted his confidence. (the compliments, boosted, his confidence) boosted
#
# the faulty wiring sparked a fire. (the faulty wiring, sparked, a fire) sparked
#
# the competition encouraged creativity. (the competition, encouraged, creativity) encouraged
#
# the workout strained his muscles. (the workout, strained, his muscles) strained
#
# the vandalism caused property damage. (the vandalism, caused, property damage) caused
#
# the disappointment dampened their spirits. (the disappointment, dampened, their spirits) dampened
#
# the car crash injured the passengers. (car crash, injured, the passengers) injured
#
# the savings accumulated over time. (the savings, accumulated, time) accumulated
#
# the betrayal shattered their trust. (the betrayal, shattered, their trust) shattered
#
# the scarcity of resources hindered progress. (the scarcity, hindered, progress) hindered
#
# the scarcity of resources hindered progress. (the scarcity, hindered, resources) hindered
#
# the investigation uncovered the truth. (the investigation, uncovered, the truth) uncovered
#
# the compromise resolved the conflict. (the compromise, resolved, the conflict) resolved
#
# the technology revolutionized communication. (the technology, revolutionized, communication) revolutionized
#
# the rumor spread panic among the crowd. (the rumor, spread, panic) spread
#
# the rumor spread panic among the crowd. (the rumor, spread, the crowd) spread
#
# the negotiations settled the dispute. (the negotiations, settled, the dispute) settled
#
# the negligence resulted in a loss. (the negligence, resulted, a loss) resulted
#
# the endorsement boosted sales. (the endorsement, boosted, sales) boosted
#
# the excessive spending depleted their savings. (the excessive spending, depleted, their savings) depleted
#
# the miscommunication caused confusion. (the miscommunication, caused, confusion) caused
#
# the endorsement amplified their popularity. (the endorsement, amplified, their popularity) amplified
#
# the incentives encouraged higher productivity. (the incentives, encouraged, higher productivity) encouraged
#
# the promotion motivated employees. (the negligence, employees, a loss) employees
#
# the weather conditions impacted crop growth. (weather conditions, impacted, crop growth) impacted
#
# the criticism demoralized the team. (the criticism, demoralized, the team) demoralized
#
# the software upgrade improved functionality. (the software, upgrade, improved functionality) upgrade
#
# the betrayal strained their relationship. (the betrayal, strained, their relationship) strained
#
# the applause energized the performer. (the applause, energized, the performer) energized
#
# the malfunction disrupted the event. (the malfunction, disrupted, the event) disrupted
#
# the scandal damaged his reputation. (the scandal, damaged, his reputation) damaged
#
# the encouragement inspired her artwork. (the encouragement, inspired, her artwork) inspired
#
# the neglect resulted in poor performance. (the neglect, resulted, poor performance) resulted
#
# the overtime work exhausted the staff. (overtime work, exhausted, the staff) exhausted
#
# the coaching refined their skills. (the coaching, refined, their skills) refined
#
# the cheating scandal tarnished the institution. (cheating scandal, tarnished, the institution) tarnished
#
# the consistent practice honed his abilities. (the consistent practice, honed, his abilities) honed
#
# the broken ladder caused the accident. (the broken ladder, caused, the accident) caused
#
# the intriguing plot captivated the readers. (the intriguing plot, captivated, the readers) captivated
#
# the warm temperatures melted the snow quickly. (the warm temperatures, melted, the snow) melted
#
# the unexpected compliment brightened her day. (the unexpected compliment, brightened, poor performance) brightened
#
# the compromise reached a mutual agreement. (the compromise, reached, a mutual agreement) reached
#
# the frequent use wore out the machinery. (the frequent use, wore, the machinery) wore
#
# the challenging puzzle stimulated their minds. (the challenging puzzle, stimulated, their minds) stimulated
#
# the lack of maintenance resulted in decay. (the lack, resulted, decay) resulted
#
# the lack of maintenance resulted in decay. (the lack, resulted, maintenance) resulted
#
# the passionate speech swayed the audience. (the passionate speech, swayed, the audience) swayed
#
# the charity's efforts alleviated poverty. (the charity's efforts, alleviated, poverty) alleviated
#
# the economic downturn affected job opportunities. (the economic downturn, affected, job opportunities) affected
#
# the innovative idea revolutionized the industry. (the innovative idea, revolutionized, the industry) revolutionized
#
# the rough terrain hindered their progress. (the rough terrain, hindered, their progress) hindered
#
# the charismatic leader inspired the team. (the charismatic leader, inspired, the team) inspired
#
# the excessive workload stressed the employees. (the excessive workload, stressed, the employees) stressed
#
# the insightful observation deepened their understanding. (the insightful observation, deepened, their understanding) deepened
#
# the faulty wiring triggered a series of problems. (the faulty wiring, triggered, a series) triggered
#
# the faulty wiring triggered a series of problems. (the faulty wiring, triggered, problems) triggered
#
# the infectious laughter cheered everyone up. (the infectious laughter, cheered, everyone) cheered
#
# the poor nutrition impacted their health. (the poor nutrition, impacted, their health) impacted
#
# the effective training improved their skills. (the effective training, improved, their skills) improved
#
# the harsh criticism demotivated the students. (the harsh criticism, demotivated, the students) demotivated
#
# the social media post sparked a controversy. (media post, sparked, a controversy) sparked
#
# the genuine smile warmed their hearts. (the genuine smile, warmed, their hearts) warmed
#
# the lack of sunlight stunted plant growth. (the lack, lack, sunlight stunted plant growth) lack
#
# the reckless driving caused the collision. (the reckless driving, caused, the collision) caused
#
# the dedication and practice led to success. (the dedication, led, success) led
#
# the dedication and practice led to success. (practice, led, success) led
#
# the distant thunder signaled an approaching storm. (the distant thunder, signaled, an approaching storm) signaled
#
# the unresolved issues strained their relationship. (the unresolved issues, strained, their relationship) strained
#
# the thorough research uncovered hidden truths. (the thorough research, uncovered, hidden truths) uncovered
#
# the wise advice guided his decision. (the wise advice, guided, his decision) guided
#
# the ongoing construction disrupted daily life. (the ongoing construction, disrupted, daily life) disrupted
#
# the repetitive tasks bored the employees. (the repetitive tasks, bored, the employees) bored
#
# the heartwarming story brought tears to their eyes. (heartwarming story, brought, tears) brought
#
# the heartwarming story brought tears to their eyes. (the heartwarming story, brought, tears) brought
#
# the heartwarming story brought tears to their eyes. (the heartwarming story, brought, their eyes) brought
#
# the efficient process saved time and resources. (the efficient process, saved, time) saved
#
# the efficient process saved time and resources. (the efficient process, saved, resources) saved
#
# the tight deadline pressured the team. (the tight deadline, pressured, the team) pressured
#
# the poor communication led to misunderstandings. (the poor communication, led, misunderstandings) led
#
# the unexpected bonus boosted their morale. (the unexpected bonus, boosted, their morale) boosted
#
# the persistent effort yielded positive outcomes. (the persistent effort, yielded, positive outcomes) yielded
#
# the unchecked pollution harmed the environment. (the unchecked pollution, harmed, the environment) harmed
#
# the sharp decline in sales worried the company. (the sharp decline, worried, the company) worried
#
# the sharp decline in sales worried the company. (the sharp decline, worried, sales) worried
#
# the thorough planning averted potential issues. (the thorough planning, averted, potential issues) averted
#
# the strong winds damaged the roof. (the strong winds, damaged, the roof) damaged
#
# the limited budget constrained their choices. (the limited budget, constrained, their choices) constrained
#
# the urgent situation demanded quick action. (the urgent situation, demanded, quick action) demanded
#
# the remarkable performance impressed the judges. (the remarkable performance, impressed, the judges) impressed
#
# the controversial decision divided the community. (the controversial decision, divided, the community) divided
#
# the heartfelt apology mended their friendship. (the heartfelt apology, mended, their friendship) mended
#
# the antibiotic treatment cured the infection. (the antibiotic treatment, cured, the infection) cured
#
# the surgeon's expertise ensured a successful procedure. (the surgeon's expertise, ensured, a successful procedure) ensured
#
# the lack of exercise contributed to weight gain. (the lack, contributed, weight gain) contributed
#
# the lack of exercise contributed to weight gain. (the lack, contributed, exercise) contributed
#
# the timely intervention prevented further complications. (the timely intervention, prevented, further complications) prevented
#
# the proper dosage of medication improved his condition. (the proper dosage, improved, his condition) improved
#
# the proper dosage of medication improved his condition. (the proper dosage, improved, medication) improved
#
# the accurate diagnosis guided the treatment plan. (the accurate diagnosis, guided, treatment plan) guided
#
# the patient's allergies triggered an allergic reaction. (the patient's allergies, triggered, an allergic reaction) triggered
#
# the consistent physical therapy aided in recovery. (the consistent physical therapy, aided, recovery) aided
#
# the immunization protected against contagious diseases. (the consistent physical therapy, immunization, contagious diseases) immunization
#
# the healthy lifestyle choices promoted overall well-being. (lifestyle choices, promoted, overall well-being) promoted
#
# the regular check-ups detected potential issues early. (the consistent physical therapy, issues, contagious diseases) issues
#
# the advanced medical technology enhanced diagnosis accuracy. (the advanced medical technology, enhanced, diagnosis accuracy) enhanced
#
# the patient's adherence to medication improved outcomes. (the patient's adherence, improved, outcomes) improved
#
# the patient's adherence to medication improved outcomes. (the patient's adherence, improved, medication) improved
#
# the proper wound care minimized the risk of infection. (wound care, minimized, the risk) minimized
#
# the proper wound care minimized the risk of infection. (the proper wound care, minimized, the risk) minimized
#
# the proper wound care minimized the risk of infection. (the proper wound care, minimized, infection) minimized
#
# the medical research led to groundbreaking discoveries. (the medical research, led, discoveries) led
#
# the genetic predisposition increased the susceptibility. (the genetic predisposition, increased, the susceptibility) increased
#
# the medical staff's dedication provided quality care. (the medical staff's dedication, provided, quality care) provided
#
# the dietary restrictions managed his chronic condition. (the dietary restrictions, managed, his chronic condition) managed
#
# the rehabilitation program restored his mobility. (rehabilitation program, restored, his mobility) restored
#
# the side effects of chemotherapy weakened her immune system. (the side effects, weakened, her immune system) weakened
#
# the side effects of chemotherapy weakened her immune system. (the side effects, weakened, chemotherapy) weakened
#
# the organ transplant saved his life. (organ transplant, saved, his life) saved
#
# the mental health therapy helped manage anxiety. (health therapy, helped, manage) helped
#
# the effective pain management improved his comfort. (pain management, improved, his comfort) improved
#
# the radiologist's expertise ensured accurate imaging. (the radiologist's expertise, ensured, accurate imaging) ensured
#
# the blood test results indicated a vitamin deficiency. (blood test results, indicated, vitamin deficiency) indicated
#
# the medication regimen controlled his blood pressure. (medication regimen, controlled, blood pressure) controlled
#
# the medical breakthrough offered hope for a cure. (the medical breakthrough, offered, hope) offered
#
# the medical breakthrough offered hope for a cure. (the medical breakthrough, offered, a cure) offered
#
# the occupational therapist aided in functional recovery. (the occupational therapist, aided, functional recovery) aided
#
# the proper wound dressing prevented complications. (the occupational therapist, wound, prevented complications) wound
#
# the medical team collaborated for optimal patient care. (the medical team, collaborated, optimal patient care) collaborated
#
# the heart monitor displayed irregular rhythms. (heart monitor, displayed, irregular rhythms) displayed
#
# the surgeon's precision minimized scarring. (precision, scarring, optimal patient care) scarring
#
# the rehabilitation exercises strengthened his muscles. (rehabilitation exercises, strengthened, his muscles) strengthened
#
# the patient's medical history influenced the treatment approach. (the patient's medical history, influenced, treatment approach) influenced
#
# the physical therapy sessions improved his range of motion. (therapy sessions, improved, his range) improved
#
# the physical therapy sessions improved his range of motion. (the physical therapy sessions, improved, his range) improved
#
# the physical therapy sessions improved his range of motion. (the physical therapy sessions, improved, motion) improved
#
# the accurate medical records facilitated proper diagnosis. (the accurate medical records, facilitated, proper diagnosis) facilitated
#
# the timely medical intervention saved her from a stroke. (the timely medical intervention, saved, a stroke) saved
#
# the medication side effects caused drowsiness. (medication side effects, caused, drowsiness) caused
#
# the medical examination revealed underlying issues. (the medical examination, revealed, underlying issues) revealed
#
# the preventive measures reduced the risk of infection. (the preventive measures, reduced, the risk) reduced
#
# the preventive measures reduced the risk of infection. (the preventive measures, reduced, infection) reduced
#
# the pediatrician's guidance ensured proper child development. (the pediatrician's guidance, ensured, child development) ensured
#
# the specialist's consultation provided expert insights. (the specialist's consultation, provided, expert insights) provided
#
# the pain management techniques alleviated discomfort. (management techniques, alleviated, discomfort) alleviated
#
# the diagnostic tests confirmed the presence of a tumor. (the diagnostic tests, confirmed, the presence) confirmed
#
# the diagnostic tests confirmed the presence of a tumor. (the diagnostic tests, confirmed, a tumor) confirmed
#
# the vaccination schedule protected against communicable diseases. (the vaccination schedule, protected, communicable diseases) protected
#
# the health screening identified potential health risks. (health screening, identified, health risks) identified
#
# the intensive care unit monitored critically ill patients. (care unit, monitored, critically ill patients) monitored
#
# the medical treatment plan addressed specific symptoms. (treatment plan, addressed, specific symptoms) addressed
#
# the medical device monitored glucose levels. (the medical device, monitored, glucose levels) monitored
#
# the surgical procedure required meticulous planning. (the surgical procedure, required, meticulous planning) required
#
# the faulty wiring caused the electrical outage. (the faulty wiring, caused, the electrical outage) caused
#
# poor time management caused him to miss the deadline. (poor time management, to miss, the deadline) to miss
#
# excessive sugar consumption can cause tooth decay. (sugar consumption, can cause, tooth decay) can cause
#
# the lack of exercise caused weight gain. (the lack, caused, weight gain) caused
#
# the lack of exercise caused weight gain. (the lack, caused, exercise) caused
#
# the car accident caused a major traffic jam. (car accident, caused, traffic jam) caused
#
# his careless actions caused the glass to shatter. (the glass, caused, communicable diseases) caused
#
# skipping breakfast can cause low energy levels throughout the day. (skipping breakfast, can cause, energy levels) can cause
#
# skipping breakfast can cause low energy levels throughout the day. (skipping breakfast, can cause, low energy levels) can cause
#
# skipping breakfast can cause low energy levels throughout the day. (skipping breakfast, can cause, the day) can cause
#
# the allergen exposure caused a severe allergic reaction. (allergen exposure, caused, a severe allergic reaction) caused
#
# overuse of electronic devices can cause eye strain. (overuse, can cause, eye strain) can cause
#
# overuse of electronic devices can cause eye strain. (overuse, can cause, electronic devices) can cause
#
# the earthquake caused buildings to collapse. (buildings, caused, communicable diseases) caused
#
# stress can cause a variety of health issues. (stress, can cause, a variety) can cause
#
# stress can cause a variety of health issues. (stress, can cause, health issues) can cause
#
# the absence of sunlight can cause vitamin d deficiency. (the absence, can cause, d deficiency) can cause
#
# the absence of sunlight can cause vitamin d deficiency. (the absence, can cause, sunlight) can cause
#
# the absence of sunlight can cause vitamin d deficiency. (the absence, can cause, vitamin d deficiency) can cause
#
# his rude behavior caused offense to others. (his rude behavior, caused, offense) caused
#
# his rude behavior caused offense to others. (his rude behavior, caused, others) caused
#
# lack of proper ventilation can cause indoor air pollution. (lack, can cause, air pollution) can cause
#
# lack of proper ventilation can cause indoor air pollution. (lack, can cause, proper ventilation) can cause
#
# lack of proper ventilation can cause indoor air pollution. (lack, can cause, indoor air pollution) can cause
#
# the strong winds caused tree branches to fall. (tree branches, caused, communicable diseases) caused
#
# smoking can cause respiratory problems. (smoking, can cause, respiratory problems) can cause
#
# the inadequate drainage system caused flooding in the streets. (the inadequate drainage system, caused, the streets) caused
#
# failing to follow instructions can cause errors in the final product. (instructions, can cause, errors) can cause
#
# failing to follow instructions can cause errors in the final product. (instructions, can cause, the final product) can cause
#
# the high humidity levels caused mold growth in the basement. (humidity levels, caused, mold growth) caused
#
# the high humidity levels caused mold growth in the basement. (the high humidity levels, caused, mold growth) caused
#
# the high humidity levels caused mold growth in the basement. (the high humidity levels, caused, the basement) caused
#
# the excessive noise from construction caused sleep disturbances. (the excessive noise, caused, sleep disturbances) caused
#
# the excessive noise from construction caused sleep disturbances. (the excessive noise, caused, construction) caused
#
# the absence of rain caused drought conditions. (the absence, caused, drought conditions) caused
#
# the absence of rain caused drought conditions. (the absence, caused, rain) caused
#
# the wrong dosage of medication can cause adverse effects. (the wrong dosage, can cause, adverse effects) can cause
#
# the wrong dosage of medication can cause adverse effects. (the wrong dosage, can cause, medication) can cause
#
# poor communication can cause misunderstandings. (poor communication, can cause, misunderstandings) can cause
#
# the malfunctioning thermostat caused temperature fluctuations. (the malfunctioning thermostat, caused, temperature fluctuations) caused
#
# improper handling of chemicals can cause hazardous reactions. (improper handling, can cause, hazardous reactions) can cause
#
# improper handling of chemicals can cause hazardous reactions. (improper handling, can cause, chemicals) can cause
#
# the scarcity of resources can cause conflicts. (the scarcity, can cause, conflicts) can cause
#
# the scarcity of resources can cause conflicts. (the scarcity, can cause, resources) can cause
#
# the intense workout caused muscle soreness. (the intense workout, caused, muscle soreness) caused
#
# the misalignment of gears caused the machine to malfunction. (the misalignment, caused, the machine) caused
#
# overexposure to the sun can cause sunburn. (overexposure, can cause, sunburn) can cause
#
# overexposure to the sun can cause sunburn. (overexposure, can cause, the sun) can cause
#
# the incorrect password entry caused account lockout. (password entry, caused, account lockout) caused
#
# the polluted water source caused widespread illness. (water source, caused, widespread illness) caused
#
# the inadequate insulation caused heat loss from the building. (the inadequate insulation, caused, heat loss) caused
#
# the inadequate insulation caused heat loss from the building. (the inadequate insulation, caused, the building) caused
#
# the absence of parental guidance can cause behavioral issues in children. (the absence, can cause, behavioral issues) can cause
#
# the absence of rain caused crop failure. (the absence, caused, crop failure) caused
#
# the excessive use of pesticides can cause harm to the environment. (the excessive use, can cause, harm) can cause
#
# poor circulation can cause numbness in extremities. (poor circulation, can cause, numbness) can cause
#
# poor circulation can cause numbness in extremities. (poor circulation, can cause, extremities) can cause
#
# the faulty brake system caused the car to skid. (the car, caused, communicable diseases) caused
#
# the financial crisis caused a decline in the housing market. (the financial crisis, caused, a decline) caused
#
# the financial crisis caused a decline in the housing market. (the financial crisis, caused, the housing market) caused
#
# the lack of sleep can cause impaired cognitive function. (the lack, can cause, impaired cognitive function) can cause
#
# the lack of sleep can cause impaired cognitive function. (the lack, can cause, sleep) can cause
#
# the absence of proper sanitation can cause the spread of diseases. (the absence, can cause, the spread) can cause
#
# the sudden change in temperature caused pipes to burst. (pipes, caused, temperature) caused
#
# the sudden change in temperature caused pipes to burst. (the sudden change, caused, temperature) caused
#
# the sudden change in temperature caused pipes to burst. (the sudden change, caused, pipes) caused
#
# the misuse of antibiotics can cause antibiotic resistance. (the misuse, can cause, antibiotic resistance) can cause
#
# the misuse of antibiotics can cause antibiotic resistance. (the misuse, can cause, antibiotics) can cause
#
# the aggressive driving behavior caused road rage. (driving behavior, caused, road rage) caused
#
# the misinterpretation of data can cause incorrect conclusions. (the misinterpretation, can cause, incorrect conclusions) can cause
#
# the misinterpretation of data can cause incorrect conclusions. (the misinterpretation, can cause, data) can cause
#
# the reduction in funding caused program cutbacks. (the reduction, caused, program cutbacks) caused
#
# the reduction in funding caused program cutbacks. (the reduction, caused, funding) caused
#
# the inadequate training can cause employees to make mistakes. (employees, to make, mistakes) to make
#
# the inadequate training can cause employees to make mistakes. (the inadequate training, to make, employees) to make
#
# the inadequate training can cause employees to make mistakes. (the inadequate training, to make, mistakes) to make
#
# the absence of parental support can cause poor academic performance. (the absence, can cause, poor academic performance) can cause
#
# the absence of parental support can cause poor academic performance. (the absence, can cause, parental support) can cause
#
# the excessive screen time caused digital eye strain. (the excessive screen time, caused, temperature) caused
#
# the lack of coordination among team members caused project delays. (the lack, caused, project delays) caused
#
# the improper storage of food can cause bacterial contamination. (the improper storage, can cause, bacterial contamination) can cause
#
# the improper storage of food can cause bacterial contamination. (the improper storage, can cause, food) can cause
#
# the defective valve caused water leakage in the pipes. (the defective valve, caused, water leakage) caused
#
# the defective valve caused water leakage in the pipes. (the defective valve, caused, the pipes) caused
#
# the absence of exercise can cause a decline in cardiovascular health. (the absence, can cause, a decline) can cause
#
# the irresponsible behavior of the driver caused a traffic accident. (the irresponsible behavior, caused, traffic accident) caused
#
# the irresponsible behavior of the driver caused a traffic accident. (the irresponsible behavior, caused, the driver) caused
#
# the irresponsible behavior of the driver caused a traffic accident. (the irresponsible behavior, caused, a traffic accident) caused
#
# the absence of proper maintenance can cause equipment breakdowns. (the absence, can cause, equipment breakdowns) can cause
#
# the absence of proper maintenance can cause equipment breakdowns. (the absence, can cause, proper maintenance) can cause
#
# the constant exposure to loud noise can cause hearing loss. (the constant exposure, can cause, hearing) can cause
#
# the constant exposure to loud noise can cause hearing loss. (the constant exposure, can cause, loud noise) can cause
#
# the constant exposure to loud noise can cause hearing loss. (the constant exposure, can cause, loss) can cause
#
# the misinformation spread on social media can cause panic. (the misinformation, spread, panic) spread
#
# the misinformation spread on social media can cause panic. (the misinformation, spread, social media) spread
#
# the excessive consumption of sugary foods can cause obesity. (the excessive consumption, can cause, obesity) can cause
#
# the excessive consumption of sugary foods can cause obesity. (the excessive consumption, can cause, sugary foods) can cause
#
# the lack of insulation in the walls can cause heat loss. (the lack, can cause, heat loss) can cause
#
# the increased pollution levels can cause respiratory problems. (pollution levels, can cause, respiratory problems) can cause
#
# the neglect of oral hygiene can cause dental issues. (the neglect, can cause, dental issues) can cause
#
# the neglect of oral hygiene can cause dental issues. (the neglect, can cause, oral hygiene) can cause
#
# the misunderstanding of instructions can cause errors in assembly. (the misunderstanding, can cause, errors) can cause
#
# the absence of clear guidelines can cause confusion. (the absence, can cause, confusion) can cause
#
# the absence of clear guidelines can cause confusion. (the absence, can cause, clear guidelines) can cause
#
# the sudden shift in market demand caused supply chain disruptions. (the sudden shift, caused, chain disruptions) caused
#
# the sudden shift in market demand caused supply chain disruptions. (the sudden shift, caused, market demand) caused
#
# the sudden shift in market demand caused supply chain disruptions. (the sudden shift, caused, supply chain disruptions) caused
#
# the lack of empathy can cause strained relationships. (the lack, can cause, strained relationships) can cause
#
# the lack of empathy can cause strained relationships. (the lack, can cause, empathy) can cause
#
# the illegal logging in the forest caused environmental degradation. (the illegal logging, caused, environmental degradation) caused
#
# the illegal logging in the forest caused environmental degradation. (the illegal logging, caused, the forest) caused
#
# the poor drainage system caused waterlogging in the streets. (the poor drainage system, caused, the streets) caused
#
# the lack of financial planning can cause debt accumulation. (the lack, can cause, debt accumulation) can cause
#
# the lack of financial planning can cause debt accumulation. (the lack, can cause, financial planning) can cause
#
# the inadequate security measures can cause data breaches. (security measures, can cause, data breaches) can cause
#
# the excessive use of electronic devices can cause sleep disturbances. (the excessive use, can cause, sleep disturbances) can cause
#
# the excessive use of electronic devices can cause sleep disturbances. (the excessive use, can cause, electronic devices) can cause
#
# the absence of streetlights can cause unsafe neighborhoods. (the absence, can cause, unsafe neighborhoods) can cause
#
# the absence of streetlights can cause unsafe neighborhoods. (the absence, can cause, streetlights) can cause
#
# the unchecked spread of rumors can cause reputational damage. (the unchecked spread, can cause, reputational damage) can cause
#
# the unchecked spread of rumors can cause reputational damage. (the unchecked spread, can cause, rumors) can cause
#
# the poor road conditions can cause vehicle damage. (road conditions, can cause, vehicle damage) can cause
#
# the irregular eating habits can cause digestive issues. (eating habits, can cause, digestive issues) can cause
#
# the lack of proper sanitation facilities can cause unsanitary conditions. (the lack, can cause, unsanitary conditions) can cause
#
# the lack of proper sanitation facilities can cause unsanitary conditions. (the lack, can cause, proper sanitation facilities) can cause
#
# the heavy rainfall caused landslides in the hilly areas. (the heavy rainfall, caused, landslides) caused
#
# the heavy rainfall caused landslides in the hilly areas. (the heavy rainfall, caused, the hilly areas) caused
#
# the lack of insect repellent can cause mosquito bites. (the lack, can cause, mosquito bites) can cause
#
# the lack of insect repellent can cause mosquito bites. (the lack, can cause, insect repellent) can cause
#
# the absence of proper training can cause inefficiencies in the workplace. (the absence, can cause, inefficiencies) can cause
#
# the exposure to harmful chemicals can cause skin irritation. (the exposure, can cause, skin irritation) can cause
#
# the exposure to harmful chemicals can cause skin irritation. (the exposure, can cause, harmful chemicals) can cause
#
# the fluctuating exchange rates can cause economic instability. (exchange rates, can cause, economic instability) can cause
#
# the absence of proper documentation can cause delays in processing. (the absence, can cause, delays) can cause
#
# the unregulated use of pesticides can cause harm to beneficial insects. (the unregulated use, can cause, harm) can cause
#
# the absence of fire safety measures can cause serious accidents. (the absence, can cause, serious accidents) can cause
#
# the absence of fire safety measures can cause serious accidents. (the absence, can cause, fire safety measures) can cause
#
# the absence of parental supervision can cause risky behavior in teenagers. (the absence, can cause, risky behavior) can cause
#
# the excessive use of antibiotics can cause disruption of gut bacteria. (the excessive use, can cause, disruption) can cause
#
# the poor air quality caused respiratory problems for residents. (air quality, caused, respiratory problems) caused
#
# the poor air quality caused respiratory problems for residents. (the poor air quality, caused, respiratory problems) caused
#
# the poor air quality caused respiratory problems for residents. (the poor air quality, caused, residents) caused
#
# the lack of diversity can cause a stagnant work environment. (the lack, can cause, work environment) can cause
#
# the lack of diversity can cause a stagnant work environment. (the lack, can cause, diversity) can cause
#
# the lack of diversity can cause a stagnant work environment. (the lack, can cause, a stagnant work environment) can cause
#
# the sudden power outage caused disruption in communication. (power outage, caused, disruption) caused
#
# the sudden power outage caused disruption in communication. (the sudden power outage, caused, disruption) caused
#
# the sudden power outage caused disruption in communication. (the sudden power outage, caused, communication) caused
#
# the absence of proper maintenance can cause elevator breakdowns. (the absence, can cause, elevator breakdowns) can cause
#
# the lack of physical activity can cause a sedentary lifestyle. (the lack, can cause, a sedentary lifestyle) can cause
#
# the lack of physical activity can cause a sedentary lifestyle. (the lack, can cause, physical activity) can cause
#
# the lack of transparency in decision-making can cause distrust. (the lack, can cause, distrust) can cause
#
# the excessive sugar intake can cause insulin resistance. (sugar intake, can cause, insulin resistance) can cause
#
# the absence of green spaces can cause stress in urban areas. (the absence, can cause, stress) can cause
#
# the incorrect calibration of instruments can cause measurement errors. (the incorrect calibration, can cause, measurement errors) can cause
#
# the incorrect calibration of instruments can cause measurement errors. (the incorrect calibration, can cause, instruments) can cause
#
# the improper disposal of waste can cause environmental pollution. (the improper disposal, can cause, environmental pollution) can cause
#
# the improper disposal of waste can cause environmental pollution. (the improper disposal, can cause, waste) can cause
#
# the absence of routine medical check-ups can cause undiagnosed health issues. (the absence, can cause, health issues) can cause
#
# the absence of routine medical check-ups can cause undiagnosed health issues. (the absence, can cause, routine medical check-ups) can cause
#
# the absence of routine medical check-ups can cause undiagnosed health issues. (the absence, can cause, undiagnosed health issues) can cause
#
# the lack of empathy in leadership can cause employee dissatisfaction. (the lack, can cause, employee dissatisfaction) can cause
#
# the absence of seat belts can cause serious injuries in car accidents. (the absence, can cause, serious injuries) can cause

# %% [markdown]
# # Causal Triples' Polarity (Whole)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen = []
for sent in causalTriples:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        allen.append(score)
        # allen.append(-1)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        allen.append(scores[2])
        # allen.append(1)
    else:
        # allen.append(scores[1])
        allen.append(0)

for causalSentence, polarity  in zip(causalTriples, allen):
    if polarity < -1 or polarity > 1:
        print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
afinn = []
for sent in causalTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    # print(score)
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    afinn.append(score)
    
for causalSentence, polarity  in zip(causalTriples, afinn):
    if polarity < -1 or polarity > 1:
        print(causalSentence, polarity)

# %% [markdown]
# ### [Vader]

# %%
vader = []
def vadersentimentanalysis(review):
    # negpos = []
    vs = analyzer.polarity_scores(review)
    return vs['compound']

for sent in causalTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    # print(compound)
    vader.append(compound)
    # vader_analysis(compound)

for causalSentence, polarity  in zip(causalTriples, vader):
    if polarity < -1 or polarity > 1:
        print(causalSentence, polarity)

# %% [markdown]
# ### [SentiStrength]

# %%
sentiStrength = []
for sent in causalTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='scale')
    # print(result)
    result = result[0]/4
    sentiStrength.append(result)

for causalSentence, polarity  in zip(causalTriples, sentiStrength):
    if polarity < -1 or polarity > 1:
        print(causalSentence, polarity)

# %% [markdown]
# ### Data Frame (Causal Triples Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'HuggingFace','Afinn','Vader','SentiStrength'])
df2["Weight"] = round(df2.sum(axis=1),2)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df2.iterrows():
    # check = False
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -4.0 and weight < -3.0:
        sentPolarity.append('Strong Negative')
        # check = True 
    elif weight >= -3 and weight < -2:
        sentPolarity.append('Moderate Negative')
        # check = True
    elif weight >= -2 and weight < -1:
        sentPolarity.append('Mild Negative')
        # check = True
    elif weight >= -1 and weight < 0:
        sentPolarity.append('Weak Negative')
        # check = True
    elif weight == 0:
        sentPolarity.append('Neutral')
        # check = True
    elif weight <= 4 and weight > 3:
        sentPolarity.append('Strong Positive')
        # check = True
    elif weight <= 3 and weight > 2:
        sentPolarity.append('Moderate Positive')
        # check = True
    elif weight <= 2 and weight > 1:
        sentPolarity.append('Mild Positive')
        # check = True
    elif weight <= 1 and weight > 0:
        sentPolarity.append('Weak Positive')
        check = True
    # if check == False:
    #     print(weight)
    #     break

df2["Polarity"] = sentPolarity
#df2.style
# Out:
# c:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Causal Sentences' Polarity (Whole)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
def Allen_sents_SentLevel(causalSentences):
    allen = []
    for sent in causalSentences:
        encoded_input = tokenizer(str(sent), return_tensors='pt')
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        if scores[0] > scores[1] and scores[0] > scores[2]:
            score = scores[0] * -1
            allen.append(score)
            # allen.append(-1)
        elif scores[2] > scores[1] and scores[2] > scores[0]:
            allen.append(scores[2])
            # allen.append(1)
        else:
            # allen.append(scores[1])
            allen.append(0)
    return allen

# %% [markdown]
# ### [Afinn]

# %%
def Afinn_sents_SentLevel(causalSentences):
    afinn = []
    for sent in causalSentences:
        #print(sent)
        score = afn.score(str(sent))
        #print(score)
        if score < -5:
            score = -5
        elif score > 5:
            score = 5
        score = score/5
        afinn.append(score)
        # if score > 0:
        #     #print('positive')
        #     afinn.append(1)
        # elif score < 0:
        #     #print('negative')
        #     afinn.append(-1)
        # else:
        #     #print('neutral')
        #     afinn.append(0)
    return afinn

# %% [markdown]
# ### [Vader]

# %%
def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def Vader_sents_SentLevel(causalSentences):
    vader = []
    for sent in causalSentences:
        #print(sent)
        #vaderTup = []
        compound = vadersentimentanalysis(str(sent))
        vader.append(compound)
        # res = vader_analysis(compound)
        #vaderTup.append(res)
        # vader.append(res)
    return vader

# %% [markdown]
# ### [SentiStrength]

# %%
def Senti_sents_SentLevel(causalSentences):
    sentiStrength = []
    for sent in causalSentences:
        #print(sent)
        result = senti.getSentiment(str(sent), score='scale')
        #print(result)
        result = result[0]/4
        sentiStrength.append(result)
        # if result[0] > 0:
        #     sentiStrength.append(1)
        # elif result[0] < 0:
        #     sentiStrength.append(-1)
        # else:
        #     sentiStrength.append(0)
    return sentiStrength

# %%
causalSents = causalSentences
print(len(causalSents))
# Out:
# 466

# %% [markdown]
# ### Data Frame (Causal Sentence at Sentence Level)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

allen = Allen_sents_SentLevel(causalSents)
afinn = Afinn_sents_SentLevel(causalSents)
vader = Vader_sents_SentLevel(causalSents)
sentiStrength = Senti_sents_SentLevel(causalSents)

df2 = pd.DataFrame(list(zip(causalSents, allen, afinn, vader,sentiStrength)), columns =['Causal Sentence', 'HuggingFace','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)


sentPolarity = []
sentsWeight_sentLevel = []

for index, row in df2.iterrows():
    sentWeightTuple = []
    weight = row['Weight']
    sentWeightTuple.append(weight)
    sentsWeight_sentLevel.append(sentWeightTuple)
    #print(weight)
    if weight >= -4.0 and weight < -3.0:
        sentPolarity.append('Strong Negative') 
    elif weight >= -3 and weight < -2:
        sentPolarity.append('Moderate Negative')
    elif weight >= -2 and weight < -1:
        sentPolarity.append('Mild Negative')
    elif weight >= -1 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 4 and weight > 3:
        sentPolarity.append('Strong Positive')
    elif weight <= 3 and weight > 2:
        sentPolarity.append('Moderate Positive')
    elif weight <= 2 and weight > 1:
        sentPolarity.append('Mild Positive')
    elif weight <= 1 and weight > 0:
        sentPolarity.append('Weak Positive')

df2["Polarity"] = sentPolarity
#df2.style
# Out:
# c:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   if __name__ == "__main__":

# %% [markdown]
# # Causal Triples' Polarity (Token Level)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen_word = []
allen_tuple = []

for tokenTuple in causalTriples:
    # print(tokenTuple)
    for token in tokenTuple:
        # print(token)
        encoded_input = tokenizer(str(token), return_tensors='pt')
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        # print(scores)
        if scores[0] > scores[1] and scores[0] > scores[2]:
            score = scores[0] * -1
            allen_tuple.append(score)
            # allen_tuple.append(-1)
        elif scores[2] > scores[1] and scores[2] > scores[0]:
            allen_tuple.append(scores[2])
            # allen_tuple.append(1)
        else:
            # allen_tuple.append(scores[1])
            allen_tuple.append(0)
    allen_word.append(allen_tuple)
    allen_tuple = []

# %% [markdown]
# ### [Afinn]

# %%
afinn_word = []
afinn_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
        #if str(token) not in marks:
            #print(token)
        score = afn.score(str(token))
        if score < -5:
            score = -5
        elif score > 5:
            score = 5
        score = score/5
        afinn_tuple.append(score)
        # if score > 0:
        #         #print('positive')
        #     afinn_tuple.append(1)
        # elif score < 0:
        #         #print('negative')
        #     afinn_tuple.append(-1)
        # else:
        #         #print('neutral')
        #     afinn_tuple.append(0)
    afinn_word.append(afinn_tuple)
    afinn_tuple = []

# %% [markdown]
# ### [Vader]

# %%
vader_word = []
vader_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) not in marks:
        vs = analyzer.polarity_scores(str(token))
        compound = vs['compound']
        vader_tuple.append(compound)
        # if compound >= 0.05:
        #     vader_tuple.append(1)   
        # elif compound <= -0.05 :
        #     vader_tuple.append(-1)
        # elif  compound > -0.05 and compound < 0.05:
        #     vader_tuple.append(0)
    vader_word.append(vader_tuple)
    vader_tuple = []

# %% [markdown]
# ### [SentiStrength]

# %%
senti_word = []
senti_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks:
        #print(token)
        result = senti.getSentiment(str(token), score='scale')
            #print(result)
        result = result[0]/4
        senti_tuple.append(result)
        # if result[0] > 0:
        #     senti_tuple.append(1)
        # elif result[0] < 0:
        #     senti_tuple.append(-1)
        # else:
        #     senti_tuple.append(0)
    senti_word.append(senti_tuple)
    senti_tuple = []

# %% [markdown]
# ### Data Frame (Causal Triples Token Level)

# %%
sum_list = []
sum_tup = []
limit= len(causalTriples)

for i in range(0,limit):
    for j in range(0,len(allen_word[i])):
        if afinn_word[i][j] == 0 and vader_word[i][j]== 0 and senti_word[i][j] == 0 and allen_word[i][j] == 0:
            res = 0
        else:
            res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

triplesWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = 0
    for w in t:
        if w == 0:
            total = total
        else:
            total = total + 1
        tripleWeight = tripleWeight + w
    if tripleWeight != 0:
        tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    triplesWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)

def dataframe_WordLevel(i):
    df = pd.DataFrame([causalTriples[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],triplesWeight_TokenLevel[i],triplePolarity_list[i]], 
                      index =   ['Tokens','HuggingFace','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

# for i in range(0,limit):
#     df = dataframe_WordLevel(i)
#     replicator(df)

# %% [markdown]
# # Causal Sentences' Polarity (Token Level)

# %% [markdown]
# ### Generating list of tokens without stop words and punctuation marks.

# %%
def GenerateTokens(causalSentences):
    marks = ['.',',','(',')','-',':',';','/',"'s",'_','__','--','"', '’', '—']
    token_list = []
   
    for sent in causalSentences:
        token_tuple = []
        for token in sent:
            if str(token) not in marks:
                if str(token) not in stopwords.words():
                    token_tuple.append(str(token))
        token_list.append(token_tuple)
    return token_list
        
#print(len(token_list))
#print(token_list)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
def Allen_sents_TokenLevel(token_list):
    allen_word = []
    allen_tuple = []
    for tokenTuple in token_list:
        # print(tokenTuple)
        for token in tokenTuple:
            # print(token)
            encoded_input = tokenizer(str(token), return_tensors='pt')
            output = model(**encoded_input)
            scores = output[0][0].detach().numpy()
            scores = softmax(scores)
            if scores[0] > scores[1] and scores[0] > scores[2]:
                score = scores[0] * -1
                allen_tuple.append(score)
            elif scores[2] > scores[1] and scores[2] > scores[0]:
                allen_tuple.append(scores[2])
            else:
                # allen_tuple.append(scores[1])
                allen_tuple.append(0)
        allen_word.append(allen_tuple)
        allen_tuple = []
    return allen_word

# %% [markdown]
# ### [Afinn]

# %%
def Afinn_sents_TokenLevel(token_list):
    afinn_word = []
    afinn_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
            #if str(token) not in marks:
                #print(token)
            score = afn.score(str(token))
            if score < -5:
                score = -5
            elif score > 5:
                score = 5
            score = score/5
            afinn_tuple.append(score)
            # if score > 0:
            #         #print('positive')
            #     afinn_tuple.append(1)
            # elif score < 0:
            #         #print('negative')
            #     afinn_tuple.append(-1)
            # else:
            #         #print('neutral')
            #     afinn_tuple.append(0)
        afinn_word.append(afinn_tuple)
        afinn_tuple = []
    return afinn_word

# %% [markdown]
# ### [Vader]

# %%
def Vader_sents_TokenLevel(token_list):
    vader_word = []
    vader_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
            vs = analyzer.polarity_scores(str(token))
            compound = vs['compound']
            vader_tuple.append(compound)
            # if compound >= 0.05:
            #     vader_tuple.append(1)   
            # elif compound <= -0.05 :
            #     vader_tuple.append(-1)
            # elif  compound > -0.05 and compound < 0.05:
            #     vader_tuple.append(0)
        vader_word.append(vader_tuple)
        vader_tuple = []
    return vader_word

# %% [markdown]
# ### [SentiStrength]

# %%
def Senti_sents_TokenLevel(token_list):
    senti_word = []
    senti_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
                #print(token)
            result = senti.getSentiment(str(token), score='scale')
                #print(result)
            result = result[0]/4
            senti_tuple.append(result)
            # if result[0] > 0:
            #     senti_tuple.append(1)
            # elif result[0] < 0:
            #     senti_tuple.append(-1)
            # else:
            #     senti_tuple.append(0)
        senti_word.append(senti_tuple)
        senti_tuple = []
    return senti_word

# %% [markdown]
# ### Data Frame (Causal Sentences Word Level)

# %%
token_list = GenerateTokens(causalSents)
allen_word = Allen_sents_TokenLevel(token_list)
afinn_word = Afinn_sents_TokenLevel(token_list)
vader_word = Vader_sents_TokenLevel(token_list)   
senti_word = Senti_sents_TokenLevel(token_list)

sum_list = []
sum_tup = []
limit= len(causalSents)

for i in range(0,limit):
    for j in range(0,len(allen_word[i])):
        if afinn_word[i][j] == 0 and vader_word[i][j]== 0 and senti_word[i][j] == 0 and allen_word[i][j] == 0:
            res = 0
        else:
            res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

sentsWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = 0
    for w in t:
        if w == 0:
            total = total
        else:
            total = total + 1
        tripleWeight = tripleWeight + w
    if tripleWeight != 0:
        tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    sentsWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)

def dataframe_WordLevel(i):
    df = pd.DataFrame([token_list[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],sentsWeight_TokenLevel[i],SentencePolarity_list[i]], 
                      index =   ['Tokens','HuggingFace','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    # replicator(df)

# %% [markdown]
# # Causal Verbs Polarity (Whole)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen = []
for sent in causalVerbs:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        allen.append(score)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        allen.append(scores[2])
    else:
        # allen.append(scores[1])
        allen.append(0)

# %% [markdown]
# ### [Afinn]

# %%
afinn = []
for sent in causalVerbs:
    #print(str(sent))
    score = afn.score(str(sent))
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    afinn.append(score)

# %% [markdown]
# ### [Vader]

# %%
vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

for sent in causalVerbs:
    compound = vadersentimentanalysis(str(sent))
    vader.append(compound)

# %% [markdown]
# ### [SentiStrength]

# %%
sentiStrength = []

for sent in causalVerbs:
    result = senti.getSentiment(str(sent), score='scale')
    result = result[0]/4
    sentiStrength.append(result)

# %% [markdown]
# ### Data Frame (Causal Verbs Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalVerbs, allen, afinn, vader,sentiStrength)), columns =['Causal Verb', 'HuggingFace','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)

sentPolarity = []
VerbsWeight_sentLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    VerbsWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -4.0 and weight < -3.0:
        sentPolarity.append('Strong Negative') 
    elif weight >= -3 and weight < -2:
        sentPolarity.append('Moderate Negative')
    elif weight >= -2 and weight < -1:
        sentPolarity.append('Mild Negative')
    elif weight >= -1 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 4 and weight > 3:
        sentPolarity.append('Strong Positive')
    elif weight <= 3 and weight > 2:
        sentPolarity.append('Moderate Positive')
    elif weight <= 2 and weight > 1:
        sentPolarity.append('Mild Positive')
    elif weight <= 1 and weight > 0:
        sentPolarity.append('Weak Positive')

df2["Polarity"] = sentPolarity
#df2.style
# Out:
# c:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Lemma Causal Verbs Polarity (Whole)

# %% [markdown]
# ### Generating list of lemmas for whole causal verbs.

# %%
lemmaDagCauseVerbs = []
tagsList = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
for verb in causalVerbs:
    # print("Verb:" + verb)
    tokens = word_tokenize(str(verb))
    # print("Tokens:" + str(tokens))
    tags = pos_tag(tokens)
    # print(tags)
    for token in tokens:
        if token not in stopwords.words() or tags[0][1] in tagsList:
            # print("Token:" + token)
            lemma = lemma_function.lemmatize(str(token))
            # print("Lemma:" + lemma)
            lemmaDagCauseVerbs.append(lemma)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen = []
for sent in lemmaDagCauseVerbs:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        allen.append(score)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        allen.append(scores[2])
    else:
        # allen.append(scores[1])
        allen.append(0)

# %% [markdown]
# ### [Afinn]

# %%
afinn = []
for sent in lemmaDagCauseVerbs:
    #print(str(sent))
    score = afn.score(str(sent))
    # print(score)
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    afinn.append(score)

# %% [markdown]
# ### [Vader]

# %%
vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

for sent in lemmaDagCauseVerbs:
    compound = vadersentimentanalysis(str(sent))
    vader.append(compound)

# %% [markdown]
# ### [SentiStrength]

# %%
sentiStrength = []

for sent in lemmaDagCauseVerbs:
    result = senti.getSentiment(str(sent), score='scale')
    result = result[0]/4
    sentiStrength.append(result)

# %% [markdown]
# ### Data Frame (Lemma Causal Verbs Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalVerbs, lemmaDagCauseVerbs,allen, afinn, vader,sentiStrength)), columns =['Causal Verb', 'Lemma(Causal Verb)' ,'HuggingFace','Afinn','Vader','SentiStrength'])
df2["Weight"] = round(df2.sum(axis=1),2)

sentPolarity = []
LemmaVerbsWeight_tokLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    LemmaVerbsWeight_tokLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -4.0 and weight < -3.0:
        sentPolarity.append('Strong Negative') 
    elif weight >= -3 and weight < -2:
        sentPolarity.append('Moderate Negative')
    elif weight >= -2 and weight < -1:
        sentPolarity.append('Mild Negative')
    elif weight >= -1 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 4 and weight > 3:
        sentPolarity.append('Strong Positive')
    elif weight <= 3 and weight > 2:
        sentPolarity.append('Moderate Positive')
    elif weight <= 2 and weight > 1:
        sentPolarity.append('Mild Positive')
    elif weight <= 1 and weight > 0:
        sentPolarity.append('Weak Positive')

df2["Polarity"] = sentPolarity
# df2.style
# Out:
# c:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Stem Causal Verbs Polarity (Whole)

# %% [markdown]
# ### Generating list of stems for whole causal verbs.

# %%
stemDagCauseVerbs = []
tagsList = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
for verb in causalVerbs:
    # print("Verb:" + verb)
    tokens = word_tokenize(str(verb))
    # print("Tokens:" + str(tokens))
    tags = pos_tag(tokens)
    # print(tags)
    for token in tokens:
        if token not in stopwords.words() or tags[0][1] in tagsList:
            # print("Token:" + token)
            stem = ps.stem(token)
            # print("Lemma:" + lemma)
            stemDagCauseVerbs.append(stem)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen = []
for sent in stemDagCauseVerbs:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        allen.append(score)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        allen.append(scores[2])
    else:
        # allen.append(scores[1])
        allen.append(0)

# %% [markdown]
# ### [Afinn]

# %%
afinn = []
for sent in stemDagCauseVerbs:
    #print(str(sent))
    score = afn.score(str(sent))
    # print(score)
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    afinn.append(score)

# %% [markdown]
# ### [Vader]

# %%
vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

for sent in stemDagCauseVerbs:
    compound = vadersentimentanalysis(str(sent))
    vader.append(compound)

# %% [markdown]
# ### [SentiStrength]

# %%
sentiStrength = []

for sent in stemDagCauseVerbs:
    result = senti.getSentiment(str(sent), score='scale')
    result = result[0]/4
    sentiStrength.append(result)

# %% [markdown]
# ### Data Frame (Stem Causal Verbs Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalVerbs, stemDagCauseVerbs, allen, afinn, vader,sentiStrength)), columns =['Causal Verb', 'Stem(Causal Verb)' ,'HuggingFace','Afinn','Vader','SentiStrength'])
df2["Weight"] = round(df2.sum(axis=1),2)

sentPolarity = []
StemVerbsWeight_tokLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    StemVerbsWeight_tokLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -4.0 and weight < -3.0:
        sentPolarity.append('Strong Negative') 
    elif weight >= -3 and weight < -2:
        sentPolarity.append('Moderate Negative')
    elif weight >= -2 and weight < -1:
        sentPolarity.append('Mild Negative')
    elif weight >= -1 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 4 and weight > 3:
        sentPolarity.append('Strong Positive')
    elif weight <= 3 and weight > 2:
        sentPolarity.append('Moderate Positive')
    elif weight <= 2 and weight > 1:
        sentPolarity.append('Mild Positive')
    elif weight <= 1 and weight > 0:
        sentPolarity.append('Weak Positive')

df2["Polarity"] = sentPolarity
# df2.style
# Out:
# c:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Overall Polarity of Sents and Triples by all Five Methods

# %%
# totalWeight_AllMethods = []

limit= len(causalSents)

# for i in range(0,limit):
#     #dataframe_WordLevel(i)
#     #print(len(allen_word[i]))
#     sum_tup = []
#     for j in range(0,len(sentsWeight_sentLevel[i])):
#         res = sentsWeight_sentLevel[i][j]+triplesWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]+triplesWeight_TokenLevel[i][j]+VerbsWeight_sentLevel[i][j]
#         #print(res)
#         res = round(res/5,2)
#         sum_tup.append(res)
#     totalWeight_AllMethods.append(sum_tup)
    
# totalPlarity_AllMethods = DetectPolarity(totalWeight_AllMethods)

# df_AllMethods = pd.DataFrame(list(zip(causalSents, causalTriples, causalVerbs,sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel, VerbsWeight_sentLevel)), 
#                              columns =['Causal Sentence', 'Causal Triple','Causal Verb' ,'Method1 (Sent_Whole)', 'Method2 (Trip_Whole)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)','Method5 (Verb_Whole)'])

df_AllMethods = pd.DataFrame(list(zip(sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel, VerbsWeight_sentLevel, LemmaVerbsWeight_tokLevel,StemVerbsWeight_tokLevel)), 
                             columns =['Method1 (Sent_Whole)', 'Method2 (Trip_Whole)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)','Method5 (Verb_Whole)','Method6 (Lemma_Verb)','Method7 (Stem_Verb)'])

# df_AllMethods.style

# %%
Method1 = []
Method2 = []
Method3 = []
Method4 = []
Method5 = []
Method6 = []
Method7 = []

for index, row in df_AllMethods.iterrows():
    Method1.append(row['Method1 (Sent_Whole)'][0])
    Method2.append(row['Method2 (Trip_Whole)'][0])
    Method3.append(row['Method3 (Sent_TokLevel)'][0])
    Method4.append(row['Method4 (Trip_TokLevel)'][0])
    Method5.append(row['Method5 (Verb_Whole)'][0])
    Method6.append(row['Method6 (Lemma_Verb)'][0])
    Method7.append(row['Method7 (Stem_Verb)'][0])

# %%
df_new = pd.DataFrame()
df_new['Strategy1'] = Method1
df_new['Strategy2'] = Method3
df_new['Strategy3'] = Method2
df_new['Strategy4'] = Method4
df_new['Strategy5'] = Method5
df_new['Strategy6'] = Method6
df_new['Strategy7'] = Method7
# df_new.style

# %%
df_new.to_excel("output.xlsx")

# %%
corr_matrix = df_new.corr()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(data=corr_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr_matrix
# Out:
#                          Method1 (Sent_Whole)  Method2 (Trip_Whole)  \
# Method1 (Sent_Whole)                 1.000000              0.929430
# Method2 (Trip_Whole)                 0.929430              1.000000
# Method3 (Sent_TokLevel)              0.902804              0.851424
# Method4 (Trip_TokLevel)              0.878078              0.917968
# Method5 (Verb_Whole)                 0.611196              0.612041
# Method6 (Lemma_Verb)                 0.062363              0.033621
# Method7 (Stem_Verb)                  0.039218              0.042844
#
#                          Method3 (Sent_TokLevel)  Method4 (Trip_TokLevel)  \
# Method1 (Sent_Whole)                    0.902804                 0.878078
# Method2 (Trip_Whole)                    0.851424                 0.917968
# Method3 (Sent_TokLevel)                 1.000000                 0.878403
# Method4 (Trip_TokLevel)                 0.878403                 1.000000
# Method5 (Verb_Whole)                    0.588101                 0.527842
# Method6 (Lemma_Verb)                    0.082415                 0.053082
# Method7 (Stem_Verb)                     0.085502                 0.061619
#
#                          Method5 (Verb_Whole)  Method6 (Lemma_Verb)  \
# Method1 (Sent_Whole)                 0.611196              0.062363
# Method2 (Trip_Whole)                 0.612041              0.033621
# Method3 (Sent_TokLevel)              0.588101              0.082415
# Method4 (Trip_TokLevel)              0.527842              0.053082
# Method5 (Verb_Whole)                 1.000000              0.079220
# Method6 (Lemma_Verb)                 0.079220              1.000000
# Method7 (Stem_Verb)                  0.088722              0.766273
#
#                          Method7 (Stem_Verb)
# Method1 (Sent_Whole)                0.039218
# Method2 (Trip_Whole)                0.042844
# Method3 (Sent_TokLevel)             0.085502
# Method4 (Trip_TokLevel)             0.061619
# Method5 (Verb_Whole)                0.088722
# Method6 (Lemma_Verb)                0.766273
# Method7 (Stem_Verb)                 1.000000
