# %%
import networkx as nx
import matplotlib.pyplot as plt 
from scipy.special import kl_div
import pysmile
import numpy as np
pysmile.License((
	b"SMILE LICENSE b120d7f5 e03fbc6a 3007cd19 "
	b"THIS IS AN ACADEMIC LICENSE AND CAN BE USED "
	b"SOLELY FOR ACADEMIC RESEARCH AND TEACHING, "
	b"AS DEFINED IN THE BAYESFUSION ACADEMIC "
	b"SOFTWARE LICENSING AGREEMENT. "
	b"Serial #: 5pmgy44gtgzun5gqbh8o40u5n "
	b"Issued for: Solat Jabeen (solatjabeen@yahoo.com) "
	b"Academic institution: Institute of Business Administration "
	b"Valid until: 2024-08-17 "
	b"Issued by BayesFusion activation server"
	),[
	0x2c,0x65,0x6e,0x68,0x4d,0x79,0xf1,0x5d,0x62,0xd2,0xcc,0xab,0x2f,0x8d,0x6d,0xf7,
	0x40,0x38,0x7d,0xab,0xca,0x8e,0xf2,0x6a,0x80,0xb5,0xee,0xdd,0x44,0xcb,0x66,0x1d,
	0xd7,0x98,0xad,0x8f,0x76,0xa0,0x1c,0x7a,0x64,0xb0,0xfb,0x81,0x62,0xaf,0xd6,0x3f,
	0xb2,0x06,0x62,0x66,0xf9,0x5f,0x5a,0x62,0x74,0x39,0xd0,0x6b,0xf6,0x03,0xef,0x45])

def FromTruthTable(i,inputs):
    count = 0

    if inputs==1:
        for a in range(1, -1, -1):
            if i == count:
                return (a)
            count = count+1

    if inputs==2:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                if i == count:
                    t = (a,b)
                    return t
                count = count+1
        
    elif inputs==3:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    if i == count:
                        t = (a,b,c)
                        return t
                    count = count+1
    
    elif inputs==4:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    for d in range(1, -1, -1):
                        if i == count:
                            t = (a,b,c,d)
                            return t
                        count = count+1

    elif inputs==5:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    for d in range(1, -1, -1):
                        for e in range(1,-1,-1):
                            if i == count:
                                t = (a,b,c,d,e)
                                return t
                            count = count+1
                            
    elif inputs==6:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    for d in range(1, -1, -1):
                        for e in range(1,-1,-1):
                            for f in range(1,-1,-1):
                                if i == count:
                                    t = (a,b,c,d,e,f)
                                    return t
                                count = count+1

class Tutorial1:
    #def __init__(self):
    def Add(self, net, id ,name, outcomes, x_pos, y_pos):
        e = self.create_cpt_node(net, id, name, outcomes, x_pos, y_pos)
        nodeNames.append(net.get_node_name(e))
        nodeIds.append(net.get_node_id(e))
        nodeHandles.append(e)
#         net.write_file("./GeNie CBN/CBN.xdsl")
        
    def AddArcs(self, net, s, d):
        net.add_arc(s, d)
#         net.write_file("./GeNie CBN/CBN.xdsl")

    def Addcpts(self, net, h, cpt):
        net. set_node_definition(h, cpt)
#         net.write_file("./GeNie CBN/CBN.xdsl")
        
    def create_cpt_node(self, net, id, name, outcomes, x_pos, y_pos):
        handle = net.add_node(pysmile.NodeType.CPT, id)
        net.set_node_name(handle, name)
        net.set_node_position(handle, x_pos, y_pos, 85, 55)
        initial_outcome_count = net.get_outcome_count(handle)
        for i in range(0, initial_outcome_count):
            net.set_outcome_id(handle, i, outcomes[i])
        for i in range(initial_outcome_count, len(outcomes)):
            net.add_outcome(handle, outcomes[i])
        return handle
    
    def print_cpt_matrix(self, net, node_handle):
        cpt = net.get_node_definition(node_handle)
        return cpt
    

def DeMorgan():    
    PDs = []
    for handle,name in zip(nodeHandles,nodeNames): 
        parent_ids = net.get_parent_ids(handle)
        num_parents = len(parent_ids)
        cpt = []
        parent_names = []
        totalCols = 1
        if num_parents == 0:
            cpt.append(baseline)
            cpt.append(1 - baseline)
            obj.Addcpts(net, handle, cpt)
        elif num_parents > 0:
            for par in parent_ids:
                    parent_names.append(net.get_node_name(par))
                    totalCols = 2 ** num_parents
            for j in range(0, totalCols):
                PI = 1
                NI = 1
                ans = FromTruthTable(j,num_parents)
                for p in range(0,len(parent_names)):
                    for edge in cwg.edges(data=True):
                        if str(parent_names[p]) == str(edge[0]) and str(name) == str(edge[1]):
                            for nbr, eattr in edge[2].items():
                                if nbr == "predicate":
                                    polarity = eattr
                                    if polarity < 0:
                                        polarity = polarity * -1
                                if nbr == "nature":
                                    n = eattr
                            break
                    if num_parents > 1:
                        if ans[p] == 0:
                            polarity = 0
                    else:
                        if ans == 0:
                            polarity = 0
                    if n == 'c':
                        PI = PI * (1 - polarity)
                    else:
                        NI = NI * (1 - polarity)
                CP = 0
                PI = 1 - (1-baseline) * PI
                NI = NI
                CP = PI * NI  
                if CP == 0:
                    CP = 0.01
                cpt.append(round(CP, 3))
                cpt.append(round((1 - CP), 3))
                pds = []
                pds.append(round(CP, 3))
                pds.append(round((1 - CP), 3))
                PDs.append(pds)
            obj.Addcpts(net, handle, cpt)
    return PDs

def GetCAstLogicStrength(polarity):
    if polarity == "Strong Negative":
        return -0.9
    elif polarity == "Moderate Negative":
        return -0.6
    elif polarity == "Mild Negative":
        return -0.6
    elif polarity == "Weak Negative":
        return -0.3
    elif polarity == "Neutral":
        return 0.1
    elif polarity == "Weak Positive":
        return 0.3
    elif polarity == "Mild Positive":
        return 0.6
    elif polarity == "Moderate Positive":
        return 0.6
    elif polarity == "Strong Positive":
        return 0.9
    
def CAST():
    PDs = []
    for handle,name in zip(nodeHandles,nodeNames): 
        parent_ids = net.get_parent_ids(handle)
        num_parents = len(parent_ids)
        cpt = []
        parent_names = []
        totalCols = 1
        if num_parents == 0:
            cpt.append(baseline)
            cpt.append(1 - baseline)
            obj.Addcpts(net, handle, cpt)
        elif num_parents > 0:
            for par in parent_ids:
                    parent_names.append(net.get_node_name(par))
                    totalCols = 2 ** num_parents
            for j in range(0, totalCols):
                PI = 1
                NI = 1
                ans = FromTruthTable(j,num_parents)
                for p in range(0,len(parent_names)):
                    for edge in cwg.edges(data=True):
                        if str(parent_names[p]) == str(edge[0]) and str(name) == str(edge[1]):
                            for nbr, eattr in edge[2].items():
                                if nbr == "predicate":
                                    polarity = eattr
                                    #polarity = GetCAstLogicStrength(eattr)
                            break
                    if num_parents > 1:
                        if ans[p] == 0:
                            polarity = 0
                    else:
                        if ans == 0:
                            polarity = 0
                    if polarity >= 0:
                        PI = PI * (1 - polarity)
                    else:
                        NI = NI * (1 - abs(polarity))
                PI = 1 - PI
                NI = 1 - NI
                AI = abs(PI - NI) / (1 - min(PI, NI))  
                CP = 0
                if PI > NI:
                    CP = baseline + ((1 - baseline) * AI)
                elif PI < NI:
                    CP = baseline - (baseline * AI)
                elif PI == NI:
                    CP = baseline
                if CP == 0:
                    CP = 0.01
                cpt.append(round(CP, 3))
                cpt.append(round((1 - CP), 3))
                pds = []
                pds.append(round(CP, 3))
                pds.append(round((1 - CP), 3))
                PDs.append(pds)
            obj.Addcpts(net, handle, cpt)
    return PDs

def GetPolarity(weight):
    if weight >= -1 and weight < -0.6:
        return 'Strong Negative' 
    elif weight >= -0.6 and weight < -0.3:
        return 'Moderate Negative'
    elif weight >= -0.3 and weight < 0:
        return 'Weak Negative'
    elif weight == 0:
        return 'Neutral'
    elif weight <= 1 and weight > 0.6:
        return 'Strong Positive'
    elif weight <= 0.6 and weight > 0.3:
        return 'Moderate Positive'
    elif weight <= 0.3 and weight > 0:
        return 'Weak Positive'
    
def Compute_KLD(P,Q):
    kl = []
    for j in range(0,len(P)):
        k = kl_div(Q[j],P[j])
        kl.append(k.sum())

    kl = np.array(kl)
    kl_divergence = round((kl.sum())/4,3)
    return kl_divergence

cwg = nx.DiGraph()
dagCauseTriples = [("A","Y"),("B","Y"),("C","Y"),("D","Y")]
types = ["c","c","i","i"]

net = pysmile.Network()
obj = Tutorial1()
outcomes = ["True","False"]
nodeNames = []    
nodeIds = []
nodeHandles = []
baseline = 0.1
x = 160
y = 40
klds = []
    
def Compute(i,j,k,l):
    weights = [i,j,k,l]
    polarities = []
    for weight in weights:
        polarities.append(GetPolarity(weight))

    for ce,w,n,p in zip(dagCauseTriples, weights, types,polarities):
        s = str(ce[0])    
        d = str(ce[1])
        cwg.add_node(s,id = str(s),title=str(s),x=615,y=200)
        cwg.add_node(d,id = str(d),title=str(d),x=615,y=200)
        cwg.add_edge(s, d, predicate=w, polarity = p,nature = n)
    if i==0.1 and j ==0.1 and k==0.1 and l==0.1:
    #if i==0.1 and j ==0.2 and k==-0.4 and l==-0.5:
        for node in cwg.nodes: 
            obj.Add(net, str(node),str(node), outcomes, x, y)
        
        for e in cwg.edges():
            for id,name in zip(nodeIds,nodeNames):
                if name == e[0]:
                    s = id
                if name == e[1]:
                    d = id 
            obj.AddArcs(net, s, d)
    pd_demorgan = DeMorgan()
#     print(len(pd_demorgan))
#     print(pd_demorgan)
#     print()
    pd_cast = CAST()
#     print(len(pd_cast))
#     print(pd_cast)
#     print()
    klds.append(Compute_KLD(pd_demorgan,pd_cast))
    
for i in np.arange(0.1, 1.0, 0.1):
    for j in np.arange(0.1, 1.0, 0.1):
        for k in np.arange(0.1, 1.0, 0.1):
            for l in np.arange(0.1, 1.0, 0.1):
                Compute(round(i,1),round(j,1),round(k,1),round(l,1))
#                 print(round(i,1),round(j,1),round(k,1),round(l,1))
                #weights = [i,j,k,l]
    
print(len(klds))
print()
print(klds)
# Out:
# 6561
#
# [0.184, 0.412, 0.75, 1.207, 1.804, 2.568, 3.565, 4.922, 7.041, 0.412, 0.667, 1.026, 1.497, 2.101, 2.866, 3.856, 5.21, 7.298, 0.75, 1.026, 1.399, 1.879, 2.489, 3.254, 4.236, 5.561, 7.643, 1.207, 1.497, 1.879, 2.367, 2.974, 3.732, 4.708, 6.014, 8.078, 1.804, 2.101, 2.489, 2.974, 3.582, 4.33, 5.292, 6.58, 8.604, 2.568, 2.866, 3.254, 3.732, 4.33, 5.073, 6.001, 7.277, 9.222, 3.565, 3.856, 4.236, 4.708, 5.292, 6.001, 6.93, 8.18, 10.076, 4.922, 5.21, 5.561, 6.014, 6.58, 7.277, 8.18, 9.336, 11.248, 7.041, 7.298, 7.643, 8.078, 8.604, 9.222, 10.076, 11.248, 13.041, 0.172, 0.386, 0.706, 1.14, 1.71, 2.443, 3.402, 4.722, 6.783, 0.386, 0.627, 0.967, 1.416, 1.992, 2.728, 3.685, 4.993, 7.041, 0.706, 0.967, 1.322, 1.78, 2.363, 3.099, 4.047, 5.339, 7.358, 1.14, 1.416, 1.78, 2.245, 2.827, 3.56, 4.503, 5.774, 7.777, 1.71, 1.992, 2.363, 2.827, 3.41, 4.132, 5.062, 6.317, 8.289, 2.443, 2.728, 3.099, 3.56, 4.132, 4.847, 5.752, 6.997, 8.917, 3.402, 3.685, 4.047, 4.503, 5.062, 5.752, 6.645, 7.857, 9.739, 4.722, 4.993, 5.339, 5.774, 6.317, 6.997, 7.857, 9.018, 10.854, 6.783, 7.041, 7.358, 7.777, 8.289, 8.917, 9.739, 10.854, 12.627, 0.166, 0.372, 0.681, 1.102, 1.654, 2.365, 3.298, 4.58, 6.606, 0.372, 0.605, 0.934, 1.368, 1.927, 2.642, 3.571, 4.848, 6.847, 0.681, 0.934, 1.277, 1.721, 2.286, 3.001, 3.924,
9.051, 4.357, 4.613, 4.932, 5.34, 5.842, 6.472, 7.278, 8.352, 10.099, 6.275, 6.517, 6.826, 7.214, 7.696, 8.271, 9.051, 10.099, 11.833, 0.172, 0.378, 0.679, 1.081, 1.6, 2.264, 3.13, 4.32, 6.21, 0.378, 0.607, 0.925, 1.338, 1.863, 2.529, 3.39, 4.575, 6.45, 0.679, 0.925, 1.254, 1.675, 2.204, 2.869, 3.726, 4.895, 6.759, 1.081, 1.338, 1.675, 2.101, 2.629, 3.29, 4.142, 5.297, 7.146, 1.6, 1.863, 2.204, 2.629, 3.158, 3.812, 4.653, 5.795, 7.625, 2.264, 2.529, 2.869, 3.29, 3.812, 4.461, 5.283, 6.415, 8.196, 3.13, 3.39, 3.726, 4.142, 4.653, 5.283, 6.098, 7.211, 8.953, 4.32, 4.575, 4.895, 5.297, 5.795, 6.415, 7.211, 8.276, 10.003, 6.21, 6.45, 6.759, 7.146, 7.625, 8.196, 8.953, 10.003, 11.701, 0.183, 0.396, 0.702, 1.105, 1.622, 2.277, 3.129, 4.298, 6.159, 0.396, 0.631, 0.952 ...

# %% [raw]
# Compute(0.1,0.2,-0.4,-0.5)

# %% [raw]
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # plt.rcParams["figure.figsize"] = [7.50, 3.50]
# plt.rcParams["figure.autolayout"] = True
#
# df = pd.DataFrame(dict(data=klds))
# fig, ax = plt.subplots()
#
# df['data'].plot(kind='bar', color='red')
# df['data'].plot(kind='line', marker='*', color='black', ms=10)
#
# plt.show()

# %% [raw]
# plt.bar(df['data'],10)
# plt.plot(df['data'], '-o', color='orange')

# %%
import matplotlib.pyplot as plt

numbers = klds

plt.hist(numbers, bins=len(klds), histtype = 'step',stacked=True)
plt.xlabel('Mean KLD')
plt.show()

# %%
import seaborn as sns

sns.distplot(klds, hist=True, kde=True, 
             bins=6561, color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3})

plt.xlabel('Mean KLD')
plt.ylabel('Density')
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Text(0, 0.5, 'Density')

# %%
sns.distplot(klds, hist=True, kde=False, 
             bins=int(6000/100), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# <AxesSubplot:>

# %%
import pandas as pd

collection = ['Food insecurity','Food insecurity','medical','Water management','political']
mean_kld_CAST = [1.124,0.758,0.891,0.464,0.839,0.292]
mean_kld_demorgan = [1.151,0.581,1.483,0.532,0.792,0.437]

plotdata = pd.DataFrame({

    "Mean KLD using CAST logic" : [1.124,0.758,0.891,0.464,0.839,0.292],

    "Mean KLD using DeMorgan" : [1.151,0.581,1.483,0.532,0.792,0.437],},
    

    index=['Food insecurity (Case I)','Food insecurity (Case II)','Medical','Water management','Political (Case I)','Political (Case II)'])

plotdata.plot(kind="bar",figsize=(15, 8))

# plt.title("Mean KLDs")

plt.xlabel("Collection")

plt.ylabel("Mean KLD")
# Out:
# Text(0, 0.5, 'Mean KLD')
