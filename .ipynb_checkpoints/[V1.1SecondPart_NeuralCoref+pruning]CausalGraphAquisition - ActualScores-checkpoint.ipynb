# %% [markdown]
# # Execute [v1.1FirstPart...] before executing this file
# # Use kernel 'second' to execute this file
# # Import necessary libraries.

# %%
import spacy
import textacy
import textacy.preprocessing
import textacy.resources
#import textacy.keyterms
#import textacy.ke
#import neuralcoref
from spacy.symbols import ORTH, POS, NOUN, VERB,PRON
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt 
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from networkx.readwrite import json_graph;
import json
from afinn import Afinn
afn = Afinn()
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
lemmatizer = WordNetLemmatizer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')
import pandas as pd
from IPython.display import display
import collections
from pd_replicator import replicator

from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax
MODEL = f"cardiffnlp/twitter-xlm-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
#model.save_pretrained(MODEL)

# from allennlp_models.pretrained import load_predictor
# predictor = load_predictor("roberta-sst")
# predictor = load_predictor("glove-sst")

# from transformers import pipeline 
# MODEL = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
# #semtiment_pipeline = pipeline("sentiment-analysis", model='cardiffnlp/twitter-roberta-base-sentiment-latest')
# semtiment_pipeline = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)

from nltk.corpus import stopwords
set(stopwords.words('english'))

from nltk.stem import PorterStemmer
ps = PorterStemmer()

nlp = spacy.load("en_core_web_sm")
#neuralcoref.add_to_pipe(nlp)

import inflect
m = inflect.engine()
from lemminflect import getInflection

from scipy.special import kl_div

import pysmile
pysmile.License((
	b"SMILE LICENSE c978699b 97c07af6 f69b7377 "
	b"THIS IS AN ACADEMIC LICENSE AND CAN BE USED "
	b"SOLELY FOR ACADEMIC RESEARCH AND TEACHING, "
	b"AS DEFINED IN THE BAYESFUSION ACADEMIC "
	b"SOFTWARE LICENSING AGREEMENT. "
	b"Serial #: damx5dd4ezqly012c37ko4l9i "
	b"Issued for: Solat Jabeen (solatjabeen@gmail.com) "
	b"Academic institution: Institute of Business Administration "
	b"Valid until: 2024-02-05 "
	b"Issued by BayesFusion activation server"
	),[
	0x73,0x67,0x28,0xba,0x6a,0x03,0x97,0x7f,0x5b,0x89,0x34,0xc7,0xc1,0x5a,0x5a,0xb3,
	0xec,0x9e,0x9e,0x6a,0x09,0xd5,0xc2,0x93,0xb4,0x57,0x24,0xc9,0x3d,0xf8,0x8d,0x25,
	0x96,0xbd,0x56,0xb8,0x3c,0xad,0x98,0x00,0xcb,0x27,0xa2,0x28,0x4b,0x1f,0x76,0xb1,
	0x92,0x1a,0x65,0x41,0xd6,0xbe,0x12,0xa3,0x4b,0x60,0x83,0x3f,0x57,0x1d,0xf7,0x23])

# %% [markdown]
# # Read text file and preprocess.

# %% [markdown]
# ### Without Neuralcoref

# %%
file_name = './Text/Simplified Guardians of Pakistan.txt'
narrative = open(file_name, encoding="utf8").read()

narrative = textacy.preprocessing.normalize_quotation_marks(narrative)
narrative = narrative.lower()
# narrative = nlp(narrative)

print('Original Narrative:')
print(narrative)

raw_sentences = sent_tokenize(narrative)

print('\nNLTK Sentences:\n')
for sent in raw_sentences:
    print(sent)
    print()
# Out:
# Original Narrative:
# afghanistan emerged as modern democratic nation. afghanistan emerged as peaceful partner. afghanistan emerged as stable partner. afghanistan was controlled by central government. afghanistan was controlled by zahir shah. afghanistan showed modernization and democracy. soviet invasion devastated modernization and democracy. civil war devastated modernization and democracy. taliban devastated modernization and democracy. soviet invasion caused tragic fragmentation and violence. civil war caused tragic fragmentation and violence. taliban caused tragic fragmentation and violence. afghanistan witnessed tragic fragmentation and violence for years. tragic fragmentation demanded afghanistan's unification. violence also demanded afghanistan's unification. afghanistan necessitates afghanistan's unification. central government must guide afghanistan's unification. central government must strengthen afghanistan's unification. afghanistan's unification can restore peace. taliban left afghanistan. afghans got opportunity. afghans must continue afghanistan's transformation. afghans must continue afghanistan's unification. zahir shah initiated afghanistan's transformation. afghanistan must achieve afghanistan's transformation. afghanistan's transformation will cause peace. afghanistan's transformation will cause prosperity. zahir shah initiated afghanistan's unification. afghans must support zahir shah. afghans must support national institutions. afghans must protect afghanistan. afghanistan must be saved from civil war. civil war leads to state's disintegration. afghans must support central government. soviet invasion initiated chaos. central government can transcend chaos. national institutions can transcend chaos. central government can cause afghanistan's transformation. national institutions can cause afghanistan's transformation. central government can cause afghanistan's unification. national institutions can cause afghanistan's unification.
#
# NLTK Sentences:
#
# afghanistan emerged as modern democratic nation.
#
# afghanistan emerged as peaceful partner.
#
# afghanistan emerged as stable partner.
#
# afghanistan was controlled by central government.
#
# afghanistan was controlled by zahir shah.
#
# afghanistan showed modernization and democracy.
#
# soviet invasion devastated modernization and democracy.
#
# civil war devastated modernization and democracy.
#
# taliban devastated modernization and democracy.
#
# soviet invasion caused tragic fragmentation and violence.
#
# civil war caused tragic fragmentation and violence.
#
# taliban caused tragic fragmentation and violence.
#
# afghanistan witnessed tragic fragmentation and violence for years.
#
# tragic fragmentation demanded afghanistan's unification.
#
# violence also demanded afghanistan's unification.
#
# afghanistan necessitates afghanistan's unification.
#
# central government must guide afghanistan's unification.
#
# central government must strengthen afghanistan's unification.
#
# afghanistan's unification can restore peace.
#
# taliban left afghanistan.
#
# afghans got opportunity.
#
# afghans must continue afghanistan's transformation.
#
# afghans must continue afghanistan's unification.
#
# zahir shah initiated afghanistan's transformation.
#
# afghanistan must achieve afghanistan's transformation.
#
# afghanistan's transformation will cause peace.
#
# afghanistan's transformation will cause prosperity.
#
# zahir shah initiated afghanistan's unification.
#
# afghans must support zahir shah.
#
# afghans must support national institutions.
#
# afghans must protect afghanistan.
#
# afghanistan must be saved from civil war.
#
# civil war leads to state's disintegration.
#
# afghans must support central government.
#
# soviet invasion initiated chaos.
#
# central government can transcend chaos.
#
# national institutions can transcend chaos.
#
# central government can cause afghanistan's transformation.
#
# national institutions can cause afghanistan's transformation.
#
# central government can cause afghanistan's unification.
#
# national institutions can cause afghanistan's unification.

# %% [markdown]
# ### After Neuralcoref

# %% [raw]
# raw_sentences = []
#
# my_file = open("./Text/AfterNeuralcoref.txt", "r")
#
# data = my_file.read()
#
# raw_sentences = data.split("\n")
# #print(data_into_list)
# my_file.close()
#
# print(len(raw_sentences))
# print('\nNLTK Sentences:\n')
# for sent in raw_sentences:
#     print(sent)

# %% [raw]
# for sent in raw_sentences:
#     sent = nlp(sent)
#     print("Sentence:")
#     print(sent)
#
#     print("Noun Chunks:")
#     for nc in sent.noun_chunks:
#         print (nc)

# %% [markdown]
# # Extract the Subject-Verb-Object triples.

# %% [raw]
# for sent in narrative.sents:
#     #print("Heyyyy!")
#     print(sent)
#     for tok in sent:
#         print(tok.text,tok.pos_,tok.dep_)

# %%
#new
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
sub = ''
obj = ''
#tuple =('a','b','c')

#print(tuple[0])

for sent in raw_sentences:
    sent = nlp(sent)
    print("Sentence:")
    print(sent)
    
    print("Noun Chunks:")
    for nc in sent.noun_chunks:
        print (nc)
        ncl.append(nc)
    print ("Number of noun chunks: ", len(ncl))
    
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            print("Triples other than textacy:")
            print(nncl[0])
            print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],triplets[0][1],ncl[1])]
#            print("Triples other than textacy:")
#            print(nncl[0])
#            finalList.append(nncl[0])
    else:
        print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                sub = token
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
                #tuple[1] = token.text
            #elif token.dep_ == 'dobj':
            #    obj = token.text
                #tuple[2] = token.text
            #    break
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue
                
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        print("Triple by combining nsubj, root and dobj:")
        print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],verb,ncl[1])]
#            print("Triples other than sub, verb and obj:")
#            print(nncl[0])
#            finalList.append(nncl[0])

    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
    
trips = finalList

#        for token in nc:
#            print(token.text, token.dep_)
# Out:
# Sentence:
# afghanistan emerged as modern democratic nation.
# Noun Chunks:
# afghanistan
# modern democratic nation
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (afghanistan, emerged, modern democratic nation)
# Sentence:
# afghanistan emerged as peaceful partner.
# Noun Chunks:
# afghanistan
# peaceful partner
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (afghanistan, emerged, peaceful partner)
# Sentence:
# afghanistan emerged as stable partner.
# Noun Chunks:
# afghanistan
# stable partner
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (afghanistan, emerged, stable partner)
# Sentence:
# afghanistan was controlled by central government.
# Noun Chunks:
# afghanistan
# central government
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (central government, controlled, afghanistan)
# Sentence:
# afghanistan was controlled by zahir shah.
# Noun Chunks:
# afghanistan
# zahir shah
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (zahir shah, controlled, afghanistan)
# Sentence:
# afghanistan showed modernization and democracy.
# Noun Chunks:
# afghanistan
# modernization
# democracy
# Number of noun chunks:  3
# Triples from textacy:
# (afghanistan, showed, modernization)
# (afghanistan, showed, democracy)
# Triples other than textacy:
# (afghanistan, showed, modernization)
# (afghanistan, showed, democracy)
# Sentence:
# soviet invasion devastated modernization and democracy.
# Noun Chunks:
# soviet invasion
# modernization
# democracy
# Number of noun chunks:  3
# Triples from textacy:
# (soviet invasion, devastated, modernization)
# (soviet invasion, devastated, democracy)
# Triples other than textacy:
# (soviet invasion, devastated, modernization)
# (soviet invasion, devastated, democracy)
# Sentence:
# civil war devastated modernization and democracy.
# Noun Chunks:
# civil war
# modernization
# democracy
# Number of noun chunks:  3
# Triples from textacy:
# (civil war, devastated, modernization)
# (civil war, devastated, democracy)
# Triples other than textacy:
# (civil war, devastated, modernization)
# (civil war, devastated, democracy)
# Sentence:
# taliban devastated modernization and democracy.
# Noun Chunks:
# taliban
# modernization
# democracy
# Number of noun chunks:  3
# Triples from textacy:
# (taliban, devastated, modernization)
# (taliban, devastated, democracy)
# Triples other than textacy:
# (taliban, devastated, modernization)
# (taliban, devastated, democracy)
# Sentence:
# soviet invasion caused tragic fragmentation and violence.
# Noun Chunks:
# soviet invasion
# tragic fragmentation
# violence
# Number of noun chunks:  3
# Triples from textacy:
# (soviet invasion, caused, tragic fragmentation)
# (soviet invasion, caused, violence)
# Triples other than textacy:
# (soviet invasion, caused, tragic fragmentation)
# (soviet invasion, caused, violence)
# Sentence:
# civil war caused tragic fragmentation and violence.
# Noun Chunks:
# civil war
# tragic fragmentation
# violence
# Number of noun chunks:  3
# Triples from textacy:
# (civil war, caused, tragic fragmentation)
# (civil war, caused, violence)
# Triples other than textacy:
# (civil war, caused, tragic fragmentation)
# (civil war, caused, violence)
# Sentence:
# taliban caused tragic fragmentation and violence.
# Noun Chunks:
# taliban
# tragic fragmentation
# violence
# Number of noun chunks:  3
# Triples from textacy:
# (taliban, caused, tragic fragmentation)
# (taliban, caused, violence)
# Triples other than textacy:
# (taliban, caused, tragic fragmentation)
# (taliban, caused, violence)
# Sentence:
# afghanistan witnessed tragic fragmentation and violence for years.
# Noun Chunks:
# afghanistan
# tragic fragmentation
# violence
# years
# Number of noun chunks:  4
# Triples from textacy:
# (afghanistan, witnessed, tragic fragmentation)
# (afghanistan, witnessed, violence)
# Sentence:
# tragic fragmentation demanded afghanistan's unification.
# Noun Chunks:
# tragic fragmentation
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (tragic fragmentation, demanded, afghanistan's unification)
# Sentence:
# violence also demanded afghanistan's unification.
# Noun Chunks:
# violence
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (violence, demanded, afghanistan's unification)
# Sentence:
# afghanistan necessitates afghanistan's unification.
# Noun Chunks:
# afghanistan
# afghanistan's unification
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (afghanistan's unification, necessitates, afghanistan's unification)
# Sentence:
# central government must guide afghanistan's unification.
# Noun Chunks:
# central government
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (central government, must guide, afghanistan's unification)
# Sentence:
# central government must strengthen afghanistan's unification.
# Noun Chunks:
# central government
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (central government, must strengthen, afghanistan's unification)
# Sentence:
# afghanistan's unification can restore peace.
# Noun Chunks:
# afghanistan's unification
# peace
# Number of noun chunks:  2
# Triples from textacy:
# (afghanistan's unification, can restore, peace)
# Sentence:
# taliban left afghanistan.
# Noun Chunks:
# taliban
# afghanistan
# Number of noun chunks:  2
# Triples from textacy:
# (taliban, left, afghanistan)
# Sentence:
# afghans got opportunity.
# Noun Chunks:
# afghans
# opportunity
# Number of noun chunks:  2
# Triples from textacy:
# (afghans, got, opportunity)
# Sentence:
# afghans must continue afghanistan's transformation.
# Noun Chunks:
# afghans
# afghanistan's transformation
# Number of noun chunks:  2
# Triples from textacy:
# (afghans, must continue, afghanistan's transformation)
# Sentence:
# afghans must continue afghanistan's unification.
# Noun Chunks:
# afghans
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (afghans, must continue, afghanistan's unification)
# Sentence:
# zahir shah initiated afghanistan's transformation.
# Noun Chunks:
# zahir shah
# afghanistan's transformation
# Number of noun chunks:  2
# Triples from textacy:
# (zahir shah, initiated, afghanistan's transformation)
# Sentence:
# afghanistan must achieve afghanistan's transformation.
# Noun Chunks:
# afghanistan
# afghanistan's transformation
# Number of noun chunks:  2
# Triples from textacy:
# (afghanistan's transformation, must achieve, afghanistan's transformation)
# Sentence:
# afghanistan's transformation will cause peace.
# Noun Chunks:
# afghanistan's transformation
# peace
# Number of noun chunks:  2
# Triples from textacy:
# (afghanistan's transformation, will cause, peace)
# Sentence:
# afghanistan's transformation will cause prosperity.
# Noun Chunks:
# afghanistan's transformation
# prosperity
# Number of noun chunks:  2
# Triples from textacy:
# (afghanistan's transformation, will cause, prosperity)
# Sentence:
# zahir shah initiated afghanistan's unification.
# Noun Chunks:
# zahir shah
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (zahir shah, initiated, afghanistan's unification)
# Sentence:
# afghans must support zahir shah.
# Noun Chunks:
# afghans
# zahir shah
# Number of noun chunks:  2
# Triples from textacy:
# (afghans, must support, zahir shah)
# Sentence:
# afghans must support national institutions.
# Noun Chunks:
# afghans
# national institutions
# Number of noun chunks:  2
# Triples from textacy:
# (afghans, must support, national institutions)
# Sentence:
# afghans must protect afghanistan.
# Noun Chunks:
# afghans
# afghanistan
# Number of noun chunks:  2
# Triples from textacy:
# (afghans, must protect, afghanistan)
# Sentence:
# afghanistan must be saved from civil war.
# Noun Chunks:
# afghanistan
# civil war
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (civil war, saved, afghanistan)
# Sentence:
# civil war leads to state's disintegration.
# Noun Chunks:
# civil war
# state's disintegration
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (civil war, leads, state's disintegration)
# Sentence:
# afghans must support central government.
# Noun Chunks:
# afghans
# central government
# Number of noun chunks:  2
# Triples from textacy:
# (afghans, must support, central government)
# Sentence:
# soviet invasion initiated chaos.
# Noun Chunks:
# soviet invasion
# chaos
# Number of noun chunks:  2
# Triples from textacy:
# (soviet invasion, initiated, chaos)
# Sentence:
# central government can transcend chaos.
# Noun Chunks:
# central government
# chaos
# Number of noun chunks:  2
# Triples from textacy:
# (central government, can transcend, chaos)
# Sentence:
# national institutions can transcend chaos.
# Noun Chunks:
# national institutions
# chaos
# Number of noun chunks:  2
# Triples from textacy:
# (national institutions, can transcend, chaos)
# Sentence:
# central government can cause afghanistan's transformation.
# Noun Chunks:
# central government
# afghanistan's transformation
# Number of noun chunks:  2
# Triples from textacy:
# (central government, can cause, afghanistan's transformation)
# Sentence:
# national institutions can cause afghanistan's transformation.
# Noun Chunks:
# national institutions
# afghanistan's transformation
# Number of noun chunks:  2
# Triples from textacy:
# (national institutions, can cause, afghanistan's transformation)
# Sentence:
# central government can cause afghanistan's unification.
# Noun Chunks:
# central government
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (central government, can cause, afghanistan's unification)
# Sentence:
# national institutions can cause afghanistan's unification.
# Noun Chunks:
# national institutions
# afghanistan's unification
# Number of noun chunks:  2
# Triples from textacy:
# (national institutions, can cause, afghanistan's unification)

# %% [raw]
# #old
# def SVO(narrative):
#     ncl = []
#     fl = []
#     nncl = [()]
#     for sent in narrative.sents:
#         #sent = str(sent)
#         print("\n" + str(sent))
#         for nc in sent.noun_chunks:
#             print (nc)
#             ncl.append(nc)
#         print(len(ncl))
#         triplets = textacy.extract.subject_verb_object_triples(sent)
#         triplets = list(triplets)
#         if len(ncl) <= 3:
#             if len(triplets) == 0:
#                 print("Method from textacy; subject_verb_object_triples extracted nothing!")
#                 for token in sent:
#                 #print(token.text, token.dep_,)
#                     if token.dep_ == 'ROOT':
#                         text = token.text
#                         break
#                     #print(token.text)
#                 if len(ncl) == 3:
#                         nncl = [(ncl[0],token.text,ncl[1])]
#                         nncl.append((ncl[0],token.text,ncl[2]))
#                         fl.append(nncl[0])
#                         fl.append(nncl[1])
#                 elif len(ncl) == 2:
#                         nncl = [(ncl[0],token.text,ncl[1])]
#                         fl.append(nncl[0])
#                 else:
#                     continue
#                 print("Triples without textacy.")
#                 print(nncl)
#
#             else:
#                 print(triplets)
#                 for t in triplets:
#                     print(t)
#                     fl.append(t)
#                 if len(ncl) == 3:
#                     nncl = [(ncl[0],triplets[0][1],ncl[1])]
#                     nncl.append((ncl[0],triplets[0][1],ncl[2]))
#                     fl.append(nncl[0])
#                     fl.append(nncl[1])
#                     #print(nncl[0])
#                     #print(nncl[1])
#                 elif len(ncl) == 2:
#                     nncl = [(ncl[0],triplets[0][1],ncl[1])]
#                     fl.append(nncl[0])
#                 else:
#                     continue;
#                 print(nncl)
#         ncl.clear()
#         nncl.clear()
#     return fl
#
# trips = SVO(narrative)

# %% [markdown]
# # Remove Duplicates from Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("Length of triples' List before removing duplicates:")
print(len(trips))

Triples = []
sentences1 = []

for sentence,ce in zip(sentences, trips):
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        sentences1.append(sentence)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            sentences1.append(sentence)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

for t in Triples:
    print(t)
# Out:
# Length of triples' List before removing duplicates:
# 63
#
# List after removing duplicates:
# 49
# (afghanistan, emerged, modern democratic nation)
# (afghanistan, emerged, peaceful partner)
# (afghanistan, emerged, stable partner)
# (central government, controlled, afghanistan)
# (zahir shah, controlled, afghanistan)
# (afghanistan, showed, modernization)
# (afghanistan, showed, democracy)
# (soviet invasion, devastated, modernization)
# (soviet invasion, devastated, democracy)
# (civil war, devastated, modernization)
# (civil war, devastated, democracy)
# (taliban, devastated, modernization)
# (taliban, devastated, democracy)
# (soviet invasion, caused, tragic fragmentation)
# (soviet invasion, caused, violence)
# (civil war, caused, tragic fragmentation)
# (civil war, caused, violence)
# (taliban, caused, tragic fragmentation)
# (taliban, caused, violence)
# (afghanistan, witnessed, tragic fragmentation)
# (afghanistan, witnessed, violence)
# (tragic fragmentation, demanded, afghanistan's unification)
# (violence, demanded, afghanistan's unification)
# (afghanistan's unification, necessitates, afghanistan's unification)
# (central government, must guide, afghanistan's unification)
# (central government, must strengthen, afghanistan's unification)
# (afghanistan's unification, can restore, peace)
# (taliban, left, afghanistan)
# (afghans, got, opportunity)
# (afghans, must continue, afghanistan's transformation)
# (afghans, must continue, afghanistan's unification)
# (zahir shah, initiated, afghanistan's transformation)
# (afghanistan's transformation, must achieve, afghanistan's transformation)
# (afghanistan's transformation, will cause, peace)
# (afghanistan's transformation, will cause, prosperity)
# (zahir shah, initiated, afghanistan's unification)
# (afghans, must support, zahir shah)
# (afghans, must support, national institutions)
# (afghans, must protect, afghanistan)
# (civil war, saved, afghanistan)
# (civil war, leads, state's disintegration)
# (afghans, must support, central government)
# (soviet invasion, initiated, chaos)
# (central government, can transcend, chaos)
# (national institutions, can transcend, chaos)
# (central government, can cause, afghanistan's transformation)
# (national institutions, can cause, afghanistan's transformation)
# (central government, can cause, afghanistan's unification)
# (national institutions, can cause, afghanistan's unification)

# %% [markdown]
# # Filter correct triples from extracted triples

# %%
correctTriples = []
sentences2 = []

for sentence,line in zip(sentences1, Triples):
    taggedWords = []
    taggedWords1 = []
    check0 = False
    check2 = False
    print(line)
    taggedWords = pos_tag(word_tokenize(str(line[0])))
    taggedWords1 = pos_tag(word_tokenize(str(line[2])))
    print(taggedWords)
    print(taggedWords1)
    for i in range(len(taggedWords)):
        if taggedWords[i][1] == 'PRP$': # PRP$ possessive pronoun – my, his, hers
            check0 = False
            break
        if taggedWords[i][1] == 'NN' or taggedWords[i][1] == 'NNS' or taggedWords[i][1] == 'VBG' and taggedWords[i][1] != 'PRP$':
            check0 = True
    for i in range(len(taggedWords1)):
        if taggedWords1[i][1] == 'PRP$':
            check2 = False
            break
        elif taggedWords1[i][1] == 'NN' or taggedWords1[i][1] == 'NNS' or taggedWords1[i][1] == 'VBG':
            check2 = True
    print(check0)  
    print(check2)
    if check0 == True and check2 == True:
        correctTriples.append(line)
        sentences2.append(sentence)
    print("**************************************************************************")
    
for correctTriple in correctTriples:
    print(correctTriple)
# Out:
# (afghanistan, emerged, modern democratic nation)
# [('afghanistan', 'NN')]
# [('modern', 'JJ'), ('democratic', 'JJ'), ('nation', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan, emerged, peaceful partner)
# [('afghanistan', 'NN')]
# [('peaceful', 'JJ'), ('partner', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan, emerged, stable partner)
# [('afghanistan', 'NN')]
# [('stable', 'JJ'), ('partner', 'NN')]
# True
# True
# **************************************************************************
# (central government, controlled, afghanistan)
# [('central', 'JJ'), ('government', 'NN')]
# [('afghanistan', 'NN')]
# True
# True
# **************************************************************************
# (zahir shah, controlled, afghanistan)
# [('zahir', 'NN'), ('shah', 'NN')]
# [('afghanistan', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan, showed, modernization)
# [('afghanistan', 'NN')]
# [('modernization', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan, showed, democracy)
# [('afghanistan', 'NN')]
# [('democracy', 'NN')]
# True
# True
# **************************************************************************
# (soviet invasion, devastated, modernization)
# [('soviet', 'JJ'), ('invasion', 'NN')]
# [('modernization', 'NN')]
# True
# True
# **************************************************************************
# (soviet invasion, devastated, democracy)
# [('soviet', 'JJ'), ('invasion', 'NN')]
# [('democracy', 'NN')]
# True
# True
# **************************************************************************
# (civil war, devastated, modernization)
# [('civil', 'JJ'), ('war', 'NN')]
# [('modernization', 'NN')]
# True
# True
# **************************************************************************
# (civil war, devastated, democracy)
# [('civil', 'JJ'), ('war', 'NN')]
# [('democracy', 'NN')]
# True
# True
# **************************************************************************
# (taliban, devastated, modernization)
# [('taliban', 'NN')]
# [('modernization', 'NN')]
# True
# True
# **************************************************************************
# (taliban, devastated, democracy)
# [('taliban', 'NN')]
# [('democracy', 'NN')]
# True
# True
# **************************************************************************
# (soviet invasion, caused, tragic fragmentation)
# [('soviet', 'JJ'), ('invasion', 'NN')]
# [('tragic', 'JJ'), ('fragmentation', 'NN')]
# True
# True
# **************************************************************************
# (soviet invasion, caused, violence)
# [('soviet', 'JJ'), ('invasion', 'NN')]
# [('violence', 'NN')]
# True
# True
# **************************************************************************
# (civil war, caused, tragic fragmentation)
# [('civil', 'JJ'), ('war', 'NN')]
# [('tragic', 'JJ'), ('fragmentation', 'NN')]
# True
# True
# **************************************************************************
# (civil war, caused, violence)
# [('civil', 'JJ'), ('war', 'NN')]
# [('violence', 'NN')]
# True
# True
# **************************************************************************
# (taliban, caused, tragic fragmentation)
# [('taliban', 'NN')]
# [('tragic', 'JJ'), ('fragmentation', 'NN')]
# True
# True
# **************************************************************************
# (taliban, caused, violence)
# [('taliban', 'NN')]
# [('violence', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan, witnessed, tragic fragmentation)
# [('afghanistan', 'NN')]
# [('tragic', 'JJ'), ('fragmentation', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan, witnessed, violence)
# [('afghanistan', 'NN')]
# [('violence', 'NN')]
# True
# True
# **************************************************************************
# (tragic fragmentation, demanded, afghanistan's unification)
# [('tragic', 'JJ'), ('fragmentation', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (violence, demanded, afghanistan's unification)
# [('violence', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan's unification, necessitates, afghanistan's unification)
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (central government, must guide, afghanistan's unification)
# [('central', 'JJ'), ('government', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (central government, must strengthen, afghanistan's unification)
# [('central', 'JJ'), ('government', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan's unification, can restore, peace)
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# [('peace', 'NN')]
# True
# True
# **************************************************************************
# (taliban, left, afghanistan)
# [('taliban', 'NN')]
# [('afghanistan', 'NN')]
# True
# True
# **************************************************************************
# (afghans, got, opportunity)
# [('afghans', 'NNS')]
# [('opportunity', 'NN')]
# True
# True
# **************************************************************************
# (afghans, must continue, afghanistan's transformation)
# [('afghans', 'NNS')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# True
# True
# **************************************************************************
# (afghans, must continue, afghanistan's unification)
# [('afghans', 'NNS')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (zahir shah, initiated, afghanistan's transformation)
# [('zahir', 'NN'), ('shah', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan's transformation, must achieve, afghanistan's transformation)
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan's transformation, will cause, peace)
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# [('peace', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan's transformation, will cause, prosperity)
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# [('prosperity', 'NN')]
# True
# True
# **************************************************************************
# (zahir shah, initiated, afghanistan's unification)
# [('zahir', 'NN'), ('shah', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (afghans, must support, zahir shah)
# [('afghans', 'NNS')]
# [('zahir', 'NN'), ('shah', 'NN')]
# True
# True
# **************************************************************************
# (afghans, must support, national institutions)
# [('afghans', 'NNS')]
# [('national', 'JJ'), ('institutions', 'NNS')]
# True
# True
# **************************************************************************
# (afghans, must protect, afghanistan)
# [('afghans', 'NNS')]
# [('afghanistan', 'NN')]
# True
# True
# **************************************************************************
# (civil war, saved, afghanistan)
# [('civil', 'JJ'), ('war', 'NN')]
# [('afghanistan', 'NN')]
# True
# True
# **************************************************************************
# (civil war, leads, state's disintegration)
# [('civil', 'JJ'), ('war', 'NN')]
# [('state', 'NN'), ("'s", 'POS'), ('disintegration', 'NN')]
# True
# True
# **************************************************************************
# (afghans, must support, central government)
# [('afghans', 'NNS')]
# [('central', 'JJ'), ('government', 'NN')]
# True
# True
# **************************************************************************
# (soviet invasion, initiated, chaos)
# [('soviet', 'JJ'), ('invasion', 'NN')]
# [('chaos', 'NN')]
# True
# True
# **************************************************************************
# (central government, can transcend, chaos)
# [('central', 'JJ'), ('government', 'NN')]
# [('chaos', 'NN')]
# True
# True
# **************************************************************************
# (national institutions, can transcend, chaos)
# [('national', 'JJ'), ('institutions', 'NNS')]
# [('chaos', 'NN')]
# True
# True
# **************************************************************************
# (central government, can cause, afghanistan's transformation)
# [('central', 'JJ'), ('government', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# True
# True
# **************************************************************************
# (national institutions, can cause, afghanistan's transformation)
# [('national', 'JJ'), ('institutions', 'NNS')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('transformation', 'NN')]
# True
# True
# **************************************************************************
# (central government, can cause, afghanistan's unification)
# [('central', 'JJ'), ('government', 'NN')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (national institutions, can cause, afghanistan's unification)
# [('national', 'JJ'), ('institutions', 'NNS')]
# [('afghanistan', 'NN'), ("'s", 'POS'), ('unification', 'NN')]
# True
# True
# **************************************************************************
# (afghanistan, emerged, modern democratic nation)
# (afghanistan, emerged, peaceful partner)
# (afghanistan, emerged, stable partner)
# (central government, controlled, afghanistan)
# (zahir shah, controlled, afghanistan)
# (afghanistan, showed, modernization)
# (afghanistan, showed, democracy)
# (soviet invasion, devastated, modernization)
# (soviet invasion, devastated, democracy)
# (civil war, devastated, modernization)
# (civil war, devastated, democracy)
# (taliban, devastated, modernization)
# (taliban, devastated, democracy)
# (soviet invasion, caused, tragic fragmentation)
# (soviet invasion, caused, violence)
# (civil war, caused, tragic fragmentation)
# (civil war, caused, violence)
# (taliban, caused, tragic fragmentation)
# (taliban, caused, violence)
# (afghanistan, witnessed, tragic fragmentation)
# (afghanistan, witnessed, violence)
# (tragic fragmentation, demanded, afghanistan's unification)
# (violence, demanded, afghanistan's unification)
# (afghanistan's unification, necessitates, afghanistan's unification)
# (central government, must guide, afghanistan's unification)
# (central government, must strengthen, afghanistan's unification)
# (afghanistan's unification, can restore, peace)
# (taliban, left, afghanistan)
# (afghans, got, opportunity)
# (afghans, must continue, afghanistan's transformation)
# (afghans, must continue, afghanistan's unification)
# (zahir shah, initiated, afghanistan's transformation)
# (afghanistan's transformation, must achieve, afghanistan's transformation)
# (afghanistan's transformation, will cause, peace)
# (afghanistan's transformation, will cause, prosperity)
# (zahir shah, initiated, afghanistan's unification)
# (afghans, must support, zahir shah)
# (afghans, must support, national institutions)
# (afghans, must protect, afghanistan)
# (civil war, saved, afghanistan)
# (civil war, leads, state's disintegration)
# (afghans, must support, central government)
# (soviet invasion, initiated, chaos)
# (central government, can transcend, chaos)
# (national institutions, can transcend, chaos)
# (central government, can cause, afghanistan's transformation)
# (national institutions, can cause, afghanistan's transformation)
# (central government, can cause, afghanistan's unification)
# (national institutions, can cause, afghanistan's unification)

# %% [markdown]
# # Print the extracted triples with sentences.

# %%
for sentence, triple  in zip(sentences2, correctTriples):
    print(sentence, triple)
    print()
# Out:
# afghanistan emerged as modern democratic nation. (afghanistan, emerged, modern democratic nation)
#
# afghanistan emerged as peaceful partner. (afghanistan, emerged, peaceful partner)
#
# afghanistan emerged as stable partner. (afghanistan, emerged, stable partner)
#
# afghanistan was controlled by central government. (central government, controlled, afghanistan)
#
# afghanistan was controlled by zahir shah. (zahir shah, controlled, afghanistan)
#
# afghanistan showed modernization and democracy. (afghanistan, showed, modernization)
#
# afghanistan showed modernization and democracy. (afghanistan, showed, democracy)
#
# soviet invasion devastated modernization and democracy. (soviet invasion, devastated, modernization)
#
# soviet invasion devastated modernization and democracy. (soviet invasion, devastated, democracy)
#
# civil war devastated modernization and democracy. (civil war, devastated, modernization)
#
# civil war devastated modernization and democracy. (civil war, devastated, democracy)
#
# taliban devastated modernization and democracy. (taliban, devastated, modernization)
#
# taliban devastated modernization and democracy. (taliban, devastated, democracy)
#
# soviet invasion caused tragic fragmentation and violence. (soviet invasion, caused, tragic fragmentation)
#
# soviet invasion caused tragic fragmentation and violence. (soviet invasion, caused, violence)
#
# civil war caused tragic fragmentation and violence. (civil war, caused, tragic fragmentation)
#
# civil war caused tragic fragmentation and violence. (civil war, caused, violence)
#
# taliban caused tragic fragmentation and violence. (taliban, caused, tragic fragmentation)
#
# taliban caused tragic fragmentation and violence. (taliban, caused, violence)
#
# afghanistan witnessed tragic fragmentation and violence for years. (afghanistan, witnessed, tragic fragmentation)
#
# afghanistan witnessed tragic fragmentation and violence for years. (afghanistan, witnessed, violence)
#
# tragic fragmentation demanded afghanistan's unification. (tragic fragmentation, demanded, afghanistan's unification)
#
# violence also demanded afghanistan's unification. (violence, demanded, afghanistan's unification)
#
# afghanistan necessitates afghanistan's unification. (afghanistan's unification, necessitates, afghanistan's unification)
#
# central government must guide afghanistan's unification. (central government, must guide, afghanistan's unification)
#
# central government must strengthen afghanistan's unification. (central government, must strengthen, afghanistan's unification)
#
# afghanistan's unification can restore peace. (afghanistan's unification, can restore, peace)
#
# taliban left afghanistan. (taliban, left, afghanistan)
#
# afghans got opportunity. (afghans, got, opportunity)
#
# afghans must continue afghanistan's transformation. (afghans, must continue, afghanistan's transformation)
#
# afghans must continue afghanistan's unification. (afghans, must continue, afghanistan's unification)
#
# zahir shah initiated afghanistan's transformation. (zahir shah, initiated, afghanistan's transformation)
#
# afghanistan must achieve afghanistan's transformation. (afghanistan's transformation, must achieve, afghanistan's transformation)
#
# afghanistan's transformation will cause peace. (afghanistan's transformation, will cause, peace)
#
# afghanistan's transformation will cause prosperity. (afghanistan's transformation, will cause, prosperity)
#
# zahir shah initiated afghanistan's unification. (zahir shah, initiated, afghanistan's unification)
#
# afghans must support zahir shah. (afghans, must support, zahir shah)
#
# afghans must support national institutions. (afghans, must support, national institutions)
#
# afghans must protect afghanistan. (afghans, must protect, afghanistan)
#
# afghanistan must be saved from civil war. (civil war, saved, afghanistan)
#
# civil war leads to state's disintegration. (civil war, leads, state's disintegration)
#
# afghans must support central government. (afghans, must support, central government)
#
# soviet invasion initiated chaos. (soviet invasion, initiated, chaos)
#
# central government can transcend chaos. (central government, can transcend, chaos)
#
# national institutions can transcend chaos. (national institutions, can transcend, chaos)
#
# central government can cause afghanistan's transformation. (central government, can cause, afghanistan's transformation)
#
# national institutions can cause afghanistan's transformation. (national institutions, can cause, afghanistan's transformation)
#
# central government can cause afghanistan's unification. (central government, can cause, afghanistan's unification)
#
# national institutions can cause afghanistan's unification. (national institutions, can cause, afghanistan's unification)

# %% [markdown]
# # Plot the knowledge Graph.

# %%
cmap = nx.DiGraph()

for triple in correctTriples:
    s = str(triple[0])    
    d = str(triple[2])
    cmap.add_edge(s, d, predicate=triple[1])
    #print(triple)

print("Nodes:",len(cmap.nodes))
print("Edges:",len(cmap.edges))
for e in cmap.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cmap, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cmap, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cmap.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cmap,'predicate')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 22
# Edges: 47
# afghanistan , {'predicate': emerged} , modern democratic nation
# afghanistan , {'predicate': emerged} , peaceful partner
# afghanistan , {'predicate': emerged} , stable partner
# afghanistan , {'predicate': showed} , modernization
# afghanistan , {'predicate': showed} , democracy
# afghanistan , {'predicate': witnessed} , tragic fragmentation
# afghanistan , {'predicate': witnessed} , violence
# central government , {'predicate': controlled} , afghanistan
# central government , {'predicate': can cause} , afghanistan's unification
# central government , {'predicate': can transcend} , chaos
# central government , {'predicate': can cause} , afghanistan's transformation
# zahir shah , {'predicate': controlled} , afghanistan
# zahir shah , {'predicate': initiated} , afghanistan's transformation
# zahir shah , {'predicate': initiated} , afghanistan's unification
# soviet invasion , {'predicate': devastated} , modernization
# soviet invasion , {'predicate': devastated} , democracy
# soviet invasion , {'predicate': caused} , tragic fragmentation
# soviet invasion , {'predicate': caused} , violence
# soviet invasion , {'predicate': initiated} , chaos
# civil war , {'predicate': devastated} , modernization
# civil war , {'predicate': devastated} , democracy
# civil war , {'predicate': caused} , tragic fragmentation
# civil war , {'predicate': caused} , violence
# civil war , {'predicate': saved} , afghanistan
# civil war , {'predicate': leads} , state's disintegration
# taliban , {'predicate': devastated} , modernization
# taliban , {'predicate': devastated} , democracy
# taliban , {'predicate': caused} , tragic fragmentation
# taliban , {'predicate': caused} , violence
# taliban , {'predicate': left} , afghanistan
# tragic fragmentation , {'predicate': demanded} , afghanistan's unification
# violence , {'predicate': demanded} , afghanistan's unification
# afghanistan's unification , {'predicate': necessitates} , afghanistan's unification
# afghanistan's unification , {'predicate': can restore} , peace
# afghans , {'predicate': got} , opportunity
# afghans , {'predicate': must continue} , afghanistan's transformation
# afghans , {'predicate': must continue} , afghanistan's unification
# afghans , {'predicate': must support} , zahir shah
# afghans , {'predicate': must support} , national institutions
# afghans , {'predicate': must protect} , afghanistan
# afghans , {'predicate': must support} , central government
# afghanistan's transformation , {'predicate': must achieve} , afghanistan's transformation
# afghanistan's transformation , {'predicate': will cause} , peace
# afghanistan's transformation , {'predicate': will cause} , prosperity
# national institutions , {'predicate': can transcend} , chaos
# national institutions , {'predicate': can cause} , afghanistan's transformation
# national institutions , {'predicate': can cause} , afghanistan's unification

# %% [markdown]
# # Dump the Knowledge Graph on "Knowledge Graph.json"

# %% [raw]
# knowledgeGraph = nx.DiGraph()
#
# for svo in correctTriples:
#     s = str(svo[0])
#     d = str(svo[2])
#     knowledgeGraph.add_node(s,id = str(s),title=str(s),x=615,y=200)
#     knowledgeGraph.add_node(d,id = str(d),title=str(d),x=615,y=200)
#     knowledgeGraph.add_edge(s, d, predicade=str(svo[1]))
#
# #print(len(knowledgeGraph.nodes))
# #print(len(knowledgeGraph.edges))
#
# data = json_graph.node_link_data(knowledgeGraph)
#
#
# out_file = open("./Json Graphs/Knowledge Graph.json", "w")
#
# json.dump(data, out_file, indent = 6)
#
# out_file.close()

# %% [markdown]
# # Create Causal Trigger Words Dictionary along with their synonyms.

# %% [raw]
# # LATEST
# #from Causal Verbs File
#
# causalWords1 = []
# my_file = open(".\CausalVerbs.txt", "r")
# data = my_file.read()
# causalWords1 = data.split("\n")
# my_file.close()
#
# synonyms1 = []
# lemma_function = WordNetLemmatizer()
#
# for cw1 in causalWords1:
# #     print(cw1)
#     synonyms1.append(cw1.lower())
# #     print(ps.stem(cw1.lower()))
#     synonyms1.append(ps.stem(cw1.lower()))
# #     print(lemma_function.lemmatize(cw1.lower()))
#     synonyms1.append(lemma_function.lemmatize(cw1.lower()))
# #     print(m.plural(cw1))
#     synonyms1.append(m.plural(cw1))
# #     print(getInflection(cw1, tag='VBD')[0])
#     synonyms1.append(getInflection(cw1, tag='VBD')[0])
# #     print(wordnet.synsets(getInflection(cw1, tag='VBD')[0]))
#     for syn in wordnet.synsets(getInflection(cw1, tag='VBD')[0]):
# #         print(syn)
# #         print(syn.lemmas())
#         for l1 in syn.lemmas():
#             synonyms1.append(l1.name().lower())
#             synonyms1.append(ps.stem(l1.name().lower()))
#             synonyms1.append(lemma_function.lemmatize(l1.name().lower()))
#             synonyms1.append(m.plural(l1.name()))
#             synonyms1.append(getInflection(l1.name(), tag='VBD')[0])
# #             print(wordnet.synsets(str(l1.name())))
#             for syn1 in wordnet.synsets(str(l1.name())):
#                 for l2 in syn1.lemmas():
#                     synonyms1.append(l2.name().lower())
#                     #synonyms1.append(ps.stem(l2.name().lower()))
#                     #synonyms1.append(lemma_function.lemmatize(l2.name().lower()))
#                     synonyms1.append(m.plural(l2.name()))
#                     synonyms1.append(getInflection(l2.name(), tag='VBD')[0])
#
# #remove duplicates from synonyms1
# synonyms = []
#
# for synonym in synonyms1:
#     if synonym not in synonyms:
#         synonyms.append(synonym)
#
#
# print(len(causalWords1))
# print(len(synonyms))
# # print(synonyms)

# %% [raw]
# #new
#
# causalWords1 = ["seized","seize","forced","caused", "resulted", "reason", "as a result of", "as a consequence of",
#                "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
#                ,"made","minimize","maximize","hindered", "displaced", "conspired","led to","activate","impel","inspire",
#                 "excite","quicken","rouse","stimulate","influence","determine","likely","probable","disconnected","separated"
#                 ,"excluded","after","as","since","trigger","oppose","fight","provides","strengthened","launched","develop"
#                ,"guarantees","declared", "developed","produced","discourages","demotivated","eliminate","terminate","eradicated","eradicate","terminated","eliminated","encouraged","motivated","freed","free","incited","incite"]
#
# # causalWords1 = []
# # my_file = open(".\CausalVerbs.txt", "r")
# # data = my_file.read()
# # causalWords1 = data.split("\n")
# # my_file.close()
#
# synonyms1 = []
# lemma_function = WordNetLemmatizer()
#
# for cw1 in causalWords1:
#     #print(cw1)
#     synonyms1.append(cw1.lower())
#     tokens1 = word_tokenize(cw1)
#     for token1, tag1 in pos_tag(tokens1):
#         lemma1 = lemma_function.lemmatize(token1)
#         #print(token1,lemma1)
#
#         for syn in wordnet.synsets(str(lemma1)):
#
#             for l1 in syn.lemmas():
#                 #print(l1)
#                 #synonyms1.append(lemma1.lower())
#                 synonyms1.append(l1.name().lower())
#                 #print(l1)
#                 for syn1 in wordnet.synsets(str(l1.name())):
#                     for l2 in syn1.lemmas():
#                         #print(l2)
#                         synonyms1.append(l2.name().lower())
#
#
# #remove duplicates from synonyms1
# synonyms = []
#
# for synonym in synonyms1:
#     if synonym not in synonyms:
#         synonyms.append(synonym)
#
# #for x in synonyms:
# #    print (synonym)
# print(len(causalWords1))
# print(len(synonyms))

# %% [markdown]
# # Writing causal trigger words dictionary to text file (dictionary.txt)

# %% [raw]
# #synonyms
# output_file = open('.\dictionary.txt', 'w')
#
# for w in synonyms:
#     #print(syn)
#     output_file.write(w + '\n')
#
# output_file.close()

# %% [markdown]
# # Reading causal trigger words dictionary from text file (dictionary.txt) to list

# %%
synonyms = []

my_file = open(".\dictionary.txt", "r")
  
data = my_file.read()
  
synonyms = data.split("\n")
#print(data_into_list)
my_file.close()

print(len(synonyms))
# Out:
# 3227

# %% [raw]
# #old
#
# causalWords = ["forced","caused", "result", "reason", "as a result of", "as a consequence of",
#                "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
#                ,"made","mimimize","maximize","led to","produced"]
#
# #causalWords = ["as a result of"]
# synonyms = []
#
# for cw in causalWords:
#
#     for syn in wordnet.synsets(str(cw)):
#         for l in syn.lemmas():
#             synonyms.append(cw)
#             synonyms.append(l.name())
#
# print(set(synonyms))
# print(len(synonyms))

# %% [markdown]
# # Filter Causal triples along with their causal sentences from SVO triples based upon causal trigger words dictionary.

# %%
#new

causeffect = [] #without duplicates
causalSentences = [] #with duplicates

lemma_function = WordNetLemmatizer()
for s,st in zip(sentences2,correctTriples):
    check = False
    tokens = word_tokenize(str(st[1]))
    for token, tag in pos_tag(tokens):
        tok = token
        lemma = lemma_function.lemmatize(token)
        stem = ps.stem(token)
        
    for synonym in synonyms:
        if synonym == lemma or synonym == tok or synonym == stem:
            if len(causeffect) == 0:
                causeffect.append(st)
                causalSentences.append(s)
            else:
                for ct in causeffect:
                    if str(st[0]) == str(ct[0]) and str(st[1]) == str(ct[1]) and str(st[2]) == str(ct[2]):
                        check = True
                        break;
                if check == False:
                    causeffect.append(st)
                    causalSentences.append(s)
            break
    

print(len(causalSentences))
print(len(causeffect))
for causalSentence, causalTriple  in zip(causalSentences, causeffect):
    print(causalSentence, causalTriple)
# Out:
# 30
# 30
# afghanistan was controlled by central government. (central government, controlled, afghanistan)
# afghanistan was controlled by zahir shah. (zahir shah, controlled, afghanistan)
# afghanistan showed modernization and democracy. (afghanistan, showed, modernization)
# afghanistan showed modernization and democracy. (afghanistan, showed, democracy)
# soviet invasion caused tragic fragmentation and violence. (soviet invasion, caused, tragic fragmentation)
# soviet invasion caused tragic fragmentation and violence. (soviet invasion, caused, violence)
# civil war caused tragic fragmentation and violence. (civil war, caused, tragic fragmentation)
# civil war caused tragic fragmentation and violence. (civil war, caused, violence)
# taliban caused tragic fragmentation and violence. (taliban, caused, tragic fragmentation)
# taliban caused tragic fragmentation and violence. (taliban, caused, violence)
# tragic fragmentation demanded afghanistan's unification. (tragic fragmentation, demanded, afghanistan's unification)
# violence also demanded afghanistan's unification. (violence, demanded, afghanistan's unification)
# central government must guide afghanistan's unification. (central government, must guide, afghanistan's unification)
# central government must strengthen afghanistan's unification. (central government, must strengthen, afghanistan's unification)
# afghanistan's unification can restore peace. (afghanistan's unification, can restore, peace)
# afghans must continue afghanistan's transformation. (afghans, must continue, afghanistan's transformation)
# afghans must continue afghanistan's unification. (afghans, must continue, afghanistan's unification)
# afghanistan must achieve afghanistan's transformation. (afghanistan's transformation, must achieve, afghanistan's transformation)
# afghanistan's transformation will cause peace. (afghanistan's transformation, will cause, peace)
# afghanistan's transformation will cause prosperity. (afghanistan's transformation, will cause, prosperity)
# afghans must support zahir shah. (afghans, must support, zahir shah)
# afghans must support national institutions. (afghans, must support, national institutions)
# civil war leads to state's disintegration. (civil war, leads, state's disintegration)
# afghans must support central government. (afghans, must support, central government)
# central government can transcend chaos. (central government, can transcend, chaos)
# national institutions can transcend chaos. (national institutions, can transcend, chaos)
# central government can cause afghanistan's transformation. (central government, can cause, afghanistan's transformation)
# national institutions can cause afghanistan's transformation. (national institutions, can cause, afghanistan's transformation)
# central government can cause afghanistan's unification. (central government, can cause, afghanistan's unification)
# national institutions can cause afghanistan's unification. (national institutions, can cause, afghanistan's unification)

# %% [raw]
# causeffect = [] #without duplicates
# causalSentences = [] #with duplicates
# #lem = []
# lemma_function = WordNetLemmatizer()
# for s,st in zip(sentences2,correctTriples):
#     check = False
#     #st = (str(st[0]),str(st[1]),str(st[2]))
#     #synonym = synonym[0]
#     tokens = word_tokenize(str(st[1]))
#     for token, tag in pos_tag(tokens):
#         lemma = lemma_function.lemmatize(token)
#         print(token,lemma)
#         #st[1] = lemma
#         #lem.append(lemma)
#
#     for synonym in synonyms:
#         if synonym == lemma:
#             #causeffect = [(st[0],st[1],st[2])]
#             #strTriples.append((ncl[0],token.text,st[2]))
#             print(synonym)
#             if len(causeffect) == 0:
#                 causeffect.append(st)
#                 causalSentences.append(s)
#             else:
#                 for ct in causeffect:
#                     if str(st[0]) == str(ct[0]) and str(st[1]) == str(ct[1]) and str(st[2]) == str(ct[2]):
#                         check = True
#                         break;
#                 if check == False:
#                     causeffect.append(st)
#                     causalSentences.append(s)
#             #if (len(causeffect) >0 ) and (st in causeffect == False):
#
#             #    causeffect.append(st)
#             break
#
# #causeffect.sort(key = lambda x: x[0])
#
# #for sortedTriple in causeffect:
# #    print(sortedTriple)
# print(len(causalSentences))
# print(len(causeffect))
# for causalSentence, causalTriple  in zip(causalSentences, causeffect):
#     print(causalSentence, causalTriple)

# %% [markdown]
# # Plot the Causal Graph.

# %%
#new (DAG Implementation)
#without duplicates
dagCauseTriples = []
cg = nx.DiGraph()
dagCauseSents = []
dagCauseVerbs = []

for ce,se in zip(causeffect,causalSentences):
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
#     dagCauseTriples.append(ce)
#     dagCauseSents.append(se)
#     dagCauseVerbs.append(str(ce[1]))
    if nx.is_directed_acyclic_graph(cg) is False:
        cg.remove_edge(s, d)
#         dagCauseTriples.remove(ce)
#         dagCauseSents.remove(se)  
#         dagCauseVerbs.remove(str(ce[1]))
    else:
        for dummy,dummy1,dummy2 in zip(dagCauseTriples,dagCauseSents,dagCauseVerbs):
            if str(dummy[0]) == s and str(dummy[2]) == d:
                dagCauseTriples.remove(dummy)
                dagCauseSents.remove(dummy1)  
                dagCauseVerbs.remove(dummy2)
                break;
        dagCauseTriples.append(ce)
        dagCauseSents.append(se)
        dagCauseVerbs.append(str(ce[1]))

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 18
# Edges: 27
# central government , {'predicade': 'controlled'} , afghanistan
# central government , {'predicade': 'can cause'} , afghanistan's unification
# central government , {'predicade': 'can transcend'} , chaos
# central government , {'predicade': 'can cause'} , afghanistan's transformation
# afghanistan , {'predicade': 'showed'} , modernization
# afghanistan , {'predicade': 'showed'} , democracy
# zahir shah , {'predicade': 'controlled'} , afghanistan
# soviet invasion , {'predicade': 'caused'} , tragic fragmentation
# soviet invasion , {'predicade': 'caused'} , violence
# tragic fragmentation , {'predicade': 'demanded'} , afghanistan's unification
# violence , {'predicade': 'demanded'} , afghanistan's unification
# civil war , {'predicade': 'caused'} , tragic fragmentation
# civil war , {'predicade': 'caused'} , violence
# civil war , {'predicade': 'leads'} , state's disintegration
# taliban , {'predicade': 'caused'} , tragic fragmentation
# taliban , {'predicade': 'caused'} , violence
# afghanistan's unification , {'predicade': 'can restore'} , peace
# afghans , {'predicade': 'must continue'} , afghanistan's transformation
# afghans , {'predicade': 'must continue'} , afghanistan's unification
# afghans , {'predicade': 'must support'} , zahir shah
# afghans , {'predicade': 'must support'} , national institutions
# afghans , {'predicade': 'must support'} , central government
# afghanistan's transformation , {'predicade': 'will cause'} , peace
# afghanistan's transformation , {'predicade': 'will cause'} , prosperity
# national institutions , {'predicade': 'can transcend'} , chaos
# national institutions , {'predicade': 'can cause'} , afghanistan's transformation
# national institutions , {'predicade': 'can cause'} , afghanistan's unification

# %% [raw]
# #old
# #without duplicates
#
# cg = nx.DiGraph()
#
# for ce in causeffect:
#     s = str(ce[0])
#     d = str(ce[2])
#     #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
#     cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
#     #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
#     cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
#     cg.add_edge(s, d, predicade=str(ce[1]))
#
#
# print("Nodes:",len(cg.nodes))
# print("Edges:",len(cg.edges))
# for e in cg.edges(data=True):
#     print(e[0],",",e[2],",",e[1])
#
# print(nx.is_directed_acyclic_graph(cg))
#
# pos = nx.spring_layout(cg, k=4, iterations=20)
# plt.figure(figsize=(15,12))
#
# nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
# edge_labels = nx.get_edge_attributes(cg,'predicade')
# nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)
#
# plt.axis('off')
# plt.show()

# %% [markdown]
# # Make Causal Graph Fully Connected (Change value of 'ce' tuple)

# %% [raw]
# sentence = "nuclear program developed nuclear bomb."
# triple = ("nuclear program", "developed", "nuclear bomb")
# verb = "developed"
# dagCauseSents.append(sentence)
# dagCauseTriples.append(triple)
# dagCauseVerbs.append(verb)

# %% [markdown]
# # Print DAG Causal Triples along with Sentences and Verbs

# %%
print(len(dagCauseTriples))
print(len(dagCauseSents))
# Out:
# 27
# 27

# %%
for causalSentence, causalTriple, causalVerb  in zip(dagCauseSents, dagCauseTriples, dagCauseVerbs):
    print(causalSentence, causalTriple, causalVerb)
# Out:
# afghanistan was controlled by central government. (central government, controlled, afghanistan) controlled
# afghanistan was controlled by zahir shah. (zahir shah, controlled, afghanistan) controlled
# afghanistan showed modernization and democracy. (afghanistan, showed, modernization) showed
# afghanistan showed modernization and democracy. (afghanistan, showed, democracy) showed
# soviet invasion caused tragic fragmentation and violence. (soviet invasion, caused, tragic fragmentation) caused
# soviet invasion caused tragic fragmentation and violence. (soviet invasion, caused, violence) caused
# civil war caused tragic fragmentation and violence. (civil war, caused, tragic fragmentation) caused
# civil war caused tragic fragmentation and violence. (civil war, caused, violence) caused
# taliban caused tragic fragmentation and violence. (taliban, caused, tragic fragmentation) caused
# taliban caused tragic fragmentation and violence. (taliban, caused, violence) caused
# tragic fragmentation demanded afghanistan's unification. (tragic fragmentation, demanded, afghanistan's unification) demanded
# violence also demanded afghanistan's unification. (violence, demanded, afghanistan's unification) demanded
# afghanistan's unification can restore peace. (afghanistan's unification, can restore, peace) can restore
# afghans must continue afghanistan's transformation. (afghans, must continue, afghanistan's transformation) must continue
# afghans must continue afghanistan's unification. (afghans, must continue, afghanistan's unification) must continue
# afghanistan's transformation will cause peace. (afghanistan's transformation, will cause, peace) will cause
# afghanistan's transformation will cause prosperity. (afghanistan's transformation, will cause, prosperity) will cause
# afghans must support zahir shah. (afghans, must support, zahir shah) must support
# afghans must support national institutions. (afghans, must support, national institutions) must support
# civil war leads to state's disintegration. (civil war, leads, state's disintegration) leads
# afghans must support central government. (afghans, must support, central government) must support
# central government can transcend chaos. (central government, can transcend, chaos) can transcend
# national institutions can transcend chaos. (national institutions, can transcend, chaos) can transcend
# central government can cause afghanistan's transformation. (central government, can cause, afghanistan's transformation) can cause
# national institutions can cause afghanistan's transformation. (national institutions, can cause, afghanistan's transformation) can cause
# central government can cause afghanistan's unification. (central government, can cause, afghanistan's unification) can cause
# national institutions can cause afghanistan's unification. (national institutions, can cause, afghanistan's unification) can cause

# %% [markdown]
# # Plot the Causal Graph on using Pyvis "Causal Graph.html" file

# %%
#nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')
nt = Network("660px", "1515px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')

for dm in dagCauseTriples:
    #color = "#ffffff"
    nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_node(str(dm[2]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_edge(str(dm[0]),str(dm[2]),label=str(dm[1]), weight=10, physics='false',color='black')

#nt.show_buttons(filter_=['physics'])
nt.set_edge_smooth('discrete')
nt.show("./Pyvis Graph/Causal Graph.html")
# Out:
#         <iframe
#             width="1515px"
#             height="660px"
#             src="./Pyvis Graph/Causal Graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [raw]
# nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')
#
# nt.add_node(1, label="Subject (cause)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_node(2, label="Object (effect)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_edge(1,2,label="Verb (cause-effect)", weight=10, physics='false',color='black')
#
#
# nt.show("./Pyvis Graph/Causal Graph.html")

# %% [markdown]
# # Dump the Causal Graph on "Causal Graph.json" file

# %% [raw]
# data = json_graph.node_link_data(cg)
#
#
# out_file = open("./Json Graphs/Causal Graph.json", "w")
#
# json.dump(data, out_file, indent = 6)
#
# out_file.close()

# %% [markdown]
# # Remove Duplicates from Causal Triples

# %% [raw]
# #causeffect = list(dict.fromkeys(causeffect))
#
# print("List before removing duplicates:")
# print(len(causeffect))
#
# for t in causeffect:
#     print(t)
#
# causalTriples = []
#
# for ce in causeffect:
#     check = False
#     #print("ce:")
#     #print(ce)
#     if len(causalTriples) == 0:
#         #print("HEY!")
#         causalTriples.append(ce)
#         #print("added!")
#     else:
#         for ct in causalTriples:
#             #print("ct:")
#             #print(ct)
#             if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
#                 #print("duplicate")
#                 check = True
#                 break;
#         if check == False:
#             causalTriples.append(ce)
#             #print("added!")
#
# print("\nList after removing duplicates:")
# print(len(causalTriples))
#
# for t in causalTriples:
#     print(t)

# %% [markdown]
# # Remove Duplicates from causalSentences

# %% [raw]
# #causalSentences = list(dict.fromkeys(causalSentences))
# #causalSentences = list(set(causalSentences))
# print("List before removing duplicates:")
# print(len(causalSentences))
#
# for t in causalSentences:
#     print(t)
#
# causalSentencesNoDup = []
#
# for ce in causalSentences:
#     check = False
#     #print("ce:")
#     #print(ce)
#     if len(causalSentencesNoDup) == 0:
#         #print("HEY!")
#         causalSentencesNoDup.append(ce)
#         #print("added!")
#     else:
#         for ct in causalSentencesNoDup:
#             #print("ct:")
#             #print(ct)
#             if str(ce) == str(ct):
#                 #print("duplicate")
#                 check = True
#                 break;
#         if check == False:
#             causalSentencesNoDup.append(ce)
#             #print("added!")
#
# print("\nList after removing duplicates:")
# print(len(causalSentencesNoDup))
#
# for t in causalSentencesNoDup:
#     print(t)

# %% [markdown]
# # Causal Triples' Polarity (Whole)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
# https://huggingface.co/cardiffnlp/twitter-xlm-roberta-base-sentiment?text=extremely+negative
# https://huggingface.co/blog/sentiment-analysis-python
# https://huggingface.co/models?pipeline_tag=text-classification&sort=downloads&search=sentiment

# returns score as output in the range [0,1] 
# mapped to (1,0,-1) -> (pos, neutral, neg)

allen = []
for sent in dagCauseTriples:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        score = round(score,3)
        allen.append(score)
        # allen.append(-1)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        scores[2] = round(scores[2],3)
        allen.append(scores[2])
        # allen.append(1)
    else:
        # allen.append(scores[1])
        allen.append(0)
    
for causalSentence, polarity  in zip(dagCauseTriples, allen):
    print(causalSentence, polarity)

# text = "must fight"
# encoded_input = tokenizer(text, return_tensors='pt')
# output = model(**encoded_input)
# scores = output[0][0].detach().numpy()
# scores = softmax(scores)
# if scores[0] > scores[1] and scores[0] > scores[2]:
#     print('negative')
# elif scores[2] > scores[1] and scores[2] > scores[0]:
#     print('positive')
# else:
#     print('neutral')

# ranking = np.argsort(scores)
# # print(ranking)
# ranking = ranking[::-1]
# for i in range(scores.shape[0]):
#     l = config.id2label[ranking[i]]
#     s = scores[ranking[i]]
#     print(f"{i+1}) {l} {np.round(float(s), 4)}")
# Out:
# (central government, controlled, afghanistan) 0
# (zahir shah, controlled, afghanistan) 0
# (afghanistan, showed, modernization) 0
# (afghanistan, showed, democracy) 0
# (soviet invasion, caused, tragic fragmentation) -0.924
# (soviet invasion, caused, violence) -0.815
# (civil war, caused, tragic fragmentation) -0.916
# (civil war, caused, violence) -0.804
# (taliban, caused, tragic fragmentation) -0.914
# (taliban, caused, violence) -0.783
# (tragic fragmentation, demanded, afghanistan's unification) -0.9
# (violence, demanded, afghanistan's unification) -0.792
# (afghanistan's unification, can restore, peace) 0.618
# (afghans, must continue, afghanistan's transformation) 0
# (afghans, must continue, afghanistan's unification) 0
# (afghanistan's transformation, will cause, peace) 0.483
# (afghanistan's transformation, will cause, prosperity) 0.51
# (afghans, must support, zahir shah) 0.418
# (afghans, must support, national institutions) 0
# (civil war, leads, state's disintegration) -0.874
# (afghans, must support, central government) 0
# (central government, can transcend, chaos) 0
# (national institutions, can transcend, chaos) 0
# (central government, can cause, afghanistan's transformation) 0
# (national institutions, can cause, afghanistan's transformation) 0
# (central government, can cause, afghanistan's unification) 0
# (national institutions, can cause, afghanistan's unification) 0

# %% [raw]
# ### [AllenNlp]

# %% [raw]
# #https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
# #https://paperswithcode.com/model/roberta-large-sst
# #https://paperswithcode.com/model/glove-lstm
#
# # returns binary output (1,0) -> (pos,neg)
# # mapped to (1,-1)
#
# # sentence = "Enemies surround Pakistan."
# # preds = predictor.predict(sentence)
# # print(f"p(positive)={preds['probs'][0]:.2%}")
# # print(f"p(negative)={preds['probs'][1]:.2%}")
# # sentiment = prediction.logits.argmax(axis=-1)
# allen = []
# for sent in dagCauseTriples:
#     #print(sent)
#     preds = predictor.predict(str(sent))
#     #print(preds['label'][0])
#     label = preds['label'][0]
#     if label is '0':
#         allen.append(-1)
#     else:
#         allen.append(1)
#
# for causalSentence, polarity  in zip(dagCauseTriples, allen):
#     print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
#https://darenr.github.io/afinn/
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/
#https://github.com/thisandagain/sentiment

# returns score as output in the range [-5,5] 
# mapped to (1,0,-1) -> (pos, neutral, neg)

afinn = []
for sent in dagCauseTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    # print(score)
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    score = round(score,3)
    afinn.append(score)
    # if score > 0:
    #     #print('positive')
    #     afinn.append(1)
    # elif score < 0:
    #     #print('negative')
    #     afinn.append(-1)
    # else:
    #     #print('neutral')
    #     afinn.append(0)
        
for causalSentence, polarity  in zip(dagCauseTriples, afinn):
    print(causalSentence, polarity)
# Out:
# (central government, controlled, afghanistan) 0.0
# (zahir shah, controlled, afghanistan) 0.0
# (afghanistan, showed, modernization) 0.0
# (afghanistan, showed, democracy) 0.0
# (soviet invasion, caused, tragic fragmentation) -0.6
# (soviet invasion, caused, violence) -0.8
# (civil war, caused, tragic fragmentation) -0.8
# (civil war, caused, violence) -1.0
# (taliban, caused, tragic fragmentation) -0.4
# (taliban, caused, violence) -0.6
# (tragic fragmentation, demanded, afghanistan's unification) -0.6
# (violence, demanded, afghanistan's unification) -0.8
# (afghanistan's unification, can restore, peace) 0.6
# (afghans, must continue, afghanistan's transformation) 0.0
# (afghans, must continue, afghanistan's unification) 0.0
# (afghanistan's transformation, will cause, peace) 0.4
# (afghanistan's transformation, will cause, prosperity) 0.6
# (afghans, must support, zahir shah) 0.4
# (afghans, must support, national institutions) 0.4
# (civil war, leads, state's disintegration) -0.4
# (afghans, must support, central government) 0.4
# (central government, can transcend, chaos) -0.4
# (national institutions, can transcend, chaos) -0.4
# (central government, can cause, afghanistan's transformation) 0.0
# (national institutions, can cause, afghanistan's transformation) 0.0
# (central government, can cause, afghanistan's unification) 0.0
# (national institutions, can cause, afghanistan's unification) 0.0

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring

# returns compound score as output in the range [-1,1] 
# mapped to (1,0,-1) -> (pos, neutral, neg)

vader = []

def vadersentimentanalysis(review):
    # negpos = []
    vs = analyzer.polarity_scores(review)
    return vs['compound']
    # negpos.append(vs['neg'])
    # negpos.append(vs['pos'])
    # return negpos

# def vader_analysis(compound):
#     # print(compound)
#     if compound >= 0.05:
#     #if compound > 0:
#         vader.append(1)
#         return 'Positive'
#     elif compound <= -0.05 :
#     #elif compound < 0:
#         vader.append(-1)
#         return 'Negative'
#     elif  compound > -0.05 and compound < 0.05:
#     #elif  compound == 0:
#         vader.append(0)
#         return 'Neutral'

# def vader_analysis(negpos):
#      if negpos[0] > negpos[1]:
#         vader.append(-1)
#         return 'Negative'
#      elif negpos[1] > negpos[0]:
#         vader.append(1)
#         return 'Positive'
    
for sent in dagCauseTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    # print(compound)
    compound = round(compound,3)
    vader.append(compound)
    # vader_analysis(compound)
    
for causalSentence, polarity  in zip(dagCauseTriples, vader):
    print(causalSentence, polarity)
# Out:
# (central government, controlled, afghanistan) 0.0
# (zahir shah, controlled, afghanistan) 0.0
# (afghanistan, showed, modernization) 0.0
# (afghanistan, showed, democracy) 0.0
# (soviet invasion, caused, tragic fragmentation) -0.459
# (soviet invasion, caused, violence) -0.625
# (civil war, caused, tragic fragmentation) -0.784
# (civil war, caused, violence) -0.84
# (taliban, caused, tragic fragmentation) -0.459
# (taliban, caused, violence) -0.625
# (tragic fragmentation, demanded, afghanistan's unification) -0.599
# (violence, demanded, afghanistan's unification) -0.718
# (afghanistan's unification, can restore, peace) 0.691
# (afghans, must continue, afghanistan's transformation) 0.0
# (afghans, must continue, afghanistan's unification) 0.0
# (afghanistan's transformation, will cause, peace) 0.542
# (afghanistan's transformation, will cause, prosperity) 0.0
# (afghans, must support, zahir shah) 0.402
# (afghans, must support, national institutions) 0.402
# (civil war, leads, state's disintegration) -0.599
# (afghans, must support, central government) 0.402
# (central government, can transcend, chaos) -0.572
# (national institutions, can transcend, chaos) -0.572
# (central government, can cause, afghanistan's transformation) 0.0
# (national institutions, can cause, afghanistan's transformation) 0.0
# (central government, can cause, afghanistan's unification) 0.0
# (national institutions, can cause, afghanistan's unification) 0.0

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/

# returns score as output in the range [-4,4] 
# mapped to (1,0,-1) -> (pos, neutral, neg)

sentiStrength = []

for sent in dagCauseTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='scale')
    # print(result)
    result = result[0]/4
    result = round(result,3)
    sentiStrength.append(result)
    # if result[0] > 0:
    #     #print('Positive')
    #     sentiStrength.append(1)
    # elif result[0] < 0:
    #     sentiStrength.append(-1)
    #     #print('Negative')
    # else:
    #     sentiStrength.append(0)
    # #    print('Neutral')

for causalSentence, polarity  in zip(dagCauseTriples, sentiStrength):
    print(causalSentence, polarity)
# Out:
# (central government, controlled, afghanistan) 0.0
# (zahir shah, controlled, afghanistan) 0.0
# (afghanistan, showed, modernization) 0.0
# (afghanistan, showed, democracy) 0.0
# (soviet invasion, caused, tragic fragmentation) -0.5
# (soviet invasion, caused, violence) -0.75
# (civil war, caused, tragic fragmentation) -0.5
# (civil war, caused, violence) -0.75
# (taliban, caused, tragic fragmentation) -0.5
# (taliban, caused, violence) -0.75
# (tragic fragmentation, demanded, afghanistan's unification) -0.5
# (violence, demanded, afghanistan's unification) -0.75
# (afghanistan's unification, can restore, peace) 0.0
# (afghans, must continue, afghanistan's transformation) 0.0
# (afghans, must continue, afghanistan's unification) 0.0
# (afghanistan's transformation, will cause, peace) 0.0
# (afghanistan's transformation, will cause, prosperity) 0.25
# (afghans, must support, zahir shah) 0.25
# (afghans, must support, national institutions) 0.25
# (civil war, leads, state's disintegration) -0.5
# (afghans, must support, central government) 0.25
# (central government, can transcend, chaos) -0.25
# (national institutions, can transcend, chaos) -0.25
# (central government, can cause, afghanistan's transformation) 0.0
# (national institutions, can cause, afghanistan's transformation) 0.0
# (central government, can cause, afghanistan's unification) 0.0
# (national institutions, can cause, afghanistan's unification) 0.0

# %% [raw]
# # SenticNet
# # Not included because can only work for individual words and not sentences
# from senticnet.senticnet import SenticNet
#
# sn = SenticNet()
# #concept_info = sn.concept('love')
# # print(concept_info)
# polarity_label = sn.polarity_label('hate')
# print(polarity_label)
# polarity_value = sn.polarity_value('hate')
# print(polarity_value)
# # moodtags = sn.moodtags('love')
# # print(moodtags)
# # semantics = sn.semantics('love')
# # print(semantics)
# # sentics = sn.sentics('love')
# # print(sentics)

# %% [raw]
# # TextBlob
# # Not included because majority results were neutral
# #https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis
# #output (Pos,neg)
#
# from textblob import TextBlob
#
# blob = []
#
# for sent in dagCauseTriples:
#     result = TextBlob(str(sent))
#     result = result.sentiment.polarity
#     print(result)
#     if result > 0:
#         blob.append(1)
#     elif result < 0:
#         blob.append(-1)
#     else:
#         blob.append(0)
#
# for causalSentence, polarity  in zip(dagCauseTriples, blob):
#     print(causalSentence, polarity)

# %% [markdown]
# ### Data Frame (Causal Triples Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df_CTW = pd.DataFrame(list(zip(dagCauseTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'HuggingFace','Afinn','Vader','SentiStrength'])
# df2["Weight"] = round(df2.sum(axis=1)/4,3)
df_CTW["Weight"] = df_CTW.sum(axis=1)

for i in df_CTW.index:
    count = 0
#     print(df2["Afinn"][i])
    if df_CTW["HuggingFace"][i] != 0:
        count = count + 1
    if df_CTW["Afinn"][i] != 0:
        count = count + 1
    if df_CTW["Vader"][i] != 0:
        count = count + 1
    if df_CTW["SentiStrength"][i] != 0:
        count = count + 1
    if count == 0:
        count = 1
    df_CTW["Weight"][i] = round(df_CTW["Weight"][i]/count,3)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df_CTW.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -1 and weight < -0.6:
        sentPolarity.append('Strong Negative') 
    elif weight >= -0.6 and weight < -0.3:
        sentPolarity.append('Moderate Negative')
    elif weight >= -0.3 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 1 and weight > 0.6:
        sentPolarity.append('Strong Positive')
    elif weight <= 0.6 and weight > 0.3:
        sentPolarity.append('Moderate Positive')
    elif weight <= 0.3 and weight > 0:
        sentPolarity.append('Weak Positive')

df_CTW["Polarity"] = sentPolarity
df_CTW.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <style type="text/css">
# </style>
# <table id="T_6b34a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Triple</th>
#       <th class="col_heading level0 col1" >HuggingFace</th>
#       <th class="col_heading level0 col2" >Afinn</th>
#       <th class="col_heading level0 col3" >Vader</th>
#       <th class="col_heading level0 col4" >SentiStrength</th>
#       <th class="col_heading level0 col5" >Weight</th>
#       <th class="col_heading level0 col6" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b34a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b34a_row0_col0" class="data row0 col0" >(central government, controlled, afghanistan)</td>
#       <td id="T_6b34a_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_6b34a_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_6b34a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_6b34a_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_6b34a_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_6b34a_row0_col6" class="data row0 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b34a_row1_col0" class="data row1 col0" >(zahir shah, controlled, afghanistan)</td>
#       <td id="T_6b34a_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_6b34a_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_6b34a_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_6b34a_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_6b34a_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_6b34a_row1_col6" class="data row1 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b34a_row2_col0" class="data row2 col0" >(afghanistan, showed, modernization)</td>
#       <td id="T_6b34a_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_6b34a_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_6b34a_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_6b34a_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_6b34a_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_6b34a_row2_col6" class="data row2 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b34a_row3_col0" class="data row3 col0" >(afghanistan, showed, democracy)</td>
#       <td id="T_6b34a_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_6b34a_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_6b34a_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_6b34a_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_6b34a_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_6b34a_row3_col6" class="data row3 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b34a_row4_col0" class="data row4 col0" >(soviet invasion, caused, tragic fragmentation)</td>
#       <td id="T_6b34a_row4_col1" class="data row4 col1" >-0.924000</td>
#       <td id="T_6b34a_row4_col2" class="data row4 col2" >-0.600000</td>
#       <td id="T_6b34a_row4_col3" class="data row4 col3" >-0.459000</td>
#       <td id="T_6b34a_row4_col4" class="data row4 col4" >-0.500000</td>
#       <td id="T_6b34a_row4_col5" class="data row4 col5" >-0.621000</td>
#       <td id="T_6b34a_row4_col6" class="data row4 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b34a_row5_col0" class="data row5 col0" >(soviet invasion, caused, violence)</td>
#       <td id="T_6b34a_row5_col1" class="data row5 col1" >-0.815000</td>
#       <td id="T_6b34a_row5_col2" class="data row5 col2" >-0.800000</td>
#       <td id="T_6b34a_row5_col3" class="data row5 col3" >-0.625000</td>
#       <td id="T_6b34a_row5_col4" class="data row5 col4" >-0.750000</td>
#       <td id="T_6b34a_row5_col5" class="data row5 col5" >-0.748000</td>
#       <td id="T_6b34a_row5_col6" class="data row5 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b34a_row6_col0" class="data row6 col0" >(civil war, caused, tragic fragmentation)</td>
#       <td id="T_6b34a_row6_col1" class="data row6 col1" >-0.916000</td>
#       <td id="T_6b34a_row6_col2" class="data row6 col2" >-0.800000</td>
#       <td id="T_6b34a_row6_col3" class="data row6 col3" >-0.784000</td>
#       <td id="T_6b34a_row6_col4" class="data row6 col4" >-0.500000</td>
#       <td id="T_6b34a_row6_col5" class="data row6 col5" >-0.750000</td>
#       <td id="T_6b34a_row6_col6" class="data row6 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6b34a_row7_col0" class="data row7 col0" >(civil war, caused, violence)</td>
#       <td id="T_6b34a_row7_col1" class="data row7 col1" >-0.804000</td>
#       <td id="T_6b34a_row7_col2" class="data row7 col2" >-1.000000</td>
#       <td id="T_6b34a_row7_col3" class="data row7 col3" >-0.840000</td>
#       <td id="T_6b34a_row7_col4" class="data row7 col4" >-0.750000</td>
#       <td id="T_6b34a_row7_col5" class="data row7 col5" >-0.848000</td>
#       <td id="T_6b34a_row7_col6" class="data row7 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6b34a_row8_col0" class="data row8 col0" >(taliban, caused, tragic fragmentation)</td>
#       <td id="T_6b34a_row8_col1" class="data row8 col1" >-0.914000</td>
#       <td id="T_6b34a_row8_col2" class="data row8 col2" >-0.400000</td>
#       <td id="T_6b34a_row8_col3" class="data row8 col3" >-0.459000</td>
#       <td id="T_6b34a_row8_col4" class="data row8 col4" >-0.500000</td>
#       <td id="T_6b34a_row8_col5" class="data row8 col5" >-0.568000</td>
#       <td id="T_6b34a_row8_col6" class="data row8 col6" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6b34a_row9_col0" class="data row9 col0" >(taliban, caused, violence)</td>
#       <td id="T_6b34a_row9_col1" class="data row9 col1" >-0.783000</td>
#       <td id="T_6b34a_row9_col2" class="data row9 col2" >-0.600000</td>
#       <td id="T_6b34a_row9_col3" class="data row9 col3" >-0.625000</td>
#       <td id="T_6b34a_row9_col4" class="data row9 col4" >-0.750000</td>
#       <td id="T_6b34a_row9_col5" class="data row9 col5" >-0.690000</td>
#       <td id="T_6b34a_row9_col6" class="data row9 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6b34a_row10_col0" class="data row10 col0" >(tragic fragmentation, demanded, afghanistan's unification)</td>
#       <td id="T_6b34a_row10_col1" class="data row10 col1" >-0.900000</td>
#       <td id="T_6b34a_row10_col2" class="data row10 col2" >-0.600000</td>
#       <td id="T_6b34a_row10_col3" class="data row10 col3" >-0.599000</td>
#       <td id="T_6b34a_row10_col4" class="data row10 col4" >-0.500000</td>
#       <td id="T_6b34a_row10_col5" class="data row10 col5" >-0.650000</td>
#       <td id="T_6b34a_row10_col6" class="data row10 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6b34a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6b34a_row11_col0" class="data row11 col0" >(violence, demanded, afghanistan's unification)</td>
#       <td id="T_6b34a_row11_col1" class="data row11 col1" >-0.792000</td>
#       <td id="T_6b34a_row11_col2" class="data row11 col2" >-0.800000</td>
#       <td id="T_6b34a_row11_col3" class="data row11 col3" >-0.718000</td>
#       <td id="T_6b34a_row11_col4" class="data row11 col4" >-0.750000</td>
#       <td id=

# %% [markdown]
# # Causal Sentences' Polarity (Whole)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
def Allen_sents_SentLevel(causalSentences):
    allen = []
    for sent in causalSentences:
        encoded_input = tokenizer(str(sent), return_tensors='pt')
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        if scores[0] > scores[1] and scores[0] > scores[2]:
            score = scores[0] * -1
            score = round(score,3)
            allen.append(score)
            # allen.append(-1)
        elif scores[2] > scores[1] and scores[2] > scores[0]:
            scores[2] = round(scores[2],3)
            allen.append(scores[2])
            # allen.append(1)
        else:
            # allen.append(scores[1])
            allen.append(0)
    return allen

# %% [raw]
# ### [AllenNlp]

# %% [raw]
# #https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
# #https://paperswithcode.com/model/roberta-large-sst
#
# #output (Pos,neg)
#
# #sentence = "Enemies surround Pakistan."
# #preds = predictor.predict(sentence)
# #print(f"p(positive)={preds['probs'][0]:.2%}")
# def Allen_sents_SentLevel(causalSentences):
#     allen = []
#     for sent in causalSentences:
#         #print(sent)
#         preds = predictor.predict(str(sent))
#         #print(preds['label'][0])
#         label = preds['label'][0]
#         if label is '0':
#             allen.append(-1)
#         else:
#             allen.append(1)
#     return allen
#
# #for causalSentence, polarity  in zip(causalSentences, allen):
# #    print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)
def Afinn_sents_SentLevel(causalSentences):
    afinn = []
    for sent in causalSentences:
        #print(sent)
        score = afn.score(str(sent))
        #print(score)
        if score < -5:
            score = -5
        elif score > 5:
            score = 5
        score = score/5
        score = round(score,3)
        afinn.append(score)
        # if score > 0:
        #     #print('positive')
        #     afinn.append(1)
        # elif score < 0:
        #     #print('negative')
        #     afinn.append(-1)
        # else:
        #     #print('neutral')
        #     afinn.append(0)
    return afinn

#for causalSentence, polarity  in zip(causalSentences, afinn):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

# def vader_analysis(compound):
#     #vader = []
#     if compound >= 0.05:
#         #vader.append(1)
#         return 1
#     elif compound <= -0.05 :
#         #vader.append(-1)
#         return -1
        
#     elif  compound > -0.05 and compound < 0.05:
#         #vader.append(0)
#         return 0
#     #return vader
    
def Vader_sents_SentLevel(causalSentences):
    vader = []
    for sent in causalSentences:
        #print(sent)
        #vaderTup = []
        compound = vadersentimentanalysis(str(sent))
        compound = round(compound,3)
        vader.append(compound)
        # res = vader_analysis(compound)
        #vaderTup.append(res)
        # vader.append(res)
    return vader

#vader = Vader_sents_SentLevel(causalSents)
#vader
#for causalSentence, polarity  in zip(causalSentences, vader):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

def Senti_sents_SentLevel(causalSentences):
    sentiStrength = []
    for sent in causalSentences:
        #print(sent)
        result = senti.getSentiment(str(sent), score='scale')
        #print(result)
        result = result[0]/4
        result = round(result,3)
        sentiStrength.append(result)
        # if result[0] > 0:
        #     sentiStrength.append(1)
        # elif result[0] < 0:
        #     sentiStrength.append(-1)
        # else:
        #     sentiStrength.append(0)
    return sentiStrength

#for causalSentence, polarity  in zip(causalSentences, sentiStrength):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiWordnet]

# %% [raw]
# def penn_to_wn(tag):
#     if tag.startswith('J'):
#         return wn.ADJ
#     elif tag.startswith('N'):
#         return wn.NOUN
#     elif tag.startswith('R'):
#         return wn.ADV
#     elif tag.startswith('V'):
#         return wn.VERB
#     return None
#
# def sentiment_sentiwordnet(text):
#     #text = text.decode("utf-8")
#     raw_sentences = sent_tokenize(text)
#     #print(raw_sentences)
#     sentiment = 0
#     tokens_count = 0
#
#     for raw_sentence in raw_sentences:
#         print(raw_sentence)
#         tagged_sentence = pos_tag(word_tokenize(raw_sentence))
#         print(tagged_sentence)
#
#         for word, tag in tagged_sentence:
#             wn_tag = penn_to_wn(tag)
#             if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
#                 continue
#
#             #lemma = lemmatizer.lemmatize(word, pos=wn_tag)
#             #if not lemma:
#             #    continue
#
#             synsets = wn.synsets(word, pos=wn_tag)
#             if not synsets:
#                 continue
#
#             synset = synsets[0]
#             swn_synset = swn.senti_synset(synset.name())
#             sentiment += swn_synset.pos_score() - swn_synset.neg_score()
#             tokens_count += 1
#         # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
#         if not tokens_count:
#             return 0
#         if sentiment>0:
#             #return "Positive"
#             print("Positive")
#         elif sentiment==0:
#             #return "Neutral"
#             print("Neutral")
#         else:
#             #return "Negative"
#             print("Negative")
#
# causalNarrative = ""
# for cS in causalSentences:
#     causalNarrative = causalNarrative+str(cS)+" "
#
# causalNarrative = nlp(causalNarrative)
# #raw_sentences = sent_tokenize(causalNarrative)
# #print(str(causalNarrative)+"\n")
# #print(raw_sentences)
# #print(str(narrative))
#
# sentiment_sentiwordnet(str(narrative))

# %% [markdown]
# ### [SentiWordNet OnlyVerbs]

# %% [raw]
# from nltk.corpus import wordnet as wn
# from nltk.corpus import sentiwordnet as swn
# from nltk.tag import pos_tag
# import nltk
#
#
# polarizedCauseffect = []
# for ce in causeffect:
#     print(ce[1])
#     token = nltk.word_tokenize(str(ce[1]))
#     after_tagging = nltk.pos_tag(token)
#     print(after_tagging)
#     print(len(after_tagging))
#     for tag in after_tagging:
#         if tag[1].startswith('V') or len(after_tagging)==1:
#             words = swn.senti_synsets(tag[0])
#             answer = list(words)[0]
#             if (answer.pos_score() > answer.neg_score()):
#                 mce = str(ce[1])+"(+ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             elif (answer.pos_score() > 0):
#                 mce = str(ce[1])+"(-ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             else:
#                 mce = str(ce[1])+"(neutral)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#
# polarizedCauseffect

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) without duplicates

# %% [raw]
# causalSents = causalSentencesNoDup
# print(len(causalSents))

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) with duplicates

# %% [raw]
# causalSents = causalSentences
# print(len(causalSents))

# %% [markdown]
# ### Data Frame (Causal Sentence at Sentence Level)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

allen = Allen_sents_SentLevel(dagCauseSents)
afinn = Afinn_sents_SentLevel(dagCauseSents)
vader = Vader_sents_SentLevel(dagCauseSents)
sentiStrength = Senti_sents_SentLevel(dagCauseSents)

df_CSW = pd.DataFrame(list(zip(dagCauseSents, allen, afinn, vader,sentiStrength)), columns =['Causal Sentence', 'HuggingFace','Afinn','Vader','SentiStrength'])
# df2["Weight"] = round(df2.sum(axis=1)/4,3)

df_CSW["Weight"] = df_CSW.sum(axis=1)

for i in df_CSW.index:
    count = 0
#     print(df2["Afinn"][i])
    if df_CSW["HuggingFace"][i] != 0:
        count = count + 1
    if df_CSW["Afinn"][i] != 0:
        count = count + 1
    if df_CSW["Vader"][i] != 0:
        count = count + 1
    if df_CSW["SentiStrength"][i] != 0:
        count = count + 1
    if count == 0:
        count = 1
    df_CSW["Weight"][i] = round(df_CSW["Weight"][i]/count,3)

sentPolarity = []
sentsWeight_sentLevel = []

for index, row in df_CSW.iterrows():
    sentWeightTuple = []
    weight = row['Weight']
    sentWeightTuple.append(weight)
    sentsWeight_sentLevel.append(sentWeightTuple)
    #print(weight)
    if weight >= -1 and weight < -0.6:
        sentPolarity.append('Strong Negative') 
    elif weight >= -0.6 and weight < -0.3:
        sentPolarity.append('Moderate Negative')
    elif weight >= -0.3 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 1 and weight > 0.6:
        sentPolarity.append('Strong Positive')
    elif weight <= 0.6 and weight > 0.3:
        sentPolarity.append('Moderate Positive')
    elif weight <= 0.3 and weight > 0:
        sentPolarity.append('Weak Positive')

df_CSW["Polarity"] = sentPolarity
df_CSW.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <style type="text/css">
# </style>
# <table id="T_a560c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Sentence</th>
#       <th class="col_heading level0 col1" >HuggingFace</th>
#       <th class="col_heading level0 col2" >Afinn</th>
#       <th class="col_heading level0 col3" >Vader</th>
#       <th class="col_heading level0 col4" >SentiStrength</th>
#       <th class="col_heading level0 col5" >Weight</th>
#       <th class="col_heading level0 col6" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a560c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a560c_row0_col0" class="data row0 col0" >afghanistan was controlled by central government.</td>
#       <td id="T_a560c_row0_col1" class="data row0 col1" >-0.520000</td>
#       <td id="T_a560c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_a560c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a560c_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_a560c_row0_col5" class="data row0 col5" >-0.520000</td>
#       <td id="T_a560c_row0_col6" class="data row0 col6" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a560c_row1_col0" class="data row1 col0" >afghanistan was controlled by zahir shah.</td>
#       <td id="T_a560c_row1_col1" class="data row1 col1" >-0.452000</td>
#       <td id="T_a560c_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_a560c_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a560c_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_a560c_row1_col5" class="data row1 col5" >-0.452000</td>
#       <td id="T_a560c_row1_col6" class="data row1 col6" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a560c_row2_col0" class="data row2 col0" >afghanistan showed modernization and democracy.</td>
#       <td id="T_a560c_row2_col1" class="data row2 col1" >0.498000</td>
#       <td id="T_a560c_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_a560c_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a560c_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_a560c_row2_col5" class="data row2 col5" >0.498000</td>
#       <td id="T_a560c_row2_col6" class="data row2 col6" >Moderate Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a560c_row3_col0" class="data row3 col0" >afghanistan showed modernization and democracy.</td>
#       <td id="T_a560c_row3_col1" class="data row3 col1" >0.498000</td>
#       <td id="T_a560c_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_a560c_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_a560c_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_a560c_row3_col5" class="data row3 col5" >0.498000</td>
#       <td id="T_a560c_row3_col6" class="data row3 col6" >Moderate Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a560c_row4_col0" class="data row4 col0" >soviet invasion caused tragic fragmentation and violence.</td>
#       <td id="T_a560c_row4_col1" class="data row4 col1" >-0.912000</td>
#       <td id="T_a560c_row4_col2" class="data row4 col2" >-1.000000</td>
#       <td id="T_a560c_row4_col3" class="data row4 col3" >-0.796000</td>
#       <td id="T_a560c_row4_col4" class="data row4 col4" >-0.750000</td>
#       <td id="T_a560c_row4_col5" class="data row4 col5" >-0.864000</td>
#       <td id="T_a560c_row4_col6" class="data row4 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a560c_row5_col0" class="data row5 col0" >soviet invasion caused tragic fragmentation and violence.</td>
#       <td id="T_a560c_row5_col1" class="data row5 col1" >-0.912000</td>
#       <td id="T_a560c_row5_col2" class="data row5 col2" >-1.000000</td>
#       <td id="T_a560c_row5_col3" class="data row5 col3" >-0.796000</td>
#       <td id="T_a560c_row5_col4" class="data row5 col4" >-0.750000</td>
#       <td id="T_a560c_row5_col5" class="data row5 col5" >-0.864000</td>
#       <td id="T_a560c_row5_col6" class="data row5 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a560c_row6_col0" class="data row6 col0" >civil war caused tragic fragmentation and violence.</td>
#       <td id="T_a560c_row6_col1" class="data row6 col1" >-0.911000</td>
#       <td id="T_a560c_row6_col2" class="data row6 col2" >-1.000000</td>
#       <td id="T_a560c_row6_col3" class="data row6 col3" >-0.900000</td>
#       <td id="T_a560c_row6_col4" class="data row6 col4" >-0.750000</td>
#       <td id="T_a560c_row6_col5" class="data row6 col5" >-0.890000</td>
#       <td id="T_a560c_row6_col6" class="data row6 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a560c_row7_col0" class="data row7 col0" >civil war caused tragic fragmentation and violence.</td>
#       <td id="T_a560c_row7_col1" class="data row7 col1" >-0.911000</td>
#       <td id="T_a560c_row7_col2" class="data row7 col2" >-1.000000</td>
#       <td id="T_a560c_row7_col3" class="data row7 col3" >-0.900000</td>
#       <td id="T_a560c_row7_col4" class="data row7 col4" >-0.750000</td>
#       <td id="T_a560c_row7_col5" class="data row7 col5" >-0.890000</td>
#       <td id="T_a560c_row7_col6" class="data row7 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a560c_row8_col0" class="data row8 col0" >taliban caused tragic fragmentation and violence.</td>
#       <td id="T_a560c_row8_col1" class="data row8 col1" >-0.938000</td>
#       <td id="T_a560c_row8_col2" class="data row8 col2" >-1.000000</td>
#       <td id="T_a560c_row8_col3" class="data row8 col3" >-0.796000</td>
#       <td id="T_a560c_row8_col4" class="data row8 col4" >-0.750000</td>
#       <td id="T_a560c_row8_col5" class="data row8 col5" >-0.871000</td>
#       <td id="T_a560c_row8_col6" class="data row8 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a560c_row9_col0" class="data row9 col0" >taliban caused tragic fragmentation and violence.</td>
#       <td id="T_a560c_row9_col1" class="data row9 col1" >-0.938000</td>
#       <td id="T_a560c_row9_col2" class="data row9 col2" >-1.000000</td>
#       <td id="T_a560c_row9_col3" class="data row9 col3" >-0.796000</td>
#       <td id="T_a560c_row9_col4" class="data row9 col4" >-0.750000</td>
#       <td id="T_a560c_row9_col5" class="data row9 col5" >-0.871000</td>
#       <td id="T_a560c_row9_col6" class="data row9 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a560c_row10_col0" class="data row10 col0" >tragic fragmentation demanded afghanistan's unification.</td>
#       <td id="T_a560c_row10_col1" class="data row10 col1" >-0.910000</td>
#       <td id="T_a560c_row10_col2" class="data row10 col2" >-0.600000</td>
#       <td id="T_a560c_row10_col3" class="data row10 col3" >-0.599000</td>
#       <td id="T_a560c_row10_col4" class="data row10 col4" >-0.500000</td>
#       <td id="T_a560c_row10_col5" class="data row10 col5" >-0.652000</td>
#       <td id="T_a560c_row10_col6" class="data row10 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a560c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a560c_row11_col0" class="data row11 col0" >violence also demanded afghanistan's unification.</td>
#       <td id="T_a560c_row11_col1" class="data row11 col1" >-0.758000</td>
#       <td id="T_a560c_row11_col2" class="data row11 col2" >-0.

# %% [markdown]
# # Causal Triples' Polarity (Token Level)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen_word = []
allen_tuple = []

for tokenTuple in dagCauseTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        # print(token)
        encoded_input = tokenizer(str(token), return_tensors='pt')
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        # print(scores)
        if scores[0] > scores[1] and scores[0] > scores[2]:
            score = scores[0] * -1
            score = round(score,3)
            allen_tuple.append(score)
            # allen_tuple.append(-1)
        elif scores[2] > scores[1] and scores[2] > scores[0]:
            scores[2] = round(scores[2],3)
            allen_tuple.append(scores[2])
            # allen_tuple.append(1)
        else:
            # allen_tuple.append(scores[1])
            allen_tuple.append(0)
    allen_word.append(allen_tuple)
    allen_tuple = []
                
for a,b in zip(dagCauseTriples,allen_word):
    print(a,b)
# Out:
# (central government, controlled, afghanistan) [0, 0, -0.448]
# (zahir shah, controlled, afghanistan) [0, 0, -0.448]
# (afghanistan, showed, modernization) [-0.448, 0, 0]
# (afghanistan, showed, democracy) [-0.448, 0, 0]
# (soviet invasion, caused, tragic fragmentation) [-0.687, 0, -0.948]
# (soviet invasion, caused, violence) [-0.687, 0, -0.455]
# (civil war, caused, tragic fragmentation) [-0.591, 0, -0.948]
# (civil war, caused, violence) [-0.591, 0, -0.455]
# (taliban, caused, tragic fragmentation) [-0.398, 0, -0.948]
# (taliban, caused, violence) [-0.398, 0, -0.455]
# (tragic fragmentation, demanded, afghanistan's unification) [-0.948, 0, 0]
# (violence, demanded, afghanistan's unification) [-0.455, 0, 0]
# (afghanistan's unification, can restore, peace) [0, 0, 0]
# (afghans, must continue, afghanistan's transformation) [-0.425, 0.411, -0.522]
# (afghans, must continue, afghanistan's unification) [-0.425, 0.411, 0]
# (afghanistan's transformation, will cause, peace) [-0.522, 0, 0]
# (afghanistan's transformation, will cause, prosperity) [-0.522, 0, 0.391]
# (afghans, must support, zahir shah) [-0.425, 0.419, 0]
# (afghans, must support, national institutions) [-0.425, 0.419, 0]
# (civil war, leads, state's disintegration) [-0.591, 0, -0.914]
# (afghans, must support, central government) [-0.425, 0.419, 0]
# (central government, can transcend, chaos) [0, 0, -0.475]
# (national institutions, can transcend, chaos) [0, 0, -0.475]
# (central government, can cause, afghanistan's transformation) [0, 0, -0.522]
# (national institutions, can cause, afghanistan's transformation) [0, 0, -0.522]
# (central government, can cause, afghanistan's unification) [0, 0, 0]
# (national institutions, can cause, afghanistan's unification) [0, 0, 0]

# %% [raw]
# ### [AllenNlp]

# %% [raw]
# allen_word = []
# allen_tuple = []
#
# for tokenTuple in dagCauseTriples:
#     #print(tokenTuple)
#     for token in tokenTuple:
#         #if str(token) not in marks:
#         #print(token)
#         preds = predictor.predict(str(token))
#             #print(preds['label'][0])
#         label = preds['label'][0]
#         if label is '0':
#             allen_tuple.append(-1)
#                 #allen_word.append(-1)
#         else:
#                 #allen_word.append(1)
#             allen_tuple.append(1)
#     allen_word.append(allen_tuple)
#     allen_tuple = []
#
# for a,b in zip(dagCauseTriples,allen_word):
#     #print(len(a))
#     print(a,b)

# %% [markdown]
# ### [Afinn]

# %%
afinn_word = []
afinn_tuple = []

for tokenTuple in dagCauseTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
        #if str(token) not in marks:
            #print(token)
        score = afn.score(str(token))
        if score < -5:
            score = -5
        elif score > 5:
            score = 5
        score = score/5
        score = round(score,3)
        afinn_tuple.append(score)
        # if score > 0:
        #         #print('positive')
        #     afinn_tuple.append(1)
        # elif score < 0:
        #         #print('negative')
        #     afinn_tuple.append(-1)
        # else:
        #         #print('neutral')
        #     afinn_tuple.append(0)
    afinn_word.append(afinn_tuple)
    afinn_tuple = []

for a,b in zip(dagCauseTriples,afinn_word):
   # print(len(a))
    print(a,b)
# Out:
# (central government, controlled, afghanistan) [0.0, 0.0, 0.0]
# (zahir shah, controlled, afghanistan) [0.0, 0.0, 0.0]
# (afghanistan, showed, modernization) [0.0, 0.0, 0.0]
# (afghanistan, showed, democracy) [0.0, 0.0, 0.0]
# (soviet invasion, caused, tragic fragmentation) [-0.2, 0.0, -0.4]
# (soviet invasion, caused, violence) [-0.2, 0.0, -0.6]
# (civil war, caused, tragic fragmentation) [-0.4, 0.0, -0.4]
# (civil war, caused, violence) [-0.4, 0.0, -0.6]
# (taliban, caused, tragic fragmentation) [0.0, 0.0, -0.4]
# (taliban, caused, violence) [0.0, 0.0, -0.6]
# (tragic fragmentation, demanded, afghanistan's unification) [-0.4, -0.2, 0.0]
# (violence, demanded, afghanistan's unification) [-0.6, -0.2, 0.0]
# (afghanistan's unification, can restore, peace) [0.0, 0.2, 0.4]
# (afghans, must continue, afghanistan's transformation) [0.0, 0.0, 0.0]
# (afghans, must continue, afghanistan's unification) [0.0, 0.0, 0.0]
# (afghanistan's transformation, will cause, peace) [0.0, 0.0, 0.4]
# (afghanistan's transformation, will cause, prosperity) [0.0, 0.0, 0.6]
# (afghans, must support, zahir shah) [0.0, 0.4, 0.0]
# (afghans, must support, national institutions) [0.0, 0.4, 0.0]
# (civil war, leads, state's disintegration) [-0.4, 0.0, 0.0]
# (afghans, must support, central government) [0.0, 0.4, 0.0]
# (central government, can transcend, chaos) [0.0, 0.0, -0.4]
# (national institutions, can transcend, chaos) [0.0, 0.0, -0.4]
# (central government, can cause, afghanistan's transformation) [0.0, 0.0, 0.0]
# (national institutions, can cause, afghanistan's transformation) [0.0, 0.0, 0.0]
# (central government, can cause, afghanistan's unification) [0.0, 0.0, 0.0]
# (national institutions, can cause, afghanistan's unification) [0.0, 0.0, 0.0]

# %% [markdown]
# ### [Vader]

# %%
vader_word = []
vader_tuple = []

for tokenTuple in dagCauseTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) not in marks:
        vs = analyzer.polarity_scores(str(token))
        compound = vs['compound']
        compound = round(compound,3)
        vader_tuple.append(compound)
        # if compound >= 0.05:
        #     vader_tuple.append(1)   
        # elif compound <= -0.05 :
        #     vader_tuple.append(-1)
        # elif  compound > -0.05 and compound < 0.05:
        #     vader_tuple.append(0)
    vader_word.append(vader_tuple)
    vader_tuple = []

for a,b in zip(dagCauseTriples,vader_word):
    #print(len(a))
    print(a,b)
# Out:
# (central government, controlled, afghanistan) [0.0, 0.0, 0.0]
# (zahir shah, controlled, afghanistan) [0.0, 0.0, 0.0]
# (afghanistan, showed, modernization) [0.0, 0.0, 0.0]
# (afghanistan, showed, democracy) [0.0, 0.0, 0.0]
# (soviet invasion, caused, tragic fragmentation) [0.0, 0.0, -0.459]
# (soviet invasion, caused, violence) [0.0, 0.0, -0.625]
# (civil war, caused, tragic fragmentation) [-0.599, 0.0, -0.459]
# (civil war, caused, violence) [-0.599, 0.0, -0.625]
# (taliban, caused, tragic fragmentation) [0.0, 0.0, -0.459]
# (taliban, caused, violence) [0.0, 0.0, -0.625]
# (tragic fragmentation, demanded, afghanistan's unification) [-0.459, -0.226, 0.0]
# (violence, demanded, afghanistan's unification) [-0.625, -0.226, 0.0]
# (afghanistan's unification, can restore, peace) [0.0, 0.296, 0.542]
# (afghans, must continue, afghanistan's transformation) [0.0, 0.0, 0.0]
# (afghans, must continue, afghanistan's unification) [0.0, 0.0, 0.0]
# (afghanistan's transformation, will cause, peace) [0.0, 0.0, 0.542]
# (afghanistan's transformation, will cause, prosperity) [0.0, 0.0, 0.0]
# (afghans, must support, zahir shah) [0.0, 0.402, 0.0]
# (afghans, must support, national institutions) [0.0, 0.402, 0.0]
# (civil war, leads, state's disintegration) [-0.599, 0.0, 0.0]
# (afghans, must support, central government) [0.0, 0.402, 0.0]
# (central government, can transcend, chaos) [0.0, 0.0, -0.572]
# (national institutions, can transcend, chaos) [0.0, 0.0, -0.572]
# (central government, can cause, afghanistan's transformation) [0.0, 0.0, 0.0]
# (national institutions, can cause, afghanistan's transformation) [0.0, 0.0, 0.0]
# (central government, can cause, afghanistan's unification) [0.0, 0.0, 0.0]
# (national institutions, can cause, afghanistan's unification) [0.0, 0.0, 0.0]

# %% [markdown]
# ### [SentiStrength]

# %%
senti_word = []
senti_tuple = []

for tokenTuple in dagCauseTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks:
        #print(token)
        result = senti.getSentiment(str(token), score='scale')
            #print(result)
        result = result[0]/4
        result = round(result,3)
        senti_tuple.append(result)
        # if result[0] > 0:
        #     senti_tuple.append(1)
        # elif result[0] < 0:
        #     senti_tuple.append(-1)
        # else:
        #     senti_tuple.append(0)
    senti_word.append(senti_tuple)
    senti_tuple = []
    
for a,b in zip(dagCauseTriples,senti_word):
    #print(len(a))
    print(a,b)
# Out:
# (central government, controlled, afghanistan) [0.0, 0.0, 0.0]
# (zahir shah, controlled, afghanistan) [0.0, 0.0, 0.0]
# (afghanistan, showed, modernization) [0.0, 0.0, 0.0]
# (afghanistan, showed, democracy) [0.0, 0.0, 0.0]
# (soviet invasion, caused, tragic fragmentation) [0.0, 0.0, -0.5]
# (soviet invasion, caused, violence) [0.0, 0.0, -0.75]
# (civil war, caused, tragic fragmentation) [-0.5, 0.0, -0.5]
# (civil war, caused, violence) [-0.5, 0.0, -0.75]
# (taliban, caused, tragic fragmentation) [0.0, 0.0, -0.5]
# (taliban, caused, violence) [0.0, 0.0, -0.75]
# (tragic fragmentation, demanded, afghanistan's unification) [-0.5, 0.0, 0.0]
# (violence, demanded, afghanistan's unification) [-0.75, 0.0, 0.0]
# (afghanistan's unification, can restore, peace) [0.0, 0.0, 0.0]
# (afghans, must continue, afghanistan's transformation) [0.0, 0.0, 0.0]
# (afghans, must continue, afghanistan's unification) [0.0, 0.0, 0.0]
# (afghanistan's transformation, will cause, peace) [0.0, 0.0, 0.0]
# (afghanistan's transformation, will cause, prosperity) [0.0, 0.0, 0.25]
# (afghans, must support, zahir shah) [0.0, 0.25, 0.0]
# (afghans, must support, national institutions) [0.0, 0.25, 0.0]
# (civil war, leads, state's disintegration) [-0.5, 0.0, 0.0]
# (afghans, must support, central government) [0.0, 0.25, 0.0]
# (central government, can transcend, chaos) [0.0, 0.0, -0.25]
# (national institutions, can transcend, chaos) [0.0, 0.0, -0.25]
# (central government, can cause, afghanistan's transformation) [0.0, 0.0, 0.0]
# (national institutions, can cause, afghanistan's transformation) [0.0, 0.0, 0.0]
# (central government, can cause, afghanistan's unification) [0.0, 0.0, 0.0]
# (national institutions, can cause, afghanistan's unification) [0.0, 0.0, 0.0]

# %% [markdown]
# ### Data Frame (Causal Triples Token Level)

# %%
#new

sum_list = []
sum_tup = []
limit= len(dagCauseTriples)

for i in range(0,limit):
    for j in range(0,len(allen_word[i])):
        count = 0
        if afinn_word[i][j] != 0: 
            count = count +1
        if vader_word[i][j] != 0:
            count = count +1
        if senti_word[i][j] != 0:
            count = count +1
        if allen_word[i][j] != 0:
            count = count +1
        if count == 0:
            count = 1
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        res = res/count
        res = round(res,3)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -1 and weight < -0.6:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -0.6 and weight < -0.3:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -0.3 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 1 and weight > 0.6:
                tokenPolarity.append('Strong Positive')
            elif weight <= 0.6 and weight > 0.3:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 0.3 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

triplesWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight, 3)
    if tripleWeight > 1: 
        tripleWeight = 1
    if tripleWeight < -1:
        tripleWeight = -1
    weightSumTup.append(tripleWeight)
    triplesWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)

token_list = []
for i in dagCauseTriples:
    dummy = []
    for j in i:
        dummy.append(str(j))
    token_list.append(dummy)
    
df1 = pd.DataFrame(list(zip(dagCauseTriples,token_list, allen_word, afinn_word,vader_word,senti_word,sum_list,tokenPolarity_list,triplesWeight_TokenLevel, triplePolarity_list)), 
                      columns =['Causal Triple', "Tokens", 'HuggingFace','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])

df1 = df1.explode(['Tokens', 'HuggingFace','Afinn','Vader','SentiStrength','Token Weight', 'Token Polarity'], ignore_index=False)

prev = -1
for index, row in df1.iterrows():
    if prev == index:
        row['Causal Triple'] = ""
        row['Triple Weight'] = ""
        row['Triple Polarity'] = ""
    prev = index
df1.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_aadc2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Triple</th>
#       <th class="col_heading level0 col1" >Tokens</th>
#       <th class="col_heading level0 col2" >HuggingFace</th>
#       <th class="col_heading level0 col3" >Afinn</th>
#       <th class="col_heading level0 col4" >Vader</th>
#       <th class="col_heading level0 col5" >SentiStrength</th>
#       <th class="col_heading level0 col6" >Token Weight</th>
#       <th class="col_heading level0 col7" >Token Polarity</th>
#       <th class="col_heading level0 col8" >Triple Weight</th>
#       <th class="col_heading level0 col9" >Triple Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aadc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aadc2_row0_col0" class="data row0 col0" >(central government, controlled, afghanistan)</td>
#       <td id="T_aadc2_row0_col1" class="data row0 col1" >central government</td>
#       <td id="T_aadc2_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_aadc2_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_aadc2_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_aadc2_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_aadc2_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_aadc2_row0_col7" class="data row0 col7" >Neutral</td>
#       <td id="T_aadc2_row0_col8" class="data row0 col8" >[-0.448]</td>
#       <td id="T_aadc2_row0_col9" class="data row0 col9" >['Moderate Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_aadc2_row1_col0" class="data row1 col0" ></td>
#       <td id="T_aadc2_row1_col1" class="data row1 col1" >controlled</td>
#       <td id="T_aadc2_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_aadc2_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_aadc2_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_aadc2_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_aadc2_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_aadc2_row1_col7" class="data row1 col7" >Neutral</td>
#       <td id="T_aadc2_row1_col8" class="data row1 col8" ></td>
#       <td id="T_aadc2_row1_col9" class="data row1 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_aadc2_row2_col0" class="data row2 col0" ></td>
#       <td id="T_aadc2_row2_col1" class="data row2 col1" >afghanistan</td>
#       <td id="T_aadc2_row2_col2" class="data row2 col2" >-0.448000</td>
#       <td id="T_aadc2_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_aadc2_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_aadc2_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_aadc2_row2_col6" class="data row2 col6" >-0.448000</td>
#       <td id="T_aadc2_row2_col7" class="data row2 col7" >Moderate Negative</td>
#       <td id="T_aadc2_row2_col8" class="data row2 col8" ></td>
#       <td id="T_aadc2_row2_col9" class="data row2 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_aadc2_row3_col0" class="data row3 col0" >(zahir shah, controlled, afghanistan)</td>
#       <td id="T_aadc2_row3_col1" class="data row3 col1" >zahir shah</td>
#       <td id="T_aadc2_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_aadc2_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_aadc2_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_aadc2_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_aadc2_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_aadc2_row3_col7" class="data row3 col7" >Neutral</td>
#       <td id="T_aadc2_row3_col8" class="data row3 col8" >[-0.448]</td>
#       <td id="T_aadc2_row3_col9" class="data row3 col9" >['Moderate Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_aadc2_row4_col0" class="data row4 col0" ></td>
#       <td id="T_aadc2_row4_col1" class="data row4 col1" >controlled</td>
#       <td id="T_aadc2_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_aadc2_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_aadc2_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_aadc2_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_aadc2_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_aadc2_row4_col7" class="data row4 col7" >Neutral</td>
#       <td id="T_aadc2_row4_col8" class="data row4 col8" ></td>
#       <td id="T_aadc2_row4_col9" class="data row4 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_aadc2_row5_col0" class="data row5 col0" ></td>
#       <td id="T_aadc2_row5_col1" class="data row5 col1" >afghanistan</td>
#       <td id="T_aadc2_row5_col2" class="data row5 col2" >-0.448000</td>
#       <td id="T_aadc2_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_aadc2_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_aadc2_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_aadc2_row5_col6" class="data row5 col6" >-0.448000</td>
#       <td id="T_aadc2_row5_col7" class="data row5 col7" >Moderate Negative</td>
#       <td id="T_aadc2_row5_col8" class="data row5 col8" ></td>
#       <td id="T_aadc2_row5_col9" class="data row5 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_aadc2_row6_col0" class="data row6 col0" >(afghanistan, showed, modernization)</td>
#       <td id="T_aadc2_row6_col1" class="data row6 col1" >afghanistan</td>
#       <td id="T_aadc2_row6_col2" class="data row6 col2" >-0.448000</td>
#       <td id="T_aadc2_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_aadc2_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_aadc2_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_aadc2_row6_col6" class="data row6 col6" >-0.448000</td>
#       <td id="T_aadc2_row6_col7" class="data row6 col7" >Moderate Negative</td>
#       <td id="T_aadc2_row6_col8" class="data row6 col8" >[-0.448]</td>
#       <td id="T_aadc2_row6_col9" class="data row6 col9" >['Moderate Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_aadc2_row7_col0" class="data row7 col0" ></td>
#       <td id="T_aadc2_row7_col1" class="data row7 col1" >showed</td>
#       <td id="T_aadc2_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_aadc2_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_aadc2_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_aadc2_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_aadc2_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_aadc2_row7_col7" class="data row7 col7" >Neutral</td>
#       <td id="T_aadc2_row7_col8" class="data row7 col8" ></td>
#       <td id="T_aadc2_row7_col9" class="data row7 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_aadc2_level0_row8" class="row_heading level0 row8" >2</th>
#       <td id="T_aadc2_row8_col0" class="data row8 col0" ></td>
#       <td id="T_aadc2_row8_col1" class="data row8 col1" >modernization</td>
#       <td id="T_aadc2_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_aadc2_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_aadc2_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_aadc2_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_aadc2_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_aadc2_row8_col7" class="data row8 col7" >Neutral</td>
#       <td id="T_aadc2_row8_col8" class="data row8 col8" ></td>
#       <td id="T_aadc2_row8_col9" class="data row8 col9" ></td>
#     </tr>
#     <tr>
#       <

# %%
triplesPolarity_list = []
tripleWeight_TokenLevel = []
for i,j in zip(triplesWeight_TokenLevel,triplePolarity_list):
    tripleWeight_TokenLevel.append(i[0])
    triplesPolarity_list.append(j[0]) 
    
df_CTT = pd.DataFrame(list(zip(tripleWeight_TokenLevel, triplesPolarity_list)), columns =['Weight','Polarity'])
df_CTT.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b3d3c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Weight</th>
#       <th class="col_heading level0 col1" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3d3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3d3c_row0_col0" class="data row0 col0" >-0.448000</td>
#       <td id="T_b3d3c_row0_col1" class="data row0 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3d3c_row1_col0" class="data row1 col0" >-0.448000</td>
#       <td id="T_b3d3c_row1_col1" class="data row1 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3d3c_row2_col0" class="data row2 col0" >-0.448000</td>
#       <td id="T_b3d3c_row2_col1" class="data row2 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3d3c_row3_col0" class="data row3 col0" >-0.448000</td>
#       <td id="T_b3d3c_row3_col1" class="data row3 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3d3c_row4_col0" class="data row4 col0" >-1.000000</td>
#       <td id="T_b3d3c_row4_col1" class="data row4 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3d3c_row5_col0" class="data row5 col0" >-1.000000</td>
#       <td id="T_b3d3c_row5_col1" class="data row5 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3d3c_row6_col0" class="data row6 col0" >-1.000000</td>
#       <td id="T_b3d3c_row6_col1" class="data row6 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3d3c_row7_col0" class="data row7 col0" >-1.000000</td>
#       <td id="T_b3d3c_row7_col1" class="data row7 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3d3c_row8_col0" class="data row8 col0" >-0.975000</td>
#       <td id="T_b3d3c_row8_col1" class="data row8 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3d3c_row9_col0" class="data row9 col0" >-1.000000</td>
#       <td id="T_b3d3c_row9_col1" class="data row9 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b3d3c_row10_col0" class="data row10 col0" >-0.790000</td>
#       <td id="T_b3d3c_row10_col1" class="data row10 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b3d3c_row11_col0" class="data row11 col0" >-0.820000</td>
#       <td id="T_b3d3c_row11_col1" class="data row11 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b3d3c_row12_col0" class="data row12 col0" >0.719000</td>
#       <td id="T_b3d3c_row12_col1" class="data row12 col1" >Strong Positive</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b3d3c_row13_col0" class="data row13 col0" >-0.536000</td>
#       <td id="T_b3d3c_row13_col1" class="data row13 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b3d3c_row14_col0" class="data row14 col0" >-0.014000</td>
#       <td id="T_b3d3c_row14_col1" class="data row14 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b3d3c_row15_col0" class="data row15 col0" >-0.051000</td>
#       <td id="T_b3d3c_row15_col1" class="data row15 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b3d3c_row16_col0" class="data row16 col0" >-0.108000</td>
#       <td id="T_b3d3c_row16_col1" class="data row16 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b3d3c_row17_col0" class="data row17 col0" >-0.057000</td>
#       <td id="T_b3d3c_row17_col1" class="data row17 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b3d3c_row18_col0" class="data row18 col0" >-0.057000</td>
#       <td id="T_b3d3c_row18_col1" class="data row18 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b3d3c_row19_col0" class="data row19 col0" >-1.000000</td>
#       <td id="T_b3d3c_row19_col1" class="data row19 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b3d3c_row20_col0" class="data row20 col0" >-0.057000</td>
#       <td id="T_b3d3c_row20_col1" class="data row20 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b3d3c_row21_col0" class="data row21 col0" >-0.424000</td>
#       <td id="T_b3d3c_row21_col1" class="data row21 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b3d3c_row22_col0" class="data row22 col0" >-0.424000</td>
#       <td id="T_b3d3c_row22_col1" class="data row22 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b3d3c_row23_col0" class="data row23 col0" >-0.522000</td>
#       <td id="T_b3d3c_row23_col1" class="data row23 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b3d3c_row24_col0" class="data row24 col0" >-0.522000</td>
#       <td id="T_b3d3c_row24_col1" class="data row24 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b3d3c_row25_col0" class="data row25 col0" >0.000000</td>
#       <td id="T_b3d3c_row25_col1" class="data row25 col1" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_b3d3c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b3d3c_row26_col0" class="data row26 col0" >0.000000</td>
#       <td id="T_b3d3c_row26_col1" class="data row26 col1" >Neutral</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# #old
#
# sum_list = []
# sum_tup = []
# limit= len(dagCauseTriples)
# #print(limit)
#
# for i in range(0,limit):
#     #dataframe_WordLevel(i)
#     #print(len(allen_word[i]))
#     for j in range(0,len(allen_word[i])):
#         if afinn_word[i][j] == 0 and vader_word[i][j]== 0 and senti_word[i][j] == 0 and allen_word[i][j] == 0:
#             res = 0
#             #check = 1
#         else:
#             res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
#             res = res/4
#             res = round(res,3)
#         #print(res)
#         sum_tup.append(res)
#     sum_list.append(sum_tup)
#     sum_tup = []
#
# def DetectPolarity(sum_list):
#     tokenPolarity = []
#     tokenPolarity_list = []
#     for s in sum_list:
#         for weight in s:
#             if weight >= -1 and weight < -0.6:
#                 tokenPolarity.append('Strong Negative')
#             elif weight >= -0.6 and weight < -0.3:
#                 tokenPolarity.append('Moderate Negative')
#             elif weight >= -0.3 and weight < 0:
#                 tokenPolarity.append('Weak Negative')
#             elif weight == 0:
#                 tokenPolarity.append('Neutral')
#             elif weight <= 1 and weight > 0.6:
#                 tokenPolarity.append('Strong Positive')
#             elif weight <= 0.6 and weight > 0.3:
#                 tokenPolarity.append('Moderate Positive')
#             elif weight <= 0.3 and weight > 0:
#                 tokenPolarity.append('Weak Positive')
#         tokenPolarity_list.append(tokenPolarity)
#         tokenPolarity = []
#     return tokenPolarity_list
#
# tokenPolarity_list = DetectPolarity(sum_list)
#
# triplesWeight_TokenLevel = []
# weightSumTup = []
# for t in sum_list:
#     tripleWeight = 0
#     total = 0
#     #print(total)
#     for w in t:
#         #print(w)
#         if w == 0:
#             total = total
#         else:
#             total = total + 1
#         tripleWeight = tripleWeight + w
#     #print(total)
#     if tripleWeight != 0:
#         tripleWeight = round(tripleWeight/total, 3)
#     weightSumTup.append(tripleWeight)
#     triplesWeight_TokenLevel.append(weightSumTup)
#     weightSumTup = []
#
# triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)
#
# #Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
# #maxPolarity = []
# #triplePolarity_list = []
# #for t in tokenPolarity_list:
# #    counter=collections.Counter(t)
# #    maxPolarity.append(counter.most_common(1)[0][0])
# #    triplePolarity_list.append(maxPolarity)
# #    maxPolarity = []
#
# def dataframe_WordLevel(i):
#     #print(dagCauseTriples[i])
#     df = pd.DataFrame([dagCauseTriples[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],triplesWeight_TokenLevel[i],triplePolarity_list[i]],
#                       index =   ['Tokens','HuggingFace','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])
#     pd.set_option("display.max_rows", None, "display.max_columns", None)
#     return df
#
# for i in range(0,limit):
#     df = dataframe_WordLevel(i)
#     #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
#     #display(df)
#     #df.to_excel(r'./Text/output.xlsx', index = False)
#     replicator(df)
#
# #for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
# #    print(s,w,p)

# %% [markdown]
# # Causal Sentences' Polarity (Token Level)

# %% [markdown]
# ### Generating list of tokens without stop words and punctuation marks.

# %%
def GenerateTokens(causalSentences):
    marks = ['.',',','(',')','-',':',';','/',"'s",'_','__','--','"', '’', '—']
    tagsList = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
    token_list = []
   
    for sent in causalSentences:
        tokens = word_tokenize(str(sent))
        tags = pos_tag(tokens)
        token_tuple = []
        for token,tag in tags:
            if str(token) not in marks:
                if str(token) not in stopwords.words() or tag in tagsList:
                    token_tuple.append(str(token))
        token_list.append(token_tuple)
    return token_list
        
#print(len(token_list))
#print(token_list)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
def Allen_sents_TokenLevel(token_list):
    allen_word = []
    allen_tuple = []
    for tokenTuple in token_list:
        # print(tokenTuple)
        for token in tokenTuple:
            # print(token)
            encoded_input = tokenizer(str(token), return_tensors='pt')
            output = model(**encoded_input)
            scores = output[0][0].detach().numpy()
            scores = softmax(scores)
            if scores[0] > scores[1] and scores[0] > scores[2]:
                score = scores[0] * -1
                score = round(score,3)
                allen_tuple.append(score)
            elif scores[2] > scores[1] and scores[2] > scores[0]:
                scores[2] = round(scores[2],3)
                allen_tuple.append(scores[2])
            else:
                # allen_tuple.append(scores[1])
                allen_tuple.append(0)
        allen_word.append(allen_tuple)
        allen_tuple = []
    return allen_word

# %% [raw]
# ### [AllenNlp]

# %% [raw]
# def Allen_sents_TokenLevel(token_list):
#     allen_word = []
#     allen_tuple = []
#     for tokenTuple in token_list:
#         #print(sent)
#         for token in tokenTuple:
#             #if str(token) not in marks:
#                 #print(token)
#             preds = predictor.predict(str(token))
#                 #print(preds['label'][0])
#             label = preds['label'][0]
#             if label is '0':
#                 allen_tuple.append(-1)
#                     #allen_word.append(-1)
#             else:
#                     #allen_word.append(1)
#                 allen_tuple.append(1)
#         allen_word.append(allen_tuple)
#         allen_tuple = []
#     return allen_word
#
# #for a in allen_word:
# #    print(len(a))
# #    print(a)

# %% [markdown]
# ### [Afinn]

# %%
def Afinn_sents_TokenLevel(token_list):
    afinn_word = []
    afinn_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
            #if str(token) not in marks:
                #print(token)
            score = afn.score(str(token))
            if score < -5:
                score = -5
            elif score > 5:
                score = 5
            score = score/5
            score = round(score,3)
            afinn_tuple.append(score)
            # if score > 0:
            #         #print('positive')
            #     afinn_tuple.append(1)
            # elif score < 0:
            #         #print('negative')
            #     afinn_tuple.append(-1)
            # else:
            #         #print('neutral')
            #     afinn_tuple.append(0)
        afinn_word.append(afinn_tuple)
        afinn_tuple = []
    return afinn_word

#for a in afinn_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Vader]

# %%
def Vader_sents_TokenLevel(token_list):
    vader_word = []
    vader_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
            vs = analyzer.polarity_scores(str(token))
            compound = vs['compound']
            compound = round(compound,3)
            vader_tuple.append(compound)
            # if compound >= 0.05:
            #     vader_tuple.append(1)   
            # elif compound <= -0.05 :
            #     vader_tuple.append(-1)
            # elif  compound > -0.05 and compound < 0.05:
            #     vader_tuple.append(0)
        vader_word.append(vader_tuple)
        vader_tuple = []
    return vader_word

#for a in vader_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [SentiStrength]

# %%
def Senti_sents_TokenLevel(token_list):
    senti_word = []
    senti_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
                #print(token)
            result = senti.getSentiment(str(token), score='scale')
                #print(result)
            result = result[0]/4
            result = round(result,3)
            senti_tuple.append(result)
            # if result[0] > 0:
            #     senti_tuple.append(1)
            # elif result[0] < 0:
            #     senti_tuple.append(-1)
            # else:
            #     senti_tuple.append(0)
        senti_word.append(senti_tuple)
        senti_tuple = []
    return senti_word
    
#for a in senti_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### Data Frame (Causal Sentences Word Level)

# %%
#new

token_list = GenerateTokens(dagCauseSents)
allen_word = Allen_sents_TokenLevel(token_list)
afinn_word = Afinn_sents_TokenLevel(token_list)
vader_word = Vader_sents_TokenLevel(token_list)   
senti_word = Senti_sents_TokenLevel(token_list)

sum_list = []
sum_tup = []
limit= len(dagCauseSents)

for i in range(0,limit):
    for j in range(0,len(allen_word[i])):
        count = 0
        if afinn_word[i][j] != 0: 
            count = count +1
        if vader_word[i][j] != 0:
            count = count +1
        if senti_word[i][j] != 0:
            count = count +1
        if allen_word[i][j] != 0:
            count = count +1
        if count == 0:
            count = 1
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        res = res/count
        res = round(res,3)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -1 and weight < -0.6:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -0.6 and weight < -0.3:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -0.3 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 1 and weight > 0.6:
                tokenPolarity.append('Strong Positive')
            elif weight <= 0.6 and weight > 0.3:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 0.3 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

sentsWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = 0
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight, 3)
    if tripleWeight > 1: 
        tripleWeight = 1
    if tripleWeight < -1:
        tripleWeight = -1
    weightSumTup.append(tripleWeight)
    sentsWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)

    
df1 = pd.DataFrame(list(zip(dagCauseSents,token_list, allen_word, afinn_word,vader_word,senti_word,sum_list,tokenPolarity_list,sentsWeight_TokenLevel,SentencePolarity_list)), 
                      columns =['Causal Sentence', "Tokens", 'HuggingFace','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])

df1 = df1.explode(['Tokens', 'HuggingFace','Afinn','Vader','SentiStrength','Token Weight', 'Token Polarity'], ignore_index=False)

prev = -1
for index, row in df1.iterrows():
    if prev == index:
        row['Causal Sentence'] = ""
        row['Sentence Weight'] = ""
        row['Sentence Polarity'] = ""
    prev = index
df1.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_47ac8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Sentence</th>
#       <th class="col_heading level0 col1" >Tokens</th>
#       <th class="col_heading level0 col2" >HuggingFace</th>
#       <th class="col_heading level0 col3" >Afinn</th>
#       <th class="col_heading level0 col4" >Vader</th>
#       <th class="col_heading level0 col5" >SentiStrength</th>
#       <th class="col_heading level0 col6" >Token Weight</th>
#       <th class="col_heading level0 col7" >Token Polarity</th>
#       <th class="col_heading level0 col8" >Sentence Weight</th>
#       <th class="col_heading level0 col9" >Sentence Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47ac8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47ac8_row0_col0" class="data row0 col0" >afghanistan was controlled by central government.</td>
#       <td id="T_47ac8_row0_col1" class="data row0 col1" >afghanistan</td>
#       <td id="T_47ac8_row0_col2" class="data row0 col2" >-0.448000</td>
#       <td id="T_47ac8_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_47ac8_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_47ac8_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_47ac8_row0_col6" class="data row0 col6" >-0.448000</td>
#       <td id="T_47ac8_row0_col7" class="data row0 col7" >Moderate Negative</td>
#       <td id="T_47ac8_row0_col8" class="data row0 col8" >[-0.448]</td>
#       <td id="T_47ac8_row0_col9" class="data row0 col9" >['Moderate Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_47ac8_row1_col0" class="data row1 col0" ></td>
#       <td id="T_47ac8_row1_col1" class="data row1 col1" >was</td>
#       <td id="T_47ac8_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_47ac8_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_47ac8_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_47ac8_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_47ac8_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_47ac8_row1_col7" class="data row1 col7" >Neutral</td>
#       <td id="T_47ac8_row1_col8" class="data row1 col8" ></td>
#       <td id="T_47ac8_row1_col9" class="data row1 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_47ac8_row2_col0" class="data row2 col0" ></td>
#       <td id="T_47ac8_row2_col1" class="data row2 col1" >controlled</td>
#       <td id="T_47ac8_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_47ac8_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_47ac8_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_47ac8_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_47ac8_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_47ac8_row2_col7" class="data row2 col7" >Neutral</td>
#       <td id="T_47ac8_row2_col8" class="data row2 col8" ></td>
#       <td id="T_47ac8_row2_col9" class="data row2 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_47ac8_row3_col0" class="data row3 col0" ></td>
#       <td id="T_47ac8_row3_col1" class="data row3 col1" >central</td>
#       <td id="T_47ac8_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_47ac8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_47ac8_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_47ac8_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_47ac8_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_47ac8_row3_col7" class="data row3 col7" >Neutral</td>
#       <td id="T_47ac8_row3_col8" class="data row3 col8" ></td>
#       <td id="T_47ac8_row3_col9" class="data row3 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_47ac8_row4_col0" class="data row4 col0" ></td>
#       <td id="T_47ac8_row4_col1" class="data row4 col1" >government</td>
#       <td id="T_47ac8_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_47ac8_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_47ac8_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_47ac8_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_47ac8_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_47ac8_row4_col7" class="data row4 col7" >Neutral</td>
#       <td id="T_47ac8_row4_col8" class="data row4 col8" ></td>
#       <td id="T_47ac8_row4_col9" class="data row4 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_47ac8_row5_col0" class="data row5 col0" >afghanistan was controlled by zahir shah.</td>
#       <td id="T_47ac8_row5_col1" class="data row5 col1" >afghanistan</td>
#       <td id="T_47ac8_row5_col2" class="data row5 col2" >-0.448000</td>
#       <td id="T_47ac8_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_47ac8_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_47ac8_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_47ac8_row5_col6" class="data row5 col6" >-0.448000</td>
#       <td id="T_47ac8_row5_col7" class="data row5 col7" >Moderate Negative</td>
#       <td id="T_47ac8_row5_col8" class="data row5 col8" >[-0.791]</td>
#       <td id="T_47ac8_row5_col9" class="data row5 col9" >['Strong Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_47ac8_row6_col0" class="data row6 col0" ></td>
#       <td id="T_47ac8_row6_col1" class="data row6 col1" >was</td>
#       <td id="T_47ac8_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_47ac8_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_47ac8_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_47ac8_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_47ac8_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_47ac8_row6_col7" class="data row6 col7" >Neutral</td>
#       <td id="T_47ac8_row6_col8" class="data row6 col8" ></td>
#       <td id="T_47ac8_row6_col9" class="data row6 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_47ac8_row7_col0" class="data row7 col0" ></td>
#       <td id="T_47ac8_row7_col1" class="data row7 col1" >controlled</td>
#       <td id="T_47ac8_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_47ac8_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_47ac8_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_47ac8_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_47ac8_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_47ac8_row7_col7" class="data row7 col7" >Neutral</td>
#       <td id="T_47ac8_row7_col8" class="data row7 col8" ></td>
#       <td id="T_47ac8_row7_col9" class="data row7 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_47ac8_row8_col0" class="data row8 col0" ></td>
#       <td id="T_47ac8_row8_col1" class="data row8 col1" >zahir</td>
#       <td id="T_47ac8_row8_col2" class="data row8 col2" >-0.343000</td>
#       <td id="T_47ac8_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_47ac8_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_47ac8_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_47ac8_row8_col6" class="data row8 col6" >-0.343000</td>
#       <td id="T_47ac8_row8_col7" class="data row8 col7" >Moderate Negative</td>
#       <td id="T_47ac8_row8_col8" class="data row8 col8" ></td>
#       <td id="T_47ac8_row8_col9" class="data row8 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_47ac8_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T

# %%
sentencePolarity_list = []
sentWeight_TokenLevel = []
for i,j in zip (sentsWeight_TokenLevel,SentencePolarity_list):
    sentWeight_TokenLevel.append(i[0]) 
    sentencePolarity_list.append(j[0]) 
    
df_CST = pd.DataFrame(list(zip(sentWeight_TokenLevel, sentencePolarity_list)), columns =['Weight','Polarity'])
df_CST.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4ca5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Weight</th>
#       <th class="col_heading level0 col1" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4ca5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4ca5_row0_col0" class="data row0 col0" >-0.448000</td>
#       <td id="T_d4ca5_row0_col1" class="data row0 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4ca5_row1_col0" class="data row1 col0" >-0.791000</td>
#       <td id="T_d4ca5_row1_col1" class="data row1 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4ca5_row2_col0" class="data row2 col0" >-0.448000</td>
#       <td id="T_d4ca5_row2_col1" class="data row2 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4ca5_row3_col0" class="data row3 col0" >-0.448000</td>
#       <td id="T_d4ca5_row3_col1" class="data row3 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4ca5_row4_col0" class="data row4 col0" >-1.000000</td>
#       <td id="T_d4ca5_row4_col1" class="data row4 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d4ca5_row5_col0" class="data row5 col0" >-1.000000</td>
#       <td id="T_d4ca5_row5_col1" class="data row5 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d4ca5_row6_col0" class="data row6 col0" >-1.000000</td>
#       <td id="T_d4ca5_row6_col1" class="data row6 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d4ca5_row7_col0" class="data row7 col0" >-1.000000</td>
#       <td id="T_d4ca5_row7_col1" class="data row7 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d4ca5_row8_col0" class="data row8 col0" >-1.000000</td>
#       <td id="T_d4ca5_row8_col1" class="data row8 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d4ca5_row9_col0" class="data row9 col0" >-1.000000</td>
#       <td id="T_d4ca5_row9_col1" class="data row9 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d4ca5_row10_col0" class="data row10 col0" >-1.000000</td>
#       <td id="T_d4ca5_row10_col1" class="data row10 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d4ca5_row11_col0" class="data row11 col0" >-1.000000</td>
#       <td id="T_d4ca5_row11_col1" class="data row11 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d4ca5_row12_col0" class="data row12 col0" >0.271000</td>
#       <td id="T_d4ca5_row12_col1" class="data row12 col1" >Weak Positive</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d4ca5_row13_col0" class="data row13 col0" >-0.873000</td>
#       <td id="T_d4ca5_row13_col1" class="data row13 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d4ca5_row14_col0" class="data row14 col0" >-0.873000</td>
#       <td id="T_d4ca5_row14_col1" class="data row14 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d4ca5_row15_col0" class="data row15 col0" >0.023000</td>
#       <td id="T_d4ca5_row15_col1" class="data row15 col1" >Weak Positive</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d4ca5_row16_col0" class="data row16 col0" >-0.034000</td>
#       <td id="T_d4ca5_row16_col1" class="data row16 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d4ca5_row17_col0" class="data row17 col0" >-0.417000</td>
#       <td id="T_d4ca5_row17_col1" class="data row17 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d4ca5_row18_col0" class="data row18 col0" >-0.074000</td>
#       <td id="T_d4ca5_row18_col1" class="data row18 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d4ca5_row19_col0" class="data row19 col0" >-0.690000</td>
#       <td id="T_d4ca5_row19_col1" class="data row19 col1" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d4ca5_row20_col0" class="data row20 col0" >-0.074000</td>
#       <td id="T_d4ca5_row20_col1" class="data row20 col1" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d4ca5_row21_col0" class="data row21 col0" >-0.424000</td>
#       <td id="T_d4ca5_row21_col1" class="data row21 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d4ca5_row22_col0" class="data row22 col0" >-0.424000</td>
#       <td id="T_d4ca5_row22_col1" class="data row22 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d4ca5_row23_col0" class="data row23 col0" >-0.448000</td>
#       <td id="T_d4ca5_row23_col1" class="data row23 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d4ca5_row24_col0" class="data row24 col0" >-0.448000</td>
#       <td id="T_d4ca5_row24_col1" class="data row24 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d4ca5_row25_col0" class="data row25 col0" >-0.448000</td>
#       <td id="T_d4ca5_row25_col1" class="data row25 col1" >Moderate Negative</td>
#     </tr>
#     <tr>
#       <th id="T_d4ca5_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d4ca5_row26_col0" class="data row26 col0" >-0.448000</td>
#       <td id="T_d4ca5_row26_col1" class="data row26 col1" >Moderate Negative</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# #old
#
# token_list = GenerateTokens(dagCauseSents)
# #print(token_list)
# allen_word = Allen_sents_TokenLevel(token_list)
# afinn_word = Afinn_sents_TokenLevel(token_list)
# vader_word = Vader_sents_TokenLevel(token_list)
# senti_word = Senti_sents_TokenLevel(token_list)
#
# sum_list = []
# sum_tup = []
# limit= len(dagCauseSents)
#
# #print(limit)
# for i in range(0,limit):
#     #dataframe_WordLevel(i)
#     #print(len(allen_word[i]))
#     for j in range(0,len(allen_word[i])):
#         count = 0
#         if afinn_word[i][j] != 0:
#             count = count +1
#         if vader_word[i][j] != 0:
#             count = count +1
#         if senti_word[i][j] != 0:
#             count = count +1
#         if allen_word[i][j] != 0:
#             count = count +1
#         if count == 0:
#             count = 1
#         res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
#         res = res/count
#         res = round(res,3)
#         #print(res)
#         sum_tup.append(res)
#     sum_list.append(sum_tup)
#     sum_tup = []
#
# def DetectPolarity(sum_list):
#     tokenPolarity = []
#     tokenPolarity_list = []
#     for s in sum_list:
#         for weight in s:
#             if weight >= -1 and weight < -0.6:
#                 tokenPolarity.append('Strong Negative')
#             elif weight >= -0.6 and weight < -0.3:
#                 tokenPolarity.append('Moderate Negative')
#             elif weight >= -0.3 and weight < 0:
#                 tokenPolarity.append('Weak Negative')
#             elif weight == 0:
#                 tokenPolarity.append('Neutral')
#             elif weight <= 1 and weight > 0.6:
#                 tokenPolarity.append('Strong Positive')
#             elif weight <= 0.6 and weight > 0.3:
#                 tokenPolarity.append('Moderate Positive')
#             elif weight <= 0.3 and weight > 0:
#                 tokenPolarity.append('Weak Positive')
#         tokenPolarity_list.append(tokenPolarity)
#         tokenPolarity = []
#     return tokenPolarity_list
#
# tokenPolarity_list = DetectPolarity(sum_list)
#
# sentsWeight_TokenLevel = []
# weightSumTup = []
# for t in sum_list:
#     tripleWeight = 0
#     total = 0
#     #total = len(t)
#     #print(total)
#     for w in t:
#         tripleWeight = tripleWeight + w
#     tripleWeight = round(tripleWeight, 3)
#     if tripleWeight > 1:
#         tripleWeight = 1
#     if tripleWeight < -1:
#         tripleWeight = -1
#     weightSumTup.append(tripleWeight)
#     sentsWeight_TokenLevel.append(weightSumTup)
#     weightSumTup = []
#
# SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)
#
# #Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
# #maxPolarity = []
# #triplePolarity_list = []
# #for t in tokenPolarity_list:
# #    counter=collections.Counter(t)
# #    maxPolarity.append(counter.most_common(1)[0][0])
# #    triplePolarity_list.append(maxPolarity)
# #    maxPolarity = []
#
#
# def dataframe_WordLevel(i):
#     df = pd.DataFrame([token_list[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],sentsWeight_TokenLevel[i],SentencePolarity_list[i]],
#                       index =   ['Tokens','HuggingFace','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])
#     pd.set_option("display.max_rows", None, "display.max_columns", None)
#     return df
#
# for i in range(0,limit):
#     df_CST = dataframe_WordLevel(i)
#     #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
#     #display(df)
#     #df.to_excel(r'./Text/output.xlsx', index = False)
#     replicator(df_CST)
#
# #for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
# #    print(s,w,p)

# %% [markdown]
# # Causal Verbs Polarity (Whole)

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen = []
for sent in dagCauseVerbs:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        score = round(score,3)
        allen.append(score)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        scores[2] = round(scores[2],3)
        allen.append(scores[2])
    else:
        # allen.append(scores[1])
        allen.append(0)

for causalSentence, polarity  in zip(dagCauseVerbs, allen):
    print(causalSentence, polarity)
# Out:
# controlled 0
# controlled 0
# showed 0
# showed 0
# caused 0
# caused 0
# caused 0
# caused 0
# caused 0
# caused 0
# demanded 0
# demanded 0
# can restore 0
# must continue 0.411
# must continue 0.411
# will cause 0
# will cause 0
# must support 0.419
# must support 0.419
# leads 0
# must support 0.419
# can transcend 0
# can transcend 0
# can cause 0
# can cause 0
# can cause 0
# can cause 0

# %% [raw]
# ### [AllenNlp]

# %% [raw]
# allen = []
# for sent in dagCauseVerbs:
#     preds = predictor.predict(str(sent))
#     label = preds['label'][0]
#     if label is '0':
#         allen.append(-1)
#     else:
#         allen.append(1)
#
# for causalSentence, polarity  in zip(dagCauseVerbs, allen):
#     print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
afinn = []
for sent in dagCauseVerbs:
    #print(str(sent))
    score = afn.score(str(sent))
    # print(score)
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    score = round(score,3)
    afinn.append(score)
    # if score > 0:
    #     #print('positive')
    #     afinn.append(1)
    # elif score < 0:
    #     #print('negative')
    #     afinn.append(-1)
    # else:
    #     #print('neutral')
    #     afinn.append(0)
        
for causalSentence, polarity  in zip(dagCauseVerbs, afinn):
    print(causalSentence, polarity)
# Out:
# controlled 0.0
# controlled 0.0
# showed 0.0
# showed 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# demanded -0.2
# demanded -0.2
# can restore 0.2
# must continue 0.0
# must continue 0.0
# will cause 0.0
# will cause 0.0
# must support 0.4
# must support 0.4
# leads 0.0
# must support 0.4
# can transcend 0.0
# can transcend 0.0
# can cause 0.0
# can cause 0.0
# can cause 0.0
# can cause 0.0

# %% [markdown]
# ### [Vader]

# %%
vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

# def vader_analysis(compound):
#     if compound >= 0.05:
#         vader.append(1)
#         return 'Positive'
#     elif compound <= -0.05 :
#         vader.append(-1)
#         return 'Negative'
#     elif  compound > -0.05 and compound < 0.05:
#         vader.append(0)
#         return 'Neutral'
    
for sent in dagCauseVerbs:
    compound = vadersentimentanalysis(str(sent))
    compound = round(compound,3)
    compound = round(compound,3)
    vader.append(compound)
    
for causalSentence, polarity  in zip(dagCauseVerbs, vader):
    print(causalSentence, polarity)
# Out:
# controlled 0.0
# controlled 0.0
# showed 0.0
# showed 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# demanded -0.226
# demanded -0.226
# can restore 0.296
# must continue 0.0
# must continue 0.0
# will cause 0.0
# will cause 0.0
# must support 0.402
# must support 0.402
# leads 0.0
# must support 0.402
# can transcend 0.0
# can transcend 0.0
# can cause 0.0
# can cause 0.0
# can cause 0.0
# can cause 0.0

# %% [markdown]
# ### [SentiStrength]

# %%
sentiStrength = []

for sent in dagCauseVerbs:
    result = senti.getSentiment(str(sent), score='scale')
    result = result[0]/4
    result = round(result,3)
    sentiStrength.append(result)
    # if result[0] > 0:
    #     sentiStrength.append(1)
    # elif result[0] < 0:
    #     sentiStrength.append(-1)
    # else:
    #     sentiStrength.append(0)
    
for causalSentence, polarity  in zip(dagCauseVerbs, sentiStrength):
    print(causalSentence, polarity)
# Out:
# controlled 0.0
# controlled 0.0
# showed 0.0
# showed 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# demanded 0.0
# demanded 0.0
# can restore 0.0
# must continue 0.0
# must continue 0.0
# will cause 0.0
# will cause 0.0
# must support 0.25
# must support 0.25
# leads 0.0
# must support 0.25
# can transcend 0.0
# can transcend 0.0
# can cause 0.0
# can cause 0.0
# can cause 0.0
# can cause 0.0

# %% [markdown]
# ### Data Frame (Causal Verbs Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df_CVW = pd.DataFrame(list(zip(dagCauseVerbs, allen, afinn, vader,sentiStrength)), columns =['Causal Verb', 'HuggingFace','Afinn','Vader','SentiStrength'])
# df2["Weight"] = round(df2.sum(axis=1)/4,3)

df_CVW["Weight"] = df_CVW.sum(axis=1)

for i in df_CVW.index:
    count = 0
#     print(df2["Afinn"][i])
    if df_CVW["HuggingFace"][i] != 0:
        count = count + 1
    if df_CVW["Afinn"][i] != 0:
        count = count + 1
    if df_CVW["Vader"][i] != 0:
        count = count + 1
    if df_CVW["SentiStrength"][i] != 0:
        count = count + 1
    if count == 0:
        count = 1
    df_CVW["Weight"][i] = round(df_CVW["Weight"][i]/count,3)

sentPolarity = []
VerbsWeight_sentLevel = []

for index, row in df_CVW.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    VerbsWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -1 and weight < -0.6:
        sentPolarity.append('Strong Negative') 
    elif weight >= -0.6 and weight < -0.3:
        sentPolarity.append('Moderate Negative')
    elif weight >= -0.3 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 1 and weight > 0.6:
        sentPolarity.append('Strong Positive')
    elif weight <= 0.6 and weight > 0.3:
        sentPolarity.append('Moderate Positive')
    elif weight <= 0.3 and weight > 0:
        sentPolarity.append('Weak Positive')

df_CVW["Polarity"] = sentPolarity
df_CVW.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <style type="text/css">
# </style>
# <table id="T_61758_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Verb</th>
#       <th class="col_heading level0 col1" >HuggingFace</th>
#       <th class="col_heading level0 col2" >Afinn</th>
#       <th class="col_heading level0 col3" >Vader</th>
#       <th class="col_heading level0 col4" >SentiStrength</th>
#       <th class="col_heading level0 col5" >Weight</th>
#       <th class="col_heading level0 col6" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61758_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61758_row0_col0" class="data row0 col0" >controlled</td>
#       <td id="T_61758_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_61758_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_61758_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_61758_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_61758_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_61758_row0_col6" class="data row0 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61758_row1_col0" class="data row1 col0" >controlled</td>
#       <td id="T_61758_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_61758_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_61758_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_61758_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_61758_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_61758_row1_col6" class="data row1 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61758_row2_col0" class="data row2 col0" >showed</td>
#       <td id="T_61758_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_61758_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_61758_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_61758_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_61758_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_61758_row2_col6" class="data row2 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_61758_row3_col0" class="data row3 col0" >showed</td>
#       <td id="T_61758_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_61758_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_61758_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_61758_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_61758_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_61758_row3_col6" class="data row3 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_61758_row4_col0" class="data row4 col0" >caused</td>
#       <td id="T_61758_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_61758_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_61758_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_61758_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_61758_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_61758_row4_col6" class="data row4 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_61758_row5_col0" class="data row5 col0" >caused</td>
#       <td id="T_61758_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_61758_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_61758_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_61758_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_61758_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_61758_row5_col6" class="data row5 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_61758_row6_col0" class="data row6 col0" >caused</td>
#       <td id="T_61758_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_61758_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_61758_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_61758_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_61758_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_61758_row6_col6" class="data row6 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_61758_row7_col0" class="data row7 col0" >caused</td>
#       <td id="T_61758_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_61758_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_61758_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_61758_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_61758_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_61758_row7_col6" class="data row7 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_61758_row8_col0" class="data row8 col0" >caused</td>
#       <td id="T_61758_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_61758_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_61758_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_61758_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_61758_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_61758_row8_col6" class="data row8 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_61758_row9_col0" class="data row9 col0" >caused</td>
#       <td id="T_61758_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_61758_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_61758_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_61758_row9_col4" class="data row9 col4" >0.000000</td>
#       <td id="T_61758_row9_col5" class="data row9 col5" >0.000000</td>
#       <td id="T_61758_row9_col6" class="data row9 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_61758_row10_col0" class="data row10 col0" >demanded</td>
#       <td id="T_61758_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_61758_row10_col2" class="data row10 col2" >-0.200000</td>
#       <td id="T_61758_row10_col3" class="data row10 col3" >-0.226000</td>
#       <td id="T_61758_row10_col4" class="data row10 col4" >0.000000</td>
#       <td id="T_61758_row10_col5" class="data row10 col5" >-0.213000</td>
#       <td id="T_61758_row10_col6" class="data row10 col6" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_61758_row11_col0" class="data row11 col0" >demanded</td>
#       <td id="T_61758_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_61758_row11_col2" class="data row11 col2" >-0.200000</td>
#       <td id="T_61758_row11_col3" class="data row11 col3" >-0.226000</td>
#       <td id="T_61758_row11_col4" class="data row11 col4" >0.000000</td>
#       <td id="T_61758_row11_col5" class="data row11 col5" >-0.213000</td>
#       <td id="T_61758_row11_col6" class="data row11 col6" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_61758_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_61758_row12_col0" class="data row12 col0" >can restore</td>
#       <td id="T_61758_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_61758_row12_col2" class="data row12 col2" >0.200000</td>
#       <td id="T_6175

# %% [markdown]
# # Lemma Causal Verbs Polarity (Whole)

# %% [markdown]
# ### Generating list of lemmas for whole causal verbs.

# %%
lemmaDagCauseVerbs = []
tagsList = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
for verb in dagCauseVerbs:
    #print("Verb:" + verb)
    tokens = word_tokenize(verb)
    #print("Tokens:" + str(tokens))
    tags = pos_tag(tokens)
    #print(tags)
    for token,tag in tags:
        #print("Token:" + token)
        #print("Tag:" + tag)
        if token not in stopwords.words() or tag in tagsList:
            #print("No stop:" + token)
            lemma = lemma_function.lemmatize(str(token))
            #print("Lemma:" + lemma)
            lemmaDagCauseVerbs.append(lemma)
        
for v, l in zip(dagCauseVerbs,lemmaDagCauseVerbs):
    print(v,l)
# Out:
# controlled controlled
# controlled controlled
# showed showed
# showed showed
# caused caused
# caused caused
# caused caused
# caused caused
# caused caused
# caused caused
# demanded demanded
# demanded demanded
# can restore restore
# must continue continue
# must continue continue
# will cause cause
# will cause cause
# must support support
# must support support
# leads lead
# must support support
# can transcend transcend
# can transcend transcend
# can cause cause
# can cause cause
# can cause cause
# can cause cause

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen = []
for sent in lemmaDagCauseVerbs:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        score = round(score,3)
        allen.append(score)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        scores[2] = round(scores[2],3)
        allen.append(scores[2])
    else:
        # allen.append(scores[1])
        allen.append(0)

for causalSentence, polarity  in zip(lemmaDagCauseVerbs, allen):
    print(causalSentence, polarity)
# Out:
# controlled 0
# controlled 0
# showed 0
# showed 0
# caused 0
# caused 0
# caused 0
# caused 0
# caused 0
# caused 0
# demanded 0
# demanded 0
# restore 0
# continue 0
# continue 0
# cause 0
# cause 0
# support 0
# support 0
# lead 0
# support 0
# transcend 0
# transcend 0
# cause 0
# cause 0
# cause 0
# cause 0

# %% [markdown]
# ### [Afinn]

# %%
afinn = []
for sent in lemmaDagCauseVerbs:
    #print(str(sent))
    score = afn.score(str(sent))
    # print(score)
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    score = round(score,3)
    afinn.append(score)
    # if score > 0:
    #     #print('positive')
    #     afinn.append(1)
    # elif score < 0:
    #     #print('negative')
    #     afinn.append(-1)
    # else:
    #     #print('neutral')
    #     afinn.append(0)
        
for causalSentence, polarity  in zip(lemmaDagCauseVerbs, afinn):
    print(causalSentence, polarity)
# Out:
# controlled 0.0
# controlled 0.0
# showed 0.0
# showed 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# demanded -0.2
# demanded -0.2
# restore 0.2
# continue 0.0
# continue 0.0
# cause 0.0
# cause 0.0
# support 0.4
# support 0.4
# lead 0.0
# support 0.4
# transcend 0.0
# transcend 0.0
# cause 0.0
# cause 0.0
# cause 0.0
# cause 0.0

# %% [markdown]
# ### [Vader]

# %%
vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

# def vader_analysis(compound):
#     if compound >= 0.05:
#         vader.append(1)
#         return 'Positive'
#     elif compound <= -0.05 :
#         vader.append(-1)
#         return 'Negative'
#     elif  compound > -0.05 and compound < 0.05:
#         vader.append(0)
#         return 'Neutral'
    
for sent in lemmaDagCauseVerbs:
    compound = vadersentimentanalysis(str(sent))
    compound = round(compound,3)
    vader.append(compound)
    
for causalSentence, polarity  in zip(lemmaDagCauseVerbs, vader):
    print(causalSentence, polarity)
# Out:
# controlled 0.0
# controlled 0.0
# showed 0.0
# showed 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# demanded -0.226
# demanded -0.226
# restore 0.296
# continue 0.0
# continue 0.0
# cause 0.0
# cause 0.0
# support 0.402
# support 0.402
# lead 0.0
# support 0.402
# transcend 0.0
# transcend 0.0
# cause 0.0
# cause 0.0
# cause 0.0
# cause 0.0

# %% [markdown]
# ### [SentiStrength]

# %%
sentiStrength = []

for sent in lemmaDagCauseVerbs:
    result = senti.getSentiment(str(sent), score='scale')
    result = result[0]/4
    result = round(result,3)
    sentiStrength.append(result)
    # if result[0] > 0:
    #     sentiStrength.append(1)
    # elif result[0] < 0:
    #     sentiStrength.append(-1)
    # else:
    #     sentiStrength.append(0)
    
for causalSentence, polarity  in zip(lemmaDagCauseVerbs, sentiStrength):
    print(causalSentence, polarity)
# Out:
# controlled 0.0
# controlled 0.0
# showed 0.0
# showed 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# caused 0.0
# demanded 0.0
# demanded 0.0
# restore 0.0
# continue 0.0
# continue 0.0
# cause 0.0
# cause 0.0
# support 0.25
# support 0.25
# lead 0.0
# support 0.25
# transcend 0.0
# transcend 0.0
# cause 0.0
# cause 0.0
# cause 0.0
# cause 0.0

# %% [markdown]
# ### Data Frame (Lemma Causal Verbs Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df_CVL = pd.DataFrame(list(zip(dagCauseVerbs, lemmaDagCauseVerbs,allen, afinn, vader,sentiStrength)), columns =['Causal Verb', 'Lemma(Causal Verb)' ,'HuggingFace','Afinn','Vader','SentiStrength'])
# df2["Weight"] = round(df2.sum(axis=1)/4,3)

df_CVL["Weight"] = df_CVL.sum(axis=1)

for i in df_CVL.index:
    count = 0
#     print(df2["Afinn"][i])
    if df_CVL["HuggingFace"][i] != 0:
        count = count + 1
    if df_CVL["Afinn"][i] != 0:
        count = count + 1
    if df_CVL["Vader"][i] != 0:
        count = count + 1
    if df_CVL["SentiStrength"][i] != 0:
        count = count + 1
    if count == 0:
        count = 1
    df_CVL["Weight"][i] = round(df_CVL["Weight"][i]/count,3)

sentPolarity = []
LemmaVerbsWeight_tokLevel = []

for index, row in df_CVL.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    LemmaVerbsWeight_tokLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -1 and weight < -0.6:
        sentPolarity.append('Strong Negative') 
    elif weight >= -0.6 and weight < -0.3:
        sentPolarity.append('Moderate Negative')
    elif weight >= -0.3 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 1 and weight > 0.6:
        sentPolarity.append('Strong Positive')
    elif weight <= 0.6 and weight > 0.3:
        sentPolarity.append('Moderate Positive')
    elif weight <= 0.3 and weight > 0:
        sentPolarity.append('Weak Positive')

df_CVL["Polarity"] = sentPolarity
df_CVL.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <style type="text/css">
# </style>
# <table id="T_1032b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Verb</th>
#       <th class="col_heading level0 col1" >Lemma(Causal Verb)</th>
#       <th class="col_heading level0 col2" >HuggingFace</th>
#       <th class="col_heading level0 col3" >Afinn</th>
#       <th class="col_heading level0 col4" >Vader</th>
#       <th class="col_heading level0 col5" >SentiStrength</th>
#       <th class="col_heading level0 col6" >Weight</th>
#       <th class="col_heading level0 col7" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1032b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1032b_row0_col0" class="data row0 col0" >controlled</td>
#       <td id="T_1032b_row0_col1" class="data row0 col1" >controlled</td>
#       <td id="T_1032b_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1032b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_1032b_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_1032b_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_1032b_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_1032b_row0_col7" class="data row0 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1032b_row1_col0" class="data row1 col0" >controlled</td>
#       <td id="T_1032b_row1_col1" class="data row1 col1" >controlled</td>
#       <td id="T_1032b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_1032b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_1032b_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_1032b_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_1032b_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_1032b_row1_col7" class="data row1 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1032b_row2_col0" class="data row2 col0" >showed</td>
#       <td id="T_1032b_row2_col1" class="data row2 col1" >showed</td>
#       <td id="T_1032b_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_1032b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_1032b_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_1032b_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_1032b_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_1032b_row2_col7" class="data row2 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1032b_row3_col0" class="data row3 col0" >showed</td>
#       <td id="T_1032b_row3_col1" class="data row3 col1" >showed</td>
#       <td id="T_1032b_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_1032b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_1032b_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_1032b_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_1032b_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_1032b_row3_col7" class="data row3 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1032b_row4_col0" class="data row4 col0" >caused</td>
#       <td id="T_1032b_row4_col1" class="data row4 col1" >caused</td>
#       <td id="T_1032b_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_1032b_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_1032b_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_1032b_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_1032b_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_1032b_row4_col7" class="data row4 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1032b_row5_col0" class="data row5 col0" >caused</td>
#       <td id="T_1032b_row5_col1" class="data row5 col1" >caused</td>
#       <td id="T_1032b_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_1032b_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_1032b_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_1032b_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_1032b_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_1032b_row5_col7" class="data row5 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1032b_row6_col0" class="data row6 col0" >caused</td>
#       <td id="T_1032b_row6_col1" class="data row6 col1" >caused</td>
#       <td id="T_1032b_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_1032b_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_1032b_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_1032b_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_1032b_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_1032b_row6_col7" class="data row6 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1032b_row7_col0" class="data row7 col0" >caused</td>
#       <td id="T_1032b_row7_col1" class="data row7 col1" >caused</td>
#       <td id="T_1032b_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_1032b_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_1032b_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_1032b_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_1032b_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_1032b_row7_col7" class="data row7 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1032b_row8_col0" class="data row8 col0" >caused</td>
#       <td id="T_1032b_row8_col1" class="data row8 col1" >caused</td>
#       <td id="T_1032b_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_1032b_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_1032b_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_1032b_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_1032b_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_1032b_row8_col7" class="data row8 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1032b_row9_col0" class="data row9 col0" >caused</td>
#       <td id="T_1032b_row9_col1" class="data row9 col1" >caused</td>
#       <td id="T_1032b_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_1032b_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_1032b_row9_col4" class="data row9 col4" >0.000000</td>
#       <td id="T_1032b_row9_col5" class="data row9 col5" >0.000000</td>
#       <td id="T_1032b_row9_col6" class="data row9 col6" >0.000000</td>
#       <td id="T_1032b_row9_col7" class="data row9 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1032b_row10_col0" class="data row10 col0" >demanded</td>
#       <td id="T_1032b_row10_col1" class="data row10 col1" >demanded</td>
#       <td id="T_1032b_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_1032b_row10_col3" class="data row10 col3" >-0.200000</td>
#       <td id="T_1032b_row10_col4" class="data row10 col4" >-0.226000</td>
#       <td id="T_1032b_row10_col5" class="data row10 col5" >0.000000</td>
#       <td id="T_1032b_row10_col6" class="data row10 col6" >-0.213000</td>
#       <td id="T_1032b_row10_col7" class="data row10 col7" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_1032b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1032b_row11_col0" class="data row11 col0" >demanded</td>
#       <td id="T_1032b_ro

# %% [markdown]
# # Stem Causal Verbs Polarity (Whole)

# %% [markdown]
# ### Generating list of stems for whole causal verbs.

# %%
stemDagCauseVerbs = []
tagsList = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
for verb in dagCauseVerbs:
    # print("Verb:" + verb)
    tokens = word_tokenize(verb)
    # print("Tokens:" + str(tokens))
    tags = pos_tag(tokens)
    # print(tags)
    for token,tag in tags:
        if token not in stopwords.words() or tag in tagsList:
            # print("Token:" + token)
            stem = ps.stem(token)
            # print("Lemma:" + lemma)
            stemDagCauseVerbs.append(stem)
        
for v, l in zip(dagCauseVerbs,stemDagCauseVerbs):
    print(v,l)
# Out:
# controlled control
# controlled control
# showed show
# showed show
# caused caus
# caused caus
# caused caus
# caused caus
# caused caus
# caused caus
# demanded demand
# demanded demand
# can restore restor
# must continue continu
# must continue continu
# will cause caus
# will cause caus
# must support support
# must support support
# leads lead
# must support support
# can transcend transcend
# can transcend transcend
# can cause caus
# can cause caus
# can cause caus
# can cause caus

# %% [markdown]
# ### [Pre-trained] Hugging face twitter-XLM-roBERTa-base

# %%
allen = []
for sent in stemDagCauseVerbs:
    encoded_input = tokenizer(str(sent), return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    if scores[0] > scores[1] and scores[0] > scores[2]:
        score = scores[0] * -1
        score = round(score,3)
        allen.append(score)
    elif scores[2] > scores[1] and scores[2] > scores[0]:
        scores[2] = round(scores[2],3)
        allen.append(scores[2])
    else:
        # allen.append(scores[1])
        allen.append(0)

for causalSentence, polarity  in zip(stemDagCauseVerbs, allen):
    print(causalSentence, polarity)
# Out:
# control 0
# control 0
# show 0
# show 0
# caus 0
# caus 0
# caus 0
# caus 0
# caus 0
# caus 0
# demand 0
# demand 0
# restor 0
# continu 0
# continu 0
# caus 0
# caus 0
# support 0
# support 0
# lead 0
# support 0
# transcend 0
# transcend 0
# caus 0
# caus 0
# caus 0
# caus 0

# %% [markdown]
# ### [Afinn]

# %%
afinn = []
for sent in stemDagCauseVerbs:
    #print(str(sent))
    score = afn.score(str(sent))
    # print(score)
    if score < -5:
        score = -5
    elif score > 5:
        score = 5
    score = score/5
    score = round(score,3)
    afinn.append(score)
    # if score > 0:
    #     #print('positive')
    #     afinn.append(1)
    # elif score < 0:
    #     #print('negative')
    #     afinn.append(-1)
    # else:
    #     #print('neutral')
    #     afinn.append(0)
        
for causalSentence, polarity  in zip(stemDagCauseVerbs, afinn):
    print(causalSentence, polarity)
# Out:
# control 0.0
# control 0.0
# show 0.0
# show 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# demand -0.2
# demand -0.2
# restor 0.0
# continu 0.0
# continu 0.0
# caus 0.0
# caus 0.0
# support 0.4
# support 0.4
# lead 0.0
# support 0.4
# transcend 0.0
# transcend 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0

# %% [markdown]
# ### [Vader]

# %%
vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

# def vader_analysis(compound):
#     if compound >= 0.05:
#         vader.append(1)
#         return 'Positive'
#     elif compound <= -0.05 :
#         vader.append(-1)
#         return 'Negative'
#     elif  compound > -0.05 and compound < 0.05:
#         vader.append(0)
#         return 'Neutral'
    
for sent in stemDagCauseVerbs:
    compound = vadersentimentanalysis(str(sent))
    compound = round(compound,3)
    vader.append(compound)
    
for causalSentence, polarity  in zip(stemDagCauseVerbs, vader):
    print(causalSentence, polarity)
# Out:
# control 0.0
# control 0.0
# show 0.0
# show 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# demand -0.128
# demand -0.128
# restor 0.0
# continu 0.0
# continu 0.0
# caus 0.0
# caus 0.0
# support 0.402
# support 0.402
# lead 0.0
# support 0.402
# transcend 0.0
# transcend 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0

# %% [markdown]
# ### [SentiStrength]

# %%
sentiStrength = []

for sent in stemDagCauseVerbs:
    result = senti.getSentiment(str(sent), score='scale')
    result = result[0]/4
    result = round(result,3)
    sentiStrength.append(result)
    # if result[0] > 0:
    #     sentiStrength.append(1)
    # elif result[0] < 0:
    #     sentiStrength.append(-1)
    # else:
    #     sentiStrength.append(0)
    
for causalSentence, polarity  in zip(stemDagCauseVerbs, sentiStrength):
    print(causalSentence, polarity)
# Out:
# control 0.0
# control 0.0
# show 0.0
# show 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# demand 0.0
# demand 0.0
# restor 0.0
# continu 0.0
# continu 0.0
# caus 0.0
# caus 0.0
# support 0.25
# support 0.25
# lead 0.0
# support 0.25
# transcend 0.0
# transcend 0.0
# caus 0.0
# caus 0.0
# caus 0.0
# caus 0.0

# %% [markdown]
# ### Data Frame (Stem Causal Verbs Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df_CVS = pd.DataFrame(list(zip(dagCauseVerbs, stemDagCauseVerbs, allen, afinn, vader,sentiStrength)), columns =['Causal Verb', 'Stem(Causal Verb)' ,'HuggingFace','Afinn','Vader','SentiStrength'])
# df2["Weight"] = round(df2.sum(axis=1)/4,3)

df_CVS["Weight"] = df_CVS.sum(axis=1)

for i in df_CVS.index:
    count = 0
#     print(df2["Afinn"][i])
    if df_CVS["HuggingFace"][i] != 0:
        count = count + 1
    if df_CVS["Afinn"][i] != 0:
        count = count + 1
    if df_CVS["Vader"][i] != 0:
        count = count + 1
    if df_CVS["SentiStrength"][i] != 0:
        count = count + 1
    if count == 0:
        count = 1
    df_CVS["Weight"][i] = round(df_CVS["Weight"][i]/count,3)

sentPolarity = []
StemVerbsWeight_tokLevel = []

for index, row in df_CVS.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    StemVerbsWeight_tokLevel.append(tripleWeightTuple)
    #print(weight)
    if weight >= -1 and weight < -0.6:
        sentPolarity.append('Strong Negative') 
    elif weight >= -0.6 and weight < -0.3:
        sentPolarity.append('Moderate Negative')
    elif weight >= -0.3 and weight < 0:
        sentPolarity.append('Weak Negative')
    elif weight == 0:
        sentPolarity.append('Neutral')
    elif weight <= 1 and weight > 0.6:
        sentPolarity.append('Strong Positive')
    elif weight <= 0.6 and weight > 0.3:
        sentPolarity.append('Moderate Positive')
    elif weight <= 0.3 and weight > 0:
        sentPolarity.append('Weak Positive')

df_CVS["Polarity"] = sentPolarity
df_CVS.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\sjsheikh\Anaconda3\envs\Second\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <style type="text/css">
# </style>
# <table id="T_dad0f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Verb</th>
#       <th class="col_heading level0 col1" >Stem(Causal Verb)</th>
#       <th class="col_heading level0 col2" >HuggingFace</th>
#       <th class="col_heading level0 col3" >Afinn</th>
#       <th class="col_heading level0 col4" >Vader</th>
#       <th class="col_heading level0 col5" >SentiStrength</th>
#       <th class="col_heading level0 col6" >Weight</th>
#       <th class="col_heading level0 col7" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dad0f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dad0f_row0_col0" class="data row0 col0" >controlled</td>
#       <td id="T_dad0f_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_dad0f_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_dad0f_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_dad0f_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_dad0f_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_dad0f_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_dad0f_row0_col7" class="data row0 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dad0f_row1_col0" class="data row1 col0" >controlled</td>
#       <td id="T_dad0f_row1_col1" class="data row1 col1" >control</td>
#       <td id="T_dad0f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_dad0f_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_dad0f_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_dad0f_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_dad0f_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_dad0f_row1_col7" class="data row1 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dad0f_row2_col0" class="data row2 col0" >showed</td>
#       <td id="T_dad0f_row2_col1" class="data row2 col1" >show</td>
#       <td id="T_dad0f_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_dad0f_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_dad0f_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_dad0f_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_dad0f_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_dad0f_row2_col7" class="data row2 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dad0f_row3_col0" class="data row3 col0" >showed</td>
#       <td id="T_dad0f_row3_col1" class="data row3 col1" >show</td>
#       <td id="T_dad0f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_dad0f_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_dad0f_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_dad0f_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_dad0f_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_dad0f_row3_col7" class="data row3 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dad0f_row4_col0" class="data row4 col0" >caused</td>
#       <td id="T_dad0f_row4_col1" class="data row4 col1" >caus</td>
#       <td id="T_dad0f_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_dad0f_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_dad0f_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_dad0f_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_dad0f_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_dad0f_row4_col7" class="data row4 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dad0f_row5_col0" class="data row5 col0" >caused</td>
#       <td id="T_dad0f_row5_col1" class="data row5 col1" >caus</td>
#       <td id="T_dad0f_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_dad0f_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_dad0f_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_dad0f_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_dad0f_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_dad0f_row5_col7" class="data row5 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dad0f_row6_col0" class="data row6 col0" >caused</td>
#       <td id="T_dad0f_row6_col1" class="data row6 col1" >caus</td>
#       <td id="T_dad0f_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_dad0f_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_dad0f_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_dad0f_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_dad0f_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_dad0f_row6_col7" class="data row6 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dad0f_row7_col0" class="data row7 col0" >caused</td>
#       <td id="T_dad0f_row7_col1" class="data row7 col1" >caus</td>
#       <td id="T_dad0f_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_dad0f_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_dad0f_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_dad0f_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_dad0f_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_dad0f_row7_col7" class="data row7 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dad0f_row8_col0" class="data row8 col0" >caused</td>
#       <td id="T_dad0f_row8_col1" class="data row8 col1" >caus</td>
#       <td id="T_dad0f_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_dad0f_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_dad0f_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_dad0f_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_dad0f_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_dad0f_row8_col7" class="data row8 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dad0f_row9_col0" class="data row9 col0" >caused</td>
#       <td id="T_dad0f_row9_col1" class="data row9 col1" >caus</td>
#       <td id="T_dad0f_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_dad0f_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_dad0f_row9_col4" class="data row9 col4" >0.000000</td>
#       <td id="T_dad0f_row9_col5" class="data row9 col5" >0.000000</td>
#       <td id="T_dad0f_row9_col6" class="data row9 col6" >0.000000</td>
#       <td id="T_dad0f_row9_col7" class="data row9 col7" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dad0f_row10_col0" class="data row10 col0" >demanded</td>
#       <td id="T_dad0f_row10_col1" class="data row10 col1" >demand</td>
#       <td id="T_dad0f_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_dad0f_row10_col3" class="data row10 col3" >-0.200000</td>
#       <td id="T_dad0f_row10_col4" class="data row10 col4" >-0.128000</td>
#       <td id="T_dad0f_row10_col5" class="data row10 col5" >0.000000</td>
#       <td id="T_dad0f_row10_col6" class="data row10 col6" >-0.164000</td>
#       <td id="T_dad0f_row10_col7" class="data row10 col7" >Weak Negative</td>
#     </tr>
#     <tr>
#       <th id="T_dad0f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dad0f_row11_col0" class="data row11 col0" >demanded</td>
#       <td id="T_dad0f_row11_col1" class="data row

# %% [markdown]
# # Overall Polarity of Sents and Triples by all Seven Methods

# %% [raw]
# ### Follow the following instructions (steps) before executing the cell given below
# #### Step1- Execute cell for setting causalSents to causalSentences (with duplicates).
# #### Step2- Execute cell for computing sentences' polarity at sentence level.
# #### Step3- Execute cell for computing sentences' polarity at token level.
# #### Step4- Execute the below cell.

# %%
totalWeight_AllMethods = []

limit= len(dagCauseSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+triplesWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]+triplesWeight_TokenLevel[i][j]+VerbsWeight_sentLevel[i][j]
        #print(res)
        res = round(res/7,2)
        sum_tup.append(res)
    totalWeight_AllMethods.append(sum_tup)
    
totalPlarity_AllMethods = DetectPolarity(totalWeight_AllMethods)

df_AllMethods = pd.DataFrame(list(zip(dagCauseSents, dagCauseTriples, dagCauseVerbs,lemmaDagCauseVerbs,stemDagCauseVerbs,sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel, VerbsWeight_sentLevel ,LemmaVerbsWeight_tokLevel,StemVerbsWeight_tokLevel,totalWeight_AllMethods,totalPlarity_AllMethods)), 
                             columns =['Causal Sentence', 'Causal Triple','Causal Verb', 'Lemma(Causal Verb)', 'Stem(Causal Verb)','Method1 (Sent_Whole)', 'Method2 (Trip_Whole)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)','Method5 (Verb_Whole)','Method6 (Lemma_Verb)','Method7 (Stem_Verb)','Total Weight','Overall Polarity'])

df_AllMethods.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac69a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Sentence</th>
#       <th class="col_heading level0 col1" >Causal Triple</th>
#       <th class="col_heading level0 col2" >Causal Verb</th>
#       <th class="col_heading level0 col3" >Lemma(Causal Verb)</th>
#       <th class="col_heading level0 col4" >Stem(Causal Verb)</th>
#       <th class="col_heading level0 col5" >Method1 (Sent_Whole)</th>
#       <th class="col_heading level0 col6" >Method2 (Trip_Whole)</th>
#       <th class="col_heading level0 col7" >Method3 (Sent_TokLevel)</th>
#       <th class="col_heading level0 col8" >Method4 (Trip_TokLevel)</th>
#       <th class="col_heading level0 col9" >Method5 (Verb_Whole)</th>
#       <th class="col_heading level0 col10" >Method6 (Lemma_Verb)</th>
#       <th class="col_heading level0 col11" >Method7 (Stem_Verb)</th>
#       <th class="col_heading level0 col12" >Total Weight</th>
#       <th class="col_heading level0 col13" >Overall Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac69a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac69a_row0_col0" class="data row0 col0" >afghanistan was controlled by central government.</td>
#       <td id="T_ac69a_row0_col1" class="data row0 col1" >(central government, controlled, afghanistan)</td>
#       <td id="T_ac69a_row0_col2" class="data row0 col2" >controlled</td>
#       <td id="T_ac69a_row0_col3" class="data row0 col3" >controlled</td>
#       <td id="T_ac69a_row0_col4" class="data row0 col4" >control</td>
#       <td id="T_ac69a_row0_col5" class="data row0 col5" >[-0.52]</td>
#       <td id="T_ac69a_row0_col6" class="data row0 col6" >[0.0]</td>
#       <td id="T_ac69a_row0_col7" class="data row0 col7" >[-0.448]</td>
#       <td id="T_ac69a_row0_col8" class="data row0 col8" >[-0.448]</td>
#       <td id="T_ac69a_row0_col9" class="data row0 col9" >[0.0]</td>
#       <td id="T_ac69a_row0_col10" class="data row0 col10" >[0.0]</td>
#       <td id="T_ac69a_row0_col11" class="data row0 col11" >[0.0]</td>
#       <td id="T_ac69a_row0_col12" class="data row0 col12" >[-0.2]</td>
#       <td id="T_ac69a_row0_col13" class="data row0 col13" >['Weak Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_ac69a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac69a_row1_col0" class="data row1 col0" >afghanistan was controlled by zahir shah.</td>
#       <td id="T_ac69a_row1_col1" class="data row1 col1" >(zahir shah, controlled, afghanistan)</td>
#       <td id="T_ac69a_row1_col2" class="data row1 col2" >controlled</td>
#       <td id="T_ac69a_row1_col3" class="data row1 col3" >controlled</td>
#       <td id="T_ac69a_row1_col4" class="data row1 col4" >control</td>
#       <td id="T_ac69a_row1_col5" class="data row1 col5" >[-0.452]</td>
#       <td id="T_ac69a_row1_col6" class="data row1 col6" >[0.0]</td>
#       <td id="T_ac69a_row1_col7" class="data row1 col7" >[-0.791]</td>
#       <td id="T_ac69a_row1_col8" class="data row1 col8" >[-0.448]</td>
#       <td id="T_ac69a_row1_col9" class="data row1 col9" >[0.0]</td>
#       <td id="T_ac69a_row1_col10" class="data row1 col10" >[0.0]</td>
#       <td id="T_ac69a_row1_col11" class="data row1 col11" >[0.0]</td>
#       <td id="T_ac69a_row1_col12" class="data row1 col12" >[-0.24]</td>
#       <td id="T_ac69a_row1_col13" class="data row1 col13" >['Weak Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_ac69a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac69a_row2_col0" class="data row2 col0" >afghanistan showed modernization and democracy.</td>
#       <td id="T_ac69a_row2_col1" class="data row2 col1" >(afghanistan, showed, modernization)</td>
#       <td id="T_ac69a_row2_col2" class="data row2 col2" >showed</td>
#       <td id="T_ac69a_row2_col3" class="data row2 col3" >showed</td>
#       <td id="T_ac69a_row2_col4" class="data row2 col4" >show</td>
#       <td id="T_ac69a_row2_col5" class="data row2 col5" >[0.498]</td>
#       <td id="T_ac69a_row2_col6" class="data row2 col6" >[0.0]</td>
#       <td id="T_ac69a_row2_col7" class="data row2 col7" >[-0.448]</td>
#       <td id="T_ac69a_row2_col8" class="data row2 col8" >[-0.448]</td>
#       <td id="T_ac69a_row2_col9" class="data row2 col9" >[0.0]</td>
#       <td id="T_ac69a_row2_col10" class="data row2 col10" >[0.0]</td>
#       <td id="T_ac69a_row2_col11" class="data row2 col11" >[0.0]</td>
#       <td id="T_ac69a_row2_col12" class="data row2 col12" >[-0.06]</td>
#       <td id="T_ac69a_row2_col13" class="data row2 col13" >['Weak Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_ac69a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac69a_row3_col0" class="data row3 col0" >afghanistan showed modernization and democracy.</td>
#       <td id="T_ac69a_row3_col1" class="data row3 col1" >(afghanistan, showed, democracy)</td>
#       <td id="T_ac69a_row3_col2" class="data row3 col2" >showed</td>
#       <td id="T_ac69a_row3_col3" class="data row3 col3" >showed</td>
#       <td id="T_ac69a_row3_col4" class="data row3 col4" >show</td>
#       <td id="T_ac69a_row3_col5" class="data row3 col5" >[0.498]</td>
#       <td id="T_ac69a_row3_col6" class="data row3 col6" >[0.0]</td>
#       <td id="T_ac69a_row3_col7" class="data row3 col7" >[-0.448]</td>
#       <td id="T_ac69a_row3_col8" class="data row3 col8" >[-0.448]</td>
#       <td id="T_ac69a_row3_col9" class="data row3 col9" >[0.0]</td>
#       <td id="T_ac69a_row3_col10" class="data row3 col10" >[0.0]</td>
#       <td id="T_ac69a_row3_col11" class="data row3 col11" >[0.0]</td>
#       <td id="T_ac69a_row3_col12" class="data row3 col12" >[-0.06]</td>
#       <td id="T_ac69a_row3_col13" class="data row3 col13" >['Weak Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_ac69a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac69a_row4_col0" class="data row4 col0" >soviet invasion caused tragic fragmentation and violence.</td>
#       <td id="T_ac69a_row4_col1" class="data row4 col1" >(soviet invasion, caused, tragic fragmentation)</td>
#       <td id="T_ac69a_row4_col2" class="data row4 col2" >caused</td>
#       <td id="T_ac69a_row4_col3" class="data row4 col3" >caused</td>
#       <td id="T_ac69a_row4_col4" class="data row4 col4" >caus</td>
#       <td id="T_ac69a_row4_col5" class="data row4 col5" >[-0.864]</td>
#       <td id="T_ac69a_row4_col6" class="data row4 col6" >[-0.621]</td>
#       <td id="T_ac69a_row4_col7" class="data row4 col7" >[-1]</td>
#       <td id="T_ac69a_row4_col8" class="data row4 col8" >[-1]</td>
#       <td id="T_ac69a_row4_col9" class="data row4 col9" >[0.0]</td>
#       <td id="T_ac69a_row4_col10" class="data row4 col10" >[0.0]</td>
#       <td id="T_ac69a_row4_col11" class="data row4 col11" >[0.0]</td>
#       <td id="T_ac69a_row4_col12" class="data row4 col12" >[-0.5]</td>
#       <td id="T_ac69a_row4_col13" class="data row4 col13" >['Moderate Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_ac69a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ac69a_row5_col0" class="data row5 col0" >soviet invasion caused tragic fragmentation and violence.</td>
#       <td id="T_ac69a_row5_col1" class="data row5 col1" >(soviet invasion, caused, violence)</td>
#       <td id="T_ac69a_row5_col2" class="data row5 col2" >caused</td>
#       <td id="T_ac69a_row5_col3" class="data row5 col3" >caused</td>
#       <td id="T_ac69a_row5_col4" class="data row5 col4" >caus</td>
#       <td id="T_ac69a_row5_col5" class="data row5 col5" >[-0.864]</td>
#       <td id="T_ac69a_row5_col6" class="data row5 col6" >[-0.748]</td>
#       <td id="T_ac69a_row5_col7" class="data row5 col7" >[-1]</td>
#       <td id="T_ac69a_row5_col8" class="data row5 col8" >[-1]</td>
#       <td id="T_ac69a_row5_col9" class="data row5 col9" >[0.0]</td>
#       <td id="T_ac69a_row5_col10" class="data row5 col10" >[0.0]</td>
#       <td id="T_ac69a_row5_col11" class="data row5 col11" >[0.0]</td>
#       <td id="T_ac69a_row5_col12" class="data row5 col12" >[-0.52]</td>
#       <td id="T_ac69a_row5_col13" class="data row5 col13"

# %% [markdown]
# # Make Causal Graph Fully Connected (Change value of 'ce' tuple)

# %% [raw]
# ce = ("nuclear program","developed","nuclear bomb")
# cg.add_edge(ce[0], ce[2], predicade=ce[1])
# dagCauseTriples.append(ce)
# if nx.is_directed_acyclic_graph(cg) is False:
#     cg.remove_edge(ce[0], ce[2])
#     dagCauseTriples.remove(ce)
# else:
#     print("Nodes:",len(cg.nodes))
#     print("Edges:",len(cg.edges))
#     for e in cg.edges(data=True):
#         print(e[0],",",e[2],",",e[1])
#
#     pos = nx.spring_layout(cg, k=4, iterations=20)
#     plt.figure(figsize=(15,12))
#
#     nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
#     edge_labels = nx.get_edge_attributes(cg,'predicade')
#     nx.draw_networkx_edge_labels(cg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)
#
#     plt.axis('off')
#     plt.show()

# %% [markdown]
# # Get weights and polarities from selected method(s) for CPT computation

# %% [raw]
# # weights = df_CSW["Weight"].tolist()
# # polarities = df_CSW["Polarity"].tolist()
#
# # weights = df_CST["Weight"].tolist()
# # polarities = df_CST["Polarity"].tolist()
#
# # weights = df_CTW["Weight"].tolist()
# # polarities = df_CTW["Polarity"].tolist()
#
# # weights = df_CTT["Weight"].tolist()
# # polarities = df_CTT["Polarity"].tolist()
#
# # weights = df_CVW["Weight"].tolist()
# # polarities = df_CVW["Polarity"].tolist()
#
# # weights = df_CVL["Weight"].tolist()
# # polarities = df_CVL["Polarity"].tolist()
#
# # weights = df_CVS["Weight"].tolist()
# # polarities = df_CVS["Polarity"].tolist()
#
# print(weights)
# print(polarities)
# bench_check = False

# %% [markdown]
# # Combine methods to get weights and polarities for CPT computation

# %%
def GetPolarity(weight):
    if weight >= -1 and weight < -0.6:
        return 'Strong Negative' 
    elif weight >= -0.6 and weight < -0.3:
        return 'Moderate Negative'
    elif weight >= -0.3 and weight < 0:
        return 'Weak Negative'
    elif weight == 0:
        return 'Neutral'
    elif weight <= 1 and weight > 0.6:
        return 'Strong Positive'
    elif weight <= 0.6 and weight > 0.3:
        return 'Moderate Positive'
    elif weight <= 0.3 and weight > 0:
        return 'Weak Positive'

# %%
# Combining CTW and CVW Methods
bench_check = False
weights = (round(((df_CTW["Weight"] + df_CVW["Weight"]) / 2), 3)).tolist()
polarities = []
for weight in weights:
    polarities.append(GetPolarity(weight))
print(weights)
print(polarities)
# Out:
# [0.0, 0.0, 0.0, 0.0, -0.31, -0.374, -0.375, -0.424, -0.284, -0.345, -0.432, -0.489, 0.442, 0.206, 0.206, 0.238, 0.226, 0.368, 0.36, -0.296, 0.36, -0.204, -0.204, 0.0, 0.0, 0.0, 0.0]
# ['Neutral', 'Neutral', 'Neutral', 'Neutral', 'Moderate Negative', 'Moderate Negative', 'Moderate Negative', 'Moderate Negative', 'Weak Negative', 'Moderate Negative', 'Moderate Negative', 'Moderate Negative', 'Moderate Positive', 'Weak Positive', 'Weak Positive', 'Weak Positive', 'Weak Positive', 'Moderate Positive', 'Moderate Positive', 'Weak Negative', 'Moderate Positive', 'Weak Negative', 'Weak Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral']

# %% [markdown]
# # Benchmark weights from Domain Expert

# %% [raw]
# dagCauseTriples

# %% [raw]
# weights = [0.67, 0.9, 0.9, 0.9, 0.67, 0.99, 0.9, 0.67, 0.9, 0.67, 0.67, 0.67, 0.67] #for Pakistan's Nuclear Pride
#
# bench_check = True
# polarities = []
# for weight in weights:
#     polarities.append(GetPolarity(weight))
# print(weights)
# print(polarities)

# %% [markdown]
# # Plot the Polarized/Weighted Causal Graph.

# %%
dagCauseWeights = []
cwg = nx.DiGraph()

for ce,w in zip(dagCauseTriples, weights):
    s = str(ce[0])    
    d = str(ce[2])
#     w = GetCAstLogicStrength(p[0])
    cwg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    cwg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cwg.add_edge(s, d, predicate=w)
    
print("Nodes:",len(cwg.nodes))
print("Edges:",len(cwg.edges))

for e in cwg.edges(data=True):
    print(e[0],",",e[2],",",e[1])
    

pos = nx.spring_layout(cwg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cwg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cwg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cwg,'predicate')
#edge_labels2 = nx.get_edge_attributes(cwg,'polarity')
#edge_labels3 = nx.get_edge_attributes(cwg,'weight')

nx.draw_networkx_edge_labels(cwg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 18
# Edges: 27
# central government , {'predicate': 0.0} , afghanistan
# central government , {'predicate': -0.204} , chaos
# central government , {'predicate': 0.0} , afghanistan's transformation
# central government , {'predicate': 0.0} , afghanistan's unification
# afghanistan , {'predicate': 0.0} , modernization
# afghanistan , {'predicate': 0.0} , democracy
# zahir shah , {'predicate': 0.0} , afghanistan
# soviet invasion , {'predicate': -0.31} , tragic fragmentation
# soviet invasion , {'predicate': -0.374} , violence
# tragic fragmentation , {'predicate': -0.432} , afghanistan's unification
# violence , {'predicate': -0.489} , afghanistan's unification
# civil war , {'predicate': -0.375} , tragic fragmentation
# civil war , {'predicate': -0.424} , violence
# civil war , {'predicate': -0.296} , state's disintegration
# taliban , {'predicate': -0.284} , tragic fragmentation
# taliban , {'predicate': -0.345} , violence
# afghanistan's unification , {'predicate': 0.442} , peace
# afghans , {'predicate': 0.206} , afghanistan's transformation
# afghans , {'predicate': 0.206} , afghanistan's unification
# afghans , {'predicate': 0.368} , zahir shah
# afghans , {'predicate': 0.36} , national institutions
# afghans , {'predicate': 0.36} , central government
# afghanistan's transformation , {'predicate': 0.238} , peace
# afghanistan's transformation , {'predicate': 0.226} , prosperity
# national institutions , {'predicate': -0.204} , chaos
# national institutions , {'predicate': 0.0} , afghanistan's transformation
# national institutions , {'predicate': 0.0} , afghanistan's unification

# %% [markdown]
# # Plot the Polarized Causal Graph on using Pyvis "Polarized Causal Graph.html" file

# %%
nt = Network("660px", "1515px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Polarized Causal Graph')

for dm,w in zip(dagCauseTriples, weights):
    nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_node(str(dm[2]),shape = 'box',physics='false',color = "#ffffff")
    p = GetPolarity(w)
    nt.add_edge(str(dm[0]),str(dm[2]),label=str(dm[1]) + " ("+str(p)+" "+str(w)+")", weight=10, physics='false',color='black')
    #nt.add_edge(str(dm[0]),str(dm[2]),label="h = "+str(w), weight=10, physics='false',color='black') #only add h vaules on edges

#nt.show_buttons(filter_=['physics'])
nt.set_edge_smooth('discrete')
nt.show("./Pyvis Graph/Polarized Causal Graph.html")
# Out:
#         <iframe
#             width="1515px"
#             height="660px"
#             src="./Pyvis Graph/Polarized Causal Graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Compute CPs using CAST Logic

# %%
def FromTruthTable(i,inputs):
    count = 0

    if inputs==1:
        for a in range(1, -1, -1):
            if i == count:
                return (a)
            count = count+1

    if inputs==2:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                if i == count:
                    t = (a,b)
                    return t
                count = count+1
        
    elif inputs==3:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    if i == count:
                        t = (a,b,c)
                        return t
                    count = count+1
    
    elif inputs==4:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    for d in range(1, -1, -1):
                        if i == count:
                            t = (a,b,c,d)
                            return t
                        count = count+1

    elif inputs==5:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    for d in range(1, -1, -1):
                        for e in range(1,-1,-1):
                            if i == count:
                                t = (a,b,c,d,e)
                                return t
                            count = count+1
                            
    elif inputs==6:
        for a in range(1, -1, -1):
            for b in range(1, -1, -1):
                for c in range(1, -1, -1):
                    for d in range(1, -1, -1):
                        for e in range(1,-1,-1):
                            for f in range(1,-1,-1):
                                if i == count:
                                    t = (a,b,c,d,e,f)
                                    return t
                                count = count+1

class Tutorial1:
    #def __init__(self):
    def Add(self, net, id ,name, outcomes, x_pos, y_pos):
        e = self.create_cpt_node(net, id, name, outcomes, x_pos, y_pos)
        nodeNames.append(net.get_node_name(e))
        nodeIds.append(net.get_node_id(e))
        nodeHandles.append(e)
        net.write_file("./GeNie CBN/CBN.xdsl")
        
    def AddArcs(self, net, s, d):
        net.add_arc(s, d)
        net.write_file("./GeNie CBN/CBN.xdsl")

    def Addcpts(self, net, h, cpt):
        net. set_node_definition(h, cpt)
        net.write_file("./GeNie CBN/CBN.xdsl")
        
    def create_cpt_node(self, net, id, name, outcomes, x_pos, y_pos):
        handle = net.add_node(pysmile.NodeType.CPT, id)
        net.set_node_name(handle, name)
        net.set_node_position(handle, x_pos, y_pos, 85, 55)
        initial_outcome_count = net.get_outcome_count(handle)
        for i in range(0, initial_outcome_count):
            net.set_outcome_id(handle, i, outcomes[i])
        for i in range(initial_outcome_count, len(outcomes)):
            net.add_outcome(handle, outcomes[i])
        return handle
    
    def print_cpt_matrix(self, net, node_handle):
        cpt = net.get_node_definition(node_handle)
        return cpt
    

net = pysmile.Network()
obj = Tutorial1()
outcomes = ["True","False"]
nodeNames = []    
nodeIds = []
nodeHandles = []
# cpts=[]
PDs = []
baseline = 0.1
x = 160
y = 40

for node in cwg.nodes: 
    obj.Add(net, str(node),str(node), outcomes, x, y)
        
for e in cwg.edges():
    for id,name in zip(nodeIds,nodeNames):
        if name == e[0]:
            s = id
        if name == e[1]:
            d = id 
    obj.AddArcs(net, s, d)
    
for handle,name in zip(nodeHandles,nodeNames): 
    print("Handle:" + str(handle))
    print("Node:" + name)
    print(net.get_outcome_ids(handle))
    parent_ids = net.get_parent_ids(handle)
    num_parents = len(parent_ids)
    print("Number of Parents:" + str(num_parents))
    cpt = []
    parent_names = []
    totalCols = 1
    if num_parents == 0:
        cpt.append(baseline)
        cpt.append(1 - baseline)
        print("CPT:" + str(cpt))
        obj.Addcpts(net, handle, cpt)
        print("CPT from Network:")
        print(obj.print_cpt_matrix(net, handle))
        print("********************************************************************")
    elif num_parents > 0:
        for par in parent_ids:
                parent_names.append(net.get_node_name(par))
                totalCols = 2 ** num_parents
        print("Names of Parents:" + str(parent_names))
        print("totalCols:" + str(totalCols))
        for j in range(0, totalCols):
            print("j: "+str(j))
            PI = 1
            NI = 1
            ans = FromTruthTable(j,num_parents)
            print("From Dummy: "+str(ans))
            #for parent in parent_names:
            for p in range(0,len(parent_names)):
                for edge in cwg.edges(data=True):
                    if str(parent_names[p]) == str(edge[0]) and str(name) == str(edge[1]):
                        for nbr, eattr in edge[2].items():
                            if nbr == "predicate":
                                polarity = eattr
                        break
                print("Parent: " + parent_names[p])
                print("Polarity: " + str(polarity))
                print("p: "+str(p))
                if num_parents > 1:
                    if ans[p] == 0:
                        polarity = 0
                        print("New Polarity: " + str(polarity))
                else:
                    if ans == 0:
                        polarity = 0
                        print("New Polarity: " + str(polarity))
                if polarity >= 0:
                    #polarity = polarity/4
                    PI = PI * (1 - polarity)
                else:
                    #polarity = polarity/ (-4)
                    NI = NI * (1 - abs(polarity))
            PI = 1 - PI
            NI = 1 - NI
            AI = abs(PI - NI) / (1 - min(PI, NI))  
            CP = 0
            if PI > NI:
                CP = baseline + ((1 - baseline) * AI)
            elif PI < NI:
                CP = baseline - (baseline * AI)
            elif PI == NI:
                CP = baseline
            if CP == 0:
                CP = 0.01
            cpt.append(round(CP, 3))
            cpt.append(round((1 - CP), 3))
            pds = []
            pds.append(round(CP, 3))
            pds.append(round((1 - CP), 3))
            PDs.append(pds)
        print("CPT:" + str(cpt))
        obj.Addcpts(net, handle, cpt)
        print("CPT from Network:")
        print(obj.print_cpt_matrix(net, handle))
        print("********************************************************************")
# Out:
# Handle:0
# Node:central government
# ['True', 'False']
# Number of Parents:1
# Names of Parents:['afghans']
# totalCols:2
# j: 0
# From Dummy: 1
# Parent: afghans
# Polarity: 0.36
# p: 0
# j: 1
# From Dummy: 0
# Parent: afghans
# Polarity: 0.36
# p: 0
# New Polarity: 0
# CPT:[0.424, 0.576, 0.1, 0.9]
# CPT from Network:
# [0.424, 0.576, 0.1, 0.9]
# ********************************************************************
# Handle:1
# Node:afghanistan
# ['True', 'False']
# Number of Parents:2
# Names of Parents:['central government', 'zahir shah']
# totalCols:4
# j: 0
# From Dummy: (1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: zahir shah
# Polarity: 0.0
# p: 1
# j: 1
# From Dummy: (1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: zahir shah
# Polarity: 0.0
# p: 1
# New Polarity: 0
# j: 2
# From Dummy: (0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: zahir shah
# Polarity: 0.0
# p: 1
# j: 3
# From Dummy: (0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: zahir shah
# Polarity: 0.0
# p: 1
# New Polarity: 0
# CPT:[0.1, 0.9, 0.1, 0.9, 0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9, 0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:2
# Node:zahir shah
# ['True', 'False']
# Number of Parents:1
# Names of Parents:['afghans']
# totalCols:2
# j: 0
# From Dummy: 1
# Parent: afghans
# Polarity: 0.368
# p: 0
# j: 1
# From Dummy: 0
# Parent: afghans
# Polarity: 0.368
# p: 0
# New Polarity: 0
# CPT:[0.431, 0.569, 0.1, 0.9]
# CPT from Network:
# [0.431, 0.569, 0.1, 0.9]
# ********************************************************************
# Handle:3
# Node:modernization
# ['True', 'False']
# Number of Parents:1
# Names of Parents:['afghanistan']
# totalCols:2
# j: 0
# From Dummy: 1
# Parent: afghanistan
# Polarity: 0.0
# p: 0
# j: 1
# From Dummy: 0
# Parent: afghanistan
# Polarity: 0.0
# p: 0
# New Polarity: 0
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:4
# Node:democracy
# ['True', 'False']
# Number of Parents:1
# Names of Parents:['afghanistan']
# totalCols:2
# j: 0
# From Dummy: 1
# Parent: afghanistan
# Polarity: 0.0
# p: 0
# j: 1
# From Dummy: 0
# Parent: afghanistan
# Polarity: 0.0
# p: 0
# New Polarity: 0
# CPT:[0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:5
# Node:soviet invasion
# ['True', 'False']
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:6
# Node:tragic fragmentation
# ['True', 'False']
# Number of Parents:3
# Names of Parents:['soviet invasion', 'civil war', 'taliban']
# totalCols:8
# j: 0
# From Dummy: (1, 1, 1)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# Parent: taliban
# Polarity: -0.284
# p: 2
# j: 1
# From Dummy: (1, 1, 0)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# Parent: taliban
# Polarity: -0.284
# p: 2
# New Polarity: 0
# j: 2
# From Dummy: (1, 0, 1)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.284
# p: 2
# j: 3
# From Dummy: (1, 0, 0)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.284
# p: 2
# New Polarity: 0
# j: 4
# From Dummy: (0, 1, 1)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# Parent: taliban
# Polarity: -0.284
# p: 2
# j: 5
# From Dummy: (0, 1, 0)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# Parent: taliban
# Polarity: -0.284
# p: 2
# New Polarity: 0
# j: 6
# From Dummy: (0, 0, 1)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.284
# p: 2
# j: 7
# From Dummy: (0, 0, 0)
# Parent: soviet invasion
# Polarity: -0.31
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.375
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.284
# p: 2
# New Polarity: 0
# CPT:[0.031, 0.969, 0.043, 0.957, 0.049, 0.951, 0.069, 0.931, 0.045, 0.955, 0.062, 0.938, 0.072, 0.928, 0.1, 0.9]
# CPT from Network:
# [0.031, 0.969, 0.043, 0.957, 0.049, 0.951, 0.069, 0.931, 0.045, 0.955, 0.062, 0.938, 0.072, 0.928, 0.1, 0.9]
# ********************************************************************
# Handle:7
# Node:violence
# ['True', 'False']
# Number of Parents:3
# Names of Parents:['soviet invasion', 'civil war', 'taliban']
# totalCols:8
# j: 0
# From Dummy: (1, 1, 1)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# Parent: taliban
# Polarity: -0.345
# p: 2
# j: 1
# From Dummy: (1, 1, 0)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# Parent: taliban
# Polarity: -0.345
# p: 2
# New Polarity: 0
# j: 2
# From Dummy: (1, 0, 1)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.345
# p: 2
# j: 3
# From Dummy: (1, 0, 0)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.345
# p: 2
# New Polarity: 0
# j: 4
# From Dummy: (0, 1, 1)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# Parent: taliban
# Polarity: -0.345
# p: 2
# j: 5
# From Dummy: (0, 1, 0)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# Parent: taliban
# Polarity: -0.345
# p: 2
# New Polarity: 0
# j: 6
# From Dummy: (0, 0, 1)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.345
# p: 2
# j: 7
# From Dummy: (0, 0, 0)
# Parent: soviet invasion
# Polarity: -0.374
# p: 0
# New Polarity: 0
# Parent: civil war
# Polarity: -0.424
# p: 1
# New Polarity: 0
# Parent: taliban
# Polarity: -0.345
# p: 2
# New Polarity: 0
# CPT:[0.024, 0.976, 0.036, 0.964, 0.041, 0.959, 0.063, 0.937, 0.038, 0.962, 0.058, 0.942, 0.066, 0.934, 0.1, 0.9]
# CPT from Network:
# [0.024, 0.976, 0.036, 0.964, 0.041, 0.959, 0.063, 0.937, 0.038, 0.962, 0.058, 0.942, 0.066, 0.934, 0.1, 0.9]
# ********************************************************************
# Handle:8
# Node:civil war
# ['True', 'False']
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:9
# Node:taliban
# ['True', 'False']
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:10
# Node:afghanistan's unification
# ['True', 'False']
# Number of Parents:5
# Names of Parents:['central government', 'tragic fragmentation', 'violence', 'afghans', 'national institutions']
# totalCols:32
# j: 0
# From Dummy: (1, 1, 1, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 1
# From Dummy: (1, 1, 1, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 2
# From Dummy: (1, 1, 1, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 3
# From Dummy: (1, 1, 1, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 4
# From Dummy: (1, 1, 0, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 5
# From Dummy: (1, 1, 0, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 6
# From Dummy: (1, 1, 0, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 7
# From Dummy: (1, 1, 0, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 8
# From Dummy: (1, 0, 1, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 9
# From Dummy: (1, 0, 1, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 10
# From Dummy: (1, 0, 1, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 11
# From Dummy: (1, 0, 1, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 12
# From Dummy: (1, 0, 0, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 13
# From Dummy: (1, 0, 0, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 14
# From Dummy: (1, 0, 0, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 15
# From Dummy: (1, 0, 0, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 16
# From Dummy: (0, 1, 1, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 17
# From Dummy: (0, 1, 1, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 18
# From Dummy: (0, 1, 1, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 19
# From Dummy: (0, 1, 1, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 20
# From Dummy: (0, 1, 0, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 21
# From Dummy: (0, 1, 0, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 22
# From Dummy: (0, 1, 0, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 23
# From Dummy: (0, 1, 0, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 24
# From Dummy: (0, 0, 1, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 25
# From Dummy: (0, 0, 1, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 26
# From Dummy: (0, 0, 1, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 27
# From Dummy: (0, 0, 1, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 28
# From Dummy: (0, 0, 0, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 29
# From Dummy: (0, 0, 0, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# j: 30
# From Dummy: (0, 0, 0, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# j: 31
# From Dummy: (0, 0, 0, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: tragic fragmentation
# Polarity: -0.432
# p: 1
# New Polarity: 0
# Parent: violence
# Polarity: -0.489
# p: 2
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 3
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 4
# New Polarity: 0
# CPT:[0.037, 0.963, 0.037, 0.963, 0.029, 0.971, 0.029, 0.971, 0.072, 0.928, 0.072, 0.928, 0.057, 0.943, 0.057, 0.943, 0.064, 0.936, 0.064, 0.936, 0.051, 0.949, 0.051, 0.949, 0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9, 0.037, 0.963, 0.037, 0.963, 0.029, 0.971, 0.029, 0.971, 0.072, 0.928, 0.072, 0.928, 0.057, 0.943, 0.057, 0.943, 0.064, 0.936, 0.064, 0.936, 0.051, 0.949, 0.051, 0.949, 0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.037, 0.963, 0.037, 0.963, 0.029, 0.971, 0.029, 0.971, 0.072, 0.928, 0.072, 0.928, 0.057, 0.943, 0.057, 0.943, 0.064, 0.936, 0.064, 0.936, 0.051, 0.949, 0.051, 0.949, 0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9, 0.037, 0.963, 0.037, 0.963, 0.029, 0.971, 0.029, 0.971, 0.072, 0.928, 0.072, 0.928, 0.057, 0.943, 0.057, 0.943, 0.064, 0.936, 0.064, 0.936, 0.051, 0.949, 0.051, 0.949, 0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:11
# Node:peace
# ['True', 'False']
# Number of Parents:2
# Names of Parents:["afghanistan's unification", "afghanistan's transformation"]
# totalCols:4
# j: 0
# From Dummy: (1, 1)
# Parent: afghanistan's unification
# Polarity: 0.442
# p: 0
# Parent: afghanistan's transformation
# Polarity: 0.238
# p: 1
# j: 1
# From Dummy: (1, 0)
# Parent: afghanistan's unification
# Polarity: 0.442
# p: 0
# Parent: afghanistan's transformation
# Polarity: 0.238
# p: 1
# New Polarity: 0
# j: 2
# From Dummy: (0, 1)
# Parent: afghanistan's unification
# Polarity: 0.442
# p: 0
# New Polarity: 0
# Parent: afghanistan's transformation
# Polarity: 0.238
# p: 1
# j: 3
# From Dummy: (0, 0)
# Parent: afghanistan's unification
# Polarity: 0.442
# p: 0
# New Polarity: 0
# Parent: afghanistan's transformation
# Polarity: 0.238
# p: 1
# New Polarity: 0
# CPT:[0.617, 0.383, 0.498, 0.502, 0.314, 0.686, 0.1, 0.9]
# CPT from Network:
# [0.617, 0.383, 0.498, 0.502, 0.314, 0.686, 0.1, 0.9]
# ********************************************************************
# Handle:12
# Node:afghans
# ['True', 'False']
# Number of Parents:0
# CPT:[0.1, 0.9]
# CPT from Network:
# [0.1, 0.9]
# ********************************************************************
# Handle:13
# Node:afghanistan's transformation
# ['True', 'False']
# Number of Parents:3
# Names of Parents:['central government', 'afghans', 'national institutions']
# totalCols:8
# j: 0
# From Dummy: (1, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# Parent: national institutions
# Polarity: 0.0
# p: 2
# j: 1
# From Dummy: (1, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# Parent: national institutions
# Polarity: 0.0
# p: 2
# New Polarity: 0
# j: 2
# From Dummy: (1, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 2
# j: 3
# From Dummy: (1, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 2
# New Polarity: 0
# j: 4
# From Dummy: (0, 1, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# Parent: national institutions
# Polarity: 0.0
# p: 2
# j: 5
# From Dummy: (0, 1, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# Parent: national institutions
# Polarity: 0.0
# p: 2
# New Polarity: 0
# j: 6
# From Dummy: (0, 0, 1)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 2
# j: 7
# From Dummy: (0, 0, 0)
# Parent: central government
# Polarity: 0.0
# p: 0
# New Polarity: 0
# Parent: afghans
# Polarity: 0.206
# p: 1
# New Polarity: 0
# Parent: national institutions
# Polarity: 0.0
# p: 2
# New Polarity: 0
# CPT:[0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9, 0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9]
# CPT from Network:
# [0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9, 0.285, 0.715, 0.285, 0.715, 0.1, 0.9, 0.1, 0.9]
# ********************************************************************
# Handle:14
# Node:prosperity
# ['True', 'False']
# Number of Parents:1
# Names of Parents:["afghanistan's transformation"]
# totalCols:2
# j: 0
# From Dummy: 1
# Parent: afghanistan's transformation
# Polarity: 0.226
# p: 0
# j: 1
# From Dummy: 0
# Parent: afghanistan's transformation
# Polarity: 0.226
# p: 0
# New Polarity: 0
# CPT:[0.303, 0.697, 0.1, 0.9]
# CPT from Network:
# [0.303, 0.697, 0.1, 0.9]
# ********************************************************************
# Handle:15
# Node:national institutions
# ['True', 'False']
# Number of Parents:1
# Names of Parents:['afghans']
# totalCols:2
# j: 0
# From Dummy: 1
# Parent: afghans
# Polarity: 0.36
# p: 0
# j: 1
# From Dummy: 0
# Parent: afghans
# Polarity: 0.36
# p: 0
# New Polarity: 0
# CPT:[0.424, 0.576, 0.1, 0.9]
# CPT from Network:
# [0.424, 0.576, 0.1, 0.9]
# ********************************************************************
# Handle:16
# Node:state's disintegration
# ['True', 'False']
# Number of Parents:1
# Names of Parents:['civil war']
# totalCols:2
# j: 0
# From Dummy: 1
# Parent: civil war
# Polarity: -0.296
# p: 0
# j: 1
# From Dummy: 0
# Parent: civil war
# Polarity: -0.296
# p: 0
# New Polarity: 0
# CPT:[0.07, 0.93, 0.1, 0.9]
# CPT from Network:
# [0.07, 0.93, 0.1, 0.9]
# ********************************************************************
# Handle:17
# Node:chaos
# ['True', 'False']
# Number of Parents:2
# Names of Parents:['central government', 'national institutions']
# totalCols:4
# j: 0
# From Dummy: (1, 1)
# Parent: central government
# Polarity: -0.204
# p: 0
# Parent: national institutions
# Polarity: -0.204
# p: 1
# j: 1
# From Dummy: (1, 0)
# Parent: central government
# Polarity: -0.204
# p: 0
# Parent: national institutions
# Polarity: -0.204
# p: 1
# New Polarity: 0
# j: 2
# From Dummy: (0, 1)
# Parent: central government
# Polarity: -0.204
# p: 0
# New Polarity: 0
# Parent: national institutions
# Polarity: -0.204
# p: 1
# j: 3
# From Dummy: (0, 0)
# Parent: central government
# Polarity: -0.204
# p: 0
# New Polarity: 0
# Parent: national institutions
# Polarity: -0.204
# p: 1
# New Polarity: 0
# CPT:[0.063, 0.937, 0.08, 0.92, 0.08, 0.92, 0.1, 0.9]
# CPT from Network:
# [0.063, 0.937, 0.08, 0.92, 0.08, 0.92, 0.1, 0.9]
# ********************************************************************

# %% [markdown]
# # Set PDs for KL-Divergence

# %%
print(bench_check)
print()

if bench_check == False:
    P = PDs #Actual
    Q = None
else:
    Q = PDs #Expected
    
print(P)
print()
print(Q)
# Out:
# False
#
# [[0.424, 0.576], [0.1, 0.9], [0.1, 0.9], [0.1, 0.9], [0.1, 0.9], [0.1, 0.9], [0.431, 0.569], [0.1, 0.9], [0.1, 0.9], [0.1, 0.9], [0.1, 0.9], [0.1, 0.9], [0.031, 0.969], [0.043, 0.957], [0.049, 0.951], [0.069, 0.931], [0.045, 0.955], [0.062, 0.938], [0.072, 0.928], [0.1, 0.9], [0.024, 0.976], [0.036, 0.964], [0.041, 0.959], [0.063, 0.937], [0.038, 0.962], [0.058, 0.942], [0.066, 0.934], [0.1, 0.9], [0.037, 0.963], [0.037, 0.963], [0.029, 0.971], [0.029, 0.971], [0.072, 0.928], [0.072, 0.928], [0.057, 0.943], [0.057, 0.943], [0.064, 0.936], [0.064, 0.936], [0.051, 0.949], [0.051, 0.949], [0.285, 0.715], [0.285, 0.715], [0.1, 0.9], [0.1, 0.9], [0.037, 0.963], [0.037, 0.963], [0.029, 0.971], [0.029, 0.971], [0.072, 0.928], [0.072, 0.928], [0.057, 0.943], [0.057, 0.943], [0.064, 0.936], [0.064, 0.936], [0.051, 0.949], [0.051, 0.949], [0.285, 0.715], [0.285, 0.715], [0.1, 0.9], [0.1, 0.9], [0.617, 0.383], [0.498, 0.502], [0.314, 0.686], [0.1, 0.9], [0.285, 0.715], [0.285, 0.715], [0.1, 0.9], [0.1, 0.9], [0.285, 0.715], [0.285, 0.715], [0.1, 0.9], [0.1, 0.9], [0.303, 0.697], [0.1, 0.9], [0.424, 0.576], [0.1, 0.9], [0.07, 0.93], [0.1, 0.9], [0.063, 0.937], [0.08, 0.92], [0.08, 0.92], [0.1, 0.9]]
#
# None

# %% [markdown]
# # Compute KL Divergence

# %% [markdown]
# ### Execute from cell 'Benchmark weights from Domain Expert' to above cell then execute the below cell

# %% [raw]
# # https://www.pythonclear.com/data-science/python-kl-divergence/
# # https://www.statology.org/kl-divergence-python/
#
# # PR Unit 16
# # If two distributions perfectly match, D_{KL} (p||q) = 0 otherwise it can take values between 0 and ∞.
# # Lower the KL divergence value, the better we have matched the true distribution with our approximation.
#
# kl = []
# for i in range(0,len(P)):
#     k = kl_div(P[i],Q[i])
#     kl.append(k.sum())
#
# kl = np.array(kl)
# kl_divergence = round((kl.sum()),3)
# print(kl_divergence)

# %% [markdown]
# # Overall Polarity of Triples at two (sentence and token) levels

# %% [raw]
# totalTriplesWeight_AllLevels = []
#
# limit= len(dagCauseTriples)
#
# for i in range(0,limit):
#     #dataframe_WordLevel(i)
#     #print(len(allen_word[i]))
#     sum_tup = []
#     for j in range(0,len(triplesWeight_sentLevel[i])):
#         res = triplesWeight_sentLevel[i][j]+triplesWeight_TokenLevel[i][j]
#         #print(res)
#         res = round(res/2,2)
#         sum_tup.append(res)
#     totalTriplesWeight_AllLevels.append(sum_tup)
#
# totalTripsPlarity_AllLevels = DetectPolarity(totalTriplesWeight_AllLevels)
#
# df_TripAllLevels = pd.DataFrame(list(zip(dagCauseTriples, triplesWeight_sentLevel, triplesWeight_TokenLevel, totalTriplesWeight_AllLevels, totalTripsPlarity_AllLevels)),
#                              columns =['Causal Triple', 'Weight (Trip_SentLevel)','Weight (Trip_TokLevel)','Total Weight (All Levels)','Overall Polarity'])
#
# df_TripAllLevels.style

# %% [markdown]
# # Overall Polarity of Sentences at two (sentence and token) Levels

# %% [raw]
# totalSentsWeight_AllLevels = []
#
# limit= len(dagCauseSents)
#
# for i in range(0,limit):
#     #dataframe_WordLevel(i)
#     #print(len(allen_word[i]))
#     sum_tup = []
#     for j in range(0,len(sentsWeight_sentLevel[i])):
#         res = sentsWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]
#         #print(res)
#         res = round(res/2,2)
#         sum_tup.append(res)
#     totalSentsWeight_AllLevels.append(sum_tup)
#
# totalSentsPolarity_AllLevels = DetectPolarity(totalSentsWeight_AllLevels)
#
# df_SentsAllLevels = pd.DataFrame(list(zip(dagCauseSents, sentsWeight_sentLevel, sentsWeight_TokenLevel, totalSentsWeight_AllLevels, totalSentsPolarity_AllLevels)),
#                              columns =['Causal Sentence', 'Weight (Sent_SentLevel)','Weight (Sent_TokLevel)','Total Weight (All Levels)','Overall Polarity'])
#
# df_SentsAllLevels.style

# %% [markdown]
# # Plot the Polarized/Modified Causal Graph.

# %% [raw]
# cg = nx.DiGraph()
#
# for ce in polarizedCauseffect:
#     s = str(ce[0])
#     d = str(ce[2])
#     cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
#     cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
#     cg.add_edge(s, d, predicade=str(ce[1]))
#
# print(len(cg.nodes))
# print(len(cg.edges))
#
# pos = nx.spring_layout(cg, k=4, iterations=20)
# plt.figure(figsize=(15,12))
#
# nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
# edge_labels = nx.get_edge_attributes(cg,'predicade')
# nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)
#
# plt.axis('off')
# plt.show()
