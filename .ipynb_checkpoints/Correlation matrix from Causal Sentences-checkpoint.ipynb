# %%
import spacy
import textacy
from nltk import sent_tokenize, word_tokenize, pos_tag

nlp = spacy.load("en_core_web_sm")

from allennlp_models.pretrained import load_predictor
predictor1 = load_predictor("roberta-sst")
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_core_web_sm' (2.2.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.7). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp\tango\__init__.py:18: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   "AllenNLP Tango is an experimental API and parts of it might change or disappear "
# 2023-01-30 09:27:35,057 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-01-30 09:27:35,070 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\coref-spanbert.json as plain json
# 2023-01-30 09:27:35,088 - INFO - allennlp.common.params - id = coref-spanbert
# 2023-01-30 09:27:35,088 - INFO - allennlp.common.params - type = coref-spanbert
# 2023-01-30 09:27:35,095 - INFO - allennlp.common.params - registered_model_name = coref
# 2023-01-30 09:27:35,095 - INFO - allennlp.common.params - type = coref
# 2023-01-30 09:27:35,095 - INFO - allennlp.common.params - model_class = None
# 2023-01-30 09:27:35,103 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-01-30 09:27:35,103 - INFO - allennlp.common.params - display_name = Coreference Resolution
# 2023-01-30 09:27:35,103 - INFO - allennlp.common.params - type = Coreference Resolution
# 2023-01-30 09:27:35,103 - INFO - allennlp.common.params - task_id = coref
# 2023-01-30 09:27:35,103 - INFO - allennlp.common.params - type = coref
# 2023-01-30 09:27:35,121 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,122 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,122 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,136 - INFO - allennlp.common.params - model_usage.archive_file = coref-spanbert-large-2021.03.10.tar.gz
# 2023-01-30 09:27:35,136 - INFO - allennlp.common.params - type = coref-spanbert-large-2021.03.10.tar.gz
# 2023-01-30 09:27:35,170 - INFO - allennlp.common.params - model_usage.training_config = coref/coref_spanbert_large.jsonnet
# 2023-01-30 09:27:35,170 - INFO - allennlp.common.params - type = coref/coref_spanbert_large.jsonnet
# 2023-01-30 09:27:35,185 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-01-30 09:27:35,186 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-01-30 09:27:35,186 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-01-30 09:27:35,203 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,207 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,210 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,216 - INFO - allennlp.common.params - model_details.description = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-01-30 09:27:35,220 - INFO - allennlp.common.params - type = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-01-30 09:27:35,232 - INFO - allennlp.common.params - model_details.short_description = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-01-30 09:27:35,236 - INFO - allennlp.common.params - type = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-01-30 09:27:35,244 - INFO - allennlp.common.params - model_details.developed_by = Lee et al
# 2023-01-30 09:27:35,249 - INFO - allennlp.common.params - type = Lee et al
# 2023-01-30 09:27:35,251 - INFO - allennlp.common.params - model_details.contributed_by = Zhaofeng Wu
# 2023-01-30 09:27:35,253 - INFO - allennlp.common.params - type = Zhaofeng Wu
# 2023-01-30 09:27:35,256 - INFO - allennlp.common.params - model_details.date = 2020-02-27
# 2023-01-30 09:27:35,259 - INFO - allennlp.common.params - type = 2020-02-27
# 2023-01-30 09:27:35,263 - INFO - allennlp.common.params - model_details.version = 2
# 2023-01-30 09:27:35,264 - INFO - allennlp.common.params - type = 2
# 2023-01-30 09:27:35,268 - INFO - allennlp.common.params - model_details.model_type = SpanBERT
# 2023-01-30 09:27:35,270 - INFO - allennlp.common.params - type = SpanBERT
# 2023-01-30 09:27:35,275 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,278 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,281 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,287 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lee2018HigherorderCR,
# title={Higher-order Coreference Resolution with Coarse-to-fine Inference},
# author={Kenton Lee and Luheng He and L. Zettlemoyer},
# booktitle={NAACL-HLT},
# year={2018}}
#
# 2023-01-30 09:27:35,291 - INFO - allennlp.common.params - model_details.paper.title = Higher-order Coreference Resolution with Coarse-to-fine Inference
# 2023-01-30 09:27:35,293 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:4891749
# 2023-01-30 09:27:35,295 - INFO - allennlp.common.params - model_details.license = None
# 2023-01-30 09:27:35,297 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-01-30 09:27:35,299 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-01-30 09:27:35,312 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,316 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,319 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,319 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-01-30 09:27:35,319 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-01-30 09:27:35,319 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-01-30 09:27:35,319 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,330 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,330 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,338 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-01-30 09:27:35,338 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-01-30 09:27:35,343 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,343 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,343 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,343 - INFO - allennlp.common.params - metrics.model_performance_measures = CoNLL coref scores and Mention Recall
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - type = CoNLL coref scores and Mention Recall
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,353 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - evaluation_data.dataset.name = Ontonotes 5.0
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - evaluation_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = /path/to/dataset
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:35,369 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.dataset.name = Ontonotes 5.0
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-01-30 09:27:35,386 - INFO - allennlp.common.params - training_data.dataset.processed_url = /path/to/dataset
# 2023-01-30 09:27:35,405 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-01-30 09:27:35,406 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-01-30 09:27:35,407 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:35,407 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:35,407 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:35,407 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-01-30 09:27:35,422 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-01-30 09:27:35,425 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:35,427 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:35,427 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:35,427 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-01-30 09:27:35,427 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:35,436 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:35,436 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:35,436 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-01-30 09:27:35,436 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\evaluate_rc-lerc.json as plain json
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - id = evaluate_rc-lerc
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - type = evaluate_rc-lerc
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - registered_model_name = lerc
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - type = lerc
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - model_class = None
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - registered_predictor_name = lerc
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - type = lerc
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - display_name = Learned Evaluation for Reading Comprehension (LERC)
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - type = Learned Evaluation for Reading Comprehension (LERC)
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - task_id = evaluate_rc
# 2023-01-30 09:27:35,455 - INFO - allennlp.common.params - type = evaluate_rc
# 2023-01-30 09:27:35,471 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,471 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,471 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,471 - INFO - allennlp.common.params - model_usage.archive_file = lerc-2020-11-18.tar.gz
# 2023-01-30 09:27:35,471 - INFO - allennlp.common.params - type = lerc-2020-11-18.tar.gz
# 2023-01-30 09:27:35,486 - INFO - allennlp.common.params - model_usage.training_config = None
# 2023-01-30 09:27:35,487 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-01-30 09:27:35,487 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-01-30 09:27:35,487 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-01-30 09:27:35,504 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,504 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,504 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,504 - INFO - allennlp.common.params - model_details.description = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-01-30 09:27:35,504 - INFO - allennlp.common.params - type = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-01-30 09:27:35,520 - INFO - allennlp.common.params - model_details.short_description = A BERT model that scores candidate answers from 0 to 1.
# 2023-01-30 09:27:35,520 - INFO - allennlp.common.params - type = A BERT model that scores candidate answers from 0 to 1.
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - model_details.developed_by = Chen et al
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - type = Chen et al
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - model_details.contributed_by = Anthony Chen
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - type = Anthony Chen
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - model_details.date = 2021-03-10
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - type = 2021-03-10
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - model_details.version = 1
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - type = 1
# 2023-01-30 09:27:35,540 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - type = BERT
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Chen2020MOCHAAD,
# title={MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics},
# author={Anthony Chen and Gabriel Stanovsky and S. Singh and Matt Gardner},
# booktitle={EMNLP},
# year={2020}}
#
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.paper.title = MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:222208714
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.license = None
# 2023-01-30 09:27:35,553 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-01-30 09:27:35,569 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-01-30 09:27:35,569 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,585 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,587 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,596 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-01-30 09:27:35,597 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-01-30 09:27:35,603 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-01-30 09:27:35,603 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,603 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,603 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,622 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-01-30 09:27:35,637 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-01-30 09:27:35,637 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,637 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,637 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,637 - INFO - allennlp.common.params - metrics.model_performance_measures = Pearson Correlation
# 2023-01-30 09:27:35,655 - INFO - allennlp.common.params - type = Pearson Correlation
# 2023-01-30 09:27:35,655 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-01-30 09:27:35,669 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-01-30 09:27:35,670 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,670 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,686 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,686 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,703 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,703 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,703 - INFO - allennlp.common.params - evaluation_data.dataset.name = MOCHA
# 2023-01-30 09:27:35,703 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://allennlp.org/mocha
# 2023-01-30 09:27:35,713 - INFO - allennlp.common.params - evaluation_data.dataset.notes = To evaluate this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-01-30 09:27:35,713 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = None
# 2023-01-30 09:27:35,713 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-01-30 09:27:35,713 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-01-30 09:27:35,713 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:35,721 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:35,721 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:35,721 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:35,721 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:35,736 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:35,736 - INFO - allennlp.common.params - training_data.dataset.name = MOCHA
# 2023-01-30 09:27:35,736 - INFO - allennlp.common.params - training_data.dataset.url = https://allennlp.org/mocha
# 2023-01-30 09:27:35,753 - INFO - allennlp.common.params - training_data.dataset.notes = To train this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-01-30 09:27:35,753 - INFO - allennlp.common.params - training_data.dataset.processed_url = None
# 2023-01-30 09:27:35,753 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-01-30 09:27:35,753 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-01-30 09:27:35,753 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:35,769 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:35,774 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:35,775 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-01-30 09:27:35,775 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-01-30 09:27:35,775 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:35,775 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:35,788 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:35,788 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-01-30 09:27:35,788 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:35,788 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:35,788 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:35,788 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-01-30 09:27:35,803 - WARNING - allennlp.common.model_card - lerc is not a registered model.
# 2023-01-30 09:27:35,803 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\generation-bart.json as plain json
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - id = generation-bart
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - type = generation-bart
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - registered_model_name = bart
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - type = bart
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - model_class = None
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - display_name = BART
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - type = BART
# 2023-01-30 09:27:35,819 - INFO - allennlp.common.params - task_id = None
# 2023-01-30 09:27:35,835 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,836 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,836 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:35,836 - INFO - allennlp.common.params - model_usage.archive_file = bart-2020.07.25.tar.gz
# 2023-01-30 09:27:35,836 - INFO - allennlp.common.params - type = bart-2020.07.25.tar.gz
# 2023-01-30 09:27:35,853 - INFO - allennlp.common.params - model_usage.training_config = generation/bart_cnn_dm.jsonnet
# 2023-01-30 09:27:35,853 - INFO - allennlp.common.params - type = generation/bart_cnn_dm.jsonnet
# 2023-01-30 09:27:35,853 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-01-30 09:27:35,853 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-01-30 09:27:35,869 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-01-30 09:27:35,869 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,869 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,869 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:35,869 - INFO - allennlp.common.params - model_details.description = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-01-30 09:27:35,869 - INFO - allennlp.common.params - type = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-01-30 09:27:35,886 - INFO - allennlp.common.params - model_details.short_description = BART with a language model head for generation.
# 2023-01-30 09:27:35,886 - INFO - allennlp.common.params - type = BART with a language model head for generation.
# 2023-01-30 09:27:35,904 - INFO - allennlp.common.params - model_details.developed_by = Lewis et al
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - type = Lewis et al
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - model_details.contributed_by = Dirk Groeneveld
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - type = Dirk Groeneveld
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - model_details.date = 2020-07-25
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - type = 2020-07-25
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - model_details.version = 1
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - type = 1
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - model_details.model_type = BART
# 2023-01-30 09:27:35,907 - INFO - allennlp.common.params - type = BART
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lewis2020BARTDS,
# title={BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension},
# author={M. Lewis and Yinhan Liu and Naman Goyal and Marjan Ghazvininejad and A. Mohamed and Omer Levy and Ves Stoyanov and L. Zettlemoyer},
# booktitle={ACL},
# year={2020}}
#
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.paper.title = BART: Denosing Sequence-to-Sequence Pre-training for Natural Language Generation,Translation, and Comprehension
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:204960716
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.license = None
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-01-30 09:27:35,920 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-01-30 09:27:35,936 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,953 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,953 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:35,953 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-01-30 09:27:35,953 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-01-30 09:27:35,953 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-01-30 09:27:35,953 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,953 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,968 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - metrics.model_performance_measures = ROUGE and BLEU
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - type = ROUGE and BLEU
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-01-30 09:27:35,969 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.dataset.name = CNN/DailyMail
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.dataset.notes = Please download the data from the url provided.
# 2023-01-30 09:27:35,986 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-01-30 09:27:36,002 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.dataset.name = CNN/DailyMail
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-01-30 09:27:36,003 - INFO - allennlp.common.params - training_data.dataset.notes = Please download the data from the url provided.
# 2023-01-30 09:27:36,019 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-01-30 09:27:36,022 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-01-30 09:27:36,022 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:36,022 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:36,022 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:36,036 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-01-30 09:27:36,036 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-01-30 09:27:36,036 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:36,036 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:36,053 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:36,053 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-01-30 09:27:36,053 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:36,053 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:36,053 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:36,053 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-01-30 09:27:36,053 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\glove-sst.json as plain json
# 2023-01-30 09:27:36,075 - INFO - allennlp.common.params - id = glove-sst
# 2023-01-30 09:27:36,075 - INFO - allennlp.common.params - type = glove-sst
# 2023-01-30 09:27:36,075 - INFO - allennlp.common.params - registered_model_name = None
# 2023-01-30 09:27:36,079 - INFO - allennlp.common.params - model_class = None
# 2023-01-30 09:27:36,079 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-01-30 09:27:36,083 - INFO - allennlp.common.params - display_name = GLoVe-LSTM
# 2023-01-30 09:27:36,083 - INFO - allennlp.common.params - type = GLoVe-LSTM
# 2023-01-30 09:27:36,087 - INFO - allennlp.common.params - task_id = sentiment-analysis
# 2023-01-30 09:27:36,089 - INFO - allennlp.common.params - type = sentiment-analysis
# 2023-01-30 09:27:36,091 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:36,093 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:36,093 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:36,099 - INFO - allennlp.common.params - model_usage.archive_file = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-01-30 09:27:36,102 - INFO - allennlp.common.params - type = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-01-30 09:27:36,113 - INFO - allennlp.common.params - model_usage.training_config = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-01-30 09:27:36,113 - INFO - allennlp.common.params - type = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-01-30 09:27:36,132 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-01-30 09:27:36,132 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-01-30 09:27:36,138 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-01-30 09:27:36,138 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:36,138 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:36,153 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:36,153 - INFO - allennlp.common.params - model_details.description = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-01-30 09:27:36,153 - INFO - allennlp.common.params - type = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-01-30 09:27:36,153 - INFO - allennlp.common.params - model_details.short_description = LSTM binary classifier with GloVe embeddings.
# 2023-01-30 09:27:36,153 - INFO - allennlp.common.params - type = LSTM binary classifier with GloVe embeddings.
# 2023-01-30 09:27:36,169 - INFO - allennlp.common.params - model_details.developed_by = None
# 2023-01-30 09:27:36,169 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-01-30 09:27:36,169 - INFO - allennlp.common.params - model_details.date = 2020-06-09
# 2023-01-30 09:27:36,169 - INFO - allennlp.common.params - type = 2020-06-09
# 2023-01-30 09:27:36,169 - INFO - allennlp.common.params - model_details.version = 1
# 2023-01-30 09:27:36,169 - INFO - allennlp.common.params - type = 1
# 2023-01-30 09:27:36,169 - INFO - allennlp.common.params - model_details.model_type = LSTM
# 2023-01-30 09:27:36,185 - INFO - allennlp.common.params - type = LSTM
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - model_details.paper = None
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - model_details.license = None
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-01-30 09:27:36,186 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-01-30 09:27:36,202 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-01-30 09:27:36,204 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-01-30 09:27:36,205 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:36,208 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:36,211 - INFO - allennlp.common.params - factors.type = ref
# 2023-01-30 09:27:36,214 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-01-30 09:27:36,218 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-01-30 09:27:36,221 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:36,223 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:36,228 - INFO - allennlp.common.params - metrics.type = ref
# 2023-01-30 09:27:36,231 - INFO - allennlp.common.params - metrics.model_performance_measures = Accuracy
# 2023-01-30 09:27:36,234 - INFO - allennlp.common.params - type = Accuracy
# 2023-01-30 09:27:36,236 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-01-30 09:27:36,239 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-01-30 09:27:36,242 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:36,243 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:36,256 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-01-30 09:27:36,258 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:36,263 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:36,266 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-01-30 09:27:36,272 - INFO - allennlp.common.params - evaluation_data.dataset.name = Stanford Sentiment Treebank
# 2023-01-30 09:27:36,275 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-01-30 09:27:36,280 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/test.txt
# 2023-01-30 09:27:36,284 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-01-30 09:27:36,291 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-01-30 09:27:36,299 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:36,303 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:36,303 - INFO - allennlp.common.params - training_data.type = ref
# 2023-01-30 09:27:36,303 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:36,303 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:36,303 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-01-30 09:27:36,303 - INFO - allennlp.common.params - training_data.dataset.name = Stanford Sentiment Treebank
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - training_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - training_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/train.txt
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - training_data.preprocessing = Binary classification setting
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - type = Binary classification setting
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = Accuracy: 87% on SST test set.
# 2023-01-30 09:27:36,319 - INFO - allennlp.common.params - type = Accuracy: 87% on SST test set.
# 2023-01-30 09:27:36,345 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-01-30 09:27:36,349 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:36,349 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:36,357 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-01-30 09:27:36,360 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-01-30 09:27:36,361 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:36,364 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:36,368 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-01-30 09:27:36,370 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-01-30 09:27:36,375 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\lm-masked-language-model.json as plain json
# 2023-01-30 09:27:36,387 - INFO - allennlp.common.params - id = lm-masked-language-model
# 2023-01-30 09:27:36,391 - INFO - allennlp.common.params - type = lm-masked-language-model
# 2023-01-30 09:27:36,391 - INFO - allennlp.common.params - registered_model_name = masked_language_model
# 2023-01-30 09:27:36,395 - INFO - allennlp.common.params - type = masked_language_model
# 2023-01-30 09:27:36,397 - INFO - allennlp.common.params - model_class = None
# 2023-01-30 09:27:36,398 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-01-30 09:27:36,400 - INFO - allennlp.common.params - display_name = BERT-based Masked Language Model
# 2023-01-30 09:27:36,402 - INFO - allennlp.common.params - type = BERT-based Masked Language Model
# 2023-01-30 09:27:36,405 - INFO - allennlp.common.params - task_id = masked-language-modeling
# 2023-01-30 09:27:36,407 - INFO - allennlp.common.params - type = masked-language-modeling
# 2023-01-30 09:27:36,410 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:36,411 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:36,420 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-01-30 09:27:36,424 - INFO - allennlp.common.params - model_usage.archive_file = bert-masked-lm-2020-10-07.tar.gz
# 2023-01-30 09:27:36,424 - INFO - allennlp.common.params - type = bert-masked-lm-2020-10-07.tar.gz
# 2023-01-30 09:27:36,438 - INFO - allennlp.common.params - model_usage.training_config = lm/bidirectional_language_model.jsonnet
# 2023-01-30 09:27:36,438 - INFO - allennlp.common.params - type = lm/bidirectional_language_model.jsonnet
# 2023-01-30 09:27:36,453 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-01-30 09:27:36,453 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-01-30 09:27:36,469 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-01-30 09:27:36,469 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:36,469 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:36,469 - INFO - allennlp.common.params - model_details.type = ref
# 2023-01-30 09:27:36,469 - INFO - allennlp.common.params - model_details.description = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-01-30 09:27:36,486 - INFO - allennlp.common.params - type = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-01-30 09:27:36,486 - INFO - allennlp.common.params - model_details.short_description = BERT-based masked language model
# 2023-01-30 09:27:36,486 - INFO - allennlp.common.params - type = BERT-based masked language model
# 2023-01-30 09:27:36,486 - INFO - allennlp.common.params - model_details.developed_by = Devlin et al
# 2023-01-30 09:27:36,503 - INFO - allennlp.common.params - type = Devlin et al
# 2023-01-30 09:27:36,503 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-01-30 09:27:36,503 - INFO - allennlp.common.params - model_details.date = 2020-10-07
# 2023-01-30 09:27:36,503 - INFO - allennlp.common.params - type = 2020-10-07
# 2023-01-30 09:27:36,503 - INFO - allennlp.common.params - model_details.version = 1
# 2023-01-30 09:27:36,511 - INFO - allennlp.common.params - type = 1
# 2023-01-30 09:27:36,511 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-01-30 09:27:36,511 - INFO - allennlp.common.params - type = BERT
# 2023-01-30 09:27:36,511 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:36,511 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:36,519 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-01-30 09:27:36,519 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Devlin2019BERTPO,
# ...
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.output.dense.weight
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.key.bias
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.key.weight
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.query.bias
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.query.weight
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.value.bias
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.value.weight
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.intermediate.dense.bias
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.intermediate.dense.weight
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.LayerNorm.bias
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.LayerNorm.weight
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.dense.bias
# 2023-01-30 09:28:28,939 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.dense.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.key.bias
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.key.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.query.bias
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.query.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.value.bias
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.value.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2023-01-30 09:28:28,955 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.dense.bias
# 2023-01-30 09:28:28,972 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.dense.weight
# 2023-01-30 09:28:28,974 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2023-01-30 09:28:28,975 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2023-01-30 09:28:28,976 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2023-01-30 09:28:28,978 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2023-01-30 09:28:28,978 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.key.bias
# 2023-01-30 09:28:28,980 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.key.weight
# 2023-01-30 09:28:28,982 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.query.bias
# 2023-01-30 09:28:28,983 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.query.weight
# 2023-01-30 09:28:28,984 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.value.bias
# 2023-01-30 09:28:28,986 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.value.weight
# 2023-01-30 09:28:28,987 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2023-01-30 09:28:28,990 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2023-01-30 09:28:28,992 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2023-01-30 09:28:28,993 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2023-01-30 09:28:28,995 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.dense.bias
# 2023-01-30 09:28:28,996 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.dense.weight
# 2023-01-30 09:28:28,997 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2023-01-30 09:28:28,999 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2023-01-30 09:28:29,000 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2023-01-30 09:28:29,001 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2023-01-30 09:28:29,003 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.key.bias
# 2023-01-30 09:28:29,006 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.key.weight
# 2023-01-30 09:28:29,007 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.query.bias
# 2023-01-30 09:28:29,009 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.query.weight
# 2023-01-30 09:28:29,010 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.value.bias
# 2023-01-30 09:28:29,012 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.value.weight
# 2023-01-30 09:28:29,013 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2023-01-30 09:28:29,014 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2023-01-30 09:28:29,016 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2023-01-30 09:28:29,017 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2023-01-30 09:28:29,019 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.dense.bias
# 2023-01-30 09:28:29,021 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.dense.weight
# 2023-01-30 09:28:29,024 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2023-01-30 09:28:29,025 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2023-01-30 09:28:29,026 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2023-01-30 09:28:29,028 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2023-01-30 09:28:29,031 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.key.bias
# 2023-01-30 09:28:29,032 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.key.weight
# 2023-01-30 09:28:29,034 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.query.bias
# 2023-01-30 09:28:29,035 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.query.weight
# 2023-01-30 09:28:29,037 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.value.bias
# 2023-01-30 09:28:29,040 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.value.weight
# 2023-01-30 09:28:29,041 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2023-01-30 09:28:29,042 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2023-01-30 09:28:29,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2023-01-30 09:28:29,044 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2023-01-30 09:28:29,045 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.dense.bias
# 2023-01-30 09:28:29,046 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.dense.weight
# 2023-01-30 09:28:29,048 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2023-01-30 09:28:29,050 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2023-01-30 09:28:29,050 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2023-01-30 09:28:29,053 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2023-01-30 09:28:29,055 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.key.bias
# 2023-01-30 09:28:29,057 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.key.weight
# 2023-01-30 09:28:29,060 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.query.bias
# 2023-01-30 09:28:29,062 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.query.weight
# 2023-01-30 09:28:29,063 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.value.bias
# 2023-01-30 09:28:29,065 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.value.weight
# 2023-01-30 09:28:29,066 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2023-01-30 09:28:29,068 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2023-01-30 09:28:29,068 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2023-01-30 09:28:29,070 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2023-01-30 09:28:29,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.dense.bias
# 2023-01-30 09:28:29,075 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.dense.weight
# 2023-01-30 09:28:29,077 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.pooler.dense.bias
# 2023-01-30 09:28:29,079 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.pooler.dense.weight
# 2023-01-30 09:28:29,921 - INFO - allennlp.models.archival - removing temporary unarchived model dir at C:\Users\sjsheikh\AppData\Local\Temp\tmpst9t0rnw

# %%
file_name = './Text/Causal Sentences.txt'
narrative = open(file_name, encoding="utf8").read()
narrative = narrative.lower()

print('\nNLTK Sentences:\n')
raw_sentences = sent_tokenize(str(narrative))
for sent in raw_sentences:
    print(sent)
    print()
# Out:
# NLTK Sentences:
#
# the mail man jumped because the dog barked.
#
# the rain caused wilting of flowers.
#
# the sun rises in the east.
#
# the wind blew the leaves.
#
# the dog bit the mailman.
#
# the boy kicked the ball.
#
# the girl sang a song.
#
# the teacher graded the papers.
#
# the car hit the tree.
#
# the storm knocked down the power lines.
#
# the baby cried for milk.
#
# the cook made dinner.
#
# the student passed the exam.
#
# the company launched a new product.
#
# the singer performed on stage.
#
# the doctor prescribed medicine.
#
# the farmer harvested the crops.
#
# the artist painted a picture.
#
# the dog chased the cat.
#
# the bird built a nest.
#
# the teacher taught the lesson.
#
# the child played with the toy.
#
# the company released a statement.
#
# the band played a concert.
#
# the doctor examined the patient.
#
# the engineer designed the bridge.
#
# the scientist conducted the experiment.
#
# the worker assembled the machine.
#
# the author wrote a novel.
#
# the player scored a goal.
#
# the photographer took a picture.
#
# the police officer arrested the suspect.
#
# the chef cooked a meal.
#
# the musician composed a song.
#
# the designer created a website.
#
# the athlete won the race.
#
# the businessman made a deal.
#
# the driver drove the car.
#
# the writer wrote an article.
#
# the teacher gave a lecture.
#
# the student studied for the test.
#
# the company hired a new employee.
#
# the doctor treated the illness.
#
# the artist sculpted a statue.
#
# the dog barked at the stranger.
#
# the bird flew in the sky.
#
# the teacher graded the quizzes.
#
# the car broke down on the highway.
#
# the storm caused a flood.
#
# the baby slept through the night.
#
# the cook prepared the ingredients.
#
# the student completed the assignment.
#
# the company expanded its market.
#
# the singer recorded an album.
#
# the doctor performed surgery.
#
# the farmer tended to the animals.
#
# the artist drew a portrait.
#
# the dog fetched the ball.
#
# the bird sang a melody.
#
# the teacher taught a class.
#
# the child learned how to read.
#
# the company released an update.
#
# the band played a gig.
#
# the doctor diagnosed the illness.
#
# the engineer constructed the building.
#
# the scientist discovered a new element.
#
# the worker repaired the equipment.
#
# the author wrote a short story.
#
# the player made a save.
#
# the photographer captured a moment.
#
# the police officer investigated the crime.
#
# the chef served the meal.
#
# the musician played an instrument.
#
# the designer created a logo.
#
# the athlete trained for the competition.
#
# the businessman closed the deal.
#
# the driver followed the map.
#
# the writer wrote a story.
#
# the teacher gave a presentation.
#
# the student reviewed the material.
#
# zulfikar ali bhutto launched nuclear program.
#
# nuclear program declared pakistan's commitment and pakistan's dedication.
#
# aq khan developed nuclear bomb.
#
# nuclear bomb strengthened pakistan.
#
# nuclear bomb makes nuclear power.
#
# pakistan must never surrender nuclear bomb.
#
# pakistan must fight off existential threats.
#
# pakistan must support army and aq khan.
#
# army provides vigilance.
#
# vigilance strengthened national survival.
#
# institutional weakness hindered development of the agriculture sector.
#
# conflict discourages farmers from expanding production.
#
# conflict discourages traders from building marketing infrastructure.
#
# conflict discourages retailers from building marketing infrastructure.
#
# the low level of public investment shows that no irrigation infrastructure exists.
#
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
#
# inadequate transportation infrastructure has resulted in less transport to markets.
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
#
# highly saturated soils cause flooding in flood-prone areas.
#
# rain caused floods.
#
# floods have displaced more than 100,000 people in south sudan's.
#
# floods raise fears.
#
# floods devastatingly impact on food security in the war-torn nation.
#
# excessive overthinking leads to insomnia.
#
# stress caused insomnia.
#
# insomnia causes stress.
#
# stress results in insomnia.
#
# stress results to insomnia.

# %%
#new
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
sub = ''
obj = ''
#tuple =('a','b','c')

#print(tuple[0])

for sent in raw_sentences:
    sent = nlp(sent)
    print("Sentence:")
    print(sent)
    
    print("Noun Chunks:")
    for nc in sent.noun_chunks:
        print (nc)
        ncl.append(nc)
    print ("Number of noun chunks: ", len(ncl))
    
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            print("Triples other than textacy:")
            print(nncl[0])
            print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],triplets[0][1],ncl[1])]
#            print("Triples other than textacy:")
#            print(nncl[0])
#            finalList.append(nncl[0])
    else:
        print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                sub = token
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
                #tuple[1] = token.text
            #elif token.dep_ == 'dobj':
            #    obj = token.text
                #tuple[2] = token.text
            #    break
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue
                
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        print("Triple by combining nsubj, root and dobj:")
        print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],verb,ncl[1])]
#            print("Triples other than sub, verb and obj:")
#            print(nncl[0])
#            finalList.append(nncl[0])

    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
    
trips = finalList
# Out:
# Sentence:
# the mail man jumped because the dog barked.
# Noun Chunks:
# the mail man
# the dog
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the dog, jumped, '')
# Sentence:
# the rain caused wilting of flowers.
# Noun Chunks:
# the rain
# wilting
# flowers
# Number of noun chunks:  3
# Triples from textacy:
# (the rain, caused, wilting)
# Triples other than textacy:
# (the rain, caused, wilting)
# (the rain, caused, flowers)
# Sentence:
# the sun rises in the east.
# Noun Chunks:
# the sun
# the east
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the sun, rises, the east)
# Sentence:
# the wind blew the leaves.
# Noun Chunks:
# the wind
# the leaves
# Number of noun chunks:  2
# Triples from textacy:
# (the wind, blew, the leaves)
# Sentence:
# the dog bit the mailman.
# Noun Chunks:
# the dog
# the mailman
# Number of noun chunks:  2
# Triples from textacy:
# (the dog, bit, the mailman)
# Sentence:
# the boy kicked the ball.
# Noun Chunks:
# the boy
# the ball
# Number of noun chunks:  2
# Triples from textacy:
# (the boy, kicked, the ball)
# Sentence:
# the girl sang a song.
# Noun Chunks:
# the girl
# a song
# Number of noun chunks:  2
# Triples from textacy:
# (the girl, sang, a song)
# Sentence:
# the teacher graded the papers.
# Noun Chunks:
# the teacher
# the papers
# Number of noun chunks:  2
# Triples from textacy:
# (the teacher, graded, the papers)
# Sentence:
# the car hit the tree.
# Noun Chunks:
# the car
# the tree
# Number of noun chunks:  2
# Triples from textacy:
# (the car, hit, the tree)
# Sentence:
# the storm knocked down the power lines.
# Noun Chunks:
# the storm
# the power lines
# Number of noun chunks:  2
# Triples from textacy:
# (the storm, knocked, power lines)
# Sentence:
# the baby cried for milk.
# Noun Chunks:
# the baby
# milk
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the baby, cried, milk)
# Sentence:
# the cook made dinner.
# Noun Chunks:
# the cook
# dinner
# Number of noun chunks:  2
# Triples from textacy:
# (the cook, made, dinner)
# Sentence:
# the student passed the exam.
# Noun Chunks:
# the student
# the exam
# Number of noun chunks:  2
# Triples from textacy:
# (the student, passed, the exam)
# Sentence:
# the company launched a new product.
# Noun Chunks:
# the company
# a new product
# Number of noun chunks:  2
# Triples from textacy:
# (the company, launched, a new product)
# Sentence:
# the singer performed on stage.
# Noun Chunks:
# the singer
# stage
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the singer, performed, stage)
# Sentence:
# the doctor prescribed medicine.
# Noun Chunks:
# the doctor prescribed medicine
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the singer, medicine, stage)
# Sentence:
# the farmer harvested the crops.
# Noun Chunks:
# the farmer
# the crops
# Number of noun chunks:  2
# Triples from textacy:
# (the farmer, harvested, the crops)
# Sentence:
# the artist painted a picture.
# Noun Chunks:
# the artist
# a picture
# Number of noun chunks:  2
# Triples from textacy:
# (the artist, painted, a picture)
# Sentence:
# the dog chased the cat.
# Noun Chunks:
# the dog
# the cat
# Number of noun chunks:  2
# Triples from textacy:
# (the dog, chased, the cat)
# Sentence:
# the bird built a nest.
# Noun Chunks:
# the bird
# a nest
# Number of noun chunks:  2
# Triples from textacy:
# (the bird, built, a nest)
# Sentence:
# the teacher taught the lesson.
# Noun Chunks:
# the teacher
# the lesson
# Number of noun chunks:  2
# Triples from textacy:
# (the teacher, taught, the lesson)
# Sentence:
# the child played with the toy.
# Noun Chunks:
# the child
# the toy
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the child, played, the toy)
# Sentence:
# the company released a statement.
# Noun Chunks:
# the company
# a statement
# Number of noun chunks:  2
# Triples from textacy:
# (the company, released, a statement)
# Sentence:
# the band played a concert.
# Noun Chunks:
# the band
# a concert
# Number of noun chunks:  2
# Triples from textacy:
# (the band, played, a concert)
# Sentence:
# the doctor examined the patient.
# Noun Chunks:
# the doctor
# the patient
# Number of noun chunks:  2
# Triples from textacy:
# (the doctor, examined, the patient)
# Sentence:
# the engineer designed the bridge.
# Noun Chunks:
# the engineer
# the bridge
# Number of noun chunks:  2
# Triples from textacy:
# (the engineer, designed, the bridge)
# Sentence:
# the scientist conducted the experiment.
# Noun Chunks:
# the scientist
# the experiment
# Number of noun chunks:  2
# Triples from textacy:
# (the scientist, conducted, the experiment)
# Sentence:
# the worker assembled the machine.
# Noun Chunks:
# the worker
# the machine
# Number of noun chunks:  2
# Triples from textacy:
# (the worker, assembled, the machine)
# Sentence:
# the author wrote a novel.
# Noun Chunks:
# the author
# a novel
# Number of noun chunks:  2
# Triples from textacy:
# (the author, wrote, a novel)
# Sentence:
# the player scored a goal.
# Noun Chunks:
# the player
# a goal
# Number of noun chunks:  2
# Triples from textacy:
# (the player, scored, a goal)
# Sentence:
# the photographer took a picture.
# Noun Chunks:
# the photographer
# a picture
# Number of noun chunks:  2
# Triples from textacy:
# (the photographer, took, a picture)
# Sentence:
# the police officer arrested the suspect.
# Noun Chunks:
# the police officer
# the suspect
# Number of noun chunks:  2
# Triples from textacy:
# (police officer, arrested, the suspect)
# Sentence:
# the chef cooked a meal.
# Noun Chunks:
# the chef
# a meal
# Number of noun chunks:  2
# Triples from textacy:
# (the chef, cooked, a meal)
# Sentence:
# the musician composed a song.
# Noun Chunks:
# the musician
# a song
# Number of noun chunks:  2
# Triples from textacy:
# (the musician, composed, a song)
# Sentence:
# the designer created a website.
# Noun Chunks:
# the designer
# a website
# Number of noun chunks:  2
# Triples from textacy:
# (the designer, created, a website)
# Sentence:
# the athlete won the race.
# Noun Chunks:
# the athlete
# the race
# Number of noun chunks:  2
# Triples from textacy:
# (the athlete, won, the race)
# Sentence:
# the businessman made a deal.
# Noun Chunks:
# the businessman
# a deal
# Number of noun chunks:  2
# Triples from textacy:
# (the businessman, made, a deal)
# Sentence:
# the driver drove the car.
# Noun Chunks:
# the driver
# the car
# Number of noun chunks:  2
# Triples from textacy:
# (the driver, drove, the car)
# Sentence:
# the writer wrote an article.
# Noun Chunks:
# the writer
# an article
# Number of noun chunks:  2
# Triples from textacy:
# (the writer, wrote, an article)
# Sentence:
# the teacher gave a lecture.
# Noun Chunks:
# the teacher
# a lecture
# Number of noun chunks:  2
# Triples from textacy:
# (the teacher, gave, a lecture)
# Sentence:
# the student studied for the test.
# Noun Chunks:
# the student
# the test
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the student, studied, the test)
# Sentence:
# the company hired a new employee.
# Noun Chunks:
# the company
# a new employee
# Number of noun chunks:  2
# Triples from textacy:
# (the company, hired, a new employee)
# Sentence:
# the doctor treated the illness.
# Noun Chunks:
# the doctor
# the illness
# Number of noun chunks:  2
# Triples from textacy:
# (the doctor, treated, the illness)
# Sentence:
# the artist sculpted a statue.
# Noun Chunks:
# the artist
# a statue
# Number of noun chunks:  2
# Triples from textacy:
# (the artist, sculpted, a statue)
# Sentence:
# the dog barked at the stranger.
# Noun Chunks:
# the dog
# the stranger
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the dog, barked, the stranger)
# Sentence:
# the bird flew in the sky.
# Noun Chunks:
# the bird
# the sky
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the bird, flew, the sky)
# Sentence:
# the teacher graded the quizzes.
# Noun Chunks:
# the teacher
# the quizzes
# Number of noun chunks:  2
# Triples from textacy:
# (the teacher, graded, the quizzes)
# Sentence:
# the car broke down on the highway.
# Noun Chunks:
# the car
# the highway
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the car, broke, the highway)
# Sentence:
# the storm caused a flood.
# Noun Chunks:
# the storm
# a flood
# Number of noun chunks:  2
# Triples from textacy:
# (the storm, caused, a flood)
# Sentence:
# the baby slept through the night.
# Noun Chunks:
# the baby
# the night
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the baby, slept, the night)
# Sentence:
# the cook prepared the ingredients.
# Noun Chunks:
# the cook
# the ingredients
# Number of noun chunks:  2
# Triples from textacy:
# (the cook, prepared, the ingredients)
# Sentence:
# the student completed the assignment.
# Noun Chunks:
# the student
# the assignment
# Number of noun chunks:  2
# Triples from textacy:
# (the student, completed, the assignment)
# Sentence:
# the company expanded its market.
# Noun Chunks:
# the company
# its market
# Number of noun chunks:  2
# Triples from textacy:
# (the company, expanded, its market)
# Sentence:
# the singer recorded an album.
# Noun Chunks:
# the singer
# an album
# Number of noun chunks:  2
# Triples from textacy:
# (the singer, recorded, an album)
# Sentence:
# the doctor performed surgery.
# Noun Chunks:
# the doctor
# surgery
# Number of noun chunks:  2
# Triples from textacy:
# (the doctor, performed, surgery)
# Sentence:
# the farmer tended to the animals.
# Noun Chunks:
# the farmer
# the animals
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the farmer, tended, the animals)
# Sentence:
# the artist drew a portrait.
# Noun Chunks:
# the artist
# a portrait
# Number of noun chunks:  2
# Triples from textacy:
# (the artist, drew, a portrait)
# Sentence:
# the dog fetched the ball.
# Noun Chunks:
# the dog
# the ball
# Number of noun chunks:  2
# Triples from textacy:
# (the dog, fetched, the ball)
# Sentence:
# the bird sang a melody.
# Noun Chunks:
# the bird
# a melody
# Number of noun chunks:  2
# Triples from textacy:
# (the bird, sang, a melody)
# Sentence:
# the teacher taught a class.
# Noun Chunks:
# the teacher
# a class
# Number of noun chunks:  2
# Triples from textacy:
# (the teacher, taught, a class)
# Sentence:
# the child learned how to read.
# Noun Chunks:
# the child
# Number of noun chunks:  1
# Triples from textacy:
# (the child, learned, to read)
# Sentence:
# the company released an update.
# Noun Chunks:
# the company
# an update
# Number of noun chunks:  2
# Triples from textacy:
# (the company, released, an update)
# Sentence:
# the band played a gig.
# Noun Chunks:
# the band
# a gig
# Number of noun chunks:  2
# Triples from textacy:
# (the band, played, a gig)
# Sentence:
# the doctor diagnosed the illness.
# Noun Chunks:
# the doctor
# the illness
# Number of noun chunks:  2
# Triples from textacy:
# (the doctor, diagnosed, the illness)
# Sentence:
# the engineer constructed the building.
# Noun Chunks:
# the engineer
# the building
# Number of noun chunks:  2
# Triples from textacy:
# (the engineer, constructed, the building)
# Sentence:
# the scientist discovered a new element.
# Noun Chunks:
# the scientist
# a new element
# Number of noun chunks:  2
# Triples from textacy:
# (the scientist, discovered, a new element)
# Sentence:
# the worker repaired the equipment.
# Noun Chunks:
# the worker
# the equipment
# Number of noun chunks:  2
# Triples from textacy:
# (the worker, repaired, the equipment)
# Sentence:
# the author wrote a short story.
# Noun Chunks:
# the author
# a short story
# Number of noun chunks:  2
# Triples from textacy:
# (the author, wrote, a short story)
# Sentence:
# the player made a save.
# Noun Chunks:
# the player
# a save
# Number of noun chunks:  2
# Triples from textacy:
# (the player, made, a save)
# Sentence:
# the photographer captured a moment.
# Noun Chunks:
# the photographer
# a moment
# Number of noun chunks:  2
# Triples from textacy:
# (the photographer, captured, a moment)
# Sentence:
# the police officer investigated the crime.
# Noun Chunks:
# the police officer
# the crime
# Number of noun chunks:  2
# Triples from textacy:
# (police officer, investigated, the crime)
# Sentence:
# the chef served the meal.
# Noun Chunks:
# the chef
# the meal
# Number of noun chunks:  2
# Triples from textacy:
# (the chef, served, the meal)
# Sentence:
# the musician played an instrument.
# Noun Chunks:
# the musician
# an instrument
# Number of noun chunks:  2
# Triples from textacy:
# (the musician, played, an instrument)
# Sentence:
# the designer created a logo.
# Noun Chunks:
# the designer
# a logo
# Number of noun chunks:  2
# Triples from textacy:
# (the designer, created, a logo)
# Sentence:
# the athlete trained for the competition.
# Noun Chunks:
# the athlete
# the competition
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the athlete, trained, the competition)
# Sentence:
# the businessman closed the deal.
# Noun Chunks:
# the businessman
# the deal
# Number of noun chunks:  2
# Triples from textacy:
# (the businessman, closed, the deal)
# Sentence:
# the driver followed the map.
# Noun Chunks:
# the driver
# the map
# Number of noun chunks:  2
# Triples from textacy:
# (the driver, followed, the map)
# Sentence:
# the writer wrote a story.
# Noun Chunks:
# the writer
# a story
# Number of noun chunks:  2
# Triples from textacy:
# (the writer, wrote, a story)
# Sentence:
# the teacher gave a presentation.
# Noun Chunks:
# the teacher
# a presentation
# Number of noun chunks:  2
# Triples from textacy:
# (the teacher, gave, a presentation)
# Sentence:
# the student reviewed the material.
# Noun Chunks:
# the student
# the material
# Number of noun chunks:  2
# Triples from textacy:
# (the student, reviewed, the material)
# Sentence:
# zulfikar ali bhutto launched nuclear program.
# Noun Chunks:
# zulfikar ali bhutto
# nuclear program
# Number of noun chunks:  2
# Triples from textacy:
# (zulfikar ali bhutto, launched, nuclear program)
# Sentence:
# nuclear program declared pakistan's commitment and pakistan's dedication.
# Noun Chunks:
# nuclear program
# pakistan's commitment
# pakistan's dedication
# Number of noun chunks:  3
# Triples from textacy:
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# Triples other than textacy:
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# Sentence:
# aq khan developed nuclear bomb.
# Noun Chunks:
# aq khan
# nuclear bomb
# Number of noun chunks:  2
# Triples from textacy:
# (aq khan, developed, nuclear bomb)
# Sentence:
# nuclear bomb strengthened pakistan.
# Noun Chunks:
# nuclear bomb
# pakistan
# Number of noun chunks:  2
# Triples from textacy:
# (nuclear bomb, strengthened, pakistan)
# Sentence:
# nuclear bomb makes nuclear power.
# Noun Chunks:
# nuclear bomb
# nuclear power
# Number of noun chunks:  2
# Triples from textacy:
# (nuclear bomb, makes, nuclear power)
# Sentence:
# pakistan must never surrender nuclear bomb.
# Noun Chunks:
# pakistan
# nuclear bomb
# Number of noun chunks:  2
# Triples from textacy:
# (pakistan, must never surrender, nuclear bomb)
# Sentence:
# pakistan must fight off existential threats.
# Noun Chunks:
# pakistan
# existential threats
# Number of noun chunks:  2
# Triples from textacy:
# (pakistan, must fight, existential threats)
# Sentence:
# pakistan must support army and aq khan.
# Noun Chunks:
# pakistan
# army
# aq khan
# Number of noun chunks:  3
# Triples from textacy:
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# Triples other than textacy:
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# Sentence:
# army provides vigilance.
# Noun Chunks:
# army
# vigilance
# Number of noun chunks:  2
# Triples from textacy:
# (army, provides, vigilance)
# Sentence:
# vigilance strengthened national survival.
# Noun Chunks:
# vigilance
# national survival
# Number of noun chunks:  2
# Triples from textacy:
# (vigilance, strengthened, national survival)
# Sentence:
# institutional weakness hindered development of the agriculture sector.
# Noun Chunks:
# institutional weakness
# development
# the agriculture sector
# Number of noun chunks:  3
# Triples from textacy:
# (institutional weakness, hindered, development)
# Triples other than textacy:
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# Sentence:
# conflict discourages farmers from expanding production.
# Noun Chunks:
# conflict
# farmers
# production
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (conflict, discourages, production)
# Triples other than sub, verb and obj:
# (conflict, discourages, farmers)
# (conflict, discourages, production)
# Sentence:
# conflict discourages traders from building marketing infrastructure.
# Noun Chunks:
# conflict
# traders
# marketing infrastructure
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, traders)
# Triples other than textacy:
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# Sentence:
# conflict discourages retailers from building marketing infrastructure.
# Noun Chunks:
# conflict
# retailers
# marketing infrastructure
# Number of noun chunks:  3
# Triples from textacy:
# (conflict, discourages, retailers)
# Triples other than textacy:
# (conflict, discourages, retailers)
# (conflict, discourages, marketing infrastructure)
# Sentence:
# the low level of public investment shows that no irrigation infrastructure exists.
# Noun Chunks:
# the low level
# public investment
# no irrigation infrastructure
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (no irrigation infrastructure, shows, public investment)
# Triples other than sub, verb and obj:
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# Sentence:
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# Noun Chunks:
# the low level
# public investment
# only 2 percent
# south sudan's limited road network
# Number of noun chunks:  4
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (south sudan's limited road network, shows, only 2 percent)
# Sentence:
# inadequate transportation infrastructure has resulted in less transport to markets.
# Noun Chunks:
# inadequate transportation infrastructure
# less transport
# markets
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (inadequate transportation infrastructure, resulted, markets)
# Triples other than sub, verb and obj:
# (inadequate transportation infrastructure, resulted, less transport)
# (inadequate transportation infrastructure, resulted, markets)
# Sentence:
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
# Noun Chunks:
# persistent heavy rains
# the eastern sudan
# flood-prone areas
# Number of noun chunks:  3
# Triples from textacy:
# (persistent heavy rains, cause, flooding)
# Triples other than textacy:
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, cause, flood-prone areas)
# Sentence:
# highly saturated soils cause flooding in flood-prone areas.
# Noun Chunks:
# highly saturated soils
# flood-prone areas
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (highly saturated soils, cause, flood-prone areas)
# Sentence:
# rain caused floods.
# Noun Chunks:
# rain
# floods
# Number of noun chunks:  2
# Triples from textacy:
# (rain, caused, floods)
# Sentence:
# floods have displaced more than 100,000 people in south sudan's.
# Noun Chunks:
# floods
# more than 100,000 people
# south sudan
# Number of noun chunks:  3
# Triples from textacy:
# (floods, have displaced, more than 100,000 people)
# Triples other than textacy:
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# Sentence:
# floods raise fears.
# Noun Chunks:
# floods
# fears
# Number of noun chunks:  2
# Triples from textacy:
# (floods, raise, fears)
# Sentence:
# floods devastatingly impact on food security in the war-torn nation.
# Noun Chunks:
# floods devastatingly impact
# food security
# the war-torn nation
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (highly saturated soils, impact, the war-torn nation)
# Triples other than sub, verb and obj:
# (floods devastatingly impact, impact, food security)
# (floods devastatingly impact, impact, the war-torn nation)
# Sentence:
# excessive overthinking leads to insomnia.
# Noun Chunks:
# excessive overthinking
# insomnia
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking, leads, insomnia)
# Sentence:
# stress caused insomnia.
# Noun Chunks:
# stress
# insomnia
# Number of noun chunks:  2
# Triples from textacy:
# (stress, caused, insomnia)
# Sentence:
# insomnia causes stress.
# Noun Chunks:
# insomnia
# stress
# Number of noun chunks:  2
# Triples from textacy:
# (insomnia, causes, stress)
# Sentence:
# stress results in insomnia.
# Noun Chunks:
# stress results
# insomnia
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking, results, insomnia)
# Sentence:
# stress results to insomnia.
# Noun Chunks:
# stress results
# insomnia
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking, results, insomnia)

# %%
print("Length of triples' List before removing duplicates:")
print(len(trips))

Triples = []
sentences1 = []

for sentence,ce in zip(sentences, trips):
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        sentences1.append(sentence)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            sentences1.append(sentence)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

for t in Triples:
    print(t)
    
#print(len(sentences1))
# Out:
# Length of triples' List before removing duplicates:
# 134
#
# List after removing duplicates:
# 121
# (the dog, jumped, '')
# (the rain, caused, wilting)
# (the rain, caused, flowers)
# (the sun, rises, the east)
# (the wind, blew, the leaves)
# (the dog, bit, the mailman)
# (the boy, kicked, the ball)
# (the girl, sang, a song)
# (the teacher, graded, the papers)
# (the car, hit, the tree)
# (the storm, knocked, power lines)
# (the baby, cried, milk)
# (the cook, made, dinner)
# (the student, passed, the exam)
# (the company, launched, a new product)
# (the singer, performed, stage)
# (the singer, medicine, stage)
# (the farmer, harvested, the crops)
# (the artist, painted, a picture)
# (the dog, chased, the cat)
# (the bird, built, a nest)
# (the teacher, taught, the lesson)
# (the child, played, the toy)
# (the company, released, a statement)
# (the band, played, a concert)
# (the doctor, examined, the patient)
# (the engineer, designed, the bridge)
# (the scientist, conducted, the experiment)
# (the worker, assembled, the machine)
# (the author, wrote, a novel)
# (the player, scored, a goal)
# (the photographer, took, a picture)
# (police officer, arrested, the suspect)
# (the chef, cooked, a meal)
# (the musician, composed, a song)
# (the designer, created, a website)
# (the athlete, won, the race)
# (the businessman, made, a deal)
# (the driver, drove, the car)
# (the writer, wrote, an article)
# (the teacher, gave, a lecture)
# (the student, studied, the test)
# (the company, hired, a new employee)
# (the doctor, treated, the illness)
# (the artist, sculpted, a statue)
# (the dog, barked, the stranger)
# (the bird, flew, the sky)
# (the teacher, graded, the quizzes)
# (the car, broke, the highway)
# (the storm, caused, a flood)
# (the baby, slept, the night)
# (the cook, prepared, the ingredients)
# (the student, completed, the assignment)
# (the company, expanded, its market)
# (the singer, recorded, an album)
# (the doctor, performed, surgery)
# (the farmer, tended, the animals)
# (the artist, drew, a portrait)
# (the dog, fetched, the ball)
# (the bird, sang, a melody)
# (the teacher, taught, a class)
# (the child, learned, to read)
# (the company, released, an update)
# (the band, played, a gig)
# (the doctor, diagnosed, the illness)
# (the engineer, constructed, the building)
# (the scientist, discovered, a new element)
# (the worker, repaired, the equipment)
# (the author, wrote, a short story)
# (the player, made, a save)
# (the photographer, captured, a moment)
# (police officer, investigated, the crime)
# (the chef, served, the meal)
# (the musician, played, an instrument)
# (the designer, created, a logo)
# (the athlete, trained, the competition)
# (the businessman, closed, the deal)
# (the driver, followed, the map)
# (the writer, wrote, a story)
# (the teacher, gave, a presentation)
# (the student, reviewed, the material)
# (zulfikar ali bhutto, launched, nuclear program)
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# (aq khan, developed, nuclear bomb)
# (nuclear bomb, strengthened, pakistan)
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, provides, vigilance)
# (vigilance, strengthened, national survival)
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (conflict, discourages, production)
# (conflict, discourages, farmers)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (persistent heavy rains, cause, flooding)
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, cause, flood-prone areas)
# (highly saturated soils, cause, flood-prone areas)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (highly saturated soils, impact, the war-torn nation)
# (floods devastatingly impact, impact, food security)
# (floods devastatingly impact, impact, the war-torn nation)
# (excessive overthinking, leads, insomnia)
# (stress, caused, insomnia)
# (insomnia, causes, stress)
# (excessive overthinking, results, insomnia)

# %%
causalTriples = []
causalSentences = []

for sentence,line in zip(sentences1, Triples):
    taggedWords = []
    taggedWords1 = []
    check0 = False
    check2 = False
    print(line)
    taggedWords = pos_tag(word_tokenize(str(line[0])))
    taggedWords1 = pos_tag(word_tokenize(str(line[2])))
    print(taggedWords)
    print(taggedWords1)
    for i in range(len(taggedWords)):
        if taggedWords[i][1] == 'NN' or taggedWords[i][1] == 'NNS':
            check0 = True
    for i in range(len(taggedWords1)):
        if taggedWords1[i][1] == 'NN' or taggedWords1[i][1] == 'NNS':
            check2 = True
    print(check0)  
    print(check2)
    if check0 == True and check2 == True:
        causalTriples.append(line)
        causalSentences.append(sentence)
    print("**************************************************************************")
    
for correctTriple in causalTriples:
    print(correctTriple)

print(len(causalTriples))
# Out:
# (the dog, jumped, '')
# [('the', 'DT'), ('dog', 'NN')]
# []
# True
# False
# **************************************************************************
# (the rain, caused, wilting)
# [('the', 'DT'), ('rain', 'NN')]
# [('wilting', 'VBG')]
# True
# False
# **************************************************************************
# (the rain, caused, flowers)
# [('the', 'DT'), ('rain', 'NN')]
# [('flowers', 'NNS')]
# True
# True
# **************************************************************************
# (the sun, rises, the east)
# [('the', 'DT'), ('sun', 'NN')]
# [('the', 'DT'), ('east', 'NN')]
# True
# True
# **************************************************************************
# (the wind, blew, the leaves)
# [('the', 'DT'), ('wind', 'NN')]
# [('the', 'DT'), ('leaves', 'NNS')]
# True
# True
# **************************************************************************
# (the dog, bit, the mailman)
# [('the', 'DT'), ('dog', 'NN')]
# [('the', 'DT'), ('mailman', 'NN')]
# True
# True
# **************************************************************************
# (the boy, kicked, the ball)
# [('the', 'DT'), ('boy', 'NN')]
# [('the', 'DT'), ('ball', 'NN')]
# True
# True
# **************************************************************************
# (the girl, sang, a song)
# [('the', 'DT'), ('girl', 'NN')]
# [('a', 'DT'), ('song', 'NN')]
# True
# True
# **************************************************************************
# (the teacher, graded, the papers)
# [('the', 'DT'), ('teacher', 'NN')]
# [('the', 'DT'), ('papers', 'NNS')]
# True
# True
# **************************************************************************
# (the car, hit, the tree)
# [('the', 'DT'), ('car', 'NN')]
# [('the', 'DT'), ('tree', 'NN')]
# True
# True
# **************************************************************************
# (the storm, knocked, power lines)
# [('the', 'DT'), ('storm', 'NN')]
# [('power', 'NN'), ('lines', 'NNS')]
# True
# True
# **************************************************************************
# (the baby, cried, milk)
# [('the', 'DT'), ('baby', 'NN')]
# [('milk', 'NN')]
# True
# True
# **************************************************************************
# (the cook, made, dinner)
# [('the', 'DT'), ('cook', 'NN')]
# [('dinner', 'NN')]
# True
# True
# **************************************************************************
# (the student, passed, the exam)
# [('the', 'DT'), ('student', 'NN')]
# [('the', 'DT'), ('exam', 'NN')]
# True
# True
# **************************************************************************
# (the company, launched, a new product)
# [('the', 'DT'), ('company', 'NN')]
# [('a', 'DT'), ('new', 'JJ'), ('product', 'NN')]
# True
# True
# **************************************************************************
# (the singer, performed, stage)
# [('the', 'DT'), ('singer', 'NN')]
# [('stage', 'NN')]
# True
# True
# **************************************************************************
# (the singer, medicine, stage)
# [('the', 'DT'), ('singer', 'NN')]
# [('stage', 'NN')]
# True
# True
# **************************************************************************
# (the farmer, harvested, the crops)
# [('the', 'DT'), ('farmer', 'NN')]
# [('the', 'DT'), ('crops', 'NNS')]
# True
# True
# **************************************************************************
# (the artist, painted, a picture)
# [('the', 'DT'), ('artist', 'NN')]
# [('a', 'DT'), ('picture', 'NN')]
# True
# True
# **************************************************************************
# (the dog, chased, the cat)
# [('the', 'DT'), ('dog', 'NN')]
# [('the', 'DT'), ('cat', 'NN')]
# True
# True
# **************************************************************************
# (the bird, built, a nest)
# [('the', 'DT'), ('bird', 'NN')]
# [('a', 'DT'), ('nest', 'NN')]
# True
# True
# **************************************************************************
# (the teacher, taught, the lesson)
# [('the', 'DT'), ('teacher', 'NN')]
# [('the', 'DT'), ('lesson', 'NN')]
# True
# True
# **************************************************************************
# (the child, played, the toy)
# [('the', 'DT'), ('child', 'NN')]
# [('the', 'DT'), ('toy', 'NN')]
# True
# True
# **************************************************************************
# (the company, released, a statement)
# [('the', 'DT'), ('company', 'NN')]
# [('a', 'DT'), ('statement', 'NN')]
# True
# True
# **************************************************************************
# (the band, played, a concert)
# [('the', 'DT'), ('band', 'NN')]
# [('a', 'DT'), ('concert', 'NN')]
# True
# True
# **************************************************************************
# (the doctor, examined, the patient)
# [('the', 'DT'), ('doctor', 'NN')]
# [('the', 'DT'), ('patient', 'NN')]
# True
# True
# **************************************************************************
# (the engineer, designed, the bridge)
# [('the', 'DT'), ('engineer', 'NN')]
# [('the', 'DT'), ('bridge', 'NN')]
# True
# True
# **************************************************************************
# (the scientist, conducted, the experiment)
# [('the', 'DT'), ('scientist', 'NN')]
# [('the', 'DT'), ('experiment', 'NN')]
# True
# True
# **************************************************************************
# (the worker, assembled, the machine)
# [('the', 'DT'), ('worker', 'NN')]
# [('the', 'DT'), ('machine', 'NN')]
# True
# True
# **************************************************************************
# (the author, wrote, a novel)
# [('the', 'DT'), ('author', 'NN')]
# [('a', 'DT'), ('novel', 'NN')]
# True
# True
# **************************************************************************
# (the player, scored, a goal)
# [('the', 'DT'), ('player', 'NN')]
# [('a', 'DT'), ('goal', 'NN')]
# True
# True
# **************************************************************************
# (the photographer, took, a picture)
# [('the', 'DT'), ('photographer', 'NN')]
# [('a', 'DT'), ('picture', 'NN')]
# True
# True
# **************************************************************************
# (police officer, arrested, the suspect)
# [('police', 'NNS'), ('officer', 'NN')]
# [('the', 'DT'), ('suspect', 'NN')]
# True
# True
# **************************************************************************
# (the chef, cooked, a meal)
# [('the', 'DT'), ('chef', 'NN')]
# [('a', 'DT'), ('meal', 'NN')]
# True
# True
# **************************************************************************
# (the musician, composed, a song)
# [('the', 'DT'), ('musician', 'NN')]
# [('a', 'DT'), ('song', 'NN')]
# True
# True
# **************************************************************************
# (the designer, created, a website)
# [('the', 'DT'), ('designer', 'NN')]
# [('a', 'DT'), ('website', 'NN')]
# True
# True
# **************************************************************************
# (the athlete, won, the race)
# [('the', 'DT'), ('athlete', 'NN')]
# [('the', 'DT'), ('race', 'NN')]
# True
# True
# **************************************************************************
# (the businessman, made, a deal)
# [('the', 'DT'), ('businessman', 'NN')]
# [('a', 'DT'), ('deal', 'NN')]
# True
# True
# **************************************************************************
# (the driver, drove, the car)
# [('the', 'DT'), ('driver', 'NN')]
# [('the', 'DT'), ('car', 'NN')]
# True
# True
# **************************************************************************
# (the writer, wrote, an article)
# [('the', 'DT'), ('writer', 'NN')]
# [('an', 'DT'), ('article', 'NN')]
# True
# True
# **************************************************************************
# (the teacher, gave, a lecture)
# [('the', 'DT'), ('teacher', 'NN')]
# [('a', 'DT'), ('lecture', 'NN')]
# True
# True
# **************************************************************************
# (the student, studied, the test)
# [('the', 'DT'), ('student', 'NN')]
# [('the', 'DT'), ('test', 'NN')]
# True
# True
# **************************************************************************
# (the company, hired, a new employee)
# [('the', 'DT'), ('company', 'NN')]
# [('a', 'DT'), ('new', 'JJ'), ('employee', 'NN')]
# True
# True
# **************************************************************************
# (the doctor, treated, the illness)
# [('the', 'DT'), ('doctor', 'NN')]
# [('the', 'DT'), ('illness', 'NN')]
# True
# True
# **************************************************************************
# (the artist, sculpted, a statue)
# [('the', 'DT'), ('artist', 'NN')]
# [('a', 'DT'), ('statue', 'NN')]
# True
# True
# **************************************************************************
# (the dog, barked, the stranger)
# [('the', 'DT'), ('dog', 'NN')]
# [('the', 'DT'), ('stranger', 'NN')]
# True
# True
# **************************************************************************
# (the bird, flew, the sky)
# [('the', 'DT'), ('bird', 'NN')]
# [('the', 'DT'), ('sky', 'NN')]
# True
# True
# **************************************************************************
# (the teacher, graded, the quizzes)
# [('the', 'DT'), ('teacher', 'NN')]
# [('the', 'DT'), ('quizzes', 'NN')]
# True
# True
# **************************************************************************
# (the car, broke, the highway)
# [('the', 'DT'), ('car', 'NN')]
# [('the', 'DT'), ('highway', 'NN')]
# True
# True
# **************************************************************************
# (the storm, caused, a flood)
# [('the', 'DT'), ('storm', 'NN')]
# [('a', 'DT'), ('flood', 'NN')]
# True
# True
# **************************************************************************
# (the baby, slept, the night)
# [('the', 'DT'), ('baby', 'NN')]
# [('the', 'DT'), ('night', 'NN')]
# True
# True
# **************************************************************************
# (the cook, prepared, the ingredients)
# [('the', 'DT'), ('cook', 'NN')]
# [('the', 'DT'), ('ingredients', 'NNS')]
# True
# True
# **************************************************************************
# (the student, completed, the assignment)
# [('the', 'DT'), ('student', 'NN')]
# [('the', 'DT'), ('assignment', 'NN')]
# True
# True
# **************************************************************************
# (the company, expanded, its market)
# [('the', 'DT'), ('company', 'NN')]
# [('its', 'PRP$'), ('market', 'NN')]
# True
# True
# **************************************************************************
# (the singer, recorded, an album)
# [('the', 'DT'), ('singer', 'NN')]
# [('an', 'DT'), ('album', 'NN')]
# True
# True
# **************************************************************************
# (the doctor, performed, surgery)
# [('the', 'DT'), ('doctor', 'NN')]
# [('surgery', 'NN')]
# True
# True
# **************************************************************************
# (the farmer, tended, the animals)
# [('the', 'DT'), ('farmer', 'NN')]
# [('the', 'DT'), ('animals', 'NNS')]
# True
# True
# **************************************************************************
# (the artist, drew, a portrait)
# [('the', 'DT'), ('artist', 'NN')]
# [('a', 'DT'), ('portrait', 'NN')]
# True
# True
# **************************************************************************
# (the dog, fetched, the ball)
# [('the', 'DT'), ('dog', 'NN')]
# [('the', 'DT'), ('ball', 'NN')]
# True
# True
# **************************************************************************
# (the bird, sang, a melody)
# [('the', 'DT'), ('bird', 'NN')]
# [('a', 'DT'), ('melody', 'NN')]
# True
# True
# **************************************************************************
# (the teacher, taught, a class)
# [('the', 'DT'), ('teacher', 'NN')]
# [('a', 'DT'), ('class', 'NN')]
# True
# True
# **************************************************************************
# (the child, learned, to read)
# [('the', 'DT'), ('child', 'NN')]
# [('to', 'TO'), ('read', 'VB')]
# True
# False
# **************************************************************************
# (the company, released, an update)
# [('the', 'DT'), ('company', 'NN')]
# [('an', 'DT'), ('update', 'NN')]
# True
# True
# **************************************************************************
# (the band, played, a gig)
# [('the', 'DT'), ('band', 'NN')]
# [('a', 'DT'), ('gig', 'NN')]
# True
# True
# **************************************************************************
# (the doctor, diagnosed, the illness)
# [('the', 'DT'), ('doctor', 'NN')]
# [('the', 'DT'), ('illness', 'NN')]
# True
# True
# **************************************************************************
# (the engineer, constructed, the building)
# [('the', 'DT'), ('engineer', 'NN')]
# [('the', 'DT'), ('building', 'NN')]
# True
# True
# **************************************************************************
# (the scientist, discovered, a new element)
# [('the', 'DT'), ('scientist', 'NN')]
# [('a', 'DT'), ('new', 'JJ'), ('element', 'NN')]
# True
# True
# **************************************************************************
# (the worker, repaired, the equipment)
# [('the', 'DT'), ('worker', 'NN')]
# [('the', 'DT'), ('equipment', 'NN')]
# True
# True
# **************************************************************************
# (the author, wrote, a short story)
# [('the', 'DT'), ('author', 'NN')]
# [('a', 'DT'), ('short', 'JJ'), ('story', 'NN')]
# True
# True
# **************************************************************************
# (the player, made, a save)
# [('the', 'DT'), ('player', 'NN')]
# [('a', 'DT'), ('save', 'NN')]
# True
# True
# **************************************************************************
# (the photographer, captured, a moment)
# [('the', 'DT'), ('photographer', 'NN')]
# [('a', 'DT'), ('moment', 'NN')]
# True
# True
# **************************************************************************
# (police officer, investigated, the crime)
# [('police', 'NNS'), ('officer', 'NN')]
# [('the', 'DT'), ('crime', 'NN')]
# True
# True
# **************************************************************************
# (the chef, served, the meal)
# [('the', 'DT'), ('chef', 'NN')]
# [('the', 'DT'), ('meal', 'NN')]
# True
# True
# **************************************************************************
# (the musician, played, an instrument)
# [('the', 'DT'), ('musician', 'NN')]
# [('an', 'DT'), ('instrument', 'NN')]
# True
# True
# **************************************************************************
# (the designer, created, a logo)
# [('the', 'DT'), ('designer', 'NN')]
# [('a', 'DT'), ('logo', 'NN')]
# True
# True
# **************************************************************************
# (the athlete, trained, the competition)
# [('the', 'DT'), ('athlete', 'NN')]
# [('the', 'DT'), ('competition', 'NN')]
# True
# True
# **************************************************************************
# (the businessman, closed, the deal)
# [('the', 'DT'), ('businessman', 'NN')]
# [('the', 'DT'), ('deal', 'NN')]
# True
# True
# **************************************************************************
# (the driver, followed, the map)
# [('the', 'DT'), ('driver', 'NN')]
# [('the', 'DT'), ('map', 'NN')]
# True
# True
# **************************************************************************
# (the writer, wrote, a story)
# [('the', 'DT'), ('writer', 'NN')]
# [('a', 'DT'), ('story', 'NN')]
# True
# True
# **************************************************************************
# (the teacher, gave, a presentation)
# [('the', 'DT'), ('teacher', 'NN')]
# [('a', 'DT'), ('presentation', 'NN')]
# True
# True
# **************************************************************************
# (the student, reviewed, the material)
# [('the', 'DT'), ('student', 'NN')]
# [('the', 'DT'), ('material', 'NN')]
# True
# True
# **************************************************************************
# (zulfikar ali bhutto, launched, nuclear program)
# [('zulfikar', 'NN'), ('ali', 'NN'), ('bhutto', 'NN')]
# [('nuclear', 'JJ'), ('program', 'NN')]
# True
# True
# **************************************************************************
# (nuclear program, declared, pakistan's commitment)
# [('nuclear', 'JJ'), ('program', 'NN')]
# [('pakistan', 'NN'), ("'s", 'POS'), ('commitment', 'NN')]
# True
# True
# **************************************************************************
# (nuclear program, declared, pakistan's dedication)
# [('nuclear', 'JJ'), ('program', 'NN')]
# [('pakistan', 'NN'), ("'s", 'POS'), ('dedication', 'NN')]
# True
# True
# **************************************************************************
# (aq khan, developed, nuclear bomb)
# [('aq', 'NNS'), ('khan', 'VBP')]
# [('nuclear', 'JJ'), ('bomb', 'NN')]
# True
# True
# **************************************************************************
# (nuclear bomb, strengthened, pakistan)
# [('nuclear', 'JJ'), ('bomb', 'NN')]
# [('pakistan', 'NN')]
# True
# True
# **************************************************************************
# (nuclear bomb, makes, nuclear power)
# [('nuclear', 'JJ'), ('bomb', 'NN')]
# [('nuclear', 'JJ'), ('power', 'NN')]
# True
# True
# **************************************************************************
# (pakistan, must never surrender, nuclear bomb)
# [('pakistan', 'NN')]
# [('nuclear', 'JJ'), ('bomb', 'NN')]
# True
# True
# **************************************************************************
# (pakistan, must fight, existential threats)
# [('pakistan', 'NN')]
# [('existential', 'JJ'), ('threats', 'NNS')]
# True
# True
# **************************************************************************
# (pakistan, must support, army)
# [('pakistan', 'NN')]
# [('army', 'NN')]
# True
# True
# **************************************************************************
# (pakistan, must support, aq khan)
# [('pakistan', 'NN')]
# [('aq', 'NNS'), ('khan', 'VBP')]
# True
# True
# **************************************************************************
# (army, provides, vigilance)
# [('army', 'NN')]
# [('vigilance', 'NN')]
# True
# True
# **************************************************************************
# (vigilance, strengthened, national survival)
# [('vigilance', 'NN')]
# [('national', 'JJ'), ('survival', 'NN')]
# True
# True
# **************************************************************************
# (institutional weakness, hindered, development)
# [('institutional', 'JJ'), ('weakness', 'NN')]
# [('development', 'NN')]
# True
# True
# **************************************************************************
# (institutional weakness, hindered, the agriculture sector)
# [('institutional', 'JJ'), ('weakness', 'NN')]
# [('the', 'DT'), ('agriculture', 'NN'), ('sector', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, production)
# [('conflict', 'NN')]
# [('production', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, farmers)
# [('conflict', 'NN')]
# [('farmers', 'NNS')]
# True
# True
# **************************************************************************
# (conflict, discourages, traders)
# [('conflict', 'NN')]
# [('traders', 'NNS')]
# True
# True
# **************************************************************************
# (conflict, discourages, marketing infrastructure)
# [('conflict', 'NN')]
# [('marketing', 'NN'), ('infrastructure', 'NN')]
# True
# True
# **************************************************************************
# (conflict, discourages, retailers)
# [('conflict', 'NN')]
# [('retailers', 'NNS')]
# True
# True
# **************************************************************************
# (no irrigation infrastructure, shows, public investment)
# [('no', 'DT'), ('irrigation', 'NN'), ('infrastructure', 'NN')]
# [('public', 'JJ'), ('investment', 'NN')]
# True
# True
# **************************************************************************
# (the low level, shows, public investment)
# [('the', 'DT'), ('low', 'JJ'), ('level', 'NN')]
# [('public', 'JJ'), ('investment', 'NN')]
# True
# True
# **************************************************************************
# (the low level, shows, no irrigation infrastructure)
# [('the', 'DT'), ('low', 'JJ'), ('level', 'NN')]
# [('no', 'DT'), ('irrigation', 'NN'), ('infrastructure', 'NN')]
# True
# True
# **************************************************************************
# (south sudan's limited road network, shows, only 2 percent)
# [('south', 'JJ'), ('sudan', 'NN'), ("'s", 'POS'), ('limited', 'JJ'), ('road', 'NN'), ('network', 'NN')]
# [('only', 'RB'), ('2', 'CD'), ('percent', 'NN')]
# True
# True
# **************************************************************************
# (inadequate transportation infrastructure, resulted, markets)
# [('inadequate', 'JJ'), ('transportation', 'NN'), ('infrastructure', 'NN')]
# [('markets', 'NNS')]
# True
# True
# **************************************************************************
# (inadequate transportation infrastructure, resulted, less transport)
# [('inadequate', 'JJ'), ('transportation', 'NN'), ('infrastructure', 'NN')]
# [('less', 'RBR'), ('transport', 'NN')]
# True
# True
# **************************************************************************
# (persistent heavy rains, cause, flooding)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flooding', 'VBG')]
# True
# False
# **************************************************************************
# (persistent heavy rains, cause, the eastern sudan)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('the', 'DT'), ('eastern', 'JJ'), ('sudan', 'NN')]
# True
# True
# **************************************************************************
# (persistent heavy rains, cause, flood-prone areas)
# [('persistent', 'JJ'), ('heavy', 'JJ'), ('rains', 'NNS')]
# [('flood-prone', 'JJ'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (highly saturated soils, cause, flood-prone areas)
# [('highly', 'RB'), ('saturated', 'VBN'), ('soils', 'NNS')]
# [('flood-prone', 'JJ'), ('areas', 'NNS')]
# True
# True
# **************************************************************************
# (rain, caused, floods)
# [('rain', 'NN')]
# [('floods', 'NNS')]
# True
# True
# **************************************************************************
# (floods, have displaced, more than 100,000 people)
# [('floods', 'NNS')]
# [('more', 'JJR'), ('than', 'IN'), ('100,000', 'CD'), ('people', 'NNS')]
# True
# True
# **************************************************************************
# (floods, have displaced, south sudan)
# [('floods', 'NNS')]
# [('south', 'JJ'), ('sudan', 'NN')]
# True
# True
# **************************************************************************
# (floods, raise, fears)
# [('floods', 'NNS')]
# [('fears', 'NNS')]
# True
# True
# **************************************************************************
# (highly saturated soils, impact, the war-torn nation)
# [('highly', 'RB'), ('saturated', 'VBN'), ('soils', 'NNS')]
# [('the', 'DT'), ('war-torn', 'JJ'), ('nation', 'NN')]
# True
# True
# **************************************************************************
# (floods devastatingly impact, impact, food security)
# [('floods', 'NNS'), ('devastatingly', 'RB'), ('impact', 'VBP')]
# [('food', 'NN'), ('security', 'NN')]
# True
# True
# **************************************************************************
# (floods devastatingly impact, impact, the war-torn nation)
# [('floods', 'NNS'), ('devastatingly', 'RB'), ('impact', 'VBP')]
# [('the', 'DT'), ('war-torn', 'JJ'), ('nation', 'NN')]
# True
# True
# **************************************************************************
# (excessive overthinking, leads, insomnia)
# [('excessive', 'JJ'), ('overthinking', 'NN')]
# [('insomnia', 'NN')]
# True
# True
# **************************************************************************
# (stress, caused, insomnia)
# [('stress', 'NN')]
# [('insomnia', 'NN')]
# True
# True
# **************************************************************************
# (insomnia, causes, stress)
# [('insomnia', 'NN')]
# [('stress', 'NN')]
# True
# True
# **************************************************************************
# (excessive overthinking, results, insomnia)
# [('excessive', 'JJ'), ('overthinking', 'NN')]
# [('insomnia', 'NN')]
# True
# True
# **************************************************************************
# (the rain, caused, flowers)
# (the sun, rises, the east)
# (the wind, blew, the leaves)
# (the dog, bit, the mailman)
# (the boy, kicked, the ball)
# (the girl, sang, a song)
# (the teacher, graded, the papers)
# (the car, hit, the tree)
# (the storm, knocked, power lines)
# (the baby, cried, milk)
# (the cook, made, dinner)
# (the student, passed, the exam)
# (the company, launched, a new product)
# (the singer, performed, stage)
# (the singer, medicine, stage)
# (the farmer, harvested, the crops)
# (the artist, painted, a picture)
# (the dog, chased, the cat)
# (the bird, built, a nest)
# (the teacher, taught, the lesson)
# (the child, played, the toy)
# (the company, released, a statement)
# (the band, played, a concert)
# (the doctor, examined, the patient)
# (the engineer, designed, the bridge)
# (the scientist, conducted, the experiment)
# (the worker, assembled, the machine)
# (the author, wrote, a novel)
# (the player, scored, a goal)
# (the photographer, took, a picture)
# (police officer, arrested, the suspect)
# (the chef, cooked, a meal)
# (the musician, composed, a song)
# (the designer, created, a website)
# (the athlete, won, the race)
# (the businessman, made, a deal)
# (the driver, drove, the car)
# (the writer, wrote, an article)
# (the teacher, gave, a lecture)
# (the student, studied, the test)
# (the company, hired, a new employee)
# (the doctor, treated, the illness)
# (the artist, sculpted, a statue)
# (the dog, barked, the stranger)
# (the bird, flew, the sky)
# (the teacher, graded, the quizzes)
# (the car, broke, the highway)
# (the storm, caused, a flood)
# (the baby, slept, the night)
# (the cook, prepared, the ingredients)
# (the student, completed, the assignment)
# (the company, expanded, its market)
# (the singer, recorded, an album)
# (the doctor, performed, surgery)
# (the farmer, tended, the animals)
# (the artist, drew, a portrait)
# (the dog, fetched, the ball)
# (the bird, sang, a melody)
# (the teacher, taught, a class)
# (the company, released, an update)
# (the band, played, a gig)
# (the doctor, diagnosed, the illness)
# (the engineer, constructed, the building)
# (the scientist, discovered, a new element)
# (the worker, repaired, the equipment)
# (the author, wrote, a short story)
# (the player, made, a save)
# (the photographer, captured, a moment)
# (police officer, investigated, the crime)
# (the chef, served, the meal)
# (the musician, played, an instrument)
# (the designer, created, a logo)
# (the athlete, trained, the competition)
# (the businessman, closed, the deal)
# (the driver, followed, the map)
# (the writer, wrote, a story)
# (the teacher, gave, a presentation)
# (the student, reviewed, the material)
# (zulfikar ali bhutto, launched, nuclear program)
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# (aq khan, developed, nuclear bomb)
# (nuclear bomb, strengthened, pakistan)
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, provides, vigilance)
# (vigilance, strengthened, national survival)
# (institutional weakness, hindered, development)
# (institutional weakness, hindered, the agriculture sector)
# (conflict, discourages, production)
# (conflict, discourages, farmers)
# (conflict, discourages, traders)
# (conflict, discourages, marketing infrastructure)
# (conflict, discourages, retailers)
# (no irrigation infrastructure, shows, public investment)
# (the low level, shows, public investment)
# (the low level, shows, no irrigation infrastructure)
# (south sudan's limited road network, shows, only 2 percent)
# (inadequate transportation infrastructure, resulted, markets)
# (inadequate transportation infrastructure, resulted, less transport)
# (persistent heavy rains, cause, the eastern sudan)
# (persistent heavy rains, cause, flood-prone areas)
# (highly saturated soils, cause, flood-prone areas)
# (rain, caused, floods)
# (floods, have displaced, more than 100,000 people)
# (floods, have displaced, south sudan)
# (floods, raise, fears)
# (highly saturated soils, impact, the war-torn nation)
# (floods devastatingly impact, impact, food security)
# (floods devastatingly impact, impact, the war-torn nation)
# (excessive overthinking, leads, insomnia)
# (stress, caused, insomnia)
# (insomnia, causes, stress)
# (excessive overthinking, results, insomnia)
# 117

# %%
for sentence, triple  in zip(causalSentences, causalTriples):
    print(sentence, triple)
    print()
# Out:
# the rain caused wilting of flowers. (the rain, caused, flowers)
#
# the sun rises in the east. (the sun, rises, the east)
#
# the wind blew the leaves. (the wind, blew, the leaves)
#
# the dog bit the mailman. (the dog, bit, the mailman)
#
# the boy kicked the ball. (the boy, kicked, the ball)
#
# the girl sang a song. (the girl, sang, a song)
#
# the teacher graded the papers. (the teacher, graded, the papers)
#
# the car hit the tree. (the car, hit, the tree)
#
# the storm knocked down the power lines. (the storm, knocked, power lines)
#
# the baby cried for milk. (the baby, cried, milk)
#
# the cook made dinner. (the cook, made, dinner)
#
# the student passed the exam. (the student, passed, the exam)
#
# the company launched a new product. (the company, launched, a new product)
#
# the singer performed on stage. (the singer, performed, stage)
#
# the doctor prescribed medicine. (the singer, medicine, stage)
#
# the farmer harvested the crops. (the farmer, harvested, the crops)
#
# the artist painted a picture. (the artist, painted, a picture)
#
# the dog chased the cat. (the dog, chased, the cat)
#
# the bird built a nest. (the bird, built, a nest)
#
# the teacher taught the lesson. (the teacher, taught, the lesson)
#
# the child played with the toy. (the child, played, the toy)
#
# the company released a statement. (the company, released, a statement)
#
# the band played a concert. (the band, played, a concert)
#
# the doctor examined the patient. (the doctor, examined, the patient)
#
# the engineer designed the bridge. (the engineer, designed, the bridge)
#
# the scientist conducted the experiment. (the scientist, conducted, the experiment)
#
# the worker assembled the machine. (the worker, assembled, the machine)
#
# the author wrote a novel. (the author, wrote, a novel)
#
# the player scored a goal. (the player, scored, a goal)
#
# the photographer took a picture. (the photographer, took, a picture)
#
# the police officer arrested the suspect. (police officer, arrested, the suspect)
#
# the chef cooked a meal. (the chef, cooked, a meal)
#
# the musician composed a song. (the musician, composed, a song)
#
# the designer created a website. (the designer, created, a website)
#
# the athlete won the race. (the athlete, won, the race)
#
# the businessman made a deal. (the businessman, made, a deal)
#
# the driver drove the car. (the driver, drove, the car)
#
# the writer wrote an article. (the writer, wrote, an article)
#
# the teacher gave a lecture. (the teacher, gave, a lecture)
#
# the student studied for the test. (the student, studied, the test)
#
# the company hired a new employee. (the company, hired, a new employee)
#
# the doctor treated the illness. (the doctor, treated, the illness)
#
# the artist sculpted a statue. (the artist, sculpted, a statue)
#
# the dog barked at the stranger. (the dog, barked, the stranger)
#
# the bird flew in the sky. (the bird, flew, the sky)
#
# the teacher graded the quizzes. (the teacher, graded, the quizzes)
#
# the car broke down on the highway. (the car, broke, the highway)
#
# the storm caused a flood. (the storm, caused, a flood)
#
# the baby slept through the night. (the baby, slept, the night)
#
# the cook prepared the ingredients. (the cook, prepared, the ingredients)
#
# the student completed the assignment. (the student, completed, the assignment)
#
# the company expanded its market. (the company, expanded, its market)
#
# the singer recorded an album. (the singer, recorded, an album)
#
# the doctor performed surgery. (the doctor, performed, surgery)
#
# the farmer tended to the animals. (the farmer, tended, the animals)
#
# the artist drew a portrait. (the artist, drew, a portrait)
#
# the dog fetched the ball. (the dog, fetched, the ball)
#
# the bird sang a melody. (the bird, sang, a melody)
#
# the teacher taught a class. (the teacher, taught, a class)
#
# the company released an update. (the company, released, an update)
#
# the band played a gig. (the band, played, a gig)
#
# the doctor diagnosed the illness. (the doctor, diagnosed, the illness)
#
# the engineer constructed the building. (the engineer, constructed, the building)
#
# the scientist discovered a new element. (the scientist, discovered, a new element)
#
# the worker repaired the equipment. (the worker, repaired, the equipment)
#
# the author wrote a short story. (the author, wrote, a short story)
#
# the player made a save. (the player, made, a save)
#
# the photographer captured a moment. (the photographer, captured, a moment)
#
# the police officer investigated the crime. (police officer, investigated, the crime)
#
# the chef served the meal. (the chef, served, the meal)
#
# the musician played an instrument. (the musician, played, an instrument)
#
# the designer created a logo. (the designer, created, a logo)
#
# the athlete trained for the competition. (the athlete, trained, the competition)
#
# the businessman closed the deal. (the businessman, closed, the deal)
#
# the driver followed the map. (the driver, followed, the map)
#
# the writer wrote a story. (the writer, wrote, a story)
#
# the teacher gave a presentation. (the teacher, gave, a presentation)
#
# the student reviewed the material. (the student, reviewed, the material)
#
# zulfikar ali bhutto launched nuclear program. (zulfikar ali bhutto, launched, nuclear program)
#
# nuclear program declared pakistan's commitment and pakistan's dedication. (nuclear program, declared, pakistan's commitment)
#
# nuclear program declared pakistan's commitment and pakistan's dedication. (nuclear program, declared, pakistan's dedication)
#
# aq khan developed nuclear bomb. (aq khan, developed, nuclear bomb)
#
# nuclear bomb strengthened pakistan. (nuclear bomb, strengthened, pakistan)
#
# nuclear bomb makes nuclear power. (nuclear bomb, makes, nuclear power)
#
# pakistan must never surrender nuclear bomb. (pakistan, must never surrender, nuclear bomb)
#
# pakistan must fight off existential threats. (pakistan, must fight, existential threats)
#
# pakistan must support army and aq khan. (pakistan, must support, army)
#
# pakistan must support army and aq khan. (pakistan, must support, aq khan)
#
# army provides vigilance. (army, provides, vigilance)
#
# vigilance strengthened national survival. (vigilance, strengthened, national survival)
#
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, development)
#
# institutional weakness hindered development of the agriculture sector. (institutional weakness, hindered, the agriculture sector)
#
# conflict discourages farmers from expanding production. (conflict, discourages, production)
#
# conflict discourages farmers from expanding production. (conflict, discourages, farmers)
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, traders)
#
# conflict discourages traders from building marketing infrastructure. (conflict, discourages, marketing infrastructure)
#
# conflict discourages retailers from building marketing infrastructure. (conflict, discourages, retailers)
#
# the low level of public investment shows that no irrigation infrastructure exists. (no irrigation infrastructure, shows, public investment)
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, public investment)
#
# the low level of public investment shows that no irrigation infrastructure exists. (the low level, shows, no irrigation infrastructure)
#
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved. (south sudan's limited road network, shows, only 2 percent)
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, markets)
#
# inadequate transportation infrastructure has resulted in less transport to markets. (inadequate transportation infrastructure, resulted, less transport)
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, the eastern sudan)
#
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas. (persistent heavy rains, cause, flood-prone areas)
#
# highly saturated soils cause flooding in flood-prone areas. (highly saturated soils, cause, flood-prone areas)
#
# rain caused floods. (rain, caused, floods)
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, more than 100,000 people)
#
# floods have displaced more than 100,000 people in south sudan's. (floods, have displaced, south sudan)
#
# floods raise fears. (floods, raise, fears)
#
# floods devastatingly impact on food security in the war-torn nation. (highly saturated soils, impact, the war-torn nation)
#
# floods devastatingly impact on food security in the war-torn nation. (floods devastatingly impact, impact, food security)
#
# floods devastatingly impact on food security in the war-torn nation. (floods devastatingly impact, impact, the war-torn nation)
#
# excessive overthinking leads to insomnia. (excessive overthinking, leads, insomnia)
#
# stress caused insomnia. (stress, caused, insomnia)
#
# insomnia causes stress. (insomnia, causes, stress)
#
# stress results in insomnia. (excessive overthinking, results, insomnia)

# %%
#causalSentences = list(dict.fromkeys(causalSentences))
#causalSentences = list(set(causalSentences))
print("List before removing duplicates:")
print(len(causalSentences))

for t in causalSentences:
    print(t)
    
causalSentencesNoDup = []

for ce in causalSentences:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalSentencesNoDup) == 0:
        #print("HEY!")
        causalSentencesNoDup.append(ce)
        #print("added!")
    else:
        for ct in causalSentencesNoDup:
            #print("ct:")
            #print(ct)
            if str(ce) == str(ct):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalSentencesNoDup.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalSentencesNoDup))

for t in causalSentencesNoDup:
    print(t)
# Out:
# List before removing duplicates:
# 117
# the rain caused wilting of flowers.
# the sun rises in the east.
# the wind blew the leaves.
# the dog bit the mailman.
# the boy kicked the ball.
# the girl sang a song.
# the teacher graded the papers.
# the car hit the tree.
# the storm knocked down the power lines.
# the baby cried for milk.
# the cook made dinner.
# the student passed the exam.
# the company launched a new product.
# the singer performed on stage.
# the doctor prescribed medicine.
# the farmer harvested the crops.
# the artist painted a picture.
# the dog chased the cat.
# the bird built a nest.
# the teacher taught the lesson.
# the child played with the toy.
# the company released a statement.
# the band played a concert.
# the doctor examined the patient.
# the engineer designed the bridge.
# the scientist conducted the experiment.
# the worker assembled the machine.
# the author wrote a novel.
# the player scored a goal.
# the photographer took a picture.
# the police officer arrested the suspect.
# the chef cooked a meal.
# the musician composed a song.
# the designer created a website.
# the athlete won the race.
# the businessman made a deal.
# the driver drove the car.
# the writer wrote an article.
# the teacher gave a lecture.
# the student studied for the test.
# the company hired a new employee.
# the doctor treated the illness.
# the artist sculpted a statue.
# the dog barked at the stranger.
# the bird flew in the sky.
# the teacher graded the quizzes.
# the car broke down on the highway.
# the storm caused a flood.
# the baby slept through the night.
# the cook prepared the ingredients.
# the student completed the assignment.
# the company expanded its market.
# the singer recorded an album.
# the doctor performed surgery.
# the farmer tended to the animals.
# the artist drew a portrait.
# the dog fetched the ball.
# the bird sang a melody.
# the teacher taught a class.
# the company released an update.
# the band played a gig.
# the doctor diagnosed the illness.
# the engineer constructed the building.
# the scientist discovered a new element.
# the worker repaired the equipment.
# the author wrote a short story.
# the player made a save.
# the photographer captured a moment.
# the police officer investigated the crime.
# the chef served the meal.
# the musician played an instrument.
# the designer created a logo.
# the athlete trained for the competition.
# the businessman closed the deal.
# the driver followed the map.
# the writer wrote a story.
# the teacher gave a presentation.
# the student reviewed the material.
# zulfikar ali bhutto launched nuclear program.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# aq khan developed nuclear bomb.
# nuclear bomb strengthened pakistan.
# nuclear bomb makes nuclear power.
# pakistan must never surrender nuclear bomb.
# pakistan must fight off existential threats.
# pakistan must support army and aq khan.
# pakistan must support army and aq khan.
# army provides vigilance.
# vigilance strengthened national survival.
# institutional weakness hindered development of the agriculture sector.
# institutional weakness hindered development of the agriculture sector.
# conflict discourages farmers from expanding production.
# conflict discourages farmers from expanding production.
# conflict discourages traders from building marketing infrastructure.
# conflict discourages traders from building marketing infrastructure.
# conflict discourages retailers from building marketing infrastructure.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# inadequate transportation infrastructure has resulted in less transport to markets.
# inadequate transportation infrastructure has resulted in less transport to markets.
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan's.
# floods have displaced more than 100,000 people in south sudan's.
# floods raise fears.
# floods devastatingly impact on food security in the war-torn nation.
# floods devastatingly impact on food security in the war-torn nation.
# floods devastatingly impact on food security in the war-torn nation.
# excessive overthinking leads to insomnia.
# stress caused insomnia.
# insomnia causes stress.
# stress results in insomnia.
#
# List after removing duplicates:
# 105
# the rain caused wilting of flowers.
# the sun rises in the east.
# the wind blew the leaves.
# the dog bit the mailman.
# the boy kicked the ball.
# the girl sang a song.
# the teacher graded the papers.
# the car hit the tree.
# the storm knocked down the power lines.
# the baby cried for milk.
# the cook made dinner.
# the student passed the exam.
# the company launched a new product.
# the singer performed on stage.
# the doctor prescribed medicine.
# the farmer harvested the crops.
# the artist painted a picture.
# the dog chased the cat.
# the bird built a nest.
# the teacher taught the lesson.
# the child played with the toy.
# the company released a statement.
# the band played a concert.
# the doctor examined the patient.
# the engineer designed the bridge.
# the scientist conducted the experiment.
# the worker assembled the machine.
# the author wrote a novel.
# the player scored a goal.
# the photographer took a picture.
# the police officer arrested the suspect.
# the chef cooked a meal.
# the musician composed a song.
# the designer created a website.
# the athlete won the race.
# the businessman made a deal.
# the driver drove the car.
# the writer wrote an article.
# the teacher gave a lecture.
# the student studied for the test.
# the company hired a new employee.
# the doctor treated the illness.
# the artist sculpted a statue.
# the dog barked at the stranger.
# the bird flew in the sky.
# the teacher graded the quizzes.
# the car broke down on the highway.
# the storm caused a flood.
# the baby slept through the night.
# the cook prepared the ingredients.
# the student completed the assignment.
# the company expanded its market.
# the singer recorded an album.
# the doctor performed surgery.
# the farmer tended to the animals.
# the artist drew a portrait.
# the dog fetched the ball.
# the bird sang a melody.
# the teacher taught a class.
# the company released an update.
# the band played a gig.
# the doctor diagnosed the illness.
# the engineer constructed the building.
# the scientist discovered a new element.
# the worker repaired the equipment.
# the author wrote a short story.
# the player made a save.
# the photographer captured a moment.
# the police officer investigated the crime.
# the chef served the meal.
# the musician played an instrument.
# the designer created a logo.
# the athlete trained for the competition.
# the businessman closed the deal.
# the driver followed the map.
# the writer wrote a story.
# the teacher gave a presentation.
# the student reviewed the material.
# zulfikar ali bhutto launched nuclear program.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# aq khan developed nuclear bomb.
# nuclear bomb strengthened pakistan.
# nuclear bomb makes nuclear power.
# pakistan must never surrender nuclear bomb.
# pakistan must fight off existential threats.
# pakistan must support army and aq khan.
# army provides vigilance.
# vigilance strengthened national survival.
# institutional weakness hindered development of the agriculture sector.
# conflict discourages farmers from expanding production.
# conflict discourages traders from building marketing infrastructure.
# conflict discourages retailers from building marketing infrastructure.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# inadequate transportation infrastructure has resulted in less transport to markets.
# persistent heavy rains in the eastern sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan's.
# floods raise fears.
# floods devastatingly impact on food security in the war-torn nation.
# excessive overthinking leads to insomnia.
# stress caused insomnia.
# insomnia causes stress.
# stress results in insomnia.

# %%
allen = []
for sent in causalTriples:
    #print(sent)
    preds = predictor1.predict(str(sent))
    #print(preds['label'][0])
    label = preds['label'][0]
    if label is '0':
        allen.append(-1)
    else:
        allen.append(1)
    
for causalSentence, polarity  in zip(causalTriples, allen):
    print(causalSentence, polarity)
# Out:
# (the rain, caused, flowers) 1
# (the sun, rises, the east) 1
# (the wind, blew, the leaves) 1
# (the dog, bit, the mailman) -1
# (the boy, kicked, the ball) -1
# (the girl, sang, a song) 1
# (the teacher, graded, the papers) -1
# (the car, hit, the tree) -1
# (the storm, knocked, power lines) -1
# (the baby, cried, milk) -1
# (the cook, made, dinner) 1
# (the student, passed, the exam) 1
# (the company, launched, a new product) 1
# (the singer, performed, stage) 1
# (the singer, medicine, stage) 1
# (the farmer, harvested, the crops) 1
# (the artist, painted, a picture) 1
# (the dog, chased, the cat) -1
# (the bird, built, a nest) 1
# (the teacher, taught, the lesson) 1
# (the child, played, the toy) 1
# (the company, released, a statement) -1
# (the band, played, a concert) 1
# (the doctor, examined, the patient) 1
# (the engineer, designed, the bridge) 1
# (the scientist, conducted, the experiment) 1
# (the worker, assembled, the machine) -1
# (the author, wrote, a novel) 1
# (the player, scored, a goal) 1
# (the photographer, took, a picture) -1
# (police officer, arrested, the suspect) -1
# (the chef, cooked, a meal) 1
# (the musician, composed, a song) 1
# (the designer, created, a website) -1
# (the athlete, won, the race) 1
# (the businessman, made, a deal) -1
# (the driver, drove, the car) 1
# (the writer, wrote, an article) -1
# (the teacher, gave, a lecture) -1
# (the student, studied, the test) 1
# (the company, hired, a new employee) 1
# (the doctor, treated, the illness) -1
# (the artist, sculpted, a statue) 1
# (the dog, barked, the stranger) -1
# (the bird, flew, the sky) 1
# (the teacher, graded, the quizzes) -1
# (the car, broke, the highway) -1
# (the storm, caused, a flood) -1
# (the baby, slept, the night) -1
# (the cook, prepared, the ingredients) 1
# (the student, completed, the assignment) 1
# (the company, expanded, its market) 1
# (the singer, recorded, an album) 1
# (the doctor, performed, surgery) -1
# (the farmer, tended, the animals) 1
# (the artist, drew, a portrait) 1
# (the dog, fetched, the ball) 1
# (the bird, sang, a melody) 1
# (the teacher, taught, a class) 1
# (the company, released, an update) 1
# (the band, played, a gig) -1
# (the doctor, diagnosed, the illness) -1
# (the engineer, constructed, the building) 1
# (the scientist, discovered, a new element) 1
# (the worker, repaired, the equipment) 1
# (the author, wrote, a short story) 1
# (the player, made, a save) 1
# (the photographer, captured, a moment) 1
# (police officer, investigated, the crime) -1
# (the chef, served, the meal) 1
# (the musician, played, an instrument) 1
# (the designer, created, a logo) 1
# (the athlete, trained, the competition) 1
# (the businessman, closed, the deal) 1
# (the driver, followed, the map) -1
# (the writer, wrote, a story) 1
# (the teacher, gave, a presentation) 1
# (the student, reviewed, the material) 1
# (zulfikar ali bhutto, launched, nuclear program) -1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) 1
# (pakistan, must never surrender, nuclear bomb) 1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 1
# (vigilance, strengthened, national survival) 1
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, production) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, the eastern sudan) -1
# (persistent heavy rains, cause, flood-prone areas) -1
# (highly saturated soils, cause, flood-prone areas) -1
# (rain, caused, floods) -1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (highly saturated soils, impact, the war-torn nation) 1
# (floods devastatingly impact, impact, food security) -1
# (floods devastatingly impact, impact, the war-torn nation) -1
# (excessive overthinking, leads, insomnia) -1
# (stress, caused, insomnia) -1
# (insomnia, causes, stress) -1
# (excessive overthinking, results, insomnia) -1

# %%
from afinn import Afinn
afn = Afinn()

afinn = []
for sent in causalTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    #print(score)
    if score > 0:
        #print('positive')
        afinn.append(1)
    elif score < 0:
        #print('negative')
        afinn.append(-1)
    else:
        #print('neutral')
        afinn.append(0)
        
for causalSentence, polarity  in zip(causalTriples, afinn):
    print(causalSentence, polarity)
# Out:
# (the rain, caused, flowers) 0
# (the sun, rises, the east) 1
# (the wind, blew, the leaves) 0
# (the dog, bit, the mailman) 0
# (the boy, kicked, the ball) 0
# (the girl, sang, a song) 0
# (the teacher, graded, the papers) 0
# (the car, hit, the tree) 0
# (the storm, knocked, power lines) 0
# (the baby, cried, milk) -1
# (the cook, made, dinner) 0
# (the student, passed, the exam) 0
# (the company, launched, a new product) 1
# (the singer, performed, stage) 0
# (the singer, medicine, stage) 0
# (the farmer, harvested, the crops) 0
# (the artist, painted, a picture) 0
# (the dog, chased, the cat) 0
# (the bird, built, a nest) 0
# (the teacher, taught, the lesson) 0
# (the child, played, the toy) 0
# (the company, released, a statement) 0
# (the band, played, a concert) 0
# (the doctor, examined, the patient) 0
# (the engineer, designed, the bridge) 0
# (the scientist, conducted, the experiment) 0
# (the worker, assembled, the machine) 0
# (the author, wrote, a novel) 1
# (the player, scored, a goal) 0
# (the photographer, took, a picture) 0
# (police officer, arrested, the suspect) -1
# (the chef, cooked, a meal) 0
# (the musician, composed, a song) 0
# (the designer, created, a website) 0
# (the athlete, won, the race) 1
# (the businessman, made, a deal) 0
# (the driver, drove, the car) 0
# (the writer, wrote, an article) 0
# (the teacher, gave, a lecture) 0
# (the student, studied, the test) 0
# (the company, hired, a new employee) 0
# (the doctor, treated, the illness) -1
# (the artist, sculpted, a statue) 0
# (the dog, barked, the stranger) 0
# (the bird, flew, the sky) 0
# (the teacher, graded, the quizzes) 0
# (the car, broke, the highway) -1
# (the storm, caused, a flood) 0
# (the baby, slept, the night) 0
# (the cook, prepared, the ingredients) 1
# (the student, completed, the assignment) 0
# (the company, expanded, its market) 0
# (the singer, recorded, an album) 0
# (the doctor, performed, surgery) 0
# (the farmer, tended, the animals) 0
# (the artist, drew, a portrait) 0
# (the dog, fetched, the ball) 0
# (the bird, sang, a melody) 0
# (the teacher, taught, a class) 0
# (the company, released, an update) 0
# (the band, played, a gig) 0
# (the doctor, diagnosed, the illness) -1
# (the engineer, constructed, the building) 0
# (the scientist, discovered, a new element) 0
# (the worker, repaired, the equipment) 0
# (the author, wrote, a short story) 0
# (the player, made, a save) 1
# (the photographer, captured, a moment) 0
# (police officer, investigated, the crime) -1
# (the chef, served, the meal) 0
# (the musician, played, an instrument) 0
# (the designer, created, a logo) 0
# (the athlete, trained, the competition) 0
# (the businessman, closed, the deal) 0
# (the driver, followed, the map) 0
# (the writer, wrote, a story) 0
# (the teacher, gave, a presentation) 0
# (the student, reviewed, the material) 0
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) 1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) -1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 0
# (vigilance, strengthened, national survival) 1
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, production) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) 0
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, the eastern sudan) 0
# (persistent heavy rains, cause, flood-prone areas) 0
# (highly saturated soils, cause, flood-prone areas) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) 0
# (highly saturated soils, impact, the war-torn nation) -1
# (floods devastatingly impact, impact, food security) 0
# (floods devastatingly impact, impact, the war-torn nation) -1
# (excessive overthinking, leads, insomnia) -1
# (stress, caused, insomnia) -1
# (insomnia, causes, stress) -1
# (excessive overthinking, results, insomnia) -1

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    if compound >= 0.05:
        vader.append(1)
        return 'Positive'
    elif compound <= -0.05 :
        vader.append(-1)
        return 'Negative'
        
    elif  compound > -0.05 and compound < 0.05:
        vader.append(0)
        return 'Neutral'
    
for sent in causalTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    vader_analysis(compound)
    
for causalSentence, polarity  in zip(causalTriples, vader):
    print(causalSentence, polarity)
# Out:
# (the rain, caused, flowers) 0
# (the sun, rises, the east) 0
# (the wind, blew, the leaves) 0
# (the dog, bit, the mailman) 0
# (the boy, kicked, the ball) 0
# (the girl, sang, a song) 0
# (the teacher, graded, the papers) 0
# (the car, hit, the tree) 0
# (the storm, knocked, power lines) 0
# (the baby, cried, milk) -1
# (the cook, made, dinner) 0
# (the student, passed, the exam) 0
# (the company, launched, a new product) 1
# (the singer, performed, stage) 0
# (the singer, medicine, stage) 0
# (the farmer, harvested, the crops) 0
# (the artist, painted, a picture) 0
# (the dog, chased, the cat) 0
# (the bird, built, a nest) 0
# (the teacher, taught, the lesson) 0
# (the child, played, the toy) 1
# (the company, released, a statement) 0
# (the band, played, a concert) 1
# (the doctor, examined, the patient) 0
# (the engineer, designed, the bridge) 0
# (the scientist, conducted, the experiment) 0
# (the worker, assembled, the machine) 0
# (the author, wrote, a novel) 1
# (the player, scored, a goal) 0
# (the photographer, took, a picture) 0
# (police officer, arrested, the suspect) -1
# (the chef, cooked, a meal) 0
# (the musician, composed, a song) 0
# (the designer, created, a website) 1
# (the athlete, won, the race) 1
# (the businessman, made, a deal) 0
# (the driver, drove, the car) 0
# (the writer, wrote, an article) 0
# (the teacher, gave, a lecture) 0
# (the student, studied, the test) 0
# (the company, hired, a new employee) 0
# (the doctor, treated, the illness) -1
# (the artist, sculpted, a statue) 0
# (the dog, barked, the stranger) 0
# (the bird, flew, the sky) 0
# (the teacher, graded, the quizzes) 0
# (the car, broke, the highway) -1
# (the storm, caused, a flood) 0
# (the baby, slept, the night) 0
# (the cook, prepared, the ingredients) 1
# (the student, completed, the assignment) 0
# (the company, expanded, its market) 0
# (the singer, recorded, an album) 0
# (the doctor, performed, surgery) 0
# (the farmer, tended, the animals) 0
# (the artist, drew, a portrait) 0
# (the dog, fetched, the ball) 0
# (the bird, sang, a melody) 0
# (the teacher, taught, a class) 0
# (the company, released, an update) 0
# (the band, played, a gig) 1
# (the doctor, diagnosed, the illness) -1
# (the engineer, constructed, the building) 0
# (the scientist, discovered, a new element) 0
# (the worker, repaired, the equipment) 0
# (the author, wrote, a short story) 0
# (the player, made, a save) 1
# (the photographer, captured, a moment) 0
# (police officer, investigated, the crime) -1
# (the chef, served, the meal) 0
# (the musician, played, an instrument) 1
# (the designer, created, a logo) 1
# (the athlete, trained, the competition) 0
# (the businessman, closed, the deal) 0
# (the driver, followed, the map) 0
# (the writer, wrote, a story) 0
# (the teacher, gave, a presentation) 0
# (the student, reviewed, the material) 0
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 0
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) 1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 0
# (vigilance, strengthened, national survival) 1
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, production) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) 0
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, the eastern sudan) 0
# (persistent heavy rains, cause, flood-prone areas) 0
# (highly saturated soils, cause, flood-prone areas) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) -1
# (highly saturated soils, impact, the war-torn nation) 0
# (floods devastatingly impact, impact, food security) -1
# (floods devastatingly impact, impact, the war-torn nation) -1
# (excessive overthinking, leads, insomnia) 0
# (stress, caused, insomnia) -1
# (insomnia, causes, stress) -1
# (excessive overthinking, results, insomnia) 0

# %%
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')


sentiStrength = []

for sent in causalTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='binary')
    #print(result)
    
    if result[0]==1:
        #print('Positive')
        sentiStrength.append(1)
    elif result[0]==-1:
        sentiStrength.append(-1)
        #print('Negative')
    #else:
    #    print('Neutral')

for causalSentence, polarity  in zip(causalTriples, sentiStrength):
    print(causalSentence, polarity)
# Out:
# (the rain, caused, flowers) 1
# (the sun, rises, the east) 1
# (the wind, blew, the leaves) 1
# (the dog, bit, the mailman) 1
# (the boy, kicked, the ball) -1
# (the girl, sang, a song) 1
# (the teacher, graded, the papers) 1
# (the car, hit, the tree) 1
# (the storm, knocked, power lines) -1
# (the baby, cried, milk) -1
# (the cook, made, dinner) 1
# (the student, passed, the exam) 1
# (the company, launched, a new product) 1
# (the singer, performed, stage) 1
# (the singer, medicine, stage) 1
# (the farmer, harvested, the crops) 1
# (the artist, painted, a picture) 1
# (the dog, chased, the cat) -1
# (the bird, built, a nest) 1
# (the teacher, taught, the lesson) 1
# (the child, played, the toy) 1
# (the company, released, a statement) 1
# (the band, played, a concert) 1
# (the doctor, examined, the patient) 1
# (the engineer, designed, the bridge) 1
# (the scientist, conducted, the experiment) 1
# (the worker, assembled, the machine) 1
# (the author, wrote, a novel) 1
# (the player, scored, a goal) 1
# (the photographer, took, a picture) 1
# (police officer, arrested, the suspect) -1
# (the chef, cooked, a meal) 1
# (the musician, composed, a song) 1
# (the designer, created, a website) 1
# (the athlete, won, the race) 1
# (the businessman, made, a deal) 1
# (the driver, drove, the car) 1
# (the writer, wrote, an article) 1
# (the teacher, gave, a lecture) 1
# (the student, studied, the test) 1
# (the company, hired, a new employee) 1
# (the doctor, treated, the illness) -1
# (the artist, sculpted, a statue) 1
# (the dog, barked, the stranger) 1
# (the bird, flew, the sky) 1
# (the teacher, graded, the quizzes) 1
# (the car, broke, the highway) -1
# (the storm, caused, a flood) -1
# (the baby, slept, the night) 1
# (the cook, prepared, the ingredients) 1
# (the student, completed, the assignment) 1
# (the company, expanded, its market) 1
# (the singer, recorded, an album) 1
# (the doctor, performed, surgery) 1
# (the farmer, tended, the animals) 1
# (the artist, drew, a portrait) 1
# (the dog, fetched, the ball) 1
# (the bird, sang, a melody) 1
# (the teacher, taught, a class) 1
# (the company, released, an update) 1
# (the band, played, a gig) 1
# (the doctor, diagnosed, the illness) -1
# (the engineer, constructed, the building) 1
# (the scientist, discovered, a new element) 1
# (the worker, repaired, the equipment) 1
# (the author, wrote, a short story) 1
# (the player, made, a save) 1
# (the photographer, captured, a moment) -1
# (police officer, investigated, the crime) -1
# (the chef, served, the meal) 1
# (the musician, played, an instrument) 1
# (the designer, created, a logo) 1
# (the athlete, trained, the competition) 1
# (the businessman, closed, the deal) 1
# (the driver, followed, the map) 1
# (the writer, wrote, a story) 1
# (the teacher, gave, a presentation) 1
# (the student, reviewed, the material) 1
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) -1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 1
# (vigilance, strengthened, national survival) 1
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (conflict, discourages, production) -1
# (conflict, discourages, farmers) -1
# (conflict, discourages, traders) -1
# (conflict, discourages, marketing infrastructure) -1
# (conflict, discourages, retailers) -1
# (no irrigation infrastructure, shows, public investment) 1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) 1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, the eastern sudan) 1
# (persistent heavy rains, cause, flood-prone areas) 1
# (highly saturated soils, cause, flood-prone areas) 1
# (rain, caused, floods) 1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (highly saturated soils, impact, the war-torn nation) -1
# (floods devastatingly impact, impact, food security) -1
# (floods devastatingly impact, impact, the war-torn nation) -1
# (excessive overthinking, leads, insomnia) -1
# (stress, caused, insomnia) -1
# (insomnia, causes, stress) -1
# (excessive overthinking, results, insomnia) -1

# %%
import pandas as pd

df2 = pd.DataFrame(list(zip(causalTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.
# <style type="text/css">
# </style>
# <table id="T_6d0ad_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Triple</th>
#       <th class="col_heading level0 col1" >AllenNLP</th>
#       <th class="col_heading level0 col2" >Afinn</th>
#       <th class="col_heading level0 col3" >Vader</th>
#       <th class="col_heading level0 col4" >SentiStrength</th>
#       <th class="col_heading level0 col5" >Weight</th>
#       <th class="col_heading level0 col6" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d0ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d0ad_row0_col0" class="data row0 col0" >(the rain, caused, flowers)</td>
#       <td id="T_6d0ad_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_6d0ad_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6d0ad_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6d0ad_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_6d0ad_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_6d0ad_row0_col6" class="data row0 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6d0ad_row1_col0" class="data row1 col0" >(the sun, rises, the east)</td>
#       <td id="T_6d0ad_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_6d0ad_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_6d0ad_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_6d0ad_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_6d0ad_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_6d0ad_row1_col6" class="data row1 col6" >Moderate Positive</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6d0ad_row2_col0" class="data row2 col0" >(the wind, blew, the leaves)</td>
#       <td id="T_6d0ad_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_6d0ad_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_6d0ad_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_6d0ad_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_6d0ad_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_6d0ad_row2_col6" class="data row2 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6d0ad_row3_col0" class="data row3 col0" >(the dog, bit, the mailman)</td>
#       <td id="T_6d0ad_row3_col1" class="data row3 col1" >-1</td>
#       <td id="T_6d0ad_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_6d0ad_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_6d0ad_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_6d0ad_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_6d0ad_row3_col6" class="data row3 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6d0ad_row4_col0" class="data row4 col0" >(the boy, kicked, the ball)</td>
#       <td id="T_6d0ad_row4_col1" class="data row4 col1" >-1</td>
#       <td id="T_6d0ad_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_6d0ad_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_6d0ad_row4_col4" class="data row4 col4" >-1</td>
#       <td id="T_6d0ad_row4_col5" class="data row4 col5" >-2</td>
#       <td id="T_6d0ad_row4_col6" class="data row4 col6" >Mild Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6d0ad_row5_col0" class="data row5 col0" >(the girl, sang, a song)</td>
#       <td id="T_6d0ad_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_6d0ad_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_6d0ad_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_6d0ad_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_6d0ad_row5_col5" class="data row5 col5" >2</td>
#       <td id="T_6d0ad_row5_col6" class="data row5 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6d0ad_row6_col0" class="data row6 col0" >(the teacher, graded, the papers)</td>
#       <td id="T_6d0ad_row6_col1" class="data row6 col1" >-1</td>
#       <td id="T_6d0ad_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_6d0ad_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_6d0ad_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_6d0ad_row6_col5" class="data row6 col5" >0</td>
#       <td id="T_6d0ad_row6_col6" class="data row6 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6d0ad_row7_col0" class="data row7 col0" >(the car, hit, the tree)</td>
#       <td id="T_6d0ad_row7_col1" class="data row7 col1" >-1</td>
#       <td id="T_6d0ad_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_6d0ad_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_6d0ad_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_6d0ad_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_6d0ad_row7_col6" class="data row7 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6d0ad_row8_col0" class="data row8 col0" >(the storm, knocked, power lines)</td>
#       <td id="T_6d0ad_row8_col1" class="data row8 col1" >-1</td>
#       <td id="T_6d0ad_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_6d0ad_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_6d0ad_row8_col4" class="data row8 col4" >-1</td>
#       <td id="T_6d0ad_row8_col5" class="data row8 col5" >-2</td>
#       <td id="T_6d0ad_row8_col6" class="data row8 col6" >Mild Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6d0ad_row9_col0" class="data row9 col0" >(the baby, cried, milk)</td>
#       <td id="T_6d0ad_row9_col1" class="data row9 col1" >-1</td>
#       <td id="T_6d0ad_row9_col2" class="data row9 col2" >-1</td>
#       <td id="T_6d0ad_row9_col3" class="data row9 col3" >-1</td>
#       <td id="T_6d0ad_row9_col4" class="data row9 col4" >-1</td>
#       <td id="T_6d0ad_row9_col5" class="data row9 col5" >-4</td>
#       <td id="T_6d0ad_row9_col6" class="data row9 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6d0ad_row10_col0" class="data row10 col0" >(the cook, made, dinner)</td>
#       <td id="T_6d0ad_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_6d0ad_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_6d0ad_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_6d0ad_row10_col4" class="data row10 col4" >1</td>
#       <td id="T_6d0ad_row10_col5" class="data row10 col5" >2</td>
#       <td id="T_6d0ad_row10_col6" class="data row10 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6d0ad_row11_col0" class="data row11 col0" >(the student, passed, the exam)</td>
#       <td id="T_6d0ad_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_6d0ad_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_6d0ad_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_6d0ad_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_6d0ad_row11_col5" class="data row11 col5" >2</td>
#       <td id="T_6d0ad_row11_col6" class="data row11 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_6d0ad_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6d0ad_row12_col0" class="data row12 col0" >(the company, launched, a new product)</td>
#       <td id="T_6d0ad_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_6d0ad_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_6d0ad_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_6d0ad_row12_col4" class="data row12 col4" >1</t

# %%
def Allen_sents_SentLevel(causalSentences):
    allen = []
    for sent in causalSentences:
        #print(sent)
        preds = predictor1.predict(str(sent))
        #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen.append(-1)
        else:
            allen.append(1)
    return allen

# %%
def Afinn_sents_SentLevel(causalSentences):
    afinn = []
    for sent in causalSentences:
        #print(sent)
        score = afn.score(str(sent))
        #print(score)
        if score > 0:
            #print('positive')
            afinn.append(1)
        elif score < 0:
            #print('negative')
            afinn.append(-1)
        else:
            #print('neutral')
            afinn.append(0)
    return afinn

# %%
def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    #vader = []
    if compound >= 0.05:
        #vader.append(1)
        return 1
    elif compound <= -0.05 :
        #vader.append(-1)
        return -1
        
    elif  compound > -0.05 and compound < 0.05:
        #vader.append(0)
        return 0
    #return vader
    
def Vader_sents_SentLevel(causalSentences):
    vader = []
    for sent in causalSentences:
        #print(sent)
        #vaderTup = []
        compound = vadersentimentanalysis(str(sent))
        res = vader_analysis(compound)
        #vaderTup.append(res)
        vader.append(res)
    return vader

# %%
def Senti_sents_SentLevel(causalSentences):
    sentiStrength = []
    for sent in causalSentences:
        #print(sent)
        result = senti.getSentiment(str(sent), score='binary')
        #print(result)
    
        if result[0]==1:
            #print('Positive')
            sentiStrength.append(1)
        elif result[0]==-1:
            sentiStrength.append(-1)
            #print('Negative')
        #else:
        #    print('Neutral')
    return sentiStrength

# %%
causalSents = causalSentencesNoDup
print(len(causalSents))
# Out:
# 105

# %%
causalSents = causalSentences
print(len(causalSents))
# Out:
# 117

# %%
allen = Allen_sents_SentLevel(causalSents)
afinn = Afinn_sents_SentLevel(causalSents)
vader = Vader_sents_SentLevel(causalSents)
sentiStrength = Senti_sents_SentLevel(causalSents)

df2 = pd.DataFrame(list(zip(causalSents, allen, afinn, vader,sentiStrength)), columns =['Causal Sentence', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)


sentPolarity = []
sentsWeight_sentLevel = []

for index, row in df2.iterrows():
    sentWeightTuple = []
    weight = row['Weight']
    sentWeightTuple.append(weight)
    sentsWeight_sentLevel.append(sentWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   import sys
# <style type="text/css">
# </style>
# <table id="T_a1a37_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Sentence</th>
#       <th class="col_heading level0 col1" >AllenNLP</th>
#       <th class="col_heading level0 col2" >Afinn</th>
#       <th class="col_heading level0 col3" >Vader</th>
#       <th class="col_heading level0 col4" >SentiStrength</th>
#       <th class="col_heading level0 col5" >Weight</th>
#       <th class="col_heading level0 col6" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1a37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1a37_row0_col0" class="data row0 col0" >the rain caused wilting of flowers.</td>
#       <td id="T_a1a37_row0_col1" class="data row0 col1" >-1</td>
#       <td id="T_a1a37_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a1a37_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a1a37_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_a1a37_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a1a37_row0_col6" class="data row0 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1a37_row1_col0" class="data row1 col0" >the sun rises in the east.</td>
#       <td id="T_a1a37_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_a1a37_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_a1a37_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_a1a37_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_a1a37_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_a1a37_row1_col6" class="data row1 col6" >Moderate Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1a37_row2_col0" class="data row2 col0" >the wind blew the leaves.</td>
#       <td id="T_a1a37_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_a1a37_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_a1a37_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_a1a37_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_a1a37_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_a1a37_row2_col6" class="data row2 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1a37_row3_col0" class="data row3 col0" >the dog bit the mailman.</td>
#       <td id="T_a1a37_row3_col1" class="data row3 col1" >-1</td>
#       <td id="T_a1a37_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_a1a37_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_a1a37_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_a1a37_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_a1a37_row3_col6" class="data row3 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1a37_row4_col0" class="data row4 col0" >the boy kicked the ball.</td>
#       <td id="T_a1a37_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_a1a37_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_a1a37_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_a1a37_row4_col4" class="data row4 col4" >-1</td>
#       <td id="T_a1a37_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_a1a37_row4_col6" class="data row4 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1a37_row5_col0" class="data row5 col0" >the girl sang a song.</td>
#       <td id="T_a1a37_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_a1a37_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_a1a37_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_a1a37_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_a1a37_row5_col5" class="data row5 col5" >2</td>
#       <td id="T_a1a37_row5_col6" class="data row5 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1a37_row6_col0" class="data row6 col0" >the teacher graded the papers.</td>
#       <td id="T_a1a37_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_a1a37_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_a1a37_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_a1a37_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_a1a37_row6_col5" class="data row6 col5" >2</td>
#       <td id="T_a1a37_row6_col6" class="data row6 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1a37_row7_col0" class="data row7 col0" >the car hit the tree.</td>
#       <td id="T_a1a37_row7_col1" class="data row7 col1" >-1</td>
#       <td id="T_a1a37_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_a1a37_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_a1a37_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_a1a37_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_a1a37_row7_col6" class="data row7 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1a37_row8_col0" class="data row8 col0" >the storm knocked down the power lines.</td>
#       <td id="T_a1a37_row8_col1" class="data row8 col1" >-1</td>
#       <td id="T_a1a37_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_a1a37_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_a1a37_row8_col4" class="data row8 col4" >-1</td>
#       <td id="T_a1a37_row8_col5" class="data row8 col5" >-2</td>
#       <td id="T_a1a37_row8_col6" class="data row8 col6" >Mild Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1a37_row9_col0" class="data row9 col0" >the baby cried for milk.</td>
#       <td id="T_a1a37_row9_col1" class="data row9 col1" >-1</td>
#       <td id="T_a1a37_row9_col2" class="data row9 col2" >-1</td>
#       <td id="T_a1a37_row9_col3" class="data row9 col3" >-1</td>
#       <td id="T_a1a37_row9_col4" class="data row9 col4" >-1</td>
#       <td id="T_a1a37_row9_col5" class="data row9 col5" >-4</td>
#       <td id="T_a1a37_row9_col6" class="data row9 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a1a37_row10_col0" class="data row10 col0" >the cook made dinner.</td>
#       <td id="T_a1a37_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_a1a37_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_a1a37_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_a1a37_row10_col4" class="data row10 col4" >1</td>
#       <td id="T_a1a37_row10_col5" class="data row10 col5" >2</td>
#       <td id="T_a1a37_row10_col6" class="data row10 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a1a37_row11_col0" class="data row11 col0" >the student passed the exam.</td>
#       <td id="T_a1a37_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_a1a37_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_a1a37_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_a1a37_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_a1a37_row11_col5" class="data row11 col5" >2</td>
#       <td id="T_a1a37_row11_col6" class="data row11 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_a1a37_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a1a37_row12_col0" class="data row12 col0" >the company launched a new product.</td>
#       <td id="T_a1a37_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_a1a37_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_a1a37_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_a1a37_row12_col4" class="data row12 col4" >1</td>
#       <td id="T

# %%
allen_word = []
allen_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks: 
        #print(token)
        preds = predictor1.predict(str(token))
            #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen_tuple.append(-1)
                #allen_word.append(-1)
        else:
                #allen_word.append(1)
            allen_tuple.append(1)
    allen_word.append(allen_tuple)
    allen_tuple = []
                
for a,b in zip(causalTriples,allen_word):
    #print(len(a))
    print(a,b)
# Out:
# (the rain, caused, flowers) [1, 1, 1]
# (the sun, rises, the east) [1, 1, 1]
# (the wind, blew, the leaves) [1, -1, 1]
# (the dog, bit, the mailman) [1, 1, -1]
# (the boy, kicked, the ball) [1, -1, 1]
# (the girl, sang, a song) [1, -1, 1]
# (the teacher, graded, the papers) [1, 1, 1]
# (the car, hit, the tree) [1, 1, 1]
# (the storm, knocked, power lines) [1, 1, -1]
# (the baby, cried, milk) [1, -1, -1]
# (the cook, made, dinner) [1, 1, 1]
# (the student, passed, the exam) [1, -1, 1]
# (the company, launched, a new product) [1, 1, 1]
# (the singer, performed, stage) [1, 1, 1]
# (the singer, medicine, stage) [1, 1, 1]
# (the farmer, harvested, the crops) [1, -1, 1]
# (the artist, painted, a picture) [1, 1, 1]
# (the dog, chased, the cat) [1, 1, 1]
# (the bird, built, a nest) [1, 1, 1]
# (the teacher, taught, the lesson) [1, 1, 1]
# (the child, played, the toy) [1, 1, 1]
# (the company, released, a statement) [1, 1, 1]
# (the band, played, a concert) [1, 1, 1]
# (the doctor, examined, the patient) [1, 1, 1]
# (the engineer, designed, the bridge) [1, 1, 1]
# (the scientist, conducted, the experiment) [1, 1, 1]
# (the worker, assembled, the machine) [1, 1, 1]
# (the author, wrote, a novel) [1, 1, 1]
# (the player, scored, a goal) [1, 1, 1]
# (the photographer, took, a picture) [1, 1, 1]
# (police officer, arrested, the suspect) [1, 1, -1]
# (the chef, cooked, a meal) [1, 1, 1]
# (the musician, composed, a song) [1, 1, 1]
# (the designer, created, a website) [1, 1, 1]
# (the athlete, won, the race) [1, 1, 1]
# (the businessman, made, a deal) [1, 1, 1]
# (the driver, drove, the car) [1, 1, 1]
# (the writer, wrote, an article) [1, 1, 1]
# (the teacher, gave, a lecture) [1, 1, -1]
# (the student, studied, the test) [1, 1, 1]
# (the company, hired, a new employee) [1, 1, 1]
# (the doctor, treated, the illness) [1, 1, -1]
# (the artist, sculpted, a statue) [1, 1, 1]
# (the dog, barked, the stranger) [1, -1, -1]
# (the bird, flew, the sky) [1, 1, 1]
# (the teacher, graded, the quizzes) [1, 1, 1]
# (the car, broke, the highway) [1, -1, 1]
# (the storm, caused, a flood) [1, 1, -1]
# (the baby, slept, the night) [1, -1, 1]
# (the cook, prepared, the ingredients) [1, 1, 1]
# (the student, completed, the assignment) [1, 1, 1]
# (the company, expanded, its market) [1, 1, 1]
# (the singer, recorded, an album) [1, 1, 1]
# (the doctor, performed, surgery) [1, 1, 1]
# (the farmer, tended, the animals) [1, 1, 1]
# (the artist, drew, a portrait) [1, 1, 1]
# (the dog, fetched, the ball) [1, 1, 1]
# (the bird, sang, a melody) [1, -1, 1]
# (the teacher, taught, a class) [1, 1, 1]
# (the company, released, an update) [1, 1, 1]
# (the band, played, a gig) [1, 1, 1]
# (the doctor, diagnosed, the illness) [1, 1, -1]
# (the engineer, constructed, the building) [1, 1, 1]
# (the scientist, discovered, a new element) [1, 1, 1]
# (the worker, repaired, the equipment) [1, -1, 1]
# (the author, wrote, a short story) [1, 1, 1]
# (the player, made, a save) [1, 1, 1]
# (the photographer, captured, a moment) [1, 1, 1]
# (police officer, investigated, the crime) [1, 1, -1]
# (the chef, served, the meal) [1, 1, 1]
# (the musician, played, an instrument) [1, 1, 1]
# (the designer, created, a logo) [1, 1, 1]
# (the athlete, trained, the competition) [1, 1, 1]
# (the businessman, closed, the deal) [1, 1, 1]
# (the driver, followed, the map) [1, 1, 1]
# (the writer, wrote, a story) [1, 1, 1]
# (the teacher, gave, a presentation) [1, 1, 1]
# (the student, reviewed, the material) [1, 1, 1]
# (zulfikar ali bhutto, launched, nuclear program) [1, 1, -1]
# (nuclear program, declared, pakistan's commitment) [-1, 1, 1]
# (nuclear program, declared, pakistan's dedication) [-1, 1, 1]
# (aq khan, developed, nuclear bomb) [1, 1, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 1]
# (nuclear bomb, makes, nuclear power) [-1, 1, 1]
# (pakistan, must never surrender, nuclear bomb) [1, 1, -1]
# (pakistan, must fight, existential threats) [1, 1, -1]
# (pakistan, must support, army) [1, 1, 1]
# (pakistan, must support, aq khan) [1, 1, 1]
# (army, provides, vigilance) [1, 1, 1]
# (vigilance, strengthened, national survival) [1, 1, 1]
# (institutional weakness, hindered, development) [-1, -1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, -1, 1]
# (conflict, discourages, production) [-1, -1, 1]
# (conflict, discourages, farmers) [-1, -1, 1]
# (conflict, discourages, traders) [-1, -1, -1]
# (conflict, discourages, marketing infrastructure) [-1, -1, 1]
# (conflict, discourages, retailers) [-1, -1, 1]
# (no irrigation infrastructure, shows, public investment) [-1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 1, -1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, -1]
# (persistent heavy rains, cause, the eastern sudan) [-1, 1, 1]
# (persistent heavy rains, cause, flood-prone areas) [-1, 1, -1]
# (highly saturated soils, cause, flood-prone areas) [1, 1, -1]
# (rain, caused, floods) [-1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (highly saturated soils, impact, the war-torn nation) [1, 1, -1]
# (floods devastatingly impact, impact, food security) [-1, 1, 1]
# (floods devastatingly impact, impact, the war-torn nation) [-1, 1, -1]
# (excessive overthinking, leads, insomnia) [-1, 1, -1]
# (stress, caused, insomnia) [-1, 1, -1]
# (insomnia, causes, stress) [-1, 1, -1]
# (excessive overthinking, results, insomnia) [-1, 1, -1]

# %%
afinn_word = []
afinn_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
        #if str(token) not in marks:
            #print(token)
        score = afn.score(str(token))
        if score > 0:
                #print('positive')
            afinn_tuple.append(1)
        elif score < 0:
                #print('negative')
            afinn_tuple.append(-1)
        else:
                #print('neutral')
            afinn_tuple.append(0)
    afinn_word.append(afinn_tuple)
    afinn_tuple = []

for a,b in zip(causalTriples,afinn_word):
   # print(len(a))
    print(a,b)
# Out:
# (the rain, caused, flowers) [0, 0, 0]
# (the sun, rises, the east) [0, 1, 0]
# (the wind, blew, the leaves) [0, 0, 0]
# (the dog, bit, the mailman) [0, 0, 0]
# (the boy, kicked, the ball) [0, 0, 0]
# (the girl, sang, a song) [0, 0, 0]
# (the teacher, graded, the papers) [0, 0, 0]
# (the car, hit, the tree) [0, 0, 0]
# (the storm, knocked, power lines) [0, 0, 0]
# (the baby, cried, milk) [0, -1, 0]
# (the cook, made, dinner) [0, 0, 0]
# (the student, passed, the exam) [0, 0, 0]
# (the company, launched, a new product) [0, 1, 0]
# (the singer, performed, stage) [0, 0, 0]
# (the singer, medicine, stage) [0, 0, 0]
# (the farmer, harvested, the crops) [0, 0, 0]
# (the artist, painted, a picture) [0, 0, 0]
# (the dog, chased, the cat) [0, 0, 0]
# (the bird, built, a nest) [0, 0, 0]
# (the teacher, taught, the lesson) [0, 0, 0]
# (the child, played, the toy) [0, 0, 0]
# (the company, released, a statement) [0, 0, 0]
# (the band, played, a concert) [0, 0, 0]
# (the doctor, examined, the patient) [0, 0, 0]
# (the engineer, designed, the bridge) [0, 0, 0]
# (the scientist, conducted, the experiment) [0, 0, 0]
# (the worker, assembled, the machine) [0, 0, 0]
# (the author, wrote, a novel) [0, 0, 1]
# (the player, scored, a goal) [0, 0, 0]
# (the photographer, took, a picture) [0, 0, 0]
# (police officer, arrested, the suspect) [0, -1, -1]
# (the chef, cooked, a meal) [0, 0, 0]
# (the musician, composed, a song) [0, 0, 0]
# (the designer, created, a website) [0, 0, 0]
# (the athlete, won, the race) [0, 1, 0]
# (the businessman, made, a deal) [0, 0, 0]
# (the driver, drove, the car) [0, 0, 0]
# (the writer, wrote, an article) [0, 0, 0]
# (the teacher, gave, a lecture) [0, 0, 0]
# (the student, studied, the test) [0, 0, 0]
# (the company, hired, a new employee) [0, 0, 0]
# (the doctor, treated, the illness) [0, 0, -1]
# (the artist, sculpted, a statue) [0, 0, 0]
# (the dog, barked, the stranger) [0, 0, 0]
# (the bird, flew, the sky) [0, 0, 0]
# (the teacher, graded, the quizzes) [0, 0, 0]
# (the car, broke, the highway) [0, -1, 0]
# (the storm, caused, a flood) [0, 0, 0]
# (the baby, slept, the night) [0, 0, 0]
# (the cook, prepared, the ingredients) [0, 1, 0]
# (the student, completed, the assignment) [0, 0, 0]
# (the company, expanded, its market) [0, 0, 0]
# (the singer, recorded, an album) [0, 0, 0]
# (the doctor, performed, surgery) [0, 0, 0]
# (the farmer, tended, the animals) [0, 0, 0]
# (the artist, drew, a portrait) [0, 0, 0]
# (the dog, fetched, the ball) [0, 0, 0]
# (the bird, sang, a melody) [0, 0, 0]
# (the teacher, taught, a class) [0, 0, 0]
# (the company, released, an update) [0, 0, 0]
# (the band, played, a gig) [0, 0, 0]
# (the doctor, diagnosed, the illness) [0, 0, -1]
# (the engineer, constructed, the building) [0, 0, 0]
# (the scientist, discovered, a new element) [0, 0, 0]
# (the worker, repaired, the equipment) [0, 0, 0]
# (the author, wrote, a short story) [0, 0, 0]
# (the player, made, a save) [0, 0, 1]
# (the photographer, captured, a moment) [0, 0, 0]
# (police officer, investigated, the crime) [0, 0, -1]
# (the chef, served, the meal) [0, 0, 0]
# (the musician, played, an instrument) [0, 0, 0]
# (the designer, created, a logo) [0, 0, 0]
# (the athlete, trained, the competition) [0, 0, 0]
# (the businessman, closed, the deal) [0, 0, 0]
# (the driver, followed, the map) [0, 0, 0]
# (the writer, wrote, a story) [0, 0, 0]
# (the teacher, gave, a presentation) [0, 0, 0]
# (the student, reviewed, the material) [0, 0, 0]
# (zulfikar ali bhutto, launched, nuclear program) [0, 1, 0]
# (nuclear program, declared, pakistan's commitment) [0, 0, 1]
# (nuclear program, declared, pakistan's dedication) [0, 0, 1]
# (aq khan, developed, nuclear bomb) [0, 0, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 0]
# (nuclear bomb, makes, nuclear power) [-1, 0, 0]
# (pakistan, must never surrender, nuclear bomb) [0, 0, -1]
# (pakistan, must fight, existential threats) [0, -1, -1]
# (pakistan, must support, army) [0, 1, 0]
# (pakistan, must support, aq khan) [0, 1, 0]
# (army, provides, vigilance) [0, 0, 0]
# (vigilance, strengthened, national survival) [0, 1, 0]
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (conflict, discourages, production) [-1, 0, 0]
# (conflict, discourages, farmers) [-1, 0, 0]
# (conflict, discourages, traders) [-1, 0, 0]
# (conflict, discourages, marketing infrastructure) [-1, 0, 0]
# (conflict, discourages, retailers) [-1, 0, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [0, 0, 0]
# (the low level, shows, no irrigation infrastructure) [0, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, the eastern sudan) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flood-prone areas) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, 0]
# (highly saturated soils, impact, the war-torn nation) [0, 0, -1]
# (floods devastatingly impact, impact, food security) [0, 0, 0]
# (floods devastatingly impact, impact, the war-torn nation) [0, 0, -1]
# (excessive overthinking, leads, insomnia) [0, 0, -1]
# (stress, caused, insomnia) [-1, 0, -1]
# (insomnia, causes, stress) [-1, 0, -1]
# (excessive overthinking, results, insomnia) [0, 0, -1]

# %%
vader_word = []
vader_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) not in marks:
        vs = analyzer.polarity_scores(str(token))
        compound = vs['compound']
        if compound >= 0.05:
            vader_tuple.append(1)   
        elif compound <= -0.05 :
            vader_tuple.append(-1)
        elif  compound > -0.05 and compound < 0.05:
            vader_tuple.append(0)
    vader_word.append(vader_tuple)
    vader_tuple = []

for a,b in zip(causalTriples,vader_word):
    #print(len(a))
    print(a,b)
# Out:
# (the rain, caused, flowers) [0, 0, 0]
# (the sun, rises, the east) [0, 0, 0]
# (the wind, blew, the leaves) [0, 0, 0]
# (the dog, bit, the mailman) [0, 0, 0]
# (the boy, kicked, the ball) [0, 0, 0]
# (the girl, sang, a song) [0, 0, 0]
# (the teacher, graded, the papers) [0, 0, 0]
# (the car, hit, the tree) [0, 0, 0]
# (the storm, knocked, power lines) [0, 0, 0]
# (the baby, cried, milk) [0, -1, 0]
# (the cook, made, dinner) [0, 0, 0]
# (the student, passed, the exam) [0, 0, 0]
# (the company, launched, a new product) [0, 1, 0]
# (the singer, performed, stage) [0, 0, 0]
# (the singer, medicine, stage) [0, 0, 0]
# (the farmer, harvested, the crops) [0, 0, 0]
# (the artist, painted, a picture) [0, 0, 0]
# (the dog, chased, the cat) [0, 0, 0]
# (the bird, built, a nest) [0, 0, 0]
# (the teacher, taught, the lesson) [0, 0, 0]
# (the child, played, the toy) [0, 1, 0]
# (the company, released, a statement) [0, 0, 0]
# (the band, played, a concert) [0, 1, 0]
# (the doctor, examined, the patient) [0, 0, 0]
# (the engineer, designed, the bridge) [0, 0, 0]
# (the scientist, conducted, the experiment) [0, 0, 0]
# (the worker, assembled, the machine) [0, 0, 0]
# (the author, wrote, a novel) [0, 0, 1]
# (the player, scored, a goal) [0, 0, 0]
# (the photographer, took, a picture) [0, 0, 0]
# (police officer, arrested, the suspect) [0, -1, -1]
# (the chef, cooked, a meal) [0, 0, 0]
# (the musician, composed, a song) [0, 0, 0]
# (the designer, created, a website) [0, 1, 0]
# (the athlete, won, the race) [0, 1, 0]
# (the businessman, made, a deal) [0, 0, 0]
# (the driver, drove, the car) [0, 0, 0]
# (the writer, wrote, an article) [0, 0, 0]
# (the teacher, gave, a lecture) [0, 0, 0]
# (the student, studied, the test) [0, 0, 0]
# (the company, hired, a new employee) [0, 0, 0]
# (the doctor, treated, the illness) [0, 0, -1]
# (the artist, sculpted, a statue) [0, 0, 0]
# (the dog, barked, the stranger) [0, 0, 0]
# (the bird, flew, the sky) [0, 0, 0]
# (the teacher, graded, the quizzes) [0, 0, 0]
# (the car, broke, the highway) [0, -1, 0]
# (the storm, caused, a flood) [0, 0, 0]
# (the baby, slept, the night) [0, 0, 0]
# (the cook, prepared, the ingredients) [0, 1, 0]
# (the student, completed, the assignment) [0, 0, 0]
# (the company, expanded, its market) [0, 0, 0]
# (the singer, recorded, an album) [0, 0, 0]
# (the doctor, performed, surgery) [0, 0, 0]
# (the farmer, tended, the animals) [0, 0, 0]
# (the artist, drew, a portrait) [0, 0, 0]
# (the dog, fetched, the ball) [0, 0, 0]
# (the bird, sang, a melody) [0, 0, 0]
# (the teacher, taught, a class) [0, 0, 0]
# (the company, released, an update) [0, 0, 0]
# (the band, played, a gig) [0, 1, 0]
# (the doctor, diagnosed, the illness) [0, 0, -1]
# (the engineer, constructed, the building) [0, 0, 0]
# (the scientist, discovered, a new element) [0, 0, 0]
# (the worker, repaired, the equipment) [0, 0, 0]
# (the author, wrote, a short story) [0, 0, 0]
# (the player, made, a save) [0, 0, 1]
# (the photographer, captured, a moment) [0, 0, 0]
# (police officer, investigated, the crime) [0, 0, -1]
# (the chef, served, the meal) [0, 0, 0]
# (the musician, played, an instrument) [0, 1, 0]
# (the designer, created, a logo) [0, 1, 0]
# (the athlete, trained, the competition) [0, 0, 0]
# (the businessman, closed, the deal) [0, 0, 0]
# (the driver, followed, the map) [0, 0, 0]
# (the writer, wrote, a story) [0, 0, 0]
# (the teacher, gave, a presentation) [0, 0, 0]
# (the student, reviewed, the material) [0, 0, 0]
# (zulfikar ali bhutto, launched, nuclear program) [0, 1, 0]
# (nuclear program, declared, pakistan's commitment) [0, 0, 1]
# (nuclear program, declared, pakistan's dedication) [0, 0, 0]
# (aq khan, developed, nuclear bomb) [0, 0, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 0]
# (nuclear bomb, makes, nuclear power) [-1, 0, 0]
# (pakistan, must never surrender, nuclear bomb) [0, 0, -1]
# (pakistan, must fight, existential threats) [0, -1, -1]
# (pakistan, must support, army) [0, 1, 0]
# (pakistan, must support, aq khan) [0, 1, 0]
# (army, provides, vigilance) [0, 0, 0]
# (vigilance, strengthened, national survival) [0, 1, 0]
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (conflict, discourages, production) [-1, -1, 0]
# (conflict, discourages, farmers) [-1, -1, 0]
# (conflict, discourages, traders) [-1, -1, 0]
# (conflict, discourages, marketing infrastructure) [-1, -1, 0]
# (conflict, discourages, retailers) [-1, -1, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [-1, 0, 0]
# (the low level, shows, no irrigation infrastructure) [-1, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, the eastern sudan) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flood-prone areas) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, -1]
# (highly saturated soils, impact, the war-torn nation) [0, 0, 0]
# (floods devastatingly impact, impact, food security) [-1, 0, 1]
# (floods devastatingly impact, impact, the war-torn nation) [-1, 0, 0]
# (excessive overthinking, leads, insomnia) [0, 0, 0]
# (stress, caused, insomnia) [-1, 0, 0]
# (insomnia, causes, stress) [0, 0, -1]
# (excessive overthinking, results, insomnia) [0, 0, 0]

# %%
senti_word = []
senti_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks:
        #print(token)
        result = senti.getSentiment(str(token), score='binary')
            #print(result)
        if result[0]==1:
                #print('Positive')
            senti_tuple.append(1)
        elif result[0]==-1:
                #print('Negative')
            senti_tuple.append(-1)
        else:
                #print('Neutral')
            senti_tuple.append(0)
    senti_word.append(senti_tuple)
    senti_tuple = []
    
for a,b in zip(causalTriples,senti_word):
    #print(len(a))
    print(a,b)
# Out:
# (the rain, caused, flowers) [1, 1, 1]
# (the sun, rises, the east) [1, 1, 1]
# (the wind, blew, the leaves) [1, 1, 1]
# (the dog, bit, the mailman) [1, 1, 1]
# (the boy, kicked, the ball) [1, -1, 1]
# (the girl, sang, a song) [1, 1, 1]
# (the teacher, graded, the papers) [1, 1, 1]
# (the car, hit, the tree) [1, 1, 1]
# (the storm, knocked, power lines) [-1, 1, 1]
# (the baby, cried, milk) [1, -1, 1]
# (the cook, made, dinner) [1, 1, 1]
# (the student, passed, the exam) [1, 1, 1]
# (the company, launched, a new product) [1, 1, 1]
# (the singer, performed, stage) [1, 1, 1]
# (the singer, medicine, stage) [1, 1, 1]
# (the farmer, harvested, the crops) [1, 1, 1]
# (the artist, painted, a picture) [1, 1, 1]
# (the dog, chased, the cat) [1, -1, 1]
# (the bird, built, a nest) [1, 1, 1]
# (the teacher, taught, the lesson) [1, 1, 1]
# (the child, played, the toy) [1, 1, 1]
# (the company, released, a statement) [1, 1, 1]
# (the band, played, a concert) [1, 1, 1]
# (the doctor, examined, the patient) [1, 1, 1]
# (the engineer, designed, the bridge) [1, 1, 1]
# (the scientist, conducted, the experiment) [1, 1, 1]
# (the worker, assembled, the machine) [1, 1, 1]
# (the author, wrote, a novel) [1, 1, 1]
# (the player, scored, a goal) [1, 1, 1]
# (the photographer, took, a picture) [1, 1, 1]
# (police officer, arrested, the suspect) [1, 1, -1]
# (the chef, cooked, a meal) [1, 1, 1]
# (the musician, composed, a song) [1, 1, 1]
# (the designer, created, a website) [1, 1, 1]
# (the athlete, won, the race) [1, 1, 1]
# (the businessman, made, a deal) [1, 1, 1]
# (the driver, drove, the car) [1, 1, 1]
# (the writer, wrote, an article) [1, 1, 1]
# (the teacher, gave, a lecture) [1, 1, 1]
# (the student, studied, the test) [1, 1, 1]
# (the company, hired, a new employee) [1, 1, 1]
# (the doctor, treated, the illness) [1, 1, -1]
# (the artist, sculpted, a statue) [1, 1, 1]
# (the dog, barked, the stranger) [1, 1, 1]
# (the bird, flew, the sky) [1, 1, 1]
# (the teacher, graded, the quizzes) [1, 1, 1]
# (the car, broke, the highway) [1, -1, 1]
# (the storm, caused, a flood) [-1, 1, 1]
# (the baby, slept, the night) [1, 1, 1]
# (the cook, prepared, the ingredients) [1, 1, 1]
# (the student, completed, the assignment) [1, 1, 1]
# (the company, expanded, its market) [1, 1, 1]
# (the singer, recorded, an album) [1, 1, 1]
# (the doctor, performed, surgery) [1, 1, 1]
# (the farmer, tended, the animals) [1, 1, 1]
# (the artist, drew, a portrait) [1, 1, 1]
# (the dog, fetched, the ball) [1, 1, 1]
# (the bird, sang, a melody) [1, 1, 1]
# (the teacher, taught, a class) [1, 1, 1]
# (the company, released, an update) [1, 1, 1]
# (the band, played, a gig) [1, 1, 1]
# (the doctor, diagnosed, the illness) [1, 1, -1]
# (the engineer, constructed, the building) [1, 1, 1]
# (the scientist, discovered, a new element) [1, 1, 1]
# (the worker, repaired, the equipment) [1, 1, 1]
# (the author, wrote, a short story) [1, 1, 1]
# (the player, made, a save) [1, 1, 1]
# (the photographer, captured, a moment) [1, -1, 1]
# (police officer, investigated, the crime) [1, 1, -1]
# (the chef, served, the meal) [1, 1, 1]
# (the musician, played, an instrument) [1, 1, 1]
# (the designer, created, a logo) [1, 1, 1]
# (the athlete, trained, the competition) [1, 1, 1]
# (the businessman, closed, the deal) [1, 1, 1]
# (the driver, followed, the map) [1, 1, 1]
# (the writer, wrote, a story) [1, 1, 1]
# (the teacher, gave, a presentation) [1, 1, 1]
# (the student, reviewed, the material) [1, 1, 1]
# (zulfikar ali bhutto, launched, nuclear program) [1, 1, 1]
# (nuclear program, declared, pakistan's commitment) [1, 1, 1]
# (nuclear program, declared, pakistan's dedication) [1, 1, 1]
# (aq khan, developed, nuclear bomb) [1, 1, -1]
# (nuclear bomb, strengthened, pakistan) [-1, 1, 1]
# (nuclear bomb, makes, nuclear power) [-1, 1, 1]
# (pakistan, must never surrender, nuclear bomb) [1, 1, -1]
# (pakistan, must fight, existential threats) [1, -1, -1]
# (pakistan, must support, army) [1, 1, 1]
# (pakistan, must support, aq khan) [1, 1, 1]
# (army, provides, vigilance) [1, 1, 1]
# (vigilance, strengthened, national survival) [1, 1, 1]
# (institutional weakness, hindered, development) [-1, 1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, 1, 1]
# (conflict, discourages, production) [-1, -1, 1]
# (conflict, discourages, farmers) [-1, -1, 1]
# (conflict, discourages, traders) [-1, -1, 1]
# (conflict, discourages, marketing infrastructure) [-1, -1, 1]
# (conflict, discourages, retailers) [-1, -1, 1]
# (no irrigation infrastructure, shows, public investment) [1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, 1]
# (south sudan's limited road network, shows, only 2 percent) [1, 1, 1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, 1]
# (persistent heavy rains, cause, the eastern sudan) [1, 1, 1]
# (persistent heavy rains, cause, flood-prone areas) [1, 1, 1]
# (highly saturated soils, cause, flood-prone areas) [1, 1, 1]
# (rain, caused, floods) [1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (highly saturated soils, impact, the war-torn nation) [1, 1, -1]
# (floods devastatingly impact, impact, food security) [-1, 1, 1]
# (floods devastatingly impact, impact, the war-torn nation) [-1, 1, -1]
# (excessive overthinking, leads, insomnia) [-1, 1, 1]
# (stress, caused, insomnia) [-1, 1, 1]
# (insomnia, causes, stress) [1, 1, -1]
# (excessive overthinking, results, insomnia) [-1, 1, 1]

# %%
from pd_replicator import replicator

sum_list = []
sum_tup = []
limit= len(causalTriples)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

triplesWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    triplesWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)

def dataframe_WordLevel(i):
    df = pd.DataFrame([causalTriples[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],triplesWeight_TokenLevel[i],triplePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    replicator(df)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens             (the, rain)       (caused)      (flowers)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                  1              2
# Tokens                  (the, sun)              rises    (the, east)
# AllenNlp                         1                  1              1
# Afinn                            0                  1              0
# Vader                            0                  0              0
# SentiStrength                    1                  1              1
# Token Weight                     2                  3              2
# Token Polarity       Mild Positive  Moderate Positive  Mild Positive
# Triple Weight                 2.33               None           None
# Triple Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0        1              2
# Tokens             (the, wind)   (blew)  (the, leaves)
# AllenNlp                     1       -1              1
# Afinn                        0        0              0
# Vader                        0        0              0
# SentiStrength                1        1              1
# Token Weight                 2        0              2
# Token Polarity   Mild Positive  Neutral  Mild Positive
# Triple Weight             1.33     None           None
# Triple Polarity  Mild Positive     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens              (the, dog)          (bit)  (the, mailman)
# AllenNlp                     1              1              -1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength                1              1               1
# Token Weight                 2              2               0
# Token Polarity   Mild Positive  Mild Positive         Neutral
# Triple Weight             1.33           None            None
# Triple Polarity  Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens              (the, boy)       (kicked)    (the, ball)
# AllenNlp                     1             -1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1             -1              1
# Token Weight                 2             -2              2
# Token Polarity   Mild Positive  Mild Negative  Mild Positive
# Triple Weight             0.67           None           None
# Triple Polarity  Weak Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0        1              2
# Tokens             (the, girl)   (sang)      (a, song)
# AllenNlp                     1       -1              1
# Afinn                        0        0              0
# Vader                        0        0              0
# SentiStrength                1        1              1
# Token Weight                 2        0              2
# Token Polarity   Mild Positive  Neutral  Mild Positive
# Triple Weight             1.33     None           None
# Triple Polarity  Mild Positive     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1              2
# Tokens           (the, teacher)       (graded)  (the, papers)
# AllenNlp                      1              1              1
# Afinn                         0              0              0
# Vader                         0              0              0
# SentiStrength                 1              1              1
# Token Weight                  2              2              2
# Token Polarity    Mild Positive  Mild Positive  Mild Positive
# Triple Weight               2.0           None           None
# Triple Polarity   Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens              (the, car)          (hit)    (the, tree)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens            (the, storm)      (knocked)  (power, lines)
# AllenNlp                     1              1              -1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength               -1              1               1
# Token Weight                 0              2               0
# Token Polarity         Neutral  Mild Positive         Neutral
# Triple Weight             0.67           None            None
# Triple Polarity  Weak Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                1        2
# Tokens             (the, baby)            cried   (milk)
# AllenNlp                     1               -1       -1
# Afinn                        0               -1        0
# Vader                        0               -1        0
# SentiStrength                1               -1        1
# Token Weight                 2               -4        0
# Token Polarity   Mild Positive  Strong Negative  Neutral
# Triple Weight            -0.67             None     None
# Triple Polarity  Weak Negative             None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens             (the, cook)         (made)       (dinner)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0         1              2
# Tokens           (the, student)  (passed)    (the, exam)
# AllenNlp                      1        -1              1
# Afinn                         0         0              0
# Vader                         0         0              0
# SentiStrength                 1         1              1
# Token Weight                  2         0              2
# Token Polarity    Mild Positive   Neutral  Mild Positive
# Triple Weight              1.33      None           None
# Triple Polarity   Mild Positive      None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                1                  2
# Tokens              (the, company)       (launched)  (a, new, product)
# AllenNlp                         1                1                  1
# Afinn                            0                1                  0
# Vader                            0                1                  0
# SentiStrength                    1                1                  1
# Token Weight                     2                4                  2
# Token Polarity       Mild Positive  Strong Positive      Mild Positive
# Triple Weight                 2.67             None               None
# Triple Polarity  Moderate Positive             None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, singer)      performed        (stage)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, singer)       medicine        (stage)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0            1              2
# Tokens           (the, farmer)  (harvested)   (the, crops)
# AllenNlp                     1           -1              1
# Afinn                        0            0              0
# Vader                        0            0              0
# SentiStrength                1            1              1
# Token Weight                 2            0              2
# Token Polarity   Mild Positive      Neutral  Mild Positive
# Triple Weight             1.33         None           None
# Triple Polarity  Mild Positive         None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, artist)      (painted)   (a, picture)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0         1              2
# Tokens              (the, dog)  (chased)     (the, cat)
# AllenNlp                     1         1              1
# Afinn                        0         0              0
# Vader                        0         0              0
# SentiStrength                1        -1              1
# Token Weight                 2         0              2
# Token Polarity   Mild Positive   Neutral  Mild Positive
# Triple Weight             1.33      None           None
# Triple Polarity  Mild Positive      None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens             (the, bird)        (built)      (a, nest)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1              2
# Tokens           (the, teacher)       (taught)  (the, lesson)
# AllenNlp                      1              1              1
# Afinn                         0              0              0
# Vader                         0              0              0
# SentiStrength                 1              1              1
# Token Weight                  2              2              2
# Token Polarity    Mild Positive  Mild Positive  Mild Positive
# Triple Weight               2.0           None           None
# Triple Polarity   Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                  1              2
# Tokens                (the, child)             played     (the, toy)
# AllenNlp                         1                  1              1
# Afinn                            0                  0              0
# Vader                            0                  1              0
# SentiStrength                    1                  1              1
# Token Weight                     2                  3              2
# Token Polarity       Mild Positive  Moderate Positive  Mild Positive
# Triple Weight                 2.33               None           None
# Triple Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1               2
# Tokens           (the, company)     (released)  (a, statement)
# AllenNlp                      1              1               1
# Afinn                         0              0               0
# Vader                         0              0               0
# SentiStrength                 1              1               1
# Token Weight                  2              2               2
# Token Polarity    Mild Positive  Mild Positive   Mild Positive
# Triple Weight               2.0           None            None
# Triple Polarity   Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                  1              2
# Tokens                 (the, band)           (played)   (a, concert)
# AllenNlp                         1                  1              1
# Afinn                            0                  0              0
# Vader                            0                  1              0
# SentiStrength                    1                  1              1
# Token Weight                     2                  3              2
# Token Polarity       Mild Positive  Moderate Positive  Mild Positive
# Triple Weight                 2.33               None           None
# Triple Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens           (the, doctor)     (examined)  (the, patient)
# AllenNlp                     1              1               1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength                1              1               1
# Token Weight                 2              2               2
# Token Polarity   Mild Positive  Mild Positive   Mild Positive
# Triple Weight              2.0           None            None
# Triple Polarity  Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens           (the, engineer)     (designed)  (the, bridge)
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Triple Weight                2.0           None           None
# Triple Polarity    Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                 0              1                  2
# Tokens           (the, scientist)    (conducted)  (the, experiment)
# AllenNlp                        1              1                  1
# Afinn                           0              0                  0
# Vader                           0              0                  0
# SentiStrength                   1              1                  1
# Token Weight                    2              2                  2
# Token Polarity      Mild Positive  Mild Positive      Mild Positive
# Triple Weight                 2.0           None               None
# Triple Polarity     Mild Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens           (the, worker)    (assembled)  (the, machine)
# AllenNlp                     1              1               1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength                1              1               1
# Token Weight                 2              2               2
# Token Polarity   Mild Positive  Mild Positive   Mild Positive
# Triple Weight              2.0           None            None
# Triple Polarity  Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1                2
# Tokens               (the, author)        (wrote)       (a, novel)
# AllenNlp                         1              1                1
# Afinn                            0              0                1
# Vader                            0              0                1
# SentiStrength                    1              1                1
# Token Weight                     2              2                4
# Token Polarity       Mild Positive  Mild Positive  Strong Positive
# Triple Weight                 2.67           None             None
# Triple Polarity  Moderate Positive           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, player)       (scored)      (a, goal)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2
# Tokens           (the, photographer)         (took)   (a, picture)
# AllenNlp                           1              1              1
# Afinn                              0              0              0
# Vader                              0              0              0
# SentiStrength                      1              1              1
# Token Weight                       2              2              2
# Token Polarity         Mild Positive  Mild Positive  Mild Positive
# Triple Weight                    2.0           None           None
# Triple Polarity        Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0           1                2
# Tokens           (police, officer)  (arrested)   (the, suspect)
# AllenNlp                         1           1               -1
# Afinn                            0          -1               -1
# Vader                            0          -1               -1
# SentiStrength                    1           1               -1
# Token Weight                     2           0               -4
# Token Polarity       Mild Positive     Neutral  Strong Negative
# Triple Weight                -0.67        None             None
# Triple Polarity      Weak Negative        None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens             (the, chef)       (cooked)      (a, meal)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens           (the, musician)     (composed)      (a, song)
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Triple Weight                2.0           None           None
# Triple Polarity    Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                  1              2
# Tokens             (the, designer)          (created)   (a, website)
# AllenNlp                         1                  1              1
# Afinn                            0                  0              0
# Vader                            0                  1              0
# SentiStrength                    1                  1              1
# Token Weight                     2                  3              2
# Token Polarity       Mild Positive  Moderate Positive  Mild Positive
# Triple Weight                 2.33               None           None
# Triple Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                1              2
# Tokens              (the, athlete)            (won)    (the, race)
# AllenNlp                         1                1              1
# Afinn                            0                1              0
# Vader                            0                1              0
# SentiStrength                    1                1              1
# Token Weight                     2                4              2
# Token Polarity       Mild Positive  Strong Positive  Mild Positive
# Triple Weight                 2.67             None           None
# Triple Polarity  Moderate Positive             None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                   0              1              2
# Tokens           (the, businessman)         (made)      (a, deal)
# AllenNlp                          1              1              1
# Afinn                             0              0              0
# Vader                             0              0              0
# SentiStrength                     1              1              1
# Token Weight                      2              2              2
# Token Polarity        Mild Positive  Mild Positive  Mild Positive
# Triple Weight                   2.0           None           None
# Triple Polarity       Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, driver)        (drove)     (the, car)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, writer)        (wrote)  (an, article)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1             2
# Tokens           (the, teacher)         (gave)  (a, lecture)
# AllenNlp                      1              1            -1
# Afinn                         0              0             0
# Vader                         0              0             0
# SentiStrength                 1              1             1
# Token Weight                  2              2             0
# Token Polarity    Mild Positive  Mild Positive       Neutral
# Triple Weight              1.33           None          None
# Triple Polarity   Mild Positive           None          None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1              2
# Tokens           (the, student)        studied    (the, test)
# AllenNlp                      1              1              1
# Afinn                         0              0              0
# Vader                         0              0              0
# SentiStrength                 1              1              1
# Token Weight                  2              2              2
# Token Polarity    Mild Positive  Mild Positive  Mild Positive
# Triple Weight               2.0           None           None
# Triple Polarity   Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1                   2
# Tokens           (the, company)        (hired)  (a, new, employee)
# AllenNlp                      1              1                   1
# Afinn                         0              0                   0
# Vader                         0              0                   0
# SentiStrength                 1              1                   1
# Token Weight                  2              2                   2
# Token Polarity    Mild Positive  Mild Positive       Mild Positive
# Triple Weight               2.0           None                None
# Triple Polarity   Mild Positive           None                None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                2
# Tokens           (the, doctor)      (treated)   (the, illness)
# AllenNlp                     1              1               -1
# Afinn                        0              0               -1
# Vader                        0              0               -1
# SentiStrength                1              1               -1
# Token Weight                 2              2               -4
# Token Polarity   Mild Positive  Mild Positive  Strong Negative
# Triple Weight              0.0           None             None
# Triple Polarity        Neutral           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, artist)     (sculpted)    (a, statue)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0        1                2
# Tokens              (the, dog)   barked  (the, stranger)
# AllenNlp                     1       -1               -1
# Afinn                        0        0                0
# Vader                        0        0                0
# SentiStrength                1        1                1
# Token Weight                 2        0                0
# Token Polarity   Mild Positive  Neutral          Neutral
# Triple Weight             0.67     None             None
# Triple Polarity  Weak Positive     None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens             (the, bird)           flew     (the, sky)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1               2
# Tokens           (the, teacher)       (graded)  (the, quizzes)
# AllenNlp                      1              1               1
# Afinn                         0              0               0
# Vader                         0              0               0
# SentiStrength                 1              1               1
# Token Weight                  2              2               2
# Token Polarity    Mild Positive  Mild Positive   Mild Positive
# Triple Weight               2.0           None            None
# Triple Polarity   Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                1               2
# Tokens              (the, car)            broke  (the, highway)
# AllenNlp                     1               -1               1
# Afinn                        0               -1               0
# Vader                        0               -1               0
# SentiStrength                1               -1               1
# Token Weight                 2               -4               2
# Token Polarity   Mild Positive  Strong Negative   Mild Positive
# Triple Weight              0.0             None            None
# Triple Polarity        Neutral             None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1           2
# Tokens            (the, storm)       (caused)  (a, flood)
# AllenNlp                     1              1          -1
# Afinn                        0              0           0
# Vader                        0              0           0
# SentiStrength               -1              1           1
# Token Weight                 0              2           0
# Token Polarity         Neutral  Mild Positive     Neutral
# Triple Weight             0.67           None        None
# Triple Polarity  Weak Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0        1              2
# Tokens             (the, baby)    slept   (the, night)
# AllenNlp                     1       -1              1
# Afinn                        0        0              0
# Vader                        0        0              0
# SentiStrength                1        1              1
# Token Weight                 2        0              2
# Token Polarity   Mild Positive  Neutral  Mild Positive
# Triple Weight             1.33     None           None
# Triple Polarity  Mild Positive     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                1                   2
# Tokens                 (the, cook)       (prepared)  (the, ingredients)
# AllenNlp                         1                1                   1
# Afinn                            0                1                   0
# Vader                            0                1                   0
# SentiStrength                    1                1                   1
# Token Weight                     2                4                   2
# Token Polarity       Mild Positive  Strong Positive       Mild Positive
# Triple Weight                 2.67             None                None
# Triple Polarity  Moderate Positive             None                None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1                  2
# Tokens           (the, student)    (completed)  (the, assignment)
# AllenNlp                      1              1                  1
# Afinn                         0              0                  0
# Vader                         0              0                  0
# SentiStrength                 1              1                  1
# Token Weight                  2              2                  2
# Token Polarity    Mild Positive  Mild Positive      Mild Positive
# Triple Weight               2.0           None               None
# Triple Polarity   Mild Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1              2
# Tokens           (the, company)     (expanded)  (its, market)
# AllenNlp                      1              1              1
# Afinn                         0              0              0
# Vader                         0              0              0
# SentiStrength                 1              1              1
# Token Weight                  2              2              2
# Token Polarity    Mild Positive  Mild Positive  Mild Positive
# Triple Weight               2.0           None           None
# Triple Polarity   Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, singer)     (recorded)    (an, album)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, doctor)    (performed)      (surgery)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens           (the, farmer)         tended  (the, animals)
# AllenNlp                     1              1               1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength                1              1               1
# Token Weight                 2              2               2
# Token Polarity   Mild Positive  Mild Positive   Mild Positive
# Triple Weight              2.0           None            None
# Triple Polarity  Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens           (the, artist)         (drew)  (a, portrait)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens              (the, dog)      (fetched)    (the, ball)
# AllenNlp                     1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 2              2              2
# Token Polarity   Mild Positive  Mild Positive  Mild Positive
# Triple Weight              2.0           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0        1              2
# Tokens             (the, bird)   (sang)    (a, melody)
# AllenNlp                     1       -1              1
# Afinn                        0        0              0
# Vader                        0        0              0
# SentiStrength                1        1              1
# Token Weight                 2        0              2
# Token Polarity   Mild Positive  Neutral  Mild Positive
# Triple Weight             1.33     None           None
# Triple Polarity  Mild Positive     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1              2
# Tokens           (the, teacher)       (taught)     (a, class)
# AllenNlp                      1              1              1
# Afinn                         0              0              0
# Vader                         0              0              0
# SentiStrength                 1              1              1
# Token Weight                  2              2              2
# Token Polarity    Mild Positive  Mild Positive  Mild Positive
# Triple Weight               2.0           None           None
# Triple Polarity   Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                               0              1              2
# Tokens           (the, company)     (released)   (an, update)
# AllenNlp                      1              1              1
# Afinn                         0              0              0
# Vader                         0              0              0
# SentiStrength                 1              1              1
# Token Weight                  2              2              2
# Token Polarity    Mild Positive  Mild Positive  Mild Positive
# Triple Weight               2.0           None           None
# Triple Polarity   Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0                  1              2
# Tokens                 (the, band)           (played)       (a, gig)
# AllenNlp                         1                  1              1
# Afinn                            0                  0              0
# Vader                            0                  1              0
# SentiStrength                    1                  1              1
# Token Weight                     2                  3              2
# Token Polarity       Mild Positive  Moderate Positive  Mild Positive
# Triple Weight                 2.33               None           None
# Triple Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                2
# Tokens           (the, doctor)    (diagnosed)   (the, illness)
# AllenNlp                     1              1               -1
# Afinn                        0              0               -1
# Vader                        0              0               -1
# SentiStrength                1              1               -1
# Token Weight                 2              2               -4
# Token Polarity   Mild Positive  Mild Positive  Strong Negative
# Triple Weight              0.0           None             None
# Triple Polarity        Neutral           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                2
# Tokens           (the, engineer)  (constructed)  (the, building)
# AllenNlp                       1              1                1
# Afinn                          0              0                0
# Vader                          0              0                0
# SentiStrength                  1              1                1
# Token Weight                   2              2                2
# Token Polarity     Mild Positive  Mild Positive    Mild Positive
# Triple Weight                2.0           None             None
# Triple Polarity    Mild Positive           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                 0              1                  2
# Tokens           (the, scientist)   (discovered)  (a, new, element)
# AllenNlp                        1              1                  1
# Afinn                           0              0                  0
# Vader                           0              0                  0
# SentiStrength                   1              1                  1
# Token Weight                    2              2                  2
# Token Polarity      Mild Positive  Mild Positive      Mild Positive
# Triple Weight                 2.0           None               None
# Triple Polarity     Mild Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0           1                 2
# Tokens           (the, worker)  (repaired)  (the, equipment)
# AllenNlp                     1          -1                 1
# Afinn                        0           0                 0
# Vader                        0           0                 0
# SentiStrength                1           1                 1
# Token Weight                 2           0                 2
# Token Polarity   Mild Positive     Neutral     Mild Positive
# Triple Weight             1.33        None              None
# Triple Polarity  Mild Positive        None              None
# ...
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                             0.0           None
# Triple Polarity                                       Neutral           None
#
#                              2
# Tokens               (markets)
# AllenNlp                     1
# Afinn                        0
# Vader                        0
# SentiStrength                1
# Token Weight                 2
# Token Polarity   Mild Positive
# Triple Weight             None
# Triple Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                             0              1  \
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                           -0.67           None
# Triple Polarity                                 Weak Negative           None
#
#                                  2
# Tokens           (less, transport)
# AllenNlp                        -1
# Afinn                            0
# Vader                            0
# SentiStrength                    1
# Token Weight                     0
# Token Polarity             Neutral
# Triple Weight                 None
# Triple Polarity               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          1.33           None
# Triple Polarity               Mild Positive           None
#
#                                      2
# Tokens           (the, eastern, sudan)
# AllenNlp                             1
# Afinn                                0
# Vader                                0
# SentiStrength                        1
# Token Weight                         2
# Token Polarity           Mild Positive
# Triple Weight                     None
# Triple Polarity                   None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          0.67           None
# Triple Polarity               Weak Positive           None
#
#                                         2
# Tokens           (flood, -, prone, areas)
# AllenNlp                               -1
# Afinn                                   0
# Vader                                   0
# SentiStrength                           1
# Token Weight                            0
# Token Polarity                    Neutral
# Triple Weight                        None
# Triple Polarity                      None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (highly, saturated, soils)          cause
# AllenNlp                                  1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              2              2
# Token Polarity                Mild Positive  Mild Positive
# Triple Weight                          1.33           None
# Triple Polarity               Mild Positive           None
#
#                                         2
# Tokens           (flood, -, prone, areas)
# AllenNlp                               -1
# Afinn                                   0
# Vader                                   0
# SentiStrength                           1
# Token Weight                            0
# Token Polarity                    Neutral
# Triple Weight                        None
# Triple Polarity                      None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens                  (rain)       (caused)       (floods)
# AllenNlp                    -1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 0              2              2
# Token Polarity         Neutral  Mild Positive  Mild Positive
# Triple Weight             1.33           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1  \
# Tokens                (floods)  (have, displaced)
# AllenNlp                     1                 -1
# Afinn                        0                  0
# Vader                        0                  0
# SentiStrength                1                 -1
# Token Weight                 2                 -2
# Token Polarity   Mild Positive      Mild Negative
# Triple Weight             0.67               None
# Triple Polarity  Weak Positive               None
#
#                                              2
# Tokens           (more, than, 100,000, people)
# AllenNlp                                     1
# Afinn                                        0
# Vader                                        0
# SentiStrength                                1
# Token Weight                                 2
# Token Polarity                   Mild Positive
# Triple Weight                             None
# Triple Polarity                           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1               2
# Tokens                (floods)  (have, displaced)  (south, sudan)
# AllenNlp                     1                 -1               1
# Afinn                        0                  0               0
# Vader                        0                  0               0
# SentiStrength                1                 -1               1
# Token Weight                 2                 -2               2
# Token Polarity   Mild Positive      Mild Negative   Mild Positive
# Triple Weight             0.67               None            None
# Triple Polarity  Weak Positive               None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                  2
# Tokens                (floods)        (raise)            (fears)
# AllenNlp                     1              1                 -1
# Afinn                        0              0                  0
# Vader                        0              0                 -1
# SentiStrength                1              1                 -1
# Token Weight                 2              2                 -3
# Token Polarity   Mild Positive  Mild Positive  Moderate Negative
# Triple Weight             0.33           None               None
# Triple Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (highly, saturated, soils)         impact
# AllenNlp                                  1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              2              2
# Token Polarity                Mild Positive  Mild Positive
# Triple Weight                          0.33           None
# Triple Polarity               Weak Positive           None
#
#                                            2
# Tokens           (the, war, -, torn, nation)
# AllenNlp                                  -1
# Afinn                                     -1
# Vader                                      0
# SentiStrength                             -1
# Token Weight                              -3
# Token Polarity             Moderate Negative
# Triple Weight                           None
# Triple Polarity                         None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                0              1  \
# Tokens           (floods, devastatingly, impact)         impact
# AllenNlp                                      -1              1
# Afinn                                          0              0
# Vader                                         -1              0
# SentiStrength                                 -1              1
# Token Weight                                  -3              2
# Token Polarity                 Moderate Negative  Mild Positive
# Triple Weight                               0.67           None
# Triple Polarity                    Weak Positive           None
#
#                                  2
# Tokens            (food, security)
# AllenNlp                         1
# Afinn                            0
# Vader                            1
# SentiStrength                    1
# Token Weight                     3
# Token Polarity   Moderate Positive
# Triple Weight                 None
# Triple Polarity               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                0              1  \
# Tokens           (floods, devastatingly, impact)         impact
# AllenNlp                                      -1              1
# Afinn                                          0              0
# Vader                                         -1              0
# SentiStrength                                 -1              1
# Token Weight                                  -3              2
# Token Polarity                 Moderate Negative  Mild Positive
# Triple Weight                              -1.33           None
# Triple Polarity                    Mild Negative           None
#
#                                            2
# Tokens           (the, war, -, torn, nation)
# AllenNlp                                  -1
# Afinn                                     -1
# Vader                                      0
# SentiStrength                             -1
# Token Weight                              -3
# Token Polarity             Moderate Negative
# Triple Weight                           None
# Triple Polarity                         None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0              1              2
# Tokens           (excessive, overthinking)          leads     (insomnia)
# AllenNlp                                -1              1             -1
# Afinn                                    0              0             -1
# Vader                                    0              0              0
# SentiStrength                           -1              1              1
# Token Weight                            -2              2             -1
# Token Polarity               Mild Negative  Mild Positive  Weak Negative
# Triple Weight                        -0.33           None           None
# Triple Polarity              Weak Negative           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                  (stress)       (caused)     (insomnia)
# AllenNlp                      -1              1             -1
# Afinn                         -1              0             -1
# Vader                         -1              0              0
# SentiStrength                 -1              1              1
# Token Weight                  -4              2             -1
# Token Polarity   Strong Negative  Mild Positive  Weak Negative
# Triple Weight               -1.0           None           None
# Triple Polarity    Weak Negative           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                2
# Tokens              (insomnia)       (causes)         (stress)
# AllenNlp                    -1              1               -1
# Afinn                       -1              0               -1
# Vader                        0              0               -1
# SentiStrength                1              1               -1
# Token Weight                -1              2               -4
# Token Polarity   Weak Negative  Mild Positive  Strong Negative
# Triple Weight             -1.0           None             None
# Triple Polarity  Weak Negative           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0              1              2
# Tokens           (excessive, overthinking)        results     (insomnia)
# AllenNlp                                -1              1             -1
# Afinn                                    0              0             -1
# Vader                                    0              0              0
# SentiStrength                           -1              1              1
# Token Weight                            -2              2             -1
# Token Polarity               Mild Negative  Mild Positive  Weak Negative
# Triple Weight                        -0.33           None           None
# Triple Polarity              Weak Negative           None           None

# %%
from nltk.corpus import stopwords
set(stopwords.words('english'))

def GenerateTokens(causalSentences):
    marks = ['.',',','(',')','-',':',';','/',"'s",'_','__','--','"', '’', '—']
    token_list = []
   
    for sent in causalSentences:
        token_tuple = []
        for token in sent:
            if str(token) not in marks:
                if str(token) not in stopwords.words():
                    token_tuple.append(str(token))
        token_list.append(token_tuple)
    return token_list

# %%
def Allen_sents_TokenLevel(token_list):
    allen_word = []
    allen_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks: 
                #print(token)
            preds = predictor1.predict(str(token))
                #print(preds['label'][0])
            label = preds['label'][0]
            if label is '0':
                allen_tuple.append(-1)
                    #allen_word.append(-1)
            else:
                    #allen_word.append(1)
                allen_tuple.append(1)
        allen_word.append(allen_tuple)
        allen_tuple = []
    return allen_word

# %%
def Afinn_sents_TokenLevel(token_list):
    afinn_word = []
    afinn_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
            #if str(token) not in marks:
                #print(token)
            score = afn.score(str(token))
            if score > 0:
                    #print('positive')
                afinn_tuple.append(1)
            elif score < 0:
                    #print('negative')
                afinn_tuple.append(-1)
            else:
                    #print('neutral')
                afinn_tuple.append(0)
        afinn_word.append(afinn_tuple)
        afinn_tuple = []
    return afinn_word

# %%
def Vader_sents_TokenLevel(token_list):
    vader_word = []
    vader_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
            vs = analyzer.polarity_scores(str(token))
            compound = vs['compound']
            if compound >= 0.05:
                vader_tuple.append(1)   
            elif compound <= -0.05 :
                vader_tuple.append(-1)
            elif  compound > -0.05 and compound < 0.05:
                vader_tuple.append(0)
        vader_word.append(vader_tuple)
        vader_tuple = []
    return vader_word

# %%
def Senti_sents_TokenLevel(token_list):
    senti_word = []
    senti_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
                #print(token)
            result = senti.getSentiment(str(token), score='binary')
                #print(result)
            if result[0]==1:
                    #print('Positive')
                senti_tuple.append(1)
            elif result[0]==-1:
                    #print('Negative')
                senti_tuple.append(-1)
            else:
                    #print('Neutral')
                senti_tuple.append(0)
        senti_word.append(senti_tuple)
        senti_tuple = []
    return senti_word

# %%
token_list = GenerateTokens(causalSents)
allen_word = Allen_sents_TokenLevel(token_list)
afinn_word = Afinn_sents_TokenLevel(token_list)
vader_word = Vader_sents_TokenLevel(token_list)   
senti_word = Senti_sents_TokenLevel(token_list)

sum_list = []
sum_tup = []
limit= len(causalSents)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

sentsWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    sentsWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)

def dataframe_WordLevel(i):
    df = pd.DataFrame([token_list[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],sentsWeight_TokenLevel[i],SentencePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    replicator(df)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1        2              3
# Tokens                      rain         caused  wilting        flowers
# AllenNlp                      -1              1       -1              1
# Afinn                          0              0        0              0
# Vader                          0              0        0              0
# SentiStrength                  1              1        1              1
# Token Weight                   0              2        0              2
# Token Polarity           Neutral  Mild Positive  Neutral  Mild Positive
# Sentence Weight              1.0           None     None           None
# Sentence Polarity  Weak Positive           None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                  1              2
# Tokens                           sun              rises           east
# AllenNlp                           1                  1              1
# Afinn                              0                  1              0
# Vader                              0                  0              0
# SentiStrength                      1                  1              1
# Token Weight                       2                  3              2
# Token Polarity         Mild Positive  Moderate Positive  Mild Positive
# Sentence Weight                 2.33               None           None
# Sentence Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2
# Tokens                      wind     blew   leaves
# AllenNlp                       1       -1       -1
# Afinn                          0        0        0
# Vader                          0        0        0
# SentiStrength                  1        1        1
# Token Weight                   2        0        0
# Token Polarity     Mild Positive  Neutral  Neutral
# Sentence Weight             0.67     None     None
# Sentence Polarity  Weak Positive     None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1
# Tokens                       bit  mailman
# AllenNlp                       1       -1
# Afinn                          0        0
# Vader                          0        0
# SentiStrength                  1        1
# Token Weight                   2        0
# Token Polarity     Mild Positive  Neutral
# Sentence Weight              1.0     None
# Sentence Polarity  Weak Positive     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                       boy         kicked           ball
# AllenNlp                       1             -1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1             -1              1
# Token Weight                   2             -2              2
# Token Polarity     Mild Positive  Mild Negative  Mild Positive
# Sentence Weight             0.67           None           None
# Sentence Polarity  Weak Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1
# Tokens                      girl           song
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight              2.0           None
# Sentence Polarity  Mild Positive           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   teacher         graded         papers
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                       car            hit           tree
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2              3
# Tokens                     storm        knocked          power          lines
# AllenNlp                      -1              1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                 -1              1              1              1
# Token Weight                  -2              2              2              2
# Token Polarity     Mild Negative  Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              1.0           None           None           None
# Sentence Polarity  Weak Positive           None           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                1        2
# Tokens                      baby            cried     milk
# AllenNlp                       1               -1       -1
# Afinn                          0               -1        0
# Vader                          0               -1        0
# SentiStrength                  1               -1        1
# Token Weight                   2               -4        0
# Token Polarity     Mild Positive  Strong Negative  Neutral
# Sentence Weight            -0.67             None     None
# Sentence Polarity  Weak Negative             None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      cook           made         dinner
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2
# Tokens                   student   passed     exam
# AllenNlp                       1       -1       -1
# Afinn                          0        0        0
# Vader                          0        0        0
# SentiStrength                  1        1        1
# Token Weight                   2        0        0
# Token Polarity     Mild Positive  Neutral  Neutral
# Sentence Weight             0.67     None     None
# Sentence Polarity  Weak Positive     None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                1              2
# Tokens                       company         launched        product
# AllenNlp                           1                1              1
# Afinn                              0                1              0
# Vader                              0                1              0
# SentiStrength                      1                1              1
# Token Weight                       2                4              2
# Token Polarity         Mild Positive  Strong Positive  Mild Positive
# Sentence Weight                 2.67             None           None
# Sentence Polarity  Moderate Positive             None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    singer      performed          stage
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    doctor     prescribed       medicine
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0          1              2
# Tokens                    farmer  harvested          crops
# AllenNlp                       1         -1              1
# Afinn                          0          0              0
# Vader                          0          0              0
# SentiStrength                  1          1              1
# Token Weight                   2          0              2
# Token Polarity     Mild Positive    Neutral  Mild Positive
# Sentence Weight             1.33       None           None
# Sentence Polarity  Mild Positive       None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    artist        painted        picture
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                          0
# Tokens              chased
# AllenNlp                 1
# Afinn                    0
# Vader                    0
# SentiStrength           -1
# Token Weight             0
# Token Polarity     Neutral
# Sentence Weight        0.0
# Sentence Polarity  Neutral
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      bird          built           nest
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1        2
# Tokens                   teacher         taught   lesson
# AllenNlp                       1              1       -1
# Afinn                          0              0        0
# Vader                          0              0        0
# SentiStrength                  1              1        1
# Token Weight                   2              2        0
# Token Polarity     Mild Positive  Mild Positive  Neutral
# Sentence Weight             1.33           None     None
# Sentence Polarity  Mild Positive           None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                  1              2
# Tokens                         child             played            toy
# AllenNlp                           1                  1              1
# Afinn                              0                  0              0
# Vader                              0                  1              0
# SentiStrength                      1                  1              1
# Token Weight                       2                  3              2
# Token Polarity         Mild Positive  Moderate Positive  Mild Positive
# Sentence Weight                 2.33               None           None
# Sentence Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1          2
# Tokens                   company       released  statement
# AllenNlp                       1              1         -1
# Afinn                          0              0          0
# Vader                          0              0          0
# SentiStrength                  1              1          1
# Token Weight                   2              2          0
# Token Polarity     Mild Positive  Mild Positive    Neutral
# Sentence Weight             1.33           None       None
# Sentence Polarity  Mild Positive           None       None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                  1              2
# Tokens                          band             played        concert
# AllenNlp                           1                  1              1
# Afinn                              0                  0              0
# Vader                              0                  1              0
# SentiStrength                      1                  1              1
# Token Weight                       2                  3              2
# Token Polarity         Mild Positive  Moderate Positive  Mild Positive
# Sentence Weight                 2.33               None           None
# Sentence Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    doctor       examined        patient
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                  engineer       designed         bridge
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                 scientist      conducted     experiment
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    worker      assembled        machine
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1
# Tokens                    author          wrote
# AllenNlp                      -1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   0              2
# Token Polarity           Neutral  Mild Positive
# Sentence Weight              1.0           None
# Sentence Polarity  Weak Positive           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    player         scored           goal
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1
# Tokens              photographer        picture
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight              2.0           None
# Sentence Polarity  Mild Positive           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1         2                3
# Tokens                    police        officer  arrested          suspect
# AllenNlp                      -1              1         1               -1
# Afinn                          0              0        -1               -1
# Vader                          0              0        -1               -1
# SentiStrength                  1              1         1               -1
# Token Weight                   0              2         0               -4
# Token Polarity           Neutral  Mild Positive   Neutral  Strong Negative
# Sentence Weight             -0.5           None      None             None
# Sentence Polarity  Weak Negative           None      None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      chef         cooked           meal
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                  musician       composed           song
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                  1              2
# Tokens                      designer            created        website
# AllenNlp                           1                  1              1
# Afinn                              0                  0              0
# Vader                              0                  1              0
# SentiStrength                      1                  1              1
# Token Weight                       2                  3              2
# Token Polarity         Mild Positive  Moderate Positive  Mild Positive
# Sentence Weight                 2.33               None           None
# Sentence Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1
# Tokens                   athlete           race
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight              2.0           None
# Sentence Polarity  Mild Positive           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens               businessman           made           deal
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    driver          drove            car
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    writer          wrote        article
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   teacher           gave        lecture
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   student        studied           test
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   company          hired       employee
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                2
# Tokens                    doctor        treated          illness
# AllenNlp                       1              1               -1
# Afinn                          0              0               -1
# Vader                          0              0               -1
# SentiStrength                  1              1               -1
# Token Weight                   2              2               -4
# Token Polarity     Mild Positive  Mild Positive  Strong Negative
# Sentence Weight              0.0           None             None
# Sentence Polarity        Neutral           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    artist       sculpted         statue
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                          0         1
# Tokens              barked  stranger
# AllenNlp                -1        -1
# Afinn                    0         0
# Vader                    0         0
# SentiStrength            1         1
# Token Weight             0         0
# Token Polarity     Neutral   Neutral
# Sentence Weight        0.0      None
# Sentence Polarity  Neutral      None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      bird           flew            sky
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   teacher         graded        quizzes
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                1              2
# Tokens                       car            broke        highway
# AllenNlp                       1               -1              1
# Afinn                          0               -1              0
# Vader                          0               -1              0
# SentiStrength                  1               -1              1
# Token Weight                   2               -4              2
# Token Polarity     Mild Positive  Strong Negative  Mild Positive
# Sentence Weight              0.0             None           None
# Sentence Polarity        Neutral             None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1        2
# Tokens                     storm         caused    flood
# AllenNlp                      -1              1       -1
# Afinn                          0              0        0
# Vader                          0              0        0
# SentiStrength                 -1              1        1
# Token Weight                  -2              2        0
# Token Polarity     Mild Negative  Mild Positive  Neutral
# Sentence Weight              0.0           None     None
# Sentence Polarity        Neutral           None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1              2
# Tokens                      baby    slept          night
# AllenNlp                       1       -1              1
# Afinn                          0        0              0
# Vader                          0        0              0
# SentiStrength                  1        1              1
# Token Weight                   2        0              2
# Token Polarity     Mild Positive  Neutral  Mild Positive
# Sentence Weight             1.33     None           None
# Sentence Polarity  Mild Positive     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                1              2
# Tokens                          cook         prepared    ingredients
# AllenNlp                           1                1              1
# Afinn                              0                1              0
# Vader                              0                1              0
# SentiStrength                      1                1              1
# Token Weight                       2                4              2
# Token Polarity         Mild Positive  Strong Positive  Mild Positive
# Sentence Weight                 2.67             None           None
# Sentence Polarity  Moderate Positive             None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1           2
# Tokens                   student      completed  assignment
# AllenNlp                       1              1          -1
# Afinn                          0              0           0
# Vader                          0              0           0
# SentiStrength                  1              1           1
# Token Weight                   2              2           0
# Token Polarity     Mild Positive  Mild Positive     Neutral
# Sentence Weight             1.33           None        None
# Sentence Polarity  Mild Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   company       expanded         market
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    singer       recorded          album
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    doctor      performed        surgery
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    farmer         tended        animals
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                    artist           drew       portrait
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1
# Tokens                   fetched           ball
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight              2.0           None
# Sentence Polarity  Mild Positive           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1
# Tokens                      bird         melody
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight              2.0           None
# Sentence Polarity  Mild Positive           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   teacher         taught          class
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                   company       released         update
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                  1              2
# Tokens                          band             played            gig
# AllenNlp                           1                  1              1
# Afinn                              0                  0              0
# Vader                              0                  1              0
# SentiStrength                      1                  1              1
# Token Weight                       2                  3              2
# Token Polarity         Mild Positive  Moderate Positive  Mild Positive
# Sentence Weight                 2.33               None           None
# Sentence Polarity  Moderate Positive               None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                2
# Tokens                    doctor      diagnosed          illness
# AllenNlp                       1              1               -1
# Afinn                          0              0               -1
# Vader                          0              0               -1
# SentiStrength                  1              1               -1
# Token Weight                   2              2               -4
# Token Polarity     Mild Positive  Mild Positive  Strong Negative
# Sentence Weight              0.0           None             None
# Sentence Polarity        Neutral           None             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                  engineer    constructed       building
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                 scientist     discovered        element
# AllenNlp                       1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive
# Sentence Weight              2.0           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0         1              2
# Tokens                    worker  repaired      equipment
# AllenNlp                       1        -1              1
# Afinn                          0         0              0
# Vader                          0         0              0
# SentiStrength                  1         1              1
# Token Weight                   2         0              2
# Token Polarity     Mild Positive   Neutral  Mild Positive
# Sentence Weight             1.33      None           None
# Sentence Polarity  Mild Positive      None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1        2              3
# Tokens                    author          wrote    short          story
# AllenNlp                      -1              1       -1              1
# Afinn                          0              0        0              0
# Vader                          0              0        0              0
# SentiStrength                  1              1        1              1
# Token Weight                   0              2        0              2
# Token Polarity           Neutral  Mild Positive  Neutral  Mild Positive
# Sentence Weight              1.0           None     None           None
# Sentence Polarity  Weak Positive           None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1                2
# Tokens                        player           made             save
# AllenNlp                           1              1                1
# ...
# Sentence Polarity  Weak Positive     None     None           None     None
#
#                           5        6        7              8
# Tokens             flooding    flood    prone          areas
# AllenNlp                 -1       -1       -1              1
# Afinn                     0        0        0              0
# Vader                     0        0        0              0
# SentiStrength             1        1        1              1
# Token Weight              0        0        0              2
# Token Polarity      Neutral  Neutral  Neutral  Mild Positive
# Sentence Weight        None     None     None           None
# Sentence Polarity      None     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2              3        4  \
# Tokens                persistent    heavy    rains        eastern    sudan
# AllenNlp                       1       -1       -1              1       -1
# Afinn                          0        0        0              0        0
# Vader                          0        0        0              0        0
# SentiStrength                  1        1        1              1        1
# Token Weight                   2        0        0              2        0
# Token Polarity     Mild Positive  Neutral  Neutral  Mild Positive  Neutral
# Sentence Weight             0.67     None     None           None     None
# Sentence Polarity  Weak Positive     None     None           None     None
#
#                           5        6        7              8
# Tokens             flooding    flood    prone          areas
# AllenNlp                 -1       -1       -1              1
# Afinn                     0        0        0              0
# Vader                     0        0        0              0
# SentiStrength             1        1        1              1
# Token Weight              0        0        0              2
# Token Polarity      Neutral  Neutral  Neutral  Mild Positive
# Sentence Weight        None     None     None           None
# Sentence Polarity      None     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0          1        2         3        4  \
# Tokens                    highly  saturated    soils  flooding    flood
# AllenNlp                       1         -1       -1        -1       -1
# Afinn                          0          0        0         0        0
# Vader                          0          0        0         0        0
# SentiStrength                  1          1        1         1        1
# Token Weight                   2          0        0         0        0
# Token Polarity     Mild Positive    Neutral  Neutral   Neutral  Neutral
# Sentence Weight             0.57       None     None      None     None
# Sentence Polarity  Weak Positive       None     None      None     None
#
#                          5              6
# Tokens               prone          areas
# AllenNlp                -1              1
# Afinn                    0              0
# Vader                    0              0
# SentiStrength            1              1
# Token Weight             0              2
# Token Polarity     Neutral  Mild Positive
# Sentence Weight       None           None
# Sentence Polarity     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      rain         caused         floods
# AllenNlp                      -1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   0              2              2
# Token Polarity           Neutral  Mild Positive  Mild Positive
# Sentence Weight             1.33           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2        3  \
# Tokens                    floods      displaced        100,000    south
# AllenNlp                       1             -1              1       -1
# Afinn                          0              0              0        0
# Vader                          0              0              0        0
# SentiStrength                  1             -1              1        1
# Token Weight                   2             -2              2        0
# Token Polarity     Mild Positive  Mild Negative  Mild Positive  Neutral
# Sentence Weight              0.4           None           None     None
# Sentence Polarity  Weak Positive           None           None     None
#
#                          4
# Tokens               sudan
# AllenNlp                -1
# Afinn                    0
# Vader                    0
# SentiStrength            1
# Token Weight             0
# Token Polarity     Neutral
# Sentence Weight       None
# Sentence Polarity     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2        3  \
# Tokens                    floods      displaced        100,000    south
# AllenNlp                       1             -1              1       -1
# Afinn                          0              0              0        0
# Vader                          0              0              0        0
# SentiStrength                  1             -1              1        1
# Token Weight                   2             -2              2        0
# Token Polarity     Mild Positive  Mild Negative  Mild Positive  Neutral
# Sentence Weight              0.4           None           None     None
# Sentence Polarity  Weak Positive           None           None     None
#
#                          4
# Tokens               sudan
# AllenNlp                -1
# Afinn                    0
# Vader                    0
# SentiStrength            1
# Token Weight             0
# Token Polarity     Neutral
# Sentence Weight       None
# Sentence Polarity     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                  2
# Tokens                    floods          raise              fears
# AllenNlp                       1              1                 -1
# Afinn                          0              0                  0
# Vader                          0              0                 -1
# SentiStrength                  1              1                 -1
# Token Weight                   2              2                 -3
# Token Polarity     Mild Positive  Mild Positive  Moderate Negative
# Sentence Weight             0.33           None               None
# Sentence Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                  1              2  \
# Tokens                    floods      devastatingly         impact
# AllenNlp                       1                 -1              1
# Afinn                          0                  0              0
# Vader                          0                 -1              0
# SentiStrength                  1                 -1              1
# Token Weight                   2                 -3              2
# Token Polarity     Mild Positive  Moderate Negative  Mild Positive
# Sentence Weight             0.86               None           None
# Sentence Polarity  Weak Positive               None           None
#
#                                3                  4              5  \
# Tokens                      food           security           torn
# AllenNlp                       1                  1             -1
# Afinn                          0                  0             -1
# Vader                          0                  1             -1
# SentiStrength                  1                  1              1
# Token Weight                   2                  3             -2
# Token Polarity     Mild Positive  Moderate Positive  Mild Negative
# Sentence Weight             None               None           None
# Sentence Polarity           None               None           None
#
#                                6
# Tokens                    nation
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                  1              2  \
# Tokens                    floods      devastatingly         impact
# AllenNlp                       1                 -1              1
# Afinn                          0                  0              0
# Vader                          0                 -1              0
# SentiStrength                  1                 -1              1
# Token Weight                   2                 -3              2
# Token Polarity     Mild Positive  Moderate Negative  Mild Positive
# Sentence Weight             0.86               None           None
# Sentence Polarity  Weak Positive               None           None
#
#                                3                  4              5  \
# Tokens                      food           security           torn
# AllenNlp                       1                  1             -1
# Afinn                          0                  0             -1
# Vader                          0                  1             -1
# SentiStrength                  1                  1              1
# Token Weight                   2                  3             -2
# Token Polarity     Mild Positive  Moderate Positive  Mild Negative
# Sentence Weight             None               None           None
# Sentence Polarity           None               None           None
#
#                                6
# Tokens                    nation
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                  1              2  \
# Tokens                    floods      devastatingly         impact
# AllenNlp                       1                 -1              1
# Afinn                          0                  0              0
# Vader                          0                 -1              0
# SentiStrength                  1                 -1              1
# Token Weight                   2                 -3              2
# Token Polarity     Mild Positive  Moderate Negative  Mild Positive
# Sentence Weight             0.86               None           None
# Sentence Polarity  Weak Positive               None           None
#
#                                3                  4              5  \
# Tokens                      food           security           torn
# AllenNlp                       1                  1             -1
# Afinn                          0                  0             -1
# Vader                          0                  1             -1
# SentiStrength                  1                  1              1
# Token Weight                   2                  3             -2
# Token Polarity     Mild Positive  Moderate Positive  Mild Negative
# Sentence Weight             None               None           None
# Sentence Polarity           None               None           None
#
#                                6
# Tokens                    nation
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0             1              2              3
# Tokens                 excessive  overthinking          leads       insomnia
# AllenNlp                      -1            -1              1             -1
# Afinn                          0             0              0             -1
# Vader                          0             0              0              0
# SentiStrength                 -1             1              1              1
# Token Weight                  -2             0              2             -1
# Token Polarity     Mild Negative       Neutral  Mild Positive  Weak Negative
# Sentence Weight            -0.25          None           None           None
# Sentence Polarity  Weak Negative          None           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1              2
# Tokens                      stress         caused       insomnia
# AllenNlp                        -1              1             -1
# Afinn                           -1              0             -1
# Vader                           -1              0              0
# SentiStrength                   -1              1              1
# Token Weight                    -4              2             -1
# Token Polarity     Strong Negative  Mild Positive  Weak Negative
# Sentence Weight               -1.0           None           None
# Sentence Polarity    Weak Negative           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0                1
# Tokens                      insomnia           stress
# AllenNlp                          -1               -1
# Afinn                             -1               -1
# Vader                              0               -1
# SentiStrength                      1               -1
# Token Weight                      -1               -4
# Token Polarity         Weak Negative  Strong Negative
# Sentence Weight                 -2.5             None
# Sentence Polarity  Moderate Negative             None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1              2
# Tokens                      stress        results       insomnia
# AllenNlp                        -1              1             -1
# Afinn                           -1              0             -1
# Vader                           -1              0              0
# SentiStrength                   -1              1              1
# Token Weight                    -4              2             -1
# Token Polarity     Strong Negative  Mild Positive  Weak Negative
# Sentence Weight               -1.0           None           None
# Sentence Polarity    Weak Negative           None           None

# %%
totalTriplesWeight_AllLevels = []

limit= len(causalTriples)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(triplesWeight_sentLevel[i])):
        res = triplesWeight_sentLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalTriplesWeight_AllLevels.append(sum_tup)
    
totalTripsPlarity_AllLevels = DetectPolarity(totalTriplesWeight_AllLevels)

df_TripAllLevels = pd.DataFrame(list(zip(causalTriples, triplesWeight_sentLevel, triplesWeight_TokenLevel, totalTriplesWeight_AllLevels, totalTripsPlarity_AllLevels)), 
                             columns =['Causal Triple', 'Weight (Trip_SentLevel)','Weight (Trip_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_TripAllLevels.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_315a9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Triple</th>
#       <th class="col_heading level0 col1" >Weight (Trip_SentLevel)</th>
#       <th class="col_heading level0 col2" >Weight (Trip_TokLevel)</th>
#       <th class="col_heading level0 col3" >Total Weight (All Levels)</th>
#       <th class="col_heading level0 col4" >Overall Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_315a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_315a9_row0_col0" class="data row0 col0" >(the rain, caused, flowers)</td>
#       <td id="T_315a9_row0_col1" class="data row0 col1" >[2]</td>
#       <td id="T_315a9_row0_col2" class="data row0 col2" >[2.0]</td>
#       <td id="T_315a9_row0_col3" class="data row0 col3" >[2.0]</td>
#       <td id="T_315a9_row0_col4" class="data row0 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_315a9_row1_col0" class="data row1 col0" >(the sun, rises, the east)</td>
#       <td id="T_315a9_row1_col1" class="data row1 col1" >[3]</td>
#       <td id="T_315a9_row1_col2" class="data row1 col2" >[2.33]</td>
#       <td id="T_315a9_row1_col3" class="data row1 col3" >[2.67]</td>
#       <td id="T_315a9_row1_col4" class="data row1 col4" >['Moderate Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_315a9_row2_col0" class="data row2 col0" >(the wind, blew, the leaves)</td>
#       <td id="T_315a9_row2_col1" class="data row2 col1" >[2]</td>
#       <td id="T_315a9_row2_col2" class="data row2 col2" >[1.33]</td>
#       <td id="T_315a9_row2_col3" class="data row2 col3" >[1.67]</td>
#       <td id="T_315a9_row2_col4" class="data row2 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_315a9_row3_col0" class="data row3 col0" >(the dog, bit, the mailman)</td>
#       <td id="T_315a9_row3_col1" class="data row3 col1" >[0]</td>
#       <td id="T_315a9_row3_col2" class="data row3 col2" >[1.33]</td>
#       <td id="T_315a9_row3_col3" class="data row3 col3" >[0.67]</td>
#       <td id="T_315a9_row3_col4" class="data row3 col4" >['Weak Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_315a9_row4_col0" class="data row4 col0" >(the boy, kicked, the ball)</td>
#       <td id="T_315a9_row4_col1" class="data row4 col1" >[-2]</td>
#       <td id="T_315a9_row4_col2" class="data row4 col2" >[0.67]</td>
#       <td id="T_315a9_row4_col3" class="data row4 col3" >[-0.67]</td>
#       <td id="T_315a9_row4_col4" class="data row4 col4" >['Weak Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_315a9_row5_col0" class="data row5 col0" >(the girl, sang, a song)</td>
#       <td id="T_315a9_row5_col1" class="data row5 col1" >[2]</td>
#       <td id="T_315a9_row5_col2" class="data row5 col2" >[1.33]</td>
#       <td id="T_315a9_row5_col3" class="data row5 col3" >[1.67]</td>
#       <td id="T_315a9_row5_col4" class="data row5 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_315a9_row6_col0" class="data row6 col0" >(the teacher, graded, the papers)</td>
#       <td id="T_315a9_row6_col1" class="data row6 col1" >[0]</td>
#       <td id="T_315a9_row6_col2" class="data row6 col2" >[2.0]</td>
#       <td id="T_315a9_row6_col3" class="data row6 col3" >[1.0]</td>
#       <td id="T_315a9_row6_col4" class="data row6 col4" >['Weak Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_315a9_row7_col0" class="data row7 col0" >(the car, hit, the tree)</td>
#       <td id="T_315a9_row7_col1" class="data row7 col1" >[0]</td>
#       <td id="T_315a9_row7_col2" class="data row7 col2" >[2.0]</td>
#       <td id="T_315a9_row7_col3" class="data row7 col3" >[1.0]</td>
#       <td id="T_315a9_row7_col4" class="data row7 col4" >['Weak Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_315a9_row8_col0" class="data row8 col0" >(the storm, knocked, power lines)</td>
#       <td id="T_315a9_row8_col1" class="data row8 col1" >[-2]</td>
#       <td id="T_315a9_row8_col2" class="data row8 col2" >[0.67]</td>
#       <td id="T_315a9_row8_col3" class="data row8 col3" >[-0.67]</td>
#       <td id="T_315a9_row8_col4" class="data row8 col4" >['Weak Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_315a9_row9_col0" class="data row9 col0" >(the baby, cried, milk)</td>
#       <td id="T_315a9_row9_col1" class="data row9 col1" >[-4]</td>
#       <td id="T_315a9_row9_col2" class="data row9 col2" >[-0.67]</td>
#       <td id="T_315a9_row9_col3" class="data row9 col3" >[-2.33]</td>
#       <td id="T_315a9_row9_col4" class="data row9 col4" >['Moderate Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_315a9_row10_col0" class="data row10 col0" >(the cook, made, dinner)</td>
#       <td id="T_315a9_row10_col1" class="data row10 col1" >[2]</td>
#       <td id="T_315a9_row10_col2" class="data row10 col2" >[2.0]</td>
#       <td id="T_315a9_row10_col3" class="data row10 col3" >[2.0]</td>
#       <td id="T_315a9_row10_col4" class="data row10 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_315a9_row11_col0" class="data row11 col0" >(the student, passed, the exam)</td>
#       <td id="T_315a9_row11_col1" class="data row11 col1" >[2]</td>
#       <td id="T_315a9_row11_col2" class="data row11 col2" >[1.33]</td>
#       <td id="T_315a9_row11_col3" class="data row11 col3" >[1.67]</td>
#       <td id="T_315a9_row11_col4" class="data row11 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_315a9_row12_col0" class="data row12 col0" >(the company, launched, a new product)</td>
#       <td id="T_315a9_row12_col1" class="data row12 col1" >[4]</td>
#       <td id="T_315a9_row12_col2" class="data row12 col2" >[2.67]</td>
#       <td id="T_315a9_row12_col3" class="data row12 col3" >[3.33]</td>
#       <td id="T_315a9_row12_col4" class="data row12 col4" >['Strong Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_315a9_row13_col0" class="data row13 col0" >(the singer, performed, stage)</td>
#       <td id="T_315a9_row13_col1" class="data row13 col1" >[2]</td>
#       <td id="T_315a9_row13_col2" class="data row13 col2" >[2.0]</td>
#       <td id="T_315a9_row13_col3" class="data row13 col3" >[2.0]</td>
#       <td id="T_315a9_row13_col4" class="data row13 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_315a9_row14_col0" class="data row14 col0" >(the singer, medicine, stage)</td>
#       <td id="T_315a9_row14_col1" class="data row14 col1" >[2]</td>
#       <td id="T_315a9_row14_col2" class="data row14 col2" >[2.0]</td>
#       <td id="T_315a9_row14_col3" class="data row14 col3" >[2.0]</td>
#       <td id="T_315a9_row14_col4" class="data row14 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_315a9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_315a9_row15_col0" class="data row15 col0" >(the farmer, harvested, the crops)</td>
#       <td id="T_315a9_row15_col1" class="data row15 col1" >[2]</td>
#       <td id="T_315a9_row15_col2" class="data row15 col2" >[1.33]</td>
#       <td id="T_315a9_row15_col3" class="data row15 col3" >[1.67]</td>

# %%
totalSentsWeight_AllLevels = []

limit= len(causalSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalSentsWeight_AllLevels.append(sum_tup)
    
totalSentsPolarity_AllLevels = DetectPolarity(totalSentsWeight_AllLevels)

df_SentsAllLevels = pd.DataFrame(list(zip(causalSents, sentsWeight_sentLevel, sentsWeight_TokenLevel, totalSentsWeight_AllLevels, totalSentsPolarity_AllLevels)), 
                             columns =['Causal Sentence', 'Weight (Sent_SentLevel)','Weight (Sent_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_SentsAllLevels.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7093b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Sentence</th>
#       <th class="col_heading level0 col1" >Weight (Sent_SentLevel)</th>
#       <th class="col_heading level0 col2" >Weight (Sent_TokLevel)</th>
#       <th class="col_heading level0 col3" >Total Weight (All Levels)</th>
#       <th class="col_heading level0 col4" >Overall Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7093b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7093b_row0_col0" class="data row0 col0" >the rain caused wilting of flowers.</td>
#       <td id="T_7093b_row0_col1" class="data row0 col1" >[0]</td>
#       <td id="T_7093b_row0_col2" class="data row0 col2" >[1.0]</td>
#       <td id="T_7093b_row0_col3" class="data row0 col3" >[0.5]</td>
#       <td id="T_7093b_row0_col4" class="data row0 col4" >['Weak Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7093b_row1_col0" class="data row1 col0" >the sun rises in the east.</td>
#       <td id="T_7093b_row1_col1" class="data row1 col1" >[3]</td>
#       <td id="T_7093b_row1_col2" class="data row1 col2" >[2.33]</td>
#       <td id="T_7093b_row1_col3" class="data row1 col3" >[2.67]</td>
#       <td id="T_7093b_row1_col4" class="data row1 col4" >['Moderate Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7093b_row2_col0" class="data row2 col0" >the wind blew the leaves.</td>
#       <td id="T_7093b_row2_col1" class="data row2 col1" >[2]</td>
#       <td id="T_7093b_row2_col2" class="data row2 col2" >[0.67]</td>
#       <td id="T_7093b_row2_col3" class="data row2 col3" >[1.33]</td>
#       <td id="T_7093b_row2_col4" class="data row2 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7093b_row3_col0" class="data row3 col0" >the dog bit the mailman.</td>
#       <td id="T_7093b_row3_col1" class="data row3 col1" >[0]</td>
#       <td id="T_7093b_row3_col2" class="data row3 col2" >[1.0]</td>
#       <td id="T_7093b_row3_col3" class="data row3 col3" >[0.5]</td>
#       <td id="T_7093b_row3_col4" class="data row3 col4" >['Weak Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7093b_row4_col0" class="data row4 col0" >the boy kicked the ball.</td>
#       <td id="T_7093b_row4_col1" class="data row4 col1" >[0]</td>
#       <td id="T_7093b_row4_col2" class="data row4 col2" >[0.67]</td>
#       <td id="T_7093b_row4_col3" class="data row4 col3" >[0.34]</td>
#       <td id="T_7093b_row4_col4" class="data row4 col4" >['Weak Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7093b_row5_col0" class="data row5 col0" >the girl sang a song.</td>
#       <td id="T_7093b_row5_col1" class="data row5 col1" >[2]</td>
#       <td id="T_7093b_row5_col2" class="data row5 col2" >[2.0]</td>
#       <td id="T_7093b_row5_col3" class="data row5 col3" >[2.0]</td>
#       <td id="T_7093b_row5_col4" class="data row5 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7093b_row6_col0" class="data row6 col0" >the teacher graded the papers.</td>
#       <td id="T_7093b_row6_col1" class="data row6 col1" >[2]</td>
#       <td id="T_7093b_row6_col2" class="data row6 col2" >[2.0]</td>
#       <td id="T_7093b_row6_col3" class="data row6 col3" >[2.0]</td>
#       <td id="T_7093b_row6_col4" class="data row6 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7093b_row7_col0" class="data row7 col0" >the car hit the tree.</td>
#       <td id="T_7093b_row7_col1" class="data row7 col1" >[0]</td>
#       <td id="T_7093b_row7_col2" class="data row7 col2" >[2.0]</td>
#       <td id="T_7093b_row7_col3" class="data row7 col3" >[1.0]</td>
#       <td id="T_7093b_row7_col4" class="data row7 col4" >['Weak Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7093b_row8_col0" class="data row8 col0" >the storm knocked down the power lines.</td>
#       <td id="T_7093b_row8_col1" class="data row8 col1" >[-2]</td>
#       <td id="T_7093b_row8_col2" class="data row8 col2" >[1.0]</td>
#       <td id="T_7093b_row8_col3" class="data row8 col3" >[-0.5]</td>
#       <td id="T_7093b_row8_col4" class="data row8 col4" >['Weak Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7093b_row9_col0" class="data row9 col0" >the baby cried for milk.</td>
#       <td id="T_7093b_row9_col1" class="data row9 col1" >[-4]</td>
#       <td id="T_7093b_row9_col2" class="data row9 col2" >[-0.67]</td>
#       <td id="T_7093b_row9_col3" class="data row9 col3" >[-2.33]</td>
#       <td id="T_7093b_row9_col4" class="data row9 col4" >['Moderate Negative']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7093b_row10_col0" class="data row10 col0" >the cook made dinner.</td>
#       <td id="T_7093b_row10_col1" class="data row10 col1" >[2]</td>
#       <td id="T_7093b_row10_col2" class="data row10 col2" >[2.0]</td>
#       <td id="T_7093b_row10_col3" class="data row10 col3" >[2.0]</td>
#       <td id="T_7093b_row10_col4" class="data row10 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7093b_row11_col0" class="data row11 col0" >the student passed the exam.</td>
#       <td id="T_7093b_row11_col1" class="data row11 col1" >[2]</td>
#       <td id="T_7093b_row11_col2" class="data row11 col2" >[0.67]</td>
#       <td id="T_7093b_row11_col3" class="data row11 col3" >[1.33]</td>
#       <td id="T_7093b_row11_col4" class="data row11 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7093b_row12_col0" class="data row12 col0" >the company launched a new product.</td>
#       <td id="T_7093b_row12_col1" class="data row12 col1" >[4]</td>
#       <td id="T_7093b_row12_col2" class="data row12 col2" >[2.67]</td>
#       <td id="T_7093b_row12_col3" class="data row12 col3" >[3.33]</td>
#       <td id="T_7093b_row12_col4" class="data row12 col4" >['Strong Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7093b_row13_col0" class="data row13 col0" >the singer performed on stage.</td>
#       <td id="T_7093b_row13_col1" class="data row13 col1" >[2]</td>
#       <td id="T_7093b_row13_col2" class="data row13 col2" >[2.0]</td>
#       <td id="T_7093b_row13_col3" class="data row13 col3" >[2.0]</td>
#       <td id="T_7093b_row13_col4" class="data row13 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7093b_row14_col0" class="data row14 col0" >the doctor prescribed medicine.</td>
#       <td id="T_7093b_row14_col1" class="data row14 col1" >[2]</td>
#       <td id="T_7093b_row14_col2" class="data row14 col2" >[2.0]</td>
#       <td id="T_7093b_row14_col3" class="data row14 col3" >[2.0]</td>
#       <td id="T_7093b_row14_col4" class="data row14 col4" >['Mild Positive']</td>
#     </tr>
#     <tr>
#       <th id="T_7093b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7093b_row15_col0" class="data row15 col0" >the farmer harvested the crops.</td>
#       <td id="T_7093b_row15_col1" class="data row15 col1" >[2]</td>
#       <td id="T_7093b_row15_col2" class="data row15 col2" >[1.33]</td>
#       <td id="T_7093b_row15_col3" class="data row15 col3" >[1.67]</td>
#       <td id="T_7093b

# %%
#totalWeight_AllMethods = []

limit= len(causalSents)

#for i in range(0,limit):
#    sum_tup = []
#    for j in range(0,len(sentsWeight_sentLevel[i])):
#        res = sentsWeight_sentLevel[i][j]+triplesWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
#        res = round(res/4,2)
#        sum_tup.append(res)
#    totalWeight_AllMethods.append(sum_tup)
    
#totalPlarity_AllMethods = DetectPolarity(totalWeight_AllMethods)

df_AllMethods = pd.DataFrame(zip(sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel), 
                             columns =['Method1 (Sent_SentLevel)', 'Method2 (Trip_SentLevel)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)'])
df_AllMethods.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7fa49_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Method1 (Sent_SentLevel)</th>
#       <th class="col_heading level0 col1" >Method2 (Trip_SentLevel)</th>
#       <th class="col_heading level0 col2" >Method3 (Sent_TokLevel)</th>
#       <th class="col_heading level0 col3" >Method4 (Trip_TokLevel)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fa49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fa49_row0_col0" class="data row0 col0" >[0]</td>
#       <td id="T_7fa49_row0_col1" class="data row0 col1" >[2]</td>
#       <td id="T_7fa49_row0_col2" class="data row0 col2" >[1.0]</td>
#       <td id="T_7fa49_row0_col3" class="data row0 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7fa49_row1_col0" class="data row1 col0" >[3]</td>
#       <td id="T_7fa49_row1_col1" class="data row1 col1" >[3]</td>
#       <td id="T_7fa49_row1_col2" class="data row1 col2" >[2.33]</td>
#       <td id="T_7fa49_row1_col3" class="data row1 col3" >[2.33]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7fa49_row2_col0" class="data row2 col0" >[2]</td>
#       <td id="T_7fa49_row2_col1" class="data row2 col1" >[2]</td>
#       <td id="T_7fa49_row2_col2" class="data row2 col2" >[0.67]</td>
#       <td id="T_7fa49_row2_col3" class="data row2 col3" >[1.33]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7fa49_row3_col0" class="data row3 col0" >[0]</td>
#       <td id="T_7fa49_row3_col1" class="data row3 col1" >[0]</td>
#       <td id="T_7fa49_row3_col2" class="data row3 col2" >[1.0]</td>
#       <td id="T_7fa49_row3_col3" class="data row3 col3" >[1.33]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7fa49_row4_col0" class="data row4 col0" >[0]</td>
#       <td id="T_7fa49_row4_col1" class="data row4 col1" >[-2]</td>
#       <td id="T_7fa49_row4_col2" class="data row4 col2" >[0.67]</td>
#       <td id="T_7fa49_row4_col3" class="data row4 col3" >[0.67]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7fa49_row5_col0" class="data row5 col0" >[2]</td>
#       <td id="T_7fa49_row5_col1" class="data row5 col1" >[2]</td>
#       <td id="T_7fa49_row5_col2" class="data row5 col2" >[2.0]</td>
#       <td id="T_7fa49_row5_col3" class="data row5 col3" >[1.33]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7fa49_row6_col0" class="data row6 col0" >[2]</td>
#       <td id="T_7fa49_row6_col1" class="data row6 col1" >[0]</td>
#       <td id="T_7fa49_row6_col2" class="data row6 col2" >[2.0]</td>
#       <td id="T_7fa49_row6_col3" class="data row6 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7fa49_row7_col0" class="data row7 col0" >[0]</td>
#       <td id="T_7fa49_row7_col1" class="data row7 col1" >[0]</td>
#       <td id="T_7fa49_row7_col2" class="data row7 col2" >[2.0]</td>
#       <td id="T_7fa49_row7_col3" class="data row7 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7fa49_row8_col0" class="data row8 col0" >[-2]</td>
#       <td id="T_7fa49_row8_col1" class="data row8 col1" >[-2]</td>
#       <td id="T_7fa49_row8_col2" class="data row8 col2" >[1.0]</td>
#       <td id="T_7fa49_row8_col3" class="data row8 col3" >[0.67]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7fa49_row9_col0" class="data row9 col0" >[-4]</td>
#       <td id="T_7fa49_row9_col1" class="data row9 col1" >[-4]</td>
#       <td id="T_7fa49_row9_col2" class="data row9 col2" >[-0.67]</td>
#       <td id="T_7fa49_row9_col3" class="data row9 col3" >[-0.67]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7fa49_row10_col0" class="data row10 col0" >[2]</td>
#       <td id="T_7fa49_row10_col1" class="data row10 col1" >[2]</td>
#       <td id="T_7fa49_row10_col2" class="data row10 col2" >[2.0]</td>
#       <td id="T_7fa49_row10_col3" class="data row10 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7fa49_row11_col0" class="data row11 col0" >[2]</td>
#       <td id="T_7fa49_row11_col1" class="data row11 col1" >[2]</td>
#       <td id="T_7fa49_row11_col2" class="data row11 col2" >[0.67]</td>
#       <td id="T_7fa49_row11_col3" class="data row11 col3" >[1.33]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7fa49_row12_col0" class="data row12 col0" >[4]</td>
#       <td id="T_7fa49_row12_col1" class="data row12 col1" >[4]</td>
#       <td id="T_7fa49_row12_col2" class="data row12 col2" >[2.67]</td>
#       <td id="T_7fa49_row12_col3" class="data row12 col3" >[2.67]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7fa49_row13_col0" class="data row13 col0" >[2]</td>
#       <td id="T_7fa49_row13_col1" class="data row13 col1" >[2]</td>
#       <td id="T_7fa49_row13_col2" class="data row13 col2" >[2.0]</td>
#       <td id="T_7fa49_row13_col3" class="data row13 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7fa49_row14_col0" class="data row14 col0" >[2]</td>
#       <td id="T_7fa49_row14_col1" class="data row14 col1" >[2]</td>
#       <td id="T_7fa49_row14_col2" class="data row14 col2" >[2.0]</td>
#       <td id="T_7fa49_row14_col3" class="data row14 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7fa49_row15_col0" class="data row15 col0" >[2]</td>
#       <td id="T_7fa49_row15_col1" class="data row15 col1" >[2]</td>
#       <td id="T_7fa49_row15_col2" class="data row15 col2" >[1.33]</td>
#       <td id="T_7fa49_row15_col3" class="data row15 col3" >[1.33]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7fa49_row16_col0" class="data row16 col0" >[2]</td>
#       <td id="T_7fa49_row16_col1" class="data row16 col1" >[2]</td>
#       <td id="T_7fa49_row16_col2" class="data row16 col2" >[2.0]</td>
#       <td id="T_7fa49_row16_col3" class="data row16 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7fa49_row17_col0" class="data row17 col0" >[0]</td>
#       <td id="T_7fa49_row17_col1" class="data row17 col1" >[-2]</td>
#       <td id="T_7fa49_row17_col2" class="data row17 col2" >[0.0]</td>
#       <td id="T_7fa49_row17_col3" class="data row17 col3" >[1.33]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7fa49_row18_col0" class="data row18 col0" >[2]</td>
#       <td id="T_7fa49_row18_col1" class="data row18 col1" >[2]</td>
#       <td id="T_7fa49_row18_col2" class="data row18 col2" >[2.0]</td>
#       <td id="T_7fa49_row18_col3" class="data row18 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7fa49_row19_col0" class="data row19 col0" >[2]</td>
#       <td id="T_7fa49_row19_col1" class="data row19 col1" >[2]</td>
#       <td id="T_7fa49_row19_col2" class="data row19 col2" >[1.33]</td>
#       <td id="T_7fa49_row19_col3" class="data row19 col3" >[2.0]</td>
#     </tr>
#     <tr>
#       <th id="T_7fa49_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7fa49_row20_col0" class="data row20 col0" >[3]</td>
#       <td id="T_7fa49_row20_c

# %%
Method1 = []
Method2 = []
Method3 = []
Method4 = []

for index, row in df_AllMethods.iterrows():
    Method1.append(row['Method1 (Sent_SentLevel)'][0])
    Method2.append(row['Method2 (Trip_SentLevel)'][0])
    Method3.append(row['Method3 (Sent_TokLevel)'][0])
    Method4.append(row['Method4 (Trip_TokLevel)'][0])

# %%
df_new = pd.DataFrame()
df_new['Method1 (Sent_SentLevel)'] = Method1
df_new['Method2 (Trip_SentLevel)'] = Method2
df_new['Method3 (Sent_TokLevel)'] = Method3
df_new['Method4 (Trip_TokLevel)'] = Method4

# %%
import seaborn as sns

corr_matrix = df_new.corr()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(data=corr_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr_matrix
# Out:
#                           Method1 (Sent_SentLevel)  Method2 (Trip_SentLevel)  \
# Method1 (Sent_SentLevel)                  1.000000                  0.946703
# Method2 (Trip_SentLevel)                  0.946703                  1.000000
# Method3 (Sent_TokLevel)                   0.800744                  0.808357
# Method4 (Trip_TokLevel)                   0.907667                  0.907991
#
#                           Method3 (Sent_TokLevel)  Method4 (Trip_TokLevel)
# Method1 (Sent_SentLevel)                 0.800744                 0.907667
# Method2 (Trip_SentLevel)                 0.808357                 0.907991
# Method3 (Sent_TokLevel)                  1.000000                 0.838537
# Method4 (Trip_TokLevel)                  0.838537                 1.000000
