# %% [markdown]
# # Import necessary libraries.

# %%
import spacy
import textacy
import textacy.preprocessing
import textacy.resources
#import textacy.keyterms
import textacy.ke
#import neuralcoref
from spacy.symbols import ORTH, POS, NOUN, VERB,PRON
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt 
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from networkx.readwrite import json_graph;
import json
from afinn import Afinn
afn = Afinn()
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
lemmatizer = WordNetLemmatizer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from allennlp_models.pretrained import load_predictor
predictor = load_predictor("roberta-sst")   #for sentiment analysis
predictor = load_predictor("coref-spanbert") #for coreference resolution
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('C:/SentiStrength/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('C:/SentiStrength/SentStrength_Data_Sept2011/')
import pandas as pd
from IPython.display import display
import collections
from nltk.corpus import stopwords
set(stopwords.words('english'))
from pd_replicator import replicator
from textacy.preprocessing.remove import remove_punctuation
from textacy.preprocessing.normalize import normalize_hyphenated_words

nlp = spacy.load("en_core_web_sm")
#neuralcoref.add_to_pipe(nlp)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)
# C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp\tango\__init__.py:18: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   "AllenNLP Tango is an experimental API and parts of it might change or disappear "
# 2022-05-17 00:38:22,940 - ERROR - allennlp.common.plugins - Plugin allennlp_models could not be loaded: No module named 'nltk.translate.meteor_score'
# 2022-05-17 00:38:23,016 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\coref-spanbert.json as plain json
# 2022-05-17 00:38:23,042 - INFO - allennlp.common.params - id = coref-spanbert
# 2022-05-17 00:38:23,048 - INFO - allennlp.common.params - type = coref-spanbert
# 2022-05-17 00:38:23,054 - INFO - allennlp.common.params - registered_model_name = coref
# 2022-05-17 00:38:23,060 - INFO - allennlp.common.params - type = coref
# 2022-05-17 00:38:23,064 - INFO - allennlp.common.params - model_class = None
# 2022-05-17 00:38:23,067 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-17 00:38:23,070 - INFO - allennlp.common.params - display_name = Coreference Resolution
# 2022-05-17 00:38:23,073 - INFO - allennlp.common.params - type = Coreference Resolution
# 2022-05-17 00:38:23,076 - INFO - allennlp.common.params - task_id = coref
# 2022-05-17 00:38:23,081 - INFO - allennlp.common.params - type = coref
# 2022-05-17 00:38:23,086 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:23,094 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:23,103 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:23,112 - INFO - allennlp.common.params - model_usage.archive_file = coref-spanbert-large-2021.03.10.tar.gz
# 2022-05-17 00:38:23,116 - INFO - allennlp.common.params - type = coref-spanbert-large-2021.03.10.tar.gz
# 2022-05-17 00:38:23,133 - INFO - allennlp.common.params - model_usage.training_config = coref/coref_spanbert_large.jsonnet
# 2022-05-17 00:38:23,137 - INFO - allennlp.common.params - type = coref/coref_spanbert_large.jsonnet
# 2022-05-17 00:38:23,145 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-17 00:38:23,149 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-17 00:38:23,158 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-17 00:38:23,163 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:23,173 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:23,181 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:23,190 - INFO - allennlp.common.params - model_details.description = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2022-05-17 00:38:23,195 - INFO - allennlp.common.params - type = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2022-05-17 00:38:23,208 - INFO - allennlp.common.params - model_details.short_description = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2022-05-17 00:38:23,213 - INFO - allennlp.common.params - type = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2022-05-17 00:38:23,222 - INFO - allennlp.common.params - model_details.developed_by = Lee et al
# 2022-05-17 00:38:23,226 - INFO - allennlp.common.params - type = Lee et al
# 2022-05-17 00:38:23,229 - INFO - allennlp.common.params - model_details.contributed_by = Zhaofeng Wu
# 2022-05-17 00:38:23,235 - INFO - allennlp.common.params - type = Zhaofeng Wu
# 2022-05-17 00:38:23,239 - INFO - allennlp.common.params - model_details.date = 2020-02-27
# 2022-05-17 00:38:23,241 - INFO - allennlp.common.params - type = 2020-02-27
# 2022-05-17 00:38:23,247 - INFO - allennlp.common.params - model_details.version = 2
# 2022-05-17 00:38:23,250 - INFO - allennlp.common.params - type = 2
# 2022-05-17 00:38:23,253 - INFO - allennlp.common.params - model_details.model_type = SpanBERT
# 2022-05-17 00:38:23,256 - INFO - allennlp.common.params - type = SpanBERT
# 2022-05-17 00:38:23,261 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:23,281 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:23,289 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:23,297 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lee2018HigherorderCR,
# title={Higher-order Coreference Resolution with Coarse-to-fine Inference},
# author={Kenton Lee and Luheng He and L. Zettlemoyer},
# booktitle={NAACL-HLT},
# year={2018}}
#
# 2022-05-17 00:38:23,301 - INFO - allennlp.common.params - model_details.paper.title = Higher-order Coreference Resolution with Coarse-to-fine Inference
# 2022-05-17 00:38:23,303 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:4891749
# 2022-05-17 00:38:23,306 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-17 00:38:23,309 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-17 00:38:23,312 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-17 00:38:23,325 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:23,332 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:23,339 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:23,347 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-17 00:38:23,349 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-17 00:38:23,351 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-17 00:38:23,354 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:23,362 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:23,370 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:23,377 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-17 00:38:23,380 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-17 00:38:23,384 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:23,392 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:23,401 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:23,408 - INFO - allennlp.common.params - metrics.model_performance_measures = CoNLL coref scores and Mention Recall
# 2022-05-17 00:38:23,411 - INFO - allennlp.common.params - type = CoNLL coref scores and Mention Recall
# 2022-05-17 00:38:23,414 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-17 00:38:23,417 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-17 00:38:23,420 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:23,428 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:23,436 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:23,445 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:23,452 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:23,459 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:23,486 - INFO - allennlp.common.params - evaluation_data.dataset.name = Ontonotes 5.0
# 2022-05-17 00:38:23,488 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2022-05-17 00:38:23,490 - INFO - allennlp.common.params - evaluation_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2022-05-17 00:38:23,492 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = /path/to/dataset
# 2022-05-17 00:38:23,495 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-17 00:38:23,497 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-17 00:38:23,500 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:23,507 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:23,513 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:23,520 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:23,527 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:23,533 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:23,540 - INFO - allennlp.common.params - training_data.dataset.name = Ontonotes 5.0
# 2022-05-17 00:38:23,543 - INFO - allennlp.common.params - training_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2022-05-17 00:38:23,545 - INFO - allennlp.common.params - training_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2022-05-17 00:38:23,547 - INFO - allennlp.common.params - training_data.dataset.processed_url = /path/to/dataset
# 2022-05-17 00:38:23,550 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-17 00:38:23,552 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2022-05-17 00:38:23,555 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:23,562 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:23,568 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:23,575 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2022-05-17 00:38:23,577 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-17 00:38:23,580 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:23,586 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:23,593 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:23,599 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-17 00:38:23,602 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:23,609 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:23,616 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:23,623 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-17 00:38:23,629 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\evaluate_rc-lerc.json as plain json
# 2022-05-17 00:38:23,650 - INFO - allennlp.common.params - id = evaluate_rc-lerc
# 2022-05-17 00:38:23,653 - INFO - allennlp.common.params - type = evaluate_rc-lerc
# 2022-05-17 00:38:23,656 - INFO - allennlp.common.params - registered_model_name = lerc
# 2022-05-17 00:38:23,659 - INFO - allennlp.common.params - type = lerc
# 2022-05-17 00:38:23,661 - INFO - allennlp.common.params - model_class = None
# 2022-05-17 00:38:23,663 - INFO - allennlp.common.params - registered_predictor_name = lerc
# 2022-05-17 00:38:23,666 - INFO - allennlp.common.params - type = lerc
# 2022-05-17 00:38:23,668 - INFO - allennlp.common.params - display_name = Learned Evaluation for Reading Comprehension (LERC)
# 2022-05-17 00:38:23,671 - INFO - allennlp.common.params - type = Learned Evaluation for Reading Comprehension (LERC)
# 2022-05-17 00:38:23,674 - INFO - allennlp.common.params - task_id = evaluate_rc
# 2022-05-17 00:38:23,677 - INFO - allennlp.common.params - type = evaluate_rc
# 2022-05-17 00:38:23,680 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:23,688 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:23,837 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:23,853 - INFO - allennlp.common.params - model_usage.archive_file = lerc-2020-11-18.tar.gz
# 2022-05-17 00:38:23,858 - INFO - allennlp.common.params - type = lerc-2020-11-18.tar.gz
# 2022-05-17 00:38:23,882 - INFO - allennlp.common.params - model_usage.training_config = None
# 2022-05-17 00:38:23,886 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-17 00:38:23,896 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-17 00:38:23,911 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-17 00:38:23,915 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:23,922 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:23,930 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:23,938 - INFO - allennlp.common.params - model_details.description = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2022-05-17 00:38:23,941 - INFO - allennlp.common.params - type = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2022-05-17 00:38:23,955 - INFO - allennlp.common.params - model_details.short_description = A BERT model that scores candidate answers from 0 to 1.
# 2022-05-17 00:38:23,958 - INFO - allennlp.common.params - type = A BERT model that scores candidate answers from 0 to 1.
# 2022-05-17 00:38:23,966 - INFO - allennlp.common.params - model_details.developed_by = Chen et al
# 2022-05-17 00:38:23,970 - INFO - allennlp.common.params - type = Chen et al
# 2022-05-17 00:38:23,978 - INFO - allennlp.common.params - model_details.contributed_by = Anthony Chen
# 2022-05-17 00:38:23,991 - INFO - allennlp.common.params - type = Anthony Chen
# 2022-05-17 00:38:23,993 - INFO - allennlp.common.params - model_details.date = 2021-03-10
# 2022-05-17 00:38:23,999 - INFO - allennlp.common.params - type = 2021-03-10
# 2022-05-17 00:38:24,003 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-17 00:38:24,007 - INFO - allennlp.common.params - type = 1
# 2022-05-17 00:38:24,011 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2022-05-17 00:38:24,014 - INFO - allennlp.common.params - type = BERT
# 2022-05-17 00:38:24,017 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:24,023 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:24,032 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:24,038 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Chen2020MOCHAAD,
# title={MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics},
# author={Anthony Chen and Gabriel Stanovsky and S. Singh and Matt Gardner},
# booktitle={EMNLP},
# year={2020}}
#
# 2022-05-17 00:38:24,044 - INFO - allennlp.common.params - model_details.paper.title = MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics
# 2022-05-17 00:38:24,052 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:222208714
# 2022-05-17 00:38:24,073 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-17 00:38:24,077 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-17 00:38:24,116 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-17 00:38:24,125 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:24,132 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:24,138 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:24,144 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-17 00:38:24,149 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-17 00:38:24,151 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-17 00:38:24,155 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:24,165 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:24,174 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:24,181 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-17 00:38:24,184 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-17 00:38:24,188 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:24,197 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:24,207 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:24,216 - INFO - allennlp.common.params - metrics.model_performance_measures = Pearson Correlation
# 2022-05-17 00:38:24,220 - INFO - allennlp.common.params - type = Pearson Correlation
# 2022-05-17 00:38:24,223 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-17 00:38:24,226 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-17 00:38:24,230 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:24,243 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:24,253 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:24,264 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:24,297 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:24,305 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:24,312 - INFO - allennlp.common.params - evaluation_data.dataset.name = MOCHA
# 2022-05-17 00:38:24,314 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://allennlp.org/mocha
# 2022-05-17 00:38:24,316 - INFO - allennlp.common.params - evaluation_data.dataset.notes = To evaluate this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2022-05-17 00:38:24,319 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = None
# 2022-05-17 00:38:24,322 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-17 00:38:24,324 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-17 00:38:24,328 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:24,335 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:24,341 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:24,349 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:24,355 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:24,362 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:24,369 - INFO - allennlp.common.params - training_data.dataset.name = MOCHA
# 2022-05-17 00:38:24,371 - INFO - allennlp.common.params - training_data.dataset.url = https://allennlp.org/mocha
# 2022-05-17 00:38:24,373 - INFO - allennlp.common.params - training_data.dataset.notes = To train this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2022-05-17 00:38:24,375 - INFO - allennlp.common.params - training_data.dataset.processed_url = None
# 2022-05-17 00:38:24,378 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-17 00:38:24,381 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2022-05-17 00:38:24,383 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:24,389 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:24,395 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:24,402 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2022-05-17 00:38:24,405 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-17 00:38:24,409 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:24,416 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:24,424 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:24,435 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-17 00:38:24,449 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:24,458 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:24,469 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:24,479 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-17 00:38:24,505 - WARNING - allennlp.common.model_card - lerc is not a registered model.
# 2022-05-17 00:38:24,514 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\generation-bart.json as plain json
# 2022-05-17 00:38:24,537 - INFO - allennlp.common.params - id = generation-bart
# 2022-05-17 00:38:24,540 - INFO - allennlp.common.params - type = generation-bart
# 2022-05-17 00:38:24,543 - INFO - allennlp.common.params - registered_model_name = bart
# 2022-05-17 00:38:24,546 - INFO - allennlp.common.params - type = bart
# 2022-05-17 00:38:24,549 - INFO - allennlp.common.params - model_class = None
# 2022-05-17 00:38:24,550 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-17 00:38:24,553 - INFO - allennlp.common.params - display_name = BART
# 2022-05-17 00:38:24,555 - INFO - allennlp.common.params - type = BART
# 2022-05-17 00:38:24,558 - INFO - allennlp.common.params - task_id = None
# 2022-05-17 00:38:24,562 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:24,570 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:24,577 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:24,624 - INFO - allennlp.common.params - model_usage.archive_file = bart-2020.07.25.tar.gz
# 2022-05-17 00:38:24,632 - INFO - allennlp.common.params - type = bart-2020.07.25.tar.gz
# 2022-05-17 00:38:24,640 - INFO - allennlp.common.params - model_usage.training_config = generation/bart_cnn_dm.jsonnet
# 2022-05-17 00:38:24,645 - INFO - allennlp.common.params - type = generation/bart_cnn_dm.jsonnet
# 2022-05-17 00:38:24,653 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-17 00:38:24,657 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2022-05-17 00:38:24,667 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-17 00:38:24,672 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:24,680 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:24,688 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:24,696 - INFO - allennlp.common.params - model_details.description = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2022-05-17 00:38:24,699 - INFO - allennlp.common.params - type = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2022-05-17 00:38:24,707 - INFO - allennlp.common.params - model_details.short_description = BART with a language model head for generation.
# 2022-05-17 00:38:24,711 - INFO - allennlp.common.params - type = BART with a language model head for generation.
# 2022-05-17 00:38:24,719 - INFO - allennlp.common.params - model_details.developed_by = Lewis et al
# 2022-05-17 00:38:24,723 - INFO - allennlp.common.params - type = Lewis et al
# 2022-05-17 00:38:24,726 - INFO - allennlp.common.params - model_details.contributed_by = Dirk Groeneveld
# 2022-05-17 00:38:24,730 - INFO - allennlp.common.params - type = Dirk Groeneveld
# 2022-05-17 00:38:24,734 - INFO - allennlp.common.params - model_details.date = 2020-07-25
# 2022-05-17 00:38:24,737 - INFO - allennlp.common.params - type = 2020-07-25
# 2022-05-17 00:38:24,740 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-17 00:38:24,743 - INFO - allennlp.common.params - type = 1
# 2022-05-17 00:38:24,745 - INFO - allennlp.common.params - model_details.model_type = BART
# 2022-05-17 00:38:24,748 - INFO - allennlp.common.params - type = BART
# 2022-05-17 00:38:24,751 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:24,758 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:24,771 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:24,780 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lewis2020BARTDS,
# title={BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension},
# author={M. Lewis and Yinhan Liu and Naman Goyal and Marjan Ghazvininejad and A. Mohamed and Omer Levy and Ves Stoyanov and L. Zettlemoyer},
# booktitle={ACL},
# year={2020}}
#
# 2022-05-17 00:38:24,782 - INFO - allennlp.common.params - model_details.paper.title = BART: Denosing Sequence-to-Sequence Pre-training for Natural Language Generation,Translation, and Comprehension
# 2022-05-17 00:38:24,785 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:204960716
# 2022-05-17 00:38:24,787 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-17 00:38:24,790 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-17 00:38:24,793 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-17 00:38:24,807 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:24,815 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:24,822 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:24,830 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-17 00:38:24,833 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-17 00:38:24,835 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-17 00:38:24,838 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:24,845 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:24,852 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:24,860 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-17 00:38:24,862 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-17 00:38:24,865 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:24,872 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:24,880 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:24,887 - INFO - allennlp.common.params - metrics.model_performance_measures = ROUGE and BLEU
# 2022-05-17 00:38:24,889 - INFO - allennlp.common.params - type = ROUGE and BLEU
# 2022-05-17 00:38:24,892 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-17 00:38:24,894 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-17 00:38:24,898 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:24,904 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:24,911 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:24,922 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:24,958 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:24,965 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:24,971 - INFO - allennlp.common.params - evaluation_data.dataset.name = CNN/DailyMail
# 2022-05-17 00:38:24,974 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2022-05-17 00:38:24,976 - INFO - allennlp.common.params - evaluation_data.dataset.notes = Please download the data from the url provided.
# 2022-05-17 00:38:24,979 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-17 00:38:24,981 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-17 00:38:24,985 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:24,992 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:25,000 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:25,006 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:25,013 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:25,019 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:25,024 - INFO - allennlp.common.params - training_data.dataset.name = CNN/DailyMail
# 2022-05-17 00:38:25,030 - INFO - allennlp.common.params - training_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2022-05-17 00:38:25,032 - INFO - allennlp.common.params - training_data.dataset.notes = Please download the data from the url provided.
# 2022-05-17 00:38:25,034 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-17 00:38:25,040 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2022-05-17 00:38:25,044 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:25,049 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:25,055 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:25,061 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2022-05-17 00:38:25,064 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-17 00:38:25,067 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:25,072 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:25,081 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:25,088 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-17 00:38:25,092 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:25,101 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:25,109 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:25,116 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-17 00:38:25,121 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\glove-sst.json as plain json
# 2022-05-17 00:38:25,149 - INFO - allennlp.common.params - id = glove-sst
# 2022-05-17 00:38:25,152 - INFO - allennlp.common.params - type = glove-sst
# 2022-05-17 00:38:25,155 - INFO - allennlp.common.params - registered_model_name = None
# 2022-05-17 00:38:25,157 - INFO - allennlp.common.params - model_class = None
# 2022-05-17 00:38:25,160 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-17 00:38:25,162 - INFO - allennlp.common.params - display_name = GLoVe-LSTM
# 2022-05-17 00:38:25,164 - INFO - allennlp.common.params - type = GLoVe-LSTM
# 2022-05-17 00:38:25,166 - INFO - allennlp.common.params - task_id = sentiment-analysis
# 2022-05-17 00:38:25,169 - INFO - allennlp.common.params - type = sentiment-analysis
# 2022-05-17 00:38:25,172 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:25,179 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:25,187 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:25,214 - INFO - allennlp.common.params - model_usage.archive_file = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2022-05-17 00:38:25,216 - INFO - allennlp.common.params - type = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2022-05-17 00:38:25,229 - INFO - allennlp.common.params - model_usage.training_config = classification/basic_stanford_sentiment_treebank.jsonnet
# 2022-05-17 00:38:25,231 - INFO - allennlp.common.params - type = classification/basic_stanford_sentiment_treebank.jsonnet
# 2022-05-17 00:38:25,245 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-17 00:38:25,249 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-17 00:38:25,257 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-17 00:38:25,261 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:25,267 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:25,273 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:25,280 - INFO - allennlp.common.params - model_details.description = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2022-05-17 00:38:25,282 - INFO - allennlp.common.params - type = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2022-05-17 00:38:25,291 - INFO - allennlp.common.params - model_details.short_description = LSTM binary classifier with GloVe embeddings.
# 2022-05-17 00:38:25,294 - INFO - allennlp.common.params - type = LSTM binary classifier with GloVe embeddings.
# 2022-05-17 00:38:25,301 - INFO - allennlp.common.params - model_details.developed_by = None
# 2022-05-17 00:38:25,303 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2022-05-17 00:38:25,306 - INFO - allennlp.common.params - model_details.date = 2020-06-09
# 2022-05-17 00:38:25,308 - INFO - allennlp.common.params - type = 2020-06-09
# 2022-05-17 00:38:25,311 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-17 00:38:25,314 - INFO - allennlp.common.params - type = 1
# 2022-05-17 00:38:25,320 - INFO - allennlp.common.params - model_details.model_type = LSTM
# 2022-05-17 00:38:25,323 - INFO - allennlp.common.params - type = LSTM
# 2022-05-17 00:38:25,326 - INFO - allennlp.common.params - model_details.paper = None
# 2022-05-17 00:38:25,329 - INFO - allennlp.common.params - model_details.license = None
# 2022-05-17 00:38:25,332 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2022-05-17 00:38:25,336 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2022-05-17 00:38:25,344 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:25,350 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:25,356 - INFO - allennlp.common.params - intended_use.type = ref
# 2022-05-17 00:38:25,361 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2022-05-17 00:38:25,363 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2022-05-17 00:38:25,366 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2022-05-17 00:38:25,368 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:25,374 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:25,379 - INFO - allennlp.common.params - factors.type = ref
# 2022-05-17 00:38:25,386 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2022-05-17 00:38:25,390 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2022-05-17 00:38:25,393 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:25,400 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:25,407 - INFO - allennlp.common.params - metrics.type = ref
# 2022-05-17 00:38:25,413 - INFO - allennlp.common.params - metrics.model_performance_measures = Accuracy
# 2022-05-17 00:38:25,417 - INFO - allennlp.common.params - type = Accuracy
# 2022-05-17 00:38:25,419 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2022-05-17 00:38:25,421 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2022-05-17 00:38:25,425 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:25,432 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:25,439 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2022-05-17 00:38:25,447 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:25,454 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:25,460 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2022-05-17 00:38:25,467 - INFO - allennlp.common.params - evaluation_data.dataset.name = Stanford Sentiment Treebank
# 2022-05-17 00:38:25,469 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2022-05-17 00:38:25,471 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/test.txt
# 2022-05-17 00:38:25,473 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2022-05-17 00:38:25,475 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2022-05-17 00:38:25,477 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:25,484 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:25,516 - INFO - allennlp.common.params - training_data.type = ref
# 2022-05-17 00:38:25,524 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:25,531 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:25,537 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2022-05-17 00:38:25,543 - INFO - allennlp.common.params - training_data.dataset.name = Stanford Sentiment Treebank
# 2022-05-17 00:38:25,546 - INFO - allennlp.common.params - training_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2022-05-17 00:38:25,548 - INFO - allennlp.common.params - training_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/train.txt
# 2022-05-17 00:38:25,550 - INFO - allennlp.common.params - training_data.motivation = None
# 2022-05-17 00:38:25,553 - INFO - allennlp.common.params - training_data.preprocessing = Binary classification setting
# 2022-05-17 00:38:25,555 - INFO - allennlp.common.params - type = Binary classification setting
# 2022-05-17 00:38:25,557 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:25,563 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:25,569 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2022-05-17 00:38:25,576 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = Accuracy: 87% on SST test set.
# 2022-05-17 00:38:25,578 - INFO - allennlp.common.params - type = Accuracy: 87% on SST test set.
# 2022-05-17 00:38:25,590 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2022-05-17 00:38:25,593 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:25,601 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:25,608 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2022-05-17 00:38:25,615 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2022-05-17 00:38:25,619 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:25,626 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:25,633 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2022-05-17 00:38:25,639 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2022-05-17 00:38:25,644 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\hp\AppData\Roaming\Python\Python37\site-packages\allennlp_models\modelcards\lm-masked-language-model.json as plain json
# 2022-05-17 00:38:25,666 - INFO - allennlp.common.params - id = lm-masked-language-model
# 2022-05-17 00:38:25,669 - INFO - allennlp.common.params - type = lm-masked-language-model
# 2022-05-17 00:38:25,671 - INFO - allennlp.common.params - registered_model_name = masked_language_model
# 2022-05-17 00:38:25,674 - INFO - allennlp.common.params - type = masked_language_model
# 2022-05-17 00:38:25,676 - INFO - allennlp.common.params - model_class = None
# 2022-05-17 00:38:25,678 - INFO - allennlp.common.params - registered_predictor_name = None
# 2022-05-17 00:38:25,680 - INFO - allennlp.common.params - display_name = BERT-based Masked Language Model
# 2022-05-17 00:38:25,683 - INFO - allennlp.common.params - type = BERT-based Masked Language Model
# 2022-05-17 00:38:25,693 - INFO - allennlp.common.params - task_id = masked-language-modeling
# 2022-05-17 00:38:25,697 - INFO - allennlp.common.params - type = masked-language-modeling
# 2022-05-17 00:38:25,701 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:25,708 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:25,715 - INFO - allennlp.common.params - model_usage.type = ref
# 2022-05-17 00:38:25,722 - INFO - allennlp.common.params - model_usage.archive_file = bert-masked-lm-2020-10-07.tar.gz
# 2022-05-17 00:38:25,725 - INFO - allennlp.common.params - type = bert-masked-lm-2020-10-07.tar.gz
# 2022-05-17 00:38:25,736 - INFO - allennlp.common.params - model_usage.training_config = lm/bidirectional_language_model.jsonnet
# 2022-05-17 00:38:25,748 - INFO - allennlp.common.params - type = lm/bidirectional_language_model.jsonnet
# 2022-05-17 00:38:25,762 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-17 00:38:25,766 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2022-05-17 00:38:25,775 - INFO - allennlp.common.params - model_usage.overrides = None
# 2022-05-17 00:38:25,779 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:25,786 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:25,794 - INFO - allennlp.common.params - model_details.type = ref
# 2022-05-17 00:38:25,802 - INFO - allennlp.common.params - model_details.description = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2022-05-17 00:38:25,808 - INFO - allennlp.common.params - type = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2022-05-17 00:38:25,821 - INFO - allennlp.common.params - model_details.short_description = BERT-based masked language model
# 2022-05-17 00:38:25,826 - INFO - allennlp.common.params - type = BERT-based masked language model
# 2022-05-17 00:38:25,832 - INFO - allennlp.common.params - model_details.developed_by = Devlin et al
# 2022-05-17 00:38:25,836 - INFO - allennlp.common.params - type = Devlin et al
# 2022-05-17 00:38:25,841 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2022-05-17 00:38:25,845 - INFO - allennlp.common.params - model_details.date = 2020-10-07
# 2022-05-17 00:38:25,850 - INFO - allennlp.common.params - type = 2020-10-07
# 2022-05-17 00:38:25,855 - INFO - allennlp.common.params - model_details.version = 1
# 2022-05-17 00:38:25,861 - INFO - allennlp.common.params - type = 1
# 2022-05-17 00:38:25,865 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2022-05-17 00:38:25,870 - INFO - allennlp.common.params - type = BERT
# 2022-05-17 00:38:25,874 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:25,884 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:25,921 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2022-05-17 00:38:25,929 - INFO - allennlp.common.params - model_details.paper.citation =
# ...
# 2022-05-17 00:44:32,731 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.bias
# 2022-05-17 00:44:32,754 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.weight
# 2022-05-17 00:44:32,767 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2022-05-17 00:44:32,787 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2022-05-17 00:44:32,793 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2022-05-17 00:44:32,796 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2022-05-17 00:44:32,807 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.bias
# 2022-05-17 00:44:32,810 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.weight
# 2022-05-17 00:44:32,813 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.bias
# 2022-05-17 00:44:32,828 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.weight
# 2022-05-17 00:44:32,833 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.bias
# 2022-05-17 00:44:32,841 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.weight
# 2022-05-17 00:44:32,844 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2022-05-17 00:44:32,854 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2022-05-17 00:44:32,861 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2022-05-17 00:44:32,866 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2022-05-17 00:44:32,871 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.bias
# 2022-05-17 00:44:32,876 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.weight
# 2022-05-17 00:44:32,882 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2022-05-17 00:44:32,890 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2022-05-17 00:44:32,893 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2022-05-17 00:44:32,895 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2022-05-17 00:44:32,903 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.bias
# 2022-05-17 00:44:32,918 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.weight
# 2022-05-17 00:44:32,923 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.bias
# 2022-05-17 00:44:32,927 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.weight
# 2022-05-17 00:44:32,932 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.bias
# 2022-05-17 00:44:32,945 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.weight
# 2022-05-17 00:44:32,958 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2022-05-17 00:44:32,963 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2022-05-17 00:44:32,974 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2022-05-17 00:44:32,977 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2022-05-17 00:44:32,982 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.bias
# 2022-05-17 00:44:32,993 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.weight
# 2022-05-17 00:44:32,999 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2022-05-17 00:44:33,005 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2022-05-17 00:44:33,010 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2022-05-17 00:44:33,012 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2022-05-17 00:44:33,021 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.bias
# 2022-05-17 00:44:33,027 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.weight
# 2022-05-17 00:44:33,032 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.bias
# 2022-05-17 00:44:33,038 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.weight
# 2022-05-17 00:44:33,043 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.bias
# 2022-05-17 00:44:33,049 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.weight
# 2022-05-17 00:44:33,057 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2022-05-17 00:44:33,065 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2022-05-17 00:44:33,071 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2022-05-17 00:44:33,075 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2022-05-17 00:44:33,081 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.bias
# 2022-05-17 00:44:33,111 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.weight
# 2022-05-17 00:44:33,116 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2022-05-17 00:44:33,123 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2022-05-17 00:44:33,141 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2022-05-17 00:44:33,143 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2022-05-17 00:44:33,155 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2022-05-17 00:44:33,159 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2022-05-17 00:44:33,162 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2022-05-17 00:44:33,182 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2022-05-17 00:44:33,191 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2022-05-17 00:44:33,202 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2022-05-17 00:44:33,212 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2022-05-17 00:44:33,222 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2022-05-17 00:44:33,226 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2022-05-17 00:44:33,232 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2022-05-17 00:44:33,239 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2022-05-17 00:44:33,243 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2022-05-17 00:44:33,245 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2022-05-17 00:44:33,250 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2022-05-17 00:44:33,257 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2022-05-17 00:44:33,262 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2022-05-17 00:44:33,266 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2022-05-17 00:44:33,271 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2022-05-17 00:44:33,275 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2022-05-17 00:44:33,279 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2022-05-17 00:44:33,283 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2022-05-17 00:44:33,287 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2022-05-17 00:44:33,290 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2022-05-17 00:44:33,293 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2022-05-17 00:44:33,300 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2022-05-17 00:44:33,329 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2022-05-17 00:44:33,340 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2022-05-17 00:44:33,343 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2022-05-17 00:44:33,352 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2022-05-17 00:44:33,395 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2022-05-17 00:44:33,613 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2022-05-17 00:44:33,622 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2022-05-17 00:44:48,360 - INFO - allennlp.models.archival - removing temporary unarchived model dir at C:\Users\hp\AppData\Local\Temp\tmpa1718u9a

# %% [markdown]
# # Read text file and preprocess.

# %%
file_name = './Text/What Will Drive China to War.txt'
narrative = open(file_name, encoding="utf8").read()

print('Original Narrative:')
print(narrative)
print('\n')

narrative = predictor.coref_resolved(narrative)
narrative = narrative.lower()
narrative = textacy.preprocessing.normalize_quotation_marks(narrative)
narrative = normalize_hyphenated_words(narrative)
narrative = textacy.preprocessing.normalize_whitespace(narrative)
narrative = remove_punctuation(narrative, marks=';"":')

print('Narrarive after resolving coreferences:')
print(narrative)

print('\nSpacy Sentences:\n')
narrative = nlp(narrative)
for sent in narrative.sents:
    print(sent.text)
    print()

print('\nNLTK Sentences:\n')
raw_sentences = sent_tokenize(str(narrative))
for sent in raw_sentences:
    print(sent)
    print()
# Out:
# Original Narrative:
# President xi jinping declared in July that those who get in the way of China’s ascent will have their “heads bashed bloody against a Great Wall of steel.” The People’s Liberation Army Navy is churning out ships at a rate not seen since World War II, as Beijing issues threats against Taiwan and other neighbors. Top Pentagon officials have warned that China could start a military conflict in the Taiwan Strait or other geopolitical hot spots sometime this decade.
#
# Analysts and officials in Washington are fretting over worsening tensions between the United States and China and the risks to the world of two superpowers once again clashing rather than cooperating. President Joe Biden has said that America “is not seeking a new cold war.” But that is the wrong way to look at U.S.-China relations. A cold war with Beijing is already under way. The right question, instead, is whether America can deter China from initiating a hot one.
#
# Beijing is a remarkably ambitious revanchist power, one determined to make China whole again by “reuniting” Taiwan with the mainland, turning the East and South China Seas into Chinese lakes, and grabbing regional primacy as a stepping-stone to global power. It is also increasingly encircled, and faces growing resistance on many fronts—just the sort of scenario that has led it to lash out in the past.
#
# The historical record since the founding of the People’s Republic of China in 1949 is clear: When confronted by a mounting threat to its geopolitical interests, Beijing does not wait to be attacked; it shoots first to gain the advantage of surprise.
#
# In conflicts including the Korean War and clashes with Vietnam in 1979, China has often viewed the use of force as an educational exercise. It is willing to pick even a very costly fight with a single enemy to teach it, and others observing from the sidelines, a lesson.
#
# Today, Beijing might be tempted to engage in this sort of aggression in multiple areas. And once the shooting starts, the pressures for escalation are likely to be severe.
#
# Numerous scholars have analyzed when and why Beijing uses force. Most reach a similar conclusion: China attacks not when it feels confident about the future but when it worries its enemies are closing in. As Thomas Christensen, the director of the China and the World Program at Columbia University, writes, the Chinese Communist Party wages war when it perceives an opening window of vulnerability regarding its territory and immediate periphery, or a closing window of opportunity to consolidate control over disputed areas. This pattern holds regardless of the strength of China’s opponent. In fact, Beijing often has attacked far superior foes—including the U.S.—to cut them down to size and beat them back from Chinese-claimed or otherwise sensitive territory.
#
#
# Narrarive after resolving coreferences:
# president xi jinping declared in july that those who get in the way of china's ascent will have those who get in the way of china's ascent's  heads bashed bloody against a great wall of steel.  the people's liberation army navy is churning out ships at a rate not seen since world war ii, as china's issues threats against taiwan and other neighbors. top pentagon officials have warned that china's could start a military conflict in the taiwan strait or other geopolitical hot spots sometime this decade.
# analysts and officials in washington are fretting over worsening tensions between the united states and china's and the risks to the world of two superpowers once again clashing rather than cooperating. president joe biden has said that the united states  is not seeking a new cold war.  but said is the wrong way to look at u.s.-china relations. a cold war with china's is already under way. the right question, instead, is whether the united states can deter china's from initiating a hot one.
# china's is a remarkably ambitious revanchist power, one determined to make china's whole again by  reuniting  taiwan with the mainland, turning the east and south china seas into chinese lakes, and grabbing regional primacy as a stepping-stone to global power. china's is also increasingly encircled, and faces growing resistance on many fronts—just the sort of scenario that has led china's to lash out in the past.
# the historical record since the founding of the people's republic of china in 1949 is clear  when confronted by a mounting threat to china's's geopolitical interests, china's does not wait to be attacked  china's shoots first to gain the advantage of surprise.
# in conflicts including the korean war and clashes with vietnam in 1979, china's has often viewed the use of force as an educational exercise. china's is willing to pick even a very costly fight with a single enemy to teach china's, and others observing from the sidelines, a lesson.
# today, china's might be tempted to engage in this sort of aggression in multiple areas. and once the shooting starts, the pressures for escalation are likely to be severe.
# numerous scholars have analyzed when and why china's uses force. most reach a similar conclusion  china's attacks not when china's feels confident about the future but when china's worries china's's enemies are closing in. as thomas christensen, the director of the china and the world program at columbia university, writes, china's wages war when china's perceives an opening window of vulnerability regarding china's's territory and immediate periphery, or a closing window of opportunity to consolidate control over disputed areas. this pattern holds regardless of the strength of china's's opponent. in fact, china's often has attacked far superior foes—including the united states cut far superior foes—including the u.s.—to down to size and beat far superior foes—including the u.s.—to back from chinese-claimed or otherwise sensitive territory.
#
# Spacy Sentences:
#
# president xi jinping declared in july that those who get in the way of china's ascent will have those who get in the way of china's ascent's  heads bashed bloody against a great wall of steel.
#
# the people's liberation army navy is churning out ships at a rate not seen since world war ii, as china's issues threats against taiwan and other neighbors.
#
# top pentagon officials have warned that china's could start a military conflict in the taiwan strait or other geopolitical hot spots sometime this decade.
#
#
# analysts and officials in washington are fretting over worsening tensions between the united states and china's and the risks to the world of two superpowers once again clashing rather than cooperating.
#
# president joe biden has said that the united states  is not seeking a new cold war.
#
# but said is the wrong way to look at u.s.-china relations.
#
# a cold war with china's is already under way.
#
# the right question, instead, is whether the united states can deter china's from initiating a hot one.
#
#
# china's is a remarkably ambitious revanchist power, one determined to make china's whole again by  reuniting  taiwan with the mainland, turning the east and south china seas into chinese lakes, and grabbing regional primacy as a stepping-stone to global power.
#
# china's is also increasingly encircled, and faces growing resistance on many fronts—just the sort of scenario that has led china's to lash out in the past.
#
#
# the historical record since the founding of the people's republic of china in 1949 is clear  when confronted by a mounting threat to china's's geopolitical interests, china's does not wait to be attacked  china's shoots first to gain the advantage of surprise.
#
#
# in conflicts including the korean war and clashes with vietnam in 1979, china's has often viewed the use of force as an educational exercise.
#
# china's is willing to pick even a very costly fight with a single enemy to teach china's, and others observing from the sidelines, a lesson.
#
#
# today, china's might be tempted to engage in this sort of aggression in multiple areas.
#
# and once the shooting starts, the pressures for escalation are likely to be severe.
#
#
# numerous scholars have analyzed when and why china's uses force.
#
# most reach a similar conclusion  china's attacks not when china's feels confident about the future
#
# but when china's worries china's's enemies are closing in.
#
# as thomas christensen, the director of the china and the world program at columbia university, writes, china's wages war when china's perceives an opening window of vulnerability regarding china's's territory and immediate periphery, or a closing window of opportunity to consolidate control over disputed areas.
#
# this pattern holds regardless of the strength of china's's opponent.
#
# in fact, china's often has attacked far superior foes—including the united states cut far superior foes—including the u.s.—to down to size and beat far superior foes—including the u.s.—to back from chinese-claimed or otherwise sensitive territory.
#
#
# NLTK Sentences:
#
# president xi jinping declared in july that those who get in the way of china's ascent will have those who get in the way of china's ascent's  heads bashed bloody against a great wall of steel.
#
# the people's liberation army navy is churning out ships at a rate not seen since world war ii, as china's issues threats against taiwan and other neighbors.
#
# top pentagon officials have warned that china's could start a military conflict in the taiwan strait or other geopolitical hot spots sometime this decade.
#
# analysts and officials in washington are fretting over worsening tensions between the united states and china's and the risks to the world of two superpowers once again clashing rather than cooperating.
#
# president joe biden has said that the united states  is not seeking a new cold war.
#
# but said is the wrong way to look at u.s.-china relations.
#
# a cold war with china's is already under way.
#
# the right question, instead, is whether the united states can deter china's from initiating a hot one.
#
# china's is a remarkably ambitious revanchist power, one determined to make china's whole again by  reuniting  taiwan with the mainland, turning the east and south china seas into chinese lakes, and grabbing regional primacy as a stepping-stone to global power.
#
# china's is also increasingly encircled, and faces growing resistance on many fronts—just the sort of scenario that has led china's to lash out in the past.
#
# the historical record since the founding of the people's republic of china in 1949 is clear  when confronted by a mounting threat to china's's geopolitical interests, china's does not wait to be attacked  china's shoots first to gain the advantage of surprise.
#
# in conflicts including the korean war and clashes with vietnam in 1979, china's has often viewed the use of force as an educational exercise.
#
# china's is willing to pick even a very costly fight with a single enemy to teach china's, and others observing from the sidelines, a lesson.
#
# today, china's might be tempted to engage in this sort of aggression in multiple areas.
#
# and once the shooting starts, the pressures for escalation are likely to be severe.
#
# numerous scholars have analyzed when and why china's uses force.
#
# most reach a similar conclusion  china's attacks not when china's feels confident about the future but when china's worries china's's enemies are closing in.
#
# as thomas christensen, the director of the china and the world program at columbia university, writes, china's wages war when china's perceives an opening window of vulnerability regarding china's's territory and immediate periphery, or a closing window of opportunity to consolidate control over disputed areas.
#
# this pattern holds regardless of the strength of china's's opponent.
#
# in fact, china's often has attacked far superior foes—including the united states cut far superior foes—including the u.s.—to down to size and beat far superior foes—including the u.s.—to back from chinese-claimed or otherwise sensitive territory.

# %% [markdown]
# # Extract the Subject-Verb-Object triples.

# %%
#new
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
#tuple =('a','b','c')

#print(tuple[0])

for sent in raw_sentences:
    sent = nlp(sent)
    print("Sentence:")
    print(sent)
    
    print("Noun Chunks:")
    for nc in sent.noun_chunks:
        print (nc)
        ncl.append(nc)
    print ("Number of noun chunks: ", len(ncl))
    
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            print("Triples other than textacy:")
            print(nncl[0])
            print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],triplets[0][1],ncl[1])]
#            print("Triples other than textacy:")
#            print(nncl[0])
#            finalList.append(nncl[0])
    else:
        print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                sub = token
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
                #tuple[1] = token.text
            #elif token.dep_ == 'dobj':
            #    obj = token.text
                #tuple[2] = token.text
            #    break
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue
                
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        print("Triple by combining nsubj, root and dobj:")
        print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],verb,ncl[1])]
#            print("Triples other than sub, verb and obj:")
#            print(nncl[0])
#            finalList.append(nncl[0])

    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
    
trips = finalList

#        for token in nc:
#            print(token.text, token.dep_)
# Out:
# Sentence:
# president xi jinping declared in july that those who get in the way of china's ascent will have those who get in the way of china's ascent's  heads bashed bloody against a great wall of steel.
# Noun Chunks:
# president xi jinping
# july
# who
# the way
# china's ascent
# who
# the way
# china's ascent's  heads
# a great wall
# steel
# Number of noun chunks:  10
# Triples from textacy:
# (china's ascent's  heads, bashed, bloody)
# Sentence:
# the people's liberation army navy is churning out ships at a rate not seen since world war ii, as china's issues threats against taiwan and other neighbors.
# Noun Chunks:
# the people's liberation army navy
# ships
# a rate
# world war ii
# taiwan
# other neighbors
# Number of noun chunks:  6
# Triples from textacy:
# (army navy, is churning, ships)
# Sentence:
# top pentagon officials have warned that china's could start a military conflict in the taiwan strait or other geopolitical hot spots sometime this decade.
# Noun Chunks:
# top pentagon officials
# china
# a military conflict
# the taiwan strait
# other geopolitical hot spots
# Number of noun chunks:  5
# Triples from textacy:
# (china, could start, a military conflict)
# Sentence:
# analysts and officials in washington are fretting over worsening tensions between the united states and china's and the risks to the world of two superpowers once again clashing rather than cooperating.
# Noun Chunks:
# analysts
# officials
# washington
# tensions
# the united states
# china
# the risks
# the world
# two superpowers
# Number of noun chunks:  9
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (analysts, fretting, two superpowers)
# Sentence:
# president joe biden has said that the united states  is not seeking a new cold war.
# Noun Chunks:
# president joe biden
# the united states
# a new cold war
# Number of noun chunks:  3
# Triples from textacy:
# (united states, is not seeking, a new cold war)
# Triples other than textacy:
# (president joe biden, is not seeking, the united states)
# (president joe biden, is not seeking, a new cold war)
# Sentence:
# but said is the wrong way to look at u.s.-china relations.
# Noun Chunks:
# the wrong way
# u.s.-china relations
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (analysts, said, u.s.-china relations)
# Sentence:
# a cold war with china's is already under way.
# Noun Chunks:
# a cold war
# china
# way
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (a cold war, is, way)
# Triples other than sub, verb and obj:
# (a cold war, is, china)
# (a cold war, is, way)
# Sentence:
# the right question, instead, is whether the united states can deter china's from initiating a hot one.
# Noun Chunks:
# the right question
# the united states
# china
# a hot one
# Number of noun chunks:  4
# Triples from textacy:
# (united states, can deter, china)
# Sentence:
# china's is a remarkably ambitious revanchist power, one determined to make china's whole again by  reuniting  taiwan with the mainland, turning the east and south china seas into chinese lakes, and grabbing regional primacy as a stepping-stone to global power.
# Noun Chunks:
# china
# a remarkably ambitious revanchist power
# china's whole
# taiwan
# the mainland
# the east and south china seas
# chinese lakes
# regional primacy
# a stepping-stone
# global power
# Number of noun chunks:  10
# Triples from textacy:
# (one, determined, to make)
# (one, determined, turning)
# (one, determined, grabbing)
# Sentence:
# china's is also increasingly encircled, and faces growing resistance on many fronts—just the sort of scenario that has led china's to lash out in the past.
# Noun Chunks:
# china
# growing resistance
# many fronts
# just the sort
# scenario
# china
# the past
# Number of noun chunks:  7
# Triples from textacy:
# (that, has led, china)
# (that, has led, to lash)
# Sentence:
# the historical record since the founding of the people's republic of china in 1949 is clear  when confronted by a mounting threat to china's's geopolitical interests, china's does not wait to be attacked  china's shoots first to gain the advantage of surprise.
# Noun Chunks:
# the historical record
# the founding
# the people's republic
# china
# a mounting threat
# china's's geopolitical interests
# china
# china's shoots
# the advantage
# surprise
# Number of noun chunks:  10
# Triples from textacy:
# (china's shoots, does not wait, to be attacked)
# Sentence:
# in conflicts including the korean war and clashes with vietnam in 1979, china's has often viewed the use of force as an educational exercise.
# Noun Chunks:
# conflicts
# the korean war
# clashes
# vietnam
# china
# the use
# force
# an educational exercise
# Number of noun chunks:  8
# Triples from textacy:
# (china, viewed, the use)
# Sentence:
# china's is willing to pick even a very costly fight with a single enemy to teach china's, and others observing from the sidelines, a lesson.
# Noun Chunks:
# china
# even a very costly fight
# a single enemy
# china
# others
# the sidelines
# a lesson
# Number of noun chunks:  7
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (china, is, the sidelines)
# Sentence:
# today, china's might be tempted to engage in this sort of aggression in multiple areas.
# Noun Chunks:
# china
# this sort
# aggression
# multiple areas
# Number of noun chunks:  4
# Triples from textacy:
# (china, might be tempted, to engage)
# Sentence:
# and once the shooting starts, the pressures for escalation are likely to be severe.
# Noun Chunks:
# the shooting
# the pressures
# escalation
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (the pressures, are, escalation)
# Triples other than sub, verb and obj:
# (the shooting, are, the pressures)
# (the shooting, are, escalation)
# Sentence:
# numerous scholars have analyzed when and why china's uses force.
# Noun Chunks:
# numerous scholars
# when and why china's uses force
# Number of noun chunks:  2
# Triples from textacy:
# (numerous scholars, have analyzed, when and why china's uses force)
# Sentence:
# most reach a similar conclusion  china's attacks not when china's feels confident about the future but when china's worries china's's enemies are closing in.
# Noun Chunks:
# a similar conclusion
# china's attacks
# china
# the future
# china's's enemies
# Number of noun chunks:  5
# Triples from textacy:
# (most, reach, a similar conclusion)
# Sentence:
# as thomas christensen, the director of the china and the world program at columbia university, writes, china's wages war when china's perceives an opening window of vulnerability regarding china's's territory and immediate periphery, or a closing window of opportunity to consolidate control over disputed areas.
# Noun Chunks:
# thomas christensen
# the director
# the china
# the world program
# columbia university
# china's wages war
# china
# an opening window
# vulnerability
# china's's territory
# immediate periphery
# a closing window
# opportunity
# control
# disputed areas
# Number of noun chunks:  15
# Triples from textacy:
# (thomas christensen, writes, wages war)
# Sentence:
# this pattern holds regardless of the strength of china's's opponent.
# Noun Chunks:
# this pattern
# the strength
# china's's opponent
# Number of noun chunks:  3
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (this pattern, holds, china's's opponent)
# Triples other than sub, verb and obj:
# (this pattern, holds, the strength)
# (this pattern, holds, china's's opponent)
# Sentence:
# in fact, china's often has attacked far superior foes—including the united states cut far superior foes—including the u.s.—to down to size and beat far superior foes—including the u.s.—to back from chinese-claimed or otherwise sensitive territory.
# Noun Chunks:
# fact
# china
# far superior foes
# the united states
# far superior foes
# the u.s.—to
# size
# far superior foes
# the u.s.—to
# chinese-claimed or otherwise sensitive territory
# Number of noun chunks:  10
# Triples from textacy:
# (china, has attacked, far superior foes)

# %% [markdown]
# # Remove Duplicates from Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("Length of triples' List before removing duplicates:")
print(len(trips))

Triples = []
sentences1 = []

for sentence,ce in zip(sentences, trips):
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        sentences1.append(sentence)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            sentences1.append(sentence)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

for t in Triples:
    print(t)
# Out:
# Length of triples' List before removing duplicates:
# 31
#
# List after removing duplicates:
# 29
# (china's ascent's  heads, bashed, bloody)
# (army navy, is churning, ships)
# (china, could start, a military conflict)
# (analysts, fretting, two superpowers)
# (united states, is not seeking, a new cold war)
# (president joe biden, is not seeking, the united states)
# (president joe biden, is not seeking, a new cold war)
# (analysts, said, u.s.-china relations)
# (a cold war, is, way)
# (a cold war, is, china)
# (united states, can deter, china)
# (one, determined, to make)
# (one, determined, turning)
# (one, determined, grabbing)
# (that, has led, china)
# (that, has led, to lash)
# (china's shoots, does not wait, to be attacked)
# (china, viewed, the use)
# (china, is, the sidelines)
# (china, might be tempted, to engage)
# (the pressures, are, escalation)
# (the shooting, are, the pressures)
# (the shooting, are, escalation)
# (numerous scholars, have analyzed, when and why china's uses force)
# (most, reach, a similar conclusion)
# (thomas christensen, writes, wages war)
# (this pattern, holds, china's's opponent)
# (this pattern, holds, the strength)
# (china, has attacked, far superior foes)

# %% [markdown]
# # Filter correct triples from extracted triples

# %%
correctTriples = []
sentences2 = []

for sentence,line in zip(sentences1, Triples):
    taggedWords = []
    taggedWords1 = []
    check0 = False
    check2 = False
    print(line)
    taggedWords = pos_tag(word_tokenize(str(line[0])))
    taggedWords1 = pos_tag(word_tokenize(str(line[2])))
    print(taggedWords)
    print(taggedWords1)
    for i in range(len(taggedWords)):
        if taggedWords[i][1] == 'NN' or taggedWords[i][1] == 'NNS':
            check0 = True
    for i in range(len(taggedWords1)):
        if taggedWords1[i][1] == 'NN' or taggedWords1[i][1] == 'NNS':
            check2 = True
    print(check0)  
    print(check2)
    if check0 == True and check2 == True:
        correctTriples.append(line)
        sentences2.append(sentence)
    print("**************************************************************************")
    
for correctTriple in correctTriples:
    print(correctTriple)
# Out:
# (china's ascent's  heads, bashed, bloody)
# [('china', 'NN'), ("'s", 'POS'), ('ascent', 'NN'), ("'s", 'POS'), ('heads', 'NNS')]
# [('bloody', 'NN')]
# True
# True
# **************************************************************************
# (army navy, is churning, ships)
# [('army', 'NN'), ('navy', 'NN')]
# [('ships', 'NNS')]
# True
# True
# **************************************************************************
# (china, could start, a military conflict)
# [('china', 'NN')]
# [('a', 'DT'), ('military', 'JJ'), ('conflict', 'NN')]
# True
# True
# **************************************************************************
# (analysts, fretting, two superpowers)
# [('analysts', 'NNS')]
# [('two', 'CD'), ('superpowers', 'NNS')]
# True
# True
# **************************************************************************
# (united states, is not seeking, a new cold war)
# [('united', 'JJ'), ('states', 'NNS')]
# [('a', 'DT'), ('new', 'JJ'), ('cold', 'JJ'), ('war', 'NN')]
# True
# True
# **************************************************************************
# (president joe biden, is not seeking, the united states)
# [('president', 'NN'), ('joe', 'NNS'), ('biden', 'VBP')]
# [('the', 'DT'), ('united', 'JJ'), ('states', 'NNS')]
# True
# True
# **************************************************************************
# (president joe biden, is not seeking, a new cold war)
# [('president', 'NN'), ('joe', 'NNS'), ('biden', 'VBP')]
# [('a', 'DT'), ('new', 'JJ'), ('cold', 'JJ'), ('war', 'NN')]
# True
# True
# **************************************************************************
# (analysts, said, u.s.-china relations)
# [('analysts', 'NNS')]
# [('u.s.-china', 'JJ'), ('relations', 'NNS')]
# True
# True
# **************************************************************************
# (a cold war, is, way)
# [('a', 'DT'), ('cold', 'JJ'), ('war', 'NN')]
# [('way', 'NN')]
# True
# True
# **************************************************************************
# (a cold war, is, china)
# [('a', 'DT'), ('cold', 'JJ'), ('war', 'NN')]
# [('china', 'NN')]
# True
# True
# **************************************************************************
# (united states, can deter, china)
# [('united', 'JJ'), ('states', 'NNS')]
# [('china', 'NN')]
# True
# True
# **************************************************************************
# (one, determined, to make)
# [('one', 'CD')]
# [('to', 'TO'), ('make', 'VB')]
# False
# False
# **************************************************************************
# (one, determined, turning)
# [('one', 'CD')]
# [('turning', 'VBG')]
# False
# False
# **************************************************************************
# (one, determined, grabbing)
# [('one', 'CD')]
# [('grabbing', 'VBG')]
# False
# False
# **************************************************************************
# (that, has led, china)
# [('that', 'IN')]
# [('china', 'NN')]
# False
# True
# **************************************************************************
# (that, has led, to lash)
# [('that', 'IN')]
# [('to', 'TO'), ('lash', 'VB')]
# False
# False
# **************************************************************************
# (china's shoots, does not wait, to be attacked)
# [('china', 'NN'), ("'s", 'POS'), ('shoots', 'NNS')]
# [('to', 'TO'), ('be', 'VB'), ('attacked', 'VBN')]
# True
# False
# **************************************************************************
# (china, viewed, the use)
# [('china', 'NN')]
# [('the', 'DT'), ('use', 'NN')]
# True
# True
# **************************************************************************
# (china, is, the sidelines)
# [('china', 'NN')]
# [('the', 'DT'), ('sidelines', 'NNS')]
# True
# True
# **************************************************************************
# (china, might be tempted, to engage)
# [('china', 'NN')]
# [('to', 'TO'), ('engage', 'VB')]
# True
# False
# **************************************************************************
# (the pressures, are, escalation)
# [('the', 'DT'), ('pressures', 'NNS')]
# [('escalation', 'NN')]
# True
# True
# **************************************************************************
# (the shooting, are, the pressures)
# [('the', 'DT'), ('shooting', 'NN')]
# [('the', 'DT'), ('pressures', 'NNS')]
# True
# True
# **************************************************************************
# (the shooting, are, escalation)
# [('the', 'DT'), ('shooting', 'NN')]
# [('escalation', 'NN')]
# True
# True
# **************************************************************************
# (numerous scholars, have analyzed, when and why china's uses force)
# [('numerous', 'JJ'), ('scholars', 'NNS')]
# [('when', 'WRB'), ('and', 'CC'), ('why', 'WRB'), ('china', 'NN'), ("'s", 'POS'), ('uses', 'NNS'), ('force', 'NN')]
# True
# True
# **************************************************************************
# (most, reach, a similar conclusion)
# [('most', 'JJS')]
# [('a', 'DT'), ('similar', 'JJ'), ('conclusion', 'NN')]
# False
# True
# **************************************************************************
# (thomas christensen, writes, wages war)
# [('thomas', 'NN'), ('christensen', 'NN')]
# [('wages', 'NNS'), ('war', 'NN')]
# True
# True
# **************************************************************************
# (this pattern, holds, china's's opponent)
# [('this', 'DT'), ('pattern', 'NN')]
# [("china's", 'NN'), ("'s", 'POS'), ('opponent', 'NN')]
# True
# True
# **************************************************************************
# (this pattern, holds, the strength)
# [('this', 'DT'), ('pattern', 'NN')]
# [('the', 'DT'), ('strength', 'NN')]
# True
# True
# **************************************************************************
# (china, has attacked, far superior foes)
# [('china', 'NN')]
# [('far', 'RB'), ('superior', 'JJ'), ('foes', 'NNS')]
# True
# True
# **************************************************************************
# (china's ascent's  heads, bashed, bloody)
# (army navy, is churning, ships)
# (china, could start, a military conflict)
# (analysts, fretting, two superpowers)
# (united states, is not seeking, a new cold war)
# (president joe biden, is not seeking, the united states)
# (president joe biden, is not seeking, a new cold war)
# (analysts, said, u.s.-china relations)
# (a cold war, is, way)
# (a cold war, is, china)
# (united states, can deter, china)
# (china, viewed, the use)
# (china, is, the sidelines)
# (the pressures, are, escalation)
# (the shooting, are, the pressures)
# (the shooting, are, escalation)
# (numerous scholars, have analyzed, when and why china's uses force)
# (thomas christensen, writes, wages war)
# (this pattern, holds, china's's opponent)
# (this pattern, holds, the strength)
# (china, has attacked, far superior foes)

# %% [markdown]
# # Print the extracted triples with sentences.

# %%
for sentence, triple  in zip(sentences2, correctTriples):
    print(sentence, triple)
    print()
# Out:
# president xi jinping declared in july that those who get in the way of china's ascent will have those who get in the way of china's ascent's  heads bashed bloody against a great wall of steel. (china's ascent's  heads, bashed, bloody)
#
# the people's liberation army navy is churning out ships at a rate not seen since world war ii, as china's issues threats against taiwan and other neighbors. (army navy, is churning, ships)
#
# top pentagon officials have warned that china's could start a military conflict in the taiwan strait or other geopolitical hot spots sometime this decade. (china, could start, a military conflict)
#
# analysts and officials in washington are fretting over worsening tensions between the united states and china's and the risks to the world of two superpowers once again clashing rather than cooperating. (analysts, fretting, two superpowers)
#
# president joe biden has said that the united states  is not seeking a new cold war. (united states, is not seeking, a new cold war)
#
# president joe biden has said that the united states  is not seeking a new cold war. (president joe biden, is not seeking, the united states)
#
# president joe biden has said that the united states  is not seeking a new cold war. (president joe biden, is not seeking, a new cold war)
#
# but said is the wrong way to look at u.s.-china relations. (analysts, said, u.s.-china relations)
#
# a cold war with china's is already under way. (a cold war, is, way)
#
# a cold war with china's is already under way. (a cold war, is, china)
#
# the right question, instead, is whether the united states can deter china's from initiating a hot one. (united states, can deter, china)
#
# in conflicts including the korean war and clashes with vietnam in 1979, china's has often viewed the use of force as an educational exercise. (china, viewed, the use)
#
# china's is willing to pick even a very costly fight with a single enemy to teach china's, and others observing from the sidelines, a lesson. (china, is, the sidelines)
#
# and once the shooting starts, the pressures for escalation are likely to be severe. (the pressures, are, escalation)
#
# and once the shooting starts, the pressures for escalation are likely to be severe. (the shooting, are, the pressures)
#
# and once the shooting starts, the pressures for escalation are likely to be severe. (the shooting, are, escalation)
#
# numerous scholars have analyzed when and why china's uses force. (numerous scholars, have analyzed, when and why china's uses force)
#
# as thomas christensen, the director of the china and the world program at columbia university, writes, china's wages war when china's perceives an opening window of vulnerability regarding china's's territory and immediate periphery, or a closing window of opportunity to consolidate control over disputed areas. (thomas christensen, writes, wages war)
#
# this pattern holds regardless of the strength of china's's opponent. (this pattern, holds, china's's opponent)
#
# this pattern holds regardless of the strength of china's's opponent. (this pattern, holds, the strength)
#
# in fact, china's often has attacked far superior foes—including the united states cut far superior foes—including the u.s.—to down to size and beat far superior foes—including the u.s.—to back from chinese-claimed or otherwise sensitive territory. (china, has attacked, far superior foes)

# %% [markdown]
# # Plot the knowledge Graph.

# %%
cmap = nx.DiGraph()

for triple in correctTriples:
    s = str(triple[0])    
    d = str(triple[2])
    cmap.add_edge(s, d, predicate=triple[1])
    #print(triple)

print("Nodes:",len(cmap.nodes))
print("Edges:",len(cmap.edges))
for e in cmap.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cmap, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cmap, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cmap.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cmap,'predicate')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 28
# Edges: 21
# china's ascent's  heads , {'predicate': bashed} , bloody
# army navy , {'predicate': is churning} , ships
# china , {'predicate': could start} , a military conflict
# china , {'predicate': viewed} , the use
# china , {'predicate': is} , the sidelines
# china , {'predicate': has attacked} , far superior foes
# analysts , {'predicate': fretting} , two superpowers
# analysts , {'predicate': said} , u.s.-china relations
# united states , {'predicate': is not seeking} , a new cold war
# united states , {'predicate': can deter} , china
# president joe biden , {'predicate': is not seeking} , the united states
# president joe biden , {'predicate': is not seeking} , a new cold war
# a cold war , {'predicate': is} , way
# a cold war , {'predicate': is} , china
# the pressures , {'predicate': are} , escalation
# the shooting , {'predicate': are} , the pressures
# the shooting , {'predicate': are} , escalation
# numerous scholars , {'predicate': have analyzed} , when and why china's uses force
# thomas christensen , {'predicate': writes} , wages war
# this pattern , {'predicate': holds} , china's's opponent
# this pattern , {'predicate': holds} , the strength

# %% [markdown]
# # Dump the Knowledge Graph on "Knowledge Graph.json"

# %%
knowledgeGraph = nx.DiGraph()

for svo in correctTriples:
    s = str(svo[0])    
    d = str(svo[2])
    knowledgeGraph.add_node(s,id = str(s),title=str(s),x=615,y=200)
    knowledgeGraph.add_node(d,id = str(d),title=str(d),x=615,y=200)
    knowledgeGraph.add_edge(s, d, predicade=str(svo[1]))

#print(len(knowledgeGraph.nodes))
#print(len(knowledgeGraph.edges))

data = json_graph.node_link_data(knowledgeGraph)


out_file = open("./Json Graphs/Knowledge Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Create Causal Trigger Words Dictionary along with their synonyms.

# %%
#new

causalWords1 = ["forced","caused", "resulted", "reason", "as a result of", "as a consequence of", 
               "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
               ,"made","minimize","maximize","hindered", "displaced", "conspired","led to","activate","impel","inspire",
                "excite","quicken","rouse","stimulate","influence","determine","likely","probable","disconnected","separated"
                ,"excluded","after","as","since","trigger","oppose","fight","provides","strengthened","launched","develop"
               ,"guarantees","declared", "developed","produced","discourages","demotivated","encouraged","motivated"]

#causalWords1 = ["develop"]
synonyms1 = []
lemma_function = WordNetLemmatizer()

for cw1 in causalWords1:
    #print(cw1)
    synonyms1.append(cw1.lower())
    tokens1 = word_tokenize(cw1)
    for token1, tag1 in pos_tag(tokens1):
        lemma1 = lemma_function.lemmatize(token1)
        #print(token1,lemma1)
        
        for syn in wordnet.synsets(str(lemma1)):
            
            for l1 in syn.lemmas():
                #print(l1)
                #synonyms1.append(lemma1.lower())
                synonyms1.append(l1.name().lower())
                #print(l1)
                for syn1 in wordnet.synsets(str(l1.name())):
                    for l2 in syn1.lemmas():
                        #print(l2)
                        synonyms1.append(l2.name().lower())
            

#remove duplicates from synonyms1
synonyms = []
     
for synonym in synonyms1:
    if synonym not in synonyms:
        synonyms.append(synonym)
    
#for x in synonyms:
#    print (synonym)

print(len(synonyms))
# Out:
# 3226

# %% [markdown]
# # Writing causal trigger words dictionary to text file (dictionary.txt)

# %%
#synonyms
output_file = open('.\dictionary.txt', 'w')

for syn in synonyms:
    #print(syn)
    output_file.write(syn + '\n')

output_file.close()

# %% [markdown]
# # Reading causal trigger words dictionary from text file (dictionary.txt) to list

# %%
synonyms = []

my_file = open(".\dictionary.txt", "r")
  
data = my_file.read()
  
synonyms = data.split("\n")
#print(data_into_list)
my_file.close()

print(len(synonyms))
# Out:
# 3227

# %% [raw]
# #old
#
# causalWords = ["forced","caused", "result", "reason", "as a result of", "as a consequence of",
#                "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
#                ,"made","mimimize","maximize","led to","produced"]
#
# #causalWords = ["as a result of"]
# synonyms = []
#
# for cw in causalWords:
#
#     for syn in wordnet.synsets(str(cw)):
#         for l in syn.lemmas():
#             synonyms.append(cw)
#             synonyms.append(l.name())
#
# print(set(synonyms))
# print(len(synonyms))

# %% [markdown]
# # Filter Causal triples along with their causal sentences from SVO triples based upon causal trigger words dictionary.

# %%
causeffect = [] #without duplicates
causalSentences = [] #with duplicates
#lem = []
#lemma_function = WordNetLemmatizer()
for s,st in zip(sentences2,correctTriples):
    check = False
    #st = (str(st[0]),str(st[1]),str(st[2]))
    #synonym = synonym[0]
    tokens = word_tokenize(str(st[1]))
    for token, tag in pos_tag(tokens):
        lemma = lemma_function.lemmatize(token)
        #print(token,lemma)
        #st[1] = lemma
        #lem.append(lemma)
        
    for synonym in synonyms:
        if synonym == lemma:
            #causeffect = [(st[0],st[1],st[2])]
            #strTriples.append((ncl[0],token.text,st[2]))
           # print(st)
            if len(causeffect) == 0:
                causeffect.append(st)
                causalSentences.append(s)
            else:
                for ct in causeffect:
                    if str(st[0]) == str(ct[0]) and str(st[1]) == str(ct[1]) and str(st[2]) == str(ct[2]):
                        check = True
                        break;
                if check == False:
                    causeffect.append(st)
                    causalSentences.append(s)
            #if (len(causeffect) >0 ) and (st in causeffect == False):
                
            #    causeffect.append(st)
            break
    
#causeffect.sort(key = lambda x: x[0])

#for sortedTriple in causeffect:
#    print(sortedTriple)
print(len(causalSentences))
print(len(causeffect))
for causalSentence, causalTriple  in zip(causalSentences, causeffect):
    print(causalSentence, causalTriple)
# Out:
# 14
# 14
# zulfikar ali bhutto launched nuclear program. (zulfikar ali bhutto, launched, nuclear program)
# nuclear program declared pakistan's commitment and pakistan's dedication. (nuclear program, declared, pakistan's commitment)
# nuclear program declared pakistan's commitment and pakistan's dedication. (nuclear program, declared, pakistan's dedication)
# aq khan developed nuclear bomb. (aq khan, developed, nuclear bomb)
# nuclear bomb strengthened pakistan. (nuclear bomb, strengthened, pakistan)
# nuclear bomb makes nuclear power. (nuclear bomb, makes, nuclear power)
# pakistan must never surrender nuclear bomb. (pakistan, must never surrender, nuclear bomb)
# pakistan must fight off existential threats. (pakistan, must fight, existential threats)
# pakistan must support army and aq khan. (pakistan, must support, army)
# pakistan must support army and aq khan. (pakistan, must support, aq khan)
# army guards nuclear bomb. (army, guards, nuclear bomb)
# army provides vigilance. (army, provides, vigilance)
# vigilance strengthened national survival. (vigilance, strengthened, national survival)
# nuclear bomb guarantees pakistan's continued existence. (nuclear bomb, guarantees, pakistan's continued existence)

# %% [markdown]
# # Plot the Causal Graph.

# %%
#new (DAG Implementation)
#without duplicates
dagCauseTriples = []
cg = nx.DiGraph()

for ce in causeffect:
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
    dagCauseTriples.append(ce)
    if nx.is_directed_acyclic_graph(cg) is False:
        cg.remove_edge(s, d)
        dagCauseTriples.remove(ce)
        

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 13
# Edges: 11
# zulfikar ali bhutto , {'predicade': 'launched'} , nuclear program
# nuclear program , {'predicade': 'declared'} , pakistan's commitment
# nuclear program , {'predicade': 'declared'} , pakistan's dedication
# aq khan , {'predicade': 'developed'} , nuclear bomb
# nuclear bomb , {'predicade': 'strengthened'} , pakistan
# nuclear bomb , {'predicade': 'makes'} , nuclear power
# nuclear bomb , {'predicade': 'guarantees'} , pakistan's continued existence
# pakistan , {'predicade': 'must fight'} , existential threats
# pakistan , {'predicade': 'must support'} , army
# army , {'predicade': 'provides'} , vigilance
# vigilance , {'predicade': 'strengthened'} , national survival

# %% [markdown]
# # Plot the Causal Graph on using Pyvis "Causal Graph.html" file

# %%
nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')

for dm in dagCauseTriples:
    #color = "#ffffff"
    nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_node(str(dm[2]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_edge(str(dm[0]),str(dm[2]),label=str(dm[1]), weight=10, physics='false',color='black')

#nt.show_buttons(filter_=['physics'])
nt.set_edge_smooth('discrete')
nt.show("./Pyvis Graph/Causal Graph.html")
# Out:
#         <iframe
#             width="1000px"
#             height="500px"
#             src="./Pyvis Graph/Causal Graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [raw]
# nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')
#
# nt.add_node(1, label="Subject (cause)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_node(2, label="Object (effect)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_edge(1,2,label="Verb (cause-effect)", weight=10, physics='false',color='black')
#
#
# nt.show("./Pyvis Graph/Causal Graph.html")

# %% [markdown]
# # Dump the Causal Graph on "Causal Graph.json" file

# %%
data = json_graph.node_link_data(cg)


out_file = open("./Json Graphs/Causal Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Remove Duplicates from Causal Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("List before removing duplicates:")
print(len(causeffect))

for t in causeffect:
    print(t)
    
causalTriples = []

for ce in causeffect:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalTriples) == 0:
        #print("HEY!")
        causalTriples.append(ce)
        #print("added!")
    else:
        for ct in causalTriples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalTriples.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalTriples))

for t in causalTriples:
    print(t)
# Out:
# List before removing duplicates:
# 6
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, guards, nuclear bomb)
#
# List after removing duplicates:
# 6
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, guards, nuclear bomb)

# %% [markdown]
# # Remove Duplicates from causalSentences

# %%
#causalSentences = list(dict.fromkeys(causalSentences))
#causalSentences = list(set(causalSentences))
print("List before removing duplicates:")
print(len(causalSentences))

for t in causalSentences:
    print(t)
    
causalSentencesNoDup = []

for ce in causalSentences:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalSentencesNoDup) == 0:
        #print("HEY!")
        causalSentencesNoDup.append(ce)
        #print("added!")
    else:
        for ct in causalSentencesNoDup:
            #print("ct:")
            #print(ct)
            if str(ce) == str(ct):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalSentencesNoDup.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalSentencesNoDup))

for t in causalSentencesNoDup:
    print(t)
# Out:
# List before removing duplicates:
# 19
# institutional weakness hindered development of the agriculture sector.
# institutional weakness hindered development of the agriculture sector.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# inadequate transportation infrastructure has resulted in less transport to markets.
# inadequate transportation infrastructure has resulted in less transport to markets.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan.
# floods have displaced more than 100,000 people in south sudan.
# floods raise fears.
# floods devastatingly impact on food security in south sudan.
# floods devastatingly impact on food security in south sudan.
#
# List after removing duplicates:
# 11
# institutional weakness hindered development of the agriculture sector.
# the low level of public investment shows that no irrigation infrastructure exists.
# the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.
# inadequate transportation infrastructure has resulted in less transport to markets.
# persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.
# persistent heavy rains in south sudan cause flooding in flood-prone areas.
# highly saturated soils cause flooding in flood-prone areas.
# rain caused floods.
# floods have displaced more than 100,000 people in south sudan.
# floods raise fears.
# floods devastatingly impact on food security in south sudan.

# %% [markdown]
# # Causal Triples' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
allen = []
for sent in causalTriples:
    #print(sent)
    preds = predictor.predict(str(sent))
    #print(preds['label'][0])
    label = preds['label'][0]
    if label is '0':
        allen.append(-1)
    else:
        allen.append(1)
    
for causalSentence, polarity  in zip(causalTriples, allen):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) -1
# (persistent heavy rains, cause, the ethiopian highlands) -1
# (persistent heavy rains, cause, flood prone areas) -1
# (persistent heavy rains, cause, flood-prone areas) -1
# (highly saturated soils, cause, flooding) -1
# (rain, caused, floods) -1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (floods, impact, south sudan) 1
# (floods, impact, food security) 1

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)

afinn = []
for sent in causalTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    #print(score)
    if score > 0:
        #print('positive')
        afinn.append(1)
    elif score < 0:
        #print('negative')
        afinn.append(-1)
    else:
        #print('neutral')
        afinn.append(0)
        
for causalSentence, polarity  in zip(causalTriples, afinn):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) -1
# (the low level, shows, public investment) 0
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) 0
# (persistent heavy rains, cause, the ethiopian highlands) 0
# (persistent heavy rains, cause, flood prone areas) 0
# (persistent heavy rains, cause, flood-prone areas) 0
# (highly saturated soils, cause, flooding) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) 0
# (floods, impact, south sudan) 0
# (floods, impact, food security) 0

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    if compound >= 0.05:
        vader.append(1)
        return 'Positive'
    elif compound <= -0.05 :
        vader.append(-1)
        return 'Negative'
        
    elif  compound > -0.05 and compound < 0.05:
        vader.append(0)
        return 'Neutral'
    
for sent in causalTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    vader_analysis(compound)
    
for causalSentence, polarity  in zip(causalTriples, vader):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) 0
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) -1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) 0
# (persistent heavy rains, cause, the ethiopian highlands) 0
# (persistent heavy rains, cause, flood prone areas) 0
# (persistent heavy rains, cause, flood-prone areas) 0
# (highly saturated soils, cause, flooding) 0
# (rain, caused, floods) 0
# (floods, have displaced, more than 100,000 people) 0
# (floods, have displaced, south sudan) 0
# (floods, raise, fears) -1
# (floods, impact, south sudan) 0
# (floods, impact, food security) 1

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

sentiStrength = []

for sent in causalTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='binary')
    #print(result)
    
    if result[0]==1:
        #print('Positive')
        sentiStrength.append(1)
    elif result[0]==-1:
        sentiStrength.append(-1)
        #print('Negative')
    #else:
    #    print('Neutral')

for causalSentence, polarity  in zip(causalTriples, sentiStrength):
    print(causalSentence, polarity)
# Out:
# (institutional weakness, hindered, development) -1
# (institutional weakness, hindered, the agriculture sector) -1
# (no irrigation infrastructure, shows, public investment) 1
# (the low level, shows, public investment) -1
# (the low level, shows, no irrigation infrastructure) -1
# (south sudan's limited road network, shows, only 2 percent) 1
# (inadequate transportation infrastructure, resulted, markets) -1
# (inadequate transportation infrastructure, resulted, less transport) -1
# (persistent heavy rains, cause, flooding) 1
# (persistent heavy rains, cause, the ethiopian highlands) 1
# (persistent heavy rains, cause, flood prone areas) 1
# (persistent heavy rains, cause, flood-prone areas) 1
# (highly saturated soils, cause, flooding) 1
# (rain, caused, floods) 1
# (floods, have displaced, more than 100,000 people) -1
# (floods, have displaced, south sudan) -1
# (floods, raise, fears) -1
# (floods, impact, south sudan) 1
# (floods, impact, food security) 1

# %% [markdown]
# ### Data Frame (Causal Triples Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# <style  type="text/css" >
# </style><table id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Triple</th>        <th class="col_heading level0 col1" >AllenNLP</th>        <th class="col_heading level0 col2" >Afinn</th>        <th class="col_heading level0 col3" >Vader</th>        <th class="col_heading level0 col4" >SentiStrength</th>        <th class="col_heading level0 col5" >Weight</th>        <th class="col_heading level0 col6" >Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col0" class="data row0 col0" >(institutional weakness, hindered, development)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col1" class="data row0 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col2" class="data row0 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col3" class="data row0 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col4" class="data row0 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col5" class="data row0 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row0_col6" class="data row0 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col0" class="data row1 col0" >(institutional weakness, hindered, the agriculture sector)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col1" class="data row1 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col2" class="data row1 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col4" class="data row1 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col5" class="data row1 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row1_col6" class="data row1 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col0" class="data row2 col0" >(no irrigation infrastructure, shows, public investment)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col1" class="data row2 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col2" class="data row2 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col5" class="data row2 col5" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row2_col6" class="data row2 col6" >Weak Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col0" class="data row3 col0" >(the low level, shows, public investment)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col1" class="data row3 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col3" class="data row3 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col4" class="data row3 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col5" class="data row3 col5" >-3</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row3_col6" class="data row3 col6" >Moderate Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col0" class="data row4 col0" >(the low level, shows, no irrigation infrastructure)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col1" class="data row4 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col2" class="data row4 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col3" class="data row4 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col4" class="data row4 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col5" class="data row4 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row4_col6" class="data row4 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col0" class="data row5 col0" >(south sudan's limited road network, shows, only 2 percent)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col1" class="data row5 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col2" class="data row5 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col3" class="data row5 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col5" class="data row5 col5" >-2</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row5_col6" class="data row5 col6" >Mild Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col0" class="data row6 col0" >(inadequate transportation infrastructure, resulted, markets)</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col1" class="data row6 col1" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col2" class="data row6 col2" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col3" class="data row6 col3" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col4" class="data row6 col4" >-1</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col5" class="data row6 col5" >-4</td>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row6_col6" class="data row6 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7d93f8b6_3cf2_11ec_bd39_648099c56c92row7_col0" class="data row7 col0" >(inadequate transportation infrastructure, resulted, less transport)</td>

# %% [markdown]
# # Causal Sentences' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
def Allen_sents_SentLevel(causalSentences):
    allen = []
    for sent in causalSentences:
        #print(sent)
        preds = predictor.predict(str(sent))
        #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen.append(-1)
        else:
            allen.append(1)
    return allen

#for causalSentence, polarity  in zip(causalSentences, allen):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)
def Afinn_sents_SentLevel(causalSentences):
    afinn = []
    for sent in causalSentences:
        #print(sent)
        score = afn.score(str(sent))
        #print(score)
        if score > 0:
            #print('positive')
            afinn.append(1)
        elif score < 0:
            #print('negative')
            afinn.append(-1)
        else:
            #print('neutral')
            afinn.append(0)
    return afinn

#for causalSentence, polarity  in zip(causalSentences, afinn):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    #vader = []
    if compound >= 0.05:
        #vader.append(1)
        return 1
    elif compound <= -0.05 :
        #vader.append(-1)
        return -1
        
    elif  compound > -0.05 and compound < 0.05:
        #vader.append(0)
        return 0
    #return vader
    
def Vader_sents_SentLevel(causalSentences):
    vader = []
    for sent in causalSentences:
        #print(sent)
        #vaderTup = []
        compound = vadersentimentanalysis(str(sent))
        res = vader_analysis(compound)
        #vaderTup.append(res)
        vader.append(res)
    return vader

#vader = Vader_sents_SentLevel(causalSents)
#vader
#for causalSentence, polarity  in zip(causalSentences, vader):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

def Senti_sents_SentLevel(causalSentences):
    sentiStrength = []
    for sent in causalSentences:
        #print(sent)
        result = senti.getSentiment(str(sent), score='binary')
        #print(result)
    
        if result[0]==1:
            #print('Positive')
            sentiStrength.append(1)
        elif result[0]==-1:
            sentiStrength.append(-1)
            #print('Negative')
        #else:
        #    print('Neutral')
    return sentiStrength

#for causalSentence, polarity  in zip(causalSentences, sentiStrength):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiWordnet]

# %% [raw]
# def penn_to_wn(tag):
#     if tag.startswith('J'):
#         return wn.ADJ
#     elif tag.startswith('N'):
#         return wn.NOUN
#     elif tag.startswith('R'):
#         return wn.ADV
#     elif tag.startswith('V'):
#         return wn.VERB
#     return None
#
# def sentiment_sentiwordnet(text):
#     #text = text.decode("utf-8")
#     raw_sentences = sent_tokenize(text)
#     #print(raw_sentences)
#     sentiment = 0
#     tokens_count = 0
#
#     for raw_sentence in raw_sentences:
#         print(raw_sentence)
#         tagged_sentence = pos_tag(word_tokenize(raw_sentence))
#         print(tagged_sentence)
#
#         for word, tag in tagged_sentence:
#             wn_tag = penn_to_wn(tag)
#             if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
#                 continue
#
#             #lemma = lemmatizer.lemmatize(word, pos=wn_tag)
#             #if not lemma:
#             #    continue
#
#             synsets = wn.synsets(word, pos=wn_tag)
#             if not synsets:
#                 continue
#
#             synset = synsets[0]
#             swn_synset = swn.senti_synset(synset.name())
#             sentiment += swn_synset.pos_score() - swn_synset.neg_score()
#             tokens_count += 1
#         # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
#         if not tokens_count:
#             return 0
#         if sentiment>0:
#             #return "Positive"
#             print("Positive")
#         elif sentiment==0:
#             #return "Neutral"
#             print("Neutral")
#         else:
#             #return "Negative"
#             print("Negative")
#
# causalNarrative = ""
# for cS in causalSentences:
#     causalNarrative = causalNarrative+str(cS)+" "
#
# causalNarrative = nlp(causalNarrative)
# #raw_sentences = sent_tokenize(causalNarrative)
# #print(str(causalNarrative)+"\n")
# #print(raw_sentences)
# #print(str(narrative))
#
# sentiment_sentiwordnet(str(narrative))

# %% [markdown]
# ### [SentiWordNet OnlyVerbs]

# %% [raw]
# from nltk.corpus import wordnet as wn
# from nltk.corpus import sentiwordnet as swn
# from nltk.tag import pos_tag
# import nltk
#
#
# polarizedCauseffect = []
# for ce in causeffect:
#     print(ce[1])
#     token = nltk.word_tokenize(str(ce[1]))
#     after_tagging = nltk.pos_tag(token)
#     print(after_tagging)
#     print(len(after_tagging))
#     for tag in after_tagging:
#         if tag[1].startswith('V') or len(after_tagging)==1:
#             words = swn.senti_synsets(tag[0])
#             answer = list(words)[0]
#             if (answer.pos_score() > answer.neg_score()):
#                 mce = str(ce[1])+"(+ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             elif (answer.pos_score() > 0):
#                 mce = str(ce[1])+"(-ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             else:
#                 mce = str(ce[1])+"(neutral)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#
# polarizedCauseffect

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) without duplicates

# %%
causalSents = causalSentencesNoDup
print(len(causalSents))
# Out:
# 11

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) with duplicates

# %% [raw]
# causalSents = causalSentences
# print(len(causalSents))

# %% [markdown]
# ### Data Frame (Causal Sentence at Sentence Level)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

allen = Allen_sents_SentLevel(causalSents)
afinn = Afinn_sents_SentLevel(causalSents)
vader = Vader_sents_SentLevel(causalSents)
sentiStrength = Senti_sents_SentLevel(causalSents)

df2 = pd.DataFrame(list(zip(causalSents, allen, afinn, vader,sentiStrength)), columns =['Causal Sentence', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)


sentPolarity = []
sentsWeight_sentLevel = []

for index, row in df2.iterrows():
    sentWeightTuple = []
    weight = row['Weight']
    sentWeightTuple.append(weight)
    sentsWeight_sentLevel.append(sentWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# <style  type="text/css" >
# </style><table id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >AllenNLP</th>        <th class="col_heading level0 col2" >Afinn</th>        <th class="col_heading level0 col3" >Vader</th>        <th class="col_heading level0 col4" >SentiStrength</th>        <th class="col_heading level0 col5" >Weight</th>        <th class="col_heading level0 col6" >Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col1" class="data row0 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col2" class="data row0 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col3" class="data row0 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col4" class="data row0 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col5" class="data row0 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col6" class="data row0 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col1" class="data row1 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col2" class="data row1 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col4" class="data row1 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col5" class="data row1 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col6" class="data row1 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col1" class="data row2 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col2" class="data row2 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col3" class="data row2 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col4" class="data row2 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col5" class="data row2 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col6" class="data row2 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col1" class="data row3 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col2" class="data row3 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col3" class="data row3 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col4" class="data row3 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col5" class="data row3 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col6" class="data row3 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col1" class="data row4 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col6" class="data row4 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col1" class="data row5 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col6" class="data row5 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col1" class="data row6 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col4" class="data row6 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col5" class="data row6 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col6" class="data row6 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8

# %% [markdown]
# # Causal Triples' Polarity (Token Level)

# %% [markdown]
# ### [AllenNlp]

# %%
allen_word = []
allen_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks: 
        #print(token)
        preds = predictor.predict(str(token))
            #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen_tuple.append(-1)
                #allen_word.append(-1)
        else:
                #allen_word.append(1)
            allen_tuple.append(1)
    allen_word.append(allen_tuple)
    allen_tuple = []
                
for a,b in zip(causalTriples,allen_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, -1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, -1, 1]
# (no irrigation infrastructure, shows, public investment) [-1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 1, -1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, -1]
# (persistent heavy rains, cause, flooding) [-1, 1, -1]
# (persistent heavy rains, cause, the ethiopian highlands) [-1, 1, 1]
# (persistent heavy rains, cause, flood prone areas) [-1, 1, -1]
# (persistent heavy rains, cause, flood-prone areas) [-1, 1, -1]
# (highly saturated soils, cause, flooding) [1, 1, -1]
# (rain, caused, floods) [-1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (floods, impact, south sudan) [1, 1, 1]
# (floods, impact, food security) [1, 1, 1]

# %% [markdown]
# ### [Afinn]

# %%
afinn_word = []
afinn_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
        #if str(token) not in marks:
            #print(token)
        score = afn.score(str(token))
        if score > 0:
                #print('positive')
            afinn_tuple.append(1)
        elif score < 0:
                #print('negative')
            afinn_tuple.append(-1)
        else:
                #print('neutral')
            afinn_tuple.append(0)
    afinn_word.append(afinn_tuple)
    afinn_tuple = []

for a,b in zip(causalTriples,afinn_word):
   # print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [0, 0, 0]
# (the low level, shows, no irrigation infrastructure) [0, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, flooding) [0, 0, 0]
# (persistent heavy rains, cause, the ethiopian highlands) [0, 0, 0]
# (persistent heavy rains, cause, flood prone areas) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flooding) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, 0]
# (floods, impact, south sudan) [0, 0, 0]
# (floods, impact, food security) [0, 0, 0]

# %% [markdown]
# ### [Vader]

# %%
vader_word = []
vader_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) not in marks:
        vs = analyzer.polarity_scores(str(token))
        compound = vs['compound']
        if compound >= 0.05:
            vader_tuple.append(1)   
        elif compound <= -0.05 :
            vader_tuple.append(-1)
        elif  compound > -0.05 and compound < 0.05:
            vader_tuple.append(0)
    vader_word.append(vader_tuple)
    vader_tuple = []

for a,b in zip(causalTriples,vader_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [-1, 0, 0]
# (the low level, shows, no irrigation infrastructure) [-1, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, flooding) [0, 0, 0]
# (persistent heavy rains, cause, the ethiopian highlands) [0, 0, 0]
# (persistent heavy rains, cause, flood prone areas) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flooding) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, -1]
# (floods, impact, south sudan) [0, 0, 0]
# (floods, impact, food security) [0, 0, 1]

# %% [markdown]
# ### [SentiStrength]

# %%
senti_word = []
senti_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks:
        #print(token)
        result = senti.getSentiment(str(token), score='binary')
            #print(result)
        if result[0]==1:
                #print('Positive')
            senti_tuple.append(1)
        elif result[0]==-1:
                #print('Negative')
            senti_tuple.append(-1)
        else:
                #print('Neutral')
            senti_tuple.append(0)
    senti_word.append(senti_tuple)
    senti_tuple = []
    
for a,b in zip(causalTriples,senti_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, 1, 1]
# (no irrigation infrastructure, shows, public investment) [1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, 1]
# (south sudan's limited road network, shows, only 2 percent) [1, 1, 1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, 1]
# (persistent heavy rains, cause, flooding) [1, 1, 1]
# (persistent heavy rains, cause, the ethiopian highlands) [1, 1, 1]
# (persistent heavy rains, cause, flood prone areas) [1, 1, 1]
# (persistent heavy rains, cause, flood-prone areas) [1, 1, 1]
# (highly saturated soils, cause, flooding) [1, 1, 1]
# (rain, caused, floods) [1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (floods, impact, south sudan) [1, 1, 1]
# (floods, impact, food security) [1, 1, 1]

# %% [markdown]
# ### Data Frame (Causal Triples Token Level)

# %%
from pd_replicator import replicator

sum_list = []
sum_tup = []
limit= len(causalTriples)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

triplesWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    triplesWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([causalTriples[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],triplesWeight_TokenLevel[i],triplePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0           1              2
# Tokens           (institutional, weakness)  (hindered)  (development)
# AllenNlp                                -1          -1              1
# Afinn                                   -1           0              0
# Vader                                   -1           0              0
# SentiStrength                           -1           1              1
# Token Weight                            -4           0              2
# Token Polarity             Strong Negative     Neutral  Mild Positive
# Triple Weight                        -0.67        None           None
# Triple Polarity              Weak Negative        None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0           1  \
# Tokens           (institutional, weakness)  (hindered)
# AllenNlp                                -1          -1
# Afinn                                   -1           0
# Vader                                   -1           0
# SentiStrength                           -1           1
# Token Weight                            -4           0
# Token Polarity             Strong Negative     Neutral
# Triple Weight                        -0.67        None
# Triple Polarity              Weak Negative        None
#
#                                           2
# Tokens           (the, agriculture, sector)
# AllenNlp                                  1
# Afinn                                     0
# Vader                                     0
# SentiStrength                             1
# Token Weight                              2
# Token Polarity                Mild Positive
# Triple Weight                          None
# Triple Polarity                        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                 0              1  \
# Tokens           (no, irrigation, infrastructure)          shows
# AllenNlp                                       -1              1
# Afinn                                          -1              0
# Vader                                          -1              0
# SentiStrength                                   1              1
# Token Weight                                   -2              2
# Token Polarity                      Mild Negative  Mild Positive
# Triple Weight                                0.67           None
# Triple Polarity                     Weak Positive           None
#
#                                     2
# Tokens           (public, investment)
# AllenNlp                            1
# Afinn                               0
# Vader                               0
# SentiStrength                       1
# Token Weight                        2
# Token Polarity          Mild Positive
# Triple Weight                    None
# Triple Polarity                  None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1                     2
# Tokens           (the, low, level)          shows  (public, investment)
# AllenNlp                        -1              1                     1
# Afinn                            0              0                     0
# Vader                           -1              0                     0
# SentiStrength                   -1              1                     1
# Token Weight                    -3              2                     2
# Token Polarity   Moderate Negative  Mild Positive         Mild Positive
# Triple Weight                 0.33           None                  None
# Triple Polarity      Weak Positive           None                  None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1  \
# Tokens           (the, low, level)          shows
# AllenNlp                        -1              1
# Afinn                            0              0
# Vader                           -1              0
# SentiStrength                   -1              1
# Token Weight                    -3              2
# Token Polarity   Moderate Negative  Mild Positive
# Triple Weight                   -1           None
# Triple Polarity      Weak Negative           None
#
#                                                 2
# Tokens           (no, irrigation, infrastructure)
# AllenNlp                                       -1
# Afinn                                          -1
# Vader                                          -1
# SentiStrength                                   1
# Token Weight                                   -2
# Token Polarity                      Mild Negative
# Triple Weight                                None
# Triple Polarity                              None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                           0              1  \
# Tokens           (south, sudan, 's, limited, road, network)          shows
# AllenNlp                                                 -1              1
# Afinn                                                    -1              0
# Vader                                                    -1              0
# SentiStrength                                             1              1
# Token Weight                                             -2              2
# Token Polarity                                Mild Negative  Mild Positive
# Triple Weight                                             0           None
# Triple Polarity                                     Neutral           None
#
#                                   2
# Tokens           (only, 2, percent)
# AllenNlp                         -1
# Afinn                             0
# Vader                             0
# SentiStrength                     1
# Token Weight                      0
# Token Polarity              Neutral
# Triple Weight                  None
# Triple Polarity                None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                             0              1  \
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                               0           None
# Triple Polarity                                       Neutral           None
#
#                              2
# Tokens               (markets)
# AllenNlp                     1
# Afinn                        0
# Vader                        0
# SentiStrength                1
# Token Weight                 2
# Token Polarity   Mild Positive
# Triple Weight             None
# Triple Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                             0              1  \
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                           -0.67           None
# Triple Polarity                                 Weak Negative           None
#
#                                  2
# Tokens           (less, transport)
# AllenNlp                        -1
# Afinn                            0
# Vader                            0
# SentiStrength                    1
# Token Weight                     0
# Token Polarity             Neutral
# Triple Weight                 None
# Triple Polarity               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1           2
# Tokens           (persistent, heavy, rains)        (cause)  (flooding)
# AllenNlp                                 -1              1          -1
# Afinn                                     0              0           0
# Vader                                     0              0           0
# SentiStrength                             1              1           1
# Token Weight                              0              2           0
# Token Polarity                      Neutral  Mild Positive     Neutral
# Triple Weight                          0.67           None        None
# Triple Polarity               Weak Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          1.33           None
# Triple Polarity               Mild Positive           None
#
#                                            2
# Tokens           (the, ethiopian, highlands)
# AllenNlp                                   1
# Afinn                                      0
# Vader                                      0
# SentiStrength                              1
# Token Weight                               2
# Token Polarity                 Mild Positive
# Triple Weight                           None
# Triple Polarity                         None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          0.67           None
# Triple Polarity               Weak Positive           None
#
#                                      2
# Tokens           (flood, prone, areas)
# AllenNlp                            -1
# Afinn                                0
# Vader                                0
# SentiStrength                        1
# Token Weight                         0
# Token Polarity                 Neutral
# Triple Weight                     None
# Triple Polarity                   None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)          cause
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          0.67           None
# Triple Polarity               Weak Positive           None
#
#                                         2
# Tokens           (flood, -, prone, areas)
# AllenNlp                               -1
# Afinn                                   0
# Vader                                   0
# SentiStrength                           1
# Token Weight                            0
# Token Polarity                    Neutral
# Triple Weight                        None
# Triple Polarity                      None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1           2
# Tokens           (highly, saturated, soils)        (cause)  (flooding)
# AllenNlp                                  1              1          -1
# Afinn                                     0              0           0
# Vader                                     0              0           0
# SentiStrength                             1              1           1
# Token Weight                              2              2           0
# Token Polarity                Mild Positive  Mild Positive     Neutral
# Triple Weight                          1.33           None        None
# Triple Polarity               Mild Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens                  (rain)       (caused)       (floods)
# AllenNlp                    -1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 0              2              2
# Token Polarity         Neutral  Mild Positive  Mild Positive
# Triple Weight             1.33           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1  \
# Tokens                (floods)  (have, displaced)
# AllenNlp                     1                 -1
# Afinn                        0                  0
# Vader                        0                  0
# SentiStrength                1                 -1
# Token Weight                 2                 -2
# Token Polarity   Mild Positive      Mild Negative
# Triple Weight             0.67               None
# Triple Polarity  Weak Positive               None
#
#                                              2
# Tokens           (more, than, 100,000, people)
# AllenNlp                                     1
# Afinn                                        0
# Vader                                        0
# SentiStrength                                1
# Token Weight                                 2
# Token Polarity                   Mild Positive
# Triple Weight                             None
# Triple Polarity                           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1               2
# Tokens                (floods)  (have, displaced)  (south, sudan)
# AllenNlp                     1                 -1               1
# Afinn                        0                  0               0
# Vader                        0                  0               0
# SentiStrength                1                 -1               1
# Token Weight                 2                 -2               2
# Token Polarity   Mild Positive      Mild Negative   Mild Positive
# Triple Weight             0.67               None            None
# Triple Polarity  Weak Positive               None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                  2
# Tokens                (floods)        (raise)            (fears)
# AllenNlp                     1              1                 -1
# Afinn                        0              0                  0
# Vader                        0              0                 -1
# SentiStrength                1              1                 -1
# Token Weight                 2              2                 -3
# Token Polarity   Mild Positive  Mild Positive  Moderate Negative
# Triple Weight             0.33           None               None
# Triple Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens                (floods)         impact  (south, sudan)
# AllenNlp                     1              1               1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength                1              1               1
# Token Weight                 2              2               2
# Token Polarity   Mild Positive  Mild Positive   Mild Positive
# Triple Weight                2           None            None
# Triple Polarity  Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1                  2
# Tokens                    (floods)         impact   (food, security)
# AllenNlp                         1              1                  1
# Afinn                            0              0                  0
# Vader                            0              0                  1
# SentiStrength                    1              1                  1
# Token Weight                     2              2                  3
# Token Polarity       Mild Positive  Mild Positive  Moderate Positive
# Triple Weight                 2.33           None               None
# Triple Polarity  Moderate Positive           None               None

# %% [markdown]
# # Causal Sentences' Polarity (Token Level)

# %% [markdown]
# ### Generating list of tokens without stop words and punctuation marks.

# %%
def GenerateTokens(causalSentences):
    marks = ['.',',','(',')','-',':',';','/',"'s",'_','__','--','"', '’', '—']
    token_list = []
   
    for sent in causalSentences:
        token_tuple = []
        for token in sent:
            if str(token) not in marks:
                if str(token) not in stopwords.words():
                    token_tuple.append(str(token))
        token_list.append(token_tuple)
    return token_list
        
#print(len(token_list))
#print(token_list)

# %% [markdown]
# ### [AllenNlp]

# %%
def Allen_sents_TokenLevel(token_list):
    allen_word = []
    allen_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks: 
                #print(token)
            preds = predictor.predict(str(token))
                #print(preds['label'][0])
            label = preds['label'][0]
            if label is '0':
                allen_tuple.append(-1)
                    #allen_word.append(-1)
            else:
                    #allen_word.append(1)
                allen_tuple.append(1)
        allen_word.append(allen_tuple)
        allen_tuple = []
    return allen_word

#for a in allen_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Afinn]

# %%
def Afinn_sents_TokenLevel(token_list):
    afinn_word = []
    afinn_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
            #if str(token) not in marks:
                #print(token)
            score = afn.score(str(token))
            if score > 0:
                    #print('positive')
                afinn_tuple.append(1)
            elif score < 0:
                    #print('negative')
                afinn_tuple.append(-1)
            else:
                    #print('neutral')
                afinn_tuple.append(0)
        afinn_word.append(afinn_tuple)
        afinn_tuple = []
    return afinn_word

#for a in afinn_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Vader]

# %%
def Vader_sents_TokenLevel(token_list):
    vader_word = []
    vader_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
            vs = analyzer.polarity_scores(str(token))
            compound = vs['compound']
            if compound >= 0.05:
                vader_tuple.append(1)   
            elif compound <= -0.05 :
                vader_tuple.append(-1)
            elif  compound > -0.05 and compound < 0.05:
                vader_tuple.append(0)
        vader_word.append(vader_tuple)
        vader_tuple = []
    return vader_word

#for a in vader_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [SentiStrength]

# %%
def Senti_sents_TokenLevel(token_list):
    senti_word = []
    senti_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
                #print(token)
            result = senti.getSentiment(str(token), score='binary')
                #print(result)
            if result[0]==1:
                    #print('Positive')
                senti_tuple.append(1)
            elif result[0]==-1:
                    #print('Negative')
                senti_tuple.append(-1)
            else:
                    #print('Neutral')
                senti_tuple.append(0)
        senti_word.append(senti_tuple)
        senti_tuple = []
    return senti_word
    
#for a in senti_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### Data Frame (Causal Sentences Word Level)

# %%
token_list = GenerateTokens(causalSents)
allen_word = Allen_sents_TokenLevel(token_list)
afinn_word = Afinn_sents_TokenLevel(token_list)
vader_word = Vader_sents_TokenLevel(token_list)   
senti_word = Senti_sents_TokenLevel(token_list)

sum_list = []
sum_tup = []
limit= len(causalSents)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

sentsWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    sentsWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([token_list[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],sentsWeight_TokenLevel[i],SentencePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                1         2              3  \
# Tokens             institutional         weakness  hindered    development
# AllenNlp                       1               -1        -1              1
# Afinn                          0               -1         0              0
# Vader                          0               -1         0              0
# SentiStrength                  1               -1         1              1
# Token Weight                   2               -4         0              2
# Token Polarity     Mild Positive  Strong Negative   Neutral  Mild Positive
# Sentence Weight             0.67             None      None           None
# Sentence Polarity  Weak Positive             None      None           None
#
#                                4              5
# Tokens               agriculture         sector
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight             None           None
# Sentence Polarity           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 1.12           None           None
# Sentence Polarity      Mild Positive           None           None
#
#                                3              4           5               6  \
# Tokens                investment          shows  irrigation  infrastructure
# AllenNlp                       1              1          -1               1
# Afinn                          0              0           0               0
# Vader                          0              0           0               0
# SentiStrength                  1              1           1               1
# Token Weight                   2              2           0               2
# Token Polarity     Mild Positive  Mild Positive     Neutral   Mild Positive
# Sentence Weight             None           None        None            None
# Sentence Polarity           None           None        None            None
#
#                                7
# Tokens                    exists
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 0.85           None           None
# Sentence Polarity      Weak Positive           None           None
#
#                                3              4              5              6  \
# Tokens                investment          shows              2        percent
# AllenNlp                       1              1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1              1              1              1
# Token Weight                   2              2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive  Mild Positive
# Sentence Weight             None           None           None           None
# Sentence Polarity           None           None           None           None
#
#                          7        8              9       10             11  \
# Tokens               south    sudan        limited     road        network
# AllenNlp                -1       -1             -1       -1              1
# Afinn                    0        0             -1        0              0
# Vader                    0        0             -1        0              0
# SentiStrength            1        1              1        1              1
# Token Weight             0        0             -2        0              2
# Token Polarity     Neutral  Neutral  Mild Negative  Neutral  Mild Positive
# Sentence Weight       None     None           None     None           None
# Sentence Polarity     None     None           None     None           None
#
#                               12
# Tokens                     paved
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0               1               2  \
# Tokens                  inadequate  transportation  infrastructure
# AllenNlp                        -1               1               1
# Afinn                           -1               0               0
# Vader                           -1               0               0
# SentiStrength                   -1               1               1
# Token Weight                    -4               2               2
# Token Polarity     Strong Negative   Mild Positive   Mild Positive
# Sentence Weight               0.86            None            None
# Sentence Polarity    Weak Positive            None            None
#
#                                3        4              5              6
# Tokens                  resulted     less      transport        markets
# AllenNlp                       1       -1              1              1
# Afinn                          0        0              0              0
# Vader                          0        0              0              0
# SentiStrength                  1        1              1              1
# Token Weight                   2        0              2              2
# Token Polarity     Mild Positive  Neutral  Mild Positive  Mild Positive
# Sentence Weight             None     None           None           None
# Sentence Polarity           None     None           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2              3  \
# Tokens                persistent    heavy    rains      ethiopian
# AllenNlp                       1       -1       -1              1
# Afinn                          0        0        0              0
# Vader                          0        0        0              0
# SentiStrength                  1        1        1              1
# Token Weight                   2        0        0              2
# Token Polarity     Mild Positive  Neutral  Neutral  Mild Positive
# Sentence Weight                1     None     None           None
# Sentence Polarity  Weak Positive     None     None           None
#
#                                4              5         6        7        8  \
# Tokens                 highlands          cause  flooding    flood    prone
# AllenNlp                       1              1        -1       -1       -1
# Afinn                          0              0         0        0        0
# Vader                          0              0         0        0        0
# SentiStrength                  1              1         1        1        1
# Token Weight                   2              2         0        0        0
# Token Polarity     Mild Positive  Mild Positive   Neutral  Neutral  Neutral
# Sentence Weight             None           None      None     None     None
# Sentence Polarity           None           None      None     None     None
#
#                                9
# Tokens                     areas
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2        3        4  \
# Tokens                persistent    heavy    rains    south    sudan
# AllenNlp                       1       -1       -1       -1       -1
# Afinn                          0        0        0        0        0
# Vader                          0        0        0        0        0
# SentiStrength                  1        1        1        1        1
# Token Weight                   2        0        0        0        0
# Token Polarity     Mild Positive  Neutral  Neutral  Neutral  Neutral
# Sentence Weight              0.6     None     None     None     None
# Sentence Polarity  Weak Positive     None     None     None     None
#
#                                5         6        7        8              9
# Tokens                     cause  flooding    flood    prone          areas
# AllenNlp                       1        -1       -1       -1              1
# Afinn                          0         0        0        0              0
# Vader                          0         0        0        0              0
# SentiStrength                  1         1        1        1              1
# Token Weight                   2         0        0        0              2
# Token Polarity     Mild Positive   Neutral  Neutral  Neutral  Mild Positive
# Sentence Weight             None      None     None     None           None
# Sentence Polarity           None      None     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0          1        2              3         4  \
# Tokens                    highly  saturated    soils          cause  flooding
# AllenNlp                       1         -1       -1              1        -1
# Afinn                          0          0        0              0         0
# Vader                          0          0        0              0         0
# SentiStrength                  1          1        1              1         1
# Token Weight                   2          0        0              2         0
# Token Polarity     Mild Positive    Neutral  Neutral  Mild Positive   Neutral
# Sentence Weight             0.75       None     None           None      None
# Sentence Polarity  Weak Positive       None     None           None      None
#
#                          5        6              7
# Tokens               flood    prone          areas
# AllenNlp                -1       -1              1
# Afinn                    0        0              0
# Vader                    0        0              0
# SentiStrength            1        1              1
# Token Weight             0        0              2
# Token Polarity     Neutral  Neutral  Mild Positive
# Sentence Weight       None     None           None
# Sentence Polarity     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      rain         caused         floods
# AllenNlp                      -1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   0              2              2
# Token Polarity           Neutral  Mild Positive  Mild Positive
# Sentence Weight             1.33           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2              3  \
# Tokens                    floods      displaced        100,000         people
# AllenNlp                       1             -1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1             -1              1              1
# Token Weight                   2             -2              2              2
# Token Polarity     Mild Positive  Mild Negative  Mild Positive  Mild Positive
# Sentence Weight             0.67           None           None           None
# Sentence Polarity  Weak Positive           None           None           None
#
#                          4        5
# Tokens               south    sudan
# AllenNlp                -1       -1
# Afinn                    0        0
# Vader                    0        0
# SentiStrength            1        1
# Token Weight             0        0
# Token Polarity     Neutral  Neutral
# Sentence Weight       None     None
# Sentence Polarity     None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                  2
# Tokens                    floods          raise              fears
# AllenNlp                       1              1                 -1
# Afinn                          0              0                  0
# Vader                          0              0                 -1
# SentiStrength                  1              1                 -1
# Token Weight                   2              2                 -3
# Token Polarity     Mild Positive  Mild Positive  Moderate Negative
# Sentence Weight             0.33           None               None
# Sentence Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                  1              2  \
# Tokens                    floods      devastatingly         impact
# AllenNlp                       1                 -1              1
# Afinn                          0                  0              0
# Vader                          0                 -1              0
# SentiStrength                  1                 -1              1
# Token Weight                   2                 -3              2
# Token Polarity     Mild Positive  Moderate Negative  Mild Positive
# Sentence Weight             0.86               None           None
# Sentence Polarity  Weak Positive               None           None
#
#                                3                  4        5        6
# Tokens                      food           security    south    sudan
# AllenNlp                       1                  1       -1       -1
# Afinn                          0                  0        0        0
# Vader                          0                  1        0        0
# SentiStrength                  1                  1        1        1
# Token Weight                   2                  3        0        0
# Token Polarity     Mild Positive  Moderate Positive  Neutral  Neutral
# Sentence Weight             None               None     None     None
# Sentence Polarity           None               None     None     None

# %% [markdown]
# # Overall Polarity of Sents and Triples by all Four Methods

# %% [markdown]
# ### Follow the following instructions (steps) before executing the cell given below
# #### Step1- Execute cell for setting causalSents to causalTriples (with duplicates).
# #### Step2- Execute cell for computing sentences' polarity at sentence level.
# #### Step3- Execute cell for computing sentences' polarity at token level.
# #### Step4- Execute the below cell.

# %% [raw]
# totalWeight_AllMethods = []
#
# limit= len(causalSents)
#
# for i in range(0,limit):
#     #dataframe_WordLevel(i)
#     #print(len(allen_word[i]))
#     sum_tup = []
#     for j in range(0,len(sentsWeight_sentLevel[i])):
#         res = sentsWeight_sentLevel[i][j]+triplesWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]+triplesWeight_TokenLevel[i][j]
#         #print(res)
#         res = round(res/4,2)
#         sum_tup.append(res)
#     totalWeight_AllMethods.append(sum_tup)
#
# totalPlarity_AllMethods = DetectPolarity(totalWeight_AllMethods)
#
# df_AllMethods = pd.DataFrame(list(zip(causalSents, causalTriples, sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel, totalWeight_AllMethods,totalPlarity_AllMethods)),
#                              columns =['Causal Sentence', 'Causal Triple', 'Method1 (Sent_SentLevel)', 'Method2 (Trip_SentLevel)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)','Total Weight','Overall Polarity'])
#
# df_AllMethods.style

# %% [markdown]
# # Overall Polarity of Triples at two (sentence and token) levels

# %%
totalTriplesWeight_AllLevels = []

limit= len(causalTriples)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(triplesWeight_sentLevel[i])):
        res = triplesWeight_sentLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalTriplesWeight_AllLevels.append(sum_tup)
    
totalTripsPlarity_AllLevels = DetectPolarity(totalTriplesWeight_AllLevels)

df_TripAllLevels = pd.DataFrame(list(zip(causalTriples, triplesWeight_sentLevel, triplesWeight_TokenLevel, totalTriplesWeight_AllLevels, totalTripsPlarity_AllLevels)), 
                             columns =['Causal Triple', 'Weight (Trip_SentLevel)','Weight (Trip_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_TripAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d559be8c_3cf2_11ec_a91c_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Triple</th>        <th class="col_heading level0 col1" >Weight (Trip_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Trip_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col0" class="data row0 col0" >(institutional weakness, hindered, development)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col2" class="data row0 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col3" class="data row0 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col4" class="data row0 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col0" class="data row1 col0" >(institutional weakness, hindered, the agriculture sector)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col2" class="data row1 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col3" class="data row1 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col4" class="data row1 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col0" class="data row2 col0" >(no irrigation infrastructure, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col1" class="data row2 col1" >[-1]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col2" class="data row2 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col3" class="data row2 col3" >[-0.16]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col4" class="data row2 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col0" class="data row3 col0" >(the low level, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col1" class="data row3 col1" >[-3]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col2" class="data row3 col2" >[0.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col3" class="data row3 col3" >[-1.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col0" class="data row4 col0" >(the low level, shows, no irrigation infrastructure)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col1" class="data row4 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col2" class="data row4 col2" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col3" class="data row4 col3" >[-2.5]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col4" class="data row4 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col0" class="data row5 col0" >(south sudan's limited road network, shows, only 2 percent)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col1" class="data row5 col1" >[-2]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col2" class="data row5 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col3" class="data row5 col3" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col4" class="data row5 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col0" class="data row6 col0" >(inadequate transportation infrastructure, resulted, markets)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col1" class="data row6 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col2" class="data row6 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col3" class="data row6 col3" >[-2.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col4" class="data row6 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col0" class="data row7 col0" >(inadequate transportation infrastructure, resulted, less transport)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col1" class="data row7 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col2" class="data row7 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col3" class="data row7 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col4" class="data row7 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col0" class="data row8 col0" >(persistent heavy rains, cause, flooding)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col1" class="data row8 col1" >[0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col3" class="data row8 col3" >[0.34]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col4" class="data row8 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row9_col0" class="data row9 col0" >(persistent heavy r

# %% [markdown]
# # Overall Polarity of Sentences at two (sentence and token) Levels

# %%
totalSentsWeight_AllLevels = []

limit= len(causalSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalSentsWeight_AllLevels.append(sum_tup)
    
totalSentsPolarity_AllLevels = DetectPolarity(totalSentsWeight_AllLevels)

df_SentsAllLevels = pd.DataFrame(list(zip(causalSents, sentsWeight_sentLevel, sentsWeight_TokenLevel, totalSentsWeight_AllLevels, totalSentsPolarity_AllLevels)), 
                             columns =['Causal Sentence', 'Weight (Sent_SentLevel)','Weight (Sent_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_SentsAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d560e568_3cf2_11ec_870b_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >Weight (Sent_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Sent_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col2" class="data row0 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col3" class="data row0 col3" >[-1.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col4" class="data row0 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col2" class="data row1 col2" >[1.12]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col3" class="data row1 col3" >[-1.44]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col4" class="data row1 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col1" class="data row2 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col2" class="data row2 col2" >[0.85]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col3" class="data row2 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col4" class="data row2 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col1" class="data row3 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col2" class="data row3 col2" >[0.86]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col3" class="data row3 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col1" class="data row4 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col2" class="data row4 col2" >[1.0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col3" class="data row4 col3" >[0.5]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col4" class="data row4 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col1" class="data row5 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col2" class="data row5 col2" >[0.6]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col3" class="data row5 col3" >[0.3]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col4" class="data row5 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col1" class="data row6 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col2" class="data row6 col2" >[0.75]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col3" class="data row6 col3" >[0.38]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col4" class="data row6 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col0" class="data row7 col0" >rain caused floods.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col1" class="data row7 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col2" class="data row7 col2" >[1.33]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col3" class="data row7 col3" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col4" class="data row7 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col0" class="data row8 col0" >floods have displaced more than 100,000 people in south sudan.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col1" class="data row8 col1" >[-2]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col3" class="data row8 col3" >[-0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col4" class="data row8 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row9" class="row_heading level0

# %% [markdown]
# # Plot the Polarized/Modified Causal Graph.

# %% [raw]
# cg = nx.DiGraph()
#
# for ce in polarizedCauseffect:
#     s = str(ce[0])
#     d = str(ce[2])
#     cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
#     cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
#     cg.add_edge(s, d, predicade=str(ce[1]))
#
# print(len(cg.nodes))
# print(len(cg.edges))
#
# pos = nx.spring_layout(cg, k=4, iterations=20)
# plt.figure(figsize=(15,12))
#
# nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
# edge_labels = nx.get_edge_attributes(cg,'predicade')
# nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)
#
# plt.axis('off')
# plt.show()
