# %% [markdown]
# # Import necessary libraries.

# %%
import spacy
import textacy
import textacy.preprocessing
import textacy.resources
#import textacy.keyterms
import textacy.ke
import neuralcoref
from spacy.symbols import ORTH, POS, NOUN, VERB,PRON
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt 
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from networkx.readwrite import json_graph;
import json
from afinn import Afinn
afn = Afinn()
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
lemmatizer = WordNetLemmatizer()
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from allennlp_models.pretrained import load_predictor
predictor = load_predictor("roberta-sst")
from sentistrength import PySentiStr
senti = PySentiStr()
senti.setSentiStrengthPath('D:/github/causal-graph-acquisition/SentiStrengthCom.jar')
senti.setSentiStrengthLanguageFolderPath('D:/github/causal-graph-acquisition/SentStrength_Data_Sept2011/')
import pandas as pd
from IPython.display import display
import collections

from nltk.corpus import stopwords
set(stopwords.words('english'))


from pd_replicator import replicator

nlp = spacy.load("en_core_web_sm")
neuralcoref.add_to_pipe(nlp)
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp\tango\__init__.py:18: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   "AllenNLP Tango is an experimental API and parts of it might change or disappear "
# 2023-08-08 05:53:29,634 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-08-08 05:53:29,659 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\coref-spanbert.json as plain json
# 2023-08-08 05:53:29,672 - INFO - allennlp.common.params - id = coref-spanbert
# 2023-08-08 05:53:29,677 - INFO - allennlp.common.params - type = coref-spanbert
# 2023-08-08 05:53:29,679 - INFO - allennlp.common.params - registered_model_name = coref
# 2023-08-08 05:53:29,681 - INFO - allennlp.common.params - type = coref
# 2023-08-08 05:53:29,683 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:53:29,685 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:53:29,689 - INFO - allennlp.common.params - display_name = Coreference Resolution
# 2023-08-08 05:53:29,692 - INFO - allennlp.common.params - type = Coreference Resolution
# 2023-08-08 05:53:29,695 - INFO - allennlp.common.params - task_id = coref
# 2023-08-08 05:53:29,698 - INFO - allennlp.common.params - type = coref
# 2023-08-08 05:53:29,702 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:29,707 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:29,711 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:29,716 - INFO - allennlp.common.params - model_usage.archive_file = coref-spanbert-large-2021.03.10.tar.gz
# 2023-08-08 05:53:29,720 - INFO - allennlp.common.params - type = coref-spanbert-large-2021.03.10.tar.gz
# 2023-08-08 05:53:29,737 - INFO - allennlp.common.params - model_usage.training_config = coref/coref_spanbert_large.jsonnet
# 2023-08-08 05:53:29,742 - INFO - allennlp.common.params - type = coref/coref_spanbert_large.jsonnet
# 2023-08-08 05:53:29,751 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:53:29,755 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:53:29,765 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:53:29,770 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:29,775 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:29,779 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:29,782 - INFO - allennlp.common.params - model_details.description = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-08-08 05:53:29,785 - INFO - allennlp.common.params - type = The basic outline of this model is to get an embedded representation of each span in the document. These span representations are scored  and used to prune away spans that are unlikely to occur in a coreference  cluster. For the remaining spans, the model decides which antecedent span (if any) they are coreferent with. The resulting coreference links, after applying transitivity, imply a clustering of the spans in the document. The GloVe embeddings in the original paper have been substituted with SpanBERT embeddings.
# 2023-08-08 05:53:29,797 - INFO - allennlp.common.params - model_details.short_description = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-08-08 05:53:29,800 - INFO - allennlp.common.params - type = Higher-order coref with coarse-to-fine inference (with SpanBERT embeddings).
# 2023-08-08 05:53:29,808 - INFO - allennlp.common.params - model_details.developed_by = Lee et al
# 2023-08-08 05:53:29,811 - INFO - allennlp.common.params - type = Lee et al
# 2023-08-08 05:53:29,813 - INFO - allennlp.common.params - model_details.contributed_by = Zhaofeng Wu
# 2023-08-08 05:53:29,816 - INFO - allennlp.common.params - type = Zhaofeng Wu
# 2023-08-08 05:53:29,817 - INFO - allennlp.common.params - model_details.date = 2020-02-27
# 2023-08-08 05:53:29,820 - INFO - allennlp.common.params - type = 2020-02-27
# 2023-08-08 05:53:29,824 - INFO - allennlp.common.params - model_details.version = 2
# 2023-08-08 05:53:29,827 - INFO - allennlp.common.params - type = 2
# 2023-08-08 05:53:29,829 - INFO - allennlp.common.params - model_details.model_type = SpanBERT
# 2023-08-08 05:53:29,832 - INFO - allennlp.common.params - type = SpanBERT
# 2023-08-08 05:53:29,833 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:29,838 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:29,843 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:29,846 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lee2018HigherorderCR,
# title={Higher-order Coreference Resolution with Coarse-to-fine Inference},
# author={Kenton Lee and Luheng He and L. Zettlemoyer},
# booktitle={NAACL-HLT},
# year={2018}}
#
# 2023-08-08 05:53:29,849 - INFO - allennlp.common.params - model_details.paper.title = Higher-order Coreference Resolution with Coarse-to-fine Inference
# 2023-08-08 05:53:29,852 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:4891749
# 2023-08-08 05:53:29,855 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:53:29,859 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:53:29,862 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:53:29,874 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:29,878 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:29,882 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:29,889 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:53:29,891 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:53:29,894 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:53:29,897 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:29,901 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:29,905 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:29,913 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:53:29,916 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:53:29,918 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:29,923 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:29,929 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:29,933 - INFO - allennlp.common.params - metrics.model_performance_measures = CoNLL coref scores and Mention Recall
# 2023-08-08 05:53:29,936 - INFO - allennlp.common.params - type = CoNLL coref scores and Mention Recall
# 2023-08-08 05:53:29,941 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:53:29,943 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:53:29,946 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:29,951 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:29,957 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:29,962 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:29,966 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:29,971 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:29,976 - INFO - allennlp.common.params - evaluation_data.dataset.name = Ontonotes 5.0
# 2023-08-08 05:53:29,979 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-08-08 05:53:29,984 - INFO - allennlp.common.params - evaluation_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-08-08 05:53:29,990 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = /path/to/dataset
# 2023-08-08 05:53:29,994 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:53:29,998 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:53:30,002 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,008 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,014 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,021 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,025 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,029 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,034 - INFO - allennlp.common.params - training_data.dataset.name = Ontonotes 5.0
# 2023-08-08 05:53:30,040 - INFO - allennlp.common.params - training_data.dataset.url = https://catalog.ldc.upenn.edu/LDC2013T19
# 2023-08-08 05:53:30,043 - INFO - allennlp.common.params - training_data.dataset.notes = The Coreference model was evaluated on the CoNLL 2012 dataset. Unfortunately we cannot release this data due to licensing restrictions by the LDC. To compile the data in the right format for evaluating the Coreference model, please see scripts/compile_coref_data.sh. This script requires the Ontonotes 5.0 dataset, available on the LDC website.
# 2023-08-08 05:53:30,047 - INFO - allennlp.common.params - training_data.dataset.processed_url = /path/to/dataset
# 2023-08-08 05:53:30,049 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:53:30,053 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 05:53:30,056 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,060 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,064 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,075 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 05:53:30,077 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:53:30,079 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:30,082 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:30,085 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:30,090 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:53:30,093 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:30,096 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:30,100 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:30,104 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:53:30,109 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\evaluate_rc-lerc.json as plain json
# 2023-08-08 05:53:30,122 - INFO - allennlp.common.params - id = evaluate_rc-lerc
# 2023-08-08 05:53:30,124 - INFO - allennlp.common.params - type = evaluate_rc-lerc
# 2023-08-08 05:53:30,126 - INFO - allennlp.common.params - registered_model_name = lerc
# 2023-08-08 05:53:30,129 - INFO - allennlp.common.params - type = lerc
# 2023-08-08 05:53:30,131 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:53:30,133 - INFO - allennlp.common.params - registered_predictor_name = lerc
# 2023-08-08 05:53:30,135 - INFO - allennlp.common.params - type = lerc
# 2023-08-08 05:53:30,139 - INFO - allennlp.common.params - display_name = Learned Evaluation for Reading Comprehension (LERC)
# 2023-08-08 05:53:30,141 - INFO - allennlp.common.params - type = Learned Evaluation for Reading Comprehension (LERC)
# 2023-08-08 05:53:30,142 - INFO - allennlp.common.params - task_id = evaluate_rc
# 2023-08-08 05:53:30,145 - INFO - allennlp.common.params - type = evaluate_rc
# 2023-08-08 05:53:30,147 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:30,151 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:30,156 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:30,159 - INFO - allennlp.common.params - model_usage.archive_file = lerc-2020-11-18.tar.gz
# 2023-08-08 05:53:30,161 - INFO - allennlp.common.params - type = lerc-2020-11-18.tar.gz
# 2023-08-08 05:53:30,171 - INFO - allennlp.common.params - model_usage.training_config = None
# 2023-08-08 05:53:30,174 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:53:30,178 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:53:30,194 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:53:30,197 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:30,203 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:30,208 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:30,215 - INFO - allennlp.common.params - model_details.description = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-08-08 05:53:30,218 - INFO - allennlp.common.params - type = LERC is a BERT model that is trained to mimic human judgement scores on candidate answers in the MOCHA dataset. LERC outputs scores that range from 1 to 5, however, to stay consistent with metrics such as BLEU and ROUGE, we normalize the output of LERC to be between 0 and 1 in this demo.
# 2023-08-08 05:53:30,234 - INFO - allennlp.common.params - model_details.short_description = A BERT model that scores candidate answers from 0 to 1.
# 2023-08-08 05:53:30,236 - INFO - allennlp.common.params - type = A BERT model that scores candidate answers from 0 to 1.
# 2023-08-08 05:53:30,247 - INFO - allennlp.common.params - model_details.developed_by = Chen et al
# 2023-08-08 05:53:30,249 - INFO - allennlp.common.params - type = Chen et al
# 2023-08-08 05:53:30,250 - INFO - allennlp.common.params - model_details.contributed_by = Anthony Chen
# 2023-08-08 05:53:30,253 - INFO - allennlp.common.params - type = Anthony Chen
# 2023-08-08 05:53:30,255 - INFO - allennlp.common.params - model_details.date = 2021-03-10
# 2023-08-08 05:53:30,257 - INFO - allennlp.common.params - type = 2021-03-10
# 2023-08-08 05:53:30,259 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:53:30,261 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:53:30,263 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-08-08 05:53:30,264 - INFO - allennlp.common.params - type = BERT
# 2023-08-08 05:53:30,268 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:30,272 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:30,276 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:30,279 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Chen2020MOCHAAD,
# title={MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics},
# author={Anthony Chen and Gabriel Stanovsky and S. Singh and Matt Gardner},
# booktitle={EMNLP},
# year={2020}}
#
# 2023-08-08 05:53:30,283 - INFO - allennlp.common.params - model_details.paper.title = MOCHA: A Dataset for Training and Evaluating Generative Reading Comprehension Metrics
# 2023-08-08 05:53:30,285 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:222208714
# 2023-08-08 05:53:30,289 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:53:30,291 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:53:30,294 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:53:30,303 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:30,307 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:30,311 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:30,314 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:53:30,317 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:53:30,320 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:53:30,325 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:30,336 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:30,341 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:30,345 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:53:30,348 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:53:30,352 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:30,358 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:30,361 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:30,365 - INFO - allennlp.common.params - metrics.model_performance_measures = Pearson Correlation
# 2023-08-08 05:53:30,368 - INFO - allennlp.common.params - type = Pearson Correlation
# 2023-08-08 05:53:30,371 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:53:30,374 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:53:30,376 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:30,380 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:30,382 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:30,385 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:30,390 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:30,395 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:30,398 - INFO - allennlp.common.params - evaluation_data.dataset.name = MOCHA
# 2023-08-08 05:53:30,399 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://allennlp.org/mocha
# 2023-08-08 05:53:30,401 - INFO - allennlp.common.params - evaluation_data.dataset.notes = To evaluate this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-08-08 05:53:30,405 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = None
# 2023-08-08 05:53:30,408 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:53:30,410 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:53:30,411 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,414 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,418 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,421 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,424 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,428 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,431 - INFO - allennlp.common.params - training_data.dataset.name = MOCHA
# 2023-08-08 05:53:30,432 - INFO - allennlp.common.params - training_data.dataset.url = https://allennlp.org/mocha
# 2023-08-08 05:53:30,433 - INFO - allennlp.common.params - training_data.dataset.notes = To train this model follow the instructions at https://github.com/anthonywchen/MOCHA.
# 2023-08-08 05:53:30,436 - INFO - allennlp.common.params - training_data.dataset.processed_url = None
# 2023-08-08 05:53:30,439 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:53:30,441 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 05:53:30,443 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,446 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,453 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,455 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 05:53:30,458 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:53:30,460 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:30,463 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:30,467 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:30,468 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:53:30,471 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:30,475 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:30,478 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:30,481 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:53:30,485 - WARNING - allennlp.common.model_card - lerc is not a registered model.
# 2023-08-08 05:53:30,490 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\generation-bart.json as plain json
# 2023-08-08 05:53:30,501 - INFO - allennlp.common.params - id = generation-bart
# 2023-08-08 05:53:30,504 - INFO - allennlp.common.params - type = generation-bart
# 2023-08-08 05:53:30,506 - INFO - allennlp.common.params - registered_model_name = bart
# 2023-08-08 05:53:30,508 - INFO - allennlp.common.params - type = bart
# 2023-08-08 05:53:30,510 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:53:30,512 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:53:30,514 - INFO - allennlp.common.params - display_name = BART
# 2023-08-08 05:53:30,517 - INFO - allennlp.common.params - type = BART
# 2023-08-08 05:53:30,519 - INFO - allennlp.common.params - task_id = None
# 2023-08-08 05:53:30,520 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:30,524 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:30,527 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:30,532 - INFO - allennlp.common.params - model_usage.archive_file = bart-2020.07.25.tar.gz
# 2023-08-08 05:53:30,534 - INFO - allennlp.common.params - type = bart-2020.07.25.tar.gz
# 2023-08-08 05:53:30,544 - INFO - allennlp.common.params - model_usage.training_config = generation/bart_cnn_dm.jsonnet
# 2023-08-08 05:53:30,546 - INFO - allennlp.common.params - type = generation/bart_cnn_dm.jsonnet
# 2023-08-08 05:53:30,557 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:53:30,560 - INFO - allennlp.common.params - type = pip install allennlp==1.0.0 allennlp-models==1.0.0
# 2023-08-08 05:53:30,574 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:53:30,577 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:30,580 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:30,583 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:30,587 - INFO - allennlp.common.params - model_details.description = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-08-08 05:53:30,589 - INFO - allennlp.common.params - type = The BART model here uses a language modeling head, and therefore can be used for generation. The BART encoder, implemented as a `Seq2SeqEncoder`, which assumes it operates on already embedded inputs.  This means that we remove the token and position embeddings from BART in this module.  For the typical use case of using BART to encode inputs to your model (where we include the token and position embeddings from BART), you should use `PretrainedTransformerEmbedder(bart_model_name, sub_module="encoder")` instead of this.
# 2023-08-08 05:53:30,617 - INFO - allennlp.common.params - model_details.short_description = BART with a language model head for generation.
# 2023-08-08 05:53:30,622 - INFO - allennlp.common.params - type = BART with a language model head for generation.
# 2023-08-08 05:53:30,641 - INFO - allennlp.common.params - model_details.developed_by = Lewis et al
# 2023-08-08 05:53:30,650 - INFO - allennlp.common.params - type = Lewis et al
# 2023-08-08 05:53:30,655 - INFO - allennlp.common.params - model_details.contributed_by = Dirk Groeneveld
# 2023-08-08 05:53:30,662 - INFO - allennlp.common.params - type = Dirk Groeneveld
# 2023-08-08 05:53:30,667 - INFO - allennlp.common.params - model_details.date = 2020-07-25
# 2023-08-08 05:53:30,674 - INFO - allennlp.common.params - type = 2020-07-25
# 2023-08-08 05:53:30,677 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:53:30,679 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:53:30,682 - INFO - allennlp.common.params - model_details.model_type = BART
# 2023-08-08 05:53:30,689 - INFO - allennlp.common.params - type = BART
# 2023-08-08 05:53:30,692 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:30,695 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:30,700 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:30,705 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Lewis2020BARTDS,
# title={BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension},
# author={M. Lewis and Yinhan Liu and Naman Goyal and Marjan Ghazvininejad and A. Mohamed and Omer Levy and Ves Stoyanov and L. Zettlemoyer},
# booktitle={ACL},
# year={2020}}
#
# 2023-08-08 05:53:30,713 - INFO - allennlp.common.params - model_details.paper.title = BART: Denosing Sequence-to-Sequence Pre-training for Natural Language Generation,Translation, and Comprehension
# 2023-08-08 05:53:30,715 - INFO - allennlp.common.params - model_details.paper.url = https://api.semanticscholar.org/CorpusID:204960716
# 2023-08-08 05:53:30,722 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:53:30,732 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:53:30,741 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:53:30,796 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:30,804 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:30,814 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:30,825 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:53:30,832 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:53:30,841 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:53:30,849 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:30,852 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:30,860 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:30,876 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:53:30,881 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:53:30,884 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:30,887 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:30,891 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:30,894 - INFO - allennlp.common.params - metrics.model_performance_measures = ROUGE and BLEU
# 2023-08-08 05:53:30,898 - INFO - allennlp.common.params - type = ROUGE and BLEU
# 2023-08-08 05:53:30,901 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:53:30,904 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:53:30,907 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:30,911 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:30,917 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:30,921 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:30,924 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:30,929 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:30,932 - INFO - allennlp.common.params - evaluation_data.dataset.name = CNN/DailyMail
# 2023-08-08 05:53:30,934 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-08-08 05:53:30,937 - INFO - allennlp.common.params - evaluation_data.dataset.notes = Please download the data from the url provided.
# 2023-08-08 05:53:30,940 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:53:30,943 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:53:30,946 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,952 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,957 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:30,961 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,965 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,969 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:30,974 - INFO - allennlp.common.params - training_data.dataset.name = CNN/DailyMail
# 2023-08-08 05:53:30,978 - INFO - allennlp.common.params - training_data.dataset.url = https://github.com/abisee/cnn-dailymail
# 2023-08-08 05:53:30,980 - INFO - allennlp.common.params - training_data.dataset.notes = Please download the data from the url provided.
# 2023-08-08 05:53:30,983 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:53:30,986 - INFO - allennlp.common.params - training_data.preprocessing = None
# 2023-08-08 05:53:30,990 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,995 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:30,998 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:31,000 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = None
# 2023-08-08 05:53:31,002 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:53:31,005 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:31,014 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:31,018 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:31,022 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:53:31,025 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:31,028 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:31,033 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:31,039 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:53:31,046 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\glove-sst.json as plain json
# 2023-08-08 05:53:31,060 - INFO - allennlp.common.params - id = glove-sst
# 2023-08-08 05:53:31,062 - INFO - allennlp.common.params - type = glove-sst
# 2023-08-08 05:53:31,064 - INFO - allennlp.common.params - registered_model_name = None
# 2023-08-08 05:53:31,066 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:53:31,069 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:53:31,071 - INFO - allennlp.common.params - display_name = GLoVe-LSTM
# 2023-08-08 05:53:31,073 - INFO - allennlp.common.params - type = GLoVe-LSTM
# 2023-08-08 05:53:31,075 - INFO - allennlp.common.params - task_id = sentiment-analysis
# 2023-08-08 05:53:31,077 - INFO - allennlp.common.params - type = sentiment-analysis
# 2023-08-08 05:53:31,080 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:31,084 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:31,088 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:31,091 - INFO - allennlp.common.params - model_usage.archive_file = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-08-08 05:53:31,093 - INFO - allennlp.common.params - type = basic_stanford_sentiment_treebank-2020.06.09.tar.gz
# 2023-08-08 05:53:31,107 - INFO - allennlp.common.params - model_usage.training_config = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-08-08 05:53:31,109 - INFO - allennlp.common.params - type = classification/basic_stanford_sentiment_treebank.jsonnet
# 2023-08-08 05:53:31,122 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:53:31,124 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:53:31,134 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:53:31,137 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:31,141 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:31,144 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:31,148 - INFO - allennlp.common.params - model_details.description = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-08-08 05:53:31,152 - INFO - allennlp.common.params - type = This model uses GloVe embeddings and is trained on the binary classification setting of the Stanford Sentiment Treebank. It achieves about 87% on the test set.
# 2023-08-08 05:53:31,161 - INFO - allennlp.common.params - model_details.short_description = LSTM binary classifier with GloVe embeddings.
# 2023-08-08 05:53:31,163 - INFO - allennlp.common.params - type = LSTM binary classifier with GloVe embeddings.
# 2023-08-08 05:53:31,177 - INFO - allennlp.common.params - model_details.developed_by = None
# 2023-08-08 05:53:31,179 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-08-08 05:53:31,181 - INFO - allennlp.common.params - model_details.date = 2020-06-09
# 2023-08-08 05:53:31,184 - INFO - allennlp.common.params - type = 2020-06-09
# 2023-08-08 05:53:31,189 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:53:31,192 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:53:31,196 - INFO - allennlp.common.params - model_details.model_type = LSTM
# 2023-08-08 05:53:31,199 - INFO - allennlp.common.params - type = LSTM
# 2023-08-08 05:53:31,201 - INFO - allennlp.common.params - model_details.paper = None
# 2023-08-08 05:53:31,204 - INFO - allennlp.common.params - model_details.license = None
# 2023-08-08 05:53:31,206 - INFO - allennlp.common.params - model_details.contact = allennlp-contact@allenai.org
# 2023-08-08 05:53:31,210 - INFO - allennlp.common.params - type = allennlp-contact@allenai.org
# 2023-08-08 05:53:31,225 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:31,228 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:31,231 - INFO - allennlp.common.params - intended_use.type = ref
# 2023-08-08 05:53:31,236 - INFO - allennlp.common.params - intended_use.primary_uses = None
# 2023-08-08 05:53:31,238 - INFO - allennlp.common.params - intended_use.primary_users = None
# 2023-08-08 05:53:31,240 - INFO - allennlp.common.params - intended_use.out_of_scope_use_cases = None
# 2023-08-08 05:53:31,243 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:31,248 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:31,251 - INFO - allennlp.common.params - factors.type = ref
# 2023-08-08 05:53:31,254 - INFO - allennlp.common.params - factors.relevant_factors = None
# 2023-08-08 05:53:31,256 - INFO - allennlp.common.params - factors.evaluation_factors = None
# 2023-08-08 05:53:31,259 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:31,262 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:31,266 - INFO - allennlp.common.params - metrics.type = ref
# 2023-08-08 05:53:31,270 - INFO - allennlp.common.params - metrics.model_performance_measures = Accuracy
# 2023-08-08 05:53:31,273 - INFO - allennlp.common.params - type = Accuracy
# 2023-08-08 05:53:31,275 - INFO - allennlp.common.params - metrics.decision_thresholds = None
# 2023-08-08 05:53:31,277 - INFO - allennlp.common.params - metrics.variation_approaches = None
# 2023-08-08 05:53:31,279 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:31,288 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:31,291 - INFO - allennlp.common.params - evaluation_data.type = ref
# 2023-08-08 05:53:31,294 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:31,297 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:31,302 - INFO - allennlp.common.params - evaluation_data.dataset.type = ref
# 2023-08-08 05:53:31,305 - INFO - allennlp.common.params - evaluation_data.dataset.name = Stanford Sentiment Treebank
# 2023-08-08 05:53:31,309 - INFO - allennlp.common.params - evaluation_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-08-08 05:53:31,311 - INFO - allennlp.common.params - evaluation_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/test.txt
# 2023-08-08 05:53:31,314 - INFO - allennlp.common.params - evaluation_data.motivation = None
# 2023-08-08 05:53:31,316 - INFO - allennlp.common.params - evaluation_data.preprocessing = None
# 2023-08-08 05:53:31,319 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:31,323 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:31,326 - INFO - allennlp.common.params - training_data.type = ref
# 2023-08-08 05:53:31,330 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:31,335 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:31,339 - INFO - allennlp.common.params - training_data.dataset.type = ref
# 2023-08-08 05:53:31,349 - INFO - allennlp.common.params - training_data.dataset.name = Stanford Sentiment Treebank
# 2023-08-08 05:53:31,357 - INFO - allennlp.common.params - training_data.dataset.url = https://nlp.stanford.edu/sentiment/treebank.html
# 2023-08-08 05:53:31,363 - INFO - allennlp.common.params - training_data.dataset.processed_url = https://allennlp.s3.amazonaws.com/datasets/sst/train.txt
# 2023-08-08 05:53:31,368 - INFO - allennlp.common.params - training_data.motivation = None
# 2023-08-08 05:53:31,375 - INFO - allennlp.common.params - training_data.preprocessing = Binary classification setting
# 2023-08-08 05:53:31,380 - INFO - allennlp.common.params - type = Binary classification setting
# 2023-08-08 05:53:31,382 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:31,387 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:31,391 - INFO - allennlp.common.params - quantitative_analyses.type = ref
# 2023-08-08 05:53:31,394 - INFO - allennlp.common.params - quantitative_analyses.unitary_results = Accuracy: 87% on SST test set.
# 2023-08-08 05:53:31,400 - INFO - allennlp.common.params - type = Accuracy: 87% on SST test set.
# 2023-08-08 05:53:31,450 - INFO - allennlp.common.params - quantitative_analyses.intersectional_results = None
# 2023-08-08 05:53:31,458 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:31,466 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:31,475 - INFO - allennlp.common.params - model_ethical_considerations.type = ref
# 2023-08-08 05:53:31,483 - INFO - allennlp.common.params - model_ethical_considerations.ethical_considerations = None
# 2023-08-08 05:53:31,487 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:31,490 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:31,494 - INFO - allennlp.common.params - model_caveats_and_recommendations.type = ref
# 2023-08-08 05:53:31,497 - INFO - allennlp.common.params - model_caveats_and_recommendations.caveats_and_recommendations = None
# 2023-08-08 05:53:31,500 - WARNING - allennlp.common.params - error loading _jsonnet (this is expected on Windows), treating C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\allennlp_models\modelcards\lm-masked-language-model.json as plain json
# 2023-08-08 05:53:31,509 - INFO - allennlp.common.params - id = lm-masked-language-model
# 2023-08-08 05:53:31,512 - INFO - allennlp.common.params - type = lm-masked-language-model
# 2023-08-08 05:53:31,514 - INFO - allennlp.common.params - registered_model_name = masked_language_model
# 2023-08-08 05:53:31,516 - INFO - allennlp.common.params - type = masked_language_model
# 2023-08-08 05:53:31,518 - INFO - allennlp.common.params - model_class = None
# 2023-08-08 05:53:31,521 - INFO - allennlp.common.params - registered_predictor_name = None
# 2023-08-08 05:53:31,523 - INFO - allennlp.common.params - display_name = BERT-based Masked Language Model
# 2023-08-08 05:53:31,525 - INFO - allennlp.common.params - type = BERT-based Masked Language Model
# 2023-08-08 05:53:31,527 - INFO - allennlp.common.params - task_id = masked-language-modeling
# 2023-08-08 05:53:31,530 - INFO - allennlp.common.params - type = masked-language-modeling
# 2023-08-08 05:53:31,533 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:31,544 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:31,548 - INFO - allennlp.common.params - model_usage.type = ref
# 2023-08-08 05:53:31,551 - INFO - allennlp.common.params - model_usage.archive_file = bert-masked-lm-2020-10-07.tar.gz
# 2023-08-08 05:53:31,554 - INFO - allennlp.common.params - type = bert-masked-lm-2020-10-07.tar.gz
# 2023-08-08 05:53:31,566 - INFO - allennlp.common.params - model_usage.training_config = lm/bidirectional_language_model.jsonnet
# 2023-08-08 05:53:31,570 - INFO - allennlp.common.params - type = lm/bidirectional_language_model.jsonnet
# 2023-08-08 05:53:31,580 - INFO - allennlp.common.params - model_usage.install_instructions = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:53:31,582 - INFO - allennlp.common.params - type = pip install allennlp==2.1.0 allennlp-models==2.1.0
# 2023-08-08 05:53:31,592 - INFO - allennlp.common.params - model_usage.overrides = None
# 2023-08-08 05:53:31,595 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:31,599 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:31,603 - INFO - allennlp.common.params - model_details.type = ref
# 2023-08-08 05:53:31,607 - INFO - allennlp.common.params - model_details.description = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-08-08 05:53:31,611 - INFO - allennlp.common.params - type = The `MaskedLanguageModel` embeds some input tokens (including some which are masked), contextualizes them, then predicts targets for the masked tokens, computing a loss against known targets.
# 2023-08-08 05:53:31,623 - INFO - allennlp.common.params - model_details.short_description = BERT-based masked language model
# 2023-08-08 05:53:31,627 - INFO - allennlp.common.params - type = BERT-based masked language model
# 2023-08-08 05:53:31,630 - INFO - allennlp.common.params - model_details.developed_by = Devlin et al
# 2023-08-08 05:53:31,632 - INFO - allennlp.common.params - type = Devlin et al
# 2023-08-08 05:53:31,634 - INFO - allennlp.common.params - model_details.contributed_by = None
# 2023-08-08 05:53:31,637 - INFO - allennlp.common.params - model_details.date = 2020-10-07
# 2023-08-08 05:53:31,639 - INFO - allennlp.common.params - type = 2020-10-07
# 2023-08-08 05:53:31,642 - INFO - allennlp.common.params - model_details.version = 1
# 2023-08-08 05:53:31,645 - INFO - allennlp.common.params - type = 1
# 2023-08-08 05:53:31,647 - INFO - allennlp.common.params - model_details.model_type = BERT
# 2023-08-08 05:53:31,651 - INFO - allennlp.common.params - type = BERT
# 2023-08-08 05:53:31,654 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:31,658 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:31,663 - INFO - allennlp.common.params - model_details.paper.type = ref
# 2023-08-08 05:53:31,666 - INFO - allennlp.common.params - model_details.paper.citation =
# @inproceedings{Devlin2019BERTPO,
# title={BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding},
# author={J. Devlin and Ming-Wei Chang and Kenton Lee and Kristina Toutanova},
# booktitle={NAACL-HLT},
# year={2019}}
#
# 2023-08-08 05:53:31,669 - INFO - allennlp.common.params - model_details.paper.title = BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# ...
# 2023-08-08 05:54:17,640 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.output.dense.weight
# 2023-08-08 05:54:17,642 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.key.bias
# 2023-08-08 05:54:17,644 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.key.weight
# 2023-08-08 05:54:17,646 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.query.bias
# 2023-08-08 05:54:17,649 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.query.weight
# 2023-08-08 05:54:17,652 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.value.bias
# 2023-08-08 05:54:17,653 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.attention.self.value.weight
# 2023-08-08 05:54:17,655 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.intermediate.dense.bias
# 2023-08-08 05:54:17,657 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.intermediate.dense.weight
# 2023-08-08 05:54:17,659 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.LayerNorm.bias
# 2023-08-08 05:54:17,661 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.LayerNorm.weight
# 2023-08-08 05:54:17,663 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.dense.bias
# 2023-08-08 05:54:17,665 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.4.output.dense.weight
# 2023-08-08 05:54:17,668 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2023-08-08 05:54:17,669 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2023-08-08 05:54:17,670 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2023-08-08 05:54:17,672 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2023-08-08 05:54:17,673 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.key.bias
# 2023-08-08 05:54:17,675 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.key.weight
# 2023-08-08 05:54:17,676 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.query.bias
# 2023-08-08 05:54:17,678 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.query.weight
# 2023-08-08 05:54:17,680 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.value.bias
# 2023-08-08 05:54:17,681 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.attention.self.value.weight
# 2023-08-08 05:54:17,683 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2023-08-08 05:54:17,685 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2023-08-08 05:54:17,687 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2023-08-08 05:54:17,689 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2023-08-08 05:54:17,690 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.dense.bias
# 2023-08-08 05:54:17,692 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.5.output.dense.weight
# 2023-08-08 05:54:17,693 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2023-08-08 05:54:17,694 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2023-08-08 05:54:17,696 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2023-08-08 05:54:17,698 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2023-08-08 05:54:17,700 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.key.bias
# 2023-08-08 05:54:17,702 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.key.weight
# 2023-08-08 05:54:17,704 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.query.bias
# 2023-08-08 05:54:17,706 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.query.weight
# 2023-08-08 05:54:17,707 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.value.bias
# 2023-08-08 05:54:17,709 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.attention.self.value.weight
# 2023-08-08 05:54:17,710 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2023-08-08 05:54:17,712 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2023-08-08 05:54:17,714 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2023-08-08 05:54:17,716 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2023-08-08 05:54:17,717 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.dense.bias
# 2023-08-08 05:54:17,719 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.6.output.dense.weight
# 2023-08-08 05:54:17,720 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2023-08-08 05:54:17,722 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2023-08-08 05:54:17,724 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2023-08-08 05:54:17,725 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2023-08-08 05:54:17,727 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.key.bias
# 2023-08-08 05:54:17,728 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.key.weight
# 2023-08-08 05:54:17,729 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.query.bias
# 2023-08-08 05:54:17,731 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.query.weight
# 2023-08-08 05:54:17,732 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.value.bias
# 2023-08-08 05:54:17,734 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.attention.self.value.weight
# 2023-08-08 05:54:17,736 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2023-08-08 05:54:17,738 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2023-08-08 05:54:17,740 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2023-08-08 05:54:17,742 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2023-08-08 05:54:17,744 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.dense.bias
# 2023-08-08 05:54:17,745 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.7.output.dense.weight
# 2023-08-08 05:54:17,747 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2023-08-08 05:54:17,749 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2023-08-08 05:54:17,751 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2023-08-08 05:54:17,753 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2023-08-08 05:54:17,755 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.key.bias
# 2023-08-08 05:54:17,757 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.key.weight
# 2023-08-08 05:54:17,759 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.query.bias
# 2023-08-08 05:54:17,760 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.query.weight
# 2023-08-08 05:54:17,762 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.value.bias
# 2023-08-08 05:54:17,763 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.attention.self.value.weight
# 2023-08-08 05:54:17,766 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2023-08-08 05:54:17,767 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2023-08-08 05:54:17,768 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2023-08-08 05:54:17,770 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2023-08-08 05:54:17,772 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.dense.bias
# 2023-08-08 05:54:17,773 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.8.output.dense.weight
# 2023-08-08 05:54:17,776 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2023-08-08 05:54:17,778 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2023-08-08 05:54:17,779 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2023-08-08 05:54:17,781 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2023-08-08 05:54:17,784 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.key.bias
# 2023-08-08 05:54:17,786 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.key.weight
# 2023-08-08 05:54:17,788 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.query.bias
# 2023-08-08 05:54:17,790 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.query.weight
# 2023-08-08 05:54:17,792 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.value.bias
# 2023-08-08 05:54:17,794 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.attention.self.value.weight
# 2023-08-08 05:54:17,795 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2023-08-08 05:54:17,796 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2023-08-08 05:54:17,799 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2023-08-08 05:54:17,801 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2023-08-08 05:54:17,802 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.dense.bias
# 2023-08-08 05:54:17,803 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.encoder.layer.9.output.dense.weight
# 2023-08-08 05:54:17,804 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.pooler.dense.bias
# 2023-08-08 05:54:17,806 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens.transformer_model.pooler.dense.weight
# 2023-08-08 05:54:18,841 - INFO - allennlp.models.archival - removing temporary unarchived model dir at C:\Users\sjsheikh\AppData\Local\Temp\tmp7cvuxn3u

# %% [markdown]
# # Read text file and preprocess.

# %%
#from spacy.lang.en import English

file_name = './Text/Simplified Medical Text.txt'
#file_name = 'input.txt'
narrative = open(file_name, encoding="utf8").read()

narrative = textacy.preprocessing.normalize_quotation_marks(narrative)
#narrative = textacy.preprocessing.remove_punctuation(narrative, marks=",;:")
#narrative = textacy.preprocessing.normalize_whitespace(narrative)
#narrative = textacy.make_spacy_doc(narrative)
narrative = narrative.lower()
narrative = nlp(narrative)

#narrative._.coref_clusters
#narrative._.coref_resolved

print('Original Narrative:')
print(narrative)
#print('\n')
print('Extracted Coreferences:')
print(narrative._.coref_clusters)
print('\n')
narrative = narrative._.coref_resolved
print('Narrarive after resolving coreferences:')
print(narrative)

raw_sentences = sent_tokenize(narrative)
#nlp.add_pipe(nlp.create_pipe('sentencizer')) # updated
narrative = nlp(narrative)
#sentences = [sent.string.strip() for sent in narrative.sents]
#narrative = nlp(narrative)

print('\nSpacy Sentences:\n')
for sent in narrative.sents:
    print(sent.text)

print('\nNLTK Sentences:\n')
for sent in raw_sentences:
    print(sent)
# Out:
# Original Narrative:
# excessive overthinking leads to insomnia. stress caused insomnia. insomnia causes stress. stress results in insomnia. stress caused my insomnia. overthinking can increase anxiety. overthinking can cause insomnia. stress is a reason of my insomnia. stress results to insomnia.
# Extracted Coreferences:
# [my insomnia: [my insomnia, my insomnia]]
#
#
# Narrarive after resolving coreferences:
# excessive overthinking leads to insomnia. stress caused insomnia. insomnia causes stress. stress results in insomnia. stress caused my insomnia. overthinking can increase anxiety. overthinking can cause insomnia. stress is a reason of my insomnia. stress results to insomnia.
#
# Spacy Sentences:
#
# excessive overthinking leads to insomnia.
# stress caused insomnia.
# insomnia causes stress.
# stress results in insomnia.
# stress caused my insomnia.
# overthinking can increase anxiety.
# overthinking can cause insomnia.
# stress is a reason of my insomnia.
# stress results to insomnia.
#
# NLTK Sentences:
#
# excessive overthinking leads to insomnia.
# stress caused insomnia.
# insomnia causes stress.
# stress results in insomnia.
# stress caused my insomnia.
# overthinking can increase anxiety.
# overthinking can cause insomnia.
# stress is a reason of my insomnia.
# stress results to insomnia.

# %% [markdown]
# # Extract the Subject-Verb-Object triples.

# %% [raw]
# for sent in narrative.sents:
#     #print("Heyyyy!")
#     print(sent)
#     for tok in sent:
#         print(tok.text,tok.pos_,tok.dep_)

# %%
#new
finalList = []
sentences = []
ncl = []
nncl = [()]
checkPass = False
rootCheck = False
varForm1 = False
varForm2 = False
sub = ''
obj = ''
#tuple =('a','b','c')

#print(tuple[0])

for sent in narrative.sents:
    print("Sentence:")
    print(sent)
    
    print("Noun Chunks:")
    for nc in sent.noun_chunks:
        print (nc)
        ncl.append(nc)
    print ("Number of noun chunks: ", len(ncl))
    
    triplets = textacy.extract.subject_verb_object_triples(sent)
    triplets = list(triplets)
    if len(triplets) > 0:
        print("Triples from textacy:")
        for t in triplets:
            subject = t[0]
            objec = t[2]
            for chunk in ncl:
                for cToken in chunk:
                    if str(cToken) == str(t[0]):
                        subject = chunk
                    if str(cToken) == str(t[2]):
                        objec = chunk
            tup = (subject,t[1],objec)
            print(tup)
            finalList.append(tup)
            sentences.append(sent)
        if len(ncl) == 3:
            nncl = [(ncl[0],triplets[0][1],ncl[1])]
            nncl.append((ncl[0],triplets[0][1],ncl[2]))
            print("Triples other than textacy:")
            print(nncl[0])
            print(nncl[1])
            finalList.append(nncl[0])
            sentences.append(sent)
            finalList.append(nncl[1])
            sentences.append(sent)
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],triplets[0][1],ncl[1])]
#            print("Triples other than textacy:")
#            print(nncl[0])
#            finalList.append(nncl[0])
    else:
        print("Method from textacy; subject_verb_object_triples extracted nothing!")
        for token in sent:
            #print(token.text, token.dep_,)
            if token.dep_ == 'nsubj':
                print("Solat")
                sub = token
                print(sub)
                #tuple[0] = str(token.text)
            elif token.dep_ == 'nsubjpass':
                checkPass = True
                sub = token
            elif token.dep_ == 'ROOT':
                #print("Heyyyyyyy")
                verb = token
                #print(verb)
                rootCheck = True
            elif token.pos_ == 'NOUN' and token.dep_ == 'conj':
                if rootCheck is True:
                    varForm2 = True
                else:
                    varForm1 = True
                #tuple[1] = token.text
            #elif token.dep_ == 'dobj':
            #    obj = token.text
                #tuple[2] = token.text
            #    break
            else:
                if token.dep_ == 'dobj':
                    obj = token
                    continue
                elif token.dep_ == 'pobj':
                    obj = token
                    continue
                
        for nChunk in ncl:
            for nToken in nChunk:
                if str(nToken) == str(sub):
                    sub = nChunk
                if str(nToken) == str(obj):
                    obj = nChunk
        if checkPass is True:
            tuple = (obj,verb,sub)
        else:
            tuple = (sub,verb,obj)
        print("Triple by combining nsubj, root and dobj:")
        print(tuple)
        finalList.append(tuple)
        sentences.append(sent)
        if len(ncl) == 3:
            if varForm1 == True:
                nncl = [(ncl[0],verb,ncl[2])]
                nncl.append((ncl[1],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            else:
                nncl = [(ncl[0],verb,ncl[1])]
                nncl.append((ncl[0],verb,ncl[2]))
                print("Triples other than sub, verb and obj:")
                print(nncl[0])
                print(nncl[1])
                finalList.append(nncl[0])
                sentences.append(sent)
                finalList.append(nncl[1])
                sentences.append(sent)
            
#        elif len(ncl) == 2:
#            nncl = [(ncl[0],verb,ncl[1])]
#            print("Triples other than sub, verb and obj:")
#            print(nncl[0])
#            finalList.append(nncl[0])

    ncl.clear()
    nncl.clear()
    rootCheck = False
    checkPass = False
    varForm1 = False
    varForm2 = False
    
trips = finalList

#        for token in nc:
#            print(token.text, token.dep_)
# Out:
# Sentence:
# excessive overthinking leads to insomnia.
# Noun Chunks:
# excessive overthinking leads
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Solat
# overthinking
# Triple by combining nsubj, root and dobj:
# (excessive overthinking leads, leads, '')
# Sentence:
# stress caused insomnia.
# Noun Chunks:
# stress
# insomnia
# Number of noun chunks:  2
# Triples from textacy:
# (stress, caused, insomnia)
# Sentence:
# insomnia causes stress.
# Noun Chunks:
# insomnia
# stress
# Number of noun chunks:  2
# Triples from textacy:
# (insomnia, causes, stress)
# Sentence:
# stress results in insomnia.
# Noun Chunks:
# stress results
# insomnia
# Number of noun chunks:  2
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking leads, results, insomnia)
# Sentence:
# stress caused my insomnia.
# Noun Chunks:
# stress
# my insomnia
# Number of noun chunks:  2
# Triples from textacy:
# (stress, caused, my insomnia)
# Sentence:
# overthinking can increase anxiety.
# Noun Chunks:
# anxiety
# Number of noun chunks:  1
# Triples from textacy:
# (overthinking, can increase, anxiety)
# Sentence:
# overthinking can cause insomnia.
# Noun Chunks:
# insomnia
# Number of noun chunks:  1
# Triples from textacy:
# (overthinking, can cause, insomnia)
# Sentence:
# stress is a reason of my insomnia.
# Noun Chunks:
# stress
# a reason
# my insomnia
# Number of noun chunks:  3
# Triples from textacy:
# (stress, is, a reason)
# Triples other than textacy:
# (stress, is, a reason)
# (stress, is, my insomnia)
# Sentence:
# stress results to insomnia.
# Noun Chunks:
# stress results
# Number of noun chunks:  1
# Method from textacy; subject_verb_object_triples extracted nothing!
# Triple by combining nsubj, root and dobj:
# (excessive overthinking leads, results, insomnia)

# %% [raw]
# #old
# def SVO(narrative):
#     ncl = []
#     fl = []
#     nncl = [()]
#     for sent in narrative.sents:
#         #sent = str(sent)
#         print("\n" + str(sent))
#         for nc in sent.noun_chunks:
#             print (nc)
#             ncl.append(nc)
#         print(len(ncl))
#         triplets = textacy.extract.subject_verb_object_triples(sent)
#         triplets = list(triplets)
#         if len(ncl) <= 3:
#             if len(triplets) == 0:
#                 print("Method from textacy; subject_verb_object_triples extracted nothing!")
#                 for token in sent:
#                 #print(token.text, token.dep_,)
#                     if token.dep_ == 'ROOT':
#                         text = token.text
#                         break
#                     #print(token.text)
#                 if len(ncl) == 3:
#                         nncl = [(ncl[0],token.text,ncl[1])]
#                         nncl.append((ncl[0],token.text,ncl[2]))
#                         fl.append(nncl[0])
#                         fl.append(nncl[1])
#                 elif len(ncl) == 2:
#                         nncl = [(ncl[0],token.text,ncl[1])]
#                         fl.append(nncl[0])
#                 else:
#                     continue
#                 print("Triples without textacy.")
#                 print(nncl)
#
#             else:
#                 print(triplets)
#                 for t in triplets:
#                     print(t)
#                     fl.append(t)
#                 if len(ncl) == 3:
#                     nncl = [(ncl[0],triplets[0][1],ncl[1])]
#                     nncl.append((ncl[0],triplets[0][1],ncl[2]))
#                     fl.append(nncl[0])
#                     fl.append(nncl[1])
#                     #print(nncl[0])
#                     #print(nncl[1])
#                 elif len(ncl) == 2:
#                     nncl = [(ncl[0],triplets[0][1],ncl[1])]
#                     fl.append(nncl[0])
#                 else:
#                     continue;
#                 print(nncl)
#         ncl.clear()
#         nncl.clear()
#     return fl
#
# trips = SVO(narrative)

# %% [markdown]
# # Remove Duplicates from Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("Length of triples' List before removing duplicates:")
print(len(trips))

Triples = []
sentences1 = []

for sentence,ce in zip(sentences, trips):
    check = False
    #print("ce:")
    #print(ce)
    if len(Triples) == 0:
        #print("HEY!")
        Triples.append(ce)
        sentences1.append(sentence)
        #print("added!")
    else:
        for ct in Triples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            Triples.append(ce)
            sentences1.append(sentence)
            #print("added!")

print("\nList after removing duplicates:")
print(len(Triples))

for t in Triples:
    print(t)
# Out:
# Length of triples' List before removing duplicates:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15844\3768768410.py in <module>
#       7 sentences1 = []
#       8
# ----> 9 for sentence,ce in zip(sentences, trips):
#      10     check = False
#      11     #print("ce:")
#
# NameError: name 'sentences' is not defined

# %% [markdown]
# # Filter correct triples from extracted triples

# %%
correctTriples = []
sentences2 = []

for sentence,line in zip(sentences1, Triples):
    taggedWords = []
    taggedWords1 = []
    check0 = False
    check2 = False
    print(line)
    taggedWords = pos_tag(word_tokenize(str(line[0])))
    taggedWords1 = pos_tag(word_tokenize(str(line[2])))
    print(taggedWords)
    print(taggedWords1)
    for i in range(len(taggedWords)):
        if taggedWords[i][1] == 'NN' or taggedWords[i][1] == 'NNS':
            check0 = True
    for i in range(len(taggedWords1)):
        if taggedWords1[i][1] == 'NN' or taggedWords1[i][1] == 'NNS':
            check2 = True
    print(check0)  
    print(check2)
    if check0 == True and check2 == True:
        correctTriples.append(line)
        sentences2.append(sentence)
    print("**************************************************************************")
    
for correctTriple in correctTriples:
    print(correctTriple)
# Out:
# (excessive overthinking leads, leads, '')
# [('excessive', 'JJ'), ('overthinking', 'NN'), ('leads', 'NNS')]
# []
# True
# False
# **************************************************************************
# (stress, caused, insomnia)
# [('stress', 'NN')]
# [('insomnia', 'NN')]
# True
# True
# **************************************************************************
# (insomnia, causes, stress)
# [('insomnia', 'NN')]
# [('stress', 'NN')]
# True
# True
# **************************************************************************
# (excessive overthinking leads, results, insomnia)
# [('excessive', 'JJ'), ('overthinking', 'NN'), ('leads', 'NNS')]
# [('insomnia', 'NN')]
# True
# True
# **************************************************************************
# (stress, caused, my insomnia)
# [('stress', 'NN')]
# [('my', 'PRP$'), ('insomnia', 'NN')]
# True
# True
# **************************************************************************
# (overthinking, can increase, anxiety)
# [('overthinking', 'VBG')]
# [('anxiety', 'NN')]
# False
# True
# **************************************************************************
# (overthinking, can cause, insomnia)
# [('overthinking', 'VBG')]
# [('insomnia', 'NN')]
# False
# True
# **************************************************************************
# (stress, is, a reason)
# [('stress', 'NN')]
# [('a', 'DT'), ('reason', 'NN')]
# True
# True
# **************************************************************************
# (stress, is, my insomnia)
# [('stress', 'NN')]
# [('my', 'PRP$'), ('insomnia', 'NN')]
# True
# True
# **************************************************************************
# (stress, caused, insomnia)
# (insomnia, causes, stress)
# (excessive overthinking leads, results, insomnia)
# (stress, caused, my insomnia)
# (stress, is, a reason)
# (stress, is, my insomnia)

# %% [markdown]
# # Print the extracted triples with sentences.

# %%
for sentence, triple  in zip(sentences2, correctTriples):
    print(sentence, triple)
    print()
# Out:
# stress caused insomnia. (stress, caused, insomnia)
#
# insomnia causes stress. (insomnia, causes, stress)
#
# stress results in insomnia. (excessive overthinking leads, results, insomnia)
#
# stress caused my insomnia. (stress, caused, my insomnia)
#
# stress is a reason of my insomnia. (stress, is, a reason)
#
# stress is a reason of my insomnia. (stress, is, my insomnia)

# %% [markdown]
# # Plot the knowledge Graph.

# %%
cmap = nx.DiGraph()

for triple in correctTriples:
    s = str(triple[0])    
    d = str(triple[2])
    cmap.add_edge(s, d, predicate=triple[1])
    #print(triple)

print("Nodes:",len(cmap.nodes))
print("Edges:",len(cmap.edges))
for e in cmap.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cmap, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cmap, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cmap.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cmap,'predicate')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 5
# Edges: 5
# stress , {'predicate': caused} , insomnia
# stress , {'predicate': is} , my insomnia
# stress , {'predicate': is} , a reason
# insomnia , {'predicate': causes} , stress
# excessive overthinking leads , {'predicate': results} , insomnia

# %% [markdown]
# # Dump the Knowledge Graph on "Knowledge Graph.json"

# %%
knowledgeGraph = nx.DiGraph()

for svo in correctTriples:
    s = str(svo[0])    
    d = str(svo[2])
    knowledgeGraph.add_node(s,id = str(s),title=str(s),x=615,y=200)
    knowledgeGraph.add_node(d,id = str(d),title=str(d),x=615,y=200)
    knowledgeGraph.add_edge(s, d, predicade=str(svo[1]))

#print(len(knowledgeGraph.nodes))
#print(len(knowledgeGraph.edges))

data = json_graph.node_link_data(knowledgeGraph)


out_file = open("./Json Graphs/Knowledge Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Create Causal Trigger Words Dictionary along with their synonyms.

# %%
#new

causalWords1 = ["forced","caused", "resulted", "reason", "as a result of", "as a consequence of", 
               "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
               ,"made","minimize","maximize","hindered", "displaced", "conspired","led to","activate","impel","inspire",
                "excite","quicken","rouse","stimulate","influence","determine","likely","probable","disconnected","separated"
                ,"excluded","after","as","since","trigger","oppose","fight","provides","strengthened","launched","develop"
               ,"guarantees","declared", "developed","produced","discourages","demotivated","encouraged","motivated"]

#causalWords1 = ["develop"]
synonyms1 = []
lemma_function = WordNetLemmatizer()

for cw1 in causalWords1:
    #print(cw1)
    synonyms1.append(cw1.lower())
    tokens1 = word_tokenize(cw1)
    for token1, tag1 in pos_tag(tokens1):
        lemma1 = lemma_function.lemmatize(token1)
        #print(token1,lemma1)
        
        for syn in wordnet.synsets(str(lemma1)):
            
            for l1 in syn.lemmas():
                #print(l1)
                #synonyms1.append(lemma1.lower())
                synonyms1.append(l1.name().lower())
                #print(l1)
                for syn1 in wordnet.synsets(str(l1.name())):
                    for l2 in syn1.lemmas():
                        #print(l2)
                        synonyms1.append(l2.name().lower())
            

#remove duplicates from synonyms1
synonyms = []
     
for synonym in synonyms1:
    if synonym not in synonyms:
        synonyms.append(synonym)
    
#for x in synonyms:
#    print (synonym)

print(len(synonyms))
# Out:
# 3226

# %% [markdown]
# # Writing causal trigger words dictionary to text file (dictionary.txt)

# %%
#synonyms
output_file = open('.\dictionary.txt', 'w')

for syn in synonyms:
    #print(syn)
    output_file.write(syn + '\n')

output_file.close()

# %% [markdown]
# # Reading causal trigger words dictionary from text file (dictionary.txt) to list

# %%
synonyms = []

my_file = open(".\dictionary.txt", "r")
  
data = my_file.read()
  
synonyms = data.split("\n")
#print(data_into_list)
my_file.close()

print(len(synonyms))
# Out:
# 3227

# %% [raw]
# #old
#
# causalWords = ["forced","caused", "result", "reason", "as a result of", "as a consequence of",
#                "consequence", "consequently", "affect", "because", "increase", "decrease","due to","because of"
#                ,"made","mimimize","maximize","led to","produced"]
#
# #causalWords = ["as a result of"]
# synonyms = []
#
# for cw in causalWords:
#
#     for syn in wordnet.synsets(str(cw)):
#         for l in syn.lemmas():
#             synonyms.append(cw)
#             synonyms.append(l.name())
#
# print(set(synonyms))
# print(len(synonyms))

# %% [markdown]
# # Filter Causal triples along with their causal sentences from SVO triples based upon causal trigger words dictionary.

# %%
causeffect = [] #without duplicates
causalSentences = [] #with duplicates
#lem = []
#lemma_function = WordNetLemmatizer()
for s,st in zip(sentences2,correctTriples):
    check = False
    #st = (str(st[0]),str(st[1]),str(st[2]))
    #synonym = synonym[0]
    tokens = word_tokenize(str(st[1]))
    for token, tag in pos_tag(tokens):
        lemma = lemma_function.lemmatize(token)
        #print(token,lemma)
        #st[1] = lemma
        #lem.append(lemma)
        
    for synonym in synonyms:
        if synonym == lemma:
            #causeffect = [(st[0],st[1],st[2])]
            #strTriples.append((ncl[0],token.text,st[2]))
           # print(st)
            if len(causeffect) == 0:
                causeffect.append(st)
                causalSentences.append(s)
            else:
                for ct in causeffect:
                    if str(st[0]) == str(ct[0]) and str(st[1]) == str(ct[1]) and str(st[2]) == str(ct[2]):
                        check = True
                        break;
                if check == False:
                    causeffect.append(st)
                    causalSentences.append(s)
            #if (len(causeffect) >0 ) and (st in causeffect == False):
                
            #    causeffect.append(st)
            break
    
#causeffect.sort(key = lambda x: x[0])

#for sortedTriple in causeffect:
#    print(sortedTriple)
print(len(causalSentences))
print(len(causeffect))
for causalSentence, causalTriple  in zip(causalSentences, causeffect):
    print(causalSentence, causalTriple)
# Out:
# 4
# 4
# stress caused insomnia. (stress, caused, insomnia)
# insomnia causes stress. (insomnia, causes, stress)
# stress results in insomnia. (excessive overthinking leads, results, insomnia)
# stress caused my insomnia. (stress, caused, my insomnia)

# %% [markdown]
# # Plot the Causal Graph.

# %%
#new (DAG Implementation)
#without duplicates
dagCauseTriples = []
cg = nx.DiGraph()

for ce in causeffect:
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
    dagCauseTriples.append(ce)
    if nx.is_directed_acyclic_graph(cg) is False:
        cg.remove_edge(s, d)
        dagCauseTriples.remove(ce)
        

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cg, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()
# Out:
# Nodes: 4
# Edges: 3
# stress , {'predicade': 'caused'} , insomnia
# stress , {'predicade': 'caused'} , my insomnia
# excessive overthinking leads , {'predicade': 'results'} , insomnia

# %%
#old
#without duplicates

cg = nx.DiGraph()

for ce in causeffect:
    s = str(ce[0])    
    d = str(ce[2])
    #cg.add_node(s,id = str(s),title=str(s),x=615,y=200) #for d3js
    cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
    #cg.add_node(d,id = str(d),title=str(d),x=615,y=200) #for d3js
    cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
    cg.add_edge(s, d, predicade=str(ce[1]))
        

print("Nodes:",len(cg.nodes))
print("Edges:",len(cg.edges))
for e in cg.edges(data=True):
    print(e[0],",",e[2],",",e[1])
    
print(nx.is_directed_acyclic_graph(cg))

pos = nx.spring_layout(cg, k=4, iterations=20)
plt.figure(figsize=(15,12))

nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
edge_labels = nx.get_edge_attributes(cg,'predicade')
nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)

plt.axis('off')
plt.show()

# %% [markdown]
# # Plot the Causal Graph on using Pyvis "Causal Graph.html" file

# %%
nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')

for dm in dagCauseTriples:
    #color = "#ffffff"
    nt.add_node(str(dm[0]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_node(str(dm[2]),shape = 'box',physics='false',color = "#ffffff")
    nt.add_edge(str(dm[0]),str(dm[2]),label=str(dm[1]), weight=10, physics='false',color='black')

#nt.show_buttons(filter_=['physics'])
nt.set_edge_smooth('discrete')
nt.show("./Pyvis Graph/Causal Graph.html")
# Out:
#         <iframe
#             width="1000px"
#             height="500px"
#             src="./Pyvis Graph/Causal Graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [raw]
# nt = Network("500px", "1000px", notebook=True,directed=True, bgcolor='#ffffff', font_color='black', layout=None, heading='Causal Graph')
#
# nt.add_node(1, label="Subject (cause)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_node(2, label="Object (effect)",shape = 'box',physics='false',color = "#ffffff")
# nt.add_edge(1,2,label="Verb (cause-effect)", weight=10, physics='false',color='black')
#
#
# nt.show("./Pyvis Graph/Causal Graph.html")

# %% [markdown]
# # Dump the Causal Graph on "Causal Graph.json" file

# %%
data = json_graph.node_link_data(cg)


out_file = open("./Json Graphs/Causal Graph.json", "w")
  
json.dump(data, out_file, indent = 6)
  
out_file.close()

# %% [markdown]
# # Remove Duplicates from Causal Triples

# %%
#causeffect = list(dict.fromkeys(causeffect))

print("List before removing duplicates:")
print(len(causeffect))

for t in causeffect:
    print(t)
    
causalTriples = []

for ce in causeffect:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalTriples) == 0:
        #print("HEY!")
        causalTriples.append(ce)
        #print("added!")
    else:
        for ct in causalTriples:
            #print("ct:")
            #print(ct)
            if str(ce[0]) == str(ct[0]) and str(ce[1]) == str(ct[1]) and str(ce[2]) == str(ct[2]):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalTriples.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalTriples))

for t in causalTriples:
    print(t)
# Out:
# List before removing duplicates:
# 13
# (zulfikar ali bhutto, launched, nuclear program)
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# (aq khan, developed, nuclear bomb)
# (nuclear bomb, strengthened, pakistan)
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, provides, vigilance)
# (vigilance, strengthened, national survival)
# (nuclear bomb, guarantees, pakistan's continued existence)
#
# List after removing duplicates:
# 13
# (zulfikar ali bhutto, launched, nuclear program)
# (nuclear program, declared, pakistan's commitment)
# (nuclear program, declared, pakistan's dedication)
# (aq khan, developed, nuclear bomb)
# (nuclear bomb, strengthened, pakistan)
# (nuclear bomb, makes, nuclear power)
# (pakistan, must never surrender, nuclear bomb)
# (pakistan, must fight, existential threats)
# (pakistan, must support, army)
# (pakistan, must support, aq khan)
# (army, provides, vigilance)
# (vigilance, strengthened, national survival)
# (nuclear bomb, guarantees, pakistan's continued existence)

# %% [markdown]
# # Remove Duplicates from causalSentences

# %%
#causalSentences = list(dict.fromkeys(causalSentences))
#causalSentences = list(set(causalSentences))
print("List before removing duplicates:")
print(len(causalSentences))

for t in causalSentences:
    print(t)
    
causalSentencesNoDup = []

for ce in causalSentences:
    check = False
    #print("ce:")
    #print(ce)
    if len(causalSentencesNoDup) == 0:
        #print("HEY!")
        causalSentencesNoDup.append(ce)
        #print("added!")
    else:
        for ct in causalSentencesNoDup:
            #print("ct:")
            #print(ct)
            if str(ce) == str(ct):
                #print("duplicate")
                check = True
                break;
        if check == False:
            causalSentencesNoDup.append(ce)
            #print("added!")

print("\nList after removing duplicates:")
print(len(causalSentencesNoDup))

for t in causalSentencesNoDup:
    print(t)
# Out:
# List before removing duplicates:
# 13
# zulfikar ali bhutto launched nuclear program.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# aq khan developed nuclear bomb.
# nuclear bomb strengthened pakistan.
# nuclear bomb makes nuclear power.
# pakistan must never surrender nuclear bomb.
# pakistan must fight off existential threats.
# pakistan must support army and aq khan.
# pakistan must support army and aq khan.
# army provides vigilance.
# vigilance strengthened national survival.
# nuclear bomb guarantees pakistan's continued existence.
#
# List after removing duplicates:
# 11
# zulfikar ali bhutto launched nuclear program.
# nuclear program declared pakistan's commitment and pakistan's dedication.
# aq khan developed nuclear bomb.
# nuclear bomb strengthened pakistan.
# nuclear bomb makes nuclear power.
# pakistan must never surrender nuclear bomb.
# pakistan must fight off existential threats.
# pakistan must support army and aq khan.
# army provides vigilance.
# vigilance strengthened national survival.
# nuclear bomb guarantees pakistan's continued existence.

# %% [markdown]
# # Causal Triples' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
allen = []
for sent in causalTriples:
    #print(sent)
    preds = predictor.predict(str(sent))
    #print(preds['label'][0])
    label = preds['label'][0]
    if label is '0':
        allen.append(-1)
    else:
        allen.append(1)
    
for causalSentence, polarity  in zip(causalTriples, allen):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) -1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) 1
# (pakistan, must never surrender, nuclear bomb) 1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 1
# (vigilance, strengthened, national survival) 1
# (nuclear bomb, guarantees, pakistan's continued existence) 1

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)

afinn = []
for sent in causalTriples:
    #print(str(sent))
    score = afn.score(str(sent))
    #print(score)
    if score > 0:
        #print('positive')
        afinn.append(1)
    elif score < 0:
        #print('negative')
        afinn.append(-1)
    else:
        #print('neutral')
        afinn.append(0)
        
for causalSentence, polarity  in zip(causalTriples, afinn):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) 1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) -1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 0
# (vigilance, strengthened, national survival) 1
# (nuclear bomb, guarantees, pakistan's continued existence) -1

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

vader = []

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    if compound >= 0.05:
        vader.append(1)
        return 'Positive'
    elif compound <= -0.05 :
        vader.append(-1)
        return 'Negative'
        
    elif  compound > -0.05 and compound < 0.05:
        vader.append(0)
        return 'Neutral'
    
for sent in causalTriples:
    #print(sent)
    compound = vadersentimentanalysis(str(sent))
    vader_analysis(compound)
    
for causalSentence, polarity  in zip(causalTriples, vader):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 0
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) 1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 0
# (vigilance, strengthened, national survival) 1
# (nuclear bomb, guarantees, pakistan's continued existence) -1

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

sentiStrength = []

for sent in causalTriples:
    #print(sent)
    result = senti.getSentiment(str(sent), score='binary')
    #print(result)
    
    if result[0]==1:
        #print('Positive')
        sentiStrength.append(1)
    elif result[0]==-1:
        sentiStrength.append(-1)
        #print('Negative')
    #else:
    #    print('Neutral')

for causalSentence, polarity  in zip(causalTriples, sentiStrength):
    print(causalSentence, polarity)
# Out:
# (zulfikar ali bhutto, launched, nuclear program) 1
# (nuclear program, declared, pakistan's commitment) 1
# (nuclear program, declared, pakistan's dedication) 1
# (aq khan, developed, nuclear bomb) -1
# (nuclear bomb, strengthened, pakistan) -1
# (nuclear bomb, makes, nuclear power) -1
# (pakistan, must never surrender, nuclear bomb) -1
# (pakistan, must fight, existential threats) -1
# (pakistan, must support, army) 1
# (pakistan, must support, aq khan) 1
# (army, provides, vigilance) 1
# (vigilance, strengthened, national survival) 1
# (nuclear bomb, guarantees, pakistan's continued existence) -1

# %% [markdown]
# ### Data Frame (Causal Triples Whole)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

df2 = pd.DataFrame(list(zip(causalTriples, allen, afinn, vader,sentiStrength)), columns =['Causal Triple', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)

sentPolarity = []
triplesWeight_sentLevel = []

for index, row in df2.iterrows():
    tripleWeightTuple = []
    weight = row['Weight']
    tripleWeightTuple.append(weight)
    triplesWeight_sentLevel.append(tripleWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# C:\Users\sjsheikh\Anaconda3\envs\First\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.
# <style type="text/css">
# </style>
# <table id="T_fdb4b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Causal Triple</th>
#       <th class="col_heading level0 col1" >AllenNLP</th>
#       <th class="col_heading level0 col2" >Afinn</th>
#       <th class="col_heading level0 col3" >Vader</th>
#       <th class="col_heading level0 col4" >SentiStrength</th>
#       <th class="col_heading level0 col5" >Weight</th>
#       <th class="col_heading level0 col6" >Polarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdb4b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdb4b_row0_col0" class="data row0 col0" >(zulfikar ali bhutto, launched, nuclear program)</td>
#       <td id="T_fdb4b_row0_col1" class="data row0 col1" >-1</td>
#       <td id="T_fdb4b_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_fdb4b_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_fdb4b_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_fdb4b_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_fdb4b_row0_col6" class="data row0 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fdb4b_row1_col0" class="data row1 col0" >(nuclear program, declared, pakistan's commitment)</td>
#       <td id="T_fdb4b_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_fdb4b_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_fdb4b_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_fdb4b_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_fdb4b_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_fdb4b_row1_col6" class="data row1 col6" >Strong Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fdb4b_row2_col0" class="data row2 col0" >(nuclear program, declared, pakistan's dedication)</td>
#       <td id="T_fdb4b_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_fdb4b_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_fdb4b_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_fdb4b_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_fdb4b_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_fdb4b_row2_col6" class="data row2 col6" >Moderate Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fdb4b_row3_col0" class="data row3 col0" >(aq khan, developed, nuclear bomb)</td>
#       <td id="T_fdb4b_row3_col1" class="data row3 col1" >-1</td>
#       <td id="T_fdb4b_row3_col2" class="data row3 col2" >-1</td>
#       <td id="T_fdb4b_row3_col3" class="data row3 col3" >-1</td>
#       <td id="T_fdb4b_row3_col4" class="data row3 col4" >-1</td>
#       <td id="T_fdb4b_row3_col5" class="data row3 col5" >-4</td>
#       <td id="T_fdb4b_row3_col6" class="data row3 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fdb4b_row4_col0" class="data row4 col0" >(nuclear bomb, strengthened, pakistan)</td>
#       <td id="T_fdb4b_row4_col1" class="data row4 col1" >-1</td>
#       <td id="T_fdb4b_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_fdb4b_row4_col3" class="data row4 col3" >-1</td>
#       <td id="T_fdb4b_row4_col4" class="data row4 col4" >-1</td>
#       <td id="T_fdb4b_row4_col5" class="data row4 col5" >-2</td>
#       <td id="T_fdb4b_row4_col6" class="data row4 col6" >Mild Negative</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fdb4b_row5_col0" class="data row5 col0" >(nuclear bomb, makes, nuclear power)</td>
#       <td id="T_fdb4b_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_fdb4b_row5_col2" class="data row5 col2" >-1</td>
#       <td id="T_fdb4b_row5_col3" class="data row5 col3" >-1</td>
#       <td id="T_fdb4b_row5_col4" class="data row5 col4" >-1</td>
#       <td id="T_fdb4b_row5_col5" class="data row5 col5" >-2</td>
#       <td id="T_fdb4b_row5_col6" class="data row5 col6" >Mild Negative</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fdb4b_row6_col0" class="data row6 col0" >(pakistan, must never surrender, nuclear bomb)</td>
#       <td id="T_fdb4b_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_fdb4b_row6_col2" class="data row6 col2" >-1</td>
#       <td id="T_fdb4b_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_fdb4b_row6_col4" class="data row6 col4" >-1</td>
#       <td id="T_fdb4b_row6_col5" class="data row6 col5" >0</td>
#       <td id="T_fdb4b_row6_col6" class="data row6 col6" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fdb4b_row7_col0" class="data row7 col0" >(pakistan, must fight, existential threats)</td>
#       <td id="T_fdb4b_row7_col1" class="data row7 col1" >-1</td>
#       <td id="T_fdb4b_row7_col2" class="data row7 col2" >-1</td>
#       <td id="T_fdb4b_row7_col3" class="data row7 col3" >-1</td>
#       <td id="T_fdb4b_row7_col4" class="data row7 col4" >-1</td>
#       <td id="T_fdb4b_row7_col5" class="data row7 col5" >-4</td>
#       <td id="T_fdb4b_row7_col6" class="data row7 col6" >Strong Negative</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fdb4b_row8_col0" class="data row8 col0" >(pakistan, must support, army)</td>
#       <td id="T_fdb4b_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_fdb4b_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_fdb4b_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_fdb4b_row8_col4" class="data row8 col4" >1</td>
#       <td id="T_fdb4b_row8_col5" class="data row8 col5" >4</td>
#       <td id="T_fdb4b_row8_col6" class="data row8 col6" >Strong Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fdb4b_row9_col0" class="data row9 col0" >(pakistan, must support, aq khan)</td>
#       <td id="T_fdb4b_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_fdb4b_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_fdb4b_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_fdb4b_row9_col4" class="data row9 col4" >1</td>
#       <td id="T_fdb4b_row9_col5" class="data row9 col5" >4</td>
#       <td id="T_fdb4b_row9_col6" class="data row9 col6" >Strong Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fdb4b_row10_col0" class="data row10 col0" >(army, provides, vigilance)</td>
#       <td id="T_fdb4b_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_fdb4b_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_fdb4b_row10_col3" class="data row10 col3" >0</td>
#       <td id="T_fdb4b_row10_col4" class="data row10 col4" >1</td>
#       <td id="T_fdb4b_row10_col5" class="data row10 col5" >2</td>
#       <td id="T_fdb4b_row10_col6" class="data row10 col6" >Mild Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fdb4b_row11_col0" class="data row11 col0" >(vigilance, strengthened, national survival)</td>
#       <td id="T_fdb4b_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_fdb4b_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_fdb4b_row11_col3" class="data row11 col3" >1</td>
#       <td id="T_fdb4b_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_fdb4b_row11_col5" class="data row11 col5" >4</td>
#       <td id="T_fdb4b_row11_col6" class="data row11 col6" >Strong Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fdb4b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fdb4b_row12_col0" class="data row12 col0" >(nuclear bomb, guarantees, pakistan's continued existence)</td>
#       <td id="T_fdb4b_row12_col1" class="data row12 col1" >1

# %% [markdown]
# # Causal Sentences' Polarity (Whole)

# %% [markdown]
# ### [AllenNlp]

# %%
#https://demo.allennlp.org/sentiment-analysis/roberta-sentiment-analysis
#https://paperswithcode.com/model/roberta-large-sst

#output (Pos,neg)

#sentence = "Enemies surround Pakistan."
#preds = predictor.predict(sentence)
#print(f"p(positive)={preds['probs'][0]:.2%}")
def Allen_sents_SentLevel(causalSentences):
    allen = []
    for sent in causalSentences:
        #print(sent)
        preds = predictor.predict(str(sent))
        #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen.append(-1)
        else:
            allen.append(1)
    return allen

#for causalSentence, polarity  in zip(causalSentences, allen):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Afinn]

# %%
#https://www.geeksforgeeks.org/python-sentiment-analysis-using-affin/

#output (Pos,neg,neural)
def Afinn_sents_SentLevel(causalSentences):
    afinn = []
    for sent in causalSentences:
        #print(sent)
        score = afn.score(str(sent))
        #print(score)
        if score > 0:
            #print('positive')
            afinn.append(1)
        elif score < 0:
            #print('negative')
            afinn.append(-1)
        else:
            #print('neutral')
            afinn.append(0)
    return afinn

#for causalSentence, polarity  in zip(causalSentences, afinn):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [Vader]

# %%
#https://github.com/cjhutto/vaderSentiment#about-the-scoring
#output (Pos,neg,neural)

def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    #print(vs)
    return vs['compound']

def vader_analysis(compound):
    #vader = []
    if compound >= 0.05:
        #vader.append(1)
        return 1
    elif compound <= -0.05 :
        #vader.append(-1)
        return -1
        
    elif  compound > -0.05 and compound < 0.05:
        #vader.append(0)
        return 0
    #return vader
    
def Vader_sents_SentLevel(causalSentences):
    vader = []
    for sent in causalSentences:
        #print(sent)
        #vaderTup = []
        compound = vadersentimentanalysis(str(sent))
        res = vader_analysis(compound)
        #vaderTup.append(res)
        vader.append(res)
    return vader

#vader = Vader_sents_SentLevel(causalSents)
#vader
#for causalSentence, polarity  in zip(causalSentences, vader):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiStrength]

# %%
#http://sentistrength.wlv.ac.uk/
#http://paper.ijcsns.org/07_book/202001/20200107.pdf
#https://pypi.org/project/sentistrength/
#http://sentistrength.wlv.ac.uk/results.php?text=pakistan+must+support+army+and+aq+khan.&submit=Detect+Sentiment&result=trinary
#https://professorkhan.com/2019/03/29/sentiment-analysis-with-sentistrength/
#output (Pos,neg)

def Senti_sents_SentLevel(causalSentences):
    sentiStrength = []
    for sent in causalSentences:
        #print(sent)
        result = senti.getSentiment(str(sent), score='binary')
        #print(result)
    
        if result[0]==1:
            #print('Positive')
            sentiStrength.append(1)
        elif result[0]==-1:
            sentiStrength.append(-1)
            #print('Negative')
        #else:
        #    print('Neutral')
    return sentiStrength

#for causalSentence, polarity  in zip(causalSentences, sentiStrength):
#    print(causalSentence, polarity)

# %% [markdown]
# ### [SentiWordnet]

# %% [raw]
# def penn_to_wn(tag):
#     if tag.startswith('J'):
#         return wn.ADJ
#     elif tag.startswith('N'):
#         return wn.NOUN
#     elif tag.startswith('R'):
#         return wn.ADV
#     elif tag.startswith('V'):
#         return wn.VERB
#     return None
#
# def sentiment_sentiwordnet(text):
#     #text = text.decode("utf-8")
#     raw_sentences = sent_tokenize(text)
#     #print(raw_sentences)
#     sentiment = 0
#     tokens_count = 0
#
#     for raw_sentence in raw_sentences:
#         print(raw_sentence)
#         tagged_sentence = pos_tag(word_tokenize(raw_sentence))
#         print(tagged_sentence)
#
#         for word, tag in tagged_sentence:
#             wn_tag = penn_to_wn(tag)
#             if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
#                 continue
#
#             #lemma = lemmatizer.lemmatize(word, pos=wn_tag)
#             #if not lemma:
#             #    continue
#
#             synsets = wn.synsets(word, pos=wn_tag)
#             if not synsets:
#                 continue
#
#             synset = synsets[0]
#             swn_synset = swn.senti_synset(synset.name())
#             sentiment += swn_synset.pos_score() - swn_synset.neg_score()
#             tokens_count += 1
#         # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
#         if not tokens_count:
#             return 0
#         if sentiment>0:
#             #return "Positive"
#             print("Positive")
#         elif sentiment==0:
#             #return "Neutral"
#             print("Neutral")
#         else:
#             #return "Negative"
#             print("Negative")
#
# causalNarrative = ""
# for cS in causalSentences:
#     causalNarrative = causalNarrative+str(cS)+" "
#
# causalNarrative = nlp(causalNarrative)
# #raw_sentences = sent_tokenize(causalNarrative)
# #print(str(causalNarrative)+"\n")
# #print(raw_sentences)
# #print(str(narrative))
#
# sentiment_sentiwordnet(str(narrative))

# %% [markdown]
# ### [SentiWordNet OnlyVerbs]

# %% [raw]
# from nltk.corpus import wordnet as wn
# from nltk.corpus import sentiwordnet as swn
# from nltk.tag import pos_tag
# import nltk
#
#
# polarizedCauseffect = []
# for ce in causeffect:
#     print(ce[1])
#     token = nltk.word_tokenize(str(ce[1]))
#     after_tagging = nltk.pos_tag(token)
#     print(after_tagging)
#     print(len(after_tagging))
#     for tag in after_tagging:
#         if tag[1].startswith('V') or len(after_tagging)==1:
#             words = swn.senti_synsets(tag[0])
#             answer = list(words)[0]
#             if (answer.pos_score() > answer.neg_score()):
#                 mce = str(ce[1])+"(+ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             elif (answer.pos_score() > 0):
#                 mce = str(ce[1])+"(-ve)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#             else:
#                 mce = str(ce[1])+"(neutral)"
#                 ce1=(ce[0],mce,ce[2])
#                 polarizedCauseffect.append(ce1)
#                 print(ce1)
#
# polarizedCauseffect

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) without duplicates

# %%
causalSents = causalSentencesNoDup
print(len(causalSents))
# Out:
# 11

# %% [markdown]
# ### Detect Causal Sentences' Polarity (Sent Level) with duplicates

# %% [raw]
# causalSents = causalSentences
# print(len(causalSents))

# %% [markdown]
# ### Data Frame (Causal Sentence at Sentence Level)

# %%
#df2 = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, 0,0],[19, 439, 6, 452, 226,232,0]],columns=['Causal Sentence','AllenNlp','Afinn','Vader','SentiStrength','Weight','Polarity'])

allen = Allen_sents_SentLevel(causalSents)
afinn = Afinn_sents_SentLevel(causalSents)
vader = Vader_sents_SentLevel(causalSents)
sentiStrength = Senti_sents_SentLevel(causalSents)

df2 = pd.DataFrame(list(zip(causalSents, allen, afinn, vader,sentiStrength)), columns =['Causal Sentence', 'AllenNLP','Afinn','Vader','SentiStrength'])
df2["Weight"] = df2.sum(axis=1)


sentPolarity = []
sentsWeight_sentLevel = []

for index, row in df2.iterrows():
    sentWeightTuple = []
    weight = row['Weight']
    sentWeightTuple.append(weight)
    sentsWeight_sentLevel.append(sentWeightTuple)
    #print(weight)
    if weight is -4:
        sentPolarity.append('Strong Negative') 
        #print('Strong Negative')
    elif weight is -3:
        sentPolarity.append('Moderate Negative')
        #print('Moderate Negative')
    elif weight is -2:
        sentPolarity.append('Mild Negative')
        #print('Mild Negative')
    elif weight is -1:
        sentPolarity.append('Weak Negative')
        #print('Weak Negative')
    elif weight is 0:
        sentPolarity.append('Neutral')
        #print('Neutral')
    elif weight is 4:
        sentPolarity.append('Strong Positive')
        #print('Strong Positive')
    elif weight is 3:
        sentPolarity.append('Moderate Positive')
        #print('Moderate Positive')
    elif weight is 2:
        sentPolarity.append('Mild Positive')
        #print('Mild Positive')
    elif weight is 1:
        sentPolarity.append('Weak Positive')
        #print('Weak Positive')

df2["Polarity"] = sentPolarity
df2.style
# Out:
# <style  type="text/css" >
# </style><table id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >AllenNLP</th>        <th class="col_heading level0 col2" >Afinn</th>        <th class="col_heading level0 col3" >Vader</th>        <th class="col_heading level0 col4" >SentiStrength</th>        <th class="col_heading level0 col5" >Weight</th>        <th class="col_heading level0 col6" >Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col1" class="data row0 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col2" class="data row0 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col3" class="data row0 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col4" class="data row0 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col5" class="data row0 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row0_col6" class="data row0 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col1" class="data row1 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col2" class="data row1 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col4" class="data row1 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col5" class="data row1 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row1_col6" class="data row1 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col1" class="data row2 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col2" class="data row2 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col3" class="data row2 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col4" class="data row2 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col5" class="data row2 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row2_col6" class="data row2 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col1" class="data row3 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col2" class="data row3 col2" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col3" class="data row3 col3" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col4" class="data row3 col4" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col5" class="data row3 col5" >-4</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row3_col6" class="data row3 col6" >Strong Negative</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col1" class="data row4 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row4_col6" class="data row4 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col1" class="data row5 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row5_col6" class="data row5 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col1" class="data row6 col1" >-1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col4" class="data row6 col4" >1</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col5" class="data row6 col5" >0</td>
#                         <td id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92row6_col6" class="data row6 col6" >Neutral</td>
#             </tr>
#             <tr>
#                         <th id="T_8662afc6_3cf2_11ec_a9b8_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8

# %% [markdown]
# # Causal Triples' Polarity (Token Level)

# %% [markdown]
# ### [AllenNlp]

# %%
allen_word = []
allen_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks: 
        #print(token)
        preds = predictor.predict(str(token))
            #print(preds['label'][0])
        label = preds['label'][0]
        if label is '0':
            allen_tuple.append(-1)
                #allen_word.append(-1)
        else:
                #allen_word.append(1)
            allen_tuple.append(1)
    allen_word.append(allen_tuple)
    allen_tuple = []
                
for a,b in zip(causalTriples,allen_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, -1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, -1, 1]
# (no irrigation infrastructure, shows, public investment) [-1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 1, -1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, -1]
# (persistent heavy rains, cause, flooding) [-1, 1, -1]
# (persistent heavy rains, cause, the ethiopian highlands) [-1, 1, 1]
# (persistent heavy rains, cause, flood prone areas) [-1, 1, -1]
# (persistent heavy rains, cause, flood-prone areas) [-1, 1, -1]
# (highly saturated soils, cause, flooding) [1, 1, -1]
# (rain, caused, floods) [-1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (floods, impact, south sudan) [1, 1, 1]
# (floods, impact, food security) [1, 1, 1]

# %% [markdown]
# ### [Afinn]

# %%
afinn_word = []
afinn_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
        #if str(token) not in marks:
            #print(token)
        score = afn.score(str(token))
        if score > 0:
                #print('positive')
            afinn_tuple.append(1)
        elif score < 0:
                #print('negative')
            afinn_tuple.append(-1)
        else:
                #print('neutral')
            afinn_tuple.append(0)
    afinn_word.append(afinn_tuple)
    afinn_tuple = []

for a,b in zip(causalTriples,afinn_word):
   # print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [0, 0, 0]
# (the low level, shows, no irrigation infrastructure) [0, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, flooding) [0, 0, 0]
# (persistent heavy rains, cause, the ethiopian highlands) [0, 0, 0]
# (persistent heavy rains, cause, flood prone areas) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flooding) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, 0]
# (floods, impact, south sudan) [0, 0, 0]
# (floods, impact, food security) [0, 0, 0]

# %% [markdown]
# ### [Vader]

# %%
vader_word = []
vader_tuple = []

for tokenTuple in causalTriples:
    #print(sent)
    for token in tokenTuple:
        #if str(token) not in marks:
        vs = analyzer.polarity_scores(str(token))
        compound = vs['compound']
        if compound >= 0.05:
            vader_tuple.append(1)   
        elif compound <= -0.05 :
            vader_tuple.append(-1)
        elif  compound > -0.05 and compound < 0.05:
            vader_tuple.append(0)
    vader_word.append(vader_tuple)
    vader_tuple = []

for a,b in zip(causalTriples,vader_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 0, 0]
# (institutional weakness, hindered, the agriculture sector) [-1, 0, 0]
# (no irrigation infrastructure, shows, public investment) [-1, 0, 0]
# (the low level, shows, public investment) [-1, 0, 0]
# (the low level, shows, no irrigation infrastructure) [-1, 0, -1]
# (south sudan's limited road network, shows, only 2 percent) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, markets) [-1, 0, 0]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 0, 0]
# (persistent heavy rains, cause, flooding) [0, 0, 0]
# (persistent heavy rains, cause, the ethiopian highlands) [0, 0, 0]
# (persistent heavy rains, cause, flood prone areas) [0, 0, 0]
# (persistent heavy rains, cause, flood-prone areas) [0, 0, 0]
# (highly saturated soils, cause, flooding) [0, 0, 0]
# (rain, caused, floods) [0, 0, 0]
# (floods, have displaced, more than 100,000 people) [0, 0, 0]
# (floods, have displaced, south sudan) [0, 0, 0]
# (floods, raise, fears) [0, 0, -1]
# (floods, impact, south sudan) [0, 0, 0]
# (floods, impact, food security) [0, 0, 1]

# %% [markdown]
# ### [SentiStrength]

# %%
senti_word = []
senti_tuple = []

for tokenTuple in causalTriples:
    #print(tokenTuple)
    for token in tokenTuple:
        #if str(token) not in marks:
        #print(token)
        result = senti.getSentiment(str(token), score='binary')
            #print(result)
        if result[0]==1:
                #print('Positive')
            senti_tuple.append(1)
        elif result[0]==-1:
                #print('Negative')
            senti_tuple.append(-1)
        else:
                #print('Neutral')
            senti_tuple.append(0)
    senti_word.append(senti_tuple)
    senti_tuple = []
    
for a,b in zip(causalTriples,senti_word):
    #print(len(a))
    print(a,b)
# Out:
# (institutional weakness, hindered, development) [-1, 1, 1]
# (institutional weakness, hindered, the agriculture sector) [-1, 1, 1]
# (no irrigation infrastructure, shows, public investment) [1, 1, 1]
# (the low level, shows, public investment) [-1, 1, 1]
# (the low level, shows, no irrigation infrastructure) [-1, 1, 1]
# (south sudan's limited road network, shows, only 2 percent) [1, 1, 1]
# (inadequate transportation infrastructure, resulted, markets) [-1, 1, 1]
# (inadequate transportation infrastructure, resulted, less transport) [-1, 1, 1]
# (persistent heavy rains, cause, flooding) [1, 1, 1]
# (persistent heavy rains, cause, the ethiopian highlands) [1, 1, 1]
# (persistent heavy rains, cause, flood prone areas) [1, 1, 1]
# (persistent heavy rains, cause, flood-prone areas) [1, 1, 1]
# (highly saturated soils, cause, flooding) [1, 1, 1]
# (rain, caused, floods) [1, 1, 1]
# (floods, have displaced, more than 100,000 people) [1, -1, 1]
# (floods, have displaced, south sudan) [1, -1, 1]
# (floods, raise, fears) [1, 1, -1]
# (floods, impact, south sudan) [1, 1, 1]
# (floods, impact, food security) [1, 1, 1]

# %% [markdown]
# ### Data Frame (Causal Triples Token Level)

# %%
sum_list = []
sum_tup = []
limit= len(causalTriples)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

triplesWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    triplesWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

triplePolarity_list = DetectPolarity(triplesWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([causalTriples[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],triplesWeight_TokenLevel[i],triplePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Triple Weight','Triple Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0           1              2
# Tokens           (institutional, weakness)  (hindered)  (development)
# AllenNlp                                -1          -1              1
# Afinn                                   -1           0              0
# Vader                                   -1           0              0
# SentiStrength                           -1           1              1
# Token Weight                            -4           0              2
# Token Polarity             Strong Negative     Neutral  Mild Positive
# Triple Weight                        -0.67        None           None
# Triple Polarity              Weak Negative        None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                          0           1  \
# Tokens           (institutional, weakness)  (hindered)
# AllenNlp                                -1          -1
# Afinn                                   -1           0
# Vader                                   -1           0
# SentiStrength                           -1           1
# Token Weight                            -4           0
# Token Polarity             Strong Negative     Neutral
# Triple Weight                        -0.67        None
# Triple Polarity              Weak Negative        None
#
#                                           2
# Tokens           (the, agriculture, sector)
# AllenNlp                                  1
# Afinn                                     0
# Vader                                     0
# SentiStrength                             1
# Token Weight                              2
# Token Polarity                Mild Positive
# Triple Weight                          None
# Triple Polarity                        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                 0              1  \
# Tokens           (no, irrigation, infrastructure)          shows
# AllenNlp                                       -1              1
# Afinn                                          -1              0
# Vader                                          -1              0
# SentiStrength                                   1              1
# Token Weight                                   -2              2
# Token Polarity                      Mild Negative  Mild Positive
# Triple Weight                                0.67           None
# Triple Polarity                     Weak Positive           None
#
#                                     2
# Tokens           (public, investment)
# AllenNlp                            1
# Afinn                               0
# Vader                               0
# SentiStrength                       1
# Token Weight                        2
# Token Polarity          Mild Positive
# Triple Weight                    None
# Triple Polarity                  None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1                     2
# Tokens           (the, low, level)          shows  (public, investment)
# AllenNlp                        -1              1                     1
# Afinn                            0              0                     0
# Vader                           -1              0                     0
# SentiStrength                   -1              1                     1
# Token Weight                    -3              2                     2
# Token Polarity   Moderate Negative  Mild Positive         Mild Positive
# Triple Weight                 0.33           None                  None
# Triple Polarity      Weak Positive           None                  None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1  \
# Tokens           (the, low, level)          shows
# AllenNlp                        -1              1
# Afinn                            0              0
# Vader                           -1              0
# SentiStrength                   -1              1
# Token Weight                    -3              2
# Token Polarity   Moderate Negative  Mild Positive
# Triple Weight                   -1           None
# Triple Polarity      Weak Negative           None
#
#                                                 2
# Tokens           (no, irrigation, infrastructure)
# AllenNlp                                       -1
# Afinn                                          -1
# Vader                                          -1
# SentiStrength                                   1
# Token Weight                                   -2
# Token Polarity                      Mild Negative
# Triple Weight                                None
# Triple Polarity                              None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                           0              1  \
# Tokens           (south, sudan, 's, limited, road, network)          shows
# AllenNlp                                                 -1              1
# Afinn                                                    -1              0
# Vader                                                    -1              0
# SentiStrength                                             1              1
# Token Weight                                             -2              2
# Token Polarity                                Mild Negative  Mild Positive
# Triple Weight                                             0           None
# Triple Polarity                                     Neutral           None
#
#                                   2
# Tokens           (only, 2, percent)
# AllenNlp                         -1
# Afinn                             0
# Vader                             0
# SentiStrength                     1
# Token Weight                      0
# Token Polarity              Neutral
# Triple Weight                  None
# Triple Polarity                None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                             0              1  \
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                               0           None
# Triple Polarity                                       Neutral           None
#
#                              2
# Tokens               (markets)
# AllenNlp                     1
# Afinn                        0
# Vader                        0
# SentiStrength                1
# Token Weight                 2
# Token Polarity   Mild Positive
# Triple Weight             None
# Triple Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                                             0              1  \
# Tokens           (inadequate, transportation, infrastructure)       resulted
# AllenNlp                                                   -1              1
# Afinn                                                      -1              0
# Vader                                                      -1              0
# SentiStrength                                              -1              1
# Token Weight                                               -4              2
# Token Polarity                                Strong Negative  Mild Positive
# Triple Weight                                           -0.67           None
# Triple Polarity                                 Weak Negative           None
#
#                                  2
# Tokens           (less, transport)
# AllenNlp                        -1
# Afinn                            0
# Vader                            0
# SentiStrength                    1
# Token Weight                     0
# Token Polarity             Neutral
# Triple Weight                 None
# Triple Polarity               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1           2
# Tokens           (persistent, heavy, rains)        (cause)  (flooding)
# AllenNlp                                 -1              1          -1
# Afinn                                     0              0           0
# Vader                                     0              0           0
# SentiStrength                             1              1           1
# Token Weight                              0              2           0
# Token Polarity                      Neutral  Mild Positive     Neutral
# Triple Weight                          0.67           None        None
# Triple Polarity               Weak Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          1.33           None
# Triple Polarity               Mild Positive           None
#
#                                            2
# Tokens           (the, ethiopian, highlands)
# AllenNlp                                   1
# Afinn                                      0
# Vader                                      0
# SentiStrength                              1
# Token Weight                               2
# Token Polarity                 Mild Positive
# Triple Weight                           None
# Triple Polarity                         None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)        (cause)
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          0.67           None
# Triple Polarity               Weak Positive           None
#
#                                      2
# Tokens           (flood, prone, areas)
# AllenNlp                            -1
# Afinn                                0
# Vader                                0
# SentiStrength                        1
# Token Weight                         0
# Token Polarity                 Neutral
# Triple Weight                     None
# Triple Polarity                   None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1  \
# Tokens           (persistent, heavy, rains)          cause
# AllenNlp                                 -1              1
# Afinn                                     0              0
# Vader                                     0              0
# SentiStrength                             1              1
# Token Weight                              0              2
# Token Polarity                      Neutral  Mild Positive
# Triple Weight                          0.67           None
# Triple Polarity               Weak Positive           None
#
#                                         2
# Tokens           (flood, -, prone, areas)
# AllenNlp                               -1
# Afinn                                   0
# Vader                                   0
# SentiStrength                           1
# Token Weight                            0
# Token Polarity                    Neutral
# Triple Weight                        None
# Triple Polarity                      None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                           0              1           2
# Tokens           (highly, saturated, soils)        (cause)  (flooding)
# AllenNlp                                  1              1          -1
# Afinn                                     0              0           0
# Vader                                     0              0           0
# SentiStrength                             1              1           1
# Token Weight                              2              2           0
# Token Polarity                Mild Positive  Mild Positive     Neutral
# Triple Weight                          1.33           None        None
# Triple Polarity               Mild Positive           None        None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1              2
# Tokens                  (rain)       (caused)       (floods)
# AllenNlp                    -1              1              1
# Afinn                        0              0              0
# Vader                        0              0              0
# SentiStrength                1              1              1
# Token Weight                 0              2              2
# Token Polarity         Neutral  Mild Positive  Mild Positive
# Triple Weight             1.33           None           None
# Triple Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1  \
# Tokens                (floods)  (have, displaced)
# AllenNlp                     1                 -1
# Afinn                        0                  0
# Vader                        0                  0
# SentiStrength                1                 -1
# Token Weight                 2                 -2
# Token Polarity   Mild Positive      Mild Negative
# Triple Weight             0.67               None
# Triple Polarity  Weak Positive               None
#
#                                              2
# Tokens           (more, than, 100,000, people)
# AllenNlp                                     1
# Afinn                                        0
# Vader                                        0
# SentiStrength                                1
# Token Weight                                 2
# Token Polarity                   Mild Positive
# Triple Weight                             None
# Triple Polarity                           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0                  1               2
# Tokens                (floods)  (have, displaced)  (south, sudan)
# AllenNlp                     1                 -1               1
# Afinn                        0                  0               0
# Vader                        0                  0               0
# SentiStrength                1                 -1               1
# Token Weight                 2                 -2               2
# Token Polarity   Mild Positive      Mild Negative   Mild Positive
# Triple Weight             0.67               None            None
# Triple Polarity  Weak Positive               None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1                  2
# Tokens                (floods)        (raise)            (fears)
# AllenNlp                     1              1                 -1
# Afinn                        0              0                  0
# Vader                        0              0                 -1
# SentiStrength                1              1                 -1
# Token Weight                 2              2                 -3
# Token Polarity   Mild Positive  Mild Positive  Moderate Negative
# Triple Weight             0.33           None               None
# Triple Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                              0              1               2
# Tokens                (floods)         impact  (south, sudan)
# AllenNlp                     1              1               1
# Afinn                        0              0               0
# Vader                        0              0               0
# SentiStrength                1              1               1
# Token Weight                 2              2               2
# Token Polarity   Mild Positive  Mild Positive   Mild Positive
# Triple Weight                2           None            None
# Triple Polarity  Mild Positive           None            None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0              1                  2
# Tokens                    (floods)         impact   (food, security)
# AllenNlp                         1              1                  1
# Afinn                            0              0                  0
# Vader                            0              0                  1
# SentiStrength                    1              1                  1
# Token Weight                     2              2                  3
# Token Polarity       Mild Positive  Mild Positive  Moderate Positive
# Triple Weight                 2.33           None               None
# Triple Polarity  Moderate Positive           None               None

# %% [markdown]
# # Causal Sentences' Polarity (Token Level)

# %% [markdown]
# ### Generating list of tokens without stop words and punctuation marks.

# %%
def GenerateTokens(causalSentences):
    marks = ['.',',','(',')','-',':',';','/',"'s",'_','__','--','"', '’', '—']
    token_list = []
   
    for sent in causalSentences:
        token_tuple = []
        for token in sent:
            if str(token) not in marks:
                if str(token) not in stopwords.words():
                    token_tuple.append(str(token))
        token_list.append(token_tuple)
    return token_list
        
#print(len(token_list))
#print(token_list)

# %% [markdown]
# ### [AllenNlp]

# %%
def Allen_sents_TokenLevel(token_list):
    allen_word = []
    allen_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks: 
                #print(token)
            preds = predictor.predict(str(token))
                #print(preds['label'][0])
            label = preds['label'][0]
            if label is '0':
                allen_tuple.append(-1)
                    #allen_word.append(-1)
            else:
                    #allen_word.append(1)
                allen_tuple.append(1)
        allen_word.append(allen_tuple)
        allen_tuple = []
    return allen_word

#for a in allen_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Afinn]

# %%
def Afinn_sents_TokenLevel(token_list):
    afinn_word = []
    afinn_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) != ".": #or str(token) != ',' or str(token) != "-":
            #if str(token) not in marks:
                #print(token)
            score = afn.score(str(token))
            if score > 0:
                    #print('positive')
                afinn_tuple.append(1)
            elif score < 0:
                    #print('negative')
                afinn_tuple.append(-1)
            else:
                    #print('neutral')
                afinn_tuple.append(0)
        afinn_word.append(afinn_tuple)
        afinn_tuple = []
    return afinn_word

#for a in afinn_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [Vader]

# %%
def Vader_sents_TokenLevel(token_list):
    vader_word = []
    vader_tuple = []

    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
            vs = analyzer.polarity_scores(str(token))
            compound = vs['compound']
            if compound >= 0.05:
                vader_tuple.append(1)   
            elif compound <= -0.05 :
                vader_tuple.append(-1)
            elif  compound > -0.05 and compound < 0.05:
                vader_tuple.append(0)
        vader_word.append(vader_tuple)
        vader_tuple = []
    return vader_word

#for a in vader_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### [SentiStrength]

# %%
def Senti_sents_TokenLevel(token_list):
    senti_word = []
    senti_tuple = []
    for tokenTuple in token_list:
        #print(sent)
        for token in tokenTuple:
            #if str(token) not in marks:
                #print(token)
            result = senti.getSentiment(str(token), score='binary')
                #print(result)
            if result[0]==1:
                    #print('Positive')
                senti_tuple.append(1)
            elif result[0]==-1:
                    #print('Negative')
                senti_tuple.append(-1)
            else:
                    #print('Neutral')
                senti_tuple.append(0)
        senti_word.append(senti_tuple)
        senti_tuple = []
    return senti_word
    
#for a in senti_word:
#    print(len(a))
#    print(a)

# %% [markdown]
# ### Data Frame (Causal Sentences Word Level)

# %%
token_list = GenerateTokens(causalSents)
allen_word = Allen_sents_TokenLevel(token_list)
afinn_word = Afinn_sents_TokenLevel(token_list)
vader_word = Vader_sents_TokenLevel(token_list)   
senti_word = Senti_sents_TokenLevel(token_list)

sum_list = []
sum_tup = []
limit= len(causalSents)

#print(limit)
for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    for j in range(0,len(allen_word[i])):
        res = allen_word[i][j]+afinn_word[i][j]+vader_word[i][j]+senti_word[i][j]
        #print(res)
        sum_tup.append(res)
    sum_list.append(sum_tup)
    sum_tup = []
    
def DetectPolarity(sum_list):
    tokenPolarity = []
    tokenPolarity_list = []
    for s in sum_list:
        for weight in s:
            if weight >= -4.0 and weight < -3.0:
                tokenPolarity.append('Strong Negative') 
            elif weight >= -3 and weight < -2:
                tokenPolarity.append('Moderate Negative')
            elif weight >= -2 and weight < -1:
                tokenPolarity.append('Mild Negative')
            elif weight >= -1 and weight < 0:
                tokenPolarity.append('Weak Negative')
            elif weight == 0:
                tokenPolarity.append('Neutral')
            elif weight <= 4 and weight > 3:
                tokenPolarity.append('Strong Positive')
            elif weight <= 3 and weight > 2:
                tokenPolarity.append('Moderate Positive')
            elif weight <= 2 and weight > 1:
                tokenPolarity.append('Mild Positive')
            elif weight <= 1 and weight > 0:
                tokenPolarity.append('Weak Positive')
        tokenPolarity_list.append(tokenPolarity)
        tokenPolarity = []
    return tokenPolarity_list

tokenPolarity_list = DetectPolarity(sum_list)

sentsWeight_TokenLevel = []
weightSumTup = []
for t in sum_list:
    tripleWeight = 0
    total = len(t)
    #print(total)
    for w in t:
        tripleWeight = tripleWeight + w
    tripleWeight = round(tripleWeight/total, 2)
    weightSumTup.append(tripleWeight)
    sentsWeight_TokenLevel.append(weightSumTup)
    weightSumTup = []

SentencePolarity_list = DetectPolarity(sentsWeight_TokenLevel)

#Old algorithm that detects triples' polarity by counting the token polarities with highest frequency
#maxPolarity = []
#triplePolarity_list = []
#for t in tokenPolarity_list:
#    counter=collections.Counter(t)
#    maxPolarity.append(counter.most_common(1)[0][0])
#    triplePolarity_list.append(maxPolarity)
#    maxPolarity = []


def dataframe_WordLevel(i):
    df = pd.DataFrame([token_list[i],allen_word[i],afinn_word[i],vader_word[i],senti_word[i],sum_list[i],tokenPolarity_list[i],sentsWeight_TokenLevel[i],SentencePolarity_list[i]], 
                      index =   ['Tokens','AllenNlp','Afinn','Vader','SentiStrength','Token Weight','Token Polarity','Sentence Weight','Sentence Polarity'])
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return df

for i in range(0,limit):
    df = dataframe_WordLevel(i)
    #df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
    #display(df)
    #df.to_excel(r'./Text/output.xlsx', index = False)
    replicator(df)

#for s,w,p in zip(sum_list,weightSum,triplePolarity_list):
#    print(s,w,p)
# Out:
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                1         2              3  \
# Tokens             institutional         weakness  hindered    development
# AllenNlp                       1               -1        -1              1
# Afinn                          0               -1         0              0
# Vader                          0               -1         0              0
# SentiStrength                  1               -1         1              1
# Token Weight                   2               -4         0              2
# Token Polarity     Mild Positive  Strong Negative   Neutral  Mild Positive
# Sentence Weight             0.67             None      None           None
# Sentence Polarity  Weak Positive             None      None           None
#
#                                4              5
# Tokens               agriculture         sector
# AllenNlp                       1              1
# Afinn                          0              0
# Vader                          0              0
# SentiStrength                  1              1
# Token Weight                   2              2
# Token Polarity     Mild Positive  Mild Positive
# Sentence Weight             None           None
# Sentence Polarity           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 1.12           None           None
# Sentence Polarity      Mild Positive           None           None
#
#                                3              4           5               6  \
# Tokens                investment          shows  irrigation  infrastructure
# AllenNlp                       1              1          -1               1
# Afinn                          0              0           0               0
# Vader                          0              0           0               0
# SentiStrength                  1              1           1               1
# Token Weight                   2              2           0               2
# Token Polarity     Mild Positive  Mild Positive     Neutral   Mild Positive
# Sentence Weight             None           None        None            None
# Sentence Polarity           None           None        None            None
#
#                                7
# Tokens                    exists
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                    0              1              2  \
# Tokens                           low          level         public
# AllenNlp                          -1              1              1
# Afinn                              0              0              0
# Vader                             -1              0              0
# SentiStrength                     -1              1              1
# Token Weight                      -3              2              2
# Token Polarity     Moderate Negative  Mild Positive  Mild Positive
# Sentence Weight                 0.85           None           None
# Sentence Polarity      Weak Positive           None           None
#
#                                3              4              5              6  \
# Tokens                investment          shows              2        percent
# AllenNlp                       1              1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1              1              1              1
# Token Weight                   2              2              2              2
# Token Polarity     Mild Positive  Mild Positive  Mild Positive  Mild Positive
# Sentence Weight             None           None           None           None
# Sentence Polarity           None           None           None           None
#
#                          7        8              9       10             11  \
# Tokens               south    sudan        limited     road        network
# AllenNlp                -1       -1             -1       -1              1
# Afinn                    0        0             -1        0              0
# Vader                    0        0             -1        0              0
# SentiStrength            1        1              1        1              1
# Token Weight             0        0             -2        0              2
# Token Polarity     Neutral  Neutral  Mild Negative  Neutral  Mild Positive
# Sentence Weight       None     None           None     None           None
# Sentence Polarity     None     None           None     None           None
#
#                               12
# Tokens                     paved
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                  0               1               2  \
# Tokens                  inadequate  transportation  infrastructure
# AllenNlp                        -1               1               1
# Afinn                           -1               0               0
# Vader                           -1               0               0
# SentiStrength                   -1               1               1
# Token Weight                    -4               2               2
# Token Polarity     Strong Negative   Mild Positive   Mild Positive
# Sentence Weight               0.86            None            None
# Sentence Polarity    Weak Positive            None            None
#
#                                3        4              5              6
# Tokens                  resulted     less      transport        markets
# AllenNlp                       1       -1              1              1
# Afinn                          0        0              0              0
# Vader                          0        0              0              0
# SentiStrength                  1        1              1              1
# Token Weight                   2        0              2              2
# Token Polarity     Mild Positive  Neutral  Mild Positive  Mild Positive
# Sentence Weight             None     None           None           None
# Sentence Polarity           None     None           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2              3  \
# Tokens                persistent    heavy    rains      ethiopian
# AllenNlp                       1       -1       -1              1
# Afinn                          0        0        0              0
# Vader                          0        0        0              0
# SentiStrength                  1        1        1              1
# Token Weight                   2        0        0              2
# Token Polarity     Mild Positive  Neutral  Neutral  Mild Positive
# Sentence Weight                1     None     None           None
# Sentence Polarity  Weak Positive     None     None           None
#
#                                4              5         6        7        8  \
# Tokens                 highlands          cause  flooding    flood    prone
# AllenNlp                       1              1        -1       -1       -1
# Afinn                          0              0         0        0        0
# Vader                          0              0         0        0        0
# SentiStrength                  1              1         1        1        1
# Token Weight                   2              2         0        0        0
# Token Polarity     Mild Positive  Mild Positive   Neutral  Neutral  Neutral
# Sentence Weight             None           None      None     None     None
# Sentence Polarity           None           None      None     None     None
#
#                                9
# Tokens                     areas
# AllenNlp                       1
# Afinn                          0
# Vader                          0
# SentiStrength                  1
# Token Weight                   2
# Token Polarity     Mild Positive
# Sentence Weight             None
# Sentence Polarity           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0        1        2        3        4  \
# Tokens                persistent    heavy    rains    south    sudan
# AllenNlp                       1       -1       -1       -1       -1
# Afinn                          0        0        0        0        0
# Vader                          0        0        0        0        0
# SentiStrength                  1        1        1        1        1
# Token Weight                   2        0        0        0        0
# Token Polarity     Mild Positive  Neutral  Neutral  Neutral  Neutral
# Sentence Weight              0.6     None     None     None     None
# Sentence Polarity  Weak Positive     None     None     None     None
#
#                                5         6        7        8              9
# Tokens                     cause  flooding    flood    prone          areas
# AllenNlp                       1        -1       -1       -1              1
# Afinn                          0         0        0        0              0
# Vader                          0         0        0        0              0
# SentiStrength                  1         1        1        1              1
# Token Weight                   2         0        0        0              2
# Token Polarity     Mild Positive   Neutral  Neutral  Neutral  Mild Positive
# Sentence Weight             None      None     None     None           None
# Sentence Polarity           None      None     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0          1        2              3         4  \
# Tokens                    highly  saturated    soils          cause  flooding
# AllenNlp                       1         -1       -1              1        -1
# Afinn                          0          0        0              0         0
# Vader                          0          0        0              0         0
# SentiStrength                  1          1        1              1         1
# Token Weight                   2          0        0              2         0
# Token Polarity     Mild Positive    Neutral  Neutral  Mild Positive   Neutral
# Sentence Weight             0.75       None     None           None      None
# Sentence Polarity  Weak Positive       None     None           None      None
#
#                          5        6              7
# Tokens               flood    prone          areas
# AllenNlp                -1       -1              1
# Afinn                    0        0              0
# Vader                    0        0              0
# SentiStrength            1        1              1
# Token Weight             0        0              2
# Token Polarity     Neutral  Neutral  Mild Positive
# Sentence Weight       None     None           None
# Sentence Polarity     None     None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2
# Tokens                      rain         caused         floods
# AllenNlp                      -1              1              1
# Afinn                          0              0              0
# Vader                          0              0              0
# SentiStrength                  1              1              1
# Token Weight                   0              2              2
# Token Polarity           Neutral  Mild Positive  Mild Positive
# Sentence Weight             1.33           None           None
# Sentence Polarity  Mild Positive           None           None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1              2              3  \
# Tokens                    floods      displaced        100,000         people
# AllenNlp                       1             -1              1              1
# Afinn                          0              0              0              0
# Vader                          0              0              0              0
# SentiStrength                  1             -1              1              1
# Token Weight                   2             -2              2              2
# Token Polarity     Mild Positive  Mild Negative  Mild Positive  Mild Positive
# Sentence Weight             0.67           None           None           None
# Sentence Polarity  Weak Positive           None           None           None
#
#                          4        5
# Tokens               south    sudan
# AllenNlp                -1       -1
# Afinn                    0        0
# Vader                    0        0
# SentiStrength            1        1
# Token Weight             0        0
# Token Polarity     Neutral  Neutral
# Sentence Weight       None     None
# Sentence Polarity     None     None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0              1                  2
# Tokens                    floods          raise              fears
# AllenNlp                       1              1                 -1
# Afinn                          0              0                  0
# Vader                          0              0                 -1
# SentiStrength                  1              1                 -1
# Token Weight                   2              2                 -3
# Token Polarity     Mild Positive  Mild Positive  Moderate Negative
# Sentence Weight             0.33           None               None
# Sentence Polarity  Weak Positive           None               None
# HBox(children=(Button(description='Copy', style=ButtonStyle()), Dropdown(options=('Full DataFrame/Series', 'Ex…
#                                0                  1              2  \
# Tokens                    floods      devastatingly         impact
# AllenNlp                       1                 -1              1
# Afinn                          0                  0              0
# Vader                          0                 -1              0
# SentiStrength                  1                 -1              1
# Token Weight                   2                 -3              2
# Token Polarity     Mild Positive  Moderate Negative  Mild Positive
# Sentence Weight             0.86               None           None
# Sentence Polarity  Weak Positive               None           None
#
#                                3                  4        5        6
# Tokens                      food           security    south    sudan
# AllenNlp                       1                  1       -1       -1
# Afinn                          0                  0        0        0
# Vader                          0                  1        0        0
# SentiStrength                  1                  1        1        1
# Token Weight                   2                  3        0        0
# Token Polarity     Mild Positive  Moderate Positive  Neutral  Neutral
# Sentence Weight             None               None     None     None
# Sentence Polarity           None               None     None     None

# %% [markdown]
# # Overall Polarity of Sents and Triples by all Four Methods

# %% [markdown]
# ### Follow the following instructions (steps) before executing the cell given below
# #### Step1- Execute cell for setting causalSents to causalSentences (with duplicates).
# #### Step2- Execute cell for computing sentences' polarity at sentence level.
# #### Step3- Execute cell for computing sentences' polarity at token level.
# #### Step4- Execute the below cell.

# %%
totalWeight_AllMethods = []

limit= len(causalSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+triplesWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/4,2)
        sum_tup.append(res)
    totalWeight_AllMethods.append(sum_tup)
    
totalPlarity_AllMethods = DetectPolarity(totalWeight_AllMethods)

df_AllMethods = pd.DataFrame(list(zip(causalSents, causalTriples, sentsWeight_sentLevel, triplesWeight_sentLevel, sentsWeight_TokenLevel, triplesWeight_TokenLevel, totalWeight_AllMethods,totalPlarity_AllMethods)), 
                             columns =['Causal Sentence', 'Causal Triple', 'Method1 (Sent_SentLevel)', 'Method2 (Trip_SentLevel)','Method3 (Sent_TokLevel)','Method4 (Trip_TokLevel)','Total Weight','Overall Polarity'])

df_AllMethods.style

# %% [markdown]
# # Overall Polarity of Triples at two (sentence and token) levels

# %%
totalTriplesWeight_AllLevels = []

limit= len(causalTriples)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(triplesWeight_sentLevel[i])):
        res = triplesWeight_sentLevel[i][j]+triplesWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalTriplesWeight_AllLevels.append(sum_tup)
    
totalTripsPlarity_AllLevels = DetectPolarity(totalTriplesWeight_AllLevels)

df_TripAllLevels = pd.DataFrame(list(zip(causalTriples, triplesWeight_sentLevel, triplesWeight_TokenLevel, totalTriplesWeight_AllLevels, totalTripsPlarity_AllLevels)), 
                             columns =['Causal Triple', 'Weight (Trip_SentLevel)','Weight (Trip_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_TripAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d559be8c_3cf2_11ec_a91c_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Triple</th>        <th class="col_heading level0 col1" >Weight (Trip_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Trip_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col0" class="data row0 col0" >(institutional weakness, hindered, development)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col2" class="data row0 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col3" class="data row0 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row0_col4" class="data row0 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col0" class="data row1 col0" >(institutional weakness, hindered, the agriculture sector)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col2" class="data row1 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col3" class="data row1 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row1_col4" class="data row1 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col0" class="data row2 col0" >(no irrigation infrastructure, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col1" class="data row2 col1" >[-1]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col2" class="data row2 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col3" class="data row2 col3" >[-0.16]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row2_col4" class="data row2 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col0" class="data row3 col0" >(the low level, shows, public investment)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col1" class="data row3 col1" >[-3]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col2" class="data row3 col2" >[0.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col3" class="data row3 col3" >[-1.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col0" class="data row4 col0" >(the low level, shows, no irrigation infrastructure)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col1" class="data row4 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col2" class="data row4 col2" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col3" class="data row4 col3" >[-2.5]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row4_col4" class="data row4 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col0" class="data row5 col0" >(south sudan's limited road network, shows, only 2 percent)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col1" class="data row5 col1" >[-2]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col2" class="data row5 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col3" class="data row5 col3" >[-1.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row5_col4" class="data row5 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col0" class="data row6 col0" >(inadequate transportation infrastructure, resulted, markets)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col1" class="data row6 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col2" class="data row6 col2" >[0.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col3" class="data row6 col3" >[-2.0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row6_col4" class="data row6 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col0" class="data row7 col0" >(inadequate transportation infrastructure, resulted, less transport)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col1" class="data row7 col1" >[-4]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col2" class="data row7 col2" >[-0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col3" class="data row7 col3" >[-2.33]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row7_col4" class="data row7 col4" >['Moderate Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col0" class="data row8 col0" >(persistent heavy rains, cause, flooding)</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col1" class="data row8 col1" >[0]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col3" class="data row8 col3" >[0.34]</td>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row8_col4" class="data row8 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d559be8c_3cf2_11ec_a91c_648099c56c92level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d559be8c_3cf2_11ec_a91c_648099c56c92row9_col0" class="data row9 col0" >(persistent heavy r

# %% [markdown]
# # Overall Polarity of Sentences at two (sentence and token) Levels

# %%
totalSentsWeight_AllLevels = []

limit= len(causalSents)

for i in range(0,limit):
    #dataframe_WordLevel(i)
    #print(len(allen_word[i]))
    sum_tup = []
    for j in range(0,len(sentsWeight_sentLevel[i])):
        res = sentsWeight_sentLevel[i][j]+sentsWeight_TokenLevel[i][j]
        #print(res)
        res = round(res/2,2)
        sum_tup.append(res)
    totalSentsWeight_AllLevels.append(sum_tup)
    
totalSentsPolarity_AllLevels = DetectPolarity(totalSentsWeight_AllLevels)

df_SentsAllLevels = pd.DataFrame(list(zip(causalSents, sentsWeight_sentLevel, sentsWeight_TokenLevel, totalSentsWeight_AllLevels, totalSentsPolarity_AllLevels)), 
                             columns =['Causal Sentence', 'Weight (Sent_SentLevel)','Weight (Sent_TokLevel)','Total Weight (All Levels)','Overall Polarity'])

df_SentsAllLevels.style
# Out:
# <style  type="text/css" >
# </style><table id="T_d560e568_3cf2_11ec_870b_648099c56c92" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Causal Sentence</th>        <th class="col_heading level0 col1" >Weight (Sent_SentLevel)</th>        <th class="col_heading level0 col2" >Weight (Sent_TokLevel)</th>        <th class="col_heading level0 col3" >Total Weight (All Levels)</th>        <th class="col_heading level0 col4" >Overall Polarity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col0" class="data row0 col0" >institutional weakness hindered development of the agriculture sector.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col1" class="data row0 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col2" class="data row0 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col3" class="data row0 col3" >[-1.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row0_col4" class="data row0 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col0" class="data row1 col0" >the low level of public investment shows that no irrigation infrastructure exists.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col1" class="data row1 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col2" class="data row1 col2" >[1.12]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col3" class="data row1 col3" >[-1.44]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row1_col4" class="data row1 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col0" class="data row2 col0" >the low level of public investment shows that only 2 percent of south sudan's limited road network is paved.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col1" class="data row2 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col2" class="data row2 col2" >[0.85]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col3" class="data row2 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row2_col4" class="data row2 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col0" class="data row3 col0" >inadequate transportation infrastructure has resulted in less transport to markets.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col1" class="data row3 col1" >[-4]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col2" class="data row3 col2" >[0.86]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col3" class="data row3 col3" >[-1.57]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row3_col4" class="data row3 col4" >['Mild Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col0" class="data row4 col0" >persistent heavy rains in the ethiopian highlands cause flooding in flood prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col1" class="data row4 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col2" class="data row4 col2" >[1.0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col3" class="data row4 col3" >[0.5]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row4_col4" class="data row4 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col0" class="data row5 col0" >persistent heavy rains in south sudan cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col1" class="data row5 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col2" class="data row5 col2" >[0.6]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col3" class="data row5 col3" >[0.3]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row5_col4" class="data row5 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col0" class="data row6 col0" >highly saturated soils cause flooding in flood-prone areas.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col1" class="data row6 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col2" class="data row6 col2" >[0.75]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col3" class="data row6 col3" >[0.38]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row6_col4" class="data row6 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col0" class="data row7 col0" >rain caused floods.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col1" class="data row7 col1" >[0]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col2" class="data row7 col2" >[1.33]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col3" class="data row7 col3" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row7_col4" class="data row7 col4" >['Weak Positive']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col0" class="data row8 col0" >floods have displaced more than 100,000 people in south sudan.</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col1" class="data row8 col1" >[-2]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col2" class="data row8 col2" >[0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col3" class="data row8 col3" >[-0.67]</td>
#                         <td id="T_d560e568_3cf2_11ec_870b_648099c56c92row8_col4" class="data row8 col4" >['Weak Negative']</td>
#             </tr>
#             <tr>
#                         <th id="T_d560e568_3cf2_11ec_870b_648099c56c92level0_row9" class="row_heading level0

# %% [markdown]
# # Plot the Polarized/Modified Causal Graph.

# %% [raw]
# cg = nx.DiGraph()
#
# for ce in polarizedCauseffect:
#     s = str(ce[0])
#     d = str(ce[2])
#     cg.add_node(s,id = str(s),title=str(s),x=615,y=200)
#     cg.add_node(d,id = str(d),title=str(d),x=615,y=200)
#     cg.add_edge(s, d, predicade=str(ce[1]))
#
# print(len(cg.nodes))
# print(len(cg.edges))
#
# pos = nx.spring_layout(cg, k=4, iterations=20)
# plt.figure(figsize=(15,12))
#
# nx.draw(cg, pos=pos, with_labels=True,  node_shape="s",  node_color="none", font_size=15,  font_color='royalblue', font_weight='bold',bbox=dict(facecolor="white", alpha=0.4,boxstyle='round,pad=0.8'),labels={node: node for node in cg.nodes()},arrows=True, arrowsize=15,width=1)
# edge_labels = nx.get_edge_attributes(cg,'predicade')
# nx.draw_networkx_edge_labels(cmap, pos=pos, edge_labels = edge_labels, font_color='black',font_size=13)
#
# plt.axis('off')
# plt.show()
